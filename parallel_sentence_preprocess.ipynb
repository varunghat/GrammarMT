# %%
import numpy as np
import pandas as pd
import json 
import os

from tqdm import tqdm

# %%
with open("parallel_sentences_cleaned.json","r",encoding="utf-8") as f:
    data = json.load(f)

print(data[0])
# Out:
# {'kannada': 'ಹುĪ', 'transliteration': 'huḷi', 'english': 'sour', 'page': 31, 'block_start': 6, 'block_end': 6}

# %%
eng_1word = {}
kannada_1word = {}
other_sentences = []

for item in data:
    eng_words = item['english'].split()
    kannada_words = item['transliteration'].split()
    
    # Check if English is 1 word
    if len(eng_words) == 1:
        eng_1word[item['transliteration']] = item['english']
    # Check if Kannada is 1 word but English is not
    elif len(kannada_words) == 1 and len(eng_words) > 1:
        kannada_1word[item['transliteration']] = item['english']
    # Everything else
    else:
        other_sentences.append({
            'transliteration': item['transliteration'],
            'english': item['english']
        })

print(f"Number of 1-word English sentences: {len(eng_1word)}")
print(f"Number of 1-word Kannada sentences: {len(kannada_1word)}")
print(f"Number of other sentences: {len(other_sentences)}")
# Out:
# Number of 1-word English sentences: 413
# Number of 1-word Kannada sentences: 396
# Number of other sentences: 393

# %%
# Display the first 10 sentences of 1 word english
# Display first 10 items from eng_1word dictionary
for i, (kannada, english) in enumerate(list(eng_1word.items())[:10]):
    print(f"{i+1}. Kannada: {kannada} -> English: {english}")
# Out:
# 1. Kannada: huḷi -> English: sour
# 2. Kannada: huli -> English: tiger
# 3. Kannada: haḷḷi -> English: village
# 4. Kannada: halli -> English: lizard
# 5. Kannada: maṇe -> English: stool
# 6. Kannada: mane -> English: house
# 7. Kannada: hālu -> English: milk
# 8. Kannada: hallu -> English: tooth
# 9. Kannada: dēva -> English: god
# 10. Kannada: devva -> English: spirit

# %%
# Display first 10 items from kannada_1word dictionary
for i, (kannada, english) in enumerate(list(kannada_1word.items())[:10]):
    print(f"{i+1}. Kannada: {kannada} -> English: {english}")
# Out:
# 1. Kannada: ōḍu -> English: to run
# 2. Kannada: ōdu -> English: to read
# 3. Kannada: hēḷu -> English: to say
# 4. Kannada: hēlu -> English: to shit
# 5. Kannada: baḍi -> English: to beat
# 6. Kannada: baḍḍi -> English: interest (on money)
# 7. Kannada: maḍi -> English: ritually pure
# 8. Kannada: māḍi -> English: please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:
# 9. Kannada: nīnu -> English: you (singular and non-honorific)
# 10. Kannada: nīvu -> English: you (plural / honorific)

# %%
# POS Tagging
import spacy
nlp = spacy.load("en_core_web_sm")

def pos_tagging(sentences):
    pos_tags = []
    for sentence in tqdm(sentences):
        doc = nlp(sentence)
        tags = [(token.text, token.pos_) for token in doc]
        pos_tags.append(tags)
    return pos_tags
# Out:
# 100%|██████████| 413/413 [00:03<00:00, 115.85it/s]
# Sentence 1:
# huḷi: NOUN
#
# Sentence 2:
# huli: PROPN
#
# Sentence 3:
# haḷḷi: PROPN
#
# Sentence 4:
# halli: PROPN
#
# Sentence 5:
# maṇe: NOUN
#
# Sentence 6:
# mane: VERB
#
# Sentence 7:
# hālu: NOUN
#
# Sentence 8:
# hallu: NOUN
#
# Sentence 9:
# dēva: VERB
#
# Sentence 10:
# devva: VERB

# %%
# POS tagging for English words in eng_1word
eng_1word_sentences = list(eng_1word.values())
eng_1word_transliterations = list(eng_1word.keys())
eng_pos_tags = pos_tagging(eng_1word_sentences)
# Out:
# 100%|██████████| 413/413 [00:03<00:00, 118.75it/s]

# %%
# Show all POS tags for the first 10 sentences
for i, tags in enumerate(eng_pos_tags[:100]):
    for word, pos in tags:
        print(f"{word} ({eng_1word_transliterations[i]}): {pos}")
# Out:
# sour (huḷi): ADJ
# tiger (huli): NOUN
# village (haḷḷi): NOUN
# lizard (halli): NOUN
# stool (maṇe): PROPN
# house (mane): NOUN
# milk (hālu): NOUN
# tooth (hallu): VERB
# god (dēva): PROPN
# spirit (devva): PROPN
# I (nānu): PRON
# we (nāvu): PRON
# he (avanu): PRON
# she (avaḷu): PRON
# he (ivanu): PRON
# she (ivaḷu): PRON
# here (illi): ADV
# there (alli): ADV
# where (elli): SCONJ
# ? (elli): PUNCT
# now (īga): ADV
# then (āga): ADV
# that (adu): PRON
# closet (almāri): NOUN
# sky (ākāśa): NOUN
# this (idu): PRON
# another (innoṃdu): PRON
# today (ivattu): NOUN
# meal (ūṭa): NOUN
# town (ūru): NOUN
# two (eraḍu): NUM
# five (aidu): NUM
# one (oṃdu): NUM
# computer (kaṃpyūṭaru): NOUN
# building (kaṭṭaḍa): VERB
# paper (kāgada): NOUN
# forest (kāḍu): NOUN
# car (kāru): NOUN
# window (kiṭaki): NOUN
# chair (kurci): NOUN
# glass (gilāsu): NOUN
# goal (guri): NOUN
# teacher (guru): NOUN
# Thursday (guruvāra): PROPN
# spoon (camaca): VERB
# knife (cāku): NOUN
# mat (cāpe): NOUN
# key (cāvi): ADJ
# picture (citra): NOUN
# taxi (ṭyāksi): NOUN
# tubelight (ṭyūbulaiṭu): NOUN
# plate (taṭṭe): NOUN
# many (tuṃba): ADJ
# lamp (dīpa): PROPN
# temple (dēvasthāna): PROPN
# four (nālku): NUM
# tomorrow (nāḷe): NOUN
# floor (nela): NOUN
# fly (noṇa): VERB
# book (pustaka): NOUN
# pencil (pensilu): NOUN
# foreigner (phorenar): NOUN
# fork (phōrku): NOUN
# door (bāgilu): NOUN
# Wednesday (budhavāra): PROPN
# fire (beṃki): NOUN
# fence (bēli): NOUN
# Indian (bhāratīya): ADJ
# Tuesday (maṃgaḷavāra): PROPN
# and (mattu): CCONJ
# person (manuṣya): NOUN
# tree (mara): NOUN
# lady (mahiḷe): PROPN
# rain (maḷe): NOUN
# garland (māle): VERB
# three (mūru): NUM
# table (mēju): NOUN
# candle (mēṇabatti): NOUN
# cloud (mōḍa): PROPN
# Sunday (ravivāra): PROPN
# road (raste): NOUN
# rikshaw (rikṣā): NOUN
# airplane (vimāna): NOUN
# Saturday (śanivāra): PROPN
# Friday (śukravāra): PROPN
# suitcase (sūṭkēsu): NOUN
# sun (sūrya): PROPN
# Monday (sōmavāra): PROPN
# woman (strī): NOUN
# bird (hakki): NOUN
# many (halavu): ADJ
# cow (hasu): NOUN
# song (hāḍu): NOUN
# hippie (hippi): VERB
# boy (huḍuga): PROPN
# girl (huḍugi): NOUN
# flower (hū): NOUN
# woman (heṃgasu): NOUN
# field (hola): NOUN
# yes (haudu): INTJ
# never (yāvāgalū illa): ADV

# %%
# map the transliterations to the POS tags 
pos_mapping = {}
for i, tags in enumerate(eng_pos_tags):
    transliteration = eng_1word_transliterations[i]
    pos_mapping[transliteration] = [pos for word, pos in tags]

pos_mapping
# Out:
# {'huḷi': ['ADJ'],
#  'huli': ['NOUN'],
#  'haḷḷi': ['NOUN'],
#  'halli': ['NOUN'],
#  'maṇe': ['PROPN'],
#  'mane': ['NOUN'],
#  'hālu': ['NOUN'],
#  'hallu': ['VERB'],
#  'dēva': ['PROPN'],
#  'devva': ['PROPN'],
#  'nānu': ['PRON'],
#  'nāvu': ['PRON'],
#  'avanu': ['PRON'],
#  'avaḷu': ['PRON'],
#  'ivanu': ['PRON'],
#  'ivaḷu': ['PRON'],
#  'illi': ['ADV'],
#  'alli': ['ADV'],
#  'elli': ['SCONJ', 'PUNCT'],
#  'īga': ['ADV'],
#  'āga': ['ADV'],
#  'adu': ['PRON'],
#  'almāri': ['NOUN'],
#  'ākāśa': ['NOUN'],
#  'idu': ['PRON'],
#  'innoṃdu': ['PRON'],
#  'ivattu': ['NOUN'],
#  'ūṭa': ['NOUN'],
#  'ūru': ['NOUN'],
#  'eraḍu': ['NUM'],
#  'aidu': ['NUM'],
#  'oṃdu': ['NUM'],
#  'kaṃpyūṭaru': ['NOUN'],
#  'kaṭṭaḍa': ['VERB'],
#  'kāgada': ['NOUN'],
#  'kāḍu': ['NOUN'],
#  'kāru': ['NOUN'],
#  'kiṭaki': ['NOUN'],
#  'kurci': ['NOUN'],
#  'gilāsu': ['NOUN'],
#  'guri': ['NOUN'],
#  'guru': ['NOUN'],
#  'guruvāra': ['PROPN'],
#  'camaca': ['VERB'],
#  'cāku': ['NOUN'],
#  'cāpe': ['NOUN'],
#  'cāvi': ['ADJ'],
#  'citra': ['NOUN'],
#  'ṭyāksi': ['NOUN'],
#  'ṭyūbulaiṭu': ['NOUN'],
#  'taṭṭe': ['NOUN'],
#  'tuṃba': ['ADJ'],
#  'dīpa': ['PROPN'],
#  'dēvasthāna': ['PROPN'],
#  'nālku': ['NUM'],
#  'nāḷe': ['NOUN'],
#  'nela': ['NOUN'],
#  'noṇa': ['VERB'],
#  'pustaka': ['NOUN'],
#  'pensilu': ['NOUN'],
#  'phorenar': ['NOUN'],
#  'phōrku': ['NOUN'],
#  'bāgilu': ['NOUN'],
#  'budhavāra': ['PROPN'],
#  'beṃki': ['NOUN'],
#  'bēli': ['NOUN'],
#  'bhāratīya': ['ADJ'],
#  'maṃgaḷavāra': ['PROPN'],
#  'mattu': ['CCONJ'],
#  'manuṣya': ['NOUN'],
#  'mara': ['NOUN'],
#  'mahiḷe': ['PROPN'],
#  'maḷe': ['NOUN'],
#  'māle': ['VERB'],
#  'mūru': ['NUM'],
#  'mēju': ['NOUN'],
#  'mēṇabatti': ['NOUN'],
#  'mōḍa': ['PROPN'],
#  'ravivāra': ['PROPN'],
#  'raste': ['NOUN'],
#  'rikṣā': ['NOUN'],
#  'vimāna': ['NOUN'],
#  'śanivāra': ['PROPN'],
#  'śukravāra': ['PROPN'],
#  'sūṭkēsu': ['NOUN'],
#  'sūrya': ['PROPN'],
#  'sōmavāra': ['PROPN'],
#  'strī': ['NOUN'],
#  'hakki': ['NOUN'],
#  'halavu': ['ADJ'],
#  'hasu': ['NOUN'],
#  'hāḍu': ['NOUN'],
#  'hippi': ['VERB'],
#  'huḍuga': ['PROPN'],
#  'huḍugi': ['NOUN'],
#  'hū': ['NOUN'],
#  'heṃgasu': ['NOUN'],
#  'hola': ['NOUN'],
#  'haudu': ['INTJ'],
#  'yāvāgalū illa': ['ADV'],
#  'ēnū illa': ['PRON'],
#  'yārū illa': ['PRON'],
#  'ide': ['AUX'],
#  'ēke': ['SCONJ', 'PUNCT'],
#  'ēnu': ['PRON', 'PUNCT'],
#  'kappu': ['ADJ'],
#  'kaṣṭa': ['ADJ'],
#  'toḍaku': ['NOUN'],
#  'nanna': ['PRON'],
#  'namma': ['PRON'],
#  'patra': ['NOUN'],
#  'purōhita': ['NOUN'],
#  'biḷi': ['PROPN'],
#  'maneyavaru': ['NOUN'],
#  'yāru': ['PRON', 'PUNCT'],
#  'yāva': ['PRON', 'PUNCT'],
#  'yāvāga': ['SCONJ', 'PUNCT'],
#  'samācāra': ['NOUN'],
#  'hesaru': ['NOUN'],
#  'hēge': ['SCONJ', 'PUNCT'],
#  'appa': ['PROPN'],
#  'amma': ['NOUN'],
#  'kaṇṇu': ['NOUN'],
#  'kivi': ['NOUN'],
#  'kuri': ['NOUN'],
#  'kūsu': ['NOUN'],
#  'gaṃḍa': ['NOUN'],
#  'gaṃḍasu': ['NOUN'],
#  'nighaṃṭu': ['PROPN'],
#  'nīru': ['NOUN'],
#  'buṭṭi': ['NOUN'],
#  'maga': ['NOUN'],
#  'magaḷu': ['NOUN'],
#  'magu': ['NOUN'],
#  'māva': ['NOUN'],
#  'rāja': ['NOUN'],
#  'raita': ['NOUN'],
#  'vidhave': ['NOUN'],
#  'anubhava': ['VERB'],
#  'āṭike': ['NOUN'],
#  'āyke': ['NOUN'],
#  'keṃpu': ['PROPN'],
#  'koṃbu': ['NOUN'],
#  'koṃbe': ['NOUN'],
#  'cūpu': ['ADJ'],
#  'tudi': ['NOUN'],
#  'parimāṇa': ['NOUN'],
#  'baṭṭe': ['NOUN'],
#  'baṇṇa': ['NOUN'],
#  'bēre': ['ADJ'],
#  'saṃkhye': ['NOUN'],
#  'hasiru': ['ADJ'],
#  'haḷadi': ['ADJ'],
#  'heṃḍati': ['NOUN'],
#  'nidde': ['NOUN'],
#  'nāyi': ['NOUN'],
#  'kathe': ['NOUN'],
#  'kelasa': ['NOUN'],
#  'toṃdare': ['NOUN'],
#  'nenne': ['NOUN'],
#  'satya': ['NOUN'],
#  'haṇa': ['NOUN'],
#  'haṇṇu': ['NOUN'],
#  'mēle': ['ADP'],
#  'keḷage': ['ADP'],
#  'oḷage': ['ADP'],
#  'oḷagu': ['ADP'],
#  'hattira': ['ADP'],
#  'bage': ['VERB'],
#  'madhya': ['ADJ'],
#  'muṃde': ['ADP'],
#  'horage': ['ADV'],
#  'aḍige': ['VERB'],
#  'uttara': ['NOUN'],
#  'kāpi': ['NOUN'],
#  'gaḍi': ['NOUN'],
#  'cahā': ['NOUN'],
#  'padārtha': ['NOUN'],
#  'pavāḍa': ['NOUN'],
#  'viśēṣavāda': ['ADJ'],
#  'vaiṣṇava': ['PROPN'],
#  'samādhi': ['NOUN'],
#  'ele': ['VERB'],
#  'athavā': ['CCONJ'],
#  'abhiprāya': ['NOUN'],
#  'iḍiya': ['ADJ'],
#  'upayukta': ['ADJ'],
#  'keṭṭa': ['ADJ'],
#  'kliṣṭa': ['VERB'],
#  'gaddala': ['NOUN'],
#  'cakravarti': ['NOUN'],
#  'cikka': ['ADJ'],
#  'jagattu': ['NOUN'],
#  'dūra': ['NOUN'],
#  'nīli': ['ADJ'],
#  'praśne': ['NOUN'],
#  'bīdi': ['PROPN'],
#  'bhāra': ['NOUN'],
#  'bhārata': ['PROPN'],
#  'mukhya': ['ADJ'],
#  'yuga': ['NOUN'],
#  'saṃgīta': ['NOUN'],
#  'suṃdara': ['ADJ'],
#  'kelavu': ['PRON'],
#  'kōlu': ['VERB'],
#  'ciṃtaka': ['NOUN'],
#  'tīra': ['PROPN'],
#  'bhakta': ['NOUN'],
#  'maṭha': ['VERB'],
#  'Madhvācārya': ['PUNCT', 'NOUN', 'PUNCT'],
#  'śatamāna': ['NOUN'],
#  'saṃpradāya': ['NOUN'],
#  'hadimūraneya': ['NOUN'],
#  'āphisu': ['NOUN'],
#  'oraṭu': ['NOUN'],
#  'krūra': ['ADJ'],
#  'khuśi': ['NOUN'],
#  'tiṃgaḷu': ['NOUN'],
#  'dayaviṭṭu': ['INTJ'],
#  'pāṭha': ['NOUN'],
#  'prayatna': ['NOUN'],
#  'muṃdina': ['ADV'],
#  'yōcane': ['VERB'],
#  'vākya': ['VERB'],
#  'śabda': ['NOUN'],
#  'saṃtōṣa': ['NOUN'],
#  'sammēḷana': ['NOUN'],
#  'spaṣṭa': ['ADJ'],
#  'artha': ['VERB'],
#  'ādare': ['CCONJ'],
#  'kṣame': ['NOUN'],
#  'daya': ['NOUN'],
#  'hōṭalu': ['NOUN'],
#  'adhyāpaka': ['NOUN'],
#  'kōpa': ['NOUN'],
#  'graṃthapālaka': ['PROPN'],
#  'graṃthālaya': ['NOUN'],
#  'patrike': ['NOUN'],
#  'sahāya': ['VERB'],
#  'hemme': ['NOUN'],
#  'hōguvike': ['VERB'],
#  'bāḷike': ['VERB'],
#  'ārōgya': ['NOUN'],
#  'gōḍe': ['NOUN'],
#  'gōva': ['PROPN'],
#  'jōru': ['NOUN'],
#  'tinnu': ['VERB'],
#  'māṃsa': ['NOUN'],
#  'miliṭari': ['NOUN'],
#  'miliṭari hōṭalu': ['ADJ', 'ADJ', 'NOUN'],
#  'auṣadhi': ['NOUN'],
#  'kaṭṭe': ['VERB'],
#  'giḍa': ['NOUN'],
#  'dēvi': ['NOUN'],
#  'patni': ['NOUN'],
#  'pradakṣiṇe': ['NOUN'],
#  'bhakti': ['NOUN'],
#  'mātra': ['ADV'],
#  'saṃpattu': ['NOUN'],
#  'sādhya': ['ADJ'],
#  'sulabha': ['ADJ'],
#  'saubhāgya': ['ADV', 'PUNCT', 'NOUN'],
#  'atṛpta': ['ADJ'],
#  'atṛpti': ['NOUN'],
#  'anubhāvi': ['ADJ'],
#  'anuyāyi': ['NOUN'],
#  'asamānate': ['NOUN'],
#  'ityādi': ['X', 'X'],
#  'kuṭuṃba': ['NOUN'],
#  'kelavomme': ['ADV'],
#  'guṃpu': ['NOUN'],
#  'jāti': ['NOUN'],
#  'jīvana': ['NOUN'],
#  'tṛpta': ['ADJ'],
#  'tṛpti': ['NOUN'],
#  'dhārmika': ['ADJ'],
#  'naitika': ['ADJ'],
#  'paraṃpare': ['NOUN'],
#  'prapaṃca': ['NOUN'],
#  'prācīna': ['ADJ'],
#  'prīti': ['NOUN'],
#  'Basava': ['PUNCT', 'NOUN', 'PUNCT'],
#  'beḷavaṇige': ['NOUN'],
#  'maṃdi': ['NOUN'],
#  'manassu': ['NOUN'],
#  'samāna': ['ADJ'],
#  'samānate': ['NOUN'],
#  'sāmājika': ['ADJ'],
#  'hiṃde': ['ADP'],
#  'hinnele': ['NOUN'],
#  'hosa': ['ADJ'],
#  'anēka': ['ADJ'],
#  'ippataidu': ['NUM', 'PUNCT', 'NUM'],
#  'ēkeṃdare': ['SCONJ'],
#  'omme': ['ADV'],
#  'karāvaḷi': ['PROPN'],
#  'kaḷatmaka': ['ADJ'],
#  'kāphi': ['NOUN'],
#  'kāryakrama': ['NOUN'],
#  'kuḍuma': ['PUNCT', 'NOUN', 'PUNCT'],
#  'kēṃdra': ['NOUN'],
#  'caḷi': ['ADJ'],
#  'cikitsālaya': ['NOUN'],
#  'jille': ['NOUN'],
#  'taṃde': ['PROPN'],
#  'takṣaṇa': ['ADV'],
#  'tale': ['NOUN'],
#  'talenōvu': ['PROPN'],
#  'dēvate': ['NOUN'],
#  'Dharmasthaḷa': ['PUNCT', 'NOUN', 'PUNCT'],
#  'nōvu': ['NOUN'],
#  'paṃḍita': ['NOUN'],
#  'pūrvaja': ['NOUN'],
#  'Maṃjunātha': ['PUNCT', 'NOUN', 'PUNCT'],
#  'yātrika': ['NOUN'],
#  'rakṣaṇe': ['NOUN'],
#  'varegū': ['ADP'],
#  'varṣa': ['NOUN'],
#  'Vādirāja': ['PUNCT', 'NOUN', 'PUNCT'],
#  'śikṣaka': ['NOUN'],
#  'saṃgrahālaya': ['NOUN'],
#  'sahiṣṇute': ['NOUN'],
#  'sāṃskṛtika': ['ADJ'],
#  'sāvira': ['NUM'],
#  'sāvirāru': ['NOUN'],
#  'sumāru': ['ADV'],
#  'hadināraneya': ['ADJ'],
#  'huṣāru': ['NOUN'],
#  'ellarannu / ellarannū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellariṃda / ellariṃdalū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellara': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellaralli / ellarallū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'āru': ['NUM'],
#  'ēḷu': ['NUM'],
#  'eṃṭu': ['NUM'],
#  'oṃbattu': ['NUM'],
#  'hannoṃdu': ['NUM'],
#  'hanneraḍu': ['NUM'],
#  'hadimūru': ['NUM'],
#  'hadinālku': ['NUM'],
#  'hadinaidu': ['NUM'],
#  'hadināru': ['NUM'],
#  'hadinēḷu': ['X'],
#  'hadineṃṭu': ['NUM'],
#  'hattoṃbattu': ['NUM'],
#  'ippattu': ['NUM'],
#  'ippattoṃdu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteraḍu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattanālku': ['NUM', 'PUNCT', 'NUM'],
#  'ippattaidu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattāru': ['NUM', 'PUNCT', 'NUM'],
#  'ippattēḷu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteṃṭu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattoṃbattu': ['NUM', 'PUNCT', 'NUM'],
#  'aivattu': ['NUM'],
#  'aravattu': ['NUM'],
#  'eppattu': ['NUM'],
#  'eṃbattu': ['NUM'],
#  'toṃbattu': ['NUM'],
#  'nūru': ['NUM'],
#  'innūru': ['NUM'],
#  'munnūru': ['NUM'],
#  'nānūru': ['NUM'],
#  'ainūru': ['NUM'],
#  'ārunūru': ['NUM'],
#  'ēḷunūru': ['NUM'],
#  'eṃṭunūru': ['NUM'],
#  'oṃbainūru': ['NUM'],
#  'nūra nalvattoṃdu': ['NUM'],
#  'sāvirada oṃbainūra toṃbattaidu': ['NUM'],
#  'āgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'hōgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'utkhanana': ['NOUN'],
#  'hagga': ['NOUN'],
#  'heccu': ['ADV'],
#  'ajja': ['NOUN'],
#  'jñāna': ['NOUN'],
#  'daḍḍa': ['NOUN'],
#  'kobbu': ['ADJ'],
#  'udbhava': ['NOUN'],
#  'ayya': ['PROPN'],
#  'prabhāva': ['NOUN'],
#  'tatva': ['NOUN'],
#  'utsava': ['NOUN'],
#  'kaḷḷa': ['NOUN'],
#  'aparūpavāgi': ['ADV'],
#  'jana': ['NOUN'],
#  'bahaḷa': ['ADJ'],
#  'bhāṣe': ['NOUN'],
#  'yāvāgalū': ['ADV'],
#  'haḷeya': ['ADJ'],
#  'aṃgaḍiyavaru': ['NOUN'],
#  'ajñāna': ['NOUN'],
#  'gottu': ['NOUN'],
#  'nṛtya': ['VERB'],
#  'paravā': ['VERB'],
#  'parvata': ['NOUN'],
#  'baḷi': ['ADP'],
#  'buddhi': ['NOUN'],
#  'beḷaku': ['ADJ'],
#  'bhasma': ['PROPN'],
#  'majjige': ['NOUN'],
#  'mūgu': ['NOUN'],
#  'modalaneya': ['ADV'],
#  'rākṣasa': ['NOUN'],
#  'rūpa': ['VERB'],
#  'vimānanildāṇa': ['NOUN'],
#  'vaiṣṇavadharma': ['NOUN'],
#  'saṃkēta': ['NOUN'],
#  'saṃsthe': ['PROPN'],
#  'sāṃkētika': ['ADJ'],
#  'sāmānya': ['ADJ'],
#  'haṇe': ['PROPN']}

# %%
kan_to_eng_mapping = {}
for transliteration, english in kannada_1word.items():
    kan_to_eng_mapping[transliteration] = english

for transliteration, english in eng_1word.items():
    if transliteration not in kan_to_eng_mapping:
        kan_to_eng_mapping[transliteration] = english

kan_to_eng_mapping
# Out:
# {'ōḍu': 'to run',
#  'ōdu': 'to read',
#  'hēḷu': 'to say',
#  'hēlu': 'to shit',
#  'baḍi': 'to beat',
#  'baḍḍi': 'interest (on money)',
#  'maḍi': 'ritually pure',
#  'māḍi': 'please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:',
#  'nīnu': 'you (singular and non-honorific)',
#  'nīvu': 'you (plural / honorific)',
#  'adu': 'it / that',
#  'avaru': 'they (persons)',
#  'avu': 'they (non-persons)',
#  'idu': 'it / this',
#  'ivaru': 'he / she (honorific)',
#  'ivu': 'they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.)',
#  'hīge': 'in this manner',
#  'hāge': 'in that manner',
#  'hēge': 'in which manner?',
#  'iṣṭu': 'this much',
#  'aṣṭu': 'that much',
#  'eṣṭu': 'how much?',
#  'ide': 'it is, it exists',
#  'ili': 'mouse, rat',
#  'kālu': 'leg, foot',
#  'kai': 'hand, arm',
#  'graṃtha': 'book, volume',
#  'doḍḍa': 'big, large',
#  'paṃce': '(traditional men’s dress: ‘dhoti’)',
#  'pennu': 'ballpoint pen',
#  'pyāṃṭu': 'pair of trousers',
#  'beṭṭa': 'hill, mountain',
#  'muduki': 'old woman',
#  'maidāna': 'lawn, field',
#  'yuvati': 'young woman',
#  'luṃgi': '(traditional men’s dress: long loincloth)',
#  'vidyārthi': '[male] student',
#  'vidyārthini': '[female] student',
#  'Viṣṇu': '(name of god)',
#  'Śiva': '(name of god)',
#  'sagaṇi': 'cow dung',
#  'sāmānugaḷu': 'things, belongings',
#  'sīre': '(traditional ladies’ dress: ‘sari’)',
#  'hāḍugāra': 'singer (male)',
#  'hāḍugārti': 'singer (female)',
#  'Namaskāra.': '(the same is said when parting)',
#  'Banni.': 'Yes, you may go (‘Please come’).',
#  'Hēgiddīri?': 'How are you? Gururāja',
#  'ivara': 'his / her (honorific)',
#  'elliṃda': 'from where?',
#  'cennāgi': 'nicely, finely',
#  'nimma': 'your (honorific)',
#  'banni': 'please come',
#  'barali': 'I should come',
#  'baru': 'to come',
#  'bassu': 'bus (vehicle)',
#  'bēku': 'is wanted / required / needed',
#  'bēḍa': 'is not wanted / not required',
#  'viśēṣa': 'something special',
#  'sari': 'okay, all right, correct',
#  'akka': 'elder sister',
#  'aṇṇa': 'elder brother',
#  'kere': 'tank, water reservoir',
#  'cīla': 'bag, purse',
#  'dēśa': 'country, land',
#  'puṭa': 'page (of book etc.)',
#  'snēhita': 'friend (male)',
#  'snēhite': 'friend (female)',
#  'aṃgaḍi': 'store, shop',
#  'jana': 'person, people',
#  'jijñāsu': 'eager to learn',
#  'paṃḍite': 'learned woman',
#  'hōdenu': 'I went',
#  'ādenu': 'I became',
#  'hōdi': 'you went',
#  'ādi': 'you became',
#  'hōdanu': 'he went',
#  'ādanu': 'he became',
#  'hōdaḷu': 'she went',
#  'ādaḷu': 'she became',
#  'hōdevu': 'we went',
#  'ādevu': 'we became',
#  'hōdiri': 'you went',
#  'ādiri': 'you became',
#  'hōdaru': 'they went',
#  'ādaru': 'they became',
#  'āgu': 'to become, occur',
#  'jigi': 'to jump',
#  'kare': 'to call',
#  'taru': 'to bring',
#  'tiḷi': 'to understand',
#  'nagu': 'to laugh',
#  'bīḷu': 'to fall',
#  'māḍu': 'to do, make',
#  'hoḍe': 'to hit, strike',
#  'hōgu': 'to go',
#  'nōḍu': 'to watch, look at',
#  'bare': 'to write',
#  'anna': 'rice (cooked)',
#  'ūṭa': '(cooked) meal',
#  'koḍu': 'to give',
#  'viṣaya': 'matter, thing, topic',
#  'sāku': 'it is enough',
#  'sāladu': 'it is not enough',
#  'mēlu': 'top side',
#  'keḷagu': 'lower side',
#  'hiṃde': 'behind, ago',
#  'hiṃdu': 'rear side',
#  'āyitu': 'all right, okay',
#  'iḍu': 'to place, put',
#  'īgalū': 'also now',
#  'kaḍe': 'side, direction',
#  'kōṇe': 'room, chamber',
#  'gaḍipradēśa': 'border area',
#  'tagoḷḷu': 'to take',
#  'tuṃba': 'very, much, many',
#  'darśana': 'seeing, sight, ritual viewing of an object of reverence',
#  'nija': 'real, true',
#  'nijavāgi': 'really, truly',
#  'pradēśa': 'region, area',
#  'bāḷu': 'to live',
#  'bhakta': 'devotee, follower',
#  'śatamāna': 'century (100 years)',
#  'summane': 'just like that, quietly',
#  'svalpa': 'a bit, a little',
#  'bāḷe': 'banana tree',
#  'bēre': 'other, something else',
#  'rīti': 'style, kind',
#  'asahya': 'intolerable, disgusting',
#  'āḍu': 'to play',
#  'iṣṭa': 'liked, appreciated',
#  'ūru': 'place, village, town, ‘native place’, city',
#  'kēḷu': 'to ask, to hear',
#  'kṣētra': 'place of pilgrimage',
#  'jāga': 'place, space, spot',
#  'taṃgi': 'younger sister',
#  'tīrthaṃkara': '(holiest person in Jainism)',
#  'pūjārha': 'worthy of worship',
#  'prakāra': 'according to',
#  'manuṣya': 'human, person',
#  'mūrti': 'icon, statue',
#  'modalu': 'firstly, in the beginning',
#  'mōkṣa': '(religious) liberation',
#  'saṃsāra': '‘the worldly system of',
#  'hoṃdu': 'to acquire, achieve',
#  'kelasadavaḷu': 'housemaid (‘of-the-work she’)',
#  'maneyavaru': 'spouse (‘of-the-house person’)',
#  'avatāra': 'incarnation of a god',
#  'gurutu': 'mark, characteristic',
#  'jāsti': 'too much, excessively',
#  'taṃdaru': 'he (hon.) brought',
#  'tanna': 'his / her / its own',
#  'divasā': 'every day',
#  'pūje': 'ritual of worship',
#  'mukhya': 'something important',
#  'rathabīdi': 'Temple Street',
#  'vidēśa': 'foreign country',
#  'vaiṣṇava': 'devotee of Viṣṇu, Viṣṇuite',
#  'samudra': 'sea, ocean',
#  'hattira': 'near; nearness',
#  'heccu': 'much, a lot, very',
#  'iḷi': 'to descend, go down',
#  'kadi': 'to steal',
#  'kāpāḍu': 'to protect, guard',
#  'koḷḷu': 'to buy',
#  'jōru': 'force, forcefulness',
#  'tīvra': 'severe, intense',
#  'naḍe': 'to walk, to happen',
#  'paḍu': 'to suffer, experience, undergo',
#  'bayyu': 'to abuse, scold',
#  'beḷe': 'to grow',
#  'bhāgavahisu': 'to participate',
#  'malagu': 'to lie down, sleep',
#  'mātanāḍu': 'to speak',
#  'lēkhaki': 'writer (feminine)',
#  'vāpasu': 'back, returned',
#  'sustu': 'tiredness, fatigue',
#  'sogasu': 'grace, elegance, beauty',
#  'hattu': 'to climb; to begin',
#  'hāḍu': 'song; to sing',
#  'hāru': 'to fly, jump',
#  'horaḍu': 'to set out, leave for',
#  'kareyisu': 'to cause to call',
#  'prakaṭa': 'published, public',
#  'prayatna': 'attempt, try, effort',
#  'bēga': 'fast, soon',
#  'mēṣṭaru': '(school) teacher (‘master’)',
#  'vicitra': 'strange, odd',
#  'araḷu': 'to bloom, blossom',
#  'tamma': 'younger brother',
#  'neraḷu': 'shade, shadow',
#  'mātu': 'word, utterance',
#  'vāsa': 'living, dwelling',
#  'sigu': 'to be obtained, to be met',
#  'suddi': 'news, message',
#  'bāradu': 'may not',
#  'āse': 'desire, wish',
#  'heṃḍa': 'alcoholic beverage',
#  'eṃdare': 'i.e., that is to say',
#  'oḍati': 'mistress, owner',
#  'kāṇisu': 'to be seen, appear',
#  'kāraṇa': 'cause, reason',
#  'gottu': 'knowledge, known thing',
#  'tuḷasi': 'Indian basil',
#  'pavitra': 'pure, holy',
#  'pūjisu': 'to worship',
#  'bahaḷa': 'much, many, very',
#  'baḷasu': 'to use',
#  'beḷigge': 'in the morning',
#  'śakti': 'energy, power',
#  'śukravāra': 'energy, power',
#  'hittalu': 'back yard',
#  'hedaru': 'to fear',
#  'kareyavu': 'In modern usage, these forms are generally considered rather old-fash- ioned and hardly occur. The main reason for this is that they do not',
#  'anubhavisu': 'to experience',
#  'anubhāva': 'religious experience',
#  'kelavaru': 'some persons',
#  'kelavu': 'some (things)',
#  'guṃpugārike': 'group consciousness, ‘groupism’',
#  'naṃbu': 'to believe',
#  'baduku': 'to live',
#  'Basavaṇṇa': '(name, ‘elder brother B.’)',
#  'mānava': 'human, person',
#  'vacana': '(name of a literary form, ‘utterance’)',
#  'vaiyaktika': 'something personal',
#  'vyakti': 'person, individual',
#  'śivamaya': 'made of god',
#  'śaiva': 'pertaining to Śiva',
#  'saṃbhavisu': 'to arise, originate',
#  'sādhane': 'religious discipline / practice',
#  'sāhityakṛti': 'literary work',
#  'halavaru': 'many persons',
#  'āga': 'then, that time',
#  'ivattina': 'today’s, of today',
#  'īgina': 'of now, present',
#  'uḷi': 'to remain',
#  'kali': 'to learn',
#  'guḍḍa': 'hill, hillock',
#  'jotege': 'together with',
#  'dharmādhikāri': '(religious title and function)',
#  'neṃṭa': '(blood-) relative',
#  'pradhāna': 'main, chief',
#  'prāṇa': 'life, life force',
#  'balakaḍe': 'right (side)',
#  'beṃḍekāyi': 'okra, ‘ladies’ fingers’',
#  'muṃcitavāgi': 'beforehand, earlier',
#  'muṃduvari': 'to continue',
#  'mugi': 'to end (intr.)',
#  'mugisu': 'to end, finish (trans.)',
#  'yati': 'wandering ascetic',
#  'rūḍhi': 'custom, usage',
#  'rūpa': 'form, shape',
#  'lābha': 'profit, advantage',
#  'liṃga': '‘sign’, a particular depiction of Śiva',
#  'sinima': 'movie theatre',
#  'hāgādare': 'in that case, if that is so',
#  'hāgū': 'and, also',
#  'haṇṇugaḷellavu': '(the same)',
#  'vidyārthigaḷellaru': '(the same)',
#  'elladariṃda': 'from everything (ablative)',
#  'elladakke': 'to everything (dative)',
#  'elladara': 'of everything (genitive)',
#  'elladaralli': 'in everything (locative)',
#  'baredukoḷḷi': 'please note down [‘having written, please take’, i.e., write this down so that you need not remember]',
#  'baredukoḍi': 'please write it down for me [‘having written, please give’]',
#  'maretubiḍi!': 'please forget it!',
#  'saṃkōcapaḍabēḍa': 'don’t be shy [‘do not suffer shyness’]',
#  'oṃdu': 'one, a',
#  'oṃdannu': 'one (specific accusative)',
#  'oṃdariṃda': 'from one',
#  'oṃdakke': 'to one',
#  'oṃdara': 'of one',
#  'oṃdaralli': 'in one',
#  'eraḍannu': 'two (specific accusative)',
#  'mūrakke': 'to three',
#  'nālkara': 'of four',
#  'aidariṃda': 'from five',
#  'āraralli': 'in six Often, though, these inflected forms of the numerals must be translated in special idiomatic manners:',
#  'sāvira': '1000 When smaller numbers are added to higher units (hundreds, thousands, etc.), the connection between the higher and lower elements in the numeral is indicated by the genitive case:',
#  'oṃdaneyadu': 'the first one',
#  'hattaneyavanu': 'the tenth man These new words can of course be declined, like any pronoun or pro- nomi nalized word:',
#  'aidaneyadaralli': 'in the fifth one',
#  'hattaneyavanige': 'to the tenth man',
#  'obbanu': 'one [male] person',
#  'obbaḷu': 'one [female] person',
#  'obbaru': 'one person [politely, or neutral]',
#  'ibbaru': 'two persons',
#  'mūvaru': 'three persons',
#  'nālvaru': 'four persons',
#  'aivaru': 'five persons',
#  'ari': 'to know',
#  'aritenu': 'I knew',
#  'kalitenu': 'I learnt',
#  'mare': 'to forget',
#  'ennu': 'to say',
#  'eṃdenu': 'I said',
#  'tinnu': 'to eat',
#  'tiṃdenu': 'I ate',
#  'baydenu': 'I abused / reviled These are roots which originally, in Old Kannada, ended in a consonant',
#  'kāyu': 'to wait / grow hot',
#  'kādenu': 'I waited',
#  'kuḷiru': 'to sit down',
#  'kuḷitenu': 'I sat down',
#  'sōlu': 'to be defeated',
#  'sīnu': 'to sneeze',
#  'sītenu': 'I sneezed It should be noticed here that in the case of some of these verbs, more',
#  'ese': 'to throw',
#  'kuri': 'to aim',
#  'kusi': 'to sink down / collapse',
#  'koḷe': 'to rot',
#  'caḷi': 'to be tired',
#  'dore': 'to be obtained',
#  'bese': 'to solder',
#  'mase': 'to whet',
#  'moḷe': 'to sprout',
#  'husi': 'to speak falsehood / lie',
#  'āyu': 'to choose',
#  'oyyu': 'to carry off',
#  'koyyu': 'to reap, pluck',
#  'geyyu': 'to make',
#  'tēyu': 'to grind',
#  'toyyu': 'to become wet',
#  'māyu': 'to be hidden',
#  'mēyu': 'to graze',
#  'suyyu': 'to sigh',
#  'hāyu': 'to cross over',
#  'kavalu': 'to become branched',
#  'ciguru': 'to sprout',
#  'bevaru': 'to perspire',
#  'nāru': 'to stink',
#  'iru': 'to be',
#  'teru': 'to pay',
#  'bēsaru': 'to be bored',
#  'heru': 'to give birth',
#  'horu': 'to bear a burden',
#  'kollu': 'to kill',
#  'gellu': 'to win, overcome',
#  'nillu': 'to stand',
#  'aḷu': 'to weep',
#  'uḷu': 'to plough',
#  'ēḷu': 'to rise',
#  'kaḷu': 'to steal',
#  'kīḷu': 'to pluck, pick',
#  'biddu': '(Note the shortening of the vowel in the case of the two last-mentioned verbs.)',
#  'bēyu': 'be burnt',
#  'mīyu': 'to bathe',
#  'aḍu': 'to cook',
#  'uḍu': 'to dress',
#  'keḍu': 'to be spoilt',
#  'toḍu': 'to dress',
#  'neḍu': 'to plant',
#  'biḍu': 'to leave',
#  'suḍu': 'to burn',
#  'uṇṇu': 'to eat',
#  'kāṇu': 'to see',
#  'hogu': 'to enter',
#  'hokku': 'Alternative abbreviated forms:',
#  'ode': 'to kick',
#  'hode': 'to put on (dress)',
#  'eḷe': 'to pull',
#  'tege': 'to take',
#  'mlēccha': 'barbarian, foreigner',
#  'adannu': 'that (accusative case)',
#  'oḷḷeyadu': 'good thing',
#  'kalitare': 'if [one] learns',
#  'cennāgide': 'is good',
#  'daya': 'grace, mercy',
#  'namage': 'us (dative case)',
#  'niṃtiddāre': 'they stand',
#  'baruttāre': 'they come',
#  'mara': 'tree, wood',
#  'meccuviri': 'you will like',
#  'yaśasvi': 'glorious, successful',
#  'agnimaṃḍala': 'circle of fire',
#  'apasmara': '(name of a demon)',
#  'uṃṭāgu': 'to arise, originate',
#  'uṃṭumāḍu': 'to create',
#  'kaiyalli': '‘in the hand’, with, near',
#  'korate': 'defect, shortcoming',
#  'gaṃgādhara': '‘bearer of the Ganges’, Śiva',
#  'caṃdraśēkhara': '‘who has the moon on his crest’, Śiva',
#  'tāṃḍava': '(name of Śiva’s dance)',
#  'nakk-': '(past stem of nagu)',
#  'naṃjuṃḍa': '‘who drank poison’',
#  'nāśa': 'destruction, ruin',
#  'Madhvācārya': '(name of a philosopher)',
#  'mallikārjuna': '‘white like jasmine’',
#  'mahatva': 'greatness, importance',
#  'rēkhē': 'stripe, line',
#  'vāsasthaḷa': 'place of residence',
#  'vibhūti': 'holy ash as used by the devotees of Śiva',
#  'śivabhakta': 'devotee of Śiva',
#  'siddhapuruṣa': 'religiously liberated person',
#  'sōmaśēkhara': '‘who has the moon on his crest’, Śiva',
#  'svabhāva': 'nature, character',
#  'haccu': 'to smear, apply',
#  'huḷi': 'sour',
#  'huli': 'tiger',
#  'haḷḷi': 'village',
#  'halli': 'lizard',
#  'maṇe': 'stool',
#  'mane': 'house',
#  'hālu': 'milk',
#  'hallu': 'tooth',
#  'dēva': 'god',
#  'devva': 'spirit',
#  'nānu': 'I',
#  'nāvu': 'we',
#  'avanu': 'he',
#  'avaḷu': 'she',
#  'ivanu': 'he',
#  'ivaḷu': 'she',
#  'illi': 'here',
#  'alli': 'there',
#  'elli': 'where?',
#  'īga': 'now',
#  'almāri': 'closet',
#  'ākāśa': 'sky',
#  'innoṃdu': 'another',
#  'ivattu': 'today',
#  'eraḍu': 'two',
#  'aidu': 'five',
#  'kaṃpyūṭaru': 'computer',
#  'kaṭṭaḍa': 'building',
#  'kāgada': 'paper',
#  'kāḍu': 'forest',
#  'kāru': 'car',
#  'kiṭaki': 'window',
#  'kurci': 'chair',
#  'gilāsu': 'glass',
#  'guri': 'goal',
#  'guru': 'teacher',
#  'guruvāra': 'Thursday',
#  'camaca': 'spoon',
#  'cāku': 'knife',
#  'cāpe': 'mat',
#  'cāvi': 'key',
#  'citra': 'picture',
#  'ṭyāksi': 'taxi',
#  'ṭyūbulaiṭu': 'tubelight',
#  'taṭṭe': 'plate',
#  'dīpa': 'lamp',
#  'dēvasthāna': 'temple',
#  'nālku': 'four',
#  'nāḷe': 'tomorrow',
#  'nela': 'floor',
#  'noṇa': 'fly',
#  'pustaka': 'book',
#  'pensilu': 'pencil',
#  'phorenar': 'foreigner',
#  'phōrku': 'fork',
#  'bāgilu': 'door',
#  'budhavāra': 'Wednesday',
#  'beṃki': 'fire',
#  'bēli': 'fence',
#  'bhāratīya': 'Indian',
#  'maṃgaḷavāra': 'Tuesday',
#  'mattu': 'and',
#  'mahiḷe': 'lady',
#  'maḷe': 'rain',
#  'māle': 'garland',
#  'mūru': 'three',
#  'mēju': 'table',
#  'mēṇabatti': 'candle',
#  'mōḍa': 'cloud',
#  'ravivāra': 'Sunday',
#  'raste': 'road',
#  'rikṣā': 'rikshaw',
#  'vimāna': 'airplane',
#  'śanivāra': 'Saturday',
#  'sūṭkēsu': 'suitcase',
#  'sūrya': 'sun',
#  'sōmavāra': 'Monday',
#  'strī': 'woman',
#  'hakki': 'bird',
#  'halavu': 'many',
#  'hasu': 'cow',
#  'hippi': 'hippie',
#  'huḍuga': 'boy',
#  'huḍugi': 'girl',
#  'hū': 'flower',
#  'heṃgasu': 'woman',
#  'hola': 'field',
#  'haudu': 'yes',
#  'yāvāgalū illa': 'never',
#  'ēnū illa': 'nothing',
#  'yārū illa': 'nobody',
#  'ēke': 'why?',
#  'ēnu': 'what?',
#  'kappu': 'black',
#  'kaṣṭa': 'difficult',
#  'toḍaku': 'problem',
#  'nanna': 'my',
#  'namma': 'our',
#  'patra': 'letter',
#  'purōhita': 'priest',
#  'biḷi': 'white',
#  'yāru': 'who?',
#  'yāva': 'which?',
#  'yāvāga': 'when?',
#  'samācāra': 'news',
#  'hesaru': 'name',
#  'appa': 'father',
#  'amma': 'mother',
#  'kaṇṇu': 'eye',
#  'kivi': 'ear',
#  'kūsu': 'baby',
#  'gaṃḍa': 'husband',
#  'gaṃḍasu': 'man',
#  'nighaṃṭu': 'dictionary',
#  'nīru': 'water',
#  'buṭṭi': 'basket',
#  'maga': 'son',
#  'magaḷu': 'daughter',
#  'magu': 'child',
#  'māva': 'uncle',
#  'rāja': 'king',
#  'raita': 'farmer',
#  'vidhave': 'widow',
#  'anubhava': 'experience',
#  'āṭike': 'toy',
#  'āyke': 'choice',
#  'keṃpu': 'red',
#  'koṃbu': 'horn',
#  'koṃbe': 'branch',
#  'cūpu': 'sharp',
#  'tudi': 'tip',
#  'parimāṇa': 'size',
#  'baṭṭe': 'cloth',
#  'baṇṇa': 'colour',
#  'saṃkhye': 'number',
#  'hasiru': 'green',
#  'haḷadi': 'yellow',
#  'heṃḍati': 'wife',
#  'nidde': 'sleep',
#  'nāyi': 'dog',
#  'kathe': 'story',
#  'kelasa': 'work',
#  'toṃdare': 'trouble',
#  'nenne': 'yesterday',
#  'satya': 'truth',
#  'haṇa': 'money',
#  'haṇṇu': 'fruit',
#  'mēle': 'on',
#  'keḷage': 'under',
#  'oḷage': 'within',
#  'oḷagu': 'inside',
#  'bage': 'thought',
#  'madhya': 'middle',
#  'muṃde': 'before',
#  'horage': 'outside',
#  'aḍige': 'cooking',
#  'uttara': 'north',
#  'kāpi': 'coffee',
#  'gaḍi': 'border',
#  'cahā': 'tea',
#  'padārtha': 'thing',
#  'pavāḍa': 'miracle',
#  'viśēṣavāda': 'special',
#  'samādhi': 'tomb',
#  'ele': 'leaf',
#  'athavā': 'or',
#  'abhiprāya': 'opinion',
#  'iḍiya': 'entire',
#  'upayukta': 'useful',
#  'keṭṭa': 'bad',
#  'kliṣṭa': 'complicated',
#  'gaddala': 'noise',
#  'cakravarti': 'emperor',
#  'cikka': 'small',
#  'jagattu': 'world',
#  'dūra': 'distance',
#  'nīli': 'blue',
#  'praśne': 'question',
#  'bīdi': 'street',
#  'bhāra': 'weight',
#  'bhārata': 'India',
#  'yuga': 'era',
#  'saṃgīta': 'music',
#  'suṃdara': 'beautiful',
#  'kōlu': 'stick',
#  'ciṃtaka': 'thinker',
#  'tīra': 'coast',
#  'maṭha': 'monastery',
#  'saṃpradāya': 'tradition',
#  'hadimūraneya': 'thirteenth',
#  'āphisu': 'office',
#  'oraṭu': 'coarseness',
#  'krūra': 'cruel',
#  'khuśi': 'joy',
#  'tiṃgaḷu': 'month',
#  'dayaviṭṭu': 'please',
#  'pāṭha': 'lesson',
#  'muṃdina': 'next',
#  'yōcane': 'thought',
#  'vākya': 'sentence',
#  'śabda': 'word',
#  'saṃtōṣa': 'joy',
#  'sammēḷana': 'conference',
#  'spaṣṭa': 'clear',
#  'artha': 'meaning',
#  'ādare': 'but',
#  'kṣame': 'forgiveness',
#  'hōṭalu': 'restaurant',
#  'adhyāpaka': 'teacher',
#  'kōpa': 'anger',
#  'graṃthapālaka': 'librarian',
#  'graṃthālaya': 'library',
#  'patrike': 'magazine',
#  'sahāya': 'help',
#  'hemme': 'pride',
#  'hōguvike': 'going',
#  'bāḷike': 'living',
#  'ārōgya': 'health',
#  'gōḍe': 'wall',
#  'gōva': 'Goa',
#  'māṃsa': 'meat',
#  'miliṭari': 'military',
#  'miliṭari hōṭalu': 'non-vegetarian',
#  'auṣadhi': 'medicine',
#  'kaṭṭe': 'mount',
#  'giḍa': 'plant',
#  'dēvi': 'goddess',
#  'patni': 'wife',
#  'pradakṣiṇe': 'circumambulation',
#  'bhakti': 'devotion',
#  'mātra': 'only',
#  'saṃpattu': 'wealth',
#  'sādhya': 'possible',
#  'sulabha': 'easy',
#  'saubhāgya': 'well-being',
#  'atṛpta': 'dissatisfied',
#  'atṛpti': 'dissatisfaction',
#  'anubhāvi': 'mystic',
#  'anuyāyi': 'follower',
#  'asamānate': 'inequality',
#  'ityādi': 'etc.',
#  'kuṭuṃba': 'family',
#  'kelavomme': 'sometimes',
#  'guṃpu': 'group',
#  'jāti': 'caste',
#  'jīvana': 'life',
#  'tṛpta': 'satisfied',
#  'tṛpti': 'satisfaction',
#  'dhārmika': 'religious',
#  'naitika': 'moral',
#  'paraṃpare': 'tradition',
#  'prapaṃca': 'world',
#  'prācīna': 'ancient',
#  'prīti': 'love',
#  'Basava': '(name)',
#  'beḷavaṇige': 'development',
#  'maṃdi': 'person',
#  'manassu': 'mind',
#  'samāna': 'equal',
#  'samānate': 'equality',
#  'sāmājika': 'social',
#  'hinnele': 'background',
#  'hosa': 'new',
#  'anēka': 'many',
#  'ippataidu': 'twenty-five',
#  'ēkeṃdare': 'because',
#  'omme': 'once',
#  'karāvaḷi': 'coast',
#  'kaḷatmaka': 'artistic',
#  'kāphi': 'coffee',
#  'kāryakrama': 'program',
#  'kuḍuma': '(placename)',
#  'kēṃdra': 'centre',
#  'cikitsālaya': 'clinic',
#  'jille': 'district',
#  'taṃde': 'father',
#  'takṣaṇa': 'immediately',
#  'tale': 'head',
#  'talenōvu': 'headache',
#  'dēvate': 'divinity',
#  'Dharmasthaḷa': '(placename)',
#  'nōvu': 'pain',
#  'paṃḍita': 'scholar',
#  'pūrvaja': 'ancestor',
#  'Maṃjunātha': '(name)',
#  'yātrika': 'pilgrim',
#  'rakṣaṇe': 'protection',
#  'varegū': 'until',
#  'varṣa': 'year',
#  'Vādirāja': '(name)',
#  'śikṣaka': 'teacher',
#  'saṃgrahālaya': 'museum',
#  'sahiṣṇute': 'tolerance',
#  'sāṃskṛtika': 'cultural',
#  'sāvirāru': 'thousands',
#  'sumāru': 'approximately',
#  'hadināraneya': 'sixteenth',
#  'huṣāru': 'healthiness',
#  'ellarannu / ellarannū': '(accusative)',
#  'ellariṃda / ellariṃdalū': '(ablative)',
#  'ellara': '(genitive)',
#  'ellaralli / ellarallū': '(locative)',
#  'āru': 'six',
#  'eṃṭu': 'eight',
#  'oṃbattu': 'nine',
#  'hannoṃdu': 'eleven',
#  'hanneraḍu': 'twelve',
#  'hadimūru': 'thirteen',
#  'hadinālku': 'fourteen',
#  'hadinaidu': 'fifteen',
#  'hadināru': 'sixteen',
#  'hadinēḷu': 'seventeen',
#  'hadineṃṭu': 'eighteen',
#  'hattoṃbattu': 'nineteen',
#  'ippattu': 'twenty',
#  'ippattoṃdu': 'twenty-one',
#  'ippatteraḍu': 'twenty-two',
#  'ippattanālku': 'twenty-four',
#  'ippattaidu': 'twenty-five',
#  'ippattāru': 'twenty-six',
#  'ippattēḷu': 'twenty-seven',
#  'ippatteṃṭu': 'twenty-eight',
#  'ippattoṃbattu': 'twenty-nine',
#  'aivattu': 'fifty',
#  'aravattu': 'sixty',
#  'eppattu': 'seventy',
#  'eṃbattu': 'eighty',
#  'toṃbattu': 'ninety',
#  'nūru': 'hundred',
#  'innūru': '200',
#  'munnūru': '300',
#  'nānūru': '400',
#  'ainūru': '500',
#  'ārunūru': '600',
#  'ēḷunūru': '700',
#  'eṃṭunūru': '800',
#  'oṃbainūru': '900',
#  'nūra nalvattoṃdu': '141',
#  'sāvirada oṃbainūra toṃbattaidu': '1995',
#  'āgi': '(gerund)',
#  'hōgi': '(gerund)',
#  'utkhanana': 'excavation',
#  'hagga': 'rope',
#  'ajja': 'grandfather',
#  'jñāna': 'knowledge',
#  'daḍḍa': 'dunce',
#  'kobbu': 'fat',
#  'udbhava': 'origin',
#  'ayya': 'lord',
#  'prabhāva': 'influence',
#  'tatva': 'principle',
#  'utsava': 'feast',
#  'kaḷḷa': 'thief',
#  'aparūpavāgi': 'rarely',
#  'bhāṣe': 'language',
#  'yāvāgalū': 'always',
#  'haḷeya': 'old',
#  'aṃgaḍiyavaru': 'shopkeeper',
#  'ajñāna': 'ignorance',
#  'nṛtya': 'dance',
#  'paravā': 'worry',
#  'parvata': 'mountain',
#  'baḷi': 'near',
#  'buddhi': 'intelligence',
#  'beḷaku': 'light',
#  'bhasma': 'ash',
#  'majjige': 'buttermilk',
#  'mūgu': 'nose',
#  'modalaneya': 'first',
#  'rākṣasa': 'demon',
#  'vimānanildāṇa': 'airport',
#  'vaiṣṇavadharma': 'Viṣṇuism',
#  'saṃkēta': 'symbol',
#  'saṃsthe': 'institute',
#  'sāṃkētika': 'symbolic',
#  'sāmānya': 'ordinary',
#  'haṇe': 'forehead'}

# %%
list(kannada_1word.values())
# Out:
# ['to run',
#  'to read',
#  'to say',
#  'to shit',
#  'to beat',
#  'interest (on money)',
#  'ritually pure',
#  'please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:',
#  'you (singular and non-honorific)',
#  'you (plural / honorific)',
#  'it / that',
#  'they (persons)',
#  'they (non-persons)',
#  'it / this',
#  'he / she (honorific)',
#  'they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.)',
#  'in this manner',
#  'in that manner',
#  'in which manner?',
#  'this much',
#  'that much',
#  'how much?',
#  'it is, it exists',
#  'mouse, rat',
#  'leg, foot',
#  'hand, arm',
#  'book, volume',
#  'big, large',
#  '(traditional men’s dress: ‘dhoti’)',
#  'ballpoint pen',
#  'pair of trousers',
#  'hill, mountain',
#  'old woman',
#  'lawn, field',
#  'young woman',
#  '(traditional men’s dress: long loincloth)',
#  '[male] student',
#  '[female] student',
#  '(name of god)',
#  '(name of god)',
#  'cow dung',
#  'things, belongings',
#  '(traditional ladies’ dress: ‘sari’)',
#  'singer (male)',
#  'singer (female)',
#  '(the same is said when parting)',
#  'Yes, you may go (‘Please come’).',
#  'How are you? Gururāja',
#  'his / her (honorific)',
#  'from where?',
#  'nicely, finely',
#  'your (honorific)',
#  'please come',
#  'I should come',
#  'to come',
#  'bus (vehicle)',
#  'is wanted / required / needed',
#  'is not wanted / not required',
#  'something special',
#  'okay, all right, correct',
#  'elder sister',
#  'elder brother',
#  'tank, water reservoir',
#  'bag, purse',
#  'country, land',
#  'page (of book etc.)',
#  'friend (male)',
#  'friend (female)',
#  'store, shop',
#  'person, people',
#  'eager to learn',
#  'learned woman',
#  'I went',
#  'I became',
#  'you went',
#  'you became',
#  'he went',
#  'he became',
#  'she went',
#  'she became',
#  'we went',
#  'we became',
#  'you went',
#  'you became',
#  'they went',
#  'they became',
#  'to become, occur',
#  'to jump',
#  'to call',
#  'to bring',
#  'to understand',
#  'to laugh',
#  'to fall',
#  'to do, make',
#  'to hit, strike',
#  'to go',
#  'to watch, look at',
#  'to write',
#  'rice (cooked)',
#  '(cooked) meal',
#  'to give',
#  'matter, thing, topic',
#  'it is enough',
#  'it is not enough',
#  'top side',
#  'lower side',
#  'behind, ago',
#  'rear side',
#  'all right, okay',
#  'to place, put',
#  'also now',
#  'side, direction',
#  'room, chamber',
#  'border area',
#  'to take',
#  'very, much, many',
#  'seeing, sight, ritual viewing of an object of reverence',
#  'real, true',
#  'really, truly',
#  'region, area',
#  'to live',
#  'devotee, follower',
#  'century (100 years)',
#  'just like that, quietly',
#  'a bit, a little',
#  'banana tree',
#  'other, something else',
#  'style, kind',
#  'intolerable, disgusting',
#  'to play',
#  'liked, appreciated',
#  'place, village, town, ‘native place’, city',
#  'to ask, to hear',
#  'place of pilgrimage',
#  'place, space, spot',
#  'younger sister',
#  '(holiest person in Jainism)',
#  'worthy of worship',
#  'according to',
#  'human, person',
#  'icon, statue',
#  'firstly, in the beginning',
#  '(religious) liberation',
#  '‘the worldly system of',
#  'to acquire, achieve',
#  'housemaid (‘of-the-work she’)',
#  'spouse (‘of-the-house person’)',
#  'incarnation of a god',
#  'mark, characteristic',
#  'too much, excessively',
#  'he (hon.) brought',
#  'his / her / its own',
#  'every day',
#  'ritual of worship',
#  'something important',
#  'Temple Street',
#  'foreign country',
#  'devotee of Viṣṇu, Viṣṇuite',
#  'sea, ocean',
#  'near; nearness',
#  'much, a lot, very',
#  'to descend, go down',
#  'to steal',
#  'to protect, guard',
#  'to buy',
#  'force, forcefulness',
#  'severe, intense',
#  'to walk, to happen',
#  'to suffer, experience, undergo',
#  'to abuse, scold',
#  'to grow',
#  'to participate',
#  'to lie down, sleep',
#  'to speak',
#  'writer (feminine)',
#  'back, returned',
#  'tiredness, fatigue',
#  'grace, elegance, beauty',
#  'to climb; to begin',
#  'song; to sing',
#  'to fly, jump',
#  'to set out, leave for',
#  'to cause to call',
#  'published, public',
#  'attempt, try, effort',
#  'fast, soon',
#  '(school) teacher (‘master’)',
#  'strange, odd',
#  'to bloom, blossom',
#  'younger brother',
#  'shade, shadow',
#  'word, utterance',
#  'living, dwelling',
#  'to be obtained, to be met',
#  'news, message',
#  'may not',
#  'desire, wish',
#  'alcoholic beverage',
#  'i.e., that is to say',
#  'mistress, owner',
#  'to be seen, appear',
#  'cause, reason',
#  'knowledge, known thing',
#  'Indian basil',
#  'pure, holy',
#  'to worship',
#  'much, many, very',
#  'to use',
#  'in the morning',
#  'energy, power',
#  'energy, power',
#  'back yard',
#  'to fear',
#  'In modern usage, these forms are generally considered rather old-fash- ioned and hardly occur. The main reason for this is that they do not',
#  'to experience',
#  'religious experience',
#  'some persons',
#  'some (things)',
#  'group consciousness, ‘groupism’',
#  'to believe',
#  'to live',
#  '(name, ‘elder brother B.’)',
#  'human, person',
#  '(name of a literary form, ‘utterance’)',
#  'something personal',
#  'person, individual',
#  'made of god',
#  'pertaining to Śiva',
#  'to arise, originate',
#  'religious discipline / practice',
#  'literary work',
#  'many persons',
#  'then, that time',
#  'today’s, of today',
#  'of now, present',
#  'to remain',
#  'to learn',
#  'hill, hillock',
#  'together with',
#  '(religious title and function)',
#  '(blood-) relative',
#  'main, chief',
#  'life, life force',
#  'right (side)',
#  'okra, ‘ladies’ fingers’',
#  'beforehand, earlier',
#  'to continue',
#  'to end (intr.)',
#  'to end, finish (trans.)',
#  'wandering ascetic',
#  'custom, usage',
#  'form, shape',
#  'profit, advantage',
#  '‘sign’, a particular depiction of Śiva',
#  'movie theatre',
#  'in that case, if that is so',
#  'and, also',
#  '(the same)',
#  '(the same)',
#  'from everything (ablative)',
#  'to everything (dative)',
#  'of everything (genitive)',
#  'in everything (locative)',
#  'please note down [‘having written, please take’, i.e., write this down so that you need not remember]',
#  'please write it down for me [‘having written, please give’]',
#  'please forget it!',
#  'don’t be shy [‘do not suffer shyness’]',
#  'one, a',
#  'one (specific accusative)',
#  'from one',
#  'to one',
#  'of one',
#  'in one',
#  'two (specific accusative)',
#  'to three',
#  'of four',
#  'from five',
#  'in six Often, though, these inflected forms of the numerals must be translated in special idiomatic manners:',
#  '1000 When smaller numbers are added to higher units (hundreds, thousands, etc.), the connection between the higher and lower elements in the numeral is indicated by the genitive case:',
#  'the first one',
#  'the tenth man These new words can of course be declined, like any pronoun or pro- nomi nalized word:',
#  'in the fifth one',
#  'to the tenth man',
#  'one [male] person',
#  'one [female] person',
#  'one person [politely, or neutral]',
#  'two persons',
#  'three persons',
#  'four persons',
#  'five persons',
#  'to know',
#  'I knew',
#  'I learnt',
#  'to forget',
#  'to say',
#  'I said',
#  'to eat',
#  'I ate',
#  'I abused / reviled These are roots which originally, in Old Kannada, ended in a consonant',
#  'to wait / grow hot',
#  'I waited',
#  'to sit down',
#  'I sat down',
#  'to be defeated',
#  'to sneeze',
#  'I sneezed It should be noticed here that in the case of some of these verbs, more',
#  'to throw',
#  'to aim',
#  'to sink down / collapse',
#  'to rot',
#  'to be tired',
#  'to be obtained',
#  'to solder',
#  'to whet',
#  'to sprout',
#  'to speak falsehood / lie',
#  'to choose',
#  'to carry off',
#  'to reap, pluck',
#  'to make',
#  'to grind',
#  'to become wet',
#  'to be hidden',
#  'to graze',
#  'to sigh',
#  'to cross over',
#  'to become branched',
#  'to sprout',
#  'to perspire',
#  'to stink',
#  'to be',
#  'to pay',
#  'to be bored',
#  'to give birth',
#  'to bear a burden',
#  'to kill',
#  'to win, overcome',
#  'to stand',
#  'to weep',
#  'to plough',
#  'to rise',
#  'to steal',
#  'to pluck, pick',
#  '(Note the shortening of the vowel in the case of the two last-mentioned verbs.)',
#  'be burnt',
#  'to bathe',
#  'to cook',
#  'to dress',
#  'to be spoilt',
#  'to dress',
#  'to plant',
#  'to leave',
#  'to burn',
#  'to eat',
#  'to see',
#  'to enter',
#  'Alternative abbreviated forms:',
#  'to kick',
#  'to put on (dress)',
#  'to pull',
#  'to take',
#  'barbarian, foreigner',
#  'that (accusative case)',
#  'good thing',
#  'if [one] learns',
#  'is good',
#  'grace, mercy',
#  'us (dative case)',
#  'they stand',
#  'they come',
#  'tree, wood',
#  'you will like',
#  'glorious, successful',
#  'circle of fire',
#  '(name of a demon)',
#  'to arise, originate',
#  'to create',
#  '‘in the hand’, with, near',
#  'defect, shortcoming',
#  '‘bearer of the Ganges’, Śiva',
#  '‘who has the moon on his crest’, Śiva',
#  '(name of Śiva’s dance)',
#  '(past stem of nagu)',
#  '‘who drank poison’',
#  'destruction, ruin',
#  '(name of a philosopher)',
#  '‘white like jasmine’',
#  'greatness, importance',
#  'stripe, line',
#  'place of residence',
#  'holy ash as used by the devotees of Śiva',
#  'devotee of Śiva',
#  'religiously liberated person',
#  '‘who has the moon on his crest’, Śiva',
#  'nature, character',
#  'to smear, apply']

# %%
# POS tag for Kannada words in kannada_1word

kannada_1word_sentences = list(kannada_1word.values())
# For each sentence, remove anything inside parentheses
kannada_1word_sentences = [sentence.split('(')[0].strip() for sentence in kannada_1word_sentences]

# TODO: More preprocessing 
# 1) / implies can mean two words, so either we can split it
# 2) ? at the end of a sentence implies a question, so we can add question

kannada_1word_sentences
# Out:
# ['to run',
#  'to read',
#  'to say',
#  'to shit',
#  'to beat',
#  'interest',
#  'ritually pure',
#  'please do The two following pairs of words are prosodically similar',
#  'you',
#  'you',
#  'it / that',
#  'they',
#  'they',
#  'it / this',
#  'he / she',
#  'they / these',
#  'in this manner',
#  'in that manner',
#  'in which manner?',
#  'this much',
#  'that much',
#  'how much?',
#  'it is, it exists',
#  'mouse, rat',
#  'leg, foot',
#  'hand, arm',
#  'book, volume',
#  'big, large',
#  '',
#  'ballpoint pen',
#  'pair of trousers',
#  'hill, mountain',
#  'old woman',
#  'lawn, field',
#  'young woman',
#  '',
#  '[male] student',
#  '[female] student',
#  '',
#  '',
#  'cow dung',
#  'things, belongings',
#  '',
#  'singer',
#  'singer',
#  '',
#  'Yes, you may go',
#  'How are you? Gururāja',
#  'his / her',
#  'from where?',
#  'nicely, finely',
#  'your',
#  'please come',
#  'I should come',
#  'to come',
#  'bus',
#  'is wanted / required / needed',
#  'is not wanted / not required',
#  'something special',
#  'okay, all right, correct',
#  'elder sister',
#  'elder brother',
#  'tank, water reservoir',
#  'bag, purse',
#  'country, land',
#  'page',
#  'friend',
#  'friend',
#  'store, shop',
#  'person, people',
#  'eager to learn',
#  'learned woman',
#  'I went',
#  'I became',
#  'you went',
#  'you became',
#  'he went',
#  'he became',
#  'she went',
#  'she became',
#  'we went',
#  'we became',
#  'you went',
#  'you became',
#  'they went',
#  'they became',
#  'to become, occur',
#  'to jump',
#  'to call',
#  'to bring',
#  'to understand',
#  'to laugh',
#  'to fall',
#  'to do, make',
#  'to hit, strike',
#  'to go',
#  'to watch, look at',
#  'to write',
#  'rice',
#  '',
#  'to give',
#  'matter, thing, topic',
#  'it is enough',
#  'it is not enough',
#  'top side',
#  'lower side',
#  'behind, ago',
#  'rear side',
#  'all right, okay',
#  'to place, put',
#  'also now',
#  'side, direction',
#  'room, chamber',
#  'border area',
#  'to take',
#  'very, much, many',
#  'seeing, sight, ritual viewing of an object of reverence',
#  'real, true',
#  'really, truly',
#  'region, area',
#  'to live',
#  'devotee, follower',
#  'century',
#  'just like that, quietly',
#  'a bit, a little',
#  'banana tree',
#  'other, something else',
#  'style, kind',
#  'intolerable, disgusting',
#  'to play',
#  'liked, appreciated',
#  'place, village, town, ‘native place’, city',
#  'to ask, to hear',
#  'place of pilgrimage',
#  'place, space, spot',
#  'younger sister',
#  '',
#  'worthy of worship',
#  'according to',
#  'human, person',
#  'icon, statue',
#  'firstly, in the beginning',
#  '',
#  '‘the worldly system of',
#  'to acquire, achieve',
#  'housemaid',
#  'spouse',
#  'incarnation of a god',
#  'mark, characteristic',
#  'too much, excessively',
#  'he',
#  'his / her / its own',
#  'every day',
#  'ritual of worship',
#  'something important',
#  'Temple Street',
#  'foreign country',
#  'devotee of Viṣṇu, Viṣṇuite',
#  'sea, ocean',
#  'near; nearness',
#  'much, a lot, very',
#  'to descend, go down',
#  'to steal',
#  'to protect, guard',
#  'to buy',
#  'force, forcefulness',
#  'severe, intense',
#  'to walk, to happen',
#  'to suffer, experience, undergo',
#  'to abuse, scold',
#  'to grow',
#  'to participate',
#  'to lie down, sleep',
#  'to speak',
#  'writer',
#  'back, returned',
#  'tiredness, fatigue',
#  'grace, elegance, beauty',
#  'to climb; to begin',
#  'song; to sing',
#  'to fly, jump',
#  'to set out, leave for',
#  'to cause to call',
#  'published, public',
#  'attempt, try, effort',
#  'fast, soon',
#  '',
#  'strange, odd',
#  'to bloom, blossom',
#  'younger brother',
#  'shade, shadow',
#  'word, utterance',
#  'living, dwelling',
#  'to be obtained, to be met',
#  'news, message',
#  'may not',
#  'desire, wish',
#  'alcoholic beverage',
#  'i.e., that is to say',
#  'mistress, owner',
#  'to be seen, appear',
#  'cause, reason',
#  'knowledge, known thing',
#  'Indian basil',
#  'pure, holy',
#  'to worship',
#  'much, many, very',
#  'to use',
#  'in the morning',
#  'energy, power',
#  'energy, power',
#  'back yard',
#  'to fear',
#  'In modern usage, these forms are generally considered rather old-fash- ioned and hardly occur. The main reason for this is that they do not',
#  'to experience',
#  'religious experience',
#  'some persons',
#  'some',
#  'group consciousness, ‘groupism’',
#  'to believe',
#  'to live',
#  '',
#  'human, person',
#  '',
#  'something personal',
#  'person, individual',
#  'made of god',
#  'pertaining to Śiva',
#  'to arise, originate',
#  'religious discipline / practice',
#  'literary work',
#  'many persons',
#  'then, that time',
#  'today’s, of today',
#  'of now, present',
#  'to remain',
#  'to learn',
#  'hill, hillock',
#  'together with',
#  '',
#  '',
#  'main, chief',
#  'life, life force',
#  'right',
#  'okra, ‘ladies’ fingers’',
#  'beforehand, earlier',
#  'to continue',
#  'to end',
#  'to end, finish',
#  'wandering ascetic',
#  'custom, usage',
#  'form, shape',
#  'profit, advantage',
#  '‘sign’, a particular depiction of Śiva',
#  'movie theatre',
#  'in that case, if that is so',
#  'and, also',
#  '',
#  '',
#  'from everything',
#  'to everything',
#  'of everything',
#  'in everything',
#  'please note down [‘having written, please take’, i.e., write this down so that you need not remember]',
#  'please write it down for me [‘having written, please give’]',
#  'please forget it!',
#  'don’t be shy [‘do not suffer shyness’]',
#  'one, a',
#  'one',
#  'from one',
#  'to one',
#  'of one',
#  'in one',
#  'two',
#  'to three',
#  'of four',
#  'from five',
#  'in six Often, though, these inflected forms of the numerals must be translated in special idiomatic manners:',
#  '1000 When smaller numbers are added to higher units',
#  'the first one',
#  'the tenth man These new words can of course be declined, like any pronoun or pro- nomi nalized word:',
#  'in the fifth one',
#  'to the tenth man',
#  'one [male] person',
#  'one [female] person',
#  'one person [politely, or neutral]',
#  'two persons',
#  'three persons',
#  'four persons',
#  'five persons',
#  'to know',
#  'I knew',
#  'I learnt',
#  'to forget',
#  'to say',
#  'I said',
#  'to eat',
#  'I ate',
#  'I abused / reviled These are roots which originally, in Old Kannada, ended in a consonant',
#  'to wait / grow hot',
#  'I waited',
#  'to sit down',
#  'I sat down',
#  'to be defeated',
#  'to sneeze',
#  'I sneezed It should be noticed here that in the case of some of these verbs, more',
#  'to throw',
#  'to aim',
#  'to sink down / collapse',
#  'to rot',
#  'to be tired',
#  'to be obtained',
#  'to solder',
#  'to whet',
#  'to sprout',
#  'to speak falsehood / lie',
#  'to choose',
#  'to carry off',
#  'to reap, pluck',
#  'to make',
#  'to grind',
#  'to become wet',
#  'to be hidden',
#  'to graze',
#  'to sigh',
#  'to cross over',
#  'to become branched',
#  'to sprout',
#  'to perspire',
#  'to stink',
#  'to be',
#  'to pay',
#  'to be bored',
#  'to give birth',
#  'to bear a burden',
#  'to kill',
#  'to win, overcome',
#  'to stand',
#  'to weep',
#  'to plough',
#  'to rise',
#  'to steal',
#  'to pluck, pick',
#  '',
#  'be burnt',
#  'to bathe',
#  'to cook',
#  'to dress',
#  'to be spoilt',
#  'to dress',
#  'to plant',
#  'to leave',
#  'to burn',
#  'to eat',
#  'to see',
#  'to enter',
#  'Alternative abbreviated forms:',
#  'to kick',
#  'to put on',
#  'to pull',
#  'to take',
#  'barbarian, foreigner',
#  'that',
#  'good thing',
#  'if [one] learns',
#  'is good',
#  'grace, mercy',
#  'us',
#  'they stand',
#  'they come',
#  'tree, wood',
#  'you will like',
#  'glorious, successful',
#  'circle of fire',
#  '',
#  'to arise, originate',
#  'to create',
#  '‘in the hand’, with, near',
#  'defect, shortcoming',
#  '‘bearer of the Ganges’, Śiva',
#  '‘who has the moon on his crest’, Śiva',
#  '',
#  '',
#  '‘who drank poison’',
#  'destruction, ruin',
#  '',
#  '‘white like jasmine’',
#  'greatness, importance',
#  'stripe, line',
#  'place of residence',
#  'holy ash as used by the devotees of Śiva',
#  'devotee of Śiva',
#  'religiously liberated person',
#  '‘who has the moon on his crest’, Śiva',
#  'nature, character',
#  'to smear, apply']

# %%
kannada_1word_transliterations = list(kannada_1word.keys())
kannada_pos_tags = pos_tagging(kannada_1word_sentences)
# Show all POS tags for the first 10 sentences
# Out:
# 100%|██████████| 396/396 [00:01<00:00, 290.65it/s]

# %%
kannada_pos_tags
# Out:
# [[('to', 'PART'), ('run', 'VERB')],
#  [('to', 'PART'), ('read', 'VERB')],
#  [('to', 'PART'), ('say', 'VERB')],
#  [('to', 'PART'), ('shit', 'VERB')],
#  [('to', 'PART'), ('beat', 'VERB')],
#  [('interest', 'NOUN')],
#  [('ritually', 'ADV'), ('pure', 'ADJ')],
#  [('please', 'INTJ'),
#   ('do', 'VERB'),
#   ('The', 'DET'),
#   ('two', 'NUM'),
#   ('following', 'VERB'),
#   ('pairs', 'NOUN'),
#   ('of', 'ADP'),
#   ('words', 'NOUN'),
#   ('are', 'AUX'),
#   ('prosodically', 'ADV'),
#   ('similar', 'ADJ')],
#  [('you', 'PRON')],
#  [('you', 'PRON')],
#  [('it', 'PRON'), ('/', 'PUNCT'), ('that', 'PRON')],
#  [('they', 'PRON')],
#  [('they', 'PRON')],
#  [('it', 'PRON'), ('/', 'PUNCT'), ('this', 'PRON')],
#  [('he', 'PRON'), ('/', 'SYM'), ('she', 'PRON')],
#  [('they', 'PRON'), ('/', 'PUNCT'), ('these', 'PRON')],
#  [('in', 'ADP'), ('this', 'DET'), ('manner', 'NOUN')],
#  [('in', 'ADP'), ('that', 'DET'), ('manner', 'NOUN')],
#  [('in', 'ADP'), ('which', 'PRON'), ('manner', 'NOUN'), ('?', 'PUNCT')],
#  [('this', 'PRON'), ('much', 'ADJ')],
#  [('that', 'ADV'), ('much', 'ADV')],
#  [('how', 'SCONJ'), ('much', 'ADJ'), ('?', 'PUNCT')],
#  [('it', 'PRON'),
#   ('is', 'AUX'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('exists', 'VERB')],
#  [('mouse', 'PROPN'), (',', 'PUNCT'), ('rat', 'CCONJ')],
#  [('leg', 'PROPN'), (',', 'PUNCT'), ('foot', 'NOUN')],
#  [('hand', 'NOUN'), (',', 'PUNCT'), ('arm', 'VERB')],
#  [('book', 'NOUN'), (',', 'PUNCT'), ('volume', 'NOUN')],
#  [('big', 'ADJ'), (',', 'PUNCT'), ('large', 'ADJ')],
#  [],
#  [('ballpoint', 'PROPN'), ('pen', 'NOUN')],
#  [('pair', 'NOUN'), ('of', 'ADP'), ('trousers', 'NOUN')],
#  [('hill', 'PROPN'), (',', 'PUNCT'), ('mountain', 'NOUN')],
#  [('old', 'ADJ'), ('woman', 'NOUN')],
#  [('lawn', 'PROPN'), (',', 'PUNCT'), ('field', 'NOUN')],
#  [('young', 'ADJ'), ('woman', 'NOUN')],
#  [],
#  [('[', 'X'), ('male', 'NOUN'), (']', 'X'), ('student', 'NOUN')],
#  [('[', 'X'), ('female', 'ADJ'), (']', 'PUNCT'), ('student', 'NOUN')],
#  [],
#  [],
#  [('cow', 'NOUN'), ('dung', 'PROPN')],
#  [('things', 'NOUN'), (',', 'PUNCT'), ('belongings', 'NOUN')],
#  [],
#  [('singer', 'NOUN')],
#  [('singer', 'NOUN')],
#  [],
#  [('Yes', 'INTJ'),
#   (',', 'PUNCT'),
#   ('you', 'PRON'),
#   ('may', 'AUX'),
#   ('go', 'VERB')],
#  [('How', 'SCONJ'),
#   ('are', 'AUX'),
#   ('you', 'PRON'),
#   ('?', 'PUNCT'),
#   ('Gururāja', 'NOUN')],
#  [('his', 'PRON'), ('/', 'SYM'), ('her', 'PRON')],
#  [('from', 'ADP'), ('where', 'SCONJ'), ('?', 'PUNCT')],
#  [('nicely', 'ADV'), (',', 'PUNCT'), ('finely', 'ADV')],
#  [('your', 'PRON')],
#  [('please', 'INTJ'), ('come', 'VERB')],
#  [('I', 'PRON'), ('should', 'AUX'), ('come', 'VERB')],
#  [('to', 'PART'), ('come', 'VERB')],
#  [('bus', 'NOUN')],
#  [('is', 'AUX'),
#   ('wanted', 'VERB'),
#   ('/', 'SYM'),
#   ('required', 'VERB'),
#   ('/', 'SYM'),
#   ('needed', 'VERB')],
#  [('is', 'AUX'),
#   ('not', 'PART'),
#   ('wanted', 'VERB'),
#   ('/', 'PUNCT'),
#   ('not', 'PART'),
#   ('required', 'VERB')],
#  [('something', 'PRON'), ('special', 'ADJ')],
#  [('okay', 'INTJ'),
#   (',', 'PUNCT'),
#   ('all', 'ADV'),
#   ('right', 'ADV'),
#   (',', 'PUNCT'),
#   ('correct', 'ADJ')],
#  [('elder', 'ADJ'), ('sister', 'NOUN')],
#  [('elder', 'ADJ'), ('brother', 'NOUN')],
#  [('tank', 'NOUN'), (',', 'PUNCT'), ('water', 'NOUN'), ('reservoir', 'NOUN')],
#  [('bag', 'PROPN'), (',', 'PUNCT'), ('purse', 'NOUN')],
#  [('country', 'NOUN'), (',', 'PUNCT'), ('land', 'NOUN')],
#  [('page', 'NOUN')],
#  [('friend', 'NOUN')],
#  [('friend', 'NOUN')],
#  [('store', 'PROPN'), (',', 'PUNCT'), ('shop', 'NOUN')],
#  [('person', 'NOUN'), (',', 'PUNCT'), ('people', 'NOUN')],
#  [('eager', 'ADJ'), ('to', 'PART'), ('learn', 'VERB')],
#  [('learned', 'VERB'), ('woman', 'NOUN')],
#  [('I', 'PRON'), ('went', 'VERB')],
#  [('I', 'PRON'), ('became', 'VERB')],
#  [('you', 'PRON'), ('went', 'VERB')],
#  [('you', 'PRON'), ('became', 'VERB')],
#  [('he', 'PRON'), ('went', 'VERB')],
#  [('he', 'PRON'), ('became', 'VERB')],
#  [('she', 'PRON'), ('went', 'VERB')],
#  [('she', 'PRON'), ('became', 'VERB')],
#  [('we', 'PRON'), ('went', 'VERB')],
#  [('we', 'PRON'), ('became', 'VERB')],
#  [('you', 'PRON'), ('went', 'VERB')],
#  [('you', 'PRON'), ('became', 'VERB')],
#  [('they', 'PRON'), ('went', 'VERB')],
#  [('they', 'PRON'), ('became', 'VERB')],
#  [('to', 'PART'), ('become', 'VERB'), (',', 'PUNCT'), ('occur', 'VERB')],
#  [('to', 'PART'), ('jump', 'VERB')],
#  [('to', 'PART'), ('call', 'VERB')],
#  [('to', 'PART'), ('bring', 'VERB')],
#  [('to', 'PART'), ('understand', 'VERB')],
#  [('to', 'PART'), ('laugh', 'VERB')],
#  [('to', 'PART'), ('fall', 'VERB')],
#  [('to', 'PART'), ('do', 'VERB'), (',', 'PUNCT'), ('make', 'VERB')],
#  [('to', 'PART'), ('hit', 'VERB'), (',', 'PUNCT'), ('strike', 'VERB')],
#  [('to', 'PART'), ('go', 'VERB')],
#  [('to', 'PART'),
#   ('watch', 'VERB'),
#   (',', 'PUNCT'),
#   ('look', 'VERB'),
#   ('at', 'ADP')],
#  [('to', 'PART'), ('write', 'VERB')],
#  [('rice', 'NOUN')],
#  [],
#  [('to', 'PART'), ('give', 'VERB')],
#  [('matter', 'ADV'),
#   (',', 'PUNCT'),
#   ('thing', 'NOUN'),
#   (',', 'PUNCT'),
#   ('topic', 'NOUN')],
#  [('it', 'PRON'), ('is', 'AUX'), ('enough', 'ADJ')],
#  [('it', 'PRON'), ('is', 'AUX'), ('not', 'PART'), ('enough', 'ADJ')],
#  [('top', 'ADJ'), ('side', 'NOUN')],
#  [('lower', 'ADJ'), ('side', 'NOUN')],
#  [('behind', 'ADV'), (',', 'PUNCT'), ('ago', 'ADV')],
#  [('rear', 'ADJ'), ('side', 'NOUN')],
#  [('all', 'ADV'), ('right', 'ADV'), (',', 'PUNCT'), ('okay', 'INTJ')],
#  [('to', 'ADP'), ('place', 'NOUN'), (',', 'PUNCT'), ('put', 'VERB')],
#  [('also', 'ADV'), ('now', 'ADV')],
#  [('side', 'NOUN'), (',', 'PUNCT'), ('direction', 'NOUN')],
#  [('room', 'NOUN'), (',', 'PUNCT'), ('chamber', 'PROPN')],
#  [('border', 'NOUN'), ('area', 'NOUN')],
#  [('to', 'PART'), ('take', 'VERB')],
#  [('very', 'ADV'),
#   (',', 'PUNCT'),
#   ('much', 'ADJ'),
#   (',', 'PUNCT'),
#   ('many', 'ADJ')],
#  [('seeing', 'VERB'),
#   (',', 'PUNCT'),
#   ('sight', 'NOUN'),
#   (',', 'PUNCT'),
#   ('ritual', 'ADJ'),
#   ('viewing', 'NOUN'),
#   ('of', 'ADP'),
#   ('an', 'DET'),
#   ('object', 'NOUN'),
#   ('of', 'ADP'),
#   ('reverence', 'NOUN')],
#  [('real', 'ADJ'), (',', 'PUNCT'), ('true', 'ADJ')],
#  [('really', 'ADV'), (',', 'PUNCT'), ('truly', 'ADV')],
#  [('region', 'PROPN'), (',', 'PUNCT'), ('area', 'NOUN')],
#  [('to', 'PART'), ('live', 'VERB')],
#  [('devotee', 'NOUN'), (',', 'PUNCT'), ('follower', 'NOUN')],
#  [('century', 'NOUN')],
#  [('just', 'ADV'),
#   ('like', 'ADP'),
#   ('that', 'PRON'),
#   (',', 'PUNCT'),
#   ('quietly', 'ADV')],
#  [('a', 'DET'),
#   ('bit', 'NOUN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('little', 'ADJ')],
#  [('banana', 'PROPN'), ('tree', 'NOUN')],
#  [('other', 'ADJ'), (',', 'PUNCT'), ('something', 'PRON'), ('else', 'ADV')],
#  [('style', 'NOUN'), (',', 'PUNCT'), ('kind', 'ADJ')],
#  [('intolerable', 'ADJ'), (',', 'PUNCT'), ('disgusting', 'ADJ')],
#  [('to', 'PART'), ('play', 'VERB')],
#  [('liked', 'VERB'), (',', 'PUNCT'), ('appreciated', 'VERB')],
#  [('place', 'NOUN'),
#   (',', 'PUNCT'),
#   ('village', 'NOUN'),
#   (',', 'PUNCT'),
#   ('town', 'NOUN'),
#   (',', 'PUNCT'),
#   ('‘', 'PUNCT'),
#   ('native', 'ADJ'),
#   ('place', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('city', 'NOUN')],
#  [('to', 'PART'),
#   ('ask', 'VERB'),
#   (',', 'PUNCT'),
#   ('to', 'PART'),
#   ('hear', 'VERB')],
#  [('place', 'NOUN'), ('of', 'ADP'), ('pilgrimage', 'NOUN')],
#  [('place', 'NOUN'),
#   (',', 'PUNCT'),
#   ('space', 'NOUN'),
#   (',', 'PUNCT'),
#   ('spot', 'NOUN')],
#  [('younger', 'ADJ'), ('sister', 'NOUN')],
#  [],
#  [('worthy', 'ADJ'), ('of', 'ADP'), ('worship', 'NOUN')],
#  [('according', 'VERB'), ('to', 'ADP')],
#  [('human', 'ADJ'), (',', 'PUNCT'), ('person', 'NOUN')],
#  [('icon', 'NOUN'), (',', 'PUNCT'), ('statue', 'NOUN')],
#  [('firstly', 'ADV'),
#   (',', 'PUNCT'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('beginning', 'NOUN')],
#  [],
#  [('‘', 'PUNCT'),
#   ('the', 'DET'),
#   ('worldly', 'ADJ'),
#   ('system', 'NOUN'),
#   ('of', 'ADP')],
#  [('to', 'PART'), ('acquire', 'VERB'), (',', 'PUNCT'), ('achieve', 'VERB')],
#  [('housemaid', 'VERB')],
#  [('spouse', 'NOUN')],
#  [('incarnation', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('god', 'NOUN')],
#  [('mark', 'PROPN'), (',', 'PUNCT'), ('characteristic', 'ADJ')],
#  [('too', 'ADV'), ('much', 'ADJ'), (',', 'PUNCT'), ('excessively', 'ADV')],
#  [('he', 'PRON')],
#  [('his', 'PRON'),
#   ('/', 'SYM'),
#   ('her', 'PRON'),
#   ('/', 'SYM'),
#   ('its', 'PRON'),
#   ('own', 'ADJ')],
#  [('every', 'DET'), ('day', 'NOUN')],
#  [('ritual', 'NOUN'), ('of', 'ADP'), ('worship', 'NOUN')],
#  [('something', 'PRON'), ('important', 'ADJ')],
#  [('Temple', 'PROPN'), ('Street', 'PROPN')],
#  [('foreign', 'ADJ'), ('country', 'NOUN')],
#  [('devotee', 'NOUN'),
#   ('of', 'ADP'),
#   ('Viṣṇu', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Viṣṇuite', 'PROPN')],
#  [('sea', 'PROPN'), (',', 'PUNCT'), ('ocean', 'NOUN')],
#  [('near', 'ADV'), (';', 'PUNCT'), ('nearness', 'NOUN')],
#  [('much', 'ADV'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('lot', 'NOUN'),
#   (',', 'PUNCT'),
#   ('very', 'ADV')],
#  [('to', 'PART'),
#   ('descend', 'VERB'),
#   (',', 'PUNCT'),
#   ('go', 'VERB'),
#   ('down', 'ADV')],
#  [('to', 'PART'), ('steal', 'VERB')],
#  [('to', 'PART'), ('protect', 'VERB'), (',', 'PUNCT'), ('guard', 'NOUN')],
#  [('to', 'PART'), ('buy', 'VERB')],
#  [('force', 'NOUN'), (',', 'PUNCT'), ('forcefulness', 'NOUN')],
#  [('severe', 'ADJ'), (',', 'PUNCT'), ('intense', 'ADJ')],
#  [('to', 'PART'),
#   ('walk', 'VERB'),
#   (',', 'PUNCT'),
#   ('to', 'PART'),
#   ('happen', 'VERB')],
#  [('to', 'PART'),
#   ('suffer', 'VERB'),
#   (',', 'PUNCT'),
#   ('experience', 'NOUN'),
#   (',', 'PUNCT'),
#   ('undergo', 'VERB')],
#  [('to', 'PART'), ('abuse', 'VERB'), (',', 'PUNCT'), ('scold', 'VERB')],
#  [('to', 'PART'), ('grow', 'VERB')],
#  [('to', 'PART'), ('participate', 'VERB')],
#  [('to', 'PART'),
#   ('lie', 'VERB'),
#   ('down', 'ADV'),
#   (',', 'PUNCT'),
#   ('sleep', 'VERB')],
#  [('to', 'PART'), ('speak', 'VERB')],
#  [('writer', 'NOUN')],
#  [('back', 'ADV'), (',', 'PUNCT'), ('returned', 'VERB')],
#  [('tiredness', 'NOUN'), (',', 'PUNCT'), ('fatigue', 'NOUN')],
#  [('grace', 'NOUN'),
#   (',', 'PUNCT'),
#   ('elegance', 'NOUN'),
#   (',', 'PUNCT'),
#   ('beauty', 'NOUN')],
#  [('to', 'PART'),
#   ('climb', 'VERB'),
#   (';', 'PUNCT'),
#   ('to', 'PART'),
#   ('begin', 'VERB')],
#  [('song', 'NOUN'), (';', 'PUNCT'), ('to', 'PART'), ('sing', 'VERB')],
#  [('to', 'PART'), ('fly', 'VERB'), (',', 'PUNCT'), ('jump', 'VERB')],
#  [('to', 'PART'),
#   ('set', 'VERB'),
#   ('out', 'ADP'),
#   (',', 'PUNCT'),
#   ('leave', 'VERB'),
#   ('for', 'ADP')],
#  [('to', 'PART'), ('cause', 'VERB'), ('to', 'PART'), ('call', 'VERB')],
#  [('published', 'VERB'), (',', 'PUNCT'), ('public', 'ADJ')],
#  [('attempt', 'NOUN'),
#   (',', 'PUNCT'),
#   ('try', 'VERB'),
#   (',', 'PUNCT'),
#   ('effort', 'NOUN')],
#  [('fast', 'ADV'), (',', 'PUNCT'), ('soon', 'ADV')],
#  [],
#  [('strange', 'ADJ'), (',', 'PUNCT'), ('odd', 'ADJ')],
#  [('to', 'PART'), ('bloom', 'VERB'), (',', 'PUNCT'), ('blossom', 'NOUN')],
#  [('younger', 'ADJ'), ('brother', 'NOUN')],
#  [('shade', 'PROPN'), (',', 'PUNCT'), ('shadow', 'NOUN')],
#  [('word', 'NOUN'), (',', 'PUNCT'), ('utterance', 'NOUN')],
#  [('living', 'VERB'), (',', 'PUNCT'), ('dwelling', 'VERB')],
#  [('to', 'PART'),
#   ('be', 'AUX'),
#   ('obtained', 'VERB'),
#   (',', 'PUNCT'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('met', 'VERB')],
#  [('news', 'NOUN'), (',', 'PUNCT'), ('message', 'NOUN')],
#  [('may', 'AUX'), ('not', 'PART')],
#  [('desire', 'NOUN'), (',', 'PUNCT'), ('wish', 'VERB')],
#  [('alcoholic', 'ADJ'), ('beverage', 'NOUN')],
#  [('i.e.', 'X'),
#   (',', 'PUNCT'),
#   ('that', 'PRON'),
#   ('is', 'AUX'),
#   ('to', 'PART'),
#   ('say', 'VERB')],
#  [('mistress', 'NOUN'), (',', 'PUNCT'), ('owner', 'NOUN')],
#  [('to', 'PART'),
#   ('be', 'AUX'),
#   ('seen', 'VERB'),
#   (',', 'PUNCT'),
#   ('appear', 'VERB')],
#  [('cause', 'NOUN'), (',', 'PUNCT'), ('reason', 'NOUN')],
#  [('knowledge', 'NOUN'), (',', 'PUNCT'), ('known', 'ADJ'), ('thing', 'NOUN')],
#  [('Indian', 'ADJ'), ('basil', 'NOUN')],
#  [('pure', 'ADJ'), (',', 'PUNCT'), ('holy', 'ADJ')],
#  [('to', 'PART'), ('worship', 'VERB')],
#  [('much', 'ADJ'),
#   (',', 'PUNCT'),
#   ('many', 'ADJ'),
#   (',', 'PUNCT'),
#   ('very', 'ADV')],
#  [('to', 'PART'), ('use', 'VERB')],
#  [('in', 'ADP'), ('the', 'DET'), ('morning', 'NOUN')],
#  [('energy', 'NOUN'), (',', 'PUNCT'), ('power', 'NOUN')],
#  [('energy', 'NOUN'), (',', 'PUNCT'), ('power', 'NOUN')],
#  [('back', 'NOUN'), ('yard', 'NOUN')],
#  [('to', 'PART'), ('fear', 'VERB')],
#  [('In', 'ADP'),
#   ('modern', 'ADJ'),
#   ('usage', 'NOUN'),
#   (',', 'PUNCT'),
#   ('these', 'DET'),
#   ('forms', 'NOUN'),
#   ('are', 'AUX'),
#   ('generally', 'ADV'),
#   ('considered', 'VERB'),
#   ('rather', 'ADV'),
#   ('old', 'ADJ'),
#   ('-', 'PUNCT'),
#   ('fash-', 'ADJ'),
#   ('ioned', 'VERB'),
#   ('and', 'CCONJ'),
#   ('hardly', 'ADV'),
#   ('occur', 'VERB'),
#   ('.', 'PUNCT'),
#   ('The', 'DET'),
#   ('main', 'ADJ'),
#   ('reason', 'NOUN'),
#   ('for', 'ADP'),
#   ('this', 'PRON'),
#   ('is', 'AUX'),
#   ('that', 'SCONJ'),
#   ('they', 'PRON'),
#   ('do', 'VERB'),
#   ('not', 'PART')],
#  [('to', 'PART'), ('experience', 'VERB')],
#  [('religious', 'ADJ'), ('experience', 'NOUN')],
#  [('some', 'DET'), ('persons', 'NOUN')],
#  [('some', 'PRON')],
#  [('group', 'NOUN'),
#   ('consciousness', 'NOUN'),
#   (',', 'PUNCT'),
#   ('‘', 'PUNCT'),
#   ('groupism', 'NOUN'),
#   ('’', 'PUNCT')],
#  [('to', 'PART'), ('believe', 'VERB')],
#  [('to', 'PART'), ('live', 'VERB')],
#  [],
#  [('human', 'ADJ'), (',', 'PUNCT'), ('person', 'NOUN')],
#  [],
#  [('something', 'PRON'), ('personal', 'ADJ')],
#  [('person', 'NOUN'), (',', 'PUNCT'), ('individual', 'ADJ')],
#  [('made', 'VERB'), ('of', 'ADP'), ('god', 'PROPN')],
#  [('pertaining', 'VERB'), ('to', 'ADP'), ('Śiva', 'PROPN')],
#  [('to', 'PART'), ('arise', 'VERB'), (',', 'PUNCT'), ('originate', 'VERB')],
#  [('religious', 'ADJ'),
#   ('discipline', 'NOUN'),
#   ('/', 'SYM'),
#   ('practice', 'NOUN')],
#  [('literary', 'ADJ'), ('work', 'NOUN')],
#  [('many', 'ADJ'), ('persons', 'NOUN')],
#  [('then', 'ADV'), (',', 'PUNCT'), ('that', 'DET'), ('time', 'NOUN')],
#  [('today', 'NOUN'),
#   ('’s', 'PART'),
#   (',', 'PUNCT'),
#   ('of', 'ADP'),
#   ('today', 'NOUN')],
#  [('of', 'ADP'), ('now', 'ADV'), (',', 'PUNCT'), ('present', 'ADJ')],
#  [('to', 'PART'), ('remain', 'VERB')],
#  [('to', 'PART'), ('learn', 'VERB')],
#  [('hill', 'PROPN'), (',', 'PUNCT'), ('hillock', 'NOUN')],
#  [('together', 'ADV'), ('with', 'ADP')],
#  [],
#  [],
#  [('main', 'ADJ'), (',', 'PUNCT'), ('chief', 'NOUN')],
#  [('life', 'NOUN'), (',', 'PUNCT'), ('life', 'NOUN'), ('force', 'NOUN')],
#  [('right', 'INTJ')],
#  [('okra', 'PROPN'),
#   (',', 'PUNCT'),
#   ('‘', 'PUNCT'),
#   ('ladies', 'NOUN'),
#   ('’', 'PUNCT'),
#   ('fingers', 'NOUN'),
#   ('’', 'PUNCT')],
#  [('beforehand', 'ADV'), (',', 'PUNCT'), ('earlier', 'ADV')],
#  [('to', 'PART'), ('continue', 'VERB')],
#  [('to', 'PART'), ('end', 'VERB')],
#  [('to', 'PART'), ('end', 'VERB'), (',', 'PUNCT'), ('finish', 'VERB')],
#  [('wandering', 'VERB'), ('ascetic', 'ADJ')],
#  [('custom', 'NOUN'), (',', 'PUNCT'), ('usage', 'NOUN')],
#  [('form', 'NOUN'), (',', 'PUNCT'), ('shape', 'NOUN')],
#  [('profit', 'NOUN'), (',', 'PUNCT'), ('advantage', 'NOUN')],
#  [('‘', 'PUNCT'),
#   ('sign', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('particular', 'ADJ'),
#   ('depiction', 'NOUN'),
#   ('of', 'ADP'),
#   ('Śiva', 'PROPN')],
#  [('movie', 'NOUN'), ('theatre', 'NOUN')],
#  [('in', 'ADP'),
#   ('that', 'DET'),
#   ('case', 'NOUN'),
#   (',', 'PUNCT'),
#   ('if', 'SCONJ'),
#   ('that', 'PRON'),
#   ('is', 'AUX'),
#   ('so', 'ADV')],
#  [('and', 'CCONJ'), (',', 'PUNCT'), ('also', 'ADV')],
#  [],
#  [],
#  [('from', 'ADP'), ('everything', 'PRON')],
#  [('to', 'ADP'), ('everything', 'PRON')],
#  [('of', 'ADP'), ('everything', 'PRON')],
#  [('in', 'ADP'), ('everything', 'PRON')],
#  [('please', 'INTJ'),
#   ('note', 'VERB'),
#   ('down', 'ADP'),
#   ('[', 'X'),
#   ('‘', 'PUNCT'),
#   ('having', 'AUX'),
#   ('written', 'VERB'),
#   (',', 'PUNCT'),
#   ('please', 'INTJ'),
#   ('take', 'VERB'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('i.e.', 'X'),
#   (',', 'PUNCT'),
#   ('write', 'VERB'),
#   ('this', 'PRON'),
#   ('down', 'ADP'),
#   ('so', 'SCONJ'),
#   ('that', 'SCONJ'),
#   ('you', 'PRON'),
#   ('need', 'AUX'),
#   ('not', 'PART'),
#   ('remember', 'VERB'),
#   (']', 'PUNCT')],
#  [('please', 'INTJ'),
#   ('write', 'VERB'),
#   ('it', 'PRON'),
#   ('down', 'ADP'),
#   ('for', 'ADP'),
#   ('me', 'PRON'),
#   ('[', 'ADP'),
#   ('‘', 'PUNCT'),
#   ('having', 'AUX'),
#   ('written', 'VERB'),
#   (',', 'PUNCT'),
#   ('please', 'INTJ'),
#   ('give', 'VERB'),
#   ('’', 'PUNCT'),
#   (']', 'PUNCT')],
#  [('please', 'INTJ'), ('forget', 'VERB'), ('it', 'PRON'), ('!', 'PUNCT')],
#  [('do', 'AUX'),
#   ('n’t', 'PART'),
#   ('be', 'AUX'),
#   ('shy', 'ADJ'),
#   ('[', 'X'),
#   ('‘', 'PUNCT'),
#   ('do', 'AUX'),
#   ('not', 'PART'),
#   ('suffer', 'VERB'),
#   ('shyness', 'PROPN'),
#   ('’', 'PUNCT'),
#   (']', 'PUNCT')],
#  [('one', 'NUM'), (',', 'PUNCT'), ('a', 'PRON')],
#  [('one', 'NUM')],
#  [('from', 'ADP'), ('one', 'NUM')],
#  [('to', 'ADP'), ('one', 'NUM')],
#  [('of', 'ADP'), ('one', 'NUM')],
#  [('in', 'ADP'), ('one', 'NUM')],
#  [('two', 'NUM')],
#  [('to', 'ADP'), ('three', 'NUM')],
#  [('of', 'ADP'), ('four', 'NUM')],
#  [('from', 'ADP'), ('five', 'NUM')],
#  [('in', 'ADP'),
#   ('six', 'NUM'),
#   ('Often', 'ADV'),
#   (',', 'PUNCT'),
#   ('though', 'ADV'),
#   (',', 'PUNCT'),
#   ('these', 'PRON'),
#   ('inflected', 'VERB'),
#   ('forms', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('numerals', 'NOUN'),
#   ('must', 'AUX'),
#   ('be', 'AUX'),
#   ('translated', 'VERB'),
#   ('in', 'ADP'),
#   ('special', 'ADJ'),
#   ('idiomatic', 'ADJ'),
#   ('manners', 'NOUN'),
#   (':', 'PUNCT')],
#  [('1000', 'NUM'),
#   ('When', 'SCONJ'),
#   ('smaller', 'ADJ'),
#   ('numbers', 'NOUN'),
#   ('are', 'AUX'),
#   ('added', 'VERB'),
#   ('to', 'ADP'),
#   ('higher', 'ADJ'),
#   ('units', 'NOUN')],
#  [('the', 'DET'), ('first', 'ADJ'), ('one', 'NUM')],
#  [('the', 'DET'),
#   ('tenth', 'ADJ'),
#   ('man', 'NOUN'),
#   ('These', 'DET'),
#   ('new', 'ADJ'),
#   ('words', 'NOUN'),
#   ('can', 'AUX'),
#   ('of', 'ADP'),
#   ('course', 'NOUN'),
#   ('be', 'AUX'),
#   ('declined', 'VERB'),
#   (',', 'PUNCT'),
#   ('like', 'ADP'),
#   ('any', 'DET'),
#   ('pronoun', 'NOUN'),
#   ('or', 'CCONJ'),
#   ('pro-', 'X'),
#   ('nomi', 'ADJ'),
#   ('nalized', 'ADJ'),
#   ('word', 'NOUN'),
#   (':', 'PUNCT')],
#  [('in', 'ADP'), ('the', 'DET'), ('fifth', 'ADJ'), ('one', 'NUM')],
#  [('to', 'ADP'), ('the', 'DET'), ('tenth', 'ADJ'), ('man', 'NOUN')],
#  [('one', 'NUM'),
#   ('[', 'X'),
#   ('male', 'NOUN'),
#   (']', 'X'),
#   ('person', 'NOUN')],
#  [('one', 'NUM'),
#   ('[', 'X'),
#   ('female', 'ADJ'),
#   (']', 'PUNCT'),
#   ('person', 'NOUN')],
#  [('one', 'NUM'),
#   ('person', 'NOUN'),
#   ('[', 'PUNCT'),
#   ('politely', 'ADV'),
#   (',', 'PUNCT'),
#   ('or', 'CCONJ'),
#   ('neutral', 'ADJ'),
#   (']', 'PUNCT')],
#  [('two', 'NUM'), ('persons', 'NOUN')],
#  [('three', 'NUM'), ('persons', 'NOUN')],
#  [('four', 'NUM'), ('persons', 'NOUN')],
#  [('five', 'NUM'), ('persons', 'NOUN')],
#  [('to', 'PART'), ('know', 'VERB')],
#  [('I', 'PRON'), ('knew', 'VERB')],
#  [('I', 'PRON'), ('learnt', 'VERB')],
#  [('to', 'PART'), ('forget', 'VERB')],
#  [('to', 'PART'), ('say', 'VERB')],
#  [('I', 'PRON'), ('said', 'VERB')],
#  [('to', 'PART'), ('eat', 'VERB')],
#  [('I', 'PRON'), ('ate', 'VERB')],
#  [('I', 'PRON'),
#   ('abused', 'VERB'),
#   ('/', 'PUNCT'),
#   ('reviled', 'VERB'),
#   ('These', 'PRON'),
#   ('are', 'AUX'),
#   ('roots', 'NOUN'),
#   ('which', 'PRON'),
#   ('originally', 'ADV'),
#   (',', 'PUNCT'),
#   ('in', 'ADP'),
#   ('Old', 'PROPN'),
#   ('Kannada', 'PROPN'),
#   (',', 'PUNCT'),
#   ('ended', 'VERB'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('consonant', 'NOUN')],
#  [('to', 'PART'),
#   ('wait', 'VERB'),
#   ('/', 'SYM'),
#   ('grow', 'VERB'),
#   ('hot', 'ADJ')],
#  [('I', 'PRON'), ('waited', 'VERB')],
#  [('to', 'PART'), ('sit', 'VERB'), ('down', 'ADP')],
#  [('I', 'PRON'), ('sat', 'VERB'), ('down', 'ADP')],
#  [('to', 'PART'), ('be', 'AUX'), ('defeated', 'VERB')],
#  [('to', 'PART'), ('sneeze', 'VERB')],
#  [('I', 'PRON'),
#   ('sneezed', 'VERB'),
#   ('It', 'PRON'),
#   ('should', 'AUX'),
#   ('be', 'AUX'),
#   ('noticed', 'VERB'),
#   ('here', 'ADV'),
#   ('that', 'SCONJ'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('case', 'NOUN'),
#   ('of', 'ADP'),
#   ('some', 'PRON'),
#   ('of', 'ADP'),
#   ('these', 'DET'),
#   ('verbs', 'NOUN'),
#   (',', 'PUNCT'),
#   ('more', 'ADV')],
#  [('to', 'PART'), ('throw', 'VERB')],
#  [('to', 'PART'), ('aim', 'VERB')],
#  [('to', 'PART'),
#   ('sink', 'VERB'),
#   ('down', 'ADP'),
#   ('/', 'PUNCT'),
#   ('collapse', 'VERB')],
#  [('to', 'PART'), ('rot', 'VERB')],
#  [('to', 'PART'), ('be', 'AUX'), ('tired', 'ADJ')],
#  [('to', 'PART'), ('be', 'AUX'), ('obtained', 'VERB')],
#  [('to', 'PART'), ('solder', 'VERB')],
#  [('to', 'AUX'), ('whet', 'VERB')],
#  [('to', 'PART'), ('sprout', 'VERB')],
#  [('to', 'PART'),
#   ('speak', 'VERB'),
#   ('falsehood', 'NOUN'),
#   ('/', 'SYM'),
#   ('lie', 'NOUN')],
#  [('to', 'PART'), ('choose', 'VERB')],
#  [('to', 'PART'), ('carry', 'VERB'), ('off', 'ADP')],
#  [('to', 'PART'), ('reap', 'VERB'), (',', 'PUNCT'), ('pluck', 'VERB')],
#  [('to', 'PART'), ('make', 'VERB')],
#  [('to', 'PART'), ('grind', 'VERB')],
#  [('to', 'PART'), ('become', 'VERB'), ('wet', 'ADJ')],
#  [('to', 'PART'), ('be', 'AUX'), ('hidden', 'VERB')],
#  [('to', 'PART'), ('graze', 'VERB')],
#  [('to', 'PART'), ('sigh', 'VERB')],
#  [('to', 'PART'), ('cross', 'VERB'), ('over', 'ADP')],
#  [('to', 'PART'), ('become', 'VERB'), ('branched', 'ADJ')],
#  [('to', 'PART'), ('sprout', 'VERB')],
#  [('to', 'PART'), ('perspire', 'VERB')],
#  [('to', 'PART'), ('stink', 'VERB')],
#  [('to', 'PART'), ('be', 'AUX')],
#  [('to', 'PART'), ('pay', 'VERB')],
#  [('to', 'PART'), ('be', 'AUX'), ('bored', 'VERB')],
#  [('to', 'PART'), ('give', 'VERB'), ('birth', 'NOUN')],
#  [('to', 'PART'), ('bear', 'VERB'), ('a', 'DET'), ('burden', 'NOUN')],
#  [('to', 'PART'), ('kill', 'VERB')],
#  [('to', 'PART'), ('win', 'VERB'), (',', 'PUNCT'), ('overcome', 'VERB')],
#  [('to', 'PART'), ('stand', 'VERB')],
#  [('to', 'PART'), ('weep', 'VERB')],
#  [('to', 'PART'), ('plough', 'VERB')],
#  [('to', 'PART'), ('rise', 'VERB')],
#  [('to', 'PART'), ('steal', 'VERB')],
#  [('to', 'PART'), ('pluck', 'VERB'), (',', 'PUNCT'), ('pick', 'VERB')],
#  [],
#  [('be', 'AUX'), ('burnt', 'VERB')],
#  [('to', 'PART'), ('bathe', 'VERB')],
#  [('to', 'PART'), ('cook', 'VERB')],
#  [('to', 'PART'), ('dress', 'VERB')],
#  [('to', 'PART'), ('be', 'AUX'), ('spoilt', 'VERB')],
#  [('to', 'PART'), ('dress', 'VERB')],
#  [('to', 'PART'), ('plant', 'VERB')],
#  [('to', 'PART'), ('leave', 'VERB')],
#  [('to', 'PART'), ('burn', 'VERB')],
#  [('to', 'PART'), ('eat', 'VERB')],
#  [('to', 'PART'), ('see', 'VERB')],
#  [('to', 'PART'), ('enter', 'VERB')],
#  [('Alternative', 'ADJ'),
#   ('abbreviated', 'VERB'),
#   ('forms', 'NOUN'),
#   (':', 'PUNCT')],
#  [('to', 'PART'), ('kick', 'VERB')],
#  [('to', 'PART'), ('put', 'VERB'), ('on', 'ADP')],
#  [('to', 'PART'), ('pull', 'VERB')],
#  [('to', 'PART'), ('take', 'VERB')],
#  [('barbarian', 'PROPN'), (',', 'PUNCT'), ('foreigner', 'NOUN')],
#  [('that', 'PRON')],
#  [('good', 'ADJ'), ('thing', 'NOUN')],
#  [('if', 'SCONJ'),
#   ('[', 'X'),
#   ('one', 'NUM'),
#   (']', 'PUNCT'),
#   ('learns', 'VERB')],
#  [('is', 'AUX'), ('good', 'ADJ')],
#  [('grace', 'NOUN'), (',', 'PUNCT'), ('mercy', 'NOUN')],
#  [('us', 'PRON')],
#  [('they', 'PRON'), ('stand', 'VERB')],
#  [('they', 'PRON'), ('come', 'VERB')],
#  [('tree', 'NOUN'), (',', 'PUNCT'), ('wood', 'NOUN')],
#  [('you', 'PRON'), ('will', 'AUX'), ('like', 'VERB')],
#  [('glorious', 'ADJ'), (',', 'PUNCT'), ('successful', 'ADJ')],
#  [('circle', 'NOUN'), ('of', 'ADP'), ('fire', 'NOUN')],
#  [],
#  [('to', 'PART'), ('arise', 'VERB'), (',', 'PUNCT'), ('originate', 'VERB')],
#  [('to', 'PART'), ('create', 'VERB')],
#  [('‘', 'PUNCT'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('hand', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('with', 'ADP'),
#   (',', 'PUNCT'),
#   ('near', 'ADP')],
#  [('defect', 'NOUN'), (',', 'PUNCT'), ('shortcoming', 'VERB')],
#  [('‘', 'PUNCT'),
#   ('bearer', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('Ganges', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('Śiva', 'PROPN')],
#  [('‘', 'PUNCT'),
#   ('who', 'PRON'),
#   ('has', 'VERB'),
#   ('the', 'DET'),
#   ('moon', 'NOUN'),
#   ('on', 'ADP'),
#   ('his', 'PRON'),
#   ('crest', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('Śiva', 'PROPN')],
#  [],
#  [],
#  [('‘', 'PUNCT'),
#   ('who', 'PRON'),
#   ('drank', 'VERB'),
#   ('poison', 'NOUN'),
#   ('’', 'PUNCT')],
#  [('destruction', 'NOUN'), (',', 'PUNCT'), ('ruin', 'PROPN')],
#  [],
#  [('‘', 'PUNCT'),
#   ('white', 'ADJ'),
#   ('like', 'ADP'),
#   ('jasmine', 'NOUN'),
#   ('’', 'PUNCT')],
#  [('greatness', 'NOUN'), (',', 'PUNCT'), ('importance', 'NOUN')],
#  [('stripe', 'ADJ'), (',', 'PUNCT'), ('line', 'NOUN')],
#  [('place', 'NOUN'), ('of', 'ADP'), ('residence', 'NOUN')],
#  [('holy', 'PROPN'),
#   ('ash', 'PROPN'),
#   ('as', 'SCONJ'),
#   ('used', 'VERB'),
#   ('by', 'ADP'),
#   ('the', 'DET'),
#   ('devotees', 'NOUN'),
#   ('of', 'ADP'),
#   ('Śiva', 'PROPN')],
#  [('devotee', 'NOUN'), ('of', 'ADP'), ('Śiva', 'NOUN')],
#  [('religiously', 'ADV'), ('liberated', 'VERB'), ('person', 'NOUN')],
#  [('‘', 'PUNCT'),
#   ('who', 'PRON'),
#   ('has', 'VERB'),
#   ('the', 'DET'),
#   ('moon', 'NOUN'),
#   ('on', 'ADP'),
#   ('his', 'PRON'),
#   ('crest', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('Śiva', 'PROPN')],
#  [('nature', 'NOUN'), (',', 'PUNCT'), ('character', 'NOUN')],
#  [('to', 'PART'), ('smear', 'VERB'), (',', 'PUNCT'), ('apply', 'VERB')]]

# %%
# Show all POS tags for the first 10 sentences
for i, tags in enumerate(kannada_pos_tags[:100]):
    print(tags, f" - ({kannada_1word_transliterations[i]})")
# Out:
# [('to', 'PART'), ('run', 'VERB')]  - (ōḍu)
# [('to', 'PART'), ('read', 'VERB')]  - (ōdu)
# [('to', 'PART'), ('say', 'VERB')]  - (hēḷu)
# [('to', 'PART'), ('shit', 'VERB')]  - (hēlu)
# [('to', 'PART'), ('beat', 'VERB')]  - (baḍi)
# [('interest', 'NOUN')]  - (baḍḍi)
# [('ritually', 'ADV'), ('pure', 'ADJ')]  - (maḍi)
# [('please', 'INTJ'), ('do', 'VERB'), ('The', 'DET'), ('two', 'NUM'), ('following', 'VERB'), ('pairs', 'NOUN'), ('of', 'ADP'), ('words', 'NOUN'), ('are', 'AUX'), ('prosodically', 'ADV'), ('similar', 'ADJ')]  - (māḍi)
# [('you', 'PRON')]  - (nīnu)
# [('you', 'PRON')]  - (nīvu)
# [('it', 'PRON'), ('/', 'PUNCT'), ('that', 'PRON')]  - (adu)
# [('they', 'PRON')]  - (avaru)
# [('they', 'PRON')]  - (avu)
# [('it', 'PRON'), ('/', 'PUNCT'), ('this', 'PRON')]  - (idu)
# [('he', 'PRON'), ('/', 'SYM'), ('she', 'PRON')]  - (ivaru)
# [('they', 'PRON'), ('/', 'PUNCT'), ('these', 'PRON')]  - (ivu)
# [('in', 'ADP'), ('this', 'DET'), ('manner', 'NOUN')]  - (hīge)
# [('in', 'ADP'), ('that', 'DET'), ('manner', 'NOUN')]  - (hāge)
# [('in', 'ADP'), ('which', 'PRON'), ('manner', 'NOUN'), ('?', 'PUNCT')]  - (hēge)
# [('this', 'PRON'), ('much', 'ADJ')]  - (iṣṭu)
# [('that', 'ADV'), ('much', 'ADV')]  - (aṣṭu)
# [('how', 'SCONJ'), ('much', 'ADJ'), ('?', 'PUNCT')]  - (eṣṭu)
# [('it', 'PRON'), ('is', 'AUX'), (',', 'PUNCT'), ('it', 'PRON'), ('exists', 'VERB')]  - (ide)
# [('mouse', 'PROPN'), (',', 'PUNCT'), ('rat', 'CCONJ')]  - (ili)
# [('leg', 'PROPN'), (',', 'PUNCT'), ('foot', 'NOUN')]  - (kālu)
# [('hand', 'NOUN'), (',', 'PUNCT'), ('arm', 'VERB')]  - (kai)
# [('book', 'NOUN'), (',', 'PUNCT'), ('volume', 'NOUN')]  - (graṃtha)
# [('big', 'ADJ'), (',', 'PUNCT'), ('large', 'ADJ')]  - (doḍḍa)
# []  - (paṃce)
# [('ballpoint', 'PROPN'), ('pen', 'NOUN')]  - (pennu)
# [('pair', 'NOUN'), ('of', 'ADP'), ('trousers', 'NOUN')]  - (pyāṃṭu)
# [('hill', 'PROPN'), (',', 'PUNCT'), ('mountain', 'NOUN')]  - (beṭṭa)
# [('old', 'ADJ'), ('woman', 'NOUN')]  - (muduki)
# [('lawn', 'PROPN'), (',', 'PUNCT'), ('field', 'NOUN')]  - (maidāna)
# [('young', 'ADJ'), ('woman', 'NOUN')]  - (yuvati)
# []  - (luṃgi)
# [('[', 'X'), ('male', 'NOUN'), (']', 'X'), ('student', 'NOUN')]  - (vidyārthi)
# [('[', 'X'), ('female', 'ADJ'), (']', 'PUNCT'), ('student', 'NOUN')]  - (vidyārthini)
# []  - (Viṣṇu)
# []  - (Śiva)
# [('cow', 'NOUN'), ('dung', 'PROPN')]  - (sagaṇi)
# [('things', 'NOUN'), (',', 'PUNCT'), ('belongings', 'NOUN')]  - (sāmānugaḷu)
# []  - (sīre)
# [('singer', 'NOUN')]  - (hāḍugāra)
# [('singer', 'NOUN')]  - (hāḍugārti)
# []  - (Namaskāra.)
# [('Yes', 'INTJ'), (',', 'PUNCT'), ('you', 'PRON'), ('may', 'AUX'), ('go', 'VERB')]  - (Banni.)
# [('How', 'SCONJ'), ('are', 'AUX'), ('you', 'PRON'), ('?', 'PUNCT'), ('Gururāja', 'NOUN')]  - (Hēgiddīri?)
# [('his', 'PRON'), ('/', 'SYM'), ('her', 'PRON')]  - (ivara)
# [('from', 'ADP'), ('where', 'SCONJ'), ('?', 'PUNCT')]  - (elliṃda)
# [('nicely', 'ADV'), (',', 'PUNCT'), ('finely', 'ADV')]  - (cennāgi)
# [('your', 'PRON')]  - (nimma)
# [('please', 'INTJ'), ('come', 'VERB')]  - (banni)
# [('I', 'PRON'), ('should', 'AUX'), ('come', 'VERB')]  - (barali)
# [('to', 'PART'), ('come', 'VERB')]  - (baru)
# [('bus', 'NOUN')]  - (bassu)
# [('is', 'AUX'), ('wanted', 'VERB'), ('/', 'SYM'), ('required', 'VERB'), ('/', 'SYM'), ('needed', 'VERB')]  - (bēku)
# [('is', 'AUX'), ('not', 'PART'), ('wanted', 'VERB'), ('/', 'PUNCT'), ('not', 'PART'), ('required', 'VERB')]  - (bēḍa)
# [('something', 'PRON'), ('special', 'ADJ')]  - (viśēṣa)
# [('okay', 'INTJ'), (',', 'PUNCT'), ('all', 'ADV'), ('right', 'ADV'), (',', 'PUNCT'), ('correct', 'ADJ')]  - (sari)
# [('elder', 'ADJ'), ('sister', 'NOUN')]  - (akka)
# [('elder', 'ADJ'), ('brother', 'NOUN')]  - (aṇṇa)
# [('tank', 'NOUN'), (',', 'PUNCT'), ('water', 'NOUN'), ('reservoir', 'NOUN')]  - (kere)
# [('bag', 'PROPN'), (',', 'PUNCT'), ('purse', 'NOUN')]  - (cīla)
# [('country', 'NOUN'), (',', 'PUNCT'), ('land', 'NOUN')]  - (dēśa)
# [('page', 'NOUN')]  - (puṭa)
# [('friend', 'NOUN')]  - (snēhita)
# [('friend', 'NOUN')]  - (snēhite)
# [('store', 'PROPN'), (',', 'PUNCT'), ('shop', 'NOUN')]  - (aṃgaḍi)
# [('person', 'NOUN'), (',', 'PUNCT'), ('people', 'NOUN')]  - (jana)
# [('eager', 'ADJ'), ('to', 'PART'), ('learn', 'VERB')]  - (jijñāsu)
# [('learned', 'VERB'), ('woman', 'NOUN')]  - (paṃḍite)
# [('I', 'PRON'), ('went', 'VERB')]  - (hōdenu)
# [('I', 'PRON'), ('became', 'VERB')]  - (ādenu)
# [('you', 'PRON'), ('went', 'VERB')]  - (hōdi)
# [('you', 'PRON'), ('became', 'VERB')]  - (ādi)
# [('he', 'PRON'), ('went', 'VERB')]  - (hōdanu)
# [('he', 'PRON'), ('became', 'VERB')]  - (ādanu)
# [('she', 'PRON'), ('went', 'VERB')]  - (hōdaḷu)
# [('she', 'PRON'), ('became', 'VERB')]  - (ādaḷu)
# [('we', 'PRON'), ('went', 'VERB')]  - (hōdevu)
# [('we', 'PRON'), ('became', 'VERB')]  - (ādevu)
# [('you', 'PRON'), ('went', 'VERB')]  - (hōdiri)
# [('you', 'PRON'), ('became', 'VERB')]  - (ādiri)
# [('they', 'PRON'), ('went', 'VERB')]  - (hōdaru)
# [('they', 'PRON'), ('became', 'VERB')]  - (ādaru)
# [('to', 'PART'), ('become', 'VERB'), (',', 'PUNCT'), ('occur', 'VERB')]  - (āgu)
# [('to', 'PART'), ('jump', 'VERB')]  - (jigi)
# [('to', 'PART'), ('call', 'VERB')]  - (kare)
# [('to', 'PART'), ('bring', 'VERB')]  - (taru)
# [('to', 'PART'), ('understand', 'VERB')]  - (tiḷi)
# [('to', 'PART'), ('laugh', 'VERB')]  - (nagu)
# [('to', 'PART'), ('fall', 'VERB')]  - (bīḷu)
# [('to', 'PART'), ('do', 'VERB'), (',', 'PUNCT'), ('make', 'VERB')]  - (māḍu)
# [('to', 'PART'), ('hit', 'VERB'), (',', 'PUNCT'), ('strike', 'VERB')]  - (hoḍe)
# [('to', 'PART'), ('go', 'VERB')]  - (hōgu)
# [('to', 'PART'), ('watch', 'VERB'), (',', 'PUNCT'), ('look', 'VERB'), ('at', 'ADP')]  - (nōḍu)
# [('to', 'PART'), ('write', 'VERB')]  - (bare)
# [('rice', 'NOUN')]  - (anna)
# []  - (ūṭa)

# %%
# Map the transliterations to the POS tags
kannada_pos_mapping = {}
for i, tags in enumerate(kannada_pos_tags):
    transliteration = kannada_1word_transliterations[i]
    kannada_pos_mapping[transliteration] = [pos for word, pos in tags]  

kannada_pos_mapping
# Out:
# {'ōḍu': ['PART', 'VERB'],
#  'ōdu': ['PART', 'VERB'],
#  'hēḷu': ['PART', 'VERB'],
#  'hēlu': ['PART', 'VERB'],
#  'baḍi': ['PART', 'VERB'],
#  'baḍḍi': ['NOUN', 'PUNCT', 'ADP', 'NOUN', 'PUNCT'],
#  'maḍi': ['ADV', 'ADJ'],
#  'māḍi': ['INTJ',
#   'VERB',
#   'DET',
#   'NUM',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'DET',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'PUNCT',
#   'PUNCT',
#   'CCONJ',
#   'SCONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADJ',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'AUX',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'SCONJ',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  'nīnu': ['PRON', 'PUNCT', 'ADJ', 'CCONJ', 'ADJ', 'ADJ', 'ADJ', 'PUNCT'],
#  'nīvu': ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'],
#  'adu': ['PRON', 'PUNCT', 'PRON'],
#  'avaru': ['PRON', 'PUNCT', 'NOUN', 'PUNCT'],
#  'avu': ['PRON', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT'],
#  'idu': ['PRON', 'PUNCT', 'PRON'],
#  'ivaru': ['PRON', 'SYM', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'ivu': ['PRON',
#   'SYM',
#   'DET',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'PART',
#   'PRON',
#   'PRON',
#   'VERB',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'AUX',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'PUNCT'],
#  'hīge': ['ADP', 'DET', 'NOUN'],
#  'hāge': ['ADP', 'DET', 'NOUN'],
#  'hēge': ['ADP', 'PRON', 'NOUN', 'PUNCT'],
#  'iṣṭu': ['PRON', 'ADJ'],
#  'aṣṭu': ['ADV', 'ADV'],
#  'eṣṭu': ['SCONJ', 'ADJ', 'PUNCT'],
#  'ide': ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'],
#  'ili': ['PROPN', 'PUNCT', 'CCONJ'],
#  'kālu': ['PROPN', 'PUNCT', 'NOUN'],
#  'kai': ['NOUN', 'PUNCT', 'VERB'],
#  'graṃtha': ['NOUN', 'PUNCT', 'NOUN'],
#  'doḍḍa': ['ADJ', 'PUNCT', 'ADJ'],
#  'paṃce': ['PUNCT',
#   'ADJ',
#   'NOUN',
#   'PART',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'PUNCT'],
#  'pennu': ['PROPN', 'NOUN'],
#  'pyāṃṭu': ['NOUN', 'ADP', 'NOUN'],
#  'beṭṭa': ['PROPN', 'PUNCT', 'NOUN'],
#  'muduki': ['ADJ', 'NOUN'],
#  'maidāna': ['PROPN', 'PUNCT', 'NOUN'],
#  'yuvati': ['ADJ', 'NOUN'],
#  'luṃgi': ['PUNCT',
#   'ADJ',
#   'NOUN',
#   'PART',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'vidyārthi': ['X', 'NOUN', 'X', 'NOUN'],
#  'vidyārthini': ['X', 'ADJ', 'PUNCT', 'NOUN'],
#  'Viṣṇu': ['PUNCT', 'NOUN', 'ADP', 'PROPN', 'PUNCT'],
#  'Śiva': ['PUNCT', 'NOUN', 'ADP', 'PROPN', 'PUNCT'],
#  'sagaṇi': ['NOUN', 'PROPN'],
#  'sāmānugaḷu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sīre': ['PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'hāḍugāra': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'hāḍugārti': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'Namaskāra.': ['PUNCT',
#   'DET',
#   'ADJ',
#   'AUX',
#   'VERB',
#   'SCONJ',
#   'NOUN',
#   'PUNCT'],
#  'Banni.': ['INTJ',
#   'PUNCT',
#   'PRON',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'PUNCT'],
#  'Hēgiddīri?': ['SCONJ', 'AUX', 'PRON', 'PUNCT', 'NOUN'],
#  'ivara': ['PRON', 'SYM', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'elliṃda': ['ADP', 'SCONJ', 'PUNCT'],
#  'cennāgi': ['ADV', 'PUNCT', 'ADV'],
#  'nimma': ['PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'banni': ['INTJ', 'VERB'],
#  'barali': ['PRON', 'AUX', 'VERB'],
#  'baru': ['PART', 'VERB'],
#  'bassu': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'bēku': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'],
#  'bēḍa': ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'viśēṣa': ['PRON', 'ADJ'],
#  'sari': ['INTJ', 'PUNCT', 'ADV', 'ADV', 'PUNCT', 'ADJ'],
#  'akka': ['ADJ', 'NOUN'],
#  'aṇṇa': ['ADJ', 'NOUN'],
#  'kere': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'cīla': ['PROPN', 'PUNCT', 'NOUN'],
#  'dēśa': ['NOUN', 'PUNCT', 'NOUN'],
#  'puṭa': ['PROPN', 'PUNCT', 'ADP', 'NOUN', 'X', 'PUNCT', 'PUNCT'],
#  'snēhita': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'snēhite': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'aṃgaḍi': ['PROPN', 'PUNCT', 'NOUN'],
#  'jana': ['NOUN', 'PUNCT', 'NOUN'],
#  'jijñāsu': ['ADJ', 'PART', 'VERB'],
#  'paṃḍite': ['VERB', 'NOUN'],
#  'hōdenu': ['PRON', 'VERB'],
#  'ādenu': ['PRON', 'VERB'],
#  'hōdi': ['PRON', 'VERB'],
#  'ādi': ['PRON', 'VERB'],
#  'hōdanu': ['PRON', 'VERB'],
#  'ādanu': ['PRON', 'VERB'],
#  'hōdaḷu': ['PRON', 'VERB'],
#  'ādaḷu': ['PRON', 'VERB'],
#  'hōdevu': ['PRON', 'VERB'],
#  'ādevu': ['PRON', 'VERB'],
#  'hōdiri': ['PRON', 'VERB'],
#  'ādiri': ['PRON', 'VERB'],
#  'hōdaru': ['PRON', 'VERB'],
#  'ādaru': ['PRON', 'VERB'],
#  'āgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'jigi': ['PART', 'VERB'],
#  'kare': ['PART', 'VERB'],
#  'taru': ['PART', 'VERB'],
#  'tiḷi': ['PART', 'VERB'],
#  'nagu': ['PART', 'VERB'],
#  'bīḷu': ['PART', 'VERB'],
#  'māḍu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hoḍe': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hōgu': ['PART', 'VERB'],
#  'nōḍu': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADP'],
#  'bare': ['PART', 'VERB'],
#  'anna': ['PROPN', 'PUNCT', 'VERB', 'PUNCT'],
#  'ūṭa': ['PUNCT', 'VERB', 'PUNCT', 'NOUN'],
#  'koḍu': ['PART', 'VERB'],
#  'viṣaya': ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'sāku': ['PRON', 'AUX', 'ADJ'],
#  'sāladu': ['PRON', 'AUX', 'PART', 'ADJ'],
#  'mēlu': ['ADJ', 'NOUN'],
#  'keḷagu': ['ADJ', 'NOUN'],
#  'hiṃde': ['ADV', 'PUNCT', 'ADV'],
#  'hiṃdu': ['ADJ', 'NOUN'],
#  'āyitu': ['ADV', 'ADV', 'PUNCT', 'INTJ'],
#  'iḍu': ['ADP', 'NOUN', 'PUNCT', 'VERB'],
#  'īgalū': ['ADV', 'ADV'],
#  'kaḍe': ['NOUN', 'PUNCT', 'NOUN'],
#  'kōṇe': ['NOUN', 'PUNCT', 'PROPN'],
#  'gaḍipradēśa': ['NOUN', 'NOUN'],
#  'tagoḷḷu': ['PART', 'VERB'],
#  'tuṃba': ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'],
#  'darśana': ['VERB',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN'],
#  'nija': ['ADJ', 'PUNCT', 'ADJ'],
#  'nijavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'pradēśa': ['PROPN', 'PUNCT', 'NOUN'],
#  'bāḷu': ['PART', 'VERB'],
#  'bhakta': ['NOUN', 'PUNCT', 'NOUN'],
#  'śatamāna': ['NOUN', 'PUNCT', 'NUM', 'NOUN', 'PUNCT'],
#  'summane': ['ADV', 'ADP', 'PRON', 'PUNCT', 'ADV'],
#  'svalpa': ['DET', 'NOUN', 'PUNCT', 'DET', 'ADJ'],
#  'bāḷe': ['PROPN', 'NOUN'],
#  'bēre': ['ADJ', 'PUNCT', 'PRON', 'ADV'],
#  'rīti': ['NOUN', 'PUNCT', 'ADJ'],
#  'asahya': ['ADJ', 'PUNCT', 'ADJ'],
#  'āḍu': ['PART', 'VERB'],
#  'iṣṭa': ['VERB', 'PUNCT', 'VERB'],
#  'ūru': ['NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN'],
#  'kēḷu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'kṣētra': ['NOUN', 'ADP', 'NOUN'],
#  'jāga': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'taṃgi': ['ADJ', 'NOUN'],
#  'tīrthaṃkara': ['PUNCT', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'PUNCT'],
#  'pūjārha': ['ADJ', 'ADP', 'NOUN'],
#  'prakāra': ['VERB', 'ADP'],
#  'manuṣya': ['ADJ', 'PUNCT', 'NOUN'],
#  'mūrti': ['NOUN', 'PUNCT', 'NOUN'],
#  'modalu': ['ADV', 'PUNCT', 'ADP', 'DET', 'NOUN'],
#  'mōkṣa': ['PUNCT', 'ADJ', 'PUNCT', 'NOUN'],
#  'saṃsāra': ['PUNCT', 'DET', 'ADJ', 'NOUN', 'ADP'],
#  'hoṃdu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'kelasadavaḷu': ['X',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'DET',
#   'PUNCT',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PUNCT'],
#  'maneyavaru': ['NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'DET',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'avatāra': ['NOUN', 'ADP', 'DET', 'NOUN'],
#  'gurutu': ['PROPN', 'PUNCT', 'ADJ'],
#  'jāsti': ['ADV', 'ADJ', 'PUNCT', 'ADV'],
#  'taṃdaru': ['PRON', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT', 'VERB'],
#  'tanna': ['PRON', 'SYM', 'PRON', 'SYM', 'PRON', 'ADJ'],
#  'divasā': ['DET', 'NOUN'],
#  'pūje': ['NOUN', 'ADP', 'NOUN'],
#  'mukhya': ['PRON', 'ADJ'],
#  'rathabīdi': ['PROPN', 'PROPN'],
#  'vidēśa': ['ADJ', 'NOUN'],
#  'vaiṣṇava': ['NOUN', 'ADP', 'PROPN', 'PUNCT', 'PROPN'],
#  'samudra': ['PROPN', 'PUNCT', 'NOUN'],
#  'hattira': ['ADV', 'PUNCT', 'NOUN'],
#  'heccu': ['ADV', 'PUNCT', 'DET', 'NOUN', 'PUNCT', 'ADV'],
#  'iḷi': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADV'],
#  'kadi': ['PART', 'VERB'],
#  'kāpāḍu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'koḷḷu': ['PART', 'VERB'],
#  'jōru': ['NOUN', 'PUNCT', 'NOUN'],
#  'tīvra': ['ADJ', 'PUNCT', 'ADJ'],
#  'naḍe': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'paḍu': ['PART', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'VERB'],
#  'bayyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'beḷe': ['PART', 'VERB'],
#  'bhāgavahisu': ['PART', 'VERB'],
#  'malagu': ['PART', 'VERB', 'ADV', 'PUNCT', 'VERB'],
#  'mātanāḍu': ['PART', 'VERB'],
#  'lēkhaki': ['NOUN', 'PUNCT', 'ADJ', 'PUNCT'],
#  'vāpasu': ['ADV', 'PUNCT', 'VERB'],
#  'sustu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sogasu': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'hattu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'hāḍu': ['NOUN', 'PUNCT', 'PART', 'VERB'],
#  'hāru': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'horaḍu': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB', 'ADP'],
#  'kareyisu': ['PART', 'VERB', 'PART', 'VERB'],
#  'prakaṭa': ['VERB', 'PUNCT', 'ADJ'],
#  'prayatna': ['NOUN', 'PUNCT', 'VERB', 'PUNCT', 'NOUN'],
#  'bēga': ['ADV', 'PUNCT', 'ADV'],
#  'mēṣṭaru': ['PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'vicitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'araḷu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'tamma': ['ADJ', 'NOUN'],
#  'neraḷu': ['PROPN', 'PUNCT', 'NOUN'],
#  'mātu': ['NOUN', 'PUNCT', 'NOUN'],
#  'vāsa': ['VERB', 'PUNCT', 'VERB'],
#  'sigu': ['PART', 'AUX', 'VERB', 'PUNCT', 'PART', 'AUX', 'VERB'],
#  'suddi': ['NOUN', 'PUNCT', 'NOUN'],
#  'bāradu': ['AUX', 'PART'],
#  'āse': ['NOUN', 'PUNCT', 'VERB'],
#  'heṃḍa': ['ADJ', 'NOUN'],
#  'eṃdare': ['X', 'PUNCT', 'PRON', 'AUX', 'PART', 'VERB'],
#  'oḍati': ['NOUN', 'PUNCT', 'NOUN'],
#  'kāṇisu': ['PART', 'AUX', 'VERB', 'PUNCT', 'VERB'],
#  'kāraṇa': ['NOUN', 'PUNCT', 'NOUN'],
#  'gottu': ['NOUN', 'PUNCT', 'ADJ', 'NOUN'],
#  'tuḷasi': ['ADJ', 'NOUN'],
#  'pavitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'pūjisu': ['PART', 'VERB'],
#  'bahaḷa': ['ADJ', 'PUNCT', 'ADJ', 'PUNCT', 'ADV'],
#  'baḷasu': ['PART', 'VERB'],
#  'beḷigge': ['ADP', 'DET', 'NOUN'],
#  'śakti': ['NOUN', 'PUNCT', 'NOUN'],
#  'śukravāra': ['NOUN', 'PUNCT', 'NOUN'],
#  'hittalu': ['NOUN', 'NOUN'],
#  'hedaru': ['PART', 'VERB'],
#  'kareyavu': ['ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'VERB',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'AUX',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'PART'],
#  'anubhavisu': ['PART', 'VERB'],
#  'anubhāva': ['ADJ', 'NOUN'],
#  'kelavaru': ['DET', 'NOUN'],
#  'kelavu': ['DET', 'PUNCT', 'NOUN', 'PUNCT'],
#  'guṃpugārike': ['NOUN', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT'],
#  'naṃbu': ['PART', 'VERB'],
#  'baduku': ['PART', 'VERB'],
#  'Basavaṇṇa': ['PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PROPN',
#   'PUNCT',
#   'PUNCT'],
#  'mānava': ['ADJ', 'PUNCT', 'NOUN'],
#  'vacana': ['PUNCT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'vaiyaktika': ['PRON', 'ADJ'],
#  'vyakti': ['NOUN', 'PUNCT', 'ADJ'],
#  'śivamaya': ['VERB', 'ADP', 'PROPN'],
#  'śaiva': ['VERB', 'ADP', 'PROPN'],
#  'saṃbhavisu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'sādhane': ['ADJ', 'NOUN', 'SYM', 'NOUN'],
#  'sāhityakṛti': ['ADJ', 'NOUN'],
#  'halavaru': ['ADJ', 'NOUN'],
#  'āga': ['ADV', 'PUNCT', 'DET', 'NOUN'],
#  'ivattina': ['NOUN', 'PART', 'PUNCT', 'ADP', 'NOUN'],
#  'īgina': ['ADP', 'ADV', 'PUNCT', 'ADJ'],
#  'uḷi': ['PART', 'VERB'],
#  'kali': ['PART', 'VERB'],
#  'guḍḍa': ['PROPN', 'PUNCT', 'NOUN'],
#  'jotege': ['ADV', 'ADP'],
#  'dharmādhikāri': ['PUNCT', 'ADJ', 'NOUN', 'CCONJ', 'NOUN', 'PUNCT'],
#  'neṃṭa': ['PUNCT', 'ADJ', 'PUNCT', 'NOUN'],
#  'pradhāna': ['ADJ', 'PUNCT', 'NOUN'],
#  'prāṇa': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'balakaḍe': ['INTJ', 'PUNCT', 'NOUN', 'PUNCT'],
#  'beṃḍekāyi': ['PROPN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'muṃcitavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'muṃduvari': ['PART', 'VERB'],
#  'mugi': ['PART', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT'],
#  'mugisu': ['PART',
#   'VERB',
#   'PUNCT',
#   'PROPN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'yati': ['VERB', 'ADJ'],
#  'rūḍhi': ['NOUN', 'PUNCT', 'NOUN'],
#  'rūpa': ['NOUN', 'PUNCT', 'NOUN'],
#  'lābha': ['NOUN', 'PUNCT', 'NOUN'],
#  'liṃga': ['PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'sinima': ['NOUN', 'NOUN'],
#  'hāgādare': ['ADP', 'DET', 'NOUN', 'PUNCT', 'SCONJ', 'PRON', 'AUX', 'ADV'],
#  'hāgū': ['CCONJ', 'PUNCT', 'ADV'],
#  'haṇṇugaḷellavu': ['PUNCT', 'DET', 'ADJ', 'PUNCT'],
#  'vidyārthigaḷellaru': ['PUNCT', 'DET', 'ADJ', 'PUNCT'],
#  'elladariṃda': ['ADP', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'elladakke': ['ADP', 'PRON', 'PUNCT', 'NOUN', 'PUNCT'],
#  'elladara': ['ADP', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'elladaralli': ['ADP', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'baredukoḷḷi': ['INTJ',
#   'VERB',
#   'ADP',
#   'X',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'SCONJ',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'PUNCT'],
#  'baredukoḍi': ['INTJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADP',
#   'PRON',
#   'ADP',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT'],
#  'maretubiḍi!': ['INTJ', 'VERB', 'PRON', 'PUNCT'],
#  'saṃkōcapaḍabēḍa': ['AUX',
#   'PART',
#   'AUX',
#   'ADJ',
#   'X',
#   'PUNCT',
#   'AUX',
#   'PART',
#   'VERB',
#   'PROPN',
#   'PUNCT',
#   'PUNCT'],
#  'oṃdu': ['NUM', 'PUNCT', 'PRON'],
#  'oṃdannu': ['NUM', 'PUNCT', 'ADJ', 'ADJ', 'PUNCT'],
#  'oṃdariṃda': ['ADP', 'NUM'],
#  'oṃdakke': ['ADP', 'NUM'],
#  'oṃdara': ['ADP', 'NUM'],
#  'oṃdaralli': ['ADP', 'NUM'],
#  'eraḍannu': ['NUM', 'PUNCT', 'ADJ', 'ADJ', 'PUNCT'],
#  'mūrakke': ['ADP', 'NUM'],
#  'nālkara': ['ADP', 'NUM'],
#  'aidariṃda': ['ADP', 'NUM'],
#  'āraralli': ['ADP',
#   'NUM',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'sāvira': ['NUM',
#   'SCONJ',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'AUX',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'oṃdaneyadu': ['DET', 'ADJ', 'NUM'],
#  'hattaneyavanu': ['DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'X',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'aidaneyadaralli': ['ADP', 'DET', 'ADJ', 'NUM'],
#  'hattaneyavanige': ['ADP', 'DET', 'ADJ', 'NOUN'],
#  'obbanu': ['NUM', 'X', 'NOUN', 'X', 'NOUN'],
#  'obbaḷu': ['NUM', 'X', 'ADJ', 'PUNCT', 'NOUN'],
#  'obbaru': ['NUM', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'CCONJ', 'ADJ', 'PUNCT'],
#  'ibbaru': ['NUM', 'NOUN'],
#  'mūvaru': ['NUM', 'NOUN'],
#  'nālvaru': ['NUM', 'NOUN'],
#  'aivaru': ['NUM', 'NOUN'],
#  'ari': ['PART', 'VERB'],
#  'aritenu': ['PRON', 'VERB'],
#  'kalitenu': ['PRON', 'VERB'],
#  'mare': ['PART', 'VERB'],
#  'ennu': ['PART', 'VERB'],
#  'eṃdenu': ['PRON', 'VERB'],
#  'tinnu': ['PART', 'VERB'],
#  'tiṃdenu': ['PRON', 'VERB'],
#  'baydenu': ['PRON',
#   'VERB',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'PUNCT',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN'],
#  'kāyu': ['PART', 'VERB', 'SYM', 'VERB', 'ADJ'],
#  'kādenu': ['PRON', 'VERB'],
#  'kuḷiru': ['PART', 'VERB', 'ADP'],
#  'kuḷitenu': ['PRON', 'VERB', 'ADP'],
#  'sōlu': ['PART', 'AUX', 'VERB'],
#  'sīnu': ['PART', 'VERB'],
#  'sītenu': ['PRON',
#   'VERB',
#   'PRON',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADV',
#   'SCONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADV'],
#  'ese': ['PART', 'VERB'],
#  'kuri': ['PART', 'VERB'],
#  'kusi': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB'],
#  'koḷe': ['PART', 'VERB'],
#  'caḷi': ['PART', 'AUX', 'ADJ'],
#  'dore': ['PART', 'AUX', 'VERB'],
#  'bese': ['PART', 'VERB'],
#  'mase': ['AUX', 'VERB'],
#  'moḷe': ['PART', 'VERB'],
#  'husi': ['PART', 'VERB', 'NOUN', 'SYM', 'NOUN'],
#  'āyu': ['PART', 'VERB'],
#  'oyyu': ['PART', 'VERB', 'ADP'],
#  'koyyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'geyyu': ['PART', 'VERB'],
#  'tēyu': ['PART', 'VERB'],
#  'toyyu': ['PART', 'VERB', 'ADJ'],
#  'māyu': ['PART', 'AUX', 'VERB'],
#  'mēyu': ['PART', 'VERB'],
#  'suyyu': ['PART', 'VERB'],
#  'hāyu': ['PART', 'VERB', 'ADP'],
#  'kavalu': ['PART', 'VERB', 'ADJ'],
#  'ciguru': ['PART', 'VERB'],
#  'bevaru': ['PART', 'VERB'],
#  'nāru': ['PART', 'VERB'],
#  'iru': ['PART', 'AUX'],
#  'teru': ['PART', 'VERB'],
#  'bēsaru': ['PART', 'AUX', 'VERB'],
#  'heru': ['PART', 'VERB', 'NOUN'],
#  'horu': ['PART', 'VERB', 'DET', 'NOUN'],
#  'kollu': ['PART', 'VERB'],
#  'gellu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'nillu': ['PART', 'VERB'],
#  'aḷu': ['PART', 'VERB'],
#  'uḷu': ['PART', 'VERB'],
#  'ēḷu': ['PART', 'VERB'],
#  'kaḷu': ['PART', 'VERB'],
#  'kīḷu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'biddu': ['PUNCT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'bēyu': ['AUX', 'VERB'],
#  'mīyu': ['PART', 'VERB'],
#  'aḍu': ['PART', 'VERB'],
#  'uḍu': ['PART', 'VERB'],
#  'keḍu': ['PART', 'AUX', 'VERB'],
#  'toḍu': ['PART', 'VERB'],
#  'neḍu': ['PART', 'VERB'],
#  'biḍu': ['PART', 'VERB'],
#  'suḍu': ['PART', 'VERB'],
#  'uṇṇu': ['PART', 'VERB'],
#  'kāṇu': ['PART', 'VERB'],
#  'hogu': ['PART', 'VERB'],
#  'hokku': ['ADJ', 'VERB', 'NOUN', 'PUNCT'],
#  'ode': ['PART', 'VERB'],
#  'hode': ['PART', 'VERB', 'ADP', 'PUNCT', 'NOUN', 'PUNCT'],
#  'eḷe': ['PART', 'VERB'],
#  'tege': ['PART', 'VERB'],
#  'mlēccha': ['PROPN', 'PUNCT', 'NOUN'],
#  'adannu': ['SCONJ', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'],
#  'oḷḷeyadu': ['ADJ', 'NOUN'],
#  'kalitare': ['SCONJ', 'X', 'NUM', 'PUNCT', 'VERB'],
#  'cennāgide': ['AUX', 'ADJ'],
#  'daya': ['NOUN', 'PUNCT', 'NOUN'],
#  'namage': ['PRON', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'],
#  'niṃtiddāre': ['PRON', 'VERB'],
#  'baruttāre': ['PRON', 'VERB'],
#  'mara': ['NOUN', 'PUNCT', 'NOUN'],
#  'meccuviri': ['PRON', 'AUX', 'VERB'],
#  'yaśasvi': ['ADJ', 'PUNCT', 'ADJ'],
#  'agnimaṃḍala': ['NOUN', 'ADP', 'NOUN'],
#  'apasmara': ['PUNCT', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT'],
#  'uṃṭāgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'uṃṭumāḍu': ['PART', 'VERB'],
#  'kaiyalli': ['PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'ADP'],
#  'korate': ['NOUN', 'PUNCT', 'VERB'],
#  'gaṃgādhara': ['PUNCT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'caṃdraśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'tāṃḍava': ['PUNCT', 'NOUN', 'ADP', 'PROPN', 'PART', 'NOUN', 'PUNCT'],
#  'nakk-': ['PUNCT', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'PUNCT'],
#  'naṃjuṃḍa': ['PUNCT', 'PRON', 'VERB', 'NOUN', 'PUNCT'],
#  'nāśa': ['NOUN', 'PUNCT', 'PROPN'],
#  'Madhvācārya': ['PUNCT', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT'],
#  'mallikārjuna': ['PUNCT', 'ADJ', 'ADP', 'NOUN', 'PUNCT'],
#  'mahatva': ['NOUN', 'PUNCT', 'NOUN'],
#  'rēkhē': ['ADJ', 'PUNCT', 'NOUN'],
#  'vāsasthaḷa': ['NOUN', 'ADP', 'NOUN'],
#  'vibhūti': ['PROPN',
#   'PROPN',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'śivabhakta': ['NOUN', 'ADP', 'NOUN'],
#  'siddhapuruṣa': ['ADV', 'VERB', 'NOUN'],
#  'sōmaśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'svabhāva': ['NOUN', 'PUNCT', 'NOUN'],
#  'haccu': ['PART', 'VERB', 'PUNCT', 'VERB']}

# %%
# POS Tagging for all other sentences
other_sentences_sentences = [item['english'] for item in other_sentences]

other_sentences_transliterations = [item['transliteration'] for item in other_sentences]
other_pos_tags = pos_tagging(other_sentences_sentences)
# Out:
# 100%|██████████| 393/393 [00:01<00:00, 203.50it/s]

# %%
# Display first 10 items from other pos tags
for i, tags in enumerate(other_pos_tags[:10]):
    print(f"{i+1}. Transliteration: {other_sentences_transliterations[i]}")
    for word, pos in tags:
        print(f"   {word}: {pos}")
    
    transliteration = other_sentences_transliterations[i].lower()
    transliteration = transliteration.strip()
    # Remove any trailing punctuation
    transliteration = transliteration.rstrip('.,!?')
    # Print the transliteration

    transliteration = transliteration.split()
    # Check if the transliteration is in the pos_mapping
    for word in transliteration:
        word = word.lower()
        if word in pos_mapping:
            print(f"POS tags for {word}: {pos_mapping[word]}")
        elif word in kannada_pos_mapping:
            print(f"POS tags for {word}: {kannada_pos_mapping[word]}")
        else:
            print(f"No POS tags found for {word}")
    print("=========================================")
# Out:
# 1. Transliteration: Idu pustaka.
#    This: PRON
#    is: AUX
#    a: DET
#    book: NOUN
#    .: PUNCT
# POS tags for idu: ['PRON']
# POS tags for pustaka: ['NOUN']
# =========================================
# 2. Transliteration: Ivu pustakagaḷu.
#    These: PRON
#    are: AUX
#    books: NOUN
#    .: PUNCT
# POS tags for ivu: ['PRON', 'SYM', 'DET', 'PUNCT', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'NOUN', 'AUX', 'VERB', 'SCONJ', 'DET', 'NOUN', 'PART', 'PRON', 'PRON', 'VERB', 'AUX', 'ADJ', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PUNCT', 'SCONJ', 'DET', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'AUX', 'ADJ', 'PUNCT', 'ADJ', 'CCONJ', 'ADJ', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'AUX', 'ADV', 'VERB', 'PUNCT', 'PUNCT']
# No POS tags found for pustakagaḷu
# =========================================
# 3. Transliteration: Adu mara.
#    That: PRON
#    is: AUX
#    a: DET
#    tree: NOUN
#    .: PUNCT
# POS tags for adu: ['PRON']
# POS tags for mara: ['NOUN']
# =========================================
# 4. Transliteration: Avu maragaḷu.
#    Those: PRON
#    are: AUX
#    trees: NOUN
#    .: PUNCT
# POS tags for avu: ['PRON', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT']
# No POS tags found for maragaḷu
# =========================================
# 5. Transliteration: Adu huḍuga.
#    That: PRON
#    is: AUX
#    a: DET
#    boy: NOUN
#    .: PUNCT
# POS tags for adu: ['PRON']
# POS tags for huḍuga: ['PROPN']
# =========================================
# 6. Transliteration: Adu mane.
#    That: PRON
#    is: AUX
#    a: DET
#    house: NOUN
#    .: PUNCT
# POS tags for adu: ['PRON']
# POS tags for mane: ['NOUN']
# =========================================
# 7. Transliteration: Avu manegaḷu.
#    Those: PRON
#    are: AUX
#    houses: NOUN
#    .: PUNCT
# POS tags for avu: ['PRON', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT']
# No POS tags found for manegaḷu
# =========================================
# 8. Transliteration: Adu mahiḷe.
#    That: PRON
#    is: AUX
#    a: DET
#    lady: NOUN
#    .: PUNCT
# POS tags for adu: ['PRON']
# POS tags for mahiḷe: ['PROPN']
# =========================================
# 9. Transliteration: Nānu vidyārthi.
#    I: PRON
#    am: AUX
#    a: DET
#    [: X
#    male: NOUN
#    ]: X
#    student: NOUN
#    .: PUNCT
# POS tags for nānu: ['PRON']
# POS tags for vidyārthi: ['X', 'NOUN', 'X', 'NOUN']
# =========================================
# 10. Transliteration: Nānu vidyārthini.
#    I: PRON
#    am: AUX
#    a: DET
#    [: X
#    female: ADJ
#    ]: PUNCT
#    student: NOUN
#    .: PUNCT
# POS tags for nānu: ['PRON']
# POS tags for vidyārthini: ['X', 'ADJ', 'PUNCT', 'NOUN']
# =========================================

# %%
all_pos_mapping = {}
# Combine all mappings  
all_pos_mapping.update(pos_mapping)
all_pos_mapping.update(kannada_pos_mapping)

all_pos_mapping
# Out:
# {'huḷi': ['ADJ'],
#  'huli': ['NOUN'],
#  'haḷḷi': ['NOUN'],
#  'halli': ['NOUN'],
#  'maṇe': ['PROPN'],
#  'mane': ['NOUN'],
#  'hālu': ['NOUN'],
#  'hallu': ['VERB'],
#  'dēva': ['PROPN'],
#  'devva': ['PROPN'],
#  'nānu': ['PRON'],
#  'nāvu': ['PRON'],
#  'avanu': ['PRON'],
#  'avaḷu': ['PRON'],
#  'ivanu': ['PRON'],
#  'ivaḷu': ['PRON'],
#  'illi': ['ADV'],
#  'alli': ['ADV'],
#  'elli': ['SCONJ', 'PUNCT'],
#  'īga': ['ADV'],
#  'āga': ['ADV', 'PUNCT', 'DET', 'NOUN'],
#  'adu': ['PRON', 'PUNCT', 'PRON'],
#  'almāri': ['NOUN'],
#  'ākāśa': ['NOUN'],
#  'idu': ['PRON', 'PUNCT', 'PRON'],
#  'innoṃdu': ['PRON'],
#  'ivattu': ['NOUN'],
#  'ūṭa': ['PUNCT', 'VERB', 'PUNCT', 'NOUN'],
#  'ūru': ['NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN'],
#  'eraḍu': ['NUM'],
#  'aidu': ['NUM'],
#  'oṃdu': ['NUM', 'PUNCT', 'PRON'],
#  'kaṃpyūṭaru': ['NOUN'],
#  'kaṭṭaḍa': ['VERB'],
#  'kāgada': ['NOUN'],
#  'kāḍu': ['NOUN'],
#  'kāru': ['NOUN'],
#  'kiṭaki': ['NOUN'],
#  'kurci': ['NOUN'],
#  'gilāsu': ['NOUN'],
#  'guri': ['NOUN'],
#  'guru': ['NOUN'],
#  'guruvāra': ['PROPN'],
#  'camaca': ['VERB'],
#  'cāku': ['NOUN'],
#  'cāpe': ['NOUN'],
#  'cāvi': ['ADJ'],
#  'citra': ['NOUN'],
#  'ṭyāksi': ['NOUN'],
#  'ṭyūbulaiṭu': ['NOUN'],
#  'taṭṭe': ['NOUN'],
#  'tuṃba': ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'],
#  'dīpa': ['PROPN'],
#  'dēvasthāna': ['PROPN'],
#  'nālku': ['NUM'],
#  'nāḷe': ['NOUN'],
#  'nela': ['NOUN'],
#  'noṇa': ['VERB'],
#  'pustaka': ['NOUN'],
#  'pensilu': ['NOUN'],
#  'phorenar': ['NOUN'],
#  'phōrku': ['NOUN'],
#  'bāgilu': ['NOUN'],
#  'budhavāra': ['PROPN'],
#  'beṃki': ['NOUN'],
#  'bēli': ['NOUN'],
#  'bhāratīya': ['ADJ'],
#  'maṃgaḷavāra': ['PROPN'],
#  'mattu': ['CCONJ'],
#  'manuṣya': ['ADJ', 'PUNCT', 'NOUN'],
#  'mara': ['NOUN', 'PUNCT', 'NOUN'],
#  'mahiḷe': ['PROPN'],
#  'maḷe': ['NOUN'],
#  'māle': ['VERB'],
#  'mūru': ['NUM'],
#  'mēju': ['NOUN'],
#  'mēṇabatti': ['NOUN'],
#  'mōḍa': ['PROPN'],
#  'ravivāra': ['PROPN'],
#  'raste': ['NOUN'],
#  'rikṣā': ['NOUN'],
#  'vimāna': ['NOUN'],
#  'śanivāra': ['PROPN'],
#  'śukravāra': ['NOUN', 'PUNCT', 'NOUN'],
#  'sūṭkēsu': ['NOUN'],
#  'sūrya': ['PROPN'],
#  'sōmavāra': ['PROPN'],
#  'strī': ['NOUN'],
#  'hakki': ['NOUN'],
#  'halavu': ['ADJ'],
#  'hasu': ['NOUN'],
#  'hāḍu': ['NOUN', 'PUNCT', 'PART', 'VERB'],
#  'hippi': ['VERB'],
#  'huḍuga': ['PROPN'],
#  'huḍugi': ['NOUN'],
#  'hū': ['NOUN'],
#  'heṃgasu': ['NOUN'],
#  'hola': ['NOUN'],
#  'haudu': ['INTJ'],
#  'yāvāgalū illa': ['ADV'],
#  'ēnū illa': ['PRON'],
#  'yārū illa': ['PRON'],
#  'ide': ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'],
#  'ēke': ['SCONJ', 'PUNCT'],
#  'ēnu': ['PRON', 'PUNCT'],
#  'kappu': ['ADJ'],
#  'kaṣṭa': ['ADJ'],
#  'toḍaku': ['NOUN'],
#  'nanna': ['PRON'],
#  'namma': ['PRON'],
#  'patra': ['NOUN'],
#  'purōhita': ['NOUN'],
#  'biḷi': ['PROPN'],
#  'maneyavaru': ['NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'DET',
#   'PUNCT',
#   'NOUN',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'yāru': ['PRON', 'PUNCT'],
#  'yāva': ['PRON', 'PUNCT'],
#  'yāvāga': ['SCONJ', 'PUNCT'],
#  'samācāra': ['NOUN'],
#  'hesaru': ['NOUN'],
#  'hēge': ['ADP', 'PRON', 'NOUN', 'PUNCT'],
#  'appa': ['PROPN'],
#  'amma': ['NOUN'],
#  'kaṇṇu': ['NOUN'],
#  'kivi': ['NOUN'],
#  'kuri': ['PART', 'VERB'],
#  'kūsu': ['NOUN'],
#  'gaṃḍa': ['NOUN'],
#  'gaṃḍasu': ['NOUN'],
#  'nighaṃṭu': ['PROPN'],
#  'nīru': ['NOUN'],
#  'buṭṭi': ['NOUN'],
#  'maga': ['NOUN'],
#  'magaḷu': ['NOUN'],
#  'magu': ['NOUN'],
#  'māva': ['NOUN'],
#  'rāja': ['NOUN'],
#  'raita': ['NOUN'],
#  'vidhave': ['NOUN'],
#  'anubhava': ['VERB'],
#  'āṭike': ['NOUN'],
#  'āyke': ['NOUN'],
#  'keṃpu': ['PROPN'],
#  'koṃbu': ['NOUN'],
#  'koṃbe': ['NOUN'],
#  'cūpu': ['ADJ'],
#  'tudi': ['NOUN'],
#  'parimāṇa': ['NOUN'],
#  'baṭṭe': ['NOUN'],
#  'baṇṇa': ['NOUN'],
#  'bēre': ['ADJ', 'PUNCT', 'PRON', 'ADV'],
#  'saṃkhye': ['NOUN'],
#  'hasiru': ['ADJ'],
#  'haḷadi': ['ADJ'],
#  'heṃḍati': ['NOUN'],
#  'nidde': ['NOUN'],
#  'nāyi': ['NOUN'],
#  'kathe': ['NOUN'],
#  'kelasa': ['NOUN'],
#  'toṃdare': ['NOUN'],
#  'nenne': ['NOUN'],
#  'satya': ['NOUN'],
#  'haṇa': ['NOUN'],
#  'haṇṇu': ['NOUN'],
#  'mēle': ['ADP'],
#  'keḷage': ['ADP'],
#  'oḷage': ['ADP'],
#  'oḷagu': ['ADP'],
#  'hattira': ['ADV', 'PUNCT', 'NOUN'],
#  'bage': ['VERB'],
#  'madhya': ['ADJ'],
#  'muṃde': ['ADP'],
#  'horage': ['ADV'],
#  'aḍige': ['VERB'],
#  'uttara': ['NOUN'],
#  'kāpi': ['NOUN'],
#  'gaḍi': ['NOUN'],
#  'cahā': ['NOUN'],
#  'padārtha': ['NOUN'],
#  'pavāḍa': ['NOUN'],
#  'viśēṣavāda': ['ADJ'],
#  'vaiṣṇava': ['NOUN', 'ADP', 'PROPN', 'PUNCT', 'PROPN'],
#  'samādhi': ['NOUN'],
#  'ele': ['VERB'],
#  'athavā': ['CCONJ'],
#  'abhiprāya': ['NOUN'],
#  'iḍiya': ['ADJ'],
#  'upayukta': ['ADJ'],
#  'keṭṭa': ['ADJ'],
#  'kliṣṭa': ['VERB'],
#  'gaddala': ['NOUN'],
#  'cakravarti': ['NOUN'],
#  'cikka': ['ADJ'],
#  'jagattu': ['NOUN'],
#  'dūra': ['NOUN'],
#  'nīli': ['ADJ'],
#  'praśne': ['NOUN'],
#  'bīdi': ['PROPN'],
#  'bhāra': ['NOUN'],
#  'bhārata': ['PROPN'],
#  'mukhya': ['PRON', 'ADJ'],
#  'yuga': ['NOUN'],
#  'saṃgīta': ['NOUN'],
#  'suṃdara': ['ADJ'],
#  'kelavu': ['DET', 'PUNCT', 'NOUN', 'PUNCT'],
#  'kōlu': ['VERB'],
#  'ciṃtaka': ['NOUN'],
#  'tīra': ['PROPN'],
#  'bhakta': ['NOUN', 'PUNCT', 'NOUN'],
#  'maṭha': ['VERB'],
#  'Madhvācārya': ['PUNCT', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT'],
#  'śatamāna': ['NOUN', 'PUNCT', 'NUM', 'NOUN', 'PUNCT'],
#  'saṃpradāya': ['NOUN'],
#  'hadimūraneya': ['NOUN'],
#  'āphisu': ['NOUN'],
#  'oraṭu': ['NOUN'],
#  'krūra': ['ADJ'],
#  'khuśi': ['NOUN'],
#  'tiṃgaḷu': ['NOUN'],
#  'dayaviṭṭu': ['INTJ'],
#  'pāṭha': ['NOUN'],
#  'prayatna': ['NOUN', 'PUNCT', 'VERB', 'PUNCT', 'NOUN'],
#  'muṃdina': ['ADV'],
#  'yōcane': ['VERB'],
#  'vākya': ['VERB'],
#  'śabda': ['NOUN'],
#  'saṃtōṣa': ['NOUN'],
#  'sammēḷana': ['NOUN'],
#  'spaṣṭa': ['ADJ'],
#  'artha': ['VERB'],
#  'ādare': ['CCONJ'],
#  'kṣame': ['NOUN'],
#  'daya': ['NOUN', 'PUNCT', 'NOUN'],
#  'hōṭalu': ['NOUN'],
#  'adhyāpaka': ['NOUN'],
#  'kōpa': ['NOUN'],
#  'graṃthapālaka': ['PROPN'],
#  'graṃthālaya': ['NOUN'],
#  'patrike': ['NOUN'],
#  'sahāya': ['VERB'],
#  'hemme': ['NOUN'],
#  'hōguvike': ['VERB'],
#  'bāḷike': ['VERB'],
#  'ārōgya': ['NOUN'],
#  'gōḍe': ['NOUN'],
#  'gōva': ['PROPN'],
#  'jōru': ['NOUN', 'PUNCT', 'NOUN'],
#  'tinnu': ['PART', 'VERB'],
#  'māṃsa': ['NOUN'],
#  'miliṭari': ['NOUN'],
#  'miliṭari hōṭalu': ['ADJ', 'ADJ', 'NOUN'],
#  'auṣadhi': ['NOUN'],
#  'kaṭṭe': ['VERB'],
#  'giḍa': ['NOUN'],
#  'dēvi': ['NOUN'],
#  'patni': ['NOUN'],
#  'pradakṣiṇe': ['NOUN'],
#  'bhakti': ['NOUN'],
#  'mātra': ['ADV'],
#  'saṃpattu': ['NOUN'],
#  'sādhya': ['ADJ'],
#  'sulabha': ['ADJ'],
#  'saubhāgya': ['ADV', 'PUNCT', 'NOUN'],
#  'atṛpta': ['ADJ'],
#  'atṛpti': ['NOUN'],
#  'anubhāvi': ['ADJ'],
#  'anuyāyi': ['NOUN'],
#  'asamānate': ['NOUN'],
#  'ityādi': ['X', 'X'],
#  'kuṭuṃba': ['NOUN'],
#  'kelavomme': ['ADV'],
#  'guṃpu': ['NOUN'],
#  'jāti': ['NOUN'],
#  'jīvana': ['NOUN'],
#  'tṛpta': ['ADJ'],
#  'tṛpti': ['NOUN'],
#  'dhārmika': ['ADJ'],
#  'naitika': ['ADJ'],
#  'paraṃpare': ['NOUN'],
#  'prapaṃca': ['NOUN'],
#  'prācīna': ['ADJ'],
#  'prīti': ['NOUN'],
#  'Basava': ['PUNCT', 'NOUN', 'PUNCT'],
#  'beḷavaṇige': ['NOUN'],
#  'maṃdi': ['NOUN'],
#  'manassu': ['NOUN'],
#  'samāna': ['ADJ'],
#  'samānate': ['NOUN'],
#  'sāmājika': ['ADJ'],
#  'hiṃde': ['ADV', 'PUNCT', 'ADV'],
#  'hinnele': ['NOUN'],
#  'hosa': ['ADJ'],
#  'anēka': ['ADJ'],
#  'ippataidu': ['NUM', 'PUNCT', 'NUM'],
#  'ēkeṃdare': ['SCONJ'],
#  'omme': ['ADV'],
#  'karāvaḷi': ['PROPN'],
#  'kaḷatmaka': ['ADJ'],
#  'kāphi': ['NOUN'],
#  'kāryakrama': ['NOUN'],
#  'kuḍuma': ['PUNCT', 'NOUN', 'PUNCT'],
#  'kēṃdra': ['NOUN'],
#  'caḷi': ['PART', 'AUX', 'ADJ'],
#  'cikitsālaya': ['NOUN'],
#  'jille': ['NOUN'],
#  'taṃde': ['PROPN'],
#  'takṣaṇa': ['ADV'],
#  'tale': ['NOUN'],
#  'talenōvu': ['PROPN'],
#  'dēvate': ['NOUN'],
#  'Dharmasthaḷa': ['PUNCT', 'NOUN', 'PUNCT'],
#  'nōvu': ['NOUN'],
#  'paṃḍita': ['NOUN'],
#  'pūrvaja': ['NOUN'],
#  'Maṃjunātha': ['PUNCT', 'NOUN', 'PUNCT'],
#  'yātrika': ['NOUN'],
#  'rakṣaṇe': ['NOUN'],
#  'varegū': ['ADP'],
#  'varṣa': ['NOUN'],
#  'Vādirāja': ['PUNCT', 'NOUN', 'PUNCT'],
#  'śikṣaka': ['NOUN'],
#  'saṃgrahālaya': ['NOUN'],
#  'sahiṣṇute': ['NOUN'],
#  'sāṃskṛtika': ['ADJ'],
#  'sāvira': ['NUM',
#   'SCONJ',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'X',
#   'X',
#   'PUNCT',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'AUX',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'sāvirāru': ['NOUN'],
#  'sumāru': ['ADV'],
#  'hadināraneya': ['ADJ'],
#  'huṣāru': ['NOUN'],
#  'ellarannu / ellarannū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellariṃda / ellariṃdalū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellara': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellaralli / ellarallū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'āru': ['NUM'],
#  'ēḷu': ['PART', 'VERB'],
#  'eṃṭu': ['NUM'],
#  'oṃbattu': ['NUM'],
#  'hannoṃdu': ['NUM'],
#  'hanneraḍu': ['NUM'],
#  'hadimūru': ['NUM'],
#  'hadinālku': ['NUM'],
#  'hadinaidu': ['NUM'],
#  'hadināru': ['NUM'],
#  'hadinēḷu': ['X'],
#  'hadineṃṭu': ['NUM'],
#  'hattoṃbattu': ['NUM'],
#  'ippattu': ['NUM'],
#  'ippattoṃdu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteraḍu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattanālku': ['NUM', 'PUNCT', 'NUM'],
#  'ippattaidu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattāru': ['NUM', 'PUNCT', 'NUM'],
#  'ippattēḷu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteṃṭu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattoṃbattu': ['NUM', 'PUNCT', 'NUM'],
#  'aivattu': ['NUM'],
#  'aravattu': ['NUM'],
#  'eppattu': ['NUM'],
#  'eṃbattu': ['NUM'],
#  'toṃbattu': ['NUM'],
#  'nūru': ['NUM'],
#  'innūru': ['NUM'],
#  'munnūru': ['NUM'],
#  'nānūru': ['NUM'],
#  'ainūru': ['NUM'],
#  'ārunūru': ['NUM'],
#  'ēḷunūru': ['NUM'],
#  'eṃṭunūru': ['NUM'],
#  'oṃbainūru': ['NUM'],
#  'nūra nalvattoṃdu': ['NUM'],
#  'sāvirada oṃbainūra toṃbattaidu': ['NUM'],
#  'āgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'hōgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'utkhanana': ['NOUN'],
#  'hagga': ['NOUN'],
#  'heccu': ['ADV', 'PUNCT', 'DET', 'NOUN', 'PUNCT', 'ADV'],
#  'ajja': ['NOUN'],
#  'jñāna': ['NOUN'],
#  'daḍḍa': ['NOUN'],
#  'kobbu': ['ADJ'],
#  'udbhava': ['NOUN'],
#  'ayya': ['PROPN'],
#  'prabhāva': ['NOUN'],
#  'tatva': ['NOUN'],
#  'utsava': ['NOUN'],
#  'kaḷḷa': ['NOUN'],
#  'aparūpavāgi': ['ADV'],
#  'jana': ['NOUN', 'PUNCT', 'NOUN'],
#  'bahaḷa': ['ADJ', 'PUNCT', 'ADJ', 'PUNCT', 'ADV'],
#  'bhāṣe': ['NOUN'],
#  'yāvāgalū': ['ADV'],
#  'haḷeya': ['ADJ'],
#  'aṃgaḍiyavaru': ['NOUN'],
#  'ajñāna': ['NOUN'],
#  'gottu': ['NOUN', 'PUNCT', 'ADJ', 'NOUN'],
#  'nṛtya': ['VERB'],
#  'paravā': ['VERB'],
#  'parvata': ['NOUN'],
#  'baḷi': ['ADP'],
#  'buddhi': ['NOUN'],
#  'beḷaku': ['ADJ'],
#  'bhasma': ['PROPN'],
#  'majjige': ['NOUN'],
#  'mūgu': ['NOUN'],
#  'modalaneya': ['ADV'],
#  'rākṣasa': ['NOUN'],
#  'rūpa': ['NOUN', 'PUNCT', 'NOUN'],
#  'vimānanildāṇa': ['NOUN'],
#  'vaiṣṇavadharma': ['NOUN'],
#  'saṃkēta': ['NOUN'],
#  'saṃsthe': ['PROPN'],
#  'sāṃkētika': ['ADJ'],
#  'sāmānya': ['ADJ'],
#  'haṇe': ['PROPN'],
#  'ōḍu': ['PART', 'VERB'],
#  'ōdu': ['PART', 'VERB'],
#  'hēḷu': ['PART', 'VERB'],
#  'hēlu': ['PART', 'VERB'],
#  'baḍi': ['PART', 'VERB'],
#  'baḍḍi': ['NOUN', 'PUNCT', 'ADP', 'NOUN', 'PUNCT'],
#  'maḍi': ['ADV', 'ADJ'],
#  'māḍi': ['INTJ',
#   'VERB',
#   'DET',
#   'NUM',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'DET',
#   'ADV',
#   'NOUN',
#   'NOUN',
#   'VERB',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NUM',
#   'PUNCT',
#   'PUNCT',
#   'CCONJ',
#   'SCONJ',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADJ',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'AUX',
#   'ADJ',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PRON',
#   'AUX',
#   'SCONJ',
#   'ADP',
#   'DET',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'CCONJ',
#   'DET',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'NOUN',
#   'PUNCT'],
#  'nīnu': ['PRON', 'PUNCT', 'ADJ', 'CCONJ', 'ADJ', 'ADJ', 'ADJ', 'PUNCT'],
#  'nīvu': ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'],
#  'avaru': ['PRON', 'PUNCT', 'NOUN', 'PUNCT'],
#  'avu': ['PRON', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT'],
#  'ivaru': ['PRON', 'SYM', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'ivu': ['PRON',
#   'SYM',
#   'DET',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'PART',
#   'PRON',
#   'PRON',
#   'VERB',
#   'AUX',
#   'ADJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'SCONJ',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'AUX',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'CCONJ',
#   'ADJ',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'PUNCT'],
#  'hīge': ['ADP', 'DET', 'NOUN'],
#  'hāge': ['ADP', 'DET', 'NOUN'],
#  'iṣṭu': ['PRON', 'ADJ'],
#  'aṣṭu': ['ADV', 'ADV'],
#  'eṣṭu': ['SCONJ', 'ADJ', 'PUNCT'],
#  'ili': ['PROPN', 'PUNCT', 'CCONJ'],
#  'kālu': ['PROPN', 'PUNCT', 'NOUN'],
#  'kai': ['NOUN', 'PUNCT', 'VERB'],
#  'graṃtha': ['NOUN', 'PUNCT', 'NOUN'],
#  'doḍḍa': ['ADJ', 'PUNCT', 'ADJ'],
#  'paṃce': ['PUNCT',
#   'ADJ',
#   'NOUN',
#   'PART',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'PUNCT'],
#  'pennu': ['PROPN', 'NOUN'],
#  'pyāṃṭu': ['NOUN', 'ADP', 'NOUN'],
#  'beṭṭa': ['PROPN', 'PUNCT', 'NOUN'],
#  'muduki': ['ADJ', 'NOUN'],
#  'maidāna': ['PROPN', 'PUNCT', 'NOUN'],
#  'yuvati': ['ADJ', 'NOUN'],
#  'luṃgi': ['PUNCT',
#   'ADJ',
#   'NOUN',
#   'PART',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'vidyārthi': ['X', 'NOUN', 'X', 'NOUN'],
#  'vidyārthini': ['X', 'ADJ', 'PUNCT', 'NOUN'],
#  'Viṣṇu': ['PUNCT', 'NOUN', 'ADP', 'PROPN', 'PUNCT'],
#  'Śiva': ['PUNCT', 'NOUN', 'ADP', 'PROPN', 'PUNCT'],
#  'sagaṇi': ['NOUN', 'PROPN'],
#  'sāmānugaḷu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sīre': ['PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'hāḍugāra': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'hāḍugārti': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'Namaskāra.': ['PUNCT',
#   'DET',
#   'ADJ',
#   'AUX',
#   'VERB',
#   'SCONJ',
#   'NOUN',
#   'PUNCT'],
#  'Banni.': ['INTJ',
#   'PUNCT',
#   'PRON',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'PUNCT'],
#  'Hēgiddīri?': ['SCONJ', 'AUX', 'PRON', 'PUNCT', 'NOUN'],
#  'ivara': ['PRON', 'SYM', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'elliṃda': ['ADP', 'SCONJ', 'PUNCT'],
#  'cennāgi': ['ADV', 'PUNCT', 'ADV'],
#  'nimma': ['PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'banni': ['INTJ', 'VERB'],
#  'barali': ['PRON', 'AUX', 'VERB'],
#  'baru': ['PART', 'VERB'],
#  'bassu': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'bēku': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'],
#  'bēḍa': ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'viśēṣa': ['PRON', 'ADJ'],
#  'sari': ['INTJ', 'PUNCT', 'ADV', 'ADV', 'PUNCT', 'ADJ'],
#  'akka': ['ADJ', 'NOUN'],
#  'aṇṇa': ['ADJ', 'NOUN'],
#  'kere': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'cīla': ['PROPN', 'PUNCT', 'NOUN'],
#  'dēśa': ['NOUN', 'PUNCT', 'NOUN'],
#  'puṭa': ['PROPN', 'PUNCT', 'ADP', 'NOUN', 'X', 'PUNCT', 'PUNCT'],
#  'snēhita': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'snēhite': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'aṃgaḍi': ['PROPN', 'PUNCT', 'NOUN'],
#  'jijñāsu': ['ADJ', 'PART', 'VERB'],
#  'paṃḍite': ['VERB', 'NOUN'],
#  'hōdenu': ['PRON', 'VERB'],
#  'ādenu': ['PRON', 'VERB'],
#  'hōdi': ['PRON', 'VERB'],
#  'ādi': ['PRON', 'VERB'],
#  'hōdanu': ['PRON', 'VERB'],
#  'ādanu': ['PRON', 'VERB'],
#  'hōdaḷu': ['PRON', 'VERB'],
#  'ādaḷu': ['PRON', 'VERB'],
#  'hōdevu': ['PRON', 'VERB'],
#  'ādevu': ['PRON', 'VERB'],
#  'hōdiri': ['PRON', 'VERB'],
#  'ādiri': ['PRON', 'VERB'],
#  'hōdaru': ['PRON', 'VERB'],
#  'ādaru': ['PRON', 'VERB'],
#  'āgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'jigi': ['PART', 'VERB'],
#  'kare': ['PART', 'VERB'],
#  'taru': ['PART', 'VERB'],
#  'tiḷi': ['PART', 'VERB'],
#  'nagu': ['PART', 'VERB'],
#  'bīḷu': ['PART', 'VERB'],
#  'māḍu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hoḍe': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hōgu': ['PART', 'VERB'],
#  'nōḍu': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADP'],
#  'bare': ['PART', 'VERB'],
#  'anna': ['PROPN', 'PUNCT', 'VERB', 'PUNCT'],
#  'koḍu': ['PART', 'VERB'],
#  'viṣaya': ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'sāku': ['PRON', 'AUX', 'ADJ'],
#  'sāladu': ['PRON', 'AUX', 'PART', 'ADJ'],
#  'mēlu': ['ADJ', 'NOUN'],
#  'keḷagu': ['ADJ', 'NOUN'],
#  'hiṃdu': ['ADJ', 'NOUN'],
#  'āyitu': ['ADV', 'ADV', 'PUNCT', 'INTJ'],
#  'iḍu': ['ADP', 'NOUN', 'PUNCT', 'VERB'],
#  'īgalū': ['ADV', 'ADV'],
#  'kaḍe': ['NOUN', 'PUNCT', 'NOUN'],
#  'kōṇe': ['NOUN', 'PUNCT', 'PROPN'],
#  'gaḍipradēśa': ['NOUN', 'NOUN'],
#  'tagoḷḷu': ['PART', 'VERB'],
#  'darśana': ['VERB',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN'],
#  'nija': ['ADJ', 'PUNCT', 'ADJ'],
#  'nijavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'pradēśa': ['PROPN', 'PUNCT', 'NOUN'],
#  'bāḷu': ['PART', 'VERB'],
#  'summane': ['ADV', 'ADP', 'PRON', 'PUNCT', 'ADV'],
#  'svalpa': ['DET', 'NOUN', 'PUNCT', 'DET', 'ADJ'],
#  'bāḷe': ['PROPN', 'NOUN'],
#  'rīti': ['NOUN', 'PUNCT', 'ADJ'],
#  'asahya': ['ADJ', 'PUNCT', 'ADJ'],
#  'āḍu': ['PART', 'VERB'],
#  'iṣṭa': ['VERB', 'PUNCT', 'VERB'],
#  'kēḷu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'kṣētra': ['NOUN', 'ADP', 'NOUN'],
#  'jāga': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'taṃgi': ['ADJ', 'NOUN'],
#  'tīrthaṃkara': ['PUNCT', 'ADJ', 'NOUN', 'ADP', 'PROPN', 'PUNCT'],
#  'pūjārha': ['ADJ', 'ADP', 'NOUN'],
#  'prakāra': ['VERB', 'ADP'],
#  'mūrti': ['NOUN', 'PUNCT', 'NOUN'],
#  'modalu': ['ADV', 'PUNCT', 'ADP', 'DET', 'NOUN'],
#  'mōkṣa': ['PUNCT', 'ADJ', 'PUNCT', 'NOUN'],
#  'saṃsāra': ['PUNCT', 'DET', 'ADJ', 'NOUN', 'ADP'],
#  'hoṃdu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'kelasadavaḷu': ['X',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'DET',
#   'PUNCT',
#   'NOUN',
#   'PRON',
#   'PUNCT',
#   'PUNCT'],
#  'avatāra': ['NOUN', 'ADP', 'DET', 'NOUN'],
#  'gurutu': ['PROPN', 'PUNCT', 'ADJ'],
#  'jāsti': ['ADV', 'ADJ', 'PUNCT', 'ADV'],
#  'taṃdaru': ['PRON', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT', 'VERB'],
#  'tanna': ['PRON', 'SYM', 'PRON', 'SYM', 'PRON', 'ADJ'],
#  'divasā': ['DET', 'NOUN'],
#  'pūje': ['NOUN', 'ADP', 'NOUN'],
#  'rathabīdi': ['PROPN', 'PROPN'],
#  'vidēśa': ['ADJ', 'NOUN'],
#  'samudra': ['PROPN', 'PUNCT', 'NOUN'],
#  'iḷi': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADV'],
#  'kadi': ['PART', 'VERB'],
#  'kāpāḍu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'koḷḷu': ['PART', 'VERB'],
#  'tīvra': ['ADJ', 'PUNCT', 'ADJ'],
#  'naḍe': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'paḍu': ['PART', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'VERB'],
#  'bayyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'beḷe': ['PART', 'VERB'],
#  'bhāgavahisu': ['PART', 'VERB'],
#  'malagu': ['PART', 'VERB', 'ADV', 'PUNCT', 'VERB'],
#  'mātanāḍu': ['PART', 'VERB'],
#  'lēkhaki': ['NOUN', 'PUNCT', 'ADJ', 'PUNCT'],
#  'vāpasu': ['ADV', 'PUNCT', 'VERB'],
#  'sustu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sogasu': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'hattu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'hāru': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'horaḍu': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB', 'ADP'],
#  'kareyisu': ['PART', 'VERB', 'PART', 'VERB'],
#  'prakaṭa': ['VERB', 'PUNCT', 'ADJ'],
#  'bēga': ['ADV', 'PUNCT', 'ADV'],
#  'mēṣṭaru': ['PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'vicitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'araḷu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'tamma': ['ADJ', 'NOUN'],
#  'neraḷu': ['PROPN', 'PUNCT', 'NOUN'],
#  'mātu': ['NOUN', 'PUNCT', 'NOUN'],
#  'vāsa': ['VERB', 'PUNCT', 'VERB'],
#  'sigu': ['PART', 'AUX', 'VERB', 'PUNCT', 'PART', 'AUX', 'VERB'],
#  'suddi': ['NOUN', 'PUNCT', 'NOUN'],
#  'bāradu': ['AUX', 'PART'],
#  'āse': ['NOUN', 'PUNCT', 'VERB'],
#  'heṃḍa': ['ADJ', 'NOUN'],
#  'eṃdare': ['X', 'PUNCT', 'PRON', 'AUX', 'PART', 'VERB'],
#  'oḍati': ['NOUN', 'PUNCT', 'NOUN'],
#  'kāṇisu': ['PART', 'AUX', 'VERB', 'PUNCT', 'VERB'],
#  'kāraṇa': ['NOUN', 'PUNCT', 'NOUN'],
#  'tuḷasi': ['ADJ', 'NOUN'],
#  'pavitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'pūjisu': ['PART', 'VERB'],
#  'baḷasu': ['PART', 'VERB'],
#  'beḷigge': ['ADP', 'DET', 'NOUN'],
#  'śakti': ['NOUN', 'PUNCT', 'NOUN'],
#  'hittalu': ['NOUN', 'NOUN'],
#  'hedaru': ['PART', 'VERB'],
#  'kareyavu': ['ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'VERB',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'AUX',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'PART'],
#  'anubhavisu': ['PART', 'VERB'],
#  'anubhāva': ['ADJ', 'NOUN'],
#  'kelavaru': ['DET', 'NOUN'],
#  'guṃpugārike': ['NOUN', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT'],
#  'naṃbu': ['PART', 'VERB'],
#  'baduku': ['PART', 'VERB'],
#  'Basavaṇṇa': ['PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PROPN',
#   'PUNCT',
#   'PUNCT'],
#  'mānava': ['ADJ', 'PUNCT', 'NOUN'],
#  'vacana': ['PUNCT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'vaiyaktika': ['PRON', 'ADJ'],
#  'vyakti': ['NOUN', 'PUNCT', 'ADJ'],
#  'śivamaya': ['VERB', 'ADP', 'PROPN'],
#  'śaiva': ['VERB', 'ADP', 'PROPN'],
#  'saṃbhavisu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'sādhane': ['ADJ', 'NOUN', 'SYM', 'NOUN'],
#  'sāhityakṛti': ['ADJ', 'NOUN'],
#  'halavaru': ['ADJ', 'NOUN'],
#  'ivattina': ['NOUN', 'PART', 'PUNCT', 'ADP', 'NOUN'],
#  'īgina': ['ADP', 'ADV', 'PUNCT', 'ADJ'],
#  'uḷi': ['PART', 'VERB'],
#  'kali': ['PART', 'VERB'],
#  'guḍḍa': ['PROPN', 'PUNCT', 'NOUN'],
#  'jotege': ['ADV', 'ADP'],
#  'dharmādhikāri': ['PUNCT', 'ADJ', 'NOUN', 'CCONJ', 'NOUN', 'PUNCT'],
#  'neṃṭa': ['PUNCT', 'ADJ', 'PUNCT', 'NOUN'],
#  'pradhāna': ['ADJ', 'PUNCT', 'NOUN'],
#  'prāṇa': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'balakaḍe': ['INTJ', 'PUNCT', 'NOUN', 'PUNCT'],
#  'beṃḍekāyi': ['PROPN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'muṃcitavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'muṃduvari': ['PART', 'VERB'],
#  'mugi': ['PART', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT'],
#  'mugisu': ['PART',
#   'VERB',
#   'PUNCT',
#   'PROPN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'yati': ['VERB', 'ADJ'],
#  'rūḍhi': ['NOUN', 'PUNCT', 'NOUN'],
#  'lābha': ['NOUN', 'PUNCT', 'NOUN'],
#  'liṃga': ['PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'sinima': ['NOUN', 'NOUN'],
#  'hāgādare': ['ADP', 'DET', 'NOUN', 'PUNCT', 'SCONJ', 'PRON', 'AUX', 'ADV'],
#  'hāgū': ['CCONJ', 'PUNCT', 'ADV'],
#  'haṇṇugaḷellavu': ['PUNCT', 'DET', 'ADJ', 'PUNCT'],
#  'vidyārthigaḷellaru': ['PUNCT', 'DET', 'ADJ', 'PUNCT'],
#  'elladariṃda': ['ADP', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'elladakke': ['ADP', 'PRON', 'PUNCT', 'NOUN', 'PUNCT'],
#  'elladara': ['ADP', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'elladaralli': ['ADP', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'],
#  'baredukoḷḷi': ['INTJ',
#   'VERB',
#   'ADP',
#   'X',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'SCONJ',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'PUNCT'],
#  'baredukoḍi': ['INTJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADP',
#   'PRON',
#   'ADP',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT'],
#  'maretubiḍi!': ['INTJ', 'VERB', 'PRON', 'PUNCT'],
#  'saṃkōcapaḍabēḍa': ['AUX',
#   'PART',
#   'AUX',
#   'ADJ',
#   'X',
#   'PUNCT',
#   'AUX',
#   'PART',
#   'VERB',
#   'PROPN',
#   'PUNCT',
#   'PUNCT'],
#  'oṃdannu': ['NUM', 'PUNCT', 'ADJ', 'ADJ', 'PUNCT'],
#  'oṃdariṃda': ['ADP', 'NUM'],
#  'oṃdakke': ['ADP', 'NUM'],
#  'oṃdara': ['ADP', 'NUM'],
#  'oṃdaralli': ['ADP', 'NUM'],
#  'eraḍannu': ['NUM', 'PUNCT', 'ADJ', 'ADJ', 'PUNCT'],
#  'mūrakke': ['ADP', 'NUM'],
#  'nālkara': ['ADP', 'NUM'],
#  'aidariṃda': ['ADP', 'NUM'],
#  'āraralli': ['ADP',
#   'NUM',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'oṃdaneyadu': ['DET', 'ADJ', 'NUM'],
#  'hattaneyavanu': ['DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'X',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'aidaneyadaralli': ['ADP', 'DET', 'ADJ', 'NUM'],
#  'hattaneyavanige': ['ADP', 'DET', 'ADJ', 'NOUN'],
#  'obbanu': ['NUM', 'X', 'NOUN', 'X', 'NOUN'],
#  'obbaḷu': ['NUM', 'X', 'ADJ', 'PUNCT', 'NOUN'],
#  'obbaru': ['NUM', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'CCONJ', 'ADJ', 'PUNCT'],
#  'ibbaru': ['NUM', 'NOUN'],
#  'mūvaru': ['NUM', 'NOUN'],
#  'nālvaru': ['NUM', 'NOUN'],
#  'aivaru': ['NUM', 'NOUN'],
#  'ari': ['PART', 'VERB'],
#  'aritenu': ['PRON', 'VERB'],
#  'kalitenu': ['PRON', 'VERB'],
#  'mare': ['PART', 'VERB'],
#  'ennu': ['PART', 'VERB'],
#  'eṃdenu': ['PRON', 'VERB'],
#  'tiṃdenu': ['PRON', 'VERB'],
#  'baydenu': ['PRON',
#   'VERB',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'PUNCT',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN'],
#  'kāyu': ['PART', 'VERB', 'SYM', 'VERB', 'ADJ'],
#  'kādenu': ['PRON', 'VERB'],
#  'kuḷiru': ['PART', 'VERB', 'ADP'],
#  'kuḷitenu': ['PRON', 'VERB', 'ADP'],
#  'sōlu': ['PART', 'AUX', 'VERB'],
#  'sīnu': ['PART', 'VERB'],
#  'sītenu': ['PRON',
#   'VERB',
#   'PRON',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADV',
#   'SCONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADV'],
#  'ese': ['PART', 'VERB'],
#  'kusi': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB'],
#  'koḷe': ['PART', 'VERB'],
#  'dore': ['PART', 'AUX', 'VERB'],
#  'bese': ['PART', 'VERB'],
#  'mase': ['AUX', 'VERB'],
#  'moḷe': ['PART', 'VERB'],
#  'husi': ['PART', 'VERB', 'NOUN', 'SYM', 'NOUN'],
#  'āyu': ['PART', 'VERB'],
#  'oyyu': ['PART', 'VERB', 'ADP'],
#  'koyyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'geyyu': ['PART', 'VERB'],
#  'tēyu': ['PART', 'VERB'],
#  'toyyu': ['PART', 'VERB', 'ADJ'],
#  'māyu': ['PART', 'AUX', 'VERB'],
#  'mēyu': ['PART', 'VERB'],
#  'suyyu': ['PART', 'VERB'],
#  'hāyu': ['PART', 'VERB', 'ADP'],
#  'kavalu': ['PART', 'VERB', 'ADJ'],
#  'ciguru': ['PART', 'VERB'],
#  'bevaru': ['PART', 'VERB'],
#  'nāru': ['PART', 'VERB'],
#  'iru': ['PART', 'AUX'],
#  'teru': ['PART', 'VERB'],
#  'bēsaru': ['PART', 'AUX', 'VERB'],
#  'heru': ['PART', 'VERB', 'NOUN'],
#  'horu': ['PART', 'VERB', 'DET', 'NOUN'],
#  'kollu': ['PART', 'VERB'],
#  'gellu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'nillu': ['PART', 'VERB'],
#  'aḷu': ['PART', 'VERB'],
#  'uḷu': ['PART', 'VERB'],
#  'kaḷu': ['PART', 'VERB'],
#  'kīḷu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'biddu': ['PUNCT',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NUM',
#   'ADJ',
#   'PUNCT',
#   'VERB',
#   'NOUN',
#   'PUNCT',
#   'PUNCT'],
#  'bēyu': ['AUX', 'VERB'],
#  'mīyu': ['PART', 'VERB'],
#  'aḍu': ['PART', 'VERB'],
#  'uḍu': ['PART', 'VERB'],
#  'keḍu': ['PART', 'AUX', 'VERB'],
#  'toḍu': ['PART', 'VERB'],
#  'neḍu': ['PART', 'VERB'],
#  'biḍu': ['PART', 'VERB'],
#  'suḍu': ['PART', 'VERB'],
#  'uṇṇu': ['PART', 'VERB'],
#  'kāṇu': ['PART', 'VERB'],
#  'hogu': ['PART', 'VERB'],
#  'hokku': ['ADJ', 'VERB', 'NOUN', 'PUNCT'],
#  'ode': ['PART', 'VERB'],
#  'hode': ['PART', 'VERB', 'ADP', 'PUNCT', 'NOUN', 'PUNCT'],
#  'eḷe': ['PART', 'VERB'],
#  'tege': ['PART', 'VERB'],
#  'mlēccha': ['PROPN', 'PUNCT', 'NOUN'],
#  'adannu': ['SCONJ', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'],
#  'oḷḷeyadu': ['ADJ', 'NOUN'],
#  'kalitare': ['SCONJ', 'X', 'NUM', 'PUNCT', 'VERB'],
#  'cennāgide': ['AUX', 'ADJ'],
#  'namage': ['PRON', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'],
#  'niṃtiddāre': ['PRON', 'VERB'],
#  'baruttāre': ['PRON', 'VERB'],
#  'meccuviri': ['PRON', 'AUX', 'VERB'],
#  'yaśasvi': ['ADJ', 'PUNCT', 'ADJ'],
#  'agnimaṃḍala': ['NOUN', 'ADP', 'NOUN'],
#  'apasmara': ['PUNCT', 'NOUN', 'ADP', 'DET', 'NOUN', 'PUNCT'],
#  'uṃṭāgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'uṃṭumāḍu': ['PART', 'VERB'],
#  'kaiyalli': ['PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'ADP'],
#  'korate': ['NOUN', 'PUNCT', 'VERB'],
#  'gaṃgādhara': ['PUNCT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'caṃdraśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'tāṃḍava': ['PUNCT', 'NOUN', 'ADP', 'PROPN', 'PART', 'NOUN', 'PUNCT'],
#  'nakk-': ['PUNCT', 'ADJ', 'NOUN', 'ADP', 'NOUN', 'PUNCT'],
#  'naṃjuṃḍa': ['PUNCT', 'PRON', 'VERB', 'NOUN', 'PUNCT'],
#  'nāśa': ['NOUN', 'PUNCT', 'PROPN'],
#  'mallikārjuna': ['PUNCT', 'ADJ', 'ADP', 'NOUN', 'PUNCT'],
#  'mahatva': ['NOUN', 'PUNCT', 'NOUN'],
#  'rēkhē': ['ADJ', 'PUNCT', 'NOUN'],
#  'vāsasthaḷa': ['NOUN', 'ADP', 'NOUN'],
#  'vibhūti': ['PROPN',
#   'PROPN',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'śivabhakta': ['NOUN', 'ADP', 'NOUN'],
#  'siddhapuruṣa': ['ADV', 'VERB', 'NOUN'],
#  'sōmaśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'svabhāva': ['NOUN', 'PUNCT', 'NOUN'],
#  'haccu': ['PART', 'VERB', 'PUNCT', 'VERB']}

# %% [markdown]
# # Quick affix separation test

# %%
results = []

desc_sorted_all_pos_mapping = dict(sorted(all_pos_mapping.items(), key=lambda item: len(item[0]), reverse=True))
for i,sentence in enumerate(other_sentences_transliterations):

    translated_sentence = other_sentences_sentences[i]
    transliteration = sentence.lower()
    transliteration = transliteration.strip()
    # Remove any trailing punctuation
    
    # Split into words
    transliteration = transliteration.split()
    # Remove trailing punctuation from each word
    transliteration = [word.rstrip('.,!?') for word in transliteration]
    #print(transliteration)
    result_dict = {}
    
    # Check if the transliteration is in the pos_mapping
    for word in transliteration:
        word = word.lower()
        if word in all_pos_mapping:
            # Check if the word is in kan_to_eng_mapping
            if word in kan_to_eng_mapping:
                translation = kan_to_eng_mapping[word]
            else:
                print(f"No translation found for {word}")
                translation = None
            result_dict[word] = {"pos": all_pos_mapping[word], "translation": translation, "affix": None}
        else:
            #print(f"No POS tags found for {word}")
            # Find if the word is affixed form of any word in all_pos_mapping
            found = False
            for key in desc_sorted_all_pos_mapping.keys():
                temp_key = key
                key = key.lower()
                if word.find(key) != -1:
                    found = True
                    #print(f"Found affixed form of {key} in {word}")
                    #print(transliteration)
                    affix = word.replace(key, "______")
                    prefix,suffix = affix.split("______")
                    #print(f"Prefix: {prefix} Suffix: {suffix}")
                    result_dict[word] = {
                        "pos": all_pos_mapping[temp_key],
                        "translation": kan_to_eng_mapping.get(temp_key, None),
                        "affix": {
                            "prefix": prefix,
                            "suffix": suffix
                        }
                    }
                    
                    break
            if not found:
                print(f"No affixed form found for '{word}' do more fuzzy matching (TODO)")
                result_dict[word] = {"pos": None, "translation": None, "affix": None}
    results.append((sentence,translated_sentence, result_dict))
    #print("=========================================")
# Out:
# No affixed form found for 'adū' do more fuzzy matching (TODO)
# No affixed form found for 'alla' do more fuzzy matching (TODO)
# No affixed form found for 'toḍak-alla' do more fuzzy matching (TODO)
# No affixed form found for 'toḍak-illa' do more fuzzy matching (TODO)
# No affixed form found for 'adū' do more fuzzy matching (TODO)
# No affixed form found for 'adū' do more fuzzy matching (TODO)
# No affixed form found for 'adū' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'bekku' do more fuzzy matching (TODO)
# No affixed form found for 'dhāravāḍa' do more fuzzy matching (TODO)
# No affixed form found for 'karnāṭakada' do more fuzzy matching (TODO)
# No affixed form found for 'ēnū' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'nīvū' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'baralā' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'nānū' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'baralā' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'kṣamisi' do more fuzzy matching (TODO)
# No affixed form found for '/' do more fuzzy matching (TODO)
# No affixed form found for 'kṣamisiri' do more fuzzy matching (TODO)
# No affixed form found for 'avara' do more fuzzy matching (TODO)
# No affixed form found for 'baṃda' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'maisūrige' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷidanu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭanu' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'sāladā' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'kaṭṭidaru' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'nanagōskara' do more fuzzy matching (TODO)
# No affixed form found for 'nimagōskara' do more fuzzy matching (TODO)
# No affixed form found for 'baṃda' do more fuzzy matching (TODO)
# No affixed form found for 'ō' do more fuzzy matching (TODO)
# No affixed form found for 'gaṇēśarē' do more fuzzy matching (TODO)
# No affixed form found for 'hēgiddīri' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'alla' do more fuzzy matching (TODO)
# No affixed form found for 'tagoḷḷi' do more fuzzy matching (TODO)
# No affixed form found for 'exercise' do more fuzzy matching (TODO)
# No affixed form found for '2' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'exercise' do more fuzzy matching (TODO)
# No affixed form found for '2' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'avaradakke' do more fuzzy matching (TODO)
# No affixed form found for 'rāmanigiṃta' do more fuzzy matching (TODO)
# No affixed form found for 'gaṇēśa' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'dhāravāḍa' do more fuzzy matching (TODO)
# No affixed form found for 'adakkiṃta' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'elladakkiṃta' do more fuzzy matching (TODO)
# No affixed form found for 'rāma' do more fuzzy matching (TODO)
# No affixed form found for 'surēśarē' do more fuzzy matching (TODO)
# No affixed form found for 'gaṇēśā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'kēḷi' do more fuzzy matching (TODO)
# No affixed form found for 'paṭṭaru' do more fuzzy matching (TODO)
# No affixed form found for 'ōdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'ōdiddenu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'mātanāḍidanu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdaru' do more fuzzy matching (TODO)
# No affixed form found for '/' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'tappu' do more fuzzy matching (TODO)
# No affixed form found for 'tōruttade' do more fuzzy matching (TODO)
# No affixed form found for 'tōrisuttēne' do more fuzzy matching (TODO)
# No affixed form found for '/' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍida' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍida' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍidaru' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍida' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'tōrisida' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷida' do more fuzzy matching (TODO)
# No affixed form found for 'baṃda' do more fuzzy matching (TODO)
# No affixed form found for 'nagara' do more fuzzy matching (TODO)
# No affixed form found for 'nagara' do more fuzzy matching (TODO)
# No affixed form found for 'avaḷige' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'nagara' do more fuzzy matching (TODO)
# No affixed form found for 'avaḷige' do more fuzzy matching (TODO)
# No affixed form found for 'ōdida' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'araḷida' do more fuzzy matching (TODO)
# No affixed form found for 'araḷida' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍidanu' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍidanō' do more fuzzy matching (TODO)
# No affixed form found for 'avanige' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'bhēṭi' do more fuzzy matching (TODO)
# No affixed form found for 'ādevō' do more fuzzy matching (TODO)
# No affixed form found for 'avaḷannu' do more fuzzy matching (TODO)
# No affixed form found for 'gottilla' do more fuzzy matching (TODO)
# No affixed form found for 'nagabēkō' do more fuzzy matching (TODO)
# No affixed form found for 'aḷabēkō' do more fuzzy matching (TODO)
# No affixed form found for 'gottilla' do more fuzzy matching (TODO)
# No affixed form found for 'ēḷige' do more fuzzy matching (TODO)
# No affixed form found for 'ēḷge' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'gottilla' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'taṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'koḷḷalu' do more fuzzy matching (TODO)
# No affixed form found for 'taṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'māḍalikke' do more fuzzy matching (TODO)
# No affixed form found for 'samaya' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'bēkā' do more fuzzy matching (TODO)
# No affixed form found for 'avarannu' do more fuzzy matching (TODO)
# No affixed form found for 'māḍabēḍi' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nānū' do more fuzzy matching (TODO)
# No affixed form found for 'barabahudā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'gottilla' do more fuzzy matching (TODO)
# No affixed form found for 'avarū' do more fuzzy matching (TODO)
# No affixed form found for 'barabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'yuvudilla' do more fuzzy matching (TODO)
# No affixed form found for 'ba-' do more fuzzy matching (TODO)
# No affixed form found for 'reyuvudilla' do more fuzzy matching (TODO)
# No affixed form found for 'ba-' do more fuzzy matching (TODO)
# No affixed form found for 'reyuvudilla' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'vudilla' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷidanu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷidaru' do more fuzzy matching (TODO)
# No affixed form found for 'laṃḍan' do more fuzzy matching (TODO)
# No affixed form found for 'eṃba' do more fuzzy matching (TODO)
# No affixed form found for 'ūrige' do more fuzzy matching (TODO)
# No affixed form found for 'eṃbudu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'māḍalilla' do more fuzzy matching (TODO)
# No affixed form found for 'aṃte' do more fuzzy matching (TODO)
# No affixed form found for 'ūraṃte' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'iddāre' do more fuzzy matching (TODO)
# No affixed form found for 'ive' do more fuzzy matching (TODO)
# No affixed form found for 'avana' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'avaniṃda' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nānū' do more fuzzy matching (TODO)
# No affixed form found for 'na' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'huṣāriralilla' do more fuzzy matching (TODO)
# No affixed form found for 'sīte' do more fuzzy matching (TODO)
# No affixed form found for 'avara' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdare' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdarū' do more fuzzy matching (TODO)
# No affixed form found for 'nānū' do more fuzzy matching (TODO)
# No affixed form found for 'yārō' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdaru' do more fuzzy matching (TODO)
# No affixed form found for 'yārannō' do more fuzzy matching (TODO)
# No affixed form found for 'yārādarū' do more fuzzy matching (TODO)
# No affixed form found for 'barabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'kūtukoḷḷi' do more fuzzy matching (TODO)
# No affixed form found for 'ēnādarū' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷi' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'iddāre' do more fuzzy matching (TODO)
# No affixed form found for 'hōda' do more fuzzy matching (TODO)
# No affixed form found for 'ēnū' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'ella' do more fuzzy matching (TODO)
# No affixed form found for 'ella' do more fuzzy matching (TODO)
# No affixed form found for 'vidhy-' do more fuzzy matching (TODO)
# No affixed form found for 'tiṃda' do more fuzzy matching (TODO)
# No affixed form found for 'ella' do more fuzzy matching (TODO)
# No affixed form found for 'tiṃda' do more fuzzy matching (TODO)
# No affixed form found for 'tānu' do more fuzzy matching (TODO)
# No affixed form found for 'śrēṣṭhaneṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'tānē' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'tānē' do more fuzzy matching (TODO)
# No affixed form found for 'baṃda' do more fuzzy matching (TODO)
# No affixed form found for 'tamage' do more fuzzy matching (TODO)
# No affixed form found for 'svāmi' do more fuzzy matching (TODO)
# No affixed form found for 'tāvu' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷidare' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'avarannu' do more fuzzy matching (TODO)
# No affixed form found for 'tagoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'bā' do more fuzzy matching (TODO)
# No affixed form found for 'karakoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ōdibiṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'biṭṭubiḍi' do more fuzzy matching (TODO)
# No affixed form found for 'ōdalu' do more fuzzy matching (TODO)
# No affixed form found for 'māḍabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'biḍabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'kaḷedu' do more fuzzy matching (TODO)
# No affixed form found for 'hōyitu' do more fuzzy matching (TODO)
# No affixed form found for 'ōḍi' do more fuzzy matching (TODO)
# No affixed form found for 'hōda' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'oḍedu' do more fuzzy matching (TODO)
# No affixed form found for 'vikāsagoḷḷuttade' do more fuzzy matching (TODO)
# No affixed form found for 'saṃkōcapaḍisuttāne' do more fuzzy matching (TODO)
# No affixed form found for 'māḍaballe' do more fuzzy matching (TODO)
# No affixed form found for 'māḍaballa' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'taralā' do more fuzzy matching (TODO)
# No affixed form found for 'tanni' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'sikkitu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'sikka' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'iṃgliṣu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'koḷalu' do more fuzzy matching (TODO)
# No affixed form found for 'ive' do more fuzzy matching (TODO)
# No affixed form found for 'biddive' do more fuzzy matching (TODO)
# No affixed form found for 'ārakke' do more fuzzy matching (TODO)
# No affixed form found for 'kūḍisu' do more fuzzy matching (TODO)
# No affixed form found for 'mūrannu' do more fuzzy matching (TODO)
# No affixed form found for 'guṇisu' do more fuzzy matching (TODO)
# No affixed form found for 'nūrannu' do more fuzzy matching (TODO)
# No affixed form found for 'ive' do more fuzzy matching (TODO)
# No affixed form found for 'ive' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍiri' do more fuzzy matching (TODO)
# No affixed form found for 'meravaṇige' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'girākigaḷige' do more fuzzy matching (TODO)
# No affixed form found for 'māriddāne' do more fuzzy matching (TODO)
# No affixed form found for 'ibbarū' do more fuzzy matching (TODO)
# No affixed form found for 'barabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'mūrū' do more fuzzy matching (TODO)
# No affixed form found for 'mējina' do more fuzzy matching (TODO)
# No affixed form found for 'iddaru' do more fuzzy matching (TODO)
# No affixed form found for 'rūpāyi' do more fuzzy matching (TODO)
# No affixed form found for 'kharcu' do more fuzzy matching (TODO)
# No affixed form found for 'hoddu' do more fuzzy matching (TODO)
# No affixed form found for 'avarannu' do more fuzzy matching (TODO)
# No affixed form found for 'karakoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'tagoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'avarannu' do more fuzzy matching (TODO)
# No affixed form found for 'karakoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'tagoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'lesson' do more fuzzy matching (TODO)
# No affixed form found for '4' do more fuzzy matching (TODO)
# No affixed form found for 'lesson' do more fuzzy matching (TODO)
# No affixed form found for '12' do more fuzzy matching (TODO)

# %%
for result in results:
    sentence, translated_sentence,pos_info = result
    print(f"Sentence: {sentence}")
    print(f"Translated Sentence: {translated_sentence}")
    for word, info in pos_info.items():
        print(f"  Word: {word}, POS: {info['pos']}, Translation: {info['translation']}, Affix: {info['affix']}")
    print("=========================================")
# Out:
# Sentence: Idu pustaka.
# Translated Sentence: This is a book.
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
# =========================================
# Sentence: Ivu pustakagaḷu.
# Translated Sentence: These are books.
#   Word: ivu, POS: ['PRON', 'SYM', 'DET', 'PUNCT', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'NOUN', 'AUX', 'VERB', 'SCONJ', 'DET', 'NOUN', 'PART', 'PRON', 'PRON', 'VERB', 'AUX', 'ADJ', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PUNCT', 'SCONJ', 'DET', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'AUX', 'ADJ', 'PUNCT', 'ADJ', 'CCONJ', 'ADJ', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'AUX', 'ADV', 'VERB', 'PUNCT', 'PUNCT'], Translation: they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.), Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: Adu mara.
# Translated Sentence: That is a tree.
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: mara, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: None
# =========================================
# Sentence: Avu maragaḷu.
# Translated Sentence: Those are trees.
#   Word: avu, POS: ['PRON', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT'], Translation: they (non-persons), Affix: None
#   Word: maragaḷu, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: Adu huḍuga.
# Translated Sentence: That is a boy.
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: huḍuga, POS: ['PROPN'], Translation: boy, Affix: None
# =========================================
# Sentence: Adu mane.
# Translated Sentence: That is a house.
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: mane, POS: ['NOUN'], Translation: house, Affix: None
# =========================================
# Sentence: Avu manegaḷu.
# Translated Sentence: Those are houses.
#   Word: avu, POS: ['PRON', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT'], Translation: they (non-persons), Affix: None
#   Word: manegaḷu, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: Adu mahiḷe.
# Translated Sentence: That is a lady.
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: mahiḷe, POS: ['PROPN'], Translation: lady, Affix: None
# =========================================
# Sentence: Nānu vidyārthi.
# Translated Sentence: I am a [male] student.
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: vidyārthi, POS: ['X', 'NOUN', 'X', 'NOUN'], Translation: [male] student, Affix: None
# =========================================
# Sentence: Nānu vidyārthini.
# Translated Sentence: I am a [female] student.
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: vidyārthini, POS: ['X', 'ADJ', 'PUNCT', 'NOUN'], Translation: [female] student, Affix: None
# =========================================
# Sentence: idu mane
# Translated Sentence: this [is a] house [‘this thing – house’]
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: mane, POS: ['NOUN'], Translation: house, Affix: None
# =========================================
# Sentence: adu kaṭṭaḍa
# Translated Sentence: that [is a] building [‘that thing – building’]
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: kaṭṭaḍa, POS: ['VERB'], Translation: building, Affix: None
# =========================================
# Sentence: adu huḍugi
# Translated Sentence: that [is a] girl
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: avaḷu huḍugi
# Translated Sentence: she [is a] girl When sentences of the above type are pronounced, there is a slight
#   Word: avaḷu, POS: ['PRON'], Translation: she, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: avanu nanna maga
# Translated Sentence: he is my son
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nanna, POS: ['PRON'], Translation: my, Affix: None
#   Word: maga, POS: ['NOUN'], Translation: son, Affix: None
# =========================================
# Sentence: avaru nanna gurugaḷu
# Translated Sentence: he is my teacher
#   Word: avaru, POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Translation: they (persons), Affix: None
#   Word: nanna, POS: ['PRON'], Translation: my, Affix: None
#   Word: gurugaḷu, POS: ['NOUN'], Translation: teacher, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: avaru namma purōhitaru
# Translated Sentence: he is our priest
#   Word: avaru, POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Translation: they (persons), Affix: None
#   Word: namma, POS: ['PRON'], Translation: our, Affix: None
#   Word: purōhitaru, POS: ['NOUN'], Translation: priest, Affix: {'prefix': '', 'suffix': 'ru'}
# =========================================
# Sentence: Nīvu vidyārthiyā?
# Translated Sentence: Are you a [male] student?
#   Word: nīvu, POS: ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'], Translation: you (plural / honorific), Affix: None
#   Word: vidyārthiyā, POS: ['X', 'NOUN', 'X', 'NOUN'], Translation: [male] student, Affix: {'prefix': '', 'suffix': 'yā'}
# =========================================
# Sentence: Nīvu vidyārthiniyā?
# Translated Sentence: Are you a [female] student?
#   Word: nīvu, POS: ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'], Translation: you (plural / honorific), Affix: None
#   Word: vidyārthiniyā, POS: ['X', 'ADJ', 'PUNCT', 'NOUN'], Translation: [female] student, Affix: {'prefix': '', 'suffix': 'yā'}
# =========================================
# Sentence: Haudu, nānu vidyārthini.
# Translated Sentence: Yes, I am a [female] student.
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: vidyārthini, POS: ['X', 'ADJ', 'PUNCT', 'NOUN'], Translation: [female] student, Affix: None
# =========================================
# Sentence: Idu maravā?
# Translated Sentence: Is this a tree?
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: maravā, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: Haudu, idu mara.
# Translated Sentence: Yes, this is a tree.
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: mara, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: None
# =========================================
# Sentence: Adu pustakavā?
# Translated Sentence: Is that a book?
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: pustakavā, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: Haudu, pustaka.
# Translated Sentence: Yes, a book.
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
# =========================================
# Sentence: Adū pustakavā?
# Translated Sentence: Is that a book too?
#   Word: adū, POS: None, Translation: None, Affix: None
#   Word: pustakavā, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: Alla, adu pustakavalla.
# Translated Sentence: No, that is not a book.
#   Word: alla, POS: None, Translation: None, Affix: None
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: pustakavalla, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'valla'}
# =========================================
# Sentence: idu mara-v-alla
# Translated Sentence: this is not a tree
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: mara-v-alla, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': '-v-alla'}
# =========================================
# Sentence: adu toḍak-alla
# Translated Sentence: that is not a problem
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: toḍak-alla, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: adu huḍugi-y-alla
# Translated Sentence: that is not a girl
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: huḍugi-y-alla, POS: ['NOUN'], Translation: girl, Affix: {'prefix': '', 'suffix': '-y-alla'}
# =========================================
# Sentence: alli mara-v-illa
# Translated Sentence: there is no tree there
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: mara-v-illa, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': '-v-illa'}
# =========================================
# Sentence: alli toḍak-illa
# Translated Sentence: there is no problem there
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: toḍak-illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: alli huḍugi-y-illa
# Translated Sentence: there is no girl there Another possible word for expressing a different meaning of the English ‘no’ is the ‘no’ that expresses the denial of being wanted or being neces-
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: huḍugi-y-illa, POS: ['NOUN'], Translation: girl, Affix: {'prefix': '', 'suffix': '-y-illa'}
# =========================================
# Sentence: adū pustakavā?
# Translated Sentence: is that also a book?
#   Word: adū, POS: None, Translation: None, Affix: None
#   Word: pustakavā, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: haudu, adū pustaka
# Translated Sentence: yes, that too is a book
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: adū, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
# =========================================
# Sentence: haudu, adū ide
# Translated Sentence: yes, that too is there
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: adū, POS: None, Translation: None, Affix: None
#   Word: ide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: None
# =========================================
# Sentence: illa, adu illa
# Translated Sentence: no, that is not there
#   Word: illa, POS: None, Translation: None, Affix: None
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
# =========================================
# Sentence: ākāśa mattu bekku
# Translated Sentence: The Sky and the
#   Word: ākāśa, POS: ['NOUN'], Translation: sky, Affix: None
#   Word: mattu, POS: ['CCONJ'], Translation: and, Affix: None
#   Word: bekku, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: maisūru maṃgaḷūru beṃgaḷūru śivamogga dhāravāḍa ivu karnāṭakada nagaragaḷu
# Translated Sentence: Mysore, Mangalore, Bangalore, Shimoga, and Dharwad are cities in (‘of’) Karnataka
#   Word: maisūru, POS: ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN'], Translation: place, village, town, ‘native place’, city, Affix: {'prefix': 'mais', 'suffix': ''}
#   Word: maṃgaḷūru, POS: ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN'], Translation: place, village, town, ‘native place’, city, Affix: {'prefix': 'maṃgaḷ', 'suffix': ''}
#   Word: beṃgaḷūru, POS: ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN'], Translation: place, village, town, ‘native place’, city, Affix: {'prefix': 'beṃgaḷ', 'suffix': ''}
#   Word: śivamogga, POS: ['PUNCT', 'NOUN', 'ADP', 'PROPN', 'PUNCT'], Translation: (name of god), Affix: {'prefix': '', 'suffix': 'mogga'}
#   Word: dhāravāḍa, POS: None, Translation: None, Affix: None
#   Word: ivu, POS: ['PRON', 'SYM', 'DET', 'PUNCT', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'NOUN', 'AUX', 'VERB', 'SCONJ', 'DET', 'NOUN', 'PART', 'PRON', 'PRON', 'VERB', 'AUX', 'ADJ', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PUNCT', 'SCONJ', 'DET', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'AUX', 'ADJ', 'PUNCT', 'ADJ', 'CCONJ', 'ADJ', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'AUX', 'ADV', 'VERB', 'PUNCT', 'PUNCT'], Translation: they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.), Affix: None
#   Word: karnāṭakada, POS: None, Translation: None, Affix: None
#   Word: nagaragaḷu, POS: ['PART', 'VERB'], Translation: to weep, Affix: {'prefix': 'nagarag', 'suffix': ''}
# =========================================
# Sentence: Ēnu samācāra?
# Translated Sentence: What is the news?
#   Word: ēnu, POS: ['PRON', 'PUNCT'], Translation: what?, Affix: None
#   Word: samācāra, POS: ['NOUN'], Translation: news, Affix: None
# =========================================
# Sentence: Ēnū illa.
# Translated Sentence: Nothing (‘what-also is not’).
#   Word: ēnū, POS: None, Translation: None, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Nīvū cennāgiddīrā?
# Translated Sentence: Are you fine too?
#   Word: nīvū, POS: None, Translation: None, Affix: None
#   Word: cennāgiddīrā, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddīrā'}
# =========================================
# Sentence: Paravā illa.
# Translated Sentence: All right (‘there is no worry’).
#   Word: paravā, POS: ['VERB'], Translation: worry, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: (Nānu) baralā?
# Translated Sentence: May I leave? (‘Shall I come?’)
#   Word: (nānu), POS: ['PRON'], Translation: I, Affix: {'prefix': '(', 'suffix': ')'}
#   Word: baralā, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Namaskāra, Gururājarē.
# Translated Sentence: Greetings, Mr Gururaja. Gururāja
#   Word: namaskāra, POS: None, Translation: None, Affix: None
#   Word: gururājarē, POS: ['NOUN'], Translation: teacher, Affix: {'prefix': '', 'suffix': 'rājarē'}
# =========================================
# Sentence: Namaskāra, Rāmappanavarē.
# Translated Sentence: Greetings, Mr Rāmappa. Rāmappa
#   Word: namaskāra, POS: None, Translation: None, Affix: None
#   Word: rāmappanavarē, POS: ['PROPN'], Translation: father, Affix: {'prefix': 'rām', 'suffix': 'navarē'}
# =========================================
# Sentence: Nānu cennāgiddēne. Nīvu?
# Translated Sentence: I’m fine. And you? Rāmappa
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: cennāgiddēne, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddēne'}
#   Word: nīvu, POS: ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'], Translation: you (plural / honorific), Affix: None
# =========================================
# Sentence: Nānū cennāgiddēne. Ivaru nimma maneyavarā?
# Translated Sentence: I’m fine too. Is this your wife?
#   Word: nānū, POS: None, Translation: None, Affix: None
#   Word: cennāgiddēne, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddēne'}
#   Word: ivaru, POS: ['PRON', 'SYM', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'], Translation: he / she (honorific), Affix: None
#   Word: nimma, POS: ['PRON', 'PUNCT', 'ADJ', 'PUNCT'], Translation: your (honorific), Affix: None
#   Word: maneyavarā, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'yavarā'}
# =========================================
# Sentence: Haudu, ivara hesaru Sītamma.
# Translated Sentence: Yes, her name is Sītamma. Rāmappa
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: ivara, POS: ['PRON', 'SYM', 'PRON', 'PUNCT', 'ADJ', 'PUNCT'], Translation: his / her (honorific), Affix: None
#   Word: hesaru, POS: ['NOUN'], Translation: name, Affix: None
#   Word: sītamma, POS: ['ADJ', 'NOUN'], Translation: younger brother, Affix: {'prefix': 'sī', 'suffix': ''}
# =========================================
# Sentence: Namaskāra, Sītammanavarē.
# Translated Sentence: Greetings, Mrs Sītamma.
#   Word: namaskāra, POS: None, Translation: None, Affix: None
#   Word: sītammanavarē, POS: ['ADJ', 'NOUN'], Translation: younger brother, Affix: {'prefix': 'sī', 'suffix': 'navarē'}
# =========================================
# Sentence: Nānu baralā?
# Translated Sentence: May I take leave? Gururāja
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: baralā, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Sari, banni.
# Translated Sentence: All right, good bye. Rāmappa
#   Word: sari, POS: ['INTJ', 'PUNCT', 'ADV', 'ADV', 'PUNCT', 'ADJ'], Translation: okay, all right, correct, Affix: None
#   Word: banni, POS: ['INTJ', 'VERB'], Translation: please come, Affix: None
# =========================================
# Sentence: Baruttēne, Sītammanavarē. Namaskāra.
# Translated Sentence: Till next time, Mrs Sītamma. Good bye.
#   Word: baruttēne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttēne'}
#   Word: sītammanavarē, POS: ['ADJ', 'NOUN'], Translation: younger brother, Affix: {'prefix': 'sī', 'suffix': 'navarē'}
#   Word: namaskāra, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: kṣamisi / kṣamisiri
# Translated Sentence: excuse me, sorry (honorific)
#   Word: kṣamisi, POS: None, Translation: None, Affix: None
#   Word: /, POS: None, Translation: None, Affix: None
#   Word: kṣamisiri, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: idu hasu
# Translated Sentence: this is a cow
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: hasu, POS: ['NOUN'], Translation: cow, Affix: None
# =========================================
# Sentence: ivu hasuvina koṃbugaḷu
# Translated Sentence: these are a cow’s horns
#   Word: ivu, POS: ['PRON', 'SYM', 'DET', 'PUNCT', 'NOUN', 'PUNCT', 'DET', 'NOUN', 'NOUN', 'AUX', 'VERB', 'SCONJ', 'DET', 'NOUN', 'PART', 'PRON', 'PRON', 'VERB', 'AUX', 'ADJ', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PUNCT', 'SCONJ', 'DET', 'NOUN', 'CCONJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'AUX', 'ADJ', 'PUNCT', 'ADJ', 'CCONJ', 'ADJ', 'PUNCT', 'DET', 'ADJ', 'NOUN', 'AUX', 'ADV', 'VERB', 'PUNCT', 'PUNCT'], Translation: they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.), Affix: None
#   Word: hasuvina, POS: ['NOUN'], Translation: cow, Affix: {'prefix': '', 'suffix': 'vina'}
#   Word: koṃbugaḷu, POS: ['NOUN'], Translation: horn, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: idu baṇṇa
# Translated Sentence: this is a colour
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: baṇṇa, POS: ['NOUN'], Translation: colour, Affix: None
# =========================================
# Sentence: idu hesaru
# Translated Sentence: this is a name
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: hesaru, POS: ['NOUN'], Translation: name, Affix: None
# =========================================
# Sentence: idu avara hesaru
# Translated Sentence: this is their name
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: avara, POS: None, Translation: None, Affix: None
#   Word: hesaru, POS: ['NOUN'], Translation: name, Affix: None
# =========================================
# Sentence: pustaka cennāgide
# Translated Sentence: the book is nice
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: cennāgide, POS: ['AUX', 'ADJ'], Translation: is good, Affix: None
# =========================================
# Sentence: huḍugi baṃdaḷu
# Translated Sentence: the girl came
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
#   Word: baṃdaḷu, POS: ['PART', 'VERB'], Translation: to weep, Affix: {'prefix': 'baṃd', 'suffix': ''}
# =========================================
# Sentence: huḍuga baṃda
# Translated Sentence: the boy came
#   Word: huḍuga, POS: ['PROPN'], Translation: boy, Affix: None
#   Word: baṃda, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avanu yāvāgalū ōduttāne
# Translated Sentence: he always reads
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: yāvāgalū, POS: ['ADV'], Translation: always, Affix: None
#   Word: ōduttāne, POS: ['PART', 'VERB'], Translation: to read, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu nāḷe baruttāne
# Translated Sentence: he will come
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nāḷe, POS: ['NOUN'], Translation: tomorrow, Affix: None
#   Word: baruttāne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu yāvāgalū ōduttāne
# Translated Sentence: he always reads
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: yāvāgalū, POS: ['ADV'], Translation: always, Affix: None
#   Word: ōduttāne, POS: ['PART', 'VERB'], Translation: to read, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu yāvāgalū ōduvanu
# Translated Sentence: he will always read mean practically the same, and it is largely a matter of stylistic prefer- ence whether one uses the one or the other. In coastal Karnataka there is a stronger tendency to differentiate between the use of the present
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: yāvāgalū, POS: ['ADV'], Translation: always, Affix: None
#   Word: ōduvanu, POS: ['PART', 'VERB'], Translation: to read, Affix: {'prefix': '', 'suffix': 'vanu'}
# =========================================
# Sentence: adu baruvudilla
# Translated Sentence: it will not come
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: baruvudilla, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'vudilla'}
# =========================================
# Sentence: nānu nidde māḍuvudilla
# Translated Sentence: I will not sleep
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: nidde, POS: ['NOUN'], Translation: sleep, Affix: None
#   Word: māḍuvudilla, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: {'prefix': '', 'suffix': 'vudilla'}
# =========================================
# Sentence: avanu nidde māḍuvudilla
# Translated Sentence: he will not sleep
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nidde, POS: ['NOUN'], Translation: sleep, Affix: None
#   Word: māḍuvudilla, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: {'prefix': '', 'suffix': 'vudilla'}
# =========================================
# Sentence: nīvu nidde māḍuvudilla
# Translated Sentence: you will not sleep It is important to note that there is no distinction in the written lan-
#   Word: nīvu, POS: ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'], Translation: you (plural / honorific), Affix: None
#   Word: nidde, POS: ['NOUN'], Translation: sleep, Affix: None
#   Word: māḍuvudilla, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: {'prefix': '', 'suffix': 'vudilla'}
# =========================================
# Sentence: nidde māḍu
# Translated Sentence: to sleep
#   Word: nidde, POS: ['NOUN'], Translation: sleep, Affix: None
#   Word: māḍu, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: None
# =========================================
# Sentence: ā mara
# Translated Sentence: that tree
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: mara, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: None
# =========================================
# Sentence: ā maragaḷu
# Translated Sentence: those trees
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: maragaḷu, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: ā huḍugi
# Translated Sentence: that girl
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: ā huḍugiyaru
# Translated Sentence: those girls
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: huḍugiyaru, POS: ['NOUN'], Translation: girl, Affix: {'prefix': '', 'suffix': 'yaru'}
# =========================================
# Sentence: ī huḍugi
# Translated Sentence: this girl
#   Word: ī, POS: None, Translation: None, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: ī huḍugiyaru
# Translated Sentence: these girls
#   Word: ī, POS: None, Translation: None, Affix: None
#   Word: huḍugiyaru, POS: ['NOUN'], Translation: girl, Affix: {'prefix': '', 'suffix': 'yaru'}
# =========================================
# Sentence: avanu ā huḍuganannu hoḍeyuttāne
# Translated Sentence: he hits that boy The learner should note here the order of the parts of a transitive sen-
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: huḍuganannu, POS: ['PROPN'], Translation: boy, Affix: {'prefix': '', 'suffix': 'nannu'}
#   Word: hoḍeyuttāne, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to hit, strike, Affix: {'prefix': '', 'suffix': 'yuttāne'}
# =========================================
# Sentence: nenne avanu Maisūrige hōdanu
# Translated Sentence: yesterday he went to Mysore Here the city Maisūru (‘Mysore’ in Anglified spelling; nowadays offi- cially spelt ‘Mysuru’) is the destination of the subject’s travel, therefore
#   Word: nenne, POS: ['NOUN'], Translation: yesterday, Affix: None
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: maisūrige, POS: None, Translation: None, Affix: None
#   Word: hōdanu, POS: ['PRON', 'VERB'], Translation: he went, Affix: None
# =========================================
# Sentence: avanu ā huḍuganige ī viṣayavannu hēḷidanu
# Translated Sentence: he told this matter to that boy Usually, the indirect object (in the dative) is placed before the direct object (in the accusative) in the sentence; but because these parts of the sentence are clearly indicated by the case endings, there is some degree of freedom in the order of these parts, if the speaker / writer wishes to emphasize a part of the sentence by a less usual word order. Therefore a Kannada speaker will not say ‘he told this matter to that boy’ but ‘he to that boy this matter told’, etc. One could also say ‘to that boy he this matter told’ to emphasize the receiver of the message; or ‘he this matter to that boy told’ to emphasize the object, or ‘this matter he to that boy told’ to emphasize the object still more. But the
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: huḍuganige, POS: ['PROPN'], Translation: boy, Affix: {'prefix': '', 'suffix': 'nige'}
#   Word: ī, POS: None, Translation: None, Affix: None
#   Word: viṣayavannu, POS: ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'], Translation: matter, thing, topic, Affix: {'prefix': '', 'suffix': 'vannu'}
#   Word: hēḷidanu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avanu ūṭakke manege hōdanu
# Translated Sentence: he went home for lunch / dinner
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: ūṭakke, POS: ['PUNCT', 'VERB', 'PUNCT', 'NOUN'], Translation: (cooked) meal, Affix: {'prefix': '', 'suffix': 'kke'}
#   Word: manege, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'ge'}
#   Word: hōdanu, POS: ['PRON', 'VERB'], Translation: he went, Affix: None
# =========================================
# Sentence: avanu nanage pustaka koṭṭanu
# Translated Sentence: he gave me a book
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nanage, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: koṭṭanu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nānu nimage pustaka koṭṭenu
# Translated Sentence: I gave you a book
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: nimage, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: koṭṭenu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nānu avarige pustaka koṭṭenu
# Translated Sentence: I gave them a book
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: avarige, POS: ['PART', 'VERB'], Translation: to know, Affix: {'prefix': 'av', 'suffix': 'ge'}
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: koṭṭenu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nanage ā pustaka bēku
# Translated Sentence: I want / need that book
#   Word: nanage, POS: None, Translation: None, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: nimage ā pustakagaḷu bēku
# Translated Sentence: you want / need those books The above sentences mean, more literally translated: ‘to me that book is a desired thing’, and ‘to you those books are a desired thing’. The grammatical subject can be anything (singular, plural, neuter, femi-
#   Word: nimage, POS: None, Translation: None, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: nīvu namage bēku
# Translated Sentence: we want / need you
#   Word: nīvu, POS: ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'], Translation: you (plural / honorific), Affix: None
#   Word: namage, POS: ['PRON', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'], Translation: us (dative case), Affix: None
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: nanage ā pustaka bēḍa
# Translated Sentence: I do not want / need that book
#   Word: nanage, POS: None, Translation: None, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēḍa, POS: ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: is not wanted / not required, Affix: None
# =========================================
# Sentence: nimage ā pustakagaḷu bēḍa
# Translated Sentence: you do not want / need those books
#   Word: nimage, POS: None, Translation: None, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: bēḍa, POS: ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: is not wanted / not required, Affix: None
# =========================================
# Sentence: nanage iṣṭu anna sāku
# Translated Sentence: this much rice is enough for me
#   Word: nanage, POS: None, Translation: None, Affix: None
#   Word: iṣṭu, POS: ['PRON', 'ADJ'], Translation: this much, Affix: None
#   Word: anna, POS: ['PROPN', 'PUNCT', 'VERB', 'PUNCT'], Translation: rice (cooked), Affix: None
#   Word: sāku, POS: ['PRON', 'AUX', 'ADJ'], Translation: it is enough, Affix: None
# =========================================
# Sentence: aṣṭu haṇa nimage sāladā?
# Translated Sentence: is that much money not enough for you?
#   Word: aṣṭu, POS: ['ADV', 'ADV'], Translation: that much, Affix: None
#   Word: haṇa, POS: ['NOUN'], Translation: money, Affix: None
#   Word: nimage, POS: None, Translation: None, Affix: None
#   Word: sāladā, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avaru idannu kaiyiṃda baredaru
# Translated Sentence: they wrote this by hand
#   Word: avaru, POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Translation: they (persons), Affix: None
#   Word: idannu, POS: None, Translation: None, Affix: None
#   Word: kaiyiṃda, POS: ['NOUN', 'PUNCT', 'VERB'], Translation: hand, arm, Affix: {'prefix': '', 'suffix': 'yiṃda'}
#   Word: baredaru, POS: ['PART', 'VERB'], Translation: to write, Affix: {'prefix': '', 'suffix': 'daru'}
# =========================================
# Sentence: avaru kiviyiṃda kēḷuvaru
# Translated Sentence: they will listen with their ear[s]
#   Word: avaru, POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Translation: they (persons), Affix: None
#   Word: kiviyiṃda, POS: ['NOUN'], Translation: ear, Affix: {'prefix': '', 'suffix': 'yiṃda'}
#   Word: kēḷuvaru, POS: ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: to ask, to hear, Affix: {'prefix': '', 'suffix': 'varu'}
# =========================================
# Sentence: avaru idannu kalliniṃda kaṭṭidaru
# Translated Sentence: they built this from stone
#   Word: avaru, POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Translation: they (persons), Affix: None
#   Word: idannu, POS: None, Translation: None, Affix: None
#   Word: kalliniṃda, POS: ['ADV'], Translation: there, Affix: {'prefix': 'k', 'suffix': 'niṃda'}
#   Word: kaṭṭidaru, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avaru idannu kaiyalli baredaru
# Translated Sentence: they wrote this by hand
#   Word: avaru, POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Translation: they (persons), Affix: None
#   Word: idannu, POS: None, Translation: None, Affix: None
#   Word: kaiyalli, POS: ['PUNCT', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PUNCT', 'ADP', 'PUNCT', 'ADP'], Translation: ‘in the hand’, with, near, Affix: None
#   Word: baredaru, POS: ['PART', 'VERB'], Translation: to write, Affix: {'prefix': '', 'suffix': 'daru'}
# =========================================
# Sentence: avanu maneyoḷaginiṃda baruttāne
# Translated Sentence: he comes from within the house literally means ‘he house-[of]-inside-[from] comes’. Also the dative and especially genitive forms of postpositions are used often:
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: maneyoḷaginiṃda, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'yoḷaginiṃda'}
#   Word: baruttāne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu maneyoḷakke hōguttāne
# Translated Sentence: he enters the house
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: maneyoḷakke, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'yoḷakke'}
#   Word: hōguttāne, POS: ['PART', 'VERB'], Translation: to go, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu ūṭakkōskara baruttāne
# Translated Sentence: he comes for the meal
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: ūṭakkōskara, POS: ['PUNCT', 'VERB', 'PUNCT', 'NOUN'], Translation: (cooked) meal, Affix: {'prefix': '', 'suffix': 'kkōskara'}
#   Word: baruttāne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: pustaka nanagōskara ide
# Translated Sentence: the book is for me
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: nanagōskara, POS: None, Translation: None, Affix: None
#   Word: ide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: None
# =========================================
# Sentence: avanu nimagōskara baṃda
# Translated Sentence: he came for you
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nimagōskara, POS: None, Translation: None, Affix: None
#   Word: baṃda, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Ō banni, oḷage banni, Gaṇēśarē.
# Translated Sentence: Oh, come in, com in, Mr Ganesha.
#   Word: ō, POS: None, Translation: None, Affix: None
#   Word: banni, POS: ['INTJ', 'VERB'], Translation: please come, Affix: None
#   Word: oḷage, POS: ['ADP'], Translation: within, Affix: None
#   Word: gaṇēśarē, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Hēgiddīri? Ēnu samācāra?
# Translated Sentence: How are you? What is new? Gaṇēśa
#   Word: hēgiddīri, POS: None, Translation: None, Affix: None
#   Word: ēnu, POS: ['PRON', 'PUNCT'], Translation: what?, Affix: None
#   Word: samācāra, POS: ['NOUN'], Translation: news, Affix: None
# =========================================
# Sentence: Namaskāra, Rāmayyanavarē. Nānu cennāgiddēne. Toṃdare illa. Viśēṣavāda samācāravilla.
# Translated Sentence: Greetings, Mr Rāmayya. I’m fine. No problems. There’s no special news.
#   Word: namaskāra, POS: None, Translation: None, Affix: None
#   Word: rāmayyanavarē, POS: ['PROPN'], Translation: lord, Affix: {'prefix': 'rām', 'suffix': 'navarē'}
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: cennāgiddēne, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddēne'}
#   Word: toṃdare, POS: ['NOUN'], Translation: trouble, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
#   Word: viśēṣavāda, POS: ['ADJ'], Translation: special, Affix: None
#   Word: samācāravilla, POS: ['NOUN'], Translation: news, Affix: {'prefix': '', 'suffix': 'villa'}
# =========================================
# Sentence: Cennāgiddēne, amma.
# Translated Sentence: I’m fine, madam. Sītamma
#   Word: cennāgiddēne, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddēne'}
#   Word: amma, POS: ['NOUN'], Translation: mother, Affix: None
# =========================================
# Sentence: Nīvu ēnu tagoḷḷuttīri? Nānu cahā māḍuttēne.
# Translated Sentence: What will you have? I’ll make some tea.
#   Word: nīvu, POS: ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'], Translation: you (plural / honorific), Affix: None
#   Word: ēnu, POS: ['PRON', 'PUNCT'], Translation: what?, Affix: None
#   Word: tagoḷḷuttīri, POS: ['PART', 'VERB'], Translation: to take, Affix: {'prefix': '', 'suffix': 'ttīri'}
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: cahā, POS: ['NOUN'], Translation: tea, Affix: None
#   Word: māḍuttēne, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: Alla, svalpa tagoḷḷi.
# Translated Sentence: No, have a little bit. Gaṇēśa
#   Word: alla, POS: None, Translation: None, Affix: None
#   Word: svalpa, POS: ['DET', 'NOUN', 'PUNCT', 'DET', 'ADJ'], Translation: a bit, a little, Affix: None
#   Word: tagoḷḷi, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Nijavāgi bēḍamma.
# Translated Sentence: Really, no, madam. Sītamma
#   Word: nijavāgi, POS: ['ADV', 'PUNCT', 'ADV'], Translation: really, truly, Affix: None
#   Word: bēḍamma, POS: ['NOUN'], Translation: mother, Affix: {'prefix': 'bēḍ', 'suffix': ''}
# =========================================
# Sentence: Exercise 2
# Translated Sentence: Ask a fellow learner about the location of various objects and persons in the room, and let him answer.
#   Word: exercise, POS: None, Translation: None, Affix: None
#   Word: 2, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: adu mara
# Translated Sentence: that is a tree
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: mara, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: None
# =========================================
# Sentence: avu maragaḷu
# Translated Sentence: those are trees
#   Word: avu, POS: ['PRON', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT'], Translation: they (non-persons), Affix: None
#   Word: maragaḷu, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: nāvu raitaru
# Translated Sentence: we are farmers
#   Word: nāvu, POS: ['PRON'], Translation: we, Affix: None
#   Word: raitaru, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'ru'}
# =========================================
# Sentence: nīvu raitaru
# Translated Sentence: you are farmers
#   Word: nīvu, POS: ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'], Translation: you (plural / honorific), Affix: None
#   Word: raitaru, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'ru'}
# =========================================
# Sentence: adu maravalla
# Translated Sentence: that is not a tree
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: maravalla, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'valla'}
# =========================================
# Sentence: avu maragaḷalla
# Translated Sentence: those are not trees
#   Word: avu, POS: ['PRON', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT'], Translation: they (non-persons), Affix: None
#   Word: maragaḷalla, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷalla'}
# =========================================
# Sentence: nānu raitanalla
# Translated Sentence: I am not a farmer
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: raitanalla, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'nalla'}
# =========================================
# Sentence: nāvu raitaralla
# Translated Sentence: we are not farmers
#   Word: nāvu, POS: ['PRON'], Translation: we, Affix: None
#   Word: raitaralla, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'ralla'}
# =========================================
# Sentence: nīvu raitaralla
# Translated Sentence: you are not farmers
#   Word: nīvu, POS: ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'], Translation: you (plural / honorific), Affix: None
#   Word: raitaralla, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'ralla'}
# =========================================
# Sentence: maragaḷu alli illa
# Translated Sentence: trees are not there
#   Word: maragaḷu, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nānu alli illa
# Translated Sentence: I am not there
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: namage pustaka bēku
# Translated Sentence: we need a book
#   Word: namage, POS: ['PRON', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'], Translation: us (dative case), Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: namage pustakagaḷu bēku
# Translated Sentence: we need books
#   Word: namage, POS: ['PRON', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'], Translation: us (dative case), Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: namage pustaka bēḍa
# Translated Sentence: we do not need a book
#   Word: namage, POS: ['PRON', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'], Translation: us (dative case), Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēḍa, POS: ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: is not wanted / not required, Affix: None
# =========================================
# Sentence: namage pustakagaḷu bēḍa
# Translated Sentence: we do not need books
#   Word: namage, POS: ['PRON', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'], Translation: us (dative case), Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: bēḍa, POS: ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: is not wanted / not required, Affix: None
# =========================================
# Sentence: adu maravā?
# Translated Sentence: Is that a tree?
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: maravā, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: adu maravē?
# Translated Sentence: That surely is a tree, isn’t it?
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: maravē, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'vē'}
# =========================================
# Sentence: adu maravō?
# Translated Sentence: That is not a tree, is it?
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: maravō, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'vō'}
# =========================================
# Sentence: ā bassu keṃpu
# Translated Sentence: that bus is red
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: bassu, POS: ['NOUN', 'PUNCT', 'NOUN', 'PUNCT'], Translation: bus (vehicle), Affix: None
#   Word: keṃpu, POS: ['PROPN'], Translation: red, Affix: None
# =========================================
# Sentence: avanu cikka huḍuga
# Translated Sentence: he is a small boy
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: cikka, POS: ['ADJ'], Translation: small, Affix: None
#   Word: huḍuga, POS: ['PROPN'], Translation: boy, Affix: None
# =========================================
# Sentence: avaḷu cikka huḍugi
# Translated Sentence: she is a small girl
#   Word: avaḷu, POS: ['PRON'], Translation: she, Affix: None
#   Word: cikka, POS: ['ADJ'], Translation: small, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: adu cikka mane
# Translated Sentence: that is a small house
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: cikka, POS: ['ADJ'], Translation: small, Affix: None
#   Word: mane, POS: ['NOUN'], Translation: house, Affix: None
# =========================================
# Sentence: avaru cikka huḍugaru
# Translated Sentence: they are small boys
#   Word: avaru, POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Translation: they (persons), Affix: None
#   Word: cikka, POS: ['ADJ'], Translation: small, Affix: None
#   Word: huḍugaru, POS: ['PROPN'], Translation: boy, Affix: {'prefix': '', 'suffix': 'ru'}
# =========================================
# Sentence: avaḷu ā cikka huḍugarannu nōḍidaḷu
# Translated Sentence: she looked at those small boys
# ...
# Sentence: eṣṭu maṃdi oḷage baruttāre eṃdu nōḍiri. nūraneyavaru baṃdāga uḷidavarannu bēre kaḍege kaḷuhisiri.
# Translated Sentence: See how many people come in. When the one-hundredth person has come, send the remaining persons somewhere else.
#   Word: eṣṭu, POS: ['SCONJ', 'ADJ', 'PUNCT'], Translation: how much?, Affix: None
#   Word: maṃdi, POS: ['NOUN'], Translation: person, Affix: None
#   Word: oḷage, POS: ['ADP'], Translation: within, Affix: None
#   Word: baruttāre, POS: ['PRON', 'VERB'], Translation: they come, Affix: None
#   Word: eṃdu, POS: None, Translation: None, Affix: None
#   Word: nōḍiri, POS: None, Translation: None, Affix: None
#   Word: nūraneyavaru, POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Translation: they (persons), Affix: {'prefix': 'nūraney', 'suffix': ''}
#   Word: baṃdāga, POS: ['ADV', 'PUNCT', 'DET', 'NOUN'], Translation: then, that time, Affix: {'prefix': 'baṃd', 'suffix': ''}
#   Word: uḷidavarannu, POS: ['PART', 'VERB'], Translation: to remain, Affix: {'prefix': '', 'suffix': 'davarannu'}
#   Word: bēre, POS: ['ADJ', 'PUNCT', 'PRON', 'ADV'], Translation: other, something else, Affix: None
#   Word: kaḍege, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: side, direction, Affix: {'prefix': '', 'suffix': 'ge'}
#   Word: kaḷuhisiri, POS: ['PART', 'VERB'], Translation: to steal, Affix: {'prefix': '', 'suffix': 'hisiri'}
# =========================================
# Sentence: nālku pustakagaḷu
# Translated Sentence: four books
#   Word: nālku, POS: ['NUM'], Translation: four, Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: meravaṇige mūru bīdigaḷalli sāgitu.
# Translated Sentence: The procession went through three streets.
#   Word: meravaṇige, POS: None, Translation: None, Affix: None
#   Word: mūru, POS: ['NUM'], Translation: three, Affix: None
#   Word: bīdigaḷalli, POS: ['ADV'], Translation: there, Affix: {'prefix': 'bīdigaḷ', 'suffix': ''}
#   Word: sāgitu, POS: ['PUNCT', 'NOUN', 'PUNCT'], Translation: (gerund), Affix: {'prefix': 's', 'suffix': 'tu'}
# =========================================
# Sentence: ā nālku pustaka bēku.
# Translated Sentence: [I] need those four books. In most cases, however, the plain numerals are not used with nouns
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: nālku, POS: ['NUM'], Translation: four, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: alli aidu maṃdi vidyārthigaḷu niṃtiddāre.
# Translated Sentence: Four students are standing there.
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: aidu, POS: ['NUM'], Translation: five, Affix: None
#   Word: maṃdi, POS: ['NOUN'], Translation: person, Affix: None
#   Word: vidyārthigaḷu, POS: ['X', 'NOUN', 'X', 'NOUN'], Translation: [male] student, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: niṃtiddāre, POS: ['PRON', 'VERB'], Translation: they stand, Affix: None
# =========================================
# Sentence: hattu jana girākigaḷige haṇṇu māriddāne.
# Translated Sentence: He has sold fruits to ten customers. Alternatively, up to the count of five, one can use pronominalized short forms of numerals.
#   Word: hattu, POS: ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: to climb; to begin, Affix: None
#   Word: jana, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: person, people, Affix: None
#   Word: girākigaḷige, POS: None, Translation: None, Affix: None
#   Word: haṇṇu, POS: ['NOUN'], Translation: fruit, Affix: None
#   Word: māriddāne, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: ibbarū barabahudu.
# Translated Sentence: Both of them may come.
#   Word: ibbarū, POS: None, Translation: None, Affix: None
#   Word: barabahudu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: ibbarigū hēḷidenu
# Translated Sentence: I told both of them.
#   Word: ibbarigū, POS: ['PART', 'VERB'], Translation: to know, Affix: {'prefix': 'ibb', 'suffix': 'gū'}
#   Word: hēḷidenu, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: {'prefix': 'hēḷ', 'suffix': 'nu'}
# =========================================
# Sentence: saṃgrahālayadalli mūru citragaḷannu nōḍiddēne. mūrū cennāgive.
# Translated Sentence: I have seen three pictures in the museum. All three of them are nice.
#   Word: saṃgrahālayadalli, POS: ['NOUN'], Translation: museum, Affix: {'prefix': '', 'suffix': 'dalli'}
#   Word: mūru, POS: ['NUM'], Translation: three, Affix: None
#   Word: citragaḷannu, POS: ['NOUN'], Translation: picture, Affix: {'prefix': '', 'suffix': 'gaḷannu'}
#   Word: nōḍiddēne, POS: None, Translation: None, Affix: None
#   Word: mūrū, POS: None, Translation: None, Affix: None
#   Word: cennāgive, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 've'}
# =========================================
# Sentence: mējina mēle hattāru pustakagaḷu iddavu
# Translated Sentence: there were dozens of books on the table
#   Word: mējina, POS: None, Translation: None, Affix: None
#   Word: mēle, POS: ['ADP'], Translation: on, Affix: None
#   Word: hattāru, POS: ['NUM'], Translation: six, Affix: {'prefix': 'hatt', 'suffix': ''}
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: iddavu, POS: ['PRON', 'PUNCT', 'NOUN', 'NOUN', 'NOUN', 'PUNCT'], Translation: they (non-persons), Affix: {'prefix': 'idd', 'suffix': ''}
# =========================================
# Sentence: bīdiyalli nūrāru jana iddaru
# Translated Sentence: there were hundreds of people in the street
#   Word: bīdiyalli, POS: ['ADV'], Translation: there, Affix: {'prefix': 'bīdiy', 'suffix': ''}
#   Word: nūrāru, POS: ['NUM'], Translation: six, Affix: {'prefix': 'nūr', 'suffix': ''}
#   Word: jana, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: person, people, Affix: None
#   Word: iddaru, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avanu sāvirāru rūpāyi kharcu māḍida
# Translated Sentence: he spent thousands of rupees
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: sāvirāru, POS: ['NOUN'], Translation: thousands, Affix: None
#   Word: rūpāyi, POS: None, Translation: None, Affix: None
#   Word: kharcu, POS: None, Translation: None, Affix: None
#   Word: māḍida, POS: ['INTJ', 'VERB', 'DET', 'NUM', 'VERB', 'NOUN', 'ADP', 'NOUN', 'AUX', 'ADV', 'ADJ', 'PUNCT', 'DET', 'ADV', 'NOUN', 'NOUN', 'VERB', 'ADP', 'DET', 'ADJ', 'NUM', 'PUNCT', 'PUNCT', 'CCONJ', 'SCONJ', 'ADP', 'DET', 'ADJ', 'NOUN', 'ADP', 'DET', 'NOUN', 'DET', 'ADJ', 'NOUN', 'AUX', 'ADJ', 'SCONJ', 'DET', 'NOUN', 'AUX', 'ADJ', 'PUNCT', 'ADP', 'DET', 'ADJ', 'NOUN', 'PRON', 'AUX', 'SCONJ', 'ADP', 'DET', 'VERB', 'NOUN', 'PUNCT', 'CCONJ', 'DET', 'NOUN', 'AUX', 'VERB', 'ADP', 'NOUN', 'PUNCT'], Translation: please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:, Affix: {'prefix': '', 'suffix': 'da'}
# =========================================
# Sentence: hodedu, hoddu
# Translated Sentence: A few common verbs have special alternative abbreviated forms of the
#   Word: hodedu, POS: ['PART', 'VERB', 'ADP', 'PUNCT', 'NOUN', 'PUNCT'], Translation: to put on (dress), Affix: {'prefix': '', 'suffix': 'du'}
#   Word: hoddu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nānu avarannu karakoṃḍu baruttēne
# Translated Sentence: I’ll bring them (along with me)
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: avarannu, POS: None, Translation: None, Affix: None
#   Word: karakoṃḍu, POS: None, Translation: None, Affix: None
#   Word: baruttēne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: nānu ā pustakagaḷannu tagoṃḍu baruttēne
# Translated Sentence: I’ll bring those books
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustakagaḷannu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷannu'}
#   Word: tagoṃḍu, POS: None, Translation: None, Affix: None
#   Word: baruttēne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: nānu avarannu karakoṃḍu manege hōguttēne
# Translated Sentence: I’ll take them (persons) to my home
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: avarannu, POS: None, Translation: None, Affix: None
#   Word: karakoṃḍu, POS: None, Translation: None, Affix: None
#   Word: manege, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'ge'}
#   Word: hōguttēne, POS: ['PART', 'VERB'], Translation: to go, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: nānu ā pustakagaḷannu tagoṃḍu manege hōguttēne
# Translated Sentence: I’ll take those books home
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustakagaḷannu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷannu'}
#   Word: tagoṃḍu, POS: None, Translation: None, Affix: None
#   Word: manege, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'ge'}
#   Word: hōguttēne, POS: ['PART', 'VERB'], Translation: to go, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: Marada keḷage ēnide?
# Translated Sentence: What lies under the tree?
#   Word: marada, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'da'}
#   Word: keḷage, POS: ['ADP'], Translation: under, Affix: None
#   Word: ēnide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: {'prefix': 'ēn', 'suffix': ''}
# =========================================
# Sentence: ūṭa cennāgide.
# Translated Sentence: The meal tasted good.
#   Word: ūṭa, POS: ['PUNCT', 'VERB', 'PUNCT', 'NOUN'], Translation: (cooked) meal, Affix: None
#   Word: cennāgide, POS: ['AUX', 'ADJ'], Translation: is good, Affix: None
# =========================================
# Sentence: Maneya hattira kere ide.
# Translated Sentence: There is a water tank near the house.
#   Word: maneya, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'ya'}
#   Word: hattira, POS: ['ADV', 'PUNCT', 'NOUN'], Translation: near; nearness, Affix: None
#   Word: kere, POS: ['NOUN', 'PUNCT', 'NOUN', 'NOUN'], Translation: tank, water reservoir, Affix: None
#   Word: ide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: None
# =========================================
# Sentence: Dēvara dayadiṃda namage oḷḷeyadu āguttade.
# Translated Sentence: By God’s grace good things happen to us.
#   Word: dēvara, POS: ['PROPN'], Translation: god, Affix: {'prefix': '', 'suffix': 'ra'}
#   Word: dayadiṃda, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: grace, mercy, Affix: {'prefix': '', 'suffix': 'diṃda'}
#   Word: namage, POS: ['PRON', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'], Translation: us (dative case), Affix: None
#   Word: oḷḷeyadu, POS: ['ADJ', 'NOUN'], Translation: good thing, Affix: None
#   Word: āguttade, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to become, occur, Affix: {'prefix': '', 'suffix': 'ttade'}
# =========================================
# Sentence: Tuṃba jana illi niṃtiddāre.
# Translated Sentence: Many people are standing here.
#   Word: tuṃba, POS: ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'], Translation: very, much, many, Affix: None
#   Word: jana, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: person, people, Affix: None
#   Word: illi, POS: ['ADV'], Translation: here, Affix: None
#   Word: niṃtiddāre, POS: ['PRON', 'VERB'], Translation: they stand, Affix: None
# =========================================
# Sentence: Nanna kelasa hēgide?
# Translated Sentence: How is my work?
#   Word: nanna, POS: ['PRON'], Translation: my, Affix: None
#   Word: kelasa, POS: ['NOUN'], Translation: work, Affix: None
#   Word: hēgide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: {'prefix': 'hēg', 'suffix': ''}
# =========================================
# Sentence: Bahaḷa aparūpavāgi baruttāre.
# Translated Sentence: They come here rarely.
#   Word: bahaḷa, POS: ['ADJ', 'PUNCT', 'ADJ', 'PUNCT', 'ADV'], Translation: much, many, very, Affix: None
#   Word: aparūpavāgi, POS: ['ADV'], Translation: rarely, Affix: None
#   Word: baruttāre, POS: ['PRON', 'VERB'], Translation: they come, Affix: None
# =========================================
# Sentence: ā kelasa māḍuvavaru yāvāgalū yaśasviyāguttāre.
# Translated Sentence: Those who do this work always become successful.
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: kelasa, POS: ['NOUN'], Translation: work, Affix: None
#   Word: māḍuvavaru, POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Translation: they (persons), Affix: {'prefix': 'māḍuv', 'suffix': ''}
#   Word: yāvāgalū, POS: ['ADV'], Translation: always, Affix: None
#   Word: yaśasviyāguttāre, POS: ['ADJ', 'PUNCT', 'ADJ'], Translation: glorious, successful, Affix: {'prefix': '', 'suffix': 'yāguttāre'}
# =========================================
# Sentence: Kannaḍa oṃdu haḷeya, suṃdaravāda bhāṣe; nīvu kalitare adannu tuṃba meccuviri.
# Translated Sentence: Kannada is an old, beautiful language; if you learn it, you will like it a lot.
#   Word: kannaḍa, POS: ['PROPN', 'PUNCT', 'VERB', 'PUNCT'], Translation: rice (cooked), Affix: {'prefix': 'k', 'suffix': 'ḍa'}
#   Word: oṃdu, POS: ['NUM', 'PUNCT', 'PRON'], Translation: one, a, Affix: None
#   Word: haḷeya, POS: ['ADJ'], Translation: old, Affix: None
#   Word: suṃdaravāda, POS: ['ADJ'], Translation: beautiful, Affix: {'prefix': '', 'suffix': 'vāda'}
#   Word: bhāṣe;, POS: ['NOUN'], Translation: language, Affix: {'prefix': '', 'suffix': ';'}
#   Word: nīvu, POS: ['PRON', 'PUNCT', 'NOUN', 'SYM', 'ADJ', 'PUNCT'], Translation: you (plural / honorific), Affix: None
#   Word: kalitare, POS: ['SCONJ', 'X', 'NUM', 'PUNCT', 'VERB'], Translation: if [one] learns, Affix: None
#   Word: adannu, POS: ['SCONJ', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT'], Translation: that (accusative case), Affix: None
#   Word: tuṃba, POS: ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'], Translation: very, much, many, Affix: None
#   Word: meccuviri, POS: ['PRON', 'AUX', 'VERB'], Translation: you will like, Affix: None
# =========================================
# Sentence: Lesson 4
# Translated Sentence: 1. This is the door of my house. 2. That is the horn of a cow. 3. The tip of the horn is not sharp. 4. My book is there. 5. The colour of the book is red. 6. The colour of your books is yellow. 7. Their colour is
#   Word: lesson, POS: None, Translation: None, Affix: None
#   Word: 4, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Lesson 12
# Translated Sentence: 1. Gaṇēśa! Have you gone home? 2. He was tired and went to sleep. 3. That girl sang elegantly. 4. That boy spoke coarsely. 5. He scolded me badly and went away. 6. She saw that and laughed happily. 7. Read this lesson and ask questions. 8. The neighbours went on travel yesterday and will return next month. 9. Did he really say so? 10. Try hard and read these sentences. 11. Please speak a bit quickly. 12. He
#   Word: lesson, POS: None, Translation: None, Affix: None
#   Word: 12, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: miliṭari hōṭalu
# Translated Sentence: non-vegetarian restaurant
#   Word: miliṭari, POS: ['NOUN'], Translation: military, Affix: None
#   Word: hōṭalu, POS: ['NOUN'], Translation: restaurant, Affix: None
# =========================================

# %%
# Further splitting of prefix and suffix TODO:
for result in results:
    sentence, translated_sentence, pos_info = result
    for word, info in pos_info.items():
        if info['affix'] is not None:
            prefix = info['affix']['prefix']
            suffix = info['affix']['suffix']
            
            # Find suffxies
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 41
#      38 prev_word = trans_words[i-1] if i > 0 else "<BOS>"
#      39 next_word = trans_words[i+1] if i < len(trans_words)-1 else "<EOS>"
# ---> 41 prev_pos = word_info.get(prev_word, {}).get('pos', ["<BOS>"])[0] if prev_word != "<BOS>" else "<BOS>"
#      42 next_pos = word_info.get(next_word, {}).get('pos', ["<EOS>"])[0] if next_word != "<EOS>" else "<EOS>"
#      44 suffix_stats[suf]["pos_before"][prev_pos] += 1
#
# TypeError: 'NoneType' object is not subscriptable

# %% [markdown]
# # Get list of common affixes and their frequencies, along with the different words that contain them

# %%
from collections import defaultdict

# Words and suffixes detected
words_with_suffixes = defaultdict(list)
words_with_prefixes = defaultdict(list)
for result in results:
    sentence, translated_sentence, pos_info = result
    for word, info in pos_info.items():
        if info['affix'] is not None:
            prefix = info['affix']['prefix']
            suffix = info['affix']['suffix']
            
            # Find prefixes
            if prefix:
                words_with_prefixes[prefix].append(word)
            
            # Find suffixes
            if suffix:
                words_with_suffixes[suffix].append(word)


words_with_suffixes = dict(words_with_suffixes)

#words_with_prefixes = dict(words_with_prefixes)

words_with_suffixes

# TODO: I KNOW KANNADA HAS SUFFIXES, BUT HOW DO YOU DETECT THAT IN THE LANGUAGE?
# Out:
# ({'gaḷu': ['pustakagaḷu',
#    'maragaḷu',
#    'manegaḷu',
#    'gurugaḷu',
#    'koṃbugaḷu',
#    'maragaḷu',
#    'pustakagaḷu',
#    'pustakagaḷu',
#    'maragaḷu',
#    'maragaḷu',
#    'pustakagaḷu',
#    'pustakagaḷu',
#    'pustakagaḷu',
#    'haṇṇugaḷu',
#    'maragaḷu',
#    'haṇṇugaḷu',
#    'cīlagaḷu',
#    'pustakagaḷu',
#    'vidyārthigaḷu',
#    'pustakagaḷu'],
#   'ru': ['purōhitaru',
#    'raitaru',
#    'raitaru',
#    'huḍugaru',
#    'huḍugaru',
#    'tammaṃdiru',
#    'janaru',
#    'janaru'],
#   'yā': ['vidyārthiyā', 'vidyārthiniyā'],
#   'vā': ['maravā', 'pustakavā', 'pustakavā', 'pustakavā', 'maravā'],
#   'valla': ['pustakavalla', 'maravalla', 'iṣṭavalla'],
#   '-v-alla': ['mara-v-alla'],
#   '-y-alla': ['huḍugi-y-alla'],
#   '-v-illa': ['mara-v-illa'],
#   '-y-illa': ['huḍugi-y-illa'],
#   'mogga': ['śivamogga'],
#   'ddīrā': ['cennāgiddīrā'],
#   ')': ['(nānu)', '(aṣṭu)', '(aṣṭu)'],
#   'rājarē': ['gururājarē'],
#   'navarē': ['rāmappanavarē',
#    'sītammanavarē',
#    'sītammanavarē',
#    'rāmayyanavarē'],
#   'ddēne': ['cennāgiddēne',
#    'cennāgiddēne',
#    'cennāgiddēne',
#    'cennāgiddēne',
#    'māḍiddēne',
#    'hōgiddēne'],
#   'yavarā': ['maneyavarā'],
#   'ttēne': ['baruttēne',
#    'māḍuttēne',
#    'mugisuttēne',
#    'baruttēne',
#    'baredukoḷḷuttēne',
#    'baruttēne',
#    'baruttēne',
#    'hōguttēne',
#    'hōguttēne'],
#   'vina': ['hasuvina'],
#   'ttāne': ['ōduttāne',
#    'baruttāne',
#    'ōduttāne',
#    'baruttāne',
#    'hōguttāne',
#    'baruttāne',
#    'hōguttāne',
#    'hōguttāne'],
#   'vanu': ['ōduvanu'],
#   'vudilla': ['baruvudilla',
#    'māḍuvudilla',
#    'māḍuvudilla',
#    'māḍuvudilla',
#    'māḍuvudilla',
#    'māḍuvudilla',
#    'māḍuvudilla',
#    'baruvudilla',
#    'baruvudilla',
#    'māḍuvudilla',
#    'māḍuvudilla',
#    'māḍuvudilla',
#    'baruvudilla'],
#   'yaru': ['huḍugiyaru', 'huḍugiyaru', 'huḍugiyaru'],
#   'nannu': ['huḍuganannu',
#    'manuṣyanannu',
#    'huḍuganannu',
#    'manuṣyanannu',
#    'maganannu'],
#   'yuttāne': ['hoḍeyuttāne'],
#   'nige': ['huḍuganige', 'manuṣyanige'],
#   'vannu': ['viṣayavannu',
#    'saṃgītavannu',
#    'pustakavannu',
#    'pustakavannu',
#    'pustakavannu',
#    'kelasavannu',
#    'pustakavannu',
#    'pustakavannu',
#    'pustakavannu',
#    'hūvannu',
#    'pustakavannu',
#    'pustakavannu',
#    'kelasavannu',
#    'patravannu',
#    'pustakavannu',
#    'patravannu',
#    'patravannu',
#    'pustakavannu',
#    'patravannu',
#    'pustakavannu',
#    'patravannu',
#    'pustakavannu',
#    'pustakavannu'],
#   'kke': ['ūṭakke'],
#   'ge': ['manege',
#    'avarige',
#    'manege',
#    'manege',
#    'manege',
#    'manege',
#    'manege',
#    'manege',
#    'avarige',
#    'bagege',
#    'kaḍege',
#    'manege',
#    'manege'],
#   'yiṃda': ['kaiyiṃda', 'kiviyiṃda'],
#   'daru': ['baredaru', 'baredaru', 'baredaru', 'baredaru', 'māḍidaru'],
#   'varu': ['kēḷuvaru', 'cikkavaru'],
#   'niṃda': ['kalliniṃda'],
#   'yoḷaginiṃda': ['maneyoḷaginiṃda'],
#   'yoḷakke': ['maneyoḷakke'],
#   'kkōskara': ['ūṭakkōskara'],
#   'villa': ['samācāravilla', 'sādhyavilla', 'sādhyavilla'],
#   'ttīri': ['tagoḷḷuttīri', 'hōguttīri'],
#   'gaḷalla': ['maragaḷalla'],
#   'nalla': ['raitanalla'],
#   'ralla': ['raitaralla', 'raitaralla'],
#   'vē': ['maravē'],
#   'vō': ['maravō'],
#   'rannu': ['huḍugarannu'],
#   'vāda': ['suṃdaravāda', 'suṃdaravāda', 'suṃdaravāda'],
#   '-v-āda': ['kliṣṭa-v-āda'],
#   'ya': ['maneya', 'bhāṣeya', 'maneya'],
#   'vu': ['nōḍidevu'],
#   'du': ['nannadu', 'doḍḍadu', 'takkadu', 'hodedu'],
#   'da': ['pakkada',
#    'māḍida',
#    'māḍida',
#    'bareda',
#    'bareda',
#    'māḍida',
#    'māḍida',
#    'marada'],
#   'giṃta': ['kurcigiṃta', 'ellarigiṃta'],
#   'de': ['ellide', 'hōgide'],
#   'ddāḷō': ['māḍiddāḷō', 'māḍiddāḷō'],
#   'ttī': ['māḍuttī'],
#   'nu': ['malagidenu',
#    'nōḍidenu',
#    'nōḍidenu',
#    'yōcisidenu',
#    'yōcisidenu',
#    'nōḍidenu',
#    'nōḍidenu',
#    'hēḷidenu'],
#   'denu': ['māḍidenu', 'māḍidenu'],
#   'venu': ['ōdiruvenu', 'hāḍuvenu', 'nōḍuvenu', 'māḍuvenu', 'biḍuvenu'],
#   'dāgi': ['doḍḍadāgi', 'keṭṭadāgi'],
#   'dide': ['beḷedide'],
#   'ddāne': ['māḍiddāne'],
#   'vāgi': ['krūravāgi', 'suṃdaravāgi'],
#   'ddāḷe': ['māḍiddāḷe'],
#   'yāgi': ['lēkhakiyāgi'],
#   'dalli': ['sammēḷanadalli', 'dēvasthānadalli', 'saṃgrahālayadalli'],
#   'vahisidaḷu': ['bhāgavahisidaḷu'],
#   'nāgi': ['purōhitanāgi'],
#   'danu': ['māḍidanu'],
#   'ne': ['bēgane'],
#   'tta': ['māḍutta'],
#   'ttiddēne': ['ōduttiddēne'],
#   'ttiddenu': ['ōduttiddenu', 'baruttiddenu'],
#   'ttiruvenu': ['ōduttiruvenu'],
#   'sidenu': ['māḍisidenu'],
#   'nnu': ['tappannu',
#    'nannannu',
#    'nannannu',
#    'nannannu',
#    'ivarannu',
#    'ellarannu'],
#   'isu': ['arthaisu'],
#   'visu': ['arthavisu'],
#   'va': ['hēḷuva', 'hēḷuva', 'māḍuva', 'iruva'],
#   'yuva': ['bareyuva', 'bareyuva', 'naḍeyuva', 'naḍeyuva'],
#   'yuttēne': ['kareyuttēne', 'kareyuttēne'],
#   'yuvavanannu': ['naḍeyuvavanannu'],
#   'dannu': ['araḷidudannu', 'araḷidudannu'],
#   'nō': ['nōḍidenō'],
#   'ttānō': ['baruttānō'],
#   'vudu': ['māḍuvudu', 'māḍuvudu', 'māḍuvudu', 'māḍuvudu', 'māḍuvudu'],
#   'lla': ['cennāgilla', 'māḍilla', 'baralilla'],
#   'yuvudu': ['bareyuvudu',
#    'bareyuvudu',
#    'bareyuvudu',
#    'bareyuvudu',
#    'bareyuvudu'],
#   'kate': ['saṇṇakate'],
#   'vudakke': ['koḷḷuvudakke'],
#   'ḍa': ['kannaḍa', 'kannaḍa'],
#   'yalu': ['kaliyalu', 'bareyalu', 'bareyalu', 'bareyalu'],
#   'yuvudilla': ['bareyuvudilla', 'bareyuvudilla', 'bareyuvudilla'],
#   '-': ['bare-', 'māva-'],
#   'yuttalilla': ['bareyuttalilla'],
#   'yalilla': ['bareyalilla',
#    'bareyalilla',
#    'bareyalilla',
#    'bareyalilla',
#    'bareyalilla',
#    'bareyalilla'],
#   'dilla': ['baredilla', 'baredilla'],
#   'yāgiral-': ['vidyārthiyāgiral-'],
#   'yāgiru-': ['vidyārthiyāgiru-'],
#   'yāgiruvenu': ['vidyārthiyāgiruvenu'],
#   'vāgide': ['kaṣṭavāgide'],
#   'ttu': ['bēkāgittu'],
#   'ruvudu': ['bēkāgiruvudu'],
#   'ttade': ['bēkāguttade',
#    'māḍalpaḍuttade',
#    'māḍalpaḍuttade',
#    'māḍalāguttade',
#    'baruttade',
#    'āguttade'],
#   'ttēne”': ['baruttēne”'],
#   '”': ['cennāgide”'],
#   'daḷu': ['hedaridaḷu', 'hedaridaḷu', 'hedaridaḷu'],
#   'vudillaveṃdu': ['baruvudillaveṃdu'],
#   'veṃdu': ['kaṣṭaveṃdu'],
#   'ṃdu': ['hōgabēkeṃdu'],
#   'lli': ['nimmalli'],
#   'vuḷḷa': ['haṇavuḷḷa'],
#   'yuḷḷa': ['buddhiyuḷḷa'],
#   'villada': ['haṇavillada'],
#   'gaḷannu': ['pustakagaḷannu',
#    'haṇṇugaḷannu',
#    'patrikegaḷannu',
#    'citragaḷannu',
#    'pustakagaḷannu',
#    'pustakagaḷannu'],
#   'ddare': ['māḍiddare'],
#   'yāguttade': ['caḷiyāguttade'],
#   'yitu': ['mugiyitu'],
#   'yō': ['elliyō'],
#   'yādarū': ['elliyādarū'],
#   'daṃte': ['māḍidaṃte'],
#   'dahāge': ['māḍidahāge'],
#   'vaṃte': ['hēḷuvaṃte'],
#   ']': ['[maṃdi]'],
#   'gaḷellarannū': ['vidyārthigaḷellarannū'],
#   'gaḷannella': ['haṇṇugaḷannella'],
#   'dukoṃḍiddāne': ['tiḷidukoṃḍiddāne'],
#   'tiddāḷe': ['maretiddāḷe'],
#   'dukoṃḍiddīyā': ['tiḷidukoṃḍiddīyā'],
#   'dukoṃḍiddēne': ['tegedukoṃḍiddēne'],
#   'dukoṃḍu': ['tegedukoṃḍu', 'tegedukoṃḍu'],
#   'dukoṃḍiddīrā': ['karedukoṃḍiddīrā'],
#   'dukoḍuttēne': ['baredukoḍuttēne'],
#   'biḍu': ['māḍibiḍu'],
#   'dubiḍuttāre': ['baredubiḍuttāre'],
#   'ttāre': ['biḍuttāre'],
#   'ri': ['balliri'],
#   'nū': ['snēhitanū'],
#   'li': ['āgali'],
#   'vāgali': ['guruvāravāgali', 'śukravāravāgali'],
#   'ttadeyā': ['baruttadeyā'],
#   'vide': ['sādhyavide'],
#   'ttave': ['kāṇisuttave'],
#   'ṃda': ['nālkariṃda', 'nālkariṃda', 'ippattariṃda'],
#   'su': ['bhāgisu'],
#   'davarannu': ['uḷidavarannu'],
#   'hisiri': ['kaḷuhisiri'],
#   'tu': ['sāgitu'],
#   'gū': ['ibbarigū'],
#   've': ['cennāgive'],
#   'ra': ['dēvara'],
#   'diṃda': ['dayadiṃda'],
#   'yāguttāre': ['yaśasviyāguttāre'],
#   ';': ['bhāṣe;']},
#  {'mais': ['maisūru', 'maisūru'],
#   'maṃgaḷ': ['maṃgaḷūru'],
#   'beṃgaḷ': ['beṃgaḷūru', 'beṃgaḷūru'],
#   'nagarag': ['nagaragaḷu'],
#   '(': ['(nānu)', '(aṣṭu)', '(aṣṭu)'],
#   'rām': ['rāmappanavarē', 'rāmayyanavarē'],
#   'sī': ['sītamma', 'sītammanavarē', 'sītammanavarē'],
#   'baṃd': ['baṃdaḷu', 'baṃdavanu', 'baṃdāga'],
#   'av': ['avarige', 'avarige'],
#   'k': ['kalliniṃda', 'kannaḍa', 'kannaḍa'],
#   'bēḍ': ['bēḍamma'],
#   'nōḍid': ['nōḍidaḷu'],
#   'doḍḍ': ['doḍḍavaḷu', 'doḍḍavanu', 'doḍḍavanu'],
#   'nammavar': ['nammavaradannu'],
#   'nōḍ': ['nōḍidevu',
#    'nōḍidenu',
#    'nōḍidenu',
#    'nōḍidenō',
#    'nōḍidenu',
#    'nōḍidenu'],
#   'p': ['pakkada'],
#   'ell': ['ellarigiṃta'],
#   'malag': ['malagidenu'],
#   'ōd': ['ōdiruvenu'],
#   'bh': ['bhāgavahisidaḷu', 'bhāgisu'],
#   'sust': ['sustāgi'],
#   't': ['tappannu', 'takkadu'],
#   'māḍid': ['māḍidavanu', 'māḍidalli'],
#   'araḷ': ['araḷidudannu', 'araḷidudannu'],
#   'hāḍid': ['hāḍidaṣṭu'],
#   's': ['saṇṇakate', 'sāgitu'],
#   'hōga': ['hōgabēku', 'hōgabēku'],
#   'nōḍa': ['nōḍabēku'],
#   'malaga': ['malagabēku'],
#   'māḍa': ['māḍabēḍa', 'māḍabāradu'],
#   'bēkāg': ['bēkāgide'],
#   'bēk': ['bēkāgittu', 'bēkāgiruvudu', 'bēkāguttade'],
#   '“': ['“nāḷe', '“idu'],
#   'yōcis': ['yōcisidenu', 'yōcisidenu'],
#   'hed': ['hedaridaḷu', 'hedaridaḷu', 'hedaridaḷu'],
#   'hōgab': ['hōgabēkeṃdu'],
#   'ōda': ['ōdabāradu'],
#   'tam': ['tammaṃdiru'],
#   'māḍal': ['māḍalpaḍuttade', 'māḍalpaḍuttade', 'māḍalāguttade', 'māḍalāyitu'],
#   'ōdalāg': ['ōdalāgide'],
#   'baruva': ['baruvahāge'],
#   'hōguv': ['hōguvalli'],
#   '[': ['[maṃdi]'],
#   'ārthig': ['ārthigaḷu'],
#   'baredu': ['baredukoḷḷuttēne'],
#   'nīv': ['nīvēnu'],
#   'b': ['balliri'],
#   'sikk': ['sikkide'],
#   'a': ['asādhya', 'asādhya'],
#   'aidar': ['aidaralli'],
#   'g': ['gaḷu'],
#   'nālk': ['nālkariṃda', 'nālkariṃda'],
#   'ippatt': ['ippattariṃda'],
#   'nālkaneyadar': ['nālkaneyadaralli'],
#   'sēbug': ['sēbugaḷu'],
#   'nūraney': ['nūraneyavaru'],
#   'bīdigaḷ': ['bīdigaḷalli'],
#   'ibb': ['ibbarigū'],
#   'hēḷ': ['hēḷidenu'],
#   'hatt': ['hattāru'],
#   'idd': ['iddavu'],
#   'bīdiy': ['bīdiyalli'],
#   'nūr': ['nūrāru'],
#   'ēn': ['ēnide'],
#   'hēg': ['hēgide'],
#   'māḍuv': ['māḍuvavaru']})

# %%
suffix_counts = defaultdict(lambda: defaultdict(int))   # suffix → {stem: freq}
# For each suffix, the dictionary will contain a dict counting stems that use it
for suffix, words in words_with_suffixes.items():
    for word in words:
        # Extract the stem by removing the suffix
        stem = word[:-len(suffix)] if len(suffix) > 0 else word
        suffix_counts[suffix][stem] += 1

# %%
suffix_counts = dict(suffix_counts)
# Display the suffix counts
for suffix, stems in suffix_counts.items():
    print(f"Suffix: {suffix}")
    for stem, freq in stems.items():
        print(f"  Stem: {stem}, Frequency: {freq}")
    print("=========================================")
# Out:
# Suffix: gaḷu
#   Stem: pustaka, Frequency: 8
#   Stem: mara, Frequency: 5
#   Stem: mane, Frequency: 1
#   Stem: guru, Frequency: 1
#   Stem: koṃbu, Frequency: 1
#   Stem: haṇṇu, Frequency: 2
#   Stem: cīla, Frequency: 1
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: ru
#   Stem: purōhita, Frequency: 1
#   Stem: raita, Frequency: 2
#   Stem: huḍuga, Frequency: 2
#   Stem: tammaṃdi, Frequency: 1
#   Stem: jana, Frequency: 2
# =========================================
# Suffix: yā
#   Stem: vidyārthi, Frequency: 1
#   Stem: vidyārthini, Frequency: 1
# =========================================
# Suffix: vā
#   Stem: mara, Frequency: 2
#   Stem: pustaka, Frequency: 3
# =========================================
# Suffix: valla
#   Stem: pustaka, Frequency: 1
#   Stem: mara, Frequency: 1
#   Stem: iṣṭa, Frequency: 1
# =========================================
# Suffix: -v-alla
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: -y-alla
#   Stem: huḍugi, Frequency: 1
# =========================================
# Suffix: -v-illa
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: -y-illa
#   Stem: huḍugi, Frequency: 1
# =========================================
# Suffix: mogga
#   Stem: śiva, Frequency: 1
# =========================================
# Suffix: ddīrā
#   Stem: cennāgi, Frequency: 1
# =========================================
# Suffix: )
#   Stem: (nānu, Frequency: 1
#   Stem: (aṣṭu, Frequency: 2
# =========================================
# Suffix: rājarē
#   Stem: guru, Frequency: 1
# =========================================
# Suffix: navarē
#   Stem: rāmappa, Frequency: 1
#   Stem: sītamma, Frequency: 2
#   Stem: rāmayya, Frequency: 1
# =========================================
# Suffix: ddēne
#   Stem: cennāgi, Frequency: 4
#   Stem: māḍi, Frequency: 1
#   Stem: hōgi, Frequency: 1
# =========================================
# Suffix: yavarā
#   Stem: mane, Frequency: 1
# =========================================
# Suffix: ttēne
#   Stem: baru, Frequency: 4
#   Stem: māḍu, Frequency: 1
#   Stem: mugisu, Frequency: 1
#   Stem: baredukoḷḷu, Frequency: 1
#   Stem: hōgu, Frequency: 2
# =========================================
# Suffix: vina
#   Stem: hasu, Frequency: 1
# =========================================
# Suffix: ttāne
#   Stem: ōdu, Frequency: 2
#   Stem: baru, Frequency: 3
#   Stem: hōgu, Frequency: 3
# =========================================
# Suffix: vanu
#   Stem: ōdu, Frequency: 1
# =========================================
# Suffix: vudilla
#   Stem: baru, Frequency: 4
#   Stem: māḍu, Frequency: 9
# =========================================
# Suffix: yaru
#   Stem: huḍugi, Frequency: 3
# =========================================
# Suffix: nannu
#   Stem: huḍuga, Frequency: 2
#   Stem: manuṣya, Frequency: 2
#   Stem: maga, Frequency: 1
# =========================================
# Suffix: yuttāne
#   Stem: hoḍe, Frequency: 1
# =========================================
# Suffix: nige
#   Stem: huḍuga, Frequency: 1
#   Stem: manuṣya, Frequency: 1
# =========================================
# Suffix: vannu
#   Stem: viṣaya, Frequency: 1
#   Stem: saṃgīta, Frequency: 1
#   Stem: pustaka, Frequency: 13
#   Stem: kelasa, Frequency: 2
#   Stem: hū, Frequency: 1
#   Stem: patra, Frequency: 5
# =========================================
# Suffix: kke
#   Stem: ūṭa, Frequency: 1
# =========================================
# Suffix: ge
#   Stem: mane, Frequency: 9
#   Stem: avari, Frequency: 2
#   Stem: bage, Frequency: 1
#   Stem: kaḍe, Frequency: 1
# =========================================
# Suffix: yiṃda
#   Stem: kai, Frequency: 1
#   Stem: kivi, Frequency: 1
# =========================================
# Suffix: daru
#   Stem: bare, Frequency: 4
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: varu
#   Stem: kēḷu, Frequency: 1
#   Stem: cikka, Frequency: 1
# =========================================
# Suffix: niṃda
#   Stem: kalli, Frequency: 1
# =========================================
# Suffix: yoḷaginiṃda
#   Stem: mane, Frequency: 1
# =========================================
# Suffix: yoḷakke
#   Stem: mane, Frequency: 1
# =========================================
# Suffix: kkōskara
#   Stem: ūṭa, Frequency: 1
# =========================================
# Suffix: villa
#   Stem: samācāra, Frequency: 1
#   Stem: sādhya, Frequency: 2
# =========================================
# Suffix: ttīri
#   Stem: tagoḷḷu, Frequency: 1
#   Stem: hōgu, Frequency: 1
# =========================================
# Suffix: gaḷalla
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: nalla
#   Stem: raita, Frequency: 1
# =========================================
# Suffix: ralla
#   Stem: raita, Frequency: 2
# =========================================
# Suffix: vē
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: vō
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: rannu
#   Stem: huḍuga, Frequency: 1
# =========================================
# Suffix: vāda
#   Stem: suṃdara, Frequency: 3
# =========================================
# Suffix: -v-āda
#   Stem: kliṣṭa, Frequency: 1
# =========================================
# Suffix: ya
#   Stem: mane, Frequency: 2
#   Stem: bhāṣe, Frequency: 1
# =========================================
# Suffix: vu
#   Stem: nōḍide, Frequency: 1
# =========================================
# Suffix: du
#   Stem: nanna, Frequency: 1
#   Stem: doḍḍa, Frequency: 1
#   Stem: takka, Frequency: 1
#   Stem: hode, Frequency: 1
# =========================================
# Suffix: da
#   Stem: pakka, Frequency: 1
#   Stem: māḍi, Frequency: 4
#   Stem: bare, Frequency: 2
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: giṃta
#   Stem: kurci, Frequency: 1
#   Stem: ellari, Frequency: 1
# =========================================
# Suffix: de
#   Stem: elli, Frequency: 1
#   Stem: hōgi, Frequency: 1
# =========================================
# Suffix: ddāḷō
#   Stem: māḍi, Frequency: 2
# =========================================
# Suffix: ttī
#   Stem: māḍu, Frequency: 1
# =========================================
# Suffix: nu
#   Stem: malagide, Frequency: 1
#   Stem: nōḍide, Frequency: 4
#   Stem: yōciside, Frequency: 2
#   Stem: hēḷide, Frequency: 1
# =========================================
# Suffix: denu
#   Stem: māḍi, Frequency: 2
# =========================================
# Suffix: venu
#   Stem: ōdiru, Frequency: 1
#   Stem: hāḍu, Frequency: 1
#   Stem: nōḍu, Frequency: 1
#   Stem: māḍu, Frequency: 1
#   Stem: biḍu, Frequency: 1
# =========================================
# Suffix: dāgi
#   Stem: doḍḍa, Frequency: 1
#   Stem: keṭṭa, Frequency: 1
# =========================================
# Suffix: dide
#   Stem: beḷe, Frequency: 1
# =========================================
# Suffix: ddāne
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: vāgi
#   Stem: krūra, Frequency: 1
#   Stem: suṃdara, Frequency: 1
# =========================================
# Suffix: ddāḷe
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: yāgi
#   Stem: lēkhaki, Frequency: 1
# =========================================
# Suffix: dalli
#   Stem: sammēḷana, Frequency: 1
#   Stem: dēvasthāna, Frequency: 1
#   Stem: saṃgrahālaya, Frequency: 1
# =========================================
# Suffix: vahisidaḷu
#   Stem: bhāga, Frequency: 1
# =========================================
# Suffix: nāgi
#   Stem: purōhita, Frequency: 1
# =========================================
# Suffix: danu
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: ne
#   Stem: bēga, Frequency: 1
# =========================================
# Suffix: tta
#   Stem: māḍu, Frequency: 1
# =========================================
# Suffix: ttiddēne
#   Stem: ōdu, Frequency: 1
# =========================================
# Suffix: ttiddenu
#   Stem: ōdu, Frequency: 1
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: ttiruvenu
#   Stem: ōdu, Frequency: 1
# =========================================
# Suffix: sidenu
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: nnu
#   Stem: tappa, Frequency: 1
#   Stem: nanna, Frequency: 3
#   Stem: ivara, Frequency: 1
#   Stem: ellara, Frequency: 1
# =========================================
# Suffix: isu
#   Stem: artha, Frequency: 1
# =========================================
# Suffix: visu
#   Stem: artha, Frequency: 1
# =========================================
# Suffix: va
#   Stem: hēḷu, Frequency: 2
#   Stem: māḍu, Frequency: 1
#   Stem: iru, Frequency: 1
# =========================================
# Suffix: yuva
#   Stem: bare, Frequency: 2
#   Stem: naḍe, Frequency: 2
# =========================================
# Suffix: yuttēne
#   Stem: kare, Frequency: 2
# =========================================
# Suffix: yuvavanannu
#   Stem: naḍe, Frequency: 1
# =========================================
# Suffix: dannu
#   Stem: araḷidu, Frequency: 2
# =========================================
# Suffix: nō
#   Stem: nōḍide, Frequency: 1
# =========================================
# Suffix: ttānō
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: vudu
#   Stem: māḍu, Frequency: 5
# =========================================
# Suffix: lla
#   Stem: cennāgi, Frequency: 1
#   Stem: māḍi, Frequency: 1
#   Stem: barali, Frequency: 1
# =========================================
# Suffix: yuvudu
#   Stem: bare, Frequency: 5
# =========================================
# Suffix: kate
#   Stem: saṇṇa, Frequency: 1
# =========================================
# Suffix: vudakke
#   Stem: koḷḷu, Frequency: 1
# =========================================
# Suffix: ḍa
#   Stem: kanna, Frequency: 2
# =========================================
# Suffix: yalu
#   Stem: kali, Frequency: 1
#   Stem: bare, Frequency: 3
# =========================================
# Suffix: yuvudilla
#   Stem: bare, Frequency: 3
# =========================================
# Suffix: -
#   Stem: bare, Frequency: 1
#   Stem: māva, Frequency: 1
# =========================================
# Suffix: yuttalilla
#   Stem: bare, Frequency: 1
# =========================================
# Suffix: yalilla
#   Stem: bare, Frequency: 6
# =========================================
# Suffix: dilla
#   Stem: bare, Frequency: 2
# =========================================
# Suffix: yāgiral-
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: yāgiru-
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: yāgiruvenu
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: vāgide
#   Stem: kaṣṭa, Frequency: 1
# =========================================
# Suffix: ttu
#   Stem: bēkāgi, Frequency: 1
# =========================================
# Suffix: ruvudu
#   Stem: bēkāgi, Frequency: 1
# =========================================
# Suffix: ttade
#   Stem: bēkāgu, Frequency: 1
#   Stem: māḍalpaḍu, Frequency: 2
#   Stem: māḍalāgu, Frequency: 1
#   Stem: baru, Frequency: 1
#   Stem: āgu, Frequency: 1
# =========================================
# Suffix: ttēne”
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: ”
#   Stem: cennāgide, Frequency: 1
# =========================================
# Suffix: daḷu
#   Stem: hedari, Frequency: 3
# =========================================
# Suffix: vudillaveṃdu
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: veṃdu
#   Stem: kaṣṭa, Frequency: 1
# =========================================
# Suffix: ṃdu
#   Stem: hōgabēke, Frequency: 1
# =========================================
# Suffix: lli
#   Stem: nimma, Frequency: 1
# =========================================
# Suffix: vuḷḷa
#   Stem: haṇa, Frequency: 1
# =========================================
# Suffix: yuḷḷa
#   Stem: buddhi, Frequency: 1
# =========================================
# Suffix: villada
#   Stem: haṇa, Frequency: 1
# =========================================
# Suffix: gaḷannu
#   Stem: pustaka, Frequency: 3
#   Stem: haṇṇu, Frequency: 1
#   Stem: patrike, Frequency: 1
#   Stem: citra, Frequency: 1
# =========================================
# Suffix: ddare
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: yāguttade
#   Stem: caḷi, Frequency: 1
# =========================================
# Suffix: yitu
#   Stem: mugi, Frequency: 1
# =========================================
# Suffix: yō
#   Stem: elli, Frequency: 1
# =========================================
# Suffix: yādarū
#   Stem: elli, Frequency: 1
# =========================================
# Suffix: daṃte
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: dahāge
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: vaṃte
#   Stem: hēḷu, Frequency: 1
# =========================================
# Suffix: ]
#   Stem: [maṃdi, Frequency: 1
# =========================================
# Suffix: gaḷellarannū
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: gaḷannella
#   Stem: haṇṇu, Frequency: 1
# =========================================
# Suffix: dukoṃḍiddāne
#   Stem: tiḷi, Frequency: 1
# =========================================
# Suffix: tiddāḷe
#   Stem: mare, Frequency: 1
# =========================================
# Suffix: dukoṃḍiddīyā
#   Stem: tiḷi, Frequency: 1
# =========================================
# Suffix: dukoṃḍiddēne
#   Stem: tege, Frequency: 1
# =========================================
# Suffix: dukoṃḍu
#   Stem: tege, Frequency: 2
# =========================================
# Suffix: dukoṃḍiddīrā
#   Stem: kare, Frequency: 1
# =========================================
# Suffix: dukoḍuttēne
#   Stem: bare, Frequency: 1
# =========================================
# Suffix: biḍu
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: dubiḍuttāre
#   Stem: bare, Frequency: 1
# =========================================
# Suffix: ttāre
#   Stem: biḍu, Frequency: 1
# =========================================
# Suffix: ri
#   Stem: balli, Frequency: 1
# =========================================
# Suffix: nū
#   Stem: snēhita, Frequency: 1
# =========================================
# Suffix: li
#   Stem: āga, Frequency: 1
# =========================================
# Suffix: vāgali
#   Stem: guruvāra, Frequency: 1
#   Stem: śukravāra, Frequency: 1
# =========================================
# Suffix: ttadeyā
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: vide
#   Stem: sādhya, Frequency: 1
# =========================================
# Suffix: ttave
#   Stem: kāṇisu, Frequency: 1
# =========================================
# Suffix: ṃda
#   Stem: nālkari, Frequency: 2
#   Stem: ippattari, Frequency: 1
# =========================================
# Suffix: su
#   Stem: bhāgi, Frequency: 1
# =========================================
# Suffix: davarannu
#   Stem: uḷi, Frequency: 1
# =========================================
# Suffix: hisiri
#   Stem: kaḷu, Frequency: 1
# =========================================
# Suffix: tu
#   Stem: sāgi, Frequency: 1
# =========================================
# Suffix: gū
#   Stem: ibbari, Frequency: 1
# =========================================
# Suffix: ve
#   Stem: cennāgi, Frequency: 1
# =========================================
# Suffix: ra
#   Stem: dēva, Frequency: 1
# =========================================
# Suffix: diṃda
#   Stem: daya, Frequency: 1
# =========================================
# Suffix: yāguttāre
#   Stem: yaśasvi, Frequency: 1
# =========================================
# Suffix: ;
#   Stem: bhāṣe, Frequency: 1
# =========================================

# %%
# Retain productive suffixes
productive_suffixes = {suffix: stems for suffix, stems in suffix_counts.items() if len(stems) > 1}

# Display productive suffixes
for suffix, stems in productive_suffixes.items():
    print(f"Productive Suffix: {suffix}")
    for stem, freq in stems.items():
        print(f"  Stem: {stem}, Frequency: {freq}")
    print("=========================================")
# Out:
# Productive Suffix: gaḷu
#   Stem: pustaka, Frequency: 8
#   Stem: mara, Frequency: 5
#   Stem: mane, Frequency: 1
#   Stem: guru, Frequency: 1
#   Stem: koṃbu, Frequency: 1
#   Stem: haṇṇu, Frequency: 2
#   Stem: cīla, Frequency: 1
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Productive Suffix: ru
#   Stem: purōhita, Frequency: 1
#   Stem: raita, Frequency: 2
#   Stem: huḍuga, Frequency: 2
#   Stem: tammaṃdi, Frequency: 1
#   Stem: jana, Frequency: 2
# =========================================
# Productive Suffix: yā
#   Stem: vidyārthi, Frequency: 1
#   Stem: vidyārthini, Frequency: 1
# =========================================
# Productive Suffix: vā
#   Stem: mara, Frequency: 2
#   Stem: pustaka, Frequency: 3
# =========================================
# Productive Suffix: valla
#   Stem: pustaka, Frequency: 1
#   Stem: mara, Frequency: 1
#   Stem: iṣṭa, Frequency: 1
# =========================================
# Productive Suffix: )
#   Stem: (nānu, Frequency: 1
#   Stem: (aṣṭu, Frequency: 2
# =========================================
# Productive Suffix: navarē
#   Stem: rāmappa, Frequency: 1
#   Stem: sītamma, Frequency: 2
#   Stem: rāmayya, Frequency: 1
# =========================================
# Productive Suffix: ddēne
#   Stem: cennāgi, Frequency: 4
#   Stem: māḍi, Frequency: 1
#   Stem: hōgi, Frequency: 1
# =========================================
# Productive Suffix: ttēne
#   Stem: baru, Frequency: 4
#   Stem: māḍu, Frequency: 1
#   Stem: mugisu, Frequency: 1
#   Stem: baredukoḷḷu, Frequency: 1
#   Stem: hōgu, Frequency: 2
# =========================================
# Productive Suffix: ttāne
#   Stem: ōdu, Frequency: 2
#   Stem: baru, Frequency: 3
#   Stem: hōgu, Frequency: 3
# =========================================
# Productive Suffix: vudilla
#   Stem: baru, Frequency: 4
#   Stem: māḍu, Frequency: 9
# =========================================
# Productive Suffix: nannu
#   Stem: huḍuga, Frequency: 2
#   Stem: manuṣya, Frequency: 2
#   Stem: maga, Frequency: 1
# =========================================
# Productive Suffix: nige
#   Stem: huḍuga, Frequency: 1
#   Stem: manuṣya, Frequency: 1
# =========================================
# Productive Suffix: vannu
#   Stem: viṣaya, Frequency: 1
#   Stem: saṃgīta, Frequency: 1
#   Stem: pustaka, Frequency: 13
#   Stem: kelasa, Frequency: 2
#   Stem: hū, Frequency: 1
#   Stem: patra, Frequency: 5
# =========================================
# Productive Suffix: ge
#   Stem: mane, Frequency: 9
#   Stem: avari, Frequency: 2
#   Stem: bage, Frequency: 1
#   Stem: kaḍe, Frequency: 1
# =========================================
# Productive Suffix: yiṃda
#   Stem: kai, Frequency: 1
#   Stem: kivi, Frequency: 1
# =========================================
# Productive Suffix: daru
#   Stem: bare, Frequency: 4
#   Stem: māḍi, Frequency: 1
# =========================================
# Productive Suffix: varu
#   Stem: kēḷu, Frequency: 1
#   Stem: cikka, Frequency: 1
# =========================================
# Productive Suffix: villa
#   Stem: samācāra, Frequency: 1
#   Stem: sādhya, Frequency: 2
# =========================================
# Productive Suffix: ttīri
#   Stem: tagoḷḷu, Frequency: 1
#   Stem: hōgu, Frequency: 1
# =========================================
# Productive Suffix: ya
#   Stem: mane, Frequency: 2
#   Stem: bhāṣe, Frequency: 1
# =========================================
# Productive Suffix: du
#   Stem: nanna, Frequency: 1
#   Stem: doḍḍa, Frequency: 1
#   Stem: takka, Frequency: 1
#   Stem: hode, Frequency: 1
# =========================================
# Productive Suffix: da
#   Stem: pakka, Frequency: 1
#   Stem: māḍi, Frequency: 4
#   Stem: bare, Frequency: 2
#   Stem: mara, Frequency: 1
# =========================================
# Productive Suffix: giṃta
#   Stem: kurci, Frequency: 1
#   Stem: ellari, Frequency: 1
# =========================================
# Productive Suffix: de
#   Stem: elli, Frequency: 1
#   Stem: hōgi, Frequency: 1
# =========================================
# Productive Suffix: nu
#   Stem: malagide, Frequency: 1
#   Stem: nōḍide, Frequency: 4
#   Stem: yōciside, Frequency: 2
#   Stem: hēḷide, Frequency: 1
# =========================================
# Productive Suffix: venu
#   Stem: ōdiru, Frequency: 1
#   Stem: hāḍu, Frequency: 1
#   Stem: nōḍu, Frequency: 1
#   Stem: māḍu, Frequency: 1
#   Stem: biḍu, Frequency: 1
# =========================================
# Productive Suffix: dāgi
#   Stem: doḍḍa, Frequency: 1
#   Stem: keṭṭa, Frequency: 1
# =========================================
# Productive Suffix: vāgi
#   Stem: krūra, Frequency: 1
#   Stem: suṃdara, Frequency: 1
# =========================================
# Productive Suffix: dalli
#   Stem: sammēḷana, Frequency: 1
#   Stem: dēvasthāna, Frequency: 1
#   Stem: saṃgrahālaya, Frequency: 1
# =========================================
# Productive Suffix: ttiddenu
#   Stem: ōdu, Frequency: 1
#   Stem: baru, Frequency: 1
# =========================================
# Productive Suffix: nnu
#   Stem: tappa, Frequency: 1
#   Stem: nanna, Frequency: 3
#   Stem: ivara, Frequency: 1
#   Stem: ellara, Frequency: 1
# =========================================
# Productive Suffix: va
#   Stem: hēḷu, Frequency: 2
#   Stem: māḍu, Frequency: 1
#   Stem: iru, Frequency: 1
# =========================================
# Productive Suffix: yuva
#   Stem: bare, Frequency: 2
#   Stem: naḍe, Frequency: 2
# =========================================
# Productive Suffix: lla
#   Stem: cennāgi, Frequency: 1
#   Stem: māḍi, Frequency: 1
#   Stem: barali, Frequency: 1
# =========================================
# Productive Suffix: yalu
#   Stem: kali, Frequency: 1
#   Stem: bare, Frequency: 3
# =========================================
# Productive Suffix: -
#   Stem: bare, Frequency: 1
#   Stem: māva, Frequency: 1
# =========================================
# Productive Suffix: ttade
#   Stem: bēkāgu, Frequency: 1
#   Stem: māḍalpaḍu, Frequency: 2
#   Stem: māḍalāgu, Frequency: 1
#   Stem: baru, Frequency: 1
#   Stem: āgu, Frequency: 1
# =========================================
# Productive Suffix: gaḷannu
#   Stem: pustaka, Frequency: 3
#   Stem: haṇṇu, Frequency: 1
#   Stem: patrike, Frequency: 1
#   Stem: citra, Frequency: 1
# =========================================
# Productive Suffix: vāgali
#   Stem: guruvāra, Frequency: 1
#   Stem: śukravāra, Frequency: 1
# =========================================
# Productive Suffix: ṃda
#   Stem: nālkari, Frequency: 2
#   Stem: ippattari, Frequency: 1
# =========================================

# %%
# Take all words in the sentences and get stems with suffixes
all_words = set()
for result in results:
    sentence, translated_sentence, pos_info = result
    for word in pos_info.keys():
        all_words.add(word) 
# Display all words
print(f"Total unique words in sentences: {len(all_words)}")
# Out:
# Total unique words in sentences: 593

# %%
#all_words
# Remove all punctutation from the words
all_words = [word.strip('.,!?()[]/"!') for word in all_words]

all_words = set(all_words)  # Convert to set to remove duplicates

# Display all words
print(f"Total unique words in sentences after removing punctuation: {len(all_words)}")
# Out:
# Total unique words in sentences after removing punctuation: 590

# %%
all_words
# Out:
# {'',
#  '12',
#  '2',
#  '4',
#  'adakkiṃta',
#  'adannu',
#  'adu',
#  'adū',
#  'aidaralli',
#  'aidu',
#  'alla',
#  'alli',
#  'amma',
#  'anna',
#  'aparūpavāgi',
#  'araḷida',
#  'araḷidudannu',
#  'arthaisu',
#  'arthavisu',
#  'asādhya',
#  'athavā',
#  'avana',
#  'avanige',
#  'avaniṃda',
#  'avanu',
#  'avara',
#  'avaradakke',
#  'avarannu',
#  'avarige',
#  'avaru',
#  'avarū',
#  'avaḷannu',
#  'avaḷige',
#  'avaḷu',
#  'avu',
#  'aḷabēkō',
#  'aṃte',
#  'aṣṭu',
#  'ba-',
#  'bagege',
#  'bahaḷa',
#  'balliri',
#  'banni',
#  'barabahudu',
#  'barabahudā',
#  'baralilla',
#  'baralā',
#  'bare-',
#  'bareda',
#  'baredaru',
#  'baredilla',
#  'baredubiḍuttāre',
#  'baredukoḍuttēne',
#  'baredukoḷḷuttēne',
#  'bareyalilla',
#  'bareyalu',
#  'bareyuttalilla',
#  'bareyuva',
#  'bareyuvudilla',
#  'bareyuvudu',
#  'baruttade',
#  'baruttadeyā',
#  'baruttiddenu',
#  'baruttāne',
#  'baruttānō',
#  'baruttāre',
#  'baruttēne',
#  'baruttēne”',
#  'baruvahāge',
#  'baruvudilla',
#  'baruvudillaveṃdu',
#  'bassu',
#  'baṃda',
#  'baṃdare',
#  'baṃdaru',
#  'baṃdarū',
#  'baṃdavanu',
#  'baṃdaḷu',
#  'baṃdiddēne',
#  'baṃdāga',
#  'baṇṇa',
#  'bekku',
#  'beḷedide',
#  'beṃgaḷūru',
#  'bhāgavahisidaḷu',
#  'bhāgisu',
#  'bhāra',
#  'bhāṣe;',
#  'bhāṣeya',
#  'bhēṭi',
#  'biddive',
#  'biḍabahudu',
#  'biḍuttāre',
#  'biḍuvenu',
#  'biṭṭubiḍi',
#  'buddhi',
#  'buddhiyuḷḷa',
#  'bā',
#  'bēga',
#  'bēgane',
#  'bēku',
#  'bēkā',
#  'bēkāgide',
#  'bēkāgiruvudu',
#  'bēkāgittu',
#  'bēkāguttade',
#  'bēre',
#  'bēḍa',
#  'bēḍamma',
#  'bīdigaḷalli',
#  'bīdiyalli',
#  'cahā',
#  'caḷiyāguttade',
#  'cennāgi',
#  'cennāgiddēne',
#  'cennāgiddīrā',
#  'cennāgide',
#  'cennāgide”',
#  'cennāgilla',
#  'cennāgive',
#  'cikka',
#  'cikkavaru',
#  'citragaḷannu',
#  'cīlagaḷu',
#  'dayadiṃda',
#  'dayaviṭṭu',
#  'dhāravāḍa',
#  'doḍḍa',
#  'doḍḍadu',
#  'doḍḍadāgi',
#  'doḍḍavanu',
#  'doḍḍavaḷu',
#  'dēvara',
#  'dēvasthānadalli',
#  'ella',
#  'elladakkiṃta',
#  'ellarannu',
#  'ellarigiṃta',
#  'elli',
#  'ellide',
#  'elliyādarū',
#  'elliyō',
#  'eraḍannu',
#  'exercise',
#  'eṃba',
#  'eṃbudu',
#  'eṃdare',
#  'eṃdu',
#  'eṣṭu',
#  'gaḷu',
#  'gaṇēśa',
#  'gaṇēśarē',
#  'gaṇēśā',
#  'girākigaḷige',
#  'gottilla',
#  'gurugaḷu',
#  'gururājarē',
#  'guruvāravāgali',
#  'guṇisu',
#  'hasu',
#  'hasuvina',
#  'hattira',
#  'hattu',
#  'hattāru',
#  'haudu',
#  'haḷeya',
#  'haṇa',
#  'haṇavillada',
#  'haṇavuḷḷa',
#  'haṇṇu',
#  'haṇṇugaḷannella',
#  'haṇṇugaḷannu',
#  'haṇṇugaḷu',
#  'heccu',
#  'hedaridaḷu',
#  'hesaru',
#  'hiṃde',
#  'hoddu',
#  'hodedu',
#  'hoḍeyuttāne',
#  'huḍuga',
#  'huḍuganannu',
#  'huḍuganige',
#  'huḍugarannu',
#  'huḍugaru',
#  'huḍugi',
#  'huḍugi-y-alla',
#  'huḍugi-y-illa',
#  'huḍugiyaru',
#  'huṣāriralilla',
#  'hāge',
#  'hāḍidaṣṭu',
#  'hāḍuvenu',
#  'hēgiddīri',
#  'hēgide',
#  'hēḷi',
#  'hēḷida',
#  'hēḷidanu',
#  'hēḷidare',
#  'hēḷidaru',
#  'hēḷiddēne',
#  'hēḷidenu',
#  'hēḷuva',
#  'hēḷuvaṃte',
#  'hīge',
#  'hōda',
#  'hōdanu',
#  'hōdaru',
#  'hōdenu',
#  'hōdevu',
#  'hōgabēkeṃdu',
#  'hōgabēku',
#  'hōgi',
#  'hōgiddēne',
#  'hōgide',
#  'hōguttāne',
#  'hōguttēne',
#  'hōguttīri',
#  'hōguvalli',
#  'hōyitu',
#  'hōṭalu',
#  'hū',
#  'hūvannu',
#  'ibbarigū',
#  'ibbarū',
#  'idannu',
#  'iddaru',
#  'iddavu',
#  'iddāre',
#  'ide',
#  'idu',
#  'illa',
#  'illi',
#  'ippattariṃda',
#  'iruva',
#  'ivara',
#  'ivarannu',
#  'ivaru',
#  'ive',
#  'ivu',
#  'iṃgliṣu',
#  'iṣṭavalla',
#  'iṣṭu',
#  'jana',
#  'janaru',
#  'jāga',
#  'kaiyalli',
#  'kaiyiṃda',
#  'kalitare',
#  'kaliyalu',
#  'kalliniṃda',
#  'kannaḍa',
#  'karakoṃḍu',
#  'karedukoṃḍiddīrā',
#  'kareyuttēne',
#  'karnāṭakada',
#  'kaḍege',
#  'kaḷedu',
#  'kaḷuhisiri',
#  'kaṣṭa',
#  'kaṣṭaveṃdu',
#  'kaṣṭavāgide',
#  'kaṭṭaḍa',
#  'kaṭṭidaru',
#  'kelasa',
#  'kelasavannu',
#  'kelavu',
#  'kere',
#  'keḷage',
#  'keṃpu',
#  'keṭṭa',
#  'keṭṭadāgi',
#  'kharcu',
#  'kiviyiṃda',
#  'kiṭaki',
#  'kliṣṭa-v-āda',
#  'koḷalu',
#  'koḷḷalu',
#  'koḷḷuvudakke',
#  'koṃbugaḷu',
#  'koṭṭanu',
#  'koṭṭenu',
#  'krūravāgi',
#  'kurci',
#  'kurcigiṃta',
#  'kāru',
#  'kāṇisuttave',
#  'kēḷi',
#  'kēḷuvaru',
#  'kūtukoḷḷi',
#  'kūḍisu',
#  'kṣamisi',
#  'kṣamisiri',
#  'laṃḍan',
#  'lesson',
#  'lēkhakiyāgi',
#  'maga',
#  'maganannu',
#  'mahiḷe',
#  'maisūrige',
#  'maisūru',
#  'malagabēku',
#  'malagidenu',
#  'mane',
#  'manegaḷu',
#  'manege',
#  'maneya',
#  'maneyavaru',
#  'maneyavarā',
#  'maneyoḷaginiṃda',
#  'maneyoḷakke',
#  'manuṣya',
#  'manuṣyanannu',
#  'manuṣyanige',
#  'mara',
#  'mara-v-alla',
#  'mara-v-illa',
#  'marada',
#  'maragaḷalla',
#  'maragaḷu',
#  'maravalla',
#  'maravā',
#  'maravē',
#  'maravō',
#  'maretiddāḷe',
#  'mattu',
#  'maṃdi',
#  'maṃgaḷūru',
#  'meccuviri',
#  'meravaṇige',
#  'miliṭari',
#  'mugisuttēne',
#  'mugiyitu',
#  'muṃde',
#  'māriddāne',
#  'mātanāḍidanu',
#  'māva-',
#  'māḍabahudu',
#  'māḍaballa',
#  'māḍaballe',
#  'māḍabāradu',
#  'māḍabēḍa',
#  'māḍabēḍi',
#  'māḍalikke',
#  'māḍalilla',
#  'māḍalpaḍuttade',
#  'māḍalāguttade',
#  'māḍalāyitu',
#  'māḍibiḍu',
#  'māḍida',
#  'māḍidahāge',
#  'māḍidalli',
#  'māḍidanu',
#  'māḍidaru',
#  'māḍidavanu',
#  'māḍidaṃte',
#  'māḍiddare',
#  'māḍiddāne',
#  'māḍiddāḷe',
#  'māḍiddāḷō',
#  'māḍiddēne',
#  'māḍidenu',
#  'māḍilla',
#  'māḍisidenu',
#  'māḍu',
#  'māḍutta',
#  'māḍuttēne',
#  'māḍuttī',
#  'māḍuva',
#  'māḍuvavaru',
#  'māḍuvenu',
#  'māḍuvudilla',
#  'māḍuvudu',
#  'mējina',
#  'mēle',
#  'mūgu',
#  'mūrannu',
#  'mūru',
#  'mūrū',
#  'na',
#  'nagabēkō',
#  'nagara',
#  'nagaragaḷu',
#  'namage',
#  'namaskāra',
#  'namma',
#  'nammavaradannu',
#  'nanage',
#  'nanagōskara',
#  'nanna',
#  'nannadu',
#  'nannannu',
#  'naḍeyuva',
#  'naḍeyuvavanannu',
#  'nenne',
#  'neṃṭa',
#  'nidde',
#  'nijavāgi',
#  'nimage',
#  'nimagōskara',
#  'nimma',
#  'nimmalli',
#  'niṃtiddāre',
#  'nālkaneyadaralli',
#  'nālkariṃda',
#  'nālku',
#  'nānu',
#  'nānū',
#  'nāvu',
#  'nāḷe',
#  'nīru',
#  'nīvu',
#  'nīvēnu',
#  'nīvū',
#  'nōḍabēku',
#  'nōḍida',
#  'nōḍidanu',
#  'nōḍidanō',
#  'nōḍidaru',
#  'nōḍidaḷu',
#  'nōḍiddēne',
#  'nōḍidenu',
#  'nōḍidenō',
#  'nōḍidevu',
#  'nōḍiri',
#  'nōḍuvenu',
#  'nūraneyavaru',
#  'nūrannu',
#  'nūrāru',
#  'oḍedu',
#  'oḷage',
#  'oḷḷeyadu',
#  'oṃdu',
#  'pakkada',
#  'paravā',
#  'patni',
#  'patra',
#  'patravannu',
#  'patrikegaḷannu',
#  'paṭṭaru',
#  'praśne',
#  'purōhitanāgi',
#  'purōhitaru',
#  'pustaka',
#  'pustakagaḷannu',
#  'pustakagaḷu',
#  'pustakavalla',
#  'pustakavannu',
#  'pustakavā',
#  'raitanalla',
#  'raitaralla',
#  'raitaru',
#  'reyuvudilla',
#  'rāma',
#  'rāmanigiṃta',
#  'rāmappanavarē',
#  'rāmayyanavarē',
#  'rūpāyi',
#  'samaya',
#  'sammēḷanadalli',
#  'samācāra',
#  'samācāravilla',
#  'sari',
#  'saṃgrahālayadalli',
#  'saṃgīta',
#  'saṃgītavannu',
#  'saṃkōcapaḍisuttāne',
#  'saṃsthe',
#  'saṃtōṣa',
#  'saṇṇakate',
#  'sikka',
#  'sikkide',
#  'sikkitu',
#  'snēhitanū',
#  'surēśarē',
#  'sustāgi',
#  'suṃdaravāda',
#  'suṃdaravāgi',
#  'svalpa',
#  'svāmi',
#  'sādhya',
#  'sādhyavide',
#  'sādhyavilla',
#  'sāgitu',
#  'sāku',
#  'sāladā',
#  'sāvirāru',
#  'sēbugaḷu',
#  'sītamma',
#  'sītammanavarē',
#  'sīte',
#  'tagoḷḷi',
#  'tagoḷḷuttīri',
#  'tagoṃḍu',
#  'takkadu',
#  'tamage',
#  'tammaṃdiru',
#  'tanna',
#  'tanni',
#  'tappannu',
#  'tappu',
#  'taralā',
#  'taṃde',
#  'taṃdiddēne',
#  'tegedukoṃḍiddēne',
#  'tegedukoṃḍu',
#  'tiḷidukoṃḍiddāne',
#  'tiḷidukoṃḍiddīyā',
#  'tiṃda',
#  'toḍak-alla',
#  'toḍak-illa',
#  'toṃdare',
#  'tuṃba',
#  'tānu',
#  'tānē',
#  'tāvu',
#  'tōrisida',
#  'tōrisuttēne',
#  'tōruttade',
#  'uḷidavarannu',
#  'varṣa',
#  'vidhy-',
#  'vidyārthi',
#  'vidyārthigaḷellarannū',
#  'vidyārthigaḷu',
#  'vidyārthini',
#  'vidyārthiniyā',
#  'vidyārthiyā',
#  'vidyārthiyāgiral-',
#  'vidyārthiyāgiru-',
#  'vidyārthiyāgiruvenu',
#  'vikāsagoḷḷuttade',
#  'viśēṣavāda',
#  'viṣaya',
#  'viṣayavannu',
#  'vudilla',
#  'vāsa',
#  'yaśasviyāguttāre',
#  'yuvudilla',
#  'yārannō',
#  'yārādarū',
#  'yārō',
#  'yāva',
#  'yāvāga',
#  'yāvāgalū',
#  'yōcane',
#  'yōcisidenu',
#  'ā',
#  'ādare',
#  'ādevō',
#  'āgali',
#  'āguttade',
#  'ākāśa',
#  'ārakke',
#  'ārthigaḷu',
#  'ēke',
#  'ēnide',
#  'ēnu',
#  'ēnādarū',
#  'ēnū',
#  'ēḷge',
#  'ēḷige',
#  'ēḷu',
#  'ī',
#  'īga',
#  'ō',
#  'ōdabāradu',
#  'ōdalu',
#  'ōdalāgide',
#  'ōdibiṭṭenu',
#  'ōdida',
#  'ōdiddenu',
#  'ōdiddēne',
#  'ōdiruvenu',
#  'ōduttiddenu',
#  'ōduttiddēne',
#  'ōduttiruvenu',
#  'ōduttāne',
#  'ōduvanu',
#  'ōḍi',
#  'śivamogga',
#  'śrēṣṭhaneṃdu',
#  'śukravāravāgali',
#  'ūraṃte',
#  'ūrige',
#  'ūṭa',
#  'ūṭakke',
#  'ūṭakkōskara',
#  '“idu',
#  '“nāḷe'}

# %%
# Find stems in all_words that have suffixes we found in productive_suffixes
stems_with_suffixes = defaultdict(list)  # stem → [suffix1, suffix2, ...]
for word in all_words:
    for suffix in productive_suffixes.keys():
        if word.endswith(suffix):
            stem = word[:-len(suffix)] if len(suffix) > 0 else word
            stems_with_suffixes[stem].append(suffix)
# Convert to a regular dictionary
stems_with_suffixes = dict(stems_with_suffixes)
# Display stems with their suffixes
for stem, suffixes in stems_with_suffixes.items():
    print(f"Stem: {stem}, Suffixes: {suffixes}")
# Out:
# Stem: hī, Suffixes: ['ge']
# Stem: hōgabēkeṃ, Suffixes: ['du']
# Stem: doḍḍa, Suffixes: ['du', 'dāgi']
# Stem: maga, Suffixes: ['nannu']
# Stem: maganan, Suffixes: ['nu']
# Stem: magana, Suffixes: ['nnu']
# Stem: mugisu, Suffixes: ['ttēne']
# Stem: vidyārthiyāgiral, Suffixes: ['-']
# Stem: ōdalāgi, Suffixes: ['de']
# Stem: adan, Suffixes: ['nu']
# Stem: ada, Suffixes: ['nnu']
# Stem: tōrutta, Suffixes: ['de']
# Stem: tōru, Suffixes: ['ttade']
# Stem: krūra, Suffixes: ['vāgi']
# Stem: jana, Suffixes: ['ru']
# Stem: māḍiside, Suffixes: ['nu']
# Stem: suṃdara, Suffixes: ['vāgi']
# Stem: māḍabāra, Suffixes: ['du']
# Stem: iru, Suffixes: ['va']
# Stem: yā, Suffixes: ['va']
# Stem: kalliniṃ, Suffixes: ['da']
# Stem: kallini, Suffixes: ['ṃda']
# Stem: sādhyavi, Suffixes: ['de', 'lla']
# Stem: para, Suffixes: ['vā']
# Stem: māḍi, Suffixes: ['dalli', 'daru', 'ddēne', 'da', 'lla']
# Stem: viśēṣavā, Suffixes: ['da']
# Stem: guru, Suffixes: ['gaḷu']
# Stem: cennāgi, Suffixes: ['lla', 'ddēne', 'de']
# Stem: nūran, Suffixes: ['nu']
# Stem: nūra, Suffixes: ['nnu']
# Stem: ārthi, Suffixes: ['gaḷu']
# Stem: avaran, Suffixes: ['nu']
# Stem: avara, Suffixes: ['nnu']
# Stem: ōduva, Suffixes: ['nu']
# Stem: maisū, Suffixes: ['ru']
# Stem: oḍe, Suffixes: ['du']
# Stem: bage, Suffixes: ['ge']
# Stem: rāmani, Suffixes: ['giṃta']
# Stem: bareyuttali, Suffixes: ['lla']
# Stem: rāmappa, Suffixes: ['navarē']
# Stem: pustaka, Suffixes: ['valla', 'gaḷannu', 'gaḷu', 'vannu', 'vā']
# Stem: pustakava, Suffixes: ['lla', 'nnu']
# Stem: haḷe, Suffixes: ['ya']
# Stem: nanna, Suffixes: ['du', 'nnu']
# Stem: oṃ, Suffixes: ['du']
# Stem: purōhita, Suffixes: ['ru']
# Stem: ba, Suffixes: ['-', 'ṃda']
# Stem: pustakagaḷan, Suffixes: ['nu']
# Stem: pustakagaḷa, Suffixes: ['nnu']
# Stem: mara, Suffixes: ['vā', 'valla', 'da', 'gaḷu']
# Stem: māḍida, Suffixes: ['nu', 'ru']
# Stem: baru, Suffixes: ['ttēne', 'ttade', 'ttāne', 'vudilla', 'ttiddenu']
# Stem: mane, Suffixes: ['gaḷu', 'ge', 'ya']
# Stem: kliṣṭa-v-ā, Suffixes: ['da']
# Stem: śukravāra, Suffixes: ['vāgali']
# Stem: doḍḍava, Suffixes: ['nu']
# Stem: māḍidava, Suffixes: ['nu']
# Stem: tappan, Suffixes: ['nu']
# Stem: tappa, Suffixes: ['nnu']
# Stem: koṭṭe, Suffixes: ['nu']
# Stem: māḍu, Suffixes: ['va', 'vudilla', 'ttēne', 'venu']
# Stem: avaniṃ, Suffixes: ['da']
# Stem: avani, Suffixes: ['ṃda', 'ge']
# Stem: hēḷida, Suffixes: ['nu', 'ru']
# Stem: avari, Suffixes: ['ge']
# Stem: iṣṭa, Suffixes: ['valla']
# Stem: iṣṭava, Suffixes: ['lla']
# Stem: nōḍuve, Suffixes: ['nu']
# Stem: nōḍu, Suffixes: ['venu']
# Stem: māḍuvudi, Suffixes: ['lla']
# Stem: hōda, Suffixes: ['ru', 'nu']
# Stem: hō, Suffixes: ['daru', 'da']
# Stem: toḍak-a, Suffixes: ['lla']
# Stem: paṭṭa, Suffixes: ['ru']
# Stem: yōciside, Suffixes: ['nu']
# Stem: biḍuve, Suffixes: ['nu']
# Stem: biḍu, Suffixes: ['venu']
# Stem: maneyoḷaginiṃ, Suffixes: ['da']
# Stem: maneyoḷagini, Suffixes: ['ṃda']
# Stem: ivaran, Suffixes: ['nu']
# Stem: ivara, Suffixes: ['nnu']
# Stem: haṇṇugaḷanne, Suffixes: ['lla']
# Stem: ēḷ, Suffixes: ['ge']
# Stem: ōduttidde, Suffixes: ['nu']
# Stem: ōdu, Suffixes: ['ttiddenu', 'ttāne']
# Stem: cikkava, Suffixes: ['ru']
# Stem: cikka, Suffixes: ['varu']
# Stem: nagara, Suffixes: ['gaḷu']
# Stem: tammaṃdi, Suffixes: ['ru']
# Stem: hau, Suffixes: ['du']
# Stem: bare, Suffixes: ['yalu', '-', 'da', 'daru', 'yuva']
# Stem: ōdi, Suffixes: ['da', 'ddēne']
# Stem: patrikegaḷan, Suffixes: ['nu']
# Stem: patrikegaḷa, Suffixes: ['nnu']
# Stem: patrike, Suffixes: ['gaḷannu']
# Stem: haṇṇu, Suffixes: ['gaḷu', 'gaḷannu']
# Stem: reyu, Suffixes: ['vudilla']
# Stem: reyuvudi, Suffixes: ['lla']
# Stem: ēḷi, Suffixes: ['ge']
# Stem: nīvē, Suffixes: ['nu']
# Stem: ē, Suffixes: ['nu']
# Stem: hod, Suffixes: ['du']
# Stem: māḍide, Suffixes: ['nu']
# Stem: sama, Suffixes: ['ya']
# Stem: avaḷan, Suffixes: ['nu']
# Stem: avaḷa, Suffixes: ['nnu']
# Stem: i, Suffixes: ['lla', 'varu', 'de', 'du']
# Stem: nālkariṃ, Suffixes: ['da']
# Stem: nālkari, Suffixes: ['ṃda']
# Stem: naḍeyu, Suffixes: ['va']
# Stem: naḍe, Suffixes: ['yuva']
# Stem: barutta, Suffixes: ['de']
# Stem: huṣārirali, Suffixes: ['lla']
# Stem: vidyārthiyāgiru, Suffixes: ['-', 'venu']
# Stem: atha, Suffixes: ['vā']
# Stem: mara-v-a, Suffixes: ['lla']
# Stem: kurci, Suffixes: ['giṃta']
# Stem: iva, Suffixes: ['ru']
# Stem: manuṣ, Suffixes: ['ya']
# Stem: maisūri, Suffixes: ['ge']
# Stem: vikāsagoḷḷutta, Suffixes: ['de']
# Stem: vikāsagoḷḷu, Suffixes: ['ttade']
# Stem: ellaran, Suffixes: ['nu']
# Stem: ellara, Suffixes: ['nnu']
# Stem: hōgu, Suffixes: ['ttāne', 'ttīri', 'ttēne']
# Stem: biḍabahu, Suffixes: ['du']
# Stem: kaḍe, Suffixes: ['ge']
# Stem: huḍuga, Suffixes: ['nannu', 'nige', 'ru']
# Stem: huḍuganan, Suffixes: ['nu']
# Stem: huḍugana, Suffixes: ['nnu']
# Stem: caḷiyāgutta, Suffixes: ['de']
# Stem: caḷiyāgu, Suffixes: ['ttade']
# Stem: mātanāḍida, Suffixes: ['nu']
# Stem: beṃgaḷū, Suffixes: ['ru']
# Stem: samācāra, Suffixes: ['villa']
# Stem: samācāravi, Suffixes: ['lla']
# Stem: citragaḷan, Suffixes: ['nu']
# Stem: citragaḷa, Suffixes: ['nnu']
# Stem: citra, Suffixes: ['gaḷannu']
# Stem: viṣa, Suffixes: ['ya']
# Stem: araḷi, Suffixes: ['da']
# Stem: manuṣya, Suffixes: ['nige', 'nannu']
# Stem: manuṣyani, Suffixes: ['ge']
# Stem: guruvāra, Suffixes: ['vāgali']
# Stem: hode, Suffixes: ['du']
# Stem: hāḍuve, Suffixes: ['nu']
# Stem: hāḍu, Suffixes: ['venu']
# Stem: mara-v-i, Suffixes: ['lla']
# Stem: huḍugiya, Suffixes: ['ru']
# Stem: kali, Suffixes: ['yalu']
# Stem: hēḷide, Suffixes: ['nu']
# Stem: saṃgīta, Suffixes: ['vannu']
# Stem: saṃgītavan, Suffixes: ['nu']
# Stem: saṃgītava, Suffixes: ['nnu']
# Stem: sāvirā, Suffixes: ['ru']
# Stem: e, Suffixes: ['lla']
# Stem: pakka, Suffixes: ['da']
# Stem: barabahu, Suffixes: ['du']
# Stem: sītamma, Suffixes: ['navarē']
# Stem: baruttade, Suffixes: ['yā']
# Stem: ellari, Suffixes: ['giṃta']
# Stem: baruvudillaveṃ, Suffixes: ['du']
# Stem: nūraneyava, Suffixes: ['ru']
# Stem: nūraneya, Suffixes: ['varu']
# Stem: baruvahā, Suffixes: ['ge']
# Stem: ava, Suffixes: ['nige', 'nu', 'ru']
# Stem: maragaḷa, Suffixes: ['lla']
# Stem: taṃ, Suffixes: ['de']
# Stem: śrēṣṭhaneṃ, Suffixes: ['du']
# Stem: ōdiruve, Suffixes: ['nu']
# Stem: ōdiru, Suffixes: ['venu']
# Stem: kā, Suffixes: ['ru']
# Stem: , Suffixes: ['vudilla', 'gaḷu']
# Stem: vudi, Suffixes: ['lla']
# Stem: ōdabāra, Suffixes: ['du']
# Stem: kareyu, Suffixes: ['ttēne']
# Stem: malagide, Suffixes: ['nu']
# Stem: nana, Suffixes: ['ge']
# Stem: tama, Suffixes: ['ge']
# Stem: kaṭṭida, Suffixes: ['ru']
# Stem: kaṭṭi, Suffixes: ['daru']
# Stem: karnāṭaka, Suffixes: ['da']
# Stem: taṃdi, Suffixes: ['ddēne']
# Stem: tagoḷḷu, Suffixes: ['ttīri']
# Stem: manuṣyanan, Suffixes: ['nu']
# Stem: manuṣyana, Suffixes: ['nnu']
# Stem: nī, Suffixes: ['ru']
# Stem: tā, Suffixes: ['nu']
# Stem: asādh, Suffixes: ['ya']
# Stem: idda, Suffixes: ['ru']
# Stem: id, Suffixes: ['daru']
# Stem: tiṃ, Suffixes: ['da']
# Stem: ti, Suffixes: ['ṃda']
# Stem: bēkāgutta, Suffixes: ['de']
# Stem: bēkāgu, Suffixes: ['ttade']
# Stem: ōdutti, Suffixes: ['ddēne']
# Stem: māḍalpaḍutta, Suffixes: ['de']
# Stem: māḍalpaḍu, Suffixes: ['ttade']
# Stem: māḍuve, Suffixes: ['nu']
# Stem: baṃda, Suffixes: ['ru']
# Stem: baṃ, Suffixes: ['daru', 'da']
# Stem: nan, Suffixes: ['nannu']
# Stem: nannan, Suffixes: ['nu']
# Stem: muṃ, Suffixes: ['de']
# Stem: haṇavilla, Suffixes: ['da']
# Stem: bareda, Suffixes: ['ru']
# Stem: keḷa, Suffixes: ['ge']
# Stem: pustakavan, Suffixes: ['nu']
# Stem: tōrisu, Suffixes: ['ttēne']
# Stem: hēḷi, Suffixes: ['da', 'daru', 'ddēne']
# Stem: huḍugi-y-i, Suffixes: ['lla']
# Stem: māḍabahu, Suffixes: ['du']
# Stem: huḍugaran, Suffixes: ['nu']
# Stem: huḍugara, Suffixes: ['nnu']
# Stem: nā, Suffixes: ['nu']
# Stem: nija, Suffixes: ['vāgi']
# Stem: ōdidde, Suffixes: ['nu']
# Stem: maṃgaḷū, Suffixes: ['ru']
# Stem: toḍak-i, Suffixes: ['lla']
# Stem: vidyārthiyāgiruve, Suffixes: ['nu']
# Stem: baruvudi, Suffixes: ['lla']
# Stem: bareyu, Suffixes: ['vudilla', 'va']
# Stem: bareyuvudi, Suffixes: ['lla']
# Stem: takka, Suffixes: ['du']
# Stem: raita, Suffixes: ['ru']
# Stem: yu, Suffixes: ['vudilla']
# Stem: yuvudi, Suffixes: ['lla']
# Stem: eṃbu, Suffixes: ['du']
# Stem: araḷidudan, Suffixes: ['nu']
# Stem: araḷiduda, Suffixes: ['nnu']
# Stem: dayadiṃ, Suffixes: ['da']
# Stem: dayadi, Suffixes: ['ṃda']
# Stem: huḍugani, Suffixes: ['ge']
# Stem: barali, Suffixes: ['lla']
# Stem: tōrisi, Suffixes: ['da']
# Stem: nōḍi, Suffixes: ['ddēne', 'da', 'daru']
# Stem: sādhya, Suffixes: ['villa']
# Stem: haṇṇugaḷan, Suffixes: ['nu']
# Stem: haṇṇugaḷa, Suffixes: ['nnu']
# Stem: baredukoḍu, Suffixes: ['ttēne']
# Stem: kivi, Suffixes: ['yiṃda']
# Stem: kiviyiṃ, Suffixes: ['da']
# Stem: kiviyi, Suffixes: ['ṃda']
# Stem: girākigaḷi, Suffixes: ['ge']
# Stem: sādh, Suffixes: ['ya']
# Stem: vidyārthi, Suffixes: ['gaḷu', 'yā']
# Stem: sēbu, Suffixes: ['gaḷu']
# Stem: meravaṇi, Suffixes: ['ge']
# Stem: raitana, Suffixes: ['lla']
# Stem: bēkāgi, Suffixes: ['de']
# Stem: marava, Suffixes: ['lla']
# Stem: hiṃ, Suffixes: ['de']
# Stem: ippattariṃ, Suffixes: ['da']
# Stem: ippattari, Suffixes: ['ṃda']
# Stem: a, Suffixes: ['du', 'lla', 'varu']
# Stem: beḷedi, Suffixes: ['de']
# Stem: viṣaya, Suffixes: ['vannu']
# Stem: viṣayavan, Suffixes: ['nu']
# Stem: viṣayava, Suffixes: ['nnu']
# Stem: naḍeyuvava, Suffixes: ['nannu']
# Stem: naḍeyuvavanan, Suffixes: ['nu']
# Stem: naḍeyuvavana, Suffixes: ['nnu']
# Stem: kaṣṭaveṃ, Suffixes: ['du']
# Stem: sikki, Suffixes: ['de']
# Stem: kēḷuva, Suffixes: ['ru']
# Stem: kēḷu, Suffixes: ['varu']
# Stem: hattā, Suffixes: ['ru']
# Stem: “i, Suffixes: ['du']
# Stem: māḍaba, Suffixes: ['lla']
# Stem: baredi, Suffixes: ['lla']
# Stem: patra, Suffixes: ['vannu']
# Stem: patravan, Suffixes: ['nu']
# Stem: patrava, Suffixes: ['nnu']
# Stem: kaḷe, Suffixes: ['du']
# Stem: tegedukoṃḍi, Suffixes: ['ddēne']
# Stem: hōgi, Suffixes: ['ddēne', 'de']
# Stem: raitara, Suffixes: ['lla']
# Stem: gotti, Suffixes: ['lla']
# Stem: āgutta, Suffixes: ['de']
# Stem: āgu, Suffixes: ['ttade']
# Stem: oḷa, Suffixes: ['ge']
# Stem: bhāṣe, Suffixes: ['ya']
# Stem: vidyārthini, Suffixes: ['yā']
# Stem: baṃdi, Suffixes: ['ddēne']
# Stem: idan, Suffixes: ['nu']
# Stem: ida, Suffixes: ['nnu']
# Stem: bēkāgiruvu, Suffixes: ['du']
# Stem: elli, Suffixes: ['de']
# Stem: kelasa, Suffixes: ['vannu']
# Stem: kelasavan, Suffixes: ['nu']
# Stem: kelasava, Suffixes: ['nnu']
# Stem: nid, Suffixes: ['de']
# Stem: māḍalāgutta, Suffixes: ['de']
# Stem: māḍalāgu, Suffixes: ['ttade']
# Stem: māva, Suffixes: ['-']
# Stem: mūran, Suffixes: ['nu']
# Stem: mūra, Suffixes: ['nnu']
# Stem: nōḍida, Suffixes: ['nu', 'ru']
# Stem: eraḍan, Suffixes: ['nu']
# Stem: eraḍa, Suffixes: ['nnu']
# Stem: sammēḷana, Suffixes: ['dalli']
# Stem: aparūpa, Suffixes: ['vāgi']
# Stem: maneyava, Suffixes: ['ru']
# Stem: maneya, Suffixes: ['varu']
# Stem: hū, Suffixes: ['vannu']
# Stem: hūvan, Suffixes: ['nu']
# Stem: hūva, Suffixes: ['nnu']
# Stem: kaṣṭavāgi, Suffixes: ['de']
# Stem: ōduttiruve, Suffixes: ['nu']
# Stem: ōduttiru, Suffixes: ['venu']
# Stem: nōḍide, Suffixes: ['nu']
# Stem: hā, Suffixes: ['ge']
# Stem: mū, Suffixes: ['ru']
# Stem: nama, Suffixes: ['ge']
# Stem: ēni, Suffixes: ['de']
# Stem: bareyuvu, Suffixes: ['du']
# Stem: koṭṭa, Suffixes: ['nu']
# Stem: huḍugi-y-a, Suffixes: ['lla']
# Stem: koṃbu, Suffixes: ['gaḷu']
# Stem: uḷidavaran, Suffixes: ['nu']
# Stem: uḷidavara, Suffixes: ['nnu']
# Stem: māḍali, Suffixes: ['lla']
# Stem: baredukoḷḷu, Suffixes: ['ttēne']
# Stem: hēḷu, Suffixes: ['va']
# Stem: hōde, Suffixes: ['nu']
# Stem: ai, Suffixes: ['du']
# Stem: hesa, Suffixes: ['ru']
# Stem: hoḍeyu, Suffixes: ['ttāne']
# Stem: hēgi, Suffixes: ['de']
# Stem: ūri, Suffixes: ['ge']
# Stem: māḍidahā, Suffixes: ['ge']
# Stem: tiḷidukoṃḍiddī, Suffixes: ['yā']
# Stem: suṃdaravā, Suffixes: ['da']
# Stem: nammavaradan, Suffixes: ['nu']
# Stem: nammavarada, Suffixes: ['nnu']
# Stem: māḍuvu, Suffixes: ['du']
# Stem: kai, Suffixes: ['yiṃda']
# Stem: kaiyiṃ, Suffixes: ['da']
# Stem: kaiyi, Suffixes: ['ṃda']
# Stem: nūrā, Suffixes: ['ru']
# Stem: māḍuvava, Suffixes: ['ru']
# Stem: māḍuva, Suffixes: ['varu']
# Stem: rāmayya, Suffixes: ['navarē']
# Stem: dēvasthāna, Suffixes: ['dalli']
# Stem: vidhy, Suffixes: ['-']
# Stem: avaḷi, Suffixes: ['ge']
# Stem: eṃ, Suffixes: ['du']
# Stem: bareyali, Suffixes: ['lla']
# Stem: saṃkōcapaḍisu, Suffixes: ['ttāne']
# Stem: ōdibiṭṭe, Suffixes: ['nu']
# Stem: baṃdava, Suffixes: ['nu']
# Stem: oḷḷeya, Suffixes: ['du']
# Stem: nima, Suffixes: ['ge']
# Stem: baruttidde, Suffixes: ['nu']
# Stem: keṭṭa, Suffixes: ['dāgi']
# Stem: cīla, Suffixes: ['gaḷu']
# Stem: saṃgrahālaya, Suffixes: ['dalli']

# %%
suffix_info = {}

suffix_to_stems = defaultdict(list)  # suffix → [stems]
for stem, suffixes in stems_with_suffixes.items():
    for suffix in suffixes:
        suffix_to_stems[suffix].append(stem)

for suffix, stems in suffix_to_stems.items():
    # Create dict for this suffix
    suffix_info[suffix] = {
        "count": {},  # Will store stem:count pairs
    }
    
    # Count occurrences of each stem
    for stem in stems:
        if stem in suffix_info[suffix]["count"]:
            suffix_info[suffix]["count"][stem] += 1
        else:
            suffix_info[suffix]["count"][stem] = 1

# Display summary
print("Created info dictionary for", len(suffix_info), "suffixes")
suffix_info
# Out:
# Created info dictionary for 40 suffixes
# {'ge': {'count': {'hī': 1,
#    'bage': 1,
#    'mane': 1,
#    'avani': 1,
#    'avari': 1,
#    'ēḷ': 1,
#    'ēḷi': 1,
#    'maisūri': 1,
#    'kaḍe': 1,
#    'manuṣyani': 1,
#    'baruvahā': 1,
#    'nana': 1,
#    'tama': 1,
#    'keḷa': 1,
#    'huḍugani': 1,
#    'girākigaḷi': 1,
#    'meravaṇi': 1,
#    'oḷa': 1,
#    'hā': 1,
#    'nama': 1,
#    'ūri': 1,
#    'māḍidahā': 1,
#    'avaḷi': 1,
#    'nima': 1}},
#  'du': {'count': {'hōgabēkeṃ': 1,
#    'doḍḍa': 1,
#    'māḍabāra': 1,
#    'oḍe': 1,
#    'nanna': 1,
#    'oṃ': 1,
#    'hau': 1,
#    'hod': 1,
#    'i': 1,
#    'biḍabahu': 1,
#    'hode': 1,
#    'barabahu': 1,
#    'baruvudillaveṃ': 1,
#    'śrēṣṭhaneṃ': 1,
#    'ōdabāra': 1,
#    'māḍabahu': 1,
#    'takka': 1,
#    'eṃbu': 1,
#    'a': 1,
#    'kaṣṭaveṃ': 1,
#    '“i': 1,
#    'kaḷe': 1,
#    'bēkāgiruvu': 1,
#    'bareyuvu': 1,
#    'ai': 1,
#    'māḍuvu': 1,
#    'eṃ': 1,
#    'oḷḷeya': 1}},
#  'dāgi': {'count': {'doḍḍa': 1, 'keṭṭa': 1}},
#  'nannu': {'count': {'maga': 1,
#    'huḍuga': 1,
#    'manuṣya': 1,
#    'nan': 1,
#    'naḍeyuvava': 1}},
#  'nu': {'count': {'maganan': 1,
#    'adan': 1,
#    'māḍiside': 1,
#    'nūran': 1,
#    'avaran': 1,
#    'ōduva': 1,
#    'pustakagaḷan': 1,
#    'māḍida': 1,
#    'doḍḍava': 1,
#    'māḍidava': 1,
#    'tappan': 1,
#    'koṭṭe': 1,
#    'hēḷida': 1,
#    'nōḍuve': 1,
#    'hōda': 1,
#    'yōciside': 1,
#    'biḍuve': 1,
#    'ivaran': 1,
#    'ōduttidde': 1,
#    'patrikegaḷan': 1,
#    'nīvē': 1,
#    'ē': 1,
#    'māḍide': 1,
#    'avaḷan': 1,
#    'ellaran': 1,
#    'huḍuganan': 1,
#    'mātanāḍida': 1,
#    'citragaḷan': 1,
#    'hāḍuve': 1,
#    'hēḷide': 1,
#    'saṃgītavan': 1,
#    'ava': 1,
#    'ōdiruve': 1,
#    'malagide': 1,
#    'manuṣyanan': 1,
#    'tā': 1,
#    'māḍuve': 1,
#    'nannan': 1,
#    'pustakavan': 1,
#    'huḍugaran': 1,
#    'nā': 1,
#    'ōdidde': 1,
#    'vidyārthiyāgiruve': 1,
#    'araḷidudan': 1,
#    'haṇṇugaḷan': 1,
#    'viṣayavan': 1,
#    'naḍeyuvavanan': 1,
#    'patravan': 1,
#    'idan': 1,
#    'kelasavan': 1,
#    'mūran': 1,
#    'nōḍida': 1,
#    'eraḍan': 1,
#    'hūvan': 1,
#    'ōduttiruve': 1,
#    'nōḍide': 1,
#    'koṭṭa': 1,
#    'uḷidavaran': 1,
#    'hōde': 1,
#    'nammavaradan': 1,
#    'ōdibiṭṭe': 1,
#    'baṃdava': 1,
#    'baruttidde': 1}},
#  'nnu': {'count': {'magana': 1,
#    'ada': 1,
#    'nūra': 1,
#    'avara': 1,
#    'pustakava': 1,
#    'nanna': 1,
#    'pustakagaḷa': 1,
#    'tappa': 1,
#    'ivara': 1,
#    'patrikegaḷa': 1,
#    'avaḷa': 1,
#    'ellara': 1,
#    'huḍugana': 1,
#    'citragaḷa': 1,
#    'saṃgītava': 1,
#    'manuṣyana': 1,
#    'huḍugara': 1,
#    'araḷiduda': 1,
#    'haṇṇugaḷa': 1,
#    'viṣayava': 1,
#    'naḍeyuvavana': 1,
#    'patrava': 1,
#    'ida': 1,
#    'kelasava': 1,
#    'mūra': 1,
#    'eraḍa': 1,
#    'hūva': 1,
#    'uḷidavara': 1,
#    'nammavarada': 1}},
#  'ttēne': {'count': {'mugisu': 1,
#    'baru': 1,
#    'māḍu': 1,
#    'hōgu': 1,
#    'kareyu': 1,
#    'tōrisu': 1,
#    'baredukoḍu': 1,
#    'baredukoḷḷu': 1}},
#  '-': {'count': {'vidyārthiyāgiral': 1,
#    'ba': 1,
#    'bare': 1,
#    'vidyārthiyāgiru': 1,
#    'māva': 1,
#    'vidhy': 1}},
#  'de': {'count': {'ōdalāgi': 1,
#    'tōrutta': 1,
#    'sādhyavi': 1,
#    'cennāgi': 1,
#    'i': 1,
#    'barutta': 1,
#    'vikāsagoḷḷutta': 1,
#    'caḷiyāgutta': 1,
#    'taṃ': 1,
#    'bēkāgutta': 1,
#    'māḍalpaḍutta': 1,
#    'muṃ': 1,
#    'bēkāgi': 1,
#    'hiṃ': 1,
#    'beḷedi': 1,
#    'sikki': 1,
#    'hōgi': 1,
#    'āgutta': 1,
#    'elli': 1,
#    'nid': 1,
#    'māḍalāgutta': 1,
#    'kaṣṭavāgi': 1,
#    'ēni': 1,
#    'hēgi': 1}},
#  'ttade': {'count': {'tōru': 1,
#    'baru': 1,
#    'vikāsagoḷḷu': 1,
#    'caḷiyāgu': 1,
#    'bēkāgu': 1,
#    'māḍalpaḍu': 1,
#    'āgu': 1,
#    'māḍalāgu': 1}},
#  'vāgi': {'count': {'krūra': 1, 'suṃdara': 1, 'nija': 1, 'aparūpa': 1}},
#  'ru': {'count': {'jana': 1,
#    'maisū': 1,
#    'purōhita': 1,
#    'māḍida': 1,
#    'hēḷida': 1,
#    'hōda': 1,
#    'paṭṭa': 1,
#    'cikkava': 1,
#    'tammaṃdi': 1,
#    'iva': 1,
#    'huḍuga': 1,
#    'beṃgaḷū': 1,
#    'huḍugiya': 1,
#    'sāvirā': 1,
#    'nūraneyava': 1,
#    'ava': 1,
#    'kā': 1,
#    'kaṭṭida': 1,
#    'nī': 1,
#    'idda': 1,
#    'baṃda': 1,
#    'bareda': 1,
#    'maṃgaḷū': 1,
#    'raita': 1,
#    'kēḷuva': 1,
#    'hattā': 1,
#    'nōḍida': 1,
#    'maneyava': 1,
#    'mū': 1,
#    'hesa': 1,
#    'nūrā': 1,
#    'māḍuvava': 1}},
#  'va': {'count': {'iru': 1,
#    'yā': 1,
#    'māḍu': 1,
#    'naḍeyu': 1,
#    'bareyu': 1,
#    'hēḷu': 1}},
#  'da': {'count': {'kalliniṃ': 1,
#    'māḍi': 1,
#    'viśēṣavā': 1,
#    'mara': 1,
#    'kliṣṭa-v-ā': 1,
#    'avaniṃ': 1,
#    'hō': 1,
#    'maneyoḷaginiṃ': 1,
#    'bare': 1,
#    'ōdi': 1,
#    'nālkariṃ': 1,
#    'araḷi': 1,
#    'pakka': 1,
#    'karnāṭaka': 1,
#    'tiṃ': 1,
#    'baṃ': 1,
#    'haṇavilla': 1,
#    'hēḷi': 1,
#    'dayadiṃ': 1,
#    'tōrisi': 1,
#    'nōḍi': 1,
#    'kiviyiṃ': 1,
#    'ippattariṃ': 1,
#    'suṃdaravā': 1,
#    'kaiyiṃ': 1}},
#  'ṃda': {'count': {'kallini': 1,
#    'ba': 1,
#    'avani': 1,
#    'maneyoḷagini': 1,
#    'nālkari': 1,
#    'ti': 1,
#    'dayadi': 1,
#    'kiviyi': 1,
#    'ippattari': 1,
#    'kaiyi': 1}},
#  'lla': {'count': {'sādhyavi': 1,
#    'māḍi': 1,
#    'cennāgi': 1,
#    'bareyuttali': 1,
#    'pustakava': 1,
#    'iṣṭava': 1,
#    'māḍuvudi': 1,
#    'toḍak-a': 1,
#    'haṇṇugaḷanne': 1,
#    'reyuvudi': 1,
#    'i': 1,
#    'huṣārirali': 1,
#    'mara-v-a': 1,
#    'samācāravi': 1,
#    'mara-v-i': 1,
#    'e': 1,
#    'maragaḷa': 1,
#    'vudi': 1,
#    'huḍugi-y-i': 1,
#    'toḍak-i': 1,
#    'baruvudi': 1,
#    'bareyuvudi': 1,
#    'yuvudi': 1,
#    'barali': 1,
#    'raitana': 1,
#    'marava': 1,
#    'a': 1,
#    'māḍaba': 1,
#    'baredi': 1,
#    'raitara': 1,
#    'gotti': 1,
#    'huḍugi-y-a': 1,
#    'māḍali': 1,
#    'bareyali': 1}},
#  'vā': {'count': {'para': 1, 'pustaka': 1, 'mara': 1, 'atha': 1}},
#  'dalli': {'count': {'māḍi': 1,
#    'sammēḷana': 1,
#    'dēvasthāna': 1,
#    'saṃgrahālaya': 1}},
#  'daru': {'count': {'māḍi': 1,
#    'hō': 1,
#    'bare': 1,
#    'kaṭṭi': 1,
#    'id': 1,
#    'baṃ': 1,
#    'hēḷi': 1,
#    'nōḍi': 1}},
#  'ddēne': {'count': {'māḍi': 1,
#    'cennāgi': 1,
#    'ōdi': 1,
#    'taṃdi': 1,
#    'ōdutti': 1,
#    'hēḷi': 1,
#    'nōḍi': 1,
#    'tegedukoṃḍi': 1,
#    'hōgi': 1,
#    'baṃdi': 1}},
#  'gaḷu': {'count': {'guru': 1,
#    'ārthi': 1,
#    'pustaka': 1,
#    'mara': 1,
#    'mane': 1,
#    'nagara': 1,
#    'haṇṇu': 1,
#    '': 1,
#    'vidyārthi': 1,
#    'sēbu': 1,
#    'koṃbu': 1,
#    'cīla': 1}},
#  'giṃta': {'count': {'rāmani': 1, 'kurci': 1, 'ellari': 1}},
#  'navarē': {'count': {'rāmappa': 1, 'sītamma': 1, 'rāmayya': 1}},
#  'valla': {'count': {'pustaka': 1, 'mara': 1, 'iṣṭa': 1}},
#  'gaḷannu': {'count': {'pustaka': 1, 'patrike': 1, 'haṇṇu': 1, 'citra': 1}},
#  'vannu': {'count': {'pustaka': 1,
#    'saṃgīta': 1,
#    'viṣaya': 1,
#    'patra': 1,
#    'kelasa': 1,
#    'hū': 1}},
#  'ya': {'count': {'haḷe': 1,
#    'mane': 1,
#    'sama': 1,
#    'manuṣ': 1,
#    'viṣa': 1,
#    'asādh': 1,
#    'sādh': 1,
#    'bhāṣe': 1}},
#  'ttāne': {'count': {'baru': 1,
#    'ōdu': 1,
#    'hōgu': 1,
#    'hoḍeyu': 1,
#    'saṃkōcapaḍisu': 1}},
#  'vudilla': {'count': {'baru': 1,
#    'māḍu': 1,
#    'reyu': 1,
#    '': 1,
#    'bareyu': 1,
#    'yu': 1}},
#  'ttiddenu': {'count': {'baru': 1, 'ōdu': 1}},
#  'vāgali': {'count': {'śukravāra': 1, 'guruvāra': 1}},
#  'venu': {'count': {'māḍu': 1,
#    'nōḍu': 1,
#    'biḍu': 1,
#    'vidyārthiyāgiru': 1,
#    'hāḍu': 1,
#    'ōdiru': 1,
#    'ōduttiru': 1}},
#  'varu': {'count': {'cikka': 1,
#    'i': 1,
#    'nūraneya': 1,
#    'a': 1,
#    'kēḷu': 1,
#    'maneya': 1,
#    'māḍuva': 1}},
#  'yalu': {'count': {'bare': 1, 'kali': 1}},
#  'yuva': {'count': {'bare': 1, 'naḍe': 1}},
#  'ttīri': {'count': {'hōgu': 1, 'tagoḷḷu': 1}},
#  'nige': {'count': {'huḍuga': 1, 'manuṣya': 1, 'ava': 1}},
#  'villa': {'count': {'samācāra': 1, 'sādhya': 1}},
#  'yā': {'count': {'baruttade': 1,
#    'vidyārthi': 1,
#    'vidyārthini': 1,
#    'tiḷidukoṃḍiddī': 1}},
#  'yiṃda': {'count': {'kivi': 1, 'kai': 1}}}

# %%
from collections import Counter

# Go through the results again, word by word, and check if the word has a stem with a suffix

for result in results:
    sentence, translated_sentence, pos_info = result
    transliterations = sentence.split()
    
    # Convert pos_info.items() to a list to support indexing
    pos_items = list(pos_info.items())
    
    for i,(word, info) in enumerate(pos_items):
        if info['affix'] is not None:
            prefix = info['affix']['prefix']
            suffix = info['affix']['suffix']
            
            # Check if the suffix is in the productive suffixes
            if suffix in productive_suffixes:
                # Add POS tag for the stem, POS tag for the previous word and POS tag for the next word into suffix_info[suffix]
                stem = word[:-len(suffix)] if len(suffix) > 0 else word
                
                # Get POS tags
                stem_pos = info.get('pos', [])
                prev_pos = pos_items[i-1][1].get('pos', []) if i > 0 else ['<BOS>']  # Beginning of sentence
                next_pos = pos_items[i+1][1].get('pos', []) if i < len(pos_items)-1 else ['<EOS>']  # End of sentence
                
                # Get translation tokens if available
                trans_tokens = []
                if translated_sentence:
                    trans_tokens = translated_sentence.lower().split()
                
                # Initialize or update the add_info stats for this suffix
                if suffix not in suffix_info:
                    suffix_info[suffix] = {
                        'count': defaultdict(int),
                        'stats': {
                            'stem_pos': Counter(),  # POS tags of stems
                            'pos_before': Counter(),  # POS tags of words before
                            'pos_after': Counter(),  # POS tags of words after
                            'trans_tokens': Counter(),  # Translation tokens
                            'lemma_set': set()  # Set of unique translations
                        }
                    }
                
                # Update statistics
                suffix_info[suffix]['count'][stem] += 1
                
                # Update POS tag counts
                if 'stats' not in suffix_info[suffix]:
                    suffix_info[suffix]['stats'] = {
                        'stem_pos': Counter(),
                        'pos_before': Counter(),
                        'pos_after': Counter(), 
                    }
                if stem_pos:
                    suffix_info[suffix]['stats']['stem_pos'].update(stem_pos)
                for pos in prev_pos:
                    suffix_info[suffix]['stats']['pos_before'][pos] += 1
                for pos in next_pos:
                    suffix_info[suffix]['stats']['pos_after'][pos] += 1

                # Update translation tokens
                if translated_sentence:  # Only add translation tokens if we have a translated sentence
                    suffix_info[suffix]['stats']['trans_tokens'].update(trans_tokens)
                # Add translation to lemma set if available
                if info.get('translation'):
                    suffix_info[suffix]['stats']['lemma_set'].add(info['translation'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[141], line 64
#      62 # Update translation tokens
#      63 if translated_sentence:  # Only add translation tokens if we have a translated sentence
# ---> 64     suffix_info[suffix]['stats']['trans_tokens'].update(trans_tokens)
#      65 # Add translation to lemma set if available
#      66 if info.get('translation'):
#
# KeyError: 'trans_tokens'

# %%
# PRINT
for suffix, info in suffix_info.items():
    print(f"Suffix: {suffix}")
    print(f"  Count: {len(info['count'])} stems")
    #for stem, count in info['count'].items():
    #
    #     print(f"  Stem: {stem}, Count: {count}")
    if "add_info" in info:
        add_info = info["add_info"]
        print(f"  Stem: {add_info['stem']}, POS: {add_info['pos']}, Previous POS: {add_info['prev_pos']}, Next POS: {add_info['next_pos']}")
    print("=========================================")
# Out:
# Suffix: ge
#   Count: 24 stems
#   Stem: mane, POS: ['NOUN'], Previous POS: None, Next POS: ['PART', 'VERB']
# =========================================
# Suffix: du
#   Count: 28 stems
#   Stem: nanna, POS: ['PRON'], Previous POS: None, Next POS: ['ADJ', 'NOUN']
# =========================================
# Suffix: dāgi
#   Count: 2 stems
#   Stem: keṭṭa, POS: ['ADJ'], Previous POS: ['NOUN'], Next POS: None
# =========================================
# Suffix: nannu
#   Count: 5 stems
#   Stem: maga, POS: ['NOUN'], Previous POS: ['PROPN'], Next POS: None
# =========================================
# Suffix: nu
#   Count: 63 stems
# =========================================
# Suffix: nnu
#   Count: 29 stems
#   Stem: ellara, POS: ['PUNCT', 'ADJ', 'PUNCT'], Previous POS: ['PRON'], Next POS: None
# =========================================
# Suffix: ttēne
#   Count: 8 stems
# =========================================
# Suffix: -
#   Count: 6 stems
#   Stem: māva, POS: ['NOUN'], Previous POS: ['X', 'PUNCT', 'PRON', 'AUX', 'PART', 'VERB'], Next POS: None
# =========================================
# Suffix: de
#   Count: 24 stems
#   Stem: hōgi, POS: ['PUNCT', 'NOUN', 'PUNCT'], Previous POS: None, Next POS: None
# =========================================
# Suffix: ttade
#   Count: 8 stems
# =========================================
# Suffix: vāgi
#   Count: 4 stems
#   Stem: suṃdara, POS: ['ADJ'], Previous POS: ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'], Next POS: None
# =========================================
# Suffix: ru
#   Count: 32 stems
#   Stem: jana, POS: ['NOUN'], Previous POS: ['PART', 'AUX'], Next POS: None
# =========================================
# Suffix: va
#   Count: 6 stems
# =========================================
# Suffix: da
#   Count: 25 stems
#   Stem: mara, POS: ['NOUN'], Previous POS: None, Next POS: ['ADP']
# =========================================
# Suffix: ṃda
#   Count: 10 stems
# =========================================
# Suffix: lla
#   Count: 34 stems
# =========================================
# Suffix: vā
#   Count: 4 stems
#   Stem: mara, POS: ['NOUN'], Previous POS: ['PRON', 'PUNCT', 'PRON'], Next POS: None
# =========================================
# Suffix: dalli
#   Count: 4 stems
#   Stem: saṃgrahālaya, POS: ['NOUN'], Previous POS: None, Next POS: ['NUM']
# =========================================
# Suffix: daru
#   Count: 8 stems
# =========================================
# Suffix: ddēne
#   Count: 10 stems
#   Stem: hōgi, POS: ['PUNCT', 'NOUN', 'PUNCT'], Previous POS: ['PRON'], Next POS: None
# =========================================
# Suffix: gaḷu
#   Count: 12 stems
#   Stem: pustaka, POS: ['NOUN'], Previous POS: None, Next POS: None
# =========================================
# Suffix: giṃta
#   Count: 3 stems
#   Stem: kurci, POS: ['NOUN'], Previous POS: None, Next POS: ['PRON', 'PUNCT', 'PRON']
# =========================================
# Suffix: navarē
#   Count: 3 stems
# =========================================
# Suffix: valla
#   Count: 3 stems
#   Stem: mara, POS: ['NOUN'], Previous POS: ['PRON', 'PUNCT', 'PRON'], Next POS: None
# =========================================
# Suffix: gaḷannu
#   Count: 4 stems
#   Stem: pustaka, POS: ['NOUN'], Previous POS: None, Next POS: None
# =========================================
# Suffix: vannu
#   Count: 6 stems
#   Stem: pustaka, POS: ['NOUN'], Previous POS: None, Next POS: None
# =========================================
# Suffix: ya
#   Count: 8 stems
#   Stem: mane, POS: ['NOUN'], Previous POS: None, Next POS: ['ADV', 'PUNCT', 'NOUN']
# =========================================
# Suffix: ttāne
#   Count: 5 stems
# =========================================
# Suffix: vudilla
#   Count: 6 stems
# =========================================
# Suffix: ttiddenu
#   Count: 2 stems
# =========================================
# Suffix: vāgali
#   Count: 2 stems
#   Stem: śukravāra, POS: ['PROPN'], Previous POS: ['PROPN'], Next POS: ['INTJ', 'VERB']
# =========================================
# Suffix: venu
#   Count: 7 stems
#   Stem: hāḍu, POS: ['NOUN'], Previous POS: ['PRON'], Next POS: None
# =========================================
# Suffix: varu
#   Count: 7 stems
#   Stem: cikka, POS: ['ADJ'], Previous POS: ['PROPN'], Next POS: None
# =========================================
# Suffix: yalu
#   Count: 2 stems
# =========================================
# Suffix: yuva
#   Count: 2 stems
# =========================================
# Suffix: ttīri
#   Count: 2 stems
# =========================================
# Suffix: nige
#   Count: 3 stems
#   Stem: manuṣya, POS: ['NOUN'], Previous POS: None, Next POS: ['NOUN']
# =========================================
# Suffix: villa
#   Count: 2 stems
#   Stem: sādhya, POS: ['ADJ'], Previous POS: None, Next POS: None
# =========================================
# Suffix: yā
#   Count: 4 stems
# =========================================
# Suffix: yiṃda
#   Count: 2 stems
#   Stem: kivi, POS: ['NOUN'], Previous POS: ['PRON', 'PUNCT', 'NOUN', 'PUNCT'], Next POS: ['PART', 'VERB', 'PUNCT', 'PART', 'VERB']
# =========================================
