# %%
import numpy as np
import pandas as pd
import json 
import os

from tqdm import tqdm

# %%
with open("parallel_sentences_cleaned.json","r",encoding="utf-8") as f:
    data = json.load(f)

print(data[0])
# Out:
# {'kannada': 'ಹುĪ', 'transliteration': 'huḷi', 'english': 'sour', 'page': 31, 'block_start': 6, 'block_end': 6}

# %%
eng_1word = {}
kannada_1word = {}
other_sentences = []

for item in data:
    eng_words = item['english'].split()
    kannada_words = item['transliteration'].split()
    
    # Check if English is 1 word
    if len(eng_words) == 1:
        eng_1word[item['transliteration']] = item['english']
    # Check if Kannada is 1 word but English is not
    elif len(kannada_words) == 1 and len(eng_words) > 1:
        kannada_1word[item['transliteration']] = item['english']
    # Everything else
    else:
        other_sentences.append({
            'transliteration': item['transliteration'],
            'english': item['english']
        })

print(f"Number of 1-word English sentences: {len(eng_1word)}")
print(f"Number of 1-word Kannada sentences: {len(kannada_1word)}")
print(f"Number of other sentences: {len(other_sentences)}")
# Out:
# Number of 1-word English sentences: 413
# Number of 1-word Kannada sentences: 396
# Number of other sentences: 393

# %%
# Display the first 10 sentences of 1 word english
# Display first 10 items from eng_1word dictionary
for i, (kannada, english) in enumerate(list(eng_1word.items())[:10]):
    print(f"{i+1}. Kannada: {kannada} -> English: {english}")
# Out:
# 1. Kannada: huḷi -> English: sour
# 2. Kannada: huli -> English: tiger
# 3. Kannada: haḷḷi -> English: village
# 4. Kannada: halli -> English: lizard
# 5. Kannada: maṇe -> English: stool
# 6. Kannada: mane -> English: house
# 7. Kannada: hālu -> English: milk
# 8. Kannada: hallu -> English: tooth
# 9. Kannada: dēva -> English: god
# 10. Kannada: devva -> English: spirit

# %%
# Display first 10 items from kannada_1word dictionary
for i, (kannada, english) in enumerate(list(kannada_1word.items())[:10]):
    print(f"{i+1}. Kannada: {kannada} -> English: {english}")
# Out:
# 1. Kannada: ōḍu -> English: to run
# 2. Kannada: ōdu -> English: to read
# 3. Kannada: hēḷu -> English: to say
# 4. Kannada: hēlu -> English: to shit
# 5. Kannada: baḍi -> English: to beat
# 6. Kannada: baḍḍi -> English: interest (on money)
# 7. Kannada: maḍi -> English: ritually pure
# 8. Kannada: māḍi -> English: please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:
# 9. Kannada: nīnu -> English: you (singular and non-honorific)
# 10. Kannada: nīvu -> English: you (plural / honorific)

# %%
# POS Tagging
import spacy
nlp = spacy.load("en_core_web_sm")

def pos_tagging(sentences):
    pos_tags = []
    for sentence in tqdm(sentences):
        doc = nlp(sentence)
        tags = [(token.text, token.pos_) for token in doc]
        pos_tags.append(tags)
    return pos_tags

# %%
# POS tagging for English words in eng_1word
eng_1word_sentences = list(eng_1word.values())
eng_1word_transliterations = list(eng_1word.keys())
eng_pos_tags = pos_tagging(eng_1word_sentences)
# Out:
# 100%|██████████| 413/413 [00:01<00:00, 287.64it/s]

# %%
# Show all POS tags for the first 10 sentences
for i, tags in enumerate(eng_pos_tags[:100]):
    for word, pos in tags:
        print(f"{word} ({eng_1word_transliterations[i]}): {pos}")
# Out:
# sour (huḷi): ADJ
# tiger (huli): NOUN
# village (haḷḷi): NOUN
# lizard (halli): NOUN
# stool (maṇe): PROPN
# house (mane): NOUN
# milk (hālu): NOUN
# tooth (hallu): VERB
# god (dēva): PROPN
# spirit (devva): PROPN
# I (nānu): PRON
# we (nāvu): PRON
# he (avanu): PRON
# she (avaḷu): PRON
# he (ivanu): PRON
# she (ivaḷu): PRON
# here (illi): ADV
# there (alli): ADV
# where (elli): SCONJ
# ? (elli): PUNCT
# now (īga): ADV
# then (āga): ADV
# that (adu): PRON
# closet (almāri): NOUN
# sky (ākāśa): NOUN
# this (idu): PRON
# another (innoṃdu): PRON
# today (ivattu): NOUN
# meal (ūṭa): NOUN
# town (ūru): NOUN
# two (eraḍu): NUM
# five (aidu): NUM
# one (oṃdu): NUM
# computer (kaṃpyūṭaru): NOUN
# building (kaṭṭaḍa): VERB
# paper (kāgada): NOUN
# forest (kāḍu): NOUN
# car (kāru): NOUN
# window (kiṭaki): NOUN
# chair (kurci): NOUN
# glass (gilāsu): NOUN
# goal (guri): NOUN
# teacher (guru): NOUN
# Thursday (guruvāra): PROPN
# spoon (camaca): VERB
# knife (cāku): NOUN
# mat (cāpe): NOUN
# key (cāvi): ADJ
# picture (citra): NOUN
# taxi (ṭyāksi): NOUN
# tubelight (ṭyūbulaiṭu): NOUN
# plate (taṭṭe): NOUN
# many (tuṃba): ADJ
# lamp (dīpa): PROPN
# temple (dēvasthāna): PROPN
# four (nālku): NUM
# tomorrow (nāḷe): NOUN
# floor (nela): NOUN
# fly (noṇa): VERB
# book (pustaka): NOUN
# pencil (pensilu): NOUN
# foreigner (phorenar): NOUN
# fork (phōrku): NOUN
# door (bāgilu): NOUN
# Wednesday (budhavāra): PROPN
# fire (beṃki): NOUN
# fence (bēli): NOUN
# Indian (bhāratīya): ADJ
# Tuesday (maṃgaḷavāra): PROPN
# and (mattu): CCONJ
# person (manuṣya): NOUN
# tree (mara): NOUN
# lady (mahiḷe): PROPN
# rain (maḷe): NOUN
# garland (māle): VERB
# three (mūru): NUM
# table (mēju): NOUN
# candle (mēṇabatti): NOUN
# cloud (mōḍa): PROPN
# Sunday (ravivāra): PROPN
# road (raste): NOUN
# rikshaw (rikṣā): NOUN
# airplane (vimāna): NOUN
# Saturday (śanivāra): PROPN
# Friday (śukravāra): PROPN
# suitcase (sūṭkēsu): NOUN
# sun (sūrya): PROPN
# Monday (sōmavāra): PROPN
# woman (strī): NOUN
# bird (hakki): NOUN
# many (halavu): ADJ
# cow (hasu): NOUN
# song (hāḍu): NOUN
# hippie (hippi): VERB
# boy (huḍuga): PROPN
# girl (huḍugi): NOUN
# flower (hū): NOUN
# woman (heṃgasu): NOUN
# field (hola): NOUN
# yes (haudu): INTJ
# never (yāvāgalū illa): ADV

# %%
# map the transliterations to the POS tags 
pos_mapping = {}
for i, tags in enumerate(eng_pos_tags):
    transliteration = eng_1word_transliterations[i]
    pos_mapping[transliteration] = [pos for word, pos in tags]

pos_mapping
# Out:
# {'huḷi': ['ADJ'],
#  'huli': ['NOUN'],
#  'haḷḷi': ['NOUN'],
#  'halli': ['NOUN'],
#  'maṇe': ['PROPN'],
#  'mane': ['NOUN'],
#  'hālu': ['NOUN'],
#  'hallu': ['VERB'],
#  'dēva': ['PROPN'],
#  'devva': ['PROPN'],
#  'nānu': ['PRON'],
#  'nāvu': ['PRON'],
#  'avanu': ['PRON'],
#  'avaḷu': ['PRON'],
#  'ivanu': ['PRON'],
#  'ivaḷu': ['PRON'],
#  'illi': ['ADV'],
#  'alli': ['ADV'],
#  'elli': ['SCONJ', 'PUNCT'],
#  'īga': ['ADV'],
#  'āga': ['ADV'],
#  'adu': ['PRON'],
#  'almāri': ['NOUN'],
#  'ākāśa': ['NOUN'],
#  'idu': ['PRON'],
#  'innoṃdu': ['PRON'],
#  'ivattu': ['NOUN'],
#  'ūṭa': ['NOUN'],
#  'ūru': ['NOUN'],
#  'eraḍu': ['NUM'],
#  'aidu': ['NUM'],
#  'oṃdu': ['NUM'],
#  'kaṃpyūṭaru': ['NOUN'],
#  'kaṭṭaḍa': ['VERB'],
#  'kāgada': ['NOUN'],
#  'kāḍu': ['NOUN'],
#  'kāru': ['NOUN'],
#  'kiṭaki': ['NOUN'],
#  'kurci': ['NOUN'],
#  'gilāsu': ['NOUN'],
#  'guri': ['NOUN'],
#  'guru': ['NOUN'],
#  'guruvāra': ['PROPN'],
#  'camaca': ['VERB'],
#  'cāku': ['NOUN'],
#  'cāpe': ['NOUN'],
#  'cāvi': ['ADJ'],
#  'citra': ['NOUN'],
#  'ṭyāksi': ['NOUN'],
#  'ṭyūbulaiṭu': ['NOUN'],
#  'taṭṭe': ['NOUN'],
#  'tuṃba': ['ADJ'],
#  'dīpa': ['PROPN'],
#  'dēvasthāna': ['PROPN'],
#  'nālku': ['NUM'],
#  'nāḷe': ['NOUN'],
#  'nela': ['NOUN'],
#  'noṇa': ['VERB'],
#  'pustaka': ['NOUN'],
#  'pensilu': ['NOUN'],
#  'phorenar': ['NOUN'],
#  'phōrku': ['NOUN'],
#  'bāgilu': ['NOUN'],
#  'budhavāra': ['PROPN'],
#  'beṃki': ['NOUN'],
#  'bēli': ['NOUN'],
#  'bhāratīya': ['ADJ'],
#  'maṃgaḷavāra': ['PROPN'],
#  'mattu': ['CCONJ'],
#  'manuṣya': ['NOUN'],
#  'mara': ['NOUN'],
#  'mahiḷe': ['PROPN'],
#  'maḷe': ['NOUN'],
#  'māle': ['VERB'],
#  'mūru': ['NUM'],
#  'mēju': ['NOUN'],
#  'mēṇabatti': ['NOUN'],
#  'mōḍa': ['PROPN'],
#  'ravivāra': ['PROPN'],
#  'raste': ['NOUN'],
#  'rikṣā': ['NOUN'],
#  'vimāna': ['NOUN'],
#  'śanivāra': ['PROPN'],
#  'śukravāra': ['PROPN'],
#  'sūṭkēsu': ['NOUN'],
#  'sūrya': ['PROPN'],
#  'sōmavāra': ['PROPN'],
#  'strī': ['NOUN'],
#  'hakki': ['NOUN'],
#  'halavu': ['ADJ'],
#  'hasu': ['NOUN'],
#  'hāḍu': ['NOUN'],
#  'hippi': ['VERB'],
#  'huḍuga': ['PROPN'],
#  'huḍugi': ['NOUN'],
#  'hū': ['NOUN'],
#  'heṃgasu': ['NOUN'],
#  'hola': ['NOUN'],
#  'haudu': ['INTJ'],
#  'yāvāgalū illa': ['ADV'],
#  'ēnū illa': ['PRON'],
#  'yārū illa': ['PRON'],
#  'ide': ['AUX'],
#  'ēke': ['SCONJ', 'PUNCT'],
#  'ēnu': ['PRON', 'PUNCT'],
#  'kappu': ['ADJ'],
#  'kaṣṭa': ['ADJ'],
#  'toḍaku': ['NOUN'],
#  'nanna': ['PRON'],
#  'namma': ['PRON'],
#  'patra': ['NOUN'],
#  'purōhita': ['NOUN'],
#  'biḷi': ['PROPN'],
#  'maneyavaru': ['NOUN'],
#  'yāru': ['PRON', 'PUNCT'],
#  'yāva': ['PRON', 'PUNCT'],
#  'yāvāga': ['SCONJ', 'PUNCT'],
#  'samācāra': ['NOUN'],
#  'hesaru': ['NOUN'],
#  'hēge': ['SCONJ', 'PUNCT'],
#  'appa': ['PROPN'],
#  'amma': ['NOUN'],
#  'kaṇṇu': ['NOUN'],
#  'kivi': ['NOUN'],
#  'kuri': ['NOUN'],
#  'kūsu': ['NOUN'],
#  'gaṃḍa': ['NOUN'],
#  'gaṃḍasu': ['NOUN'],
#  'nighaṃṭu': ['PROPN'],
#  'nīru': ['NOUN'],
#  'buṭṭi': ['NOUN'],
#  'maga': ['NOUN'],
#  'magaḷu': ['NOUN'],
#  'magu': ['NOUN'],
#  'māva': ['NOUN'],
#  'rāja': ['NOUN'],
#  'raita': ['NOUN'],
#  'vidhave': ['NOUN'],
#  'anubhava': ['VERB'],
#  'āṭike': ['NOUN'],
#  'āyke': ['NOUN'],
#  'keṃpu': ['PROPN'],
#  'koṃbu': ['NOUN'],
#  'koṃbe': ['NOUN'],
#  'cūpu': ['ADJ'],
#  'tudi': ['NOUN'],
#  'parimāṇa': ['NOUN'],
#  'baṭṭe': ['NOUN'],
#  'baṇṇa': ['NOUN'],
#  'bēre': ['ADJ'],
#  'saṃkhye': ['NOUN'],
#  'hasiru': ['ADJ'],
#  'haḷadi': ['ADJ'],
#  'heṃḍati': ['NOUN'],
#  'nidde': ['NOUN'],
#  'nāyi': ['NOUN'],
#  'kathe': ['NOUN'],
#  'kelasa': ['NOUN'],
#  'toṃdare': ['NOUN'],
#  'nenne': ['NOUN'],
#  'satya': ['NOUN'],
#  'haṇa': ['NOUN'],
#  'haṇṇu': ['NOUN'],
#  'mēle': ['ADP'],
#  'keḷage': ['ADP'],
#  'oḷage': ['ADP'],
#  'oḷagu': ['ADP'],
#  'hattira': ['ADP'],
#  'bage': ['VERB'],
#  'madhya': ['ADJ'],
#  'muṃde': ['ADP'],
#  'horage': ['ADV'],
#  'aḍige': ['VERB'],
#  'uttara': ['NOUN'],
#  'kāpi': ['NOUN'],
#  'gaḍi': ['NOUN'],
#  'cahā': ['NOUN'],
#  'padārtha': ['NOUN'],
#  'pavāḍa': ['NOUN'],
#  'viśēṣavāda': ['ADJ'],
#  'vaiṣṇava': ['PROPN'],
#  'samādhi': ['NOUN'],
#  'ele': ['VERB'],
#  'athavā': ['CCONJ'],
#  'abhiprāya': ['NOUN'],
#  'iḍiya': ['ADJ'],
#  'upayukta': ['ADJ'],
#  'keṭṭa': ['ADJ'],
#  'kliṣṭa': ['VERB'],
#  'gaddala': ['NOUN'],
#  'cakravarti': ['NOUN'],
#  'cikka': ['ADJ'],
#  'jagattu': ['NOUN'],
#  'dūra': ['NOUN'],
#  'nīli': ['ADJ'],
#  'praśne': ['NOUN'],
#  'bīdi': ['PROPN'],
#  'bhāra': ['NOUN'],
#  'bhārata': ['PROPN'],
#  'mukhya': ['ADJ'],
#  'yuga': ['NOUN'],
#  'saṃgīta': ['NOUN'],
#  'suṃdara': ['ADJ'],
#  'kelavu': ['PRON'],
#  'kōlu': ['VERB'],
#  'ciṃtaka': ['NOUN'],
#  'tīra': ['PROPN'],
#  'bhakta': ['NOUN'],
#  'maṭha': ['VERB'],
#  'Madhvācārya': ['PUNCT', 'NOUN', 'PUNCT'],
#  'śatamāna': ['NOUN'],
#  'saṃpradāya': ['NOUN'],
#  'hadimūraneya': ['NOUN'],
#  'āphisu': ['NOUN'],
#  'oraṭu': ['NOUN'],
#  'krūra': ['ADJ'],
#  'khuśi': ['NOUN'],
#  'tiṃgaḷu': ['NOUN'],
#  'dayaviṭṭu': ['INTJ'],
#  'pāṭha': ['NOUN'],
#  'prayatna': ['NOUN'],
#  'muṃdina': ['ADV'],
#  'yōcane': ['VERB'],
#  'vākya': ['VERB'],
#  'śabda': ['NOUN'],
#  'saṃtōṣa': ['NOUN'],
#  'sammēḷana': ['NOUN'],
#  'spaṣṭa': ['ADJ'],
#  'artha': ['VERB'],
#  'ādare': ['CCONJ'],
#  'kṣame': ['NOUN'],
#  'daya': ['NOUN'],
#  'hōṭalu': ['NOUN'],
#  'adhyāpaka': ['NOUN'],
#  'kōpa': ['NOUN'],
#  'graṃthapālaka': ['PROPN'],
#  'graṃthālaya': ['NOUN'],
#  'patrike': ['NOUN'],
#  'sahāya': ['VERB'],
#  'hemme': ['NOUN'],
#  'hōguvike': ['VERB'],
#  'bāḷike': ['VERB'],
#  'ārōgya': ['NOUN'],
#  'gōḍe': ['NOUN'],
#  'gōva': ['PROPN'],
#  'jōru': ['NOUN'],
#  'tinnu': ['VERB'],
#  'māṃsa': ['NOUN'],
#  'miliṭari': ['NOUN'],
#  'miliṭari hōṭalu': ['ADJ', 'ADJ', 'NOUN'],
#  'auṣadhi': ['NOUN'],
#  'kaṭṭe': ['VERB'],
#  'giḍa': ['NOUN'],
#  'dēvi': ['NOUN'],
#  'patni': ['NOUN'],
#  'pradakṣiṇe': ['NOUN'],
#  'bhakti': ['NOUN'],
#  'mātra': ['ADV'],
#  'saṃpattu': ['NOUN'],
#  'sādhya': ['ADJ'],
#  'sulabha': ['ADJ'],
#  'saubhāgya': ['ADV', 'PUNCT', 'NOUN'],
#  'atṛpta': ['ADJ'],
#  'atṛpti': ['NOUN'],
#  'anubhāvi': ['ADJ'],
#  'anuyāyi': ['NOUN'],
#  'asamānate': ['NOUN'],
#  'ityādi': ['X', 'X'],
#  'kuṭuṃba': ['NOUN'],
#  'kelavomme': ['ADV'],
#  'guṃpu': ['NOUN'],
#  'jāti': ['NOUN'],
#  'jīvana': ['NOUN'],
#  'tṛpta': ['ADJ'],
#  'tṛpti': ['NOUN'],
#  'dhārmika': ['ADJ'],
#  'naitika': ['ADJ'],
#  'paraṃpare': ['NOUN'],
#  'prapaṃca': ['NOUN'],
#  'prācīna': ['ADJ'],
#  'prīti': ['NOUN'],
#  'Basava': ['PUNCT', 'NOUN', 'PUNCT'],
#  'beḷavaṇige': ['NOUN'],
#  'maṃdi': ['NOUN'],
#  'manassu': ['NOUN'],
#  'samāna': ['ADJ'],
#  'samānate': ['NOUN'],
#  'sāmājika': ['ADJ'],
#  'hiṃde': ['ADP'],
#  'hinnele': ['NOUN'],
#  'hosa': ['ADJ'],
#  'anēka': ['ADJ'],
#  'ippataidu': ['NUM', 'PUNCT', 'NUM'],
#  'ēkeṃdare': ['SCONJ'],
#  'omme': ['ADV'],
#  'karāvaḷi': ['PROPN'],
#  'kaḷatmaka': ['ADJ'],
#  'kāphi': ['NOUN'],
#  'kāryakrama': ['NOUN'],
#  'kuḍuma': ['PUNCT', 'NOUN', 'PUNCT'],
#  'kēṃdra': ['NOUN'],
#  'caḷi': ['ADJ'],
#  'cikitsālaya': ['NOUN'],
#  'jille': ['NOUN'],
#  'taṃde': ['PROPN'],
#  'takṣaṇa': ['ADV'],
#  'tale': ['NOUN'],
#  'talenōvu': ['PROPN'],
#  'dēvate': ['NOUN'],
#  'Dharmasthaḷa': ['PUNCT', 'NOUN', 'PUNCT'],
#  'nōvu': ['NOUN'],
#  'paṃḍita': ['NOUN'],
#  'pūrvaja': ['NOUN'],
#  'Maṃjunātha': ['PUNCT', 'NOUN', 'PUNCT'],
#  'yātrika': ['NOUN'],
#  'rakṣaṇe': ['NOUN'],
#  'varegū': ['ADP'],
#  'varṣa': ['NOUN'],
#  'Vādirāja': ['PUNCT', 'NOUN', 'PUNCT'],
#  'śikṣaka': ['NOUN'],
#  'saṃgrahālaya': ['NOUN'],
#  'sahiṣṇute': ['NOUN'],
#  'sāṃskṛtika': ['ADJ'],
#  'sāvira': ['NUM'],
#  'sāvirāru': ['NOUN'],
#  'sumāru': ['ADV'],
#  'hadināraneya': ['ADJ'],
#  'huṣāru': ['NOUN'],
#  'ellarannu / ellarannū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellariṃda / ellariṃdalū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellara': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellaralli / ellarallū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'āru': ['NUM'],
#  'ēḷu': ['NUM'],
#  'eṃṭu': ['NUM'],
#  'oṃbattu': ['NUM'],
#  'hannoṃdu': ['NUM'],
#  'hanneraḍu': ['NUM'],
#  'hadimūru': ['NUM'],
#  'hadinālku': ['NUM'],
#  'hadinaidu': ['NUM'],
#  'hadināru': ['NUM'],
#  'hadinēḷu': ['X'],
#  'hadineṃṭu': ['NUM'],
#  'hattoṃbattu': ['NUM'],
#  'ippattu': ['NUM'],
#  'ippattoṃdu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteraḍu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattanālku': ['NUM', 'PUNCT', 'NUM'],
#  'ippattaidu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattāru': ['NUM', 'PUNCT', 'NUM'],
#  'ippattēḷu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteṃṭu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattoṃbattu': ['NUM', 'PUNCT', 'NUM'],
#  'aivattu': ['NUM'],
#  'aravattu': ['NUM'],
#  'eppattu': ['NUM'],
#  'eṃbattu': ['NUM'],
#  'toṃbattu': ['NUM'],
#  'nūru': ['NUM'],
#  'innūru': ['NUM'],
#  'munnūru': ['NUM'],
#  'nānūru': ['NUM'],
#  'ainūru': ['NUM'],
#  'ārunūru': ['NUM'],
#  'ēḷunūru': ['NUM'],
#  'eṃṭunūru': ['NUM'],
#  'oṃbainūru': ['NUM'],
#  'nūra nalvattoṃdu': ['NUM'],
#  'sāvirada oṃbainūra toṃbattaidu': ['NUM'],
#  'āgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'hōgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'utkhanana': ['NOUN'],
#  'hagga': ['NOUN'],
#  'heccu': ['ADV'],
#  'ajja': ['NOUN'],
#  'jñāna': ['NOUN'],
#  'daḍḍa': ['NOUN'],
#  'kobbu': ['ADJ'],
#  'udbhava': ['NOUN'],
#  'ayya': ['PROPN'],
#  'prabhāva': ['NOUN'],
#  'tatva': ['NOUN'],
#  'utsava': ['NOUN'],
#  'kaḷḷa': ['NOUN'],
#  'aparūpavāgi': ['ADV'],
#  'jana': ['NOUN'],
#  'bahaḷa': ['ADJ'],
#  'bhāṣe': ['NOUN'],
#  'yāvāgalū': ['ADV'],
#  'haḷeya': ['ADJ'],
#  'aṃgaḍiyavaru': ['NOUN'],
#  'ajñāna': ['NOUN'],
#  'gottu': ['NOUN'],
#  'nṛtya': ['VERB'],
#  'paravā': ['VERB'],
#  'parvata': ['NOUN'],
#  'baḷi': ['ADP'],
#  'buddhi': ['NOUN'],
#  'beḷaku': ['ADJ'],
#  'bhasma': ['PROPN'],
#  'majjige': ['NOUN'],
#  'mūgu': ['NOUN'],
#  'modalaneya': ['ADV'],
#  'rākṣasa': ['NOUN'],
#  'rūpa': ['VERB'],
#  'vimānanildāṇa': ['NOUN'],
#  'vaiṣṇavadharma': ['NOUN'],
#  'saṃkēta': ['NOUN'],
#  'saṃsthe': ['PROPN'],
#  'sāṃkētika': ['ADJ'],
#  'sāmānya': ['ADJ'],
#  'haṇe': ['PROPN']}

# %%
kan_to_eng_mapping = {}
for transliteration, english in kannada_1word.items():
    kan_to_eng_mapping[transliteration] = english

for transliteration, english in eng_1word.items():
    if transliteration not in kan_to_eng_mapping:
        kan_to_eng_mapping[transliteration] = english

kan_to_eng_mapping
# Out:
# {'ōḍu': 'to run',
#  'ōdu': 'to read',
#  'hēḷu': 'to say',
#  'hēlu': 'to shit',
#  'baḍi': 'to beat',
#  'baḍḍi': 'interest (on money)',
#  'maḍi': 'ritually pure',
#  'māḍi': 'please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:',
#  'nīnu': 'you (singular and non-honorific)',
#  'nīvu': 'you (plural / honorific)',
#  'adu': 'it / that',
#  'avaru': 'they (persons)',
#  'avu': 'they (non-persons)',
#  'idu': 'it / this',
#  'ivaru': 'he / she (honorific)',
#  'ivu': 'they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.)',
#  'hīge': 'in this manner',
#  'hāge': 'in that manner',
#  'hēge': 'in which manner?',
#  'iṣṭu': 'this much',
#  'aṣṭu': 'that much',
#  'eṣṭu': 'how much?',
#  'ide': 'it is, it exists',
#  'ili': 'mouse, rat',
#  'kālu': 'leg, foot',
#  'kai': 'hand, arm',
#  'graṃtha': 'book, volume',
#  'doḍḍa': 'big, large',
#  'paṃce': '(traditional men’s dress: ‘dhoti’)',
#  'pennu': 'ballpoint pen',
#  'pyāṃṭu': 'pair of trousers',
#  'beṭṭa': 'hill, mountain',
#  'muduki': 'old woman',
#  'maidāna': 'lawn, field',
#  'yuvati': 'young woman',
#  'luṃgi': '(traditional men’s dress: long loincloth)',
#  'vidyārthi': '[male] student',
#  'vidyārthini': '[female] student',
#  'Viṣṇu': '(name of god)',
#  'Śiva': '(name of god)',
#  'sagaṇi': 'cow dung',
#  'sāmānugaḷu': 'things, belongings',
#  'sīre': '(traditional ladies’ dress: ‘sari’)',
#  'hāḍugāra': 'singer (male)',
#  'hāḍugārti': 'singer (female)',
#  'Namaskāra.': '(the same is said when parting)',
#  'Banni.': 'Yes, you may go (‘Please come’).',
#  'Hēgiddīri?': 'How are you? Gururāja',
#  'ivara': 'his / her (honorific)',
#  'elliṃda': 'from where?',
#  'cennāgi': 'nicely, finely',
#  'nimma': 'your (honorific)',
#  'banni': 'please come',
#  'barali': 'I should come',
#  'baru': 'to come',
#  'bassu': 'bus (vehicle)',
#  'bēku': 'is wanted / required / needed',
#  'bēḍa': 'is not wanted / not required',
#  'viśēṣa': 'something special',
#  'sari': 'okay, all right, correct',
#  'akka': 'elder sister',
#  'aṇṇa': 'elder brother',
#  'kere': 'tank, water reservoir',
#  'cīla': 'bag, purse',
#  'dēśa': 'country, land',
#  'puṭa': 'page (of book etc.)',
#  'snēhita': 'friend (male)',
#  'snēhite': 'friend (female)',
#  'aṃgaḍi': 'store, shop',
#  'jana': 'person, people',
#  'jijñāsu': 'eager to learn',
#  'paṃḍite': 'learned woman',
#  'hōdenu': 'I went',
#  'ādenu': 'I became',
#  'hōdi': 'you went',
#  'ādi': 'you became',
#  'hōdanu': 'he went',
#  'ādanu': 'he became',
#  'hōdaḷu': 'she went',
#  'ādaḷu': 'she became',
#  'hōdevu': 'we went',
#  'ādevu': 'we became',
#  'hōdiri': 'you went',
#  'ādiri': 'you became',
#  'hōdaru': 'they went',
#  'ādaru': 'they became',
#  'āgu': 'to become, occur',
#  'jigi': 'to jump',
#  'kare': 'to call',
#  'taru': 'to bring',
#  'tiḷi': 'to understand',
#  'nagu': 'to laugh',
#  'bīḷu': 'to fall',
#  'māḍu': 'to do, make',
#  'hoḍe': 'to hit, strike',
#  'hōgu': 'to go',
#  'nōḍu': 'to watch, look at',
#  'bare': 'to write',
#  'anna': 'rice (cooked)',
#  'ūṭa': '(cooked) meal',
#  'koḍu': 'to give',
#  'viṣaya': 'matter, thing, topic',
#  'sāku': 'it is enough',
#  'sāladu': 'it is not enough',
#  'mēlu': 'top side',
#  'keḷagu': 'lower side',
#  'hiṃde': 'behind, ago',
#  'hiṃdu': 'rear side',
#  'āyitu': 'all right, okay',
#  'iḍu': 'to place, put',
#  'īgalū': 'also now',
#  'kaḍe': 'side, direction',
#  'kōṇe': 'room, chamber',
#  'gaḍipradēśa': 'border area',
#  'tagoḷḷu': 'to take',
#  'tuṃba': 'very, much, many',
#  'darśana': 'seeing, sight, ritual viewing of an object of reverence',
#  'nija': 'real, true',
#  'nijavāgi': 'really, truly',
#  'pradēśa': 'region, area',
#  'bāḷu': 'to live',
#  'bhakta': 'devotee, follower',
#  'śatamāna': 'century (100 years)',
#  'summane': 'just like that, quietly',
#  'svalpa': 'a bit, a little',
#  'bāḷe': 'banana tree',
#  'bēre': 'other, something else',
#  'rīti': 'style, kind',
#  'asahya': 'intolerable, disgusting',
#  'āḍu': 'to play',
#  'iṣṭa': 'liked, appreciated',
#  'ūru': 'place, village, town, ‘native place’, city',
#  'kēḷu': 'to ask, to hear',
#  'kṣētra': 'place of pilgrimage',
#  'jāga': 'place, space, spot',
#  'taṃgi': 'younger sister',
#  'tīrthaṃkara': '(holiest person in Jainism)',
#  'pūjārha': 'worthy of worship',
#  'prakāra': 'according to',
#  'manuṣya': 'human, person',
#  'mūrti': 'icon, statue',
#  'modalu': 'firstly, in the beginning',
#  'mōkṣa': '(religious) liberation',
#  'saṃsāra': '‘the worldly system of',
#  'hoṃdu': 'to acquire, achieve',
#  'kelasadavaḷu': 'housemaid (‘of-the-work she’)',
#  'maneyavaru': 'spouse (‘of-the-house person’)',
#  'avatāra': 'incarnation of a god',
#  'gurutu': 'mark, characteristic',
#  'jāsti': 'too much, excessively',
#  'taṃdaru': 'he (hon.) brought',
#  'tanna': 'his / her / its own',
#  'divasā': 'every day',
#  'pūje': 'ritual of worship',
#  'mukhya': 'something important',
#  'rathabīdi': 'Temple Street',
#  'vidēśa': 'foreign country',
#  'vaiṣṇava': 'devotee of Viṣṇu, Viṣṇuite',
#  'samudra': 'sea, ocean',
#  'hattira': 'near; nearness',
#  'heccu': 'much, a lot, very',
#  'iḷi': 'to descend, go down',
#  'kadi': 'to steal',
#  'kāpāḍu': 'to protect, guard',
#  'koḷḷu': 'to buy',
#  'jōru': 'force, forcefulness',
#  'tīvra': 'severe, intense',
#  'naḍe': 'to walk, to happen',
#  'paḍu': 'to suffer, experience, undergo',
#  'bayyu': 'to abuse, scold',
#  'beḷe': 'to grow',
#  'bhāgavahisu': 'to participate',
#  'malagu': 'to lie down, sleep',
#  'mātanāḍu': 'to speak',
#  'lēkhaki': 'writer (feminine)',
#  'vāpasu': 'back, returned',
#  'sustu': 'tiredness, fatigue',
#  'sogasu': 'grace, elegance, beauty',
#  'hattu': 'to climb; to begin',
#  'hāḍu': 'song; to sing',
#  'hāru': 'to fly, jump',
#  'horaḍu': 'to set out, leave for',
#  'kareyisu': 'to cause to call',
#  'prakaṭa': 'published, public',
#  'prayatna': 'attempt, try, effort',
#  'bēga': 'fast, soon',
#  'mēṣṭaru': '(school) teacher (‘master’)',
#  'vicitra': 'strange, odd',
#  'araḷu': 'to bloom, blossom',
#  'tamma': 'younger brother',
#  'neraḷu': 'shade, shadow',
#  'mātu': 'word, utterance',
#  'vāsa': 'living, dwelling',
#  'sigu': 'to be obtained, to be met',
#  'suddi': 'news, message',
#  'bāradu': 'may not',
#  'āse': 'desire, wish',
#  'heṃḍa': 'alcoholic beverage',
#  'eṃdare': 'i.e., that is to say',
#  'oḍati': 'mistress, owner',
#  'kāṇisu': 'to be seen, appear',
#  'kāraṇa': 'cause, reason',
#  'gottu': 'knowledge, known thing',
#  'tuḷasi': 'Indian basil',
#  'pavitra': 'pure, holy',
#  'pūjisu': 'to worship',
#  'bahaḷa': 'much, many, very',
#  'baḷasu': 'to use',
#  'beḷigge': 'in the morning',
#  'śakti': 'energy, power',
#  'śukravāra': 'energy, power',
#  'hittalu': 'back yard',
#  'hedaru': 'to fear',
#  'kareyavu': 'In modern usage, these forms are generally considered rather old-fash- ioned and hardly occur. The main reason for this is that they do not',
#  'anubhavisu': 'to experience',
#  'anubhāva': 'religious experience',
#  'kelavaru': 'some persons',
#  'kelavu': 'some (things)',
#  'guṃpugārike': 'group consciousness, ‘groupism’',
#  'naṃbu': 'to believe',
#  'baduku': 'to live',
#  'Basavaṇṇa': '(name, ‘elder brother B.’)',
#  'mānava': 'human, person',
#  'vacana': '(name of a literary form, ‘utterance’)',
#  'vaiyaktika': 'something personal',
#  'vyakti': 'person, individual',
#  'śivamaya': 'made of god',
#  'śaiva': 'pertaining to Śiva',
#  'saṃbhavisu': 'to arise, originate',
#  'sādhane': 'religious discipline / practice',
#  'sāhityakṛti': 'literary work',
#  'halavaru': 'many persons',
#  'āga': 'then, that time',
#  'ivattina': 'today’s, of today',
#  'īgina': 'of now, present',
#  'uḷi': 'to remain',
#  'kali': 'to learn',
#  'guḍḍa': 'hill, hillock',
#  'jotege': 'together with',
#  'dharmādhikāri': '(religious title and function)',
#  'neṃṭa': '(blood-) relative',
#  'pradhāna': 'main, chief',
#  'prāṇa': 'life, life force',
#  'balakaḍe': 'right (side)',
#  'beṃḍekāyi': 'okra, ‘ladies’ fingers’',
#  'muṃcitavāgi': 'beforehand, earlier',
#  'muṃduvari': 'to continue',
#  'mugi': 'to end (intr.)',
#  'mugisu': 'to end, finish (trans.)',
#  'yati': 'wandering ascetic',
#  'rūḍhi': 'custom, usage',
#  'rūpa': 'form, shape',
#  'lābha': 'profit, advantage',
#  'liṃga': '‘sign’, a particular depiction of Śiva',
#  'sinima': 'movie theatre',
#  'hāgādare': 'in that case, if that is so',
#  'hāgū': 'and, also',
#  'haṇṇugaḷellavu': '(the same)',
#  'vidyārthigaḷellaru': '(the same)',
#  'elladariṃda': 'from everything (ablative)',
#  'elladakke': 'to everything (dative)',
#  'elladara': 'of everything (genitive)',
#  'elladaralli': 'in everything (locative)',
#  'baredukoḷḷi': 'please note down [‘having written, please take’, i.e., write this down so that you need not remember]',
#  'baredukoḍi': 'please write it down for me [‘having written, please give’]',
#  'maretubiḍi!': 'please forget it!',
#  'saṃkōcapaḍabēḍa': 'don’t be shy [‘do not suffer shyness’]',
#  'oṃdu': 'one, a',
#  'oṃdannu': 'one (specific accusative)',
#  'oṃdariṃda': 'from one',
#  'oṃdakke': 'to one',
#  'oṃdara': 'of one',
#  'oṃdaralli': 'in one',
#  'eraḍannu': 'two (specific accusative)',
#  'mūrakke': 'to three',
#  'nālkara': 'of four',
#  'aidariṃda': 'from five',
#  'āraralli': 'in six Often, though, these inflected forms of the numerals must be translated in special idiomatic manners:',
#  'sāvira': '1000 When smaller numbers are added to higher units (hundreds, thousands, etc.), the connection between the higher and lower elements in the numeral is indicated by the genitive case:',
#  'oṃdaneyadu': 'the first one',
#  'hattaneyavanu': 'the tenth man These new words can of course be declined, like any pronoun or pro- nomi nalized word:',
#  'aidaneyadaralli': 'in the fifth one',
#  'hattaneyavanige': 'to the tenth man',
#  'obbanu': 'one [male] person',
#  'obbaḷu': 'one [female] person',
#  'obbaru': 'one person [politely, or neutral]',
#  'ibbaru': 'two persons',
#  'mūvaru': 'three persons',
#  'nālvaru': 'four persons',
#  'aivaru': 'five persons',
#  'ari': 'to know',
#  'aritenu': 'I knew',
#  'kalitenu': 'I learnt',
#  'mare': 'to forget',
#  'ennu': 'to say',
#  'eṃdenu': 'I said',
#  'tinnu': 'to eat',
#  'tiṃdenu': 'I ate',
#  'baydenu': 'I abused / reviled These are roots which originally, in Old Kannada, ended in a consonant',
#  'kāyu': 'to wait / grow hot',
#  'kādenu': 'I waited',
#  'kuḷiru': 'to sit down',
#  'kuḷitenu': 'I sat down',
#  'sōlu': 'to be defeated',
#  'sīnu': 'to sneeze',
#  'sītenu': 'I sneezed It should be noticed here that in the case of some of these verbs, more',
#  'ese': 'to throw',
#  'kuri': 'to aim',
#  'kusi': 'to sink down / collapse',
#  'koḷe': 'to rot',
#  'caḷi': 'to be tired',
#  'dore': 'to be obtained',
#  'bese': 'to solder',
#  'mase': 'to whet',
#  'moḷe': 'to sprout',
#  'husi': 'to speak falsehood / lie',
#  'āyu': 'to choose',
#  'oyyu': 'to carry off',
#  'koyyu': 'to reap, pluck',
#  'geyyu': 'to make',
#  'tēyu': 'to grind',
#  'toyyu': 'to become wet',
#  'māyu': 'to be hidden',
#  'mēyu': 'to graze',
#  'suyyu': 'to sigh',
#  'hāyu': 'to cross over',
#  'kavalu': 'to become branched',
#  'ciguru': 'to sprout',
#  'bevaru': 'to perspire',
#  'nāru': 'to stink',
#  'iru': 'to be',
#  'teru': 'to pay',
#  'bēsaru': 'to be bored',
#  'heru': 'to give birth',
#  'horu': 'to bear a burden',
#  'kollu': 'to kill',
#  'gellu': 'to win, overcome',
#  'nillu': 'to stand',
#  'aḷu': 'to weep',
#  'uḷu': 'to plough',
#  'ēḷu': 'to rise',
#  'kaḷu': 'to steal',
#  'kīḷu': 'to pluck, pick',
#  'biddu': '(Note the shortening of the vowel in the case of the two last-mentioned verbs.)',
#  'bēyu': 'be burnt',
#  'mīyu': 'to bathe',
#  'aḍu': 'to cook',
#  'uḍu': 'to dress',
#  'keḍu': 'to be spoilt',
#  'toḍu': 'to dress',
#  'neḍu': 'to plant',
#  'biḍu': 'to leave',
#  'suḍu': 'to burn',
#  'uṇṇu': 'to eat',
#  'kāṇu': 'to see',
#  'hogu': 'to enter',
#  'hokku': 'Alternative abbreviated forms:',
#  'ode': 'to kick',
#  'hode': 'to put on (dress)',
#  'eḷe': 'to pull',
#  'tege': 'to take',
#  'mlēccha': 'barbarian, foreigner',
#  'adannu': 'that (accusative case)',
#  'oḷḷeyadu': 'good thing',
#  'kalitare': 'if [one] learns',
#  'cennāgide': 'is good',
#  'daya': 'grace, mercy',
#  'namage': 'us (dative case)',
#  'niṃtiddāre': 'they stand',
#  'baruttāre': 'they come',
#  'mara': 'tree, wood',
#  'meccuviri': 'you will like',
#  'yaśasvi': 'glorious, successful',
#  'agnimaṃḍala': 'circle of fire',
#  'apasmara': '(name of a demon)',
#  'uṃṭāgu': 'to arise, originate',
#  'uṃṭumāḍu': 'to create',
#  'kaiyalli': '‘in the hand’, with, near',
#  'korate': 'defect, shortcoming',
#  'gaṃgādhara': '‘bearer of the Ganges’, Śiva',
#  'caṃdraśēkhara': '‘who has the moon on his crest’, Śiva',
#  'tāṃḍava': '(name of Śiva’s dance)',
#  'nakk-': '(past stem of nagu)',
#  'naṃjuṃḍa': '‘who drank poison’',
#  'nāśa': 'destruction, ruin',
#  'Madhvācārya': '(name of a philosopher)',
#  'mallikārjuna': '‘white like jasmine’',
#  'mahatva': 'greatness, importance',
#  'rēkhē': 'stripe, line',
#  'vāsasthaḷa': 'place of residence',
#  'vibhūti': 'holy ash as used by the devotees of Śiva',
#  'śivabhakta': 'devotee of Śiva',
#  'siddhapuruṣa': 'religiously liberated person',
#  'sōmaśēkhara': '‘who has the moon on his crest’, Śiva',
#  'svabhāva': 'nature, character',
#  'haccu': 'to smear, apply',
#  'huḷi': 'sour',
#  'huli': 'tiger',
#  'haḷḷi': 'village',
#  'halli': 'lizard',
#  'maṇe': 'stool',
#  'mane': 'house',
#  'hālu': 'milk',
#  'hallu': 'tooth',
#  'dēva': 'god',
#  'devva': 'spirit',
#  'nānu': 'I',
#  'nāvu': 'we',
#  'avanu': 'he',
#  'avaḷu': 'she',
#  'ivanu': 'he',
#  'ivaḷu': 'she',
#  'illi': 'here',
#  'alli': 'there',
#  'elli': 'where?',
#  'īga': 'now',
#  'almāri': 'closet',
#  'ākāśa': 'sky',
#  'innoṃdu': 'another',
#  'ivattu': 'today',
#  'eraḍu': 'two',
#  'aidu': 'five',
#  'kaṃpyūṭaru': 'computer',
#  'kaṭṭaḍa': 'building',
#  'kāgada': 'paper',
#  'kāḍu': 'forest',
#  'kāru': 'car',
#  'kiṭaki': 'window',
#  'kurci': 'chair',
#  'gilāsu': 'glass',
#  'guri': 'goal',
#  'guru': 'teacher',
#  'guruvāra': 'Thursday',
#  'camaca': 'spoon',
#  'cāku': 'knife',
#  'cāpe': 'mat',
#  'cāvi': 'key',
#  'citra': 'picture',
#  'ṭyāksi': 'taxi',
#  'ṭyūbulaiṭu': 'tubelight',
#  'taṭṭe': 'plate',
#  'dīpa': 'lamp',
#  'dēvasthāna': 'temple',
#  'nālku': 'four',
#  'nāḷe': 'tomorrow',
#  'nela': 'floor',
#  'noṇa': 'fly',
#  'pustaka': 'book',
#  'pensilu': 'pencil',
#  'phorenar': 'foreigner',
#  'phōrku': 'fork',
#  'bāgilu': 'door',
#  'budhavāra': 'Wednesday',
#  'beṃki': 'fire',
#  'bēli': 'fence',
#  'bhāratīya': 'Indian',
#  'maṃgaḷavāra': 'Tuesday',
#  'mattu': 'and',
#  'mahiḷe': 'lady',
#  'maḷe': 'rain',
#  'māle': 'garland',
#  'mūru': 'three',
#  'mēju': 'table',
#  'mēṇabatti': 'candle',
#  'mōḍa': 'cloud',
#  'ravivāra': 'Sunday',
#  'raste': 'road',
#  'rikṣā': 'rikshaw',
#  'vimāna': 'airplane',
#  'śanivāra': 'Saturday',
#  'sūṭkēsu': 'suitcase',
#  'sūrya': 'sun',
#  'sōmavāra': 'Monday',
#  'strī': 'woman',
#  'hakki': 'bird',
#  'halavu': 'many',
#  'hasu': 'cow',
#  'hippi': 'hippie',
#  'huḍuga': 'boy',
#  'huḍugi': 'girl',
#  'hū': 'flower',
#  'heṃgasu': 'woman',
#  'hola': 'field',
#  'haudu': 'yes',
#  'yāvāgalū illa': 'never',
#  'ēnū illa': 'nothing',
#  'yārū illa': 'nobody',
#  'ēke': 'why?',
#  'ēnu': 'what?',
#  'kappu': 'black',
#  'kaṣṭa': 'difficult',
#  'toḍaku': 'problem',
#  'nanna': 'my',
#  'namma': 'our',
#  'patra': 'letter',
#  'purōhita': 'priest',
#  'biḷi': 'white',
#  'yāru': 'who?',
#  'yāva': 'which?',
#  'yāvāga': 'when?',
#  'samācāra': 'news',
#  'hesaru': 'name',
#  'appa': 'father',
#  'amma': 'mother',
#  'kaṇṇu': 'eye',
#  'kivi': 'ear',
#  'kūsu': 'baby',
#  'gaṃḍa': 'husband',
#  'gaṃḍasu': 'man',
#  'nighaṃṭu': 'dictionary',
#  'nīru': 'water',
#  'buṭṭi': 'basket',
#  'maga': 'son',
#  'magaḷu': 'daughter',
#  'magu': 'child',
#  'māva': 'uncle',
#  'rāja': 'king',
#  'raita': 'farmer',
#  'vidhave': 'widow',
#  'anubhava': 'experience',
#  'āṭike': 'toy',
#  'āyke': 'choice',
#  'keṃpu': 'red',
#  'koṃbu': 'horn',
#  'koṃbe': 'branch',
#  'cūpu': 'sharp',
#  'tudi': 'tip',
#  'parimāṇa': 'size',
#  'baṭṭe': 'cloth',
#  'baṇṇa': 'colour',
#  'saṃkhye': 'number',
#  'hasiru': 'green',
#  'haḷadi': 'yellow',
#  'heṃḍati': 'wife',
#  'nidde': 'sleep',
#  'nāyi': 'dog',
#  'kathe': 'story',
#  'kelasa': 'work',
#  'toṃdare': 'trouble',
#  'nenne': 'yesterday',
#  'satya': 'truth',
#  'haṇa': 'money',
#  'haṇṇu': 'fruit',
#  'mēle': 'on',
#  'keḷage': 'under',
#  'oḷage': 'within',
#  'oḷagu': 'inside',
#  'bage': 'thought',
#  'madhya': 'middle',
#  'muṃde': 'before',
#  'horage': 'outside',
#  'aḍige': 'cooking',
#  'uttara': 'north',
#  'kāpi': 'coffee',
#  'gaḍi': 'border',
#  'cahā': 'tea',
#  'padārtha': 'thing',
#  'pavāḍa': 'miracle',
#  'viśēṣavāda': 'special',
#  'samādhi': 'tomb',
#  'ele': 'leaf',
#  'athavā': 'or',
#  'abhiprāya': 'opinion',
#  'iḍiya': 'entire',
#  'upayukta': 'useful',
#  'keṭṭa': 'bad',
#  'kliṣṭa': 'complicated',
#  'gaddala': 'noise',
#  'cakravarti': 'emperor',
#  'cikka': 'small',
#  'jagattu': 'world',
#  'dūra': 'distance',
#  'nīli': 'blue',
#  'praśne': 'question',
#  'bīdi': 'street',
#  'bhāra': 'weight',
#  'bhārata': 'India',
#  'yuga': 'era',
#  'saṃgīta': 'music',
#  'suṃdara': 'beautiful',
#  'kōlu': 'stick',
#  'ciṃtaka': 'thinker',
#  'tīra': 'coast',
#  'maṭha': 'monastery',
#  'saṃpradāya': 'tradition',
#  'hadimūraneya': 'thirteenth',
#  'āphisu': 'office',
#  'oraṭu': 'coarseness',
#  'krūra': 'cruel',
#  'khuśi': 'joy',
#  'tiṃgaḷu': 'month',
#  'dayaviṭṭu': 'please',
#  'pāṭha': 'lesson',
#  'muṃdina': 'next',
#  'yōcane': 'thought',
#  'vākya': 'sentence',
#  'śabda': 'word',
#  'saṃtōṣa': 'joy',
#  'sammēḷana': 'conference',
#  'spaṣṭa': 'clear',
#  'artha': 'meaning',
#  'ādare': 'but',
#  'kṣame': 'forgiveness',
#  'hōṭalu': 'restaurant',
#  'adhyāpaka': 'teacher',
#  'kōpa': 'anger',
#  'graṃthapālaka': 'librarian',
#  'graṃthālaya': 'library',
#  'patrike': 'magazine',
#  'sahāya': 'help',
#  'hemme': 'pride',
#  'hōguvike': 'going',
#  'bāḷike': 'living',
#  'ārōgya': 'health',
#  'gōḍe': 'wall',
#  'gōva': 'Goa',
#  'māṃsa': 'meat',
#  'miliṭari': 'military',
#  'miliṭari hōṭalu': 'non-vegetarian',
#  'auṣadhi': 'medicine',
#  'kaṭṭe': 'mount',
#  'giḍa': 'plant',
#  'dēvi': 'goddess',
#  'patni': 'wife',
#  'pradakṣiṇe': 'circumambulation',
#  'bhakti': 'devotion',
#  'mātra': 'only',
#  'saṃpattu': 'wealth',
#  'sādhya': 'possible',
#  'sulabha': 'easy',
#  'saubhāgya': 'well-being',
#  'atṛpta': 'dissatisfied',
#  'atṛpti': 'dissatisfaction',
#  'anubhāvi': 'mystic',
#  'anuyāyi': 'follower',
#  'asamānate': 'inequality',
#  'ityādi': 'etc.',
#  'kuṭuṃba': 'family',
#  'kelavomme': 'sometimes',
#  'guṃpu': 'group',
#  'jāti': 'caste',
#  'jīvana': 'life',
#  'tṛpta': 'satisfied',
#  'tṛpti': 'satisfaction',
#  'dhārmika': 'religious',
#  'naitika': 'moral',
#  'paraṃpare': 'tradition',
#  'prapaṃca': 'world',
#  'prācīna': 'ancient',
#  'prīti': 'love',
#  'Basava': '(name)',
#  'beḷavaṇige': 'development',
#  'maṃdi': 'person',
#  'manassu': 'mind',
#  'samāna': 'equal',
#  'samānate': 'equality',
#  'sāmājika': 'social',
#  'hinnele': 'background',
#  'hosa': 'new',
#  'anēka': 'many',
#  'ippataidu': 'twenty-five',
#  'ēkeṃdare': 'because',
#  'omme': 'once',
#  'karāvaḷi': 'coast',
#  'kaḷatmaka': 'artistic',
#  'kāphi': 'coffee',
#  'kāryakrama': 'program',
#  'kuḍuma': '(placename)',
#  'kēṃdra': 'centre',
#  'cikitsālaya': 'clinic',
#  'jille': 'district',
#  'taṃde': 'father',
#  'takṣaṇa': 'immediately',
#  'tale': 'head',
#  'talenōvu': 'headache',
#  'dēvate': 'divinity',
#  'Dharmasthaḷa': '(placename)',
#  'nōvu': 'pain',
#  'paṃḍita': 'scholar',
#  'pūrvaja': 'ancestor',
#  'Maṃjunātha': '(name)',
#  'yātrika': 'pilgrim',
#  'rakṣaṇe': 'protection',
#  'varegū': 'until',
#  'varṣa': 'year',
#  'Vādirāja': '(name)',
#  'śikṣaka': 'teacher',
#  'saṃgrahālaya': 'museum',
#  'sahiṣṇute': 'tolerance',
#  'sāṃskṛtika': 'cultural',
#  'sāvirāru': 'thousands',
#  'sumāru': 'approximately',
#  'hadināraneya': 'sixteenth',
#  'huṣāru': 'healthiness',
#  'ellarannu / ellarannū': '(accusative)',
#  'ellariṃda / ellariṃdalū': '(ablative)',
#  'ellara': '(genitive)',
#  'ellaralli / ellarallū': '(locative)',
#  'āru': 'six',
#  'eṃṭu': 'eight',
#  'oṃbattu': 'nine',
#  'hannoṃdu': 'eleven',
#  'hanneraḍu': 'twelve',
#  'hadimūru': 'thirteen',
#  'hadinālku': 'fourteen',
#  'hadinaidu': 'fifteen',
#  'hadināru': 'sixteen',
#  'hadinēḷu': 'seventeen',
#  'hadineṃṭu': 'eighteen',
#  'hattoṃbattu': 'nineteen',
#  'ippattu': 'twenty',
#  'ippattoṃdu': 'twenty-one',
#  'ippatteraḍu': 'twenty-two',
#  'ippattanālku': 'twenty-four',
#  'ippattaidu': 'twenty-five',
#  'ippattāru': 'twenty-six',
#  'ippattēḷu': 'twenty-seven',
#  'ippatteṃṭu': 'twenty-eight',
#  'ippattoṃbattu': 'twenty-nine',
#  'aivattu': 'fifty',
#  'aravattu': 'sixty',
#  'eppattu': 'seventy',
#  'eṃbattu': 'eighty',
#  'toṃbattu': 'ninety',
#  'nūru': 'hundred',
#  'innūru': '200',
#  'munnūru': '300',
#  'nānūru': '400',
#  'ainūru': '500',
#  'ārunūru': '600',
#  'ēḷunūru': '700',
#  'eṃṭunūru': '800',
#  'oṃbainūru': '900',
#  'nūra nalvattoṃdu': '141',
#  'sāvirada oṃbainūra toṃbattaidu': '1995',
#  'āgi': '(gerund)',
#  'hōgi': '(gerund)',
#  'utkhanana': 'excavation',
#  'hagga': 'rope',
#  'ajja': 'grandfather',
#  'jñāna': 'knowledge',
#  'daḍḍa': 'dunce',
#  'kobbu': 'fat',
#  'udbhava': 'origin',
#  'ayya': 'lord',
#  'prabhāva': 'influence',
#  'tatva': 'principle',
#  'utsava': 'feast',
#  'kaḷḷa': 'thief',
#  'aparūpavāgi': 'rarely',
#  'bhāṣe': 'language',
#  'yāvāgalū': 'always',
#  'haḷeya': 'old',
#  'aṃgaḍiyavaru': 'shopkeeper',
#  'ajñāna': 'ignorance',
#  'nṛtya': 'dance',
#  'paravā': 'worry',
#  'parvata': 'mountain',
#  'baḷi': 'near',
#  'buddhi': 'intelligence',
#  'beḷaku': 'light',
#  'bhasma': 'ash',
#  'majjige': 'buttermilk',
#  'mūgu': 'nose',
#  'modalaneya': 'first',
#  'rākṣasa': 'demon',
#  'vimānanildāṇa': 'airport',
#  'vaiṣṇavadharma': 'Viṣṇuism',
#  'saṃkēta': 'symbol',
#  'saṃsthe': 'institute',
#  'sāṃkētika': 'symbolic',
#  'sāmānya': 'ordinary',
#  'haṇe': 'forehead'}

# %%
import json

# Save the kannada to english mapping to a json file called kan_to_eng_dict.json
with open("kan_to_eng_dict.json", "w", encoding="utf-8") as f:
    json.dump(kan_to_eng_mapping, f, ensure_ascii=False, indent=4)
# Save the POS mapping to a json file called pos_mapping.json
with open("pos_mapping.json", "w", encoding="utf-8") as f:
    json.dump(pos_mapping, f, ensure_ascii=False, indent=4)

# %%
list(kannada_1word.values())
# Out:
# ['to run',
#  'to read',
#  'to say',
#  'to shit',
#  'to beat',
#  'interest (on money)',
#  'ritually pure',
#  'please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:',
#  'you (singular and non-honorific)',
#  'you (plural / honorific)',
#  'it / that',
#  'they (persons)',
#  'they (non-persons)',
#  'it / this',
#  'he / she (honorific)',
#  'they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.)',
#  'in this manner',
#  'in that manner',
#  'in which manner?',
#  'this much',
#  'that much',
#  'how much?',
#  'it is, it exists',
#  'mouse, rat',
#  'leg, foot',
#  'hand, arm',
#  'book, volume',
#  'big, large',
#  '(traditional men’s dress: ‘dhoti’)',
#  'ballpoint pen',
#  'pair of trousers',
#  'hill, mountain',
#  'old woman',
#  'lawn, field',
#  'young woman',
#  '(traditional men’s dress: long loincloth)',
#  '[male] student',
#  '[female] student',
#  '(name of god)',
#  '(name of god)',
#  'cow dung',
#  'things, belongings',
#  '(traditional ladies’ dress: ‘sari’)',
#  'singer (male)',
#  'singer (female)',
#  '(the same is said when parting)',
#  'Yes, you may go (‘Please come’).',
#  'How are you? Gururāja',
#  'his / her (honorific)',
#  'from where?',
#  'nicely, finely',
#  'your (honorific)',
#  'please come',
#  'I should come',
#  'to come',
#  'bus (vehicle)',
#  'is wanted / required / needed',
#  'is not wanted / not required',
#  'something special',
#  'okay, all right, correct',
#  'elder sister',
#  'elder brother',
#  'tank, water reservoir',
#  'bag, purse',
#  'country, land',
#  'page (of book etc.)',
#  'friend (male)',
#  'friend (female)',
#  'store, shop',
#  'person, people',
#  'eager to learn',
#  'learned woman',
#  'I went',
#  'I became',
#  'you went',
#  'you became',
#  'he went',
#  'he became',
#  'she went',
#  'she became',
#  'we went',
#  'we became',
#  'you went',
#  'you became',
#  'they went',
#  'they became',
#  'to become, occur',
#  'to jump',
#  'to call',
#  'to bring',
#  'to understand',
#  'to laugh',
#  'to fall',
#  'to do, make',
#  'to hit, strike',
#  'to go',
#  'to watch, look at',
#  'to write',
#  'rice (cooked)',
#  '(cooked) meal',
#  'to give',
#  'matter, thing, topic',
#  'it is enough',
#  'it is not enough',
#  'top side',
#  'lower side',
#  'behind, ago',
#  'rear side',
#  'all right, okay',
#  'to place, put',
#  'also now',
#  'side, direction',
#  'room, chamber',
#  'border area',
#  'to take',
#  'very, much, many',
#  'seeing, sight, ritual viewing of an object of reverence',
#  'real, true',
#  'really, truly',
#  'region, area',
#  'to live',
#  'devotee, follower',
#  'century (100 years)',
#  'just like that, quietly',
#  'a bit, a little',
#  'banana tree',
#  'other, something else',
#  'style, kind',
#  'intolerable, disgusting',
#  'to play',
#  'liked, appreciated',
#  'place, village, town, ‘native place’, city',
#  'to ask, to hear',
#  'place of pilgrimage',
#  'place, space, spot',
#  'younger sister',
#  '(holiest person in Jainism)',
#  'worthy of worship',
#  'according to',
#  'human, person',
#  'icon, statue',
#  'firstly, in the beginning',
#  '(religious) liberation',
#  '‘the worldly system of',
#  'to acquire, achieve',
#  'housemaid (‘of-the-work she’)',
#  'spouse (‘of-the-house person’)',
#  'incarnation of a god',
#  'mark, characteristic',
#  'too much, excessively',
#  'he (hon.) brought',
#  'his / her / its own',
#  'every day',
#  'ritual of worship',
#  'something important',
#  'Temple Street',
#  'foreign country',
#  'devotee of Viṣṇu, Viṣṇuite',
#  'sea, ocean',
#  'near; nearness',
#  'much, a lot, very',
#  'to descend, go down',
#  'to steal',
#  'to protect, guard',
#  'to buy',
#  'force, forcefulness',
#  'severe, intense',
#  'to walk, to happen',
#  'to suffer, experience, undergo',
#  'to abuse, scold',
#  'to grow',
#  'to participate',
#  'to lie down, sleep',
#  'to speak',
#  'writer (feminine)',
#  'back, returned',
#  'tiredness, fatigue',
#  'grace, elegance, beauty',
#  'to climb; to begin',
#  'song; to sing',
#  'to fly, jump',
#  'to set out, leave for',
#  'to cause to call',
#  'published, public',
#  'attempt, try, effort',
#  'fast, soon',
#  '(school) teacher (‘master’)',
#  'strange, odd',
#  'to bloom, blossom',
#  'younger brother',
#  'shade, shadow',
#  'word, utterance',
#  'living, dwelling',
#  'to be obtained, to be met',
#  'news, message',
#  'may not',
#  'desire, wish',
#  'alcoholic beverage',
#  'i.e., that is to say',
#  'mistress, owner',
#  'to be seen, appear',
#  'cause, reason',
#  'knowledge, known thing',
#  'Indian basil',
#  'pure, holy',
#  'to worship',
#  'much, many, very',
#  'to use',
#  'in the morning',
#  'energy, power',
#  'energy, power',
#  'back yard',
#  'to fear',
#  'In modern usage, these forms are generally considered rather old-fash- ioned and hardly occur. The main reason for this is that they do not',
#  'to experience',
#  'religious experience',
#  'some persons',
#  'some (things)',
#  'group consciousness, ‘groupism’',
#  'to believe',
#  'to live',
#  '(name, ‘elder brother B.’)',
#  'human, person',
#  '(name of a literary form, ‘utterance’)',
#  'something personal',
#  'person, individual',
#  'made of god',
#  'pertaining to Śiva',
#  'to arise, originate',
#  'religious discipline / practice',
#  'literary work',
#  'many persons',
#  'then, that time',
#  'today’s, of today',
#  'of now, present',
#  'to remain',
#  'to learn',
#  'hill, hillock',
#  'together with',
#  '(religious title and function)',
#  '(blood-) relative',
#  'main, chief',
#  'life, life force',
#  'right (side)',
#  'okra, ‘ladies’ fingers’',
#  'beforehand, earlier',
#  'to continue',
#  'to end (intr.)',
#  'to end, finish (trans.)',
#  'wandering ascetic',
#  'custom, usage',
#  'form, shape',
#  'profit, advantage',
#  '‘sign’, a particular depiction of Śiva',
#  'movie theatre',
#  'in that case, if that is so',
#  'and, also',
#  '(the same)',
#  '(the same)',
#  'from everything (ablative)',
#  'to everything (dative)',
#  'of everything (genitive)',
#  'in everything (locative)',
#  'please note down [‘having written, please take’, i.e., write this down so that you need not remember]',
#  'please write it down for me [‘having written, please give’]',
#  'please forget it!',
#  'don’t be shy [‘do not suffer shyness’]',
#  'one, a',
#  'one (specific accusative)',
#  'from one',
#  'to one',
#  'of one',
#  'in one',
#  'two (specific accusative)',
#  'to three',
#  'of four',
#  'from five',
#  'in six Often, though, these inflected forms of the numerals must be translated in special idiomatic manners:',
#  '1000 When smaller numbers are added to higher units (hundreds, thousands, etc.), the connection between the higher and lower elements in the numeral is indicated by the genitive case:',
#  'the first one',
#  'the tenth man These new words can of course be declined, like any pronoun or pro- nomi nalized word:',
#  'in the fifth one',
#  'to the tenth man',
#  'one [male] person',
#  'one [female] person',
#  'one person [politely, or neutral]',
#  'two persons',
#  'three persons',
#  'four persons',
#  'five persons',
#  'to know',
#  'I knew',
#  'I learnt',
#  'to forget',
#  'to say',
#  'I said',
#  'to eat',
#  'I ate',
#  'I abused / reviled These are roots which originally, in Old Kannada, ended in a consonant',
#  'to wait / grow hot',
#  'I waited',
#  'to sit down',
#  'I sat down',
#  'to be defeated',
#  'to sneeze',
#  'I sneezed It should be noticed here that in the case of some of these verbs, more',
#  'to throw',
#  'to aim',
#  'to sink down / collapse',
#  'to rot',
#  'to be tired',
#  'to be obtained',
#  'to solder',
#  'to whet',
#  'to sprout',
#  'to speak falsehood / lie',
#  'to choose',
#  'to carry off',
#  'to reap, pluck',
#  'to make',
#  'to grind',
#  'to become wet',
#  'to be hidden',
#  'to graze',
#  'to sigh',
#  'to cross over',
#  'to become branched',
#  'to sprout',
#  'to perspire',
#  'to stink',
#  'to be',
#  'to pay',
#  'to be bored',
#  'to give birth',
#  'to bear a burden',
#  'to kill',
#  'to win, overcome',
#  'to stand',
#  'to weep',
#  'to plough',
#  'to rise',
#  'to steal',
#  'to pluck, pick',
#  '(Note the shortening of the vowel in the case of the two last-mentioned verbs.)',
#  'be burnt',
#  'to bathe',
#  'to cook',
#  'to dress',
#  'to be spoilt',
#  'to dress',
#  'to plant',
#  'to leave',
#  'to burn',
#  'to eat',
#  'to see',
#  'to enter',
#  'Alternative abbreviated forms:',
#  'to kick',
#  'to put on (dress)',
#  'to pull',
#  'to take',
#  'barbarian, foreigner',
#  'that (accusative case)',
#  'good thing',
#  'if [one] learns',
#  'is good',
#  'grace, mercy',
#  'us (dative case)',
#  'they stand',
#  'they come',
#  'tree, wood',
#  'you will like',
#  'glorious, successful',
#  'circle of fire',
#  '(name of a demon)',
#  'to arise, originate',
#  'to create',
#  '‘in the hand’, with, near',
#  'defect, shortcoming',
#  '‘bearer of the Ganges’, Śiva',
#  '‘who has the moon on his crest’, Śiva',
#  '(name of Śiva’s dance)',
#  '(past stem of nagu)',
#  '‘who drank poison’',
#  'destruction, ruin',
#  '(name of a philosopher)',
#  '‘white like jasmine’',
#  'greatness, importance',
#  'stripe, line',
#  'place of residence',
#  'holy ash as used by the devotees of Śiva',
#  'devotee of Śiva',
#  'religiously liberated person',
#  '‘who has the moon on his crest’, Śiva',
#  'nature, character',
#  'to smear, apply']

# %%
# POS tag for Kannada words in kannada_1word

kannada_1word_sentences = list(kannada_1word.values())
# For each sentence, remove anything inside parentheses
kannada_1word_sentences = [sentence.split('(')[0].strip() for sentence in kannada_1word_sentences]

# TODO: More preprocessing 
# 1) / implies can mean two words, so either we can split it
# 2) ? at the end of a sentence implies a question, so we can add question

kannada_1word_sentences
# Out:
# ['to run',
#  'to read',
#  'to say',
#  'to shit',
#  'to beat',
#  'interest',
#  'ritually pure',
#  'please do The two following pairs of words are prosodically similar',
#  'you',
#  'you',
#  'it / that',
#  'they',
#  'they',
#  'it / this',
#  'he / she',
#  'they / these',
#  'in this manner',
#  'in that manner',
#  'in which manner?',
#  'this much',
#  'that much',
#  'how much?',
#  'it is, it exists',
#  'mouse, rat',
#  'leg, foot',
#  'hand, arm',
#  'book, volume',
#  'big, large',
#  '',
#  'ballpoint pen',
#  'pair of trousers',
#  'hill, mountain',
#  'old woman',
#  'lawn, field',
#  'young woman',
#  '',
#  '[male] student',
#  '[female] student',
#  '',
#  '',
#  'cow dung',
#  'things, belongings',
#  '',
#  'singer',
#  'singer',
#  '',
#  'Yes, you may go',
#  'How are you? Gururāja',
#  'his / her',
#  'from where?',
#  'nicely, finely',
#  'your',
#  'please come',
#  'I should come',
#  'to come',
#  'bus',
#  'is wanted / required / needed',
#  'is not wanted / not required',
#  'something special',
#  'okay, all right, correct',
#  'elder sister',
#  'elder brother',
#  'tank, water reservoir',
#  'bag, purse',
#  'country, land',
#  'page',
#  'friend',
#  'friend',
#  'store, shop',
#  'person, people',
#  'eager to learn',
#  'learned woman',
#  'I went',
#  'I became',
#  'you went',
#  'you became',
#  'he went',
#  'he became',
#  'she went',
#  'she became',
#  'we went',
#  'we became',
#  'you went',
#  'you became',
#  'they went',
#  'they became',
#  'to become, occur',
#  'to jump',
#  'to call',
#  'to bring',
#  'to understand',
#  'to laugh',
#  'to fall',
#  'to do, make',
#  'to hit, strike',
#  'to go',
#  'to watch, look at',
#  'to write',
#  'rice',
#  '',
#  'to give',
#  'matter, thing, topic',
#  'it is enough',
#  'it is not enough',
#  'top side',
#  'lower side',
#  'behind, ago',
#  'rear side',
#  'all right, okay',
#  'to place, put',
#  'also now',
#  'side, direction',
#  'room, chamber',
#  'border area',
#  'to take',
#  'very, much, many',
#  'seeing, sight, ritual viewing of an object of reverence',
#  'real, true',
#  'really, truly',
#  'region, area',
#  'to live',
#  'devotee, follower',
#  'century',
#  'just like that, quietly',
#  'a bit, a little',
#  'banana tree',
#  'other, something else',
#  'style, kind',
#  'intolerable, disgusting',
#  'to play',
#  'liked, appreciated',
#  'place, village, town, ‘native place’, city',
#  'to ask, to hear',
#  'place of pilgrimage',
#  'place, space, spot',
#  'younger sister',
#  '',
#  'worthy of worship',
#  'according to',
#  'human, person',
#  'icon, statue',
#  'firstly, in the beginning',
#  '',
#  '‘the worldly system of',
#  'to acquire, achieve',
#  'housemaid',
#  'spouse',
#  'incarnation of a god',
#  'mark, characteristic',
#  'too much, excessively',
#  'he',
#  'his / her / its own',
#  'every day',
#  'ritual of worship',
#  'something important',
#  'Temple Street',
#  'foreign country',
#  'devotee of Viṣṇu, Viṣṇuite',
#  'sea, ocean',
#  'near; nearness',
#  'much, a lot, very',
#  'to descend, go down',
#  'to steal',
#  'to protect, guard',
#  'to buy',
#  'force, forcefulness',
#  'severe, intense',
#  'to walk, to happen',
#  'to suffer, experience, undergo',
#  'to abuse, scold',
#  'to grow',
#  'to participate',
#  'to lie down, sleep',
#  'to speak',
#  'writer',
#  'back, returned',
#  'tiredness, fatigue',
#  'grace, elegance, beauty',
#  'to climb; to begin',
#  'song; to sing',
#  'to fly, jump',
#  'to set out, leave for',
#  'to cause to call',
#  'published, public',
#  'attempt, try, effort',
#  'fast, soon',
#  '',
#  'strange, odd',
#  'to bloom, blossom',
#  'younger brother',
#  'shade, shadow',
#  'word, utterance',
#  'living, dwelling',
#  'to be obtained, to be met',
#  'news, message',
#  'may not',
#  'desire, wish',
#  'alcoholic beverage',
#  'i.e., that is to say',
#  'mistress, owner',
#  'to be seen, appear',
#  'cause, reason',
#  'knowledge, known thing',
#  'Indian basil',
#  'pure, holy',
#  'to worship',
#  'much, many, very',
#  'to use',
#  'in the morning',
#  'energy, power',
#  'energy, power',
#  'back yard',
#  'to fear',
#  'In modern usage, these forms are generally considered rather old-fash- ioned and hardly occur. The main reason for this is that they do not',
#  'to experience',
#  'religious experience',
#  'some persons',
#  'some',
#  'group consciousness, ‘groupism’',
#  'to believe',
#  'to live',
#  '',
#  'human, person',
#  '',
#  'something personal',
#  'person, individual',
#  'made of god',
#  'pertaining to Śiva',
#  'to arise, originate',
#  'religious discipline / practice',
#  'literary work',
#  'many persons',
#  'then, that time',
#  'today’s, of today',
#  'of now, present',
#  'to remain',
#  'to learn',
#  'hill, hillock',
#  'together with',
#  '',
#  '',
#  'main, chief',
#  'life, life force',
#  'right',
#  'okra, ‘ladies’ fingers’',
#  'beforehand, earlier',
#  'to continue',
#  'to end',
#  'to end, finish',
#  'wandering ascetic',
#  'custom, usage',
#  'form, shape',
#  'profit, advantage',
#  '‘sign’, a particular depiction of Śiva',
#  'movie theatre',
#  'in that case, if that is so',
#  'and, also',
#  '',
#  '',
#  'from everything',
#  'to everything',
#  'of everything',
#  'in everything',
#  'please note down [‘having written, please take’, i.e., write this down so that you need not remember]',
#  'please write it down for me [‘having written, please give’]',
#  'please forget it!',
#  'don’t be shy [‘do not suffer shyness’]',
#  'one, a',
#  'one',
#  'from one',
#  'to one',
#  'of one',
#  'in one',
#  'two',
#  'to three',
#  'of four',
#  'from five',
#  'in six Often, though, these inflected forms of the numerals must be translated in special idiomatic manners:',
#  '1000 When smaller numbers are added to higher units',
#  'the first one',
#  'the tenth man These new words can of course be declined, like any pronoun or pro- nomi nalized word:',
#  'in the fifth one',
#  'to the tenth man',
#  'one [male] person',
#  'one [female] person',
#  'one person [politely, or neutral]',
#  'two persons',
#  'three persons',
#  'four persons',
#  'five persons',
#  'to know',
#  'I knew',
#  'I learnt',
#  'to forget',
#  'to say',
#  'I said',
#  'to eat',
#  'I ate',
#  'I abused / reviled These are roots which originally, in Old Kannada, ended in a consonant',
#  'to wait / grow hot',
#  'I waited',
#  'to sit down',
#  'I sat down',
#  'to be defeated',
#  'to sneeze',
#  'I sneezed It should be noticed here that in the case of some of these verbs, more',
#  'to throw',
#  'to aim',
#  'to sink down / collapse',
#  'to rot',
#  'to be tired',
#  'to be obtained',
#  'to solder',
#  'to whet',
#  'to sprout',
#  'to speak falsehood / lie',
#  'to choose',
#  'to carry off',
#  'to reap, pluck',
#  'to make',
#  'to grind',
#  'to become wet',
#  'to be hidden',
#  'to graze',
#  'to sigh',
#  'to cross over',
#  'to become branched',
#  'to sprout',
#  'to perspire',
#  'to stink',
#  'to be',
#  'to pay',
#  'to be bored',
#  'to give birth',
#  'to bear a burden',
#  'to kill',
#  'to win, overcome',
#  'to stand',
#  'to weep',
#  'to plough',
#  'to rise',
#  'to steal',
#  'to pluck, pick',
#  '',
#  'be burnt',
#  'to bathe',
#  'to cook',
#  'to dress',
#  'to be spoilt',
#  'to dress',
#  'to plant',
#  'to leave',
#  'to burn',
#  'to eat',
#  'to see',
#  'to enter',
#  'Alternative abbreviated forms:',
#  'to kick',
#  'to put on',
#  'to pull',
#  'to take',
#  'barbarian, foreigner',
#  'that',
#  'good thing',
#  'if [one] learns',
#  'is good',
#  'grace, mercy',
#  'us',
#  'they stand',
#  'they come',
#  'tree, wood',
#  'you will like',
#  'glorious, successful',
#  'circle of fire',
#  '',
#  'to arise, originate',
#  'to create',
#  '‘in the hand’, with, near',
#  'defect, shortcoming',
#  '‘bearer of the Ganges’, Śiva',
#  '‘who has the moon on his crest’, Śiva',
#  '',
#  '',
#  '‘who drank poison’',
#  'destruction, ruin',
#  '',
#  '‘white like jasmine’',
#  'greatness, importance',
#  'stripe, line',
#  'place of residence',
#  'holy ash as used by the devotees of Śiva',
#  'devotee of Śiva',
#  'religiously liberated person',
#  '‘who has the moon on his crest’, Śiva',
#  'nature, character',
#  'to smear, apply']

# %%
kannada_1word_transliterations = list(kannada_1word.keys())
kannada_pos_tags = pos_tagging(kannada_1word_sentences)
# Show all POS tags for the first 10 sentences
# Out:
# 100%|██████████| 396/396 [00:01<00:00, 291.18it/s]

# %%
kannada_pos_tags
# Out:
# [[('to', 'PART'), ('run', 'VERB')],
#  [('to', 'PART'), ('read', 'VERB')],
#  [('to', 'PART'), ('say', 'VERB')],
#  [('to', 'PART'), ('shit', 'VERB')],
#  [('to', 'PART'), ('beat', 'VERB')],
#  [('interest', 'NOUN')],
#  [('ritually', 'ADV'), ('pure', 'ADJ')],
#  [('please', 'INTJ'),
#   ('do', 'VERB'),
#   ('The', 'DET'),
#   ('two', 'NUM'),
#   ('following', 'VERB'),
#   ('pairs', 'NOUN'),
#   ('of', 'ADP'),
#   ('words', 'NOUN'),
#   ('are', 'AUX'),
#   ('prosodically', 'ADV'),
#   ('similar', 'ADJ')],
#  [('you', 'PRON')],
#  [('you', 'PRON')],
#  [('it', 'PRON'), ('/', 'PUNCT'), ('that', 'PRON')],
#  [('they', 'PRON')],
#  [('they', 'PRON')],
#  [('it', 'PRON'), ('/', 'PUNCT'), ('this', 'PRON')],
#  [('he', 'PRON'), ('/', 'SYM'), ('she', 'PRON')],
#  [('they', 'PRON'), ('/', 'PUNCT'), ('these', 'PRON')],
#  [('in', 'ADP'), ('this', 'DET'), ('manner', 'NOUN')],
#  [('in', 'ADP'), ('that', 'DET'), ('manner', 'NOUN')],
#  [('in', 'ADP'), ('which', 'PRON'), ('manner', 'NOUN'), ('?', 'PUNCT')],
#  [('this', 'PRON'), ('much', 'ADJ')],
#  [('that', 'ADV'), ('much', 'ADV')],
#  [('how', 'SCONJ'), ('much', 'ADJ'), ('?', 'PUNCT')],
#  [('it', 'PRON'),
#   ('is', 'AUX'),
#   (',', 'PUNCT'),
#   ('it', 'PRON'),
#   ('exists', 'VERB')],
#  [('mouse', 'PROPN'), (',', 'PUNCT'), ('rat', 'CCONJ')],
#  [('leg', 'PROPN'), (',', 'PUNCT'), ('foot', 'NOUN')],
#  [('hand', 'NOUN'), (',', 'PUNCT'), ('arm', 'VERB')],
#  [('book', 'NOUN'), (',', 'PUNCT'), ('volume', 'NOUN')],
#  [('big', 'ADJ'), (',', 'PUNCT'), ('large', 'ADJ')],
#  [],
#  [('ballpoint', 'PROPN'), ('pen', 'NOUN')],
#  [('pair', 'NOUN'), ('of', 'ADP'), ('trousers', 'NOUN')],
#  [('hill', 'PROPN'), (',', 'PUNCT'), ('mountain', 'NOUN')],
#  [('old', 'ADJ'), ('woman', 'NOUN')],
#  [('lawn', 'PROPN'), (',', 'PUNCT'), ('field', 'NOUN')],
#  [('young', 'ADJ'), ('woman', 'NOUN')],
#  [],
#  [('[', 'X'), ('male', 'NOUN'), (']', 'X'), ('student', 'NOUN')],
#  [('[', 'X'), ('female', 'ADJ'), (']', 'PUNCT'), ('student', 'NOUN')],
#  [],
#  [],
#  [('cow', 'NOUN'), ('dung', 'PROPN')],
#  [('things', 'NOUN'), (',', 'PUNCT'), ('belongings', 'NOUN')],
#  [],
#  [('singer', 'NOUN')],
#  [('singer', 'NOUN')],
#  [],
#  [('Yes', 'INTJ'),
#   (',', 'PUNCT'),
#   ('you', 'PRON'),
#   ('may', 'AUX'),
#   ('go', 'VERB')],
#  [('How', 'SCONJ'),
#   ('are', 'AUX'),
#   ('you', 'PRON'),
#   ('?', 'PUNCT'),
#   ('Gururāja', 'NOUN')],
#  [('his', 'PRON'), ('/', 'SYM'), ('her', 'PRON')],
#  [('from', 'ADP'), ('where', 'SCONJ'), ('?', 'PUNCT')],
#  [('nicely', 'ADV'), (',', 'PUNCT'), ('finely', 'ADV')],
#  [('your', 'PRON')],
#  [('please', 'INTJ'), ('come', 'VERB')],
#  [('I', 'PRON'), ('should', 'AUX'), ('come', 'VERB')],
#  [('to', 'PART'), ('come', 'VERB')],
#  [('bus', 'NOUN')],
#  [('is', 'AUX'),
#   ('wanted', 'VERB'),
#   ('/', 'SYM'),
#   ('required', 'VERB'),
#   ('/', 'SYM'),
#   ('needed', 'VERB')],
#  [('is', 'AUX'),
#   ('not', 'PART'),
#   ('wanted', 'VERB'),
#   ('/', 'PUNCT'),
#   ('not', 'PART'),
#   ('required', 'VERB')],
#  [('something', 'PRON'), ('special', 'ADJ')],
#  [('okay', 'INTJ'),
#   (',', 'PUNCT'),
#   ('all', 'ADV'),
#   ('right', 'ADV'),
#   (',', 'PUNCT'),
#   ('correct', 'ADJ')],
#  [('elder', 'ADJ'), ('sister', 'NOUN')],
#  [('elder', 'ADJ'), ('brother', 'NOUN')],
#  [('tank', 'NOUN'), (',', 'PUNCT'), ('water', 'NOUN'), ('reservoir', 'NOUN')],
#  [('bag', 'PROPN'), (',', 'PUNCT'), ('purse', 'NOUN')],
#  [('country', 'NOUN'), (',', 'PUNCT'), ('land', 'NOUN')],
#  [('page', 'NOUN')],
#  [('friend', 'NOUN')],
#  [('friend', 'NOUN')],
#  [('store', 'PROPN'), (',', 'PUNCT'), ('shop', 'NOUN')],
#  [('person', 'NOUN'), (',', 'PUNCT'), ('people', 'NOUN')],
#  [('eager', 'ADJ'), ('to', 'PART'), ('learn', 'VERB')],
#  [('learned', 'VERB'), ('woman', 'NOUN')],
#  [('I', 'PRON'), ('went', 'VERB')],
#  [('I', 'PRON'), ('became', 'VERB')],
#  [('you', 'PRON'), ('went', 'VERB')],
#  [('you', 'PRON'), ('became', 'VERB')],
#  [('he', 'PRON'), ('went', 'VERB')],
#  [('he', 'PRON'), ('became', 'VERB')],
#  [('she', 'PRON'), ('went', 'VERB')],
#  [('she', 'PRON'), ('became', 'VERB')],
#  [('we', 'PRON'), ('went', 'VERB')],
#  [('we', 'PRON'), ('became', 'VERB')],
#  [('you', 'PRON'), ('went', 'VERB')],
#  [('you', 'PRON'), ('became', 'VERB')],
#  [('they', 'PRON'), ('went', 'VERB')],
#  [('they', 'PRON'), ('became', 'VERB')],
#  [('to', 'PART'), ('become', 'VERB'), (',', 'PUNCT'), ('occur', 'VERB')],
#  [('to', 'PART'), ('jump', 'VERB')],
#  [('to', 'PART'), ('call', 'VERB')],
#  [('to', 'PART'), ('bring', 'VERB')],
#  [('to', 'PART'), ('understand', 'VERB')],
#  [('to', 'PART'), ('laugh', 'VERB')],
#  [('to', 'PART'), ('fall', 'VERB')],
#  [('to', 'PART'), ('do', 'VERB'), (',', 'PUNCT'), ('make', 'VERB')],
#  [('to', 'PART'), ('hit', 'VERB'), (',', 'PUNCT'), ('strike', 'VERB')],
#  [('to', 'PART'), ('go', 'VERB')],
#  [('to', 'PART'),
#   ('watch', 'VERB'),
#   (',', 'PUNCT'),
#   ('look', 'VERB'),
#   ('at', 'ADP')],
#  [('to', 'PART'), ('write', 'VERB')],
#  [('rice', 'NOUN')],
#  [],
#  [('to', 'PART'), ('give', 'VERB')],
#  [('matter', 'ADV'),
#   (',', 'PUNCT'),
#   ('thing', 'NOUN'),
#   (',', 'PUNCT'),
#   ('topic', 'NOUN')],
#  [('it', 'PRON'), ('is', 'AUX'), ('enough', 'ADJ')],
#  [('it', 'PRON'), ('is', 'AUX'), ('not', 'PART'), ('enough', 'ADJ')],
#  [('top', 'ADJ'), ('side', 'NOUN')],
#  [('lower', 'ADJ'), ('side', 'NOUN')],
#  [('behind', 'ADV'), (',', 'PUNCT'), ('ago', 'ADV')],
#  [('rear', 'ADJ'), ('side', 'NOUN')],
#  [('all', 'ADV'), ('right', 'ADV'), (',', 'PUNCT'), ('okay', 'INTJ')],
#  [('to', 'ADP'), ('place', 'NOUN'), (',', 'PUNCT'), ('put', 'VERB')],
#  [('also', 'ADV'), ('now', 'ADV')],
#  [('side', 'NOUN'), (',', 'PUNCT'), ('direction', 'NOUN')],
#  [('room', 'NOUN'), (',', 'PUNCT'), ('chamber', 'PROPN')],
#  [('border', 'NOUN'), ('area', 'NOUN')],
#  [('to', 'PART'), ('take', 'VERB')],
#  [('very', 'ADV'),
#   (',', 'PUNCT'),
#   ('much', 'ADJ'),
#   (',', 'PUNCT'),
#   ('many', 'ADJ')],
#  [('seeing', 'VERB'),
#   (',', 'PUNCT'),
#   ('sight', 'NOUN'),
#   (',', 'PUNCT'),
#   ('ritual', 'ADJ'),
#   ('viewing', 'NOUN'),
#   ('of', 'ADP'),
#   ('an', 'DET'),
#   ('object', 'NOUN'),
#   ('of', 'ADP'),
#   ('reverence', 'NOUN')],
#  [('real', 'ADJ'), (',', 'PUNCT'), ('true', 'ADJ')],
#  [('really', 'ADV'), (',', 'PUNCT'), ('truly', 'ADV')],
#  [('region', 'PROPN'), (',', 'PUNCT'), ('area', 'NOUN')],
#  [('to', 'PART'), ('live', 'VERB')],
#  [('devotee', 'NOUN'), (',', 'PUNCT'), ('follower', 'NOUN')],
#  [('century', 'NOUN')],
#  [('just', 'ADV'),
#   ('like', 'ADP'),
#   ('that', 'PRON'),
#   (',', 'PUNCT'),
#   ('quietly', 'ADV')],
#  [('a', 'DET'),
#   ('bit', 'NOUN'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('little', 'ADJ')],
#  [('banana', 'PROPN'), ('tree', 'NOUN')],
#  [('other', 'ADJ'), (',', 'PUNCT'), ('something', 'PRON'), ('else', 'ADV')],
#  [('style', 'NOUN'), (',', 'PUNCT'), ('kind', 'ADJ')],
#  [('intolerable', 'ADJ'), (',', 'PUNCT'), ('disgusting', 'ADJ')],
#  [('to', 'PART'), ('play', 'VERB')],
#  [('liked', 'VERB'), (',', 'PUNCT'), ('appreciated', 'VERB')],
#  [('place', 'NOUN'),
#   (',', 'PUNCT'),
#   ('village', 'NOUN'),
#   (',', 'PUNCT'),
#   ('town', 'NOUN'),
#   (',', 'PUNCT'),
#   ('‘', 'PUNCT'),
#   ('native', 'ADJ'),
#   ('place', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('city', 'NOUN')],
#  [('to', 'PART'),
#   ('ask', 'VERB'),
#   (',', 'PUNCT'),
#   ('to', 'PART'),
#   ('hear', 'VERB')],
#  [('place', 'NOUN'), ('of', 'ADP'), ('pilgrimage', 'NOUN')],
#  [('place', 'NOUN'),
#   (',', 'PUNCT'),
#   ('space', 'NOUN'),
#   (',', 'PUNCT'),
#   ('spot', 'NOUN')],
#  [('younger', 'ADJ'), ('sister', 'NOUN')],
#  [],
#  [('worthy', 'ADJ'), ('of', 'ADP'), ('worship', 'NOUN')],
#  [('according', 'VERB'), ('to', 'ADP')],
#  [('human', 'ADJ'), (',', 'PUNCT'), ('person', 'NOUN')],
#  [('icon', 'NOUN'), (',', 'PUNCT'), ('statue', 'NOUN')],
#  [('firstly', 'ADV'),
#   (',', 'PUNCT'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('beginning', 'NOUN')],
#  [],
#  [('‘', 'PUNCT'),
#   ('the', 'DET'),
#   ('worldly', 'ADJ'),
#   ('system', 'NOUN'),
#   ('of', 'ADP')],
#  [('to', 'PART'), ('acquire', 'VERB'), (',', 'PUNCT'), ('achieve', 'VERB')],
#  [('housemaid', 'VERB')],
#  [('spouse', 'NOUN')],
#  [('incarnation', 'NOUN'), ('of', 'ADP'), ('a', 'DET'), ('god', 'NOUN')],
#  [('mark', 'PROPN'), (',', 'PUNCT'), ('characteristic', 'ADJ')],
#  [('too', 'ADV'), ('much', 'ADJ'), (',', 'PUNCT'), ('excessively', 'ADV')],
#  [('he', 'PRON')],
#  [('his', 'PRON'),
#   ('/', 'SYM'),
#   ('her', 'PRON'),
#   ('/', 'SYM'),
#   ('its', 'PRON'),
#   ('own', 'ADJ')],
#  [('every', 'DET'), ('day', 'NOUN')],
#  [('ritual', 'NOUN'), ('of', 'ADP'), ('worship', 'NOUN')],
#  [('something', 'PRON'), ('important', 'ADJ')],
#  [('Temple', 'PROPN'), ('Street', 'PROPN')],
#  [('foreign', 'ADJ'), ('country', 'NOUN')],
#  [('devotee', 'NOUN'),
#   ('of', 'ADP'),
#   ('Viṣṇu', 'PROPN'),
#   (',', 'PUNCT'),
#   ('Viṣṇuite', 'PROPN')],
#  [('sea', 'PROPN'), (',', 'PUNCT'), ('ocean', 'NOUN')],
#  [('near', 'ADV'), (';', 'PUNCT'), ('nearness', 'NOUN')],
#  [('much', 'ADV'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('lot', 'NOUN'),
#   (',', 'PUNCT'),
#   ('very', 'ADV')],
#  [('to', 'PART'),
#   ('descend', 'VERB'),
#   (',', 'PUNCT'),
#   ('go', 'VERB'),
#   ('down', 'ADV')],
#  [('to', 'PART'), ('steal', 'VERB')],
#  [('to', 'PART'), ('protect', 'VERB'), (',', 'PUNCT'), ('guard', 'NOUN')],
#  [('to', 'PART'), ('buy', 'VERB')],
#  [('force', 'NOUN'), (',', 'PUNCT'), ('forcefulness', 'NOUN')],
#  [('severe', 'ADJ'), (',', 'PUNCT'), ('intense', 'ADJ')],
#  [('to', 'PART'),
#   ('walk', 'VERB'),
#   (',', 'PUNCT'),
#   ('to', 'PART'),
#   ('happen', 'VERB')],
#  [('to', 'PART'),
#   ('suffer', 'VERB'),
#   (',', 'PUNCT'),
#   ('experience', 'NOUN'),
#   (',', 'PUNCT'),
#   ('undergo', 'VERB')],
#  [('to', 'PART'), ('abuse', 'VERB'), (',', 'PUNCT'), ('scold', 'VERB')],
#  [('to', 'PART'), ('grow', 'VERB')],
#  [('to', 'PART'), ('participate', 'VERB')],
#  [('to', 'PART'),
#   ('lie', 'VERB'),
#   ('down', 'ADV'),
#   (',', 'PUNCT'),
#   ('sleep', 'VERB')],
#  [('to', 'PART'), ('speak', 'VERB')],
#  [('writer', 'NOUN')],
#  [('back', 'ADV'), (',', 'PUNCT'), ('returned', 'VERB')],
#  [('tiredness', 'NOUN'), (',', 'PUNCT'), ('fatigue', 'NOUN')],
#  [('grace', 'NOUN'),
#   (',', 'PUNCT'),
#   ('elegance', 'NOUN'),
#   (',', 'PUNCT'),
#   ('beauty', 'NOUN')],
#  [('to', 'PART'),
#   ('climb', 'VERB'),
#   (';', 'PUNCT'),
#   ('to', 'PART'),
#   ('begin', 'VERB')],
#  [('song', 'NOUN'), (';', 'PUNCT'), ('to', 'PART'), ('sing', 'VERB')],
#  [('to', 'PART'), ('fly', 'VERB'), (',', 'PUNCT'), ('jump', 'VERB')],
#  [('to', 'PART'),
#   ('set', 'VERB'),
#   ('out', 'ADP'),
#   (',', 'PUNCT'),
#   ('leave', 'VERB'),
#   ('for', 'ADP')],
#  [('to', 'PART'), ('cause', 'VERB'), ('to', 'PART'), ('call', 'VERB')],
#  [('published', 'VERB'), (',', 'PUNCT'), ('public', 'ADJ')],
#  [('attempt', 'NOUN'),
#   (',', 'PUNCT'),
#   ('try', 'VERB'),
#   (',', 'PUNCT'),
#   ('effort', 'NOUN')],
#  [('fast', 'ADV'), (',', 'PUNCT'), ('soon', 'ADV')],
#  [],
#  [('strange', 'ADJ'), (',', 'PUNCT'), ('odd', 'ADJ')],
#  [('to', 'PART'), ('bloom', 'VERB'), (',', 'PUNCT'), ('blossom', 'NOUN')],
#  [('younger', 'ADJ'), ('brother', 'NOUN')],
#  [('shade', 'PROPN'), (',', 'PUNCT'), ('shadow', 'NOUN')],
#  [('word', 'NOUN'), (',', 'PUNCT'), ('utterance', 'NOUN')],
#  [('living', 'VERB'), (',', 'PUNCT'), ('dwelling', 'VERB')],
#  [('to', 'PART'),
#   ('be', 'AUX'),
#   ('obtained', 'VERB'),
#   (',', 'PUNCT'),
#   ('to', 'PART'),
#   ('be', 'AUX'),
#   ('met', 'VERB')],
#  [('news', 'NOUN'), (',', 'PUNCT'), ('message', 'NOUN')],
#  [('may', 'AUX'), ('not', 'PART')],
#  [('desire', 'NOUN'), (',', 'PUNCT'), ('wish', 'VERB')],
#  [('alcoholic', 'ADJ'), ('beverage', 'NOUN')],
#  [('i.e.', 'X'),
#   (',', 'PUNCT'),
#   ('that', 'PRON'),
#   ('is', 'AUX'),
#   ('to', 'PART'),
#   ('say', 'VERB')],
#  [('mistress', 'NOUN'), (',', 'PUNCT'), ('owner', 'NOUN')],
#  [('to', 'PART'),
#   ('be', 'AUX'),
#   ('seen', 'VERB'),
#   (',', 'PUNCT'),
#   ('appear', 'VERB')],
#  [('cause', 'NOUN'), (',', 'PUNCT'), ('reason', 'NOUN')],
#  [('knowledge', 'NOUN'), (',', 'PUNCT'), ('known', 'ADJ'), ('thing', 'NOUN')],
#  [('Indian', 'ADJ'), ('basil', 'NOUN')],
#  [('pure', 'ADJ'), (',', 'PUNCT'), ('holy', 'ADJ')],
#  [('to', 'PART'), ('worship', 'VERB')],
#  [('much', 'ADJ'),
#   (',', 'PUNCT'),
#   ('many', 'ADJ'),
#   (',', 'PUNCT'),
#   ('very', 'ADV')],
#  [('to', 'PART'), ('use', 'VERB')],
#  [('in', 'ADP'), ('the', 'DET'), ('morning', 'NOUN')],
#  [('energy', 'NOUN'), (',', 'PUNCT'), ('power', 'NOUN')],
#  [('energy', 'NOUN'), (',', 'PUNCT'), ('power', 'NOUN')],
#  [('back', 'NOUN'), ('yard', 'NOUN')],
#  [('to', 'PART'), ('fear', 'VERB')],
#  [('In', 'ADP'),
#   ('modern', 'ADJ'),
#   ('usage', 'NOUN'),
#   (',', 'PUNCT'),
#   ('these', 'DET'),
#   ('forms', 'NOUN'),
#   ('are', 'AUX'),
#   ('generally', 'ADV'),
#   ('considered', 'VERB'),
#   ('rather', 'ADV'),
#   ('old', 'ADJ'),
#   ('-', 'PUNCT'),
#   ('fash-', 'ADJ'),
#   ('ioned', 'VERB'),
#   ('and', 'CCONJ'),
#   ('hardly', 'ADV'),
#   ('occur', 'VERB'),
#   ('.', 'PUNCT'),
#   ('The', 'DET'),
#   ('main', 'ADJ'),
#   ('reason', 'NOUN'),
#   ('for', 'ADP'),
#   ('this', 'PRON'),
#   ('is', 'AUX'),
#   ('that', 'SCONJ'),
#   ('they', 'PRON'),
#   ('do', 'VERB'),
#   ('not', 'PART')],
#  [('to', 'PART'), ('experience', 'VERB')],
#  [('religious', 'ADJ'), ('experience', 'NOUN')],
#  [('some', 'DET'), ('persons', 'NOUN')],
#  [('some', 'PRON')],
#  [('group', 'NOUN'),
#   ('consciousness', 'NOUN'),
#   (',', 'PUNCT'),
#   ('‘', 'PUNCT'),
#   ('groupism', 'NOUN'),
#   ('’', 'PUNCT')],
#  [('to', 'PART'), ('believe', 'VERB')],
#  [('to', 'PART'), ('live', 'VERB')],
#  [],
#  [('human', 'ADJ'), (',', 'PUNCT'), ('person', 'NOUN')],
#  [],
#  [('something', 'PRON'), ('personal', 'ADJ')],
#  [('person', 'NOUN'), (',', 'PUNCT'), ('individual', 'ADJ')],
#  [('made', 'VERB'), ('of', 'ADP'), ('god', 'PROPN')],
#  [('pertaining', 'VERB'), ('to', 'ADP'), ('Śiva', 'PROPN')],
#  [('to', 'PART'), ('arise', 'VERB'), (',', 'PUNCT'), ('originate', 'VERB')],
#  [('religious', 'ADJ'),
#   ('discipline', 'NOUN'),
#   ('/', 'SYM'),
#   ('practice', 'NOUN')],
#  [('literary', 'ADJ'), ('work', 'NOUN')],
#  [('many', 'ADJ'), ('persons', 'NOUN')],
#  [('then', 'ADV'), (',', 'PUNCT'), ('that', 'DET'), ('time', 'NOUN')],
#  [('today', 'NOUN'),
#   ('’s', 'PART'),
#   (',', 'PUNCT'),
#   ('of', 'ADP'),
#   ('today', 'NOUN')],
#  [('of', 'ADP'), ('now', 'ADV'), (',', 'PUNCT'), ('present', 'ADJ')],
#  [('to', 'PART'), ('remain', 'VERB')],
#  [('to', 'PART'), ('learn', 'VERB')],
#  [('hill', 'PROPN'), (',', 'PUNCT'), ('hillock', 'NOUN')],
#  [('together', 'ADV'), ('with', 'ADP')],
#  [],
#  [],
#  [('main', 'ADJ'), (',', 'PUNCT'), ('chief', 'NOUN')],
#  [('life', 'NOUN'), (',', 'PUNCT'), ('life', 'NOUN'), ('force', 'NOUN')],
#  [('right', 'INTJ')],
#  [('okra', 'PROPN'),
#   (',', 'PUNCT'),
#   ('‘', 'PUNCT'),
#   ('ladies', 'NOUN'),
#   ('’', 'PUNCT'),
#   ('fingers', 'NOUN'),
#   ('’', 'PUNCT')],
#  [('beforehand', 'ADV'), (',', 'PUNCT'), ('earlier', 'ADV')],
#  [('to', 'PART'), ('continue', 'VERB')],
#  [('to', 'PART'), ('end', 'VERB')],
#  [('to', 'PART'), ('end', 'VERB'), (',', 'PUNCT'), ('finish', 'VERB')],
#  [('wandering', 'VERB'), ('ascetic', 'ADJ')],
#  [('custom', 'NOUN'), (',', 'PUNCT'), ('usage', 'NOUN')],
#  [('form', 'NOUN'), (',', 'PUNCT'), ('shape', 'NOUN')],
#  [('profit', 'NOUN'), (',', 'PUNCT'), ('advantage', 'NOUN')],
#  [('‘', 'PUNCT'),
#   ('sign', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('a', 'DET'),
#   ('particular', 'ADJ'),
#   ('depiction', 'NOUN'),
#   ('of', 'ADP'),
#   ('Śiva', 'PROPN')],
#  [('movie', 'NOUN'), ('theatre', 'NOUN')],
#  [('in', 'ADP'),
#   ('that', 'DET'),
#   ('case', 'NOUN'),
#   (',', 'PUNCT'),
#   ('if', 'SCONJ'),
#   ('that', 'PRON'),
#   ('is', 'AUX'),
#   ('so', 'ADV')],
#  [('and', 'CCONJ'), (',', 'PUNCT'), ('also', 'ADV')],
#  [],
#  [],
#  [('from', 'ADP'), ('everything', 'PRON')],
#  [('to', 'ADP'), ('everything', 'PRON')],
#  [('of', 'ADP'), ('everything', 'PRON')],
#  [('in', 'ADP'), ('everything', 'PRON')],
#  [('please', 'INTJ'),
#   ('note', 'VERB'),
#   ('down', 'ADP'),
#   ('[', 'X'),
#   ('‘', 'PUNCT'),
#   ('having', 'AUX'),
#   ('written', 'VERB'),
#   (',', 'PUNCT'),
#   ('please', 'INTJ'),
#   ('take', 'VERB'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('i.e.', 'X'),
#   (',', 'PUNCT'),
#   ('write', 'VERB'),
#   ('this', 'PRON'),
#   ('down', 'ADP'),
#   ('so', 'SCONJ'),
#   ('that', 'SCONJ'),
#   ('you', 'PRON'),
#   ('need', 'AUX'),
#   ('not', 'PART'),
#   ('remember', 'VERB'),
#   (']', 'PUNCT')],
#  [('please', 'INTJ'),
#   ('write', 'VERB'),
#   ('it', 'PRON'),
#   ('down', 'ADP'),
#   ('for', 'ADP'),
#   ('me', 'PRON'),
#   ('[', 'ADP'),
#   ('‘', 'PUNCT'),
#   ('having', 'AUX'),
#   ('written', 'VERB'),
#   (',', 'PUNCT'),
#   ('please', 'INTJ'),
#   ('give', 'VERB'),
#   ('’', 'PUNCT'),
#   (']', 'PUNCT')],
#  [('please', 'INTJ'), ('forget', 'VERB'), ('it', 'PRON'), ('!', 'PUNCT')],
#  [('do', 'AUX'),
#   ('n’t', 'PART'),
#   ('be', 'AUX'),
#   ('shy', 'ADJ'),
#   ('[', 'X'),
#   ('‘', 'PUNCT'),
#   ('do', 'AUX'),
#   ('not', 'PART'),
#   ('suffer', 'VERB'),
#   ('shyness', 'PROPN'),
#   ('’', 'PUNCT'),
#   (']', 'PUNCT')],
#  [('one', 'NUM'), (',', 'PUNCT'), ('a', 'PRON')],
#  [('one', 'NUM')],
#  [('from', 'ADP'), ('one', 'NUM')],
#  [('to', 'ADP'), ('one', 'NUM')],
#  [('of', 'ADP'), ('one', 'NUM')],
#  [('in', 'ADP'), ('one', 'NUM')],
#  [('two', 'NUM')],
#  [('to', 'ADP'), ('three', 'NUM')],
#  [('of', 'ADP'), ('four', 'NUM')],
#  [('from', 'ADP'), ('five', 'NUM')],
#  [('in', 'ADP'),
#   ('six', 'NUM'),
#   ('Often', 'ADV'),
#   (',', 'PUNCT'),
#   ('though', 'ADV'),
#   (',', 'PUNCT'),
#   ('these', 'PRON'),
#   ('inflected', 'VERB'),
#   ('forms', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('numerals', 'NOUN'),
#   ('must', 'AUX'),
#   ('be', 'AUX'),
#   ('translated', 'VERB'),
#   ('in', 'ADP'),
#   ('special', 'ADJ'),
#   ('idiomatic', 'ADJ'),
#   ('manners', 'NOUN'),
#   (':', 'PUNCT')],
#  [('1000', 'NUM'),
#   ('When', 'SCONJ'),
#   ('smaller', 'ADJ'),
#   ('numbers', 'NOUN'),
#   ('are', 'AUX'),
#   ('added', 'VERB'),
#   ('to', 'ADP'),
#   ('higher', 'ADJ'),
#   ('units', 'NOUN')],
#  [('the', 'DET'), ('first', 'ADJ'), ('one', 'NUM')],
#  [('the', 'DET'),
#   ('tenth', 'ADJ'),
#   ('man', 'NOUN'),
#   ('These', 'DET'),
#   ('new', 'ADJ'),
#   ('words', 'NOUN'),
#   ('can', 'AUX'),
#   ('of', 'ADP'),
#   ('course', 'NOUN'),
#   ('be', 'AUX'),
#   ('declined', 'VERB'),
#   (',', 'PUNCT'),
#   ('like', 'ADP'),
#   ('any', 'DET'),
#   ('pronoun', 'NOUN'),
#   ('or', 'CCONJ'),
#   ('pro-', 'X'),
#   ('nomi', 'ADJ'),
#   ('nalized', 'ADJ'),
#   ('word', 'NOUN'),
#   (':', 'PUNCT')],
#  [('in', 'ADP'), ('the', 'DET'), ('fifth', 'ADJ'), ('one', 'NUM')],
#  [('to', 'ADP'), ('the', 'DET'), ('tenth', 'ADJ'), ('man', 'NOUN')],
#  [('one', 'NUM'),
#   ('[', 'X'),
#   ('male', 'NOUN'),
#   (']', 'X'),
#   ('person', 'NOUN')],
#  [('one', 'NUM'),
#   ('[', 'X'),
#   ('female', 'ADJ'),
#   (']', 'PUNCT'),
#   ('person', 'NOUN')],
#  [('one', 'NUM'),
#   ('person', 'NOUN'),
#   ('[', 'PUNCT'),
#   ('politely', 'ADV'),
#   (',', 'PUNCT'),
#   ('or', 'CCONJ'),
#   ('neutral', 'ADJ'),
#   (']', 'PUNCT')],
#  [('two', 'NUM'), ('persons', 'NOUN')],
#  [('three', 'NUM'), ('persons', 'NOUN')],
#  [('four', 'NUM'), ('persons', 'NOUN')],
#  [('five', 'NUM'), ('persons', 'NOUN')],
#  [('to', 'PART'), ('know', 'VERB')],
#  [('I', 'PRON'), ('knew', 'VERB')],
#  [('I', 'PRON'), ('learnt', 'VERB')],
#  [('to', 'PART'), ('forget', 'VERB')],
#  [('to', 'PART'), ('say', 'VERB')],
#  [('I', 'PRON'), ('said', 'VERB')],
#  [('to', 'PART'), ('eat', 'VERB')],
#  [('I', 'PRON'), ('ate', 'VERB')],
#  [('I', 'PRON'),
#   ('abused', 'VERB'),
#   ('/', 'PUNCT'),
#   ('reviled', 'VERB'),
#   ('These', 'PRON'),
#   ('are', 'AUX'),
#   ('roots', 'NOUN'),
#   ('which', 'PRON'),
#   ('originally', 'ADV'),
#   (',', 'PUNCT'),
#   ('in', 'ADP'),
#   ('Old', 'PROPN'),
#   ('Kannada', 'PROPN'),
#   (',', 'PUNCT'),
#   ('ended', 'VERB'),
#   ('in', 'ADP'),
#   ('a', 'DET'),
#   ('consonant', 'NOUN')],
#  [('to', 'PART'),
#   ('wait', 'VERB'),
#   ('/', 'SYM'),
#   ('grow', 'VERB'),
#   ('hot', 'ADJ')],
#  [('I', 'PRON'), ('waited', 'VERB')],
#  [('to', 'PART'), ('sit', 'VERB'), ('down', 'ADP')],
#  [('I', 'PRON'), ('sat', 'VERB'), ('down', 'ADP')],
#  [('to', 'PART'), ('be', 'AUX'), ('defeated', 'VERB')],
#  [('to', 'PART'), ('sneeze', 'VERB')],
#  [('I', 'PRON'),
#   ('sneezed', 'VERB'),
#   ('It', 'PRON'),
#   ('should', 'AUX'),
#   ('be', 'AUX'),
#   ('noticed', 'VERB'),
#   ('here', 'ADV'),
#   ('that', 'SCONJ'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('case', 'NOUN'),
#   ('of', 'ADP'),
#   ('some', 'PRON'),
#   ('of', 'ADP'),
#   ('these', 'DET'),
#   ('verbs', 'NOUN'),
#   (',', 'PUNCT'),
#   ('more', 'ADV')],
#  [('to', 'PART'), ('throw', 'VERB')],
#  [('to', 'PART'), ('aim', 'VERB')],
#  [('to', 'PART'),
#   ('sink', 'VERB'),
#   ('down', 'ADP'),
#   ('/', 'PUNCT'),
#   ('collapse', 'VERB')],
#  [('to', 'PART'), ('rot', 'VERB')],
#  [('to', 'PART'), ('be', 'AUX'), ('tired', 'ADJ')],
#  [('to', 'PART'), ('be', 'AUX'), ('obtained', 'VERB')],
#  [('to', 'PART'), ('solder', 'VERB')],
#  [('to', 'AUX'), ('whet', 'VERB')],
#  [('to', 'PART'), ('sprout', 'VERB')],
#  [('to', 'PART'),
#   ('speak', 'VERB'),
#   ('falsehood', 'NOUN'),
#   ('/', 'SYM'),
#   ('lie', 'NOUN')],
#  [('to', 'PART'), ('choose', 'VERB')],
#  [('to', 'PART'), ('carry', 'VERB'), ('off', 'ADP')],
#  [('to', 'PART'), ('reap', 'VERB'), (',', 'PUNCT'), ('pluck', 'VERB')],
#  [('to', 'PART'), ('make', 'VERB')],
#  [('to', 'PART'), ('grind', 'VERB')],
#  [('to', 'PART'), ('become', 'VERB'), ('wet', 'ADJ')],
#  [('to', 'PART'), ('be', 'AUX'), ('hidden', 'VERB')],
#  [('to', 'PART'), ('graze', 'VERB')],
#  [('to', 'PART'), ('sigh', 'VERB')],
#  [('to', 'PART'), ('cross', 'VERB'), ('over', 'ADP')],
#  [('to', 'PART'), ('become', 'VERB'), ('branched', 'ADJ')],
#  [('to', 'PART'), ('sprout', 'VERB')],
#  [('to', 'PART'), ('perspire', 'VERB')],
#  [('to', 'PART'), ('stink', 'VERB')],
#  [('to', 'PART'), ('be', 'AUX')],
#  [('to', 'PART'), ('pay', 'VERB')],
#  [('to', 'PART'), ('be', 'AUX'), ('bored', 'VERB')],
#  [('to', 'PART'), ('give', 'VERB'), ('birth', 'NOUN')],
#  [('to', 'PART'), ('bear', 'VERB'), ('a', 'DET'), ('burden', 'NOUN')],
#  [('to', 'PART'), ('kill', 'VERB')],
#  [('to', 'PART'), ('win', 'VERB'), (',', 'PUNCT'), ('overcome', 'VERB')],
#  [('to', 'PART'), ('stand', 'VERB')],
#  [('to', 'PART'), ('weep', 'VERB')],
#  [('to', 'PART'), ('plough', 'VERB')],
#  [('to', 'PART'), ('rise', 'VERB')],
#  [('to', 'PART'), ('steal', 'VERB')],
#  [('to', 'PART'), ('pluck', 'VERB'), (',', 'PUNCT'), ('pick', 'VERB')],
#  [],
#  [('be', 'AUX'), ('burnt', 'VERB')],
#  [('to', 'PART'), ('bathe', 'VERB')],
#  [('to', 'PART'), ('cook', 'VERB')],
#  [('to', 'PART'), ('dress', 'VERB')],
#  [('to', 'PART'), ('be', 'AUX'), ('spoilt', 'VERB')],
#  [('to', 'PART'), ('dress', 'VERB')],
#  [('to', 'PART'), ('plant', 'VERB')],
#  [('to', 'PART'), ('leave', 'VERB')],
#  [('to', 'PART'), ('burn', 'VERB')],
#  [('to', 'PART'), ('eat', 'VERB')],
#  [('to', 'PART'), ('see', 'VERB')],
#  [('to', 'PART'), ('enter', 'VERB')],
#  [('Alternative', 'ADJ'),
#   ('abbreviated', 'VERB'),
#   ('forms', 'NOUN'),
#   (':', 'PUNCT')],
#  [('to', 'PART'), ('kick', 'VERB')],
#  [('to', 'PART'), ('put', 'VERB'), ('on', 'ADP')],
#  [('to', 'PART'), ('pull', 'VERB')],
#  [('to', 'PART'), ('take', 'VERB')],
#  [('barbarian', 'PROPN'), (',', 'PUNCT'), ('foreigner', 'NOUN')],
#  [('that', 'PRON')],
#  [('good', 'ADJ'), ('thing', 'NOUN')],
#  [('if', 'SCONJ'),
#   ('[', 'X'),
#   ('one', 'NUM'),
#   (']', 'PUNCT'),
#   ('learns', 'VERB')],
#  [('is', 'AUX'), ('good', 'ADJ')],
#  [('grace', 'NOUN'), (',', 'PUNCT'), ('mercy', 'NOUN')],
#  [('us', 'PRON')],
#  [('they', 'PRON'), ('stand', 'VERB')],
#  [('they', 'PRON'), ('come', 'VERB')],
#  [('tree', 'NOUN'), (',', 'PUNCT'), ('wood', 'NOUN')],
#  [('you', 'PRON'), ('will', 'AUX'), ('like', 'VERB')],
#  [('glorious', 'ADJ'), (',', 'PUNCT'), ('successful', 'ADJ')],
#  [('circle', 'NOUN'), ('of', 'ADP'), ('fire', 'NOUN')],
#  [],
#  [('to', 'PART'), ('arise', 'VERB'), (',', 'PUNCT'), ('originate', 'VERB')],
#  [('to', 'PART'), ('create', 'VERB')],
#  [('‘', 'PUNCT'),
#   ('in', 'ADP'),
#   ('the', 'DET'),
#   ('hand', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('with', 'ADP'),
#   (',', 'PUNCT'),
#   ('near', 'ADP')],
#  [('defect', 'NOUN'), (',', 'PUNCT'), ('shortcoming', 'VERB')],
#  [('‘', 'PUNCT'),
#   ('bearer', 'NOUN'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('Ganges', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('Śiva', 'PROPN')],
#  [('‘', 'PUNCT'),
#   ('who', 'PRON'),
#   ('has', 'VERB'),
#   ('the', 'DET'),
#   ('moon', 'NOUN'),
#   ('on', 'ADP'),
#   ('his', 'PRON'),
#   ('crest', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('Śiva', 'PROPN')],
#  [],
#  [],
#  [('‘', 'PUNCT'),
#   ('who', 'PRON'),
#   ('drank', 'VERB'),
#   ('poison', 'NOUN'),
#   ('’', 'PUNCT')],
#  [('destruction', 'NOUN'), (',', 'PUNCT'), ('ruin', 'PROPN')],
#  [],
#  [('‘', 'PUNCT'),
#   ('white', 'ADJ'),
#   ('like', 'ADP'),
#   ('jasmine', 'NOUN'),
#   ('’', 'PUNCT')],
#  [('greatness', 'NOUN'), (',', 'PUNCT'), ('importance', 'NOUN')],
#  [('stripe', 'ADJ'), (',', 'PUNCT'), ('line', 'NOUN')],
#  [('place', 'NOUN'), ('of', 'ADP'), ('residence', 'NOUN')],
#  [('holy', 'PROPN'),
#   ('ash', 'PROPN'),
#   ('as', 'SCONJ'),
#   ('used', 'VERB'),
#   ('by', 'ADP'),
#   ('the', 'DET'),
#   ('devotees', 'NOUN'),
#   ('of', 'ADP'),
#   ('Śiva', 'PROPN')],
#  [('devotee', 'NOUN'), ('of', 'ADP'), ('Śiva', 'NOUN')],
#  [('religiously', 'ADV'), ('liberated', 'VERB'), ('person', 'NOUN')],
#  [('‘', 'PUNCT'),
#   ('who', 'PRON'),
#   ('has', 'VERB'),
#   ('the', 'DET'),
#   ('moon', 'NOUN'),
#   ('on', 'ADP'),
#   ('his', 'PRON'),
#   ('crest', 'NOUN'),
#   ('’', 'PUNCT'),
#   (',', 'PUNCT'),
#   ('Śiva', 'PROPN')],
#  [('nature', 'NOUN'), (',', 'PUNCT'), ('character', 'NOUN')],
#  [('to', 'PART'), ('smear', 'VERB'), (',', 'PUNCT'), ('apply', 'VERB')]]

# %%
# Show all POS tags for the first 10 sentences
for i, tags in enumerate(kannada_pos_tags[:100]):
    print(tags, f" - ({kannada_1word_transliterations[i]})")
# Out:
# [('to', 'PART'), ('run', 'VERB')]  - (ōḍu)
# [('to', 'PART'), ('read', 'VERB')]  - (ōdu)
# [('to', 'PART'), ('say', 'VERB')]  - (hēḷu)
# [('to', 'PART'), ('shit', 'VERB')]  - (hēlu)
# [('to', 'PART'), ('beat', 'VERB')]  - (baḍi)
# [('interest', 'NOUN')]  - (baḍḍi)
# [('ritually', 'ADV'), ('pure', 'ADJ')]  - (maḍi)
# [('please', 'INTJ'), ('do', 'VERB'), ('The', 'DET'), ('two', 'NUM'), ('following', 'VERB'), ('pairs', 'NOUN'), ('of', 'ADP'), ('words', 'NOUN'), ('are', 'AUX'), ('prosodically', 'ADV'), ('similar', 'ADJ')]  - (māḍi)
# [('you', 'PRON')]  - (nīnu)
# [('you', 'PRON')]  - (nīvu)
# [('it', 'PRON'), ('/', 'PUNCT'), ('that', 'PRON')]  - (adu)
# [('they', 'PRON')]  - (avaru)
# [('they', 'PRON')]  - (avu)
# [('it', 'PRON'), ('/', 'PUNCT'), ('this', 'PRON')]  - (idu)
# [('he', 'PRON'), ('/', 'SYM'), ('she', 'PRON')]  - (ivaru)
# [('they', 'PRON'), ('/', 'PUNCT'), ('these', 'PRON')]  - (ivu)
# [('in', 'ADP'), ('this', 'DET'), ('manner', 'NOUN')]  - (hīge)
# [('in', 'ADP'), ('that', 'DET'), ('manner', 'NOUN')]  - (hāge)
# [('in', 'ADP'), ('which', 'PRON'), ('manner', 'NOUN'), ('?', 'PUNCT')]  - (hēge)
# [('this', 'PRON'), ('much', 'ADJ')]  - (iṣṭu)
# [('that', 'ADV'), ('much', 'ADV')]  - (aṣṭu)
# [('how', 'SCONJ'), ('much', 'ADJ'), ('?', 'PUNCT')]  - (eṣṭu)
# [('it', 'PRON'), ('is', 'AUX'), (',', 'PUNCT'), ('it', 'PRON'), ('exists', 'VERB')]  - (ide)
# [('mouse', 'PROPN'), (',', 'PUNCT'), ('rat', 'CCONJ')]  - (ili)
# [('leg', 'PROPN'), (',', 'PUNCT'), ('foot', 'NOUN')]  - (kālu)
# [('hand', 'NOUN'), (',', 'PUNCT'), ('arm', 'VERB')]  - (kai)
# [('book', 'NOUN'), (',', 'PUNCT'), ('volume', 'NOUN')]  - (graṃtha)
# [('big', 'ADJ'), (',', 'PUNCT'), ('large', 'ADJ')]  - (doḍḍa)
# []  - (paṃce)
# [('ballpoint', 'PROPN'), ('pen', 'NOUN')]  - (pennu)
# [('pair', 'NOUN'), ('of', 'ADP'), ('trousers', 'NOUN')]  - (pyāṃṭu)
# [('hill', 'PROPN'), (',', 'PUNCT'), ('mountain', 'NOUN')]  - (beṭṭa)
# [('old', 'ADJ'), ('woman', 'NOUN')]  - (muduki)
# [('lawn', 'PROPN'), (',', 'PUNCT'), ('field', 'NOUN')]  - (maidāna)
# [('young', 'ADJ'), ('woman', 'NOUN')]  - (yuvati)
# []  - (luṃgi)
# [('[', 'X'), ('male', 'NOUN'), (']', 'X'), ('student', 'NOUN')]  - (vidyārthi)
# [('[', 'X'), ('female', 'ADJ'), (']', 'PUNCT'), ('student', 'NOUN')]  - (vidyārthini)
# []  - (Viṣṇu)
# []  - (Śiva)
# [('cow', 'NOUN'), ('dung', 'PROPN')]  - (sagaṇi)
# [('things', 'NOUN'), (',', 'PUNCT'), ('belongings', 'NOUN')]  - (sāmānugaḷu)
# []  - (sīre)
# [('singer', 'NOUN')]  - (hāḍugāra)
# [('singer', 'NOUN')]  - (hāḍugārti)
# []  - (Namaskāra.)
# [('Yes', 'INTJ'), (',', 'PUNCT'), ('you', 'PRON'), ('may', 'AUX'), ('go', 'VERB')]  - (Banni.)
# [('How', 'SCONJ'), ('are', 'AUX'), ('you', 'PRON'), ('?', 'PUNCT'), ('Gururāja', 'NOUN')]  - (Hēgiddīri?)
# [('his', 'PRON'), ('/', 'SYM'), ('her', 'PRON')]  - (ivara)
# [('from', 'ADP'), ('where', 'SCONJ'), ('?', 'PUNCT')]  - (elliṃda)
# [('nicely', 'ADV'), (',', 'PUNCT'), ('finely', 'ADV')]  - (cennāgi)
# [('your', 'PRON')]  - (nimma)
# [('please', 'INTJ'), ('come', 'VERB')]  - (banni)
# [('I', 'PRON'), ('should', 'AUX'), ('come', 'VERB')]  - (barali)
# [('to', 'PART'), ('come', 'VERB')]  - (baru)
# [('bus', 'NOUN')]  - (bassu)
# [('is', 'AUX'), ('wanted', 'VERB'), ('/', 'SYM'), ('required', 'VERB'), ('/', 'SYM'), ('needed', 'VERB')]  - (bēku)
# [('is', 'AUX'), ('not', 'PART'), ('wanted', 'VERB'), ('/', 'PUNCT'), ('not', 'PART'), ('required', 'VERB')]  - (bēḍa)
# [('something', 'PRON'), ('special', 'ADJ')]  - (viśēṣa)
# [('okay', 'INTJ'), (',', 'PUNCT'), ('all', 'ADV'), ('right', 'ADV'), (',', 'PUNCT'), ('correct', 'ADJ')]  - (sari)
# [('elder', 'ADJ'), ('sister', 'NOUN')]  - (akka)
# [('elder', 'ADJ'), ('brother', 'NOUN')]  - (aṇṇa)
# [('tank', 'NOUN'), (',', 'PUNCT'), ('water', 'NOUN'), ('reservoir', 'NOUN')]  - (kere)
# [('bag', 'PROPN'), (',', 'PUNCT'), ('purse', 'NOUN')]  - (cīla)
# [('country', 'NOUN'), (',', 'PUNCT'), ('land', 'NOUN')]  - (dēśa)
# [('page', 'NOUN')]  - (puṭa)
# [('friend', 'NOUN')]  - (snēhita)
# [('friend', 'NOUN')]  - (snēhite)
# [('store', 'PROPN'), (',', 'PUNCT'), ('shop', 'NOUN')]  - (aṃgaḍi)
# [('person', 'NOUN'), (',', 'PUNCT'), ('people', 'NOUN')]  - (jana)
# [('eager', 'ADJ'), ('to', 'PART'), ('learn', 'VERB')]  - (jijñāsu)
# [('learned', 'VERB'), ('woman', 'NOUN')]  - (paṃḍite)
# [('I', 'PRON'), ('went', 'VERB')]  - (hōdenu)
# [('I', 'PRON'), ('became', 'VERB')]  - (ādenu)
# [('you', 'PRON'), ('went', 'VERB')]  - (hōdi)
# [('you', 'PRON'), ('became', 'VERB')]  - (ādi)
# [('he', 'PRON'), ('went', 'VERB')]  - (hōdanu)
# [('he', 'PRON'), ('became', 'VERB')]  - (ādanu)
# [('she', 'PRON'), ('went', 'VERB')]  - (hōdaḷu)
# [('she', 'PRON'), ('became', 'VERB')]  - (ādaḷu)
# [('we', 'PRON'), ('went', 'VERB')]  - (hōdevu)
# [('we', 'PRON'), ('became', 'VERB')]  - (ādevu)
# [('you', 'PRON'), ('went', 'VERB')]  - (hōdiri)
# [('you', 'PRON'), ('became', 'VERB')]  - (ādiri)
# [('they', 'PRON'), ('went', 'VERB')]  - (hōdaru)
# [('they', 'PRON'), ('became', 'VERB')]  - (ādaru)
# [('to', 'PART'), ('become', 'VERB'), (',', 'PUNCT'), ('occur', 'VERB')]  - (āgu)
# [('to', 'PART'), ('jump', 'VERB')]  - (jigi)
# [('to', 'PART'), ('call', 'VERB')]  - (kare)
# [('to', 'PART'), ('bring', 'VERB')]  - (taru)
# [('to', 'PART'), ('understand', 'VERB')]  - (tiḷi)
# [('to', 'PART'), ('laugh', 'VERB')]  - (nagu)
# [('to', 'PART'), ('fall', 'VERB')]  - (bīḷu)
# [('to', 'PART'), ('do', 'VERB'), (',', 'PUNCT'), ('make', 'VERB')]  - (māḍu)
# [('to', 'PART'), ('hit', 'VERB'), (',', 'PUNCT'), ('strike', 'VERB')]  - (hoḍe)
# [('to', 'PART'), ('go', 'VERB')]  - (hōgu)
# [('to', 'PART'), ('watch', 'VERB'), (',', 'PUNCT'), ('look', 'VERB'), ('at', 'ADP')]  - (nōḍu)
# [('to', 'PART'), ('write', 'VERB')]  - (bare)
# [('rice', 'NOUN')]  - (anna)
# []  - (ūṭa)

# %%
# Map the transliterations to the POS tags
kannada_pos_mapping = {}
for i, tags in enumerate(kannada_pos_tags):
    transliteration = kannada_1word_transliterations[i]
    kannada_pos_mapping[transliteration] = [pos for word, pos in tags]  

kannada_pos_mapping
# Out:
# {'ōḍu': ['PART', 'VERB'],
#  'ōdu': ['PART', 'VERB'],
#  'hēḷu': ['PART', 'VERB'],
#  'hēlu': ['PART', 'VERB'],
#  'baḍi': ['PART', 'VERB'],
#  'baḍḍi': ['NOUN'],
#  'maḍi': ['ADV', 'ADJ'],
#  'māḍi': ['INTJ',
#   'VERB',
#   'DET',
#   'NUM',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'ADJ'],
#  'nīnu': ['PRON'],
#  'nīvu': ['PRON'],
#  'adu': ['PRON', 'PUNCT', 'PRON'],
#  'avaru': ['PRON'],
#  'avu': ['PRON'],
#  'idu': ['PRON', 'PUNCT', 'PRON'],
#  'ivaru': ['PRON', 'SYM', 'PRON'],
#  'ivu': ['PRON', 'PUNCT', 'PRON'],
#  'hīge': ['ADP', 'DET', 'NOUN'],
#  'hāge': ['ADP', 'DET', 'NOUN'],
#  'hēge': ['ADP', 'PRON', 'NOUN', 'PUNCT'],
#  'iṣṭu': ['PRON', 'ADJ'],
#  'aṣṭu': ['ADV', 'ADV'],
#  'eṣṭu': ['SCONJ', 'ADJ', 'PUNCT'],
#  'ide': ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'],
#  'ili': ['PROPN', 'PUNCT', 'CCONJ'],
#  'kālu': ['PROPN', 'PUNCT', 'NOUN'],
#  'kai': ['NOUN', 'PUNCT', 'VERB'],
#  'graṃtha': ['NOUN', 'PUNCT', 'NOUN'],
#  'doḍḍa': ['ADJ', 'PUNCT', 'ADJ'],
#  'paṃce': [],
#  'pennu': ['PROPN', 'NOUN'],
#  'pyāṃṭu': ['NOUN', 'ADP', 'NOUN'],
#  'beṭṭa': ['PROPN', 'PUNCT', 'NOUN'],
#  'muduki': ['ADJ', 'NOUN'],
#  'maidāna': ['PROPN', 'PUNCT', 'NOUN'],
#  'yuvati': ['ADJ', 'NOUN'],
#  'luṃgi': [],
#  'vidyārthi': ['X', 'NOUN', 'X', 'NOUN'],
#  'vidyārthini': ['X', 'ADJ', 'PUNCT', 'NOUN'],
#  'Viṣṇu': [],
#  'Śiva': [],
#  'sagaṇi': ['NOUN', 'PROPN'],
#  'sāmānugaḷu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sīre': [],
#  'hāḍugāra': ['NOUN'],
#  'hāḍugārti': ['NOUN'],
#  'Namaskāra.': [],
#  'Banni.': ['INTJ', 'PUNCT', 'PRON', 'AUX', 'VERB'],
#  'Hēgiddīri?': ['SCONJ', 'AUX', 'PRON', 'PUNCT', 'NOUN'],
#  'ivara': ['PRON', 'SYM', 'PRON'],
#  'elliṃda': ['ADP', 'SCONJ', 'PUNCT'],
#  'cennāgi': ['ADV', 'PUNCT', 'ADV'],
#  'nimma': ['PRON'],
#  'banni': ['INTJ', 'VERB'],
#  'barali': ['PRON', 'AUX', 'VERB'],
#  'baru': ['PART', 'VERB'],
#  'bassu': ['NOUN'],
#  'bēku': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'],
#  'bēḍa': ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'viśēṣa': ['PRON', 'ADJ'],
#  'sari': ['INTJ', 'PUNCT', 'ADV', 'ADV', 'PUNCT', 'ADJ'],
#  'akka': ['ADJ', 'NOUN'],
#  'aṇṇa': ['ADJ', 'NOUN'],
#  'kere': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'cīla': ['PROPN', 'PUNCT', 'NOUN'],
#  'dēśa': ['NOUN', 'PUNCT', 'NOUN'],
#  'puṭa': ['NOUN'],
#  'snēhita': ['NOUN'],
#  'snēhite': ['NOUN'],
#  'aṃgaḍi': ['PROPN', 'PUNCT', 'NOUN'],
#  'jana': ['NOUN', 'PUNCT', 'NOUN'],
#  'jijñāsu': ['ADJ', 'PART', 'VERB'],
#  'paṃḍite': ['VERB', 'NOUN'],
#  'hōdenu': ['PRON', 'VERB'],
#  'ādenu': ['PRON', 'VERB'],
#  'hōdi': ['PRON', 'VERB'],
#  'ādi': ['PRON', 'VERB'],
#  'hōdanu': ['PRON', 'VERB'],
#  'ādanu': ['PRON', 'VERB'],
#  'hōdaḷu': ['PRON', 'VERB'],
#  'ādaḷu': ['PRON', 'VERB'],
#  'hōdevu': ['PRON', 'VERB'],
#  'ādevu': ['PRON', 'VERB'],
#  'hōdiri': ['PRON', 'VERB'],
#  'ādiri': ['PRON', 'VERB'],
#  'hōdaru': ['PRON', 'VERB'],
#  'ādaru': ['PRON', 'VERB'],
#  'āgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'jigi': ['PART', 'VERB'],
#  'kare': ['PART', 'VERB'],
#  'taru': ['PART', 'VERB'],
#  'tiḷi': ['PART', 'VERB'],
#  'nagu': ['PART', 'VERB'],
#  'bīḷu': ['PART', 'VERB'],
#  'māḍu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hoḍe': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hōgu': ['PART', 'VERB'],
#  'nōḍu': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADP'],
#  'bare': ['PART', 'VERB'],
#  'anna': ['NOUN'],
#  'ūṭa': [],
#  'koḍu': ['PART', 'VERB'],
#  'viṣaya': ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'sāku': ['PRON', 'AUX', 'ADJ'],
#  'sāladu': ['PRON', 'AUX', 'PART', 'ADJ'],
#  'mēlu': ['ADJ', 'NOUN'],
#  'keḷagu': ['ADJ', 'NOUN'],
#  'hiṃde': ['ADV', 'PUNCT', 'ADV'],
#  'hiṃdu': ['ADJ', 'NOUN'],
#  'āyitu': ['ADV', 'ADV', 'PUNCT', 'INTJ'],
#  'iḍu': ['ADP', 'NOUN', 'PUNCT', 'VERB'],
#  'īgalū': ['ADV', 'ADV'],
#  'kaḍe': ['NOUN', 'PUNCT', 'NOUN'],
#  'kōṇe': ['NOUN', 'PUNCT', 'PROPN'],
#  'gaḍipradēśa': ['NOUN', 'NOUN'],
#  'tagoḷḷu': ['PART', 'VERB'],
#  'tuṃba': ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'],
#  'darśana': ['VERB',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN'],
#  'nija': ['ADJ', 'PUNCT', 'ADJ'],
#  'nijavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'pradēśa': ['PROPN', 'PUNCT', 'NOUN'],
#  'bāḷu': ['PART', 'VERB'],
#  'bhakta': ['NOUN', 'PUNCT', 'NOUN'],
#  'śatamāna': ['NOUN'],
#  'summane': ['ADV', 'ADP', 'PRON', 'PUNCT', 'ADV'],
#  'svalpa': ['DET', 'NOUN', 'PUNCT', 'DET', 'ADJ'],
#  'bāḷe': ['PROPN', 'NOUN'],
#  'bēre': ['ADJ', 'PUNCT', 'PRON', 'ADV'],
#  'rīti': ['NOUN', 'PUNCT', 'ADJ'],
#  'asahya': ['ADJ', 'PUNCT', 'ADJ'],
#  'āḍu': ['PART', 'VERB'],
#  'iṣṭa': ['VERB', 'PUNCT', 'VERB'],
#  'ūru': ['NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN'],
#  'kēḷu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'kṣētra': ['NOUN', 'ADP', 'NOUN'],
#  'jāga': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'taṃgi': ['ADJ', 'NOUN'],
#  'tīrthaṃkara': [],
#  'pūjārha': ['ADJ', 'ADP', 'NOUN'],
#  'prakāra': ['VERB', 'ADP'],
#  'manuṣya': ['ADJ', 'PUNCT', 'NOUN'],
#  'mūrti': ['NOUN', 'PUNCT', 'NOUN'],
#  'modalu': ['ADV', 'PUNCT', 'ADP', 'DET', 'NOUN'],
#  'mōkṣa': [],
#  'saṃsāra': ['PUNCT', 'DET', 'ADJ', 'NOUN', 'ADP'],
#  'hoṃdu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'kelasadavaḷu': ['VERB'],
#  'maneyavaru': ['NOUN'],
#  'avatāra': ['NOUN', 'ADP', 'DET', 'NOUN'],
#  'gurutu': ['PROPN', 'PUNCT', 'ADJ'],
#  'jāsti': ['ADV', 'ADJ', 'PUNCT', 'ADV'],
#  'taṃdaru': ['PRON'],
#  'tanna': ['PRON', 'SYM', 'PRON', 'SYM', 'PRON', 'ADJ'],
#  'divasā': ['DET', 'NOUN'],
#  'pūje': ['NOUN', 'ADP', 'NOUN'],
#  'mukhya': ['PRON', 'ADJ'],
#  'rathabīdi': ['PROPN', 'PROPN'],
#  'vidēśa': ['ADJ', 'NOUN'],
#  'vaiṣṇava': ['NOUN', 'ADP', 'PROPN', 'PUNCT', 'PROPN'],
#  'samudra': ['PROPN', 'PUNCT', 'NOUN'],
#  'hattira': ['ADV', 'PUNCT', 'NOUN'],
#  'heccu': ['ADV', 'PUNCT', 'DET', 'NOUN', 'PUNCT', 'ADV'],
#  'iḷi': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADV'],
#  'kadi': ['PART', 'VERB'],
#  'kāpāḍu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'koḷḷu': ['PART', 'VERB'],
#  'jōru': ['NOUN', 'PUNCT', 'NOUN'],
#  'tīvra': ['ADJ', 'PUNCT', 'ADJ'],
#  'naḍe': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'paḍu': ['PART', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'VERB'],
#  'bayyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'beḷe': ['PART', 'VERB'],
#  'bhāgavahisu': ['PART', 'VERB'],
#  'malagu': ['PART', 'VERB', 'ADV', 'PUNCT', 'VERB'],
#  'mātanāḍu': ['PART', 'VERB'],
#  'lēkhaki': ['NOUN'],
#  'vāpasu': ['ADV', 'PUNCT', 'VERB'],
#  'sustu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sogasu': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'hattu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'hāḍu': ['NOUN', 'PUNCT', 'PART', 'VERB'],
#  'hāru': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'horaḍu': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB', 'ADP'],
#  'kareyisu': ['PART', 'VERB', 'PART', 'VERB'],
#  'prakaṭa': ['VERB', 'PUNCT', 'ADJ'],
#  'prayatna': ['NOUN', 'PUNCT', 'VERB', 'PUNCT', 'NOUN'],
#  'bēga': ['ADV', 'PUNCT', 'ADV'],
#  'mēṣṭaru': [],
#  'vicitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'araḷu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'tamma': ['ADJ', 'NOUN'],
#  'neraḷu': ['PROPN', 'PUNCT', 'NOUN'],
#  'mātu': ['NOUN', 'PUNCT', 'NOUN'],
#  'vāsa': ['VERB', 'PUNCT', 'VERB'],
#  'sigu': ['PART', 'AUX', 'VERB', 'PUNCT', 'PART', 'AUX', 'VERB'],
#  'suddi': ['NOUN', 'PUNCT', 'NOUN'],
#  'bāradu': ['AUX', 'PART'],
#  'āse': ['NOUN', 'PUNCT', 'VERB'],
#  'heṃḍa': ['ADJ', 'NOUN'],
#  'eṃdare': ['X', 'PUNCT', 'PRON', 'AUX', 'PART', 'VERB'],
#  'oḍati': ['NOUN', 'PUNCT', 'NOUN'],
#  'kāṇisu': ['PART', 'AUX', 'VERB', 'PUNCT', 'VERB'],
#  'kāraṇa': ['NOUN', 'PUNCT', 'NOUN'],
#  'gottu': ['NOUN', 'PUNCT', 'ADJ', 'NOUN'],
#  'tuḷasi': ['ADJ', 'NOUN'],
#  'pavitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'pūjisu': ['PART', 'VERB'],
#  'bahaḷa': ['ADJ', 'PUNCT', 'ADJ', 'PUNCT', 'ADV'],
#  'baḷasu': ['PART', 'VERB'],
#  'beḷigge': ['ADP', 'DET', 'NOUN'],
#  'śakti': ['NOUN', 'PUNCT', 'NOUN'],
#  'śukravāra': ['NOUN', 'PUNCT', 'NOUN'],
#  'hittalu': ['NOUN', 'NOUN'],
#  'hedaru': ['PART', 'VERB'],
#  'kareyavu': ['ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'VERB',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'AUX',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'PART'],
#  'anubhavisu': ['PART', 'VERB'],
#  'anubhāva': ['ADJ', 'NOUN'],
#  'kelavaru': ['DET', 'NOUN'],
#  'kelavu': ['PRON'],
#  'guṃpugārike': ['NOUN', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT'],
#  'naṃbu': ['PART', 'VERB'],
#  'baduku': ['PART', 'VERB'],
#  'Basavaṇṇa': [],
#  'mānava': ['ADJ', 'PUNCT', 'NOUN'],
#  'vacana': [],
#  'vaiyaktika': ['PRON', 'ADJ'],
#  'vyakti': ['NOUN', 'PUNCT', 'ADJ'],
#  'śivamaya': ['VERB', 'ADP', 'PROPN'],
#  'śaiva': ['VERB', 'ADP', 'PROPN'],
#  'saṃbhavisu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'sādhane': ['ADJ', 'NOUN', 'SYM', 'NOUN'],
#  'sāhityakṛti': ['ADJ', 'NOUN'],
#  'halavaru': ['ADJ', 'NOUN'],
#  'āga': ['ADV', 'PUNCT', 'DET', 'NOUN'],
#  'ivattina': ['NOUN', 'PART', 'PUNCT', 'ADP', 'NOUN'],
#  'īgina': ['ADP', 'ADV', 'PUNCT', 'ADJ'],
#  'uḷi': ['PART', 'VERB'],
#  'kali': ['PART', 'VERB'],
#  'guḍḍa': ['PROPN', 'PUNCT', 'NOUN'],
#  'jotege': ['ADV', 'ADP'],
#  'dharmādhikāri': [],
#  'neṃṭa': [],
#  'pradhāna': ['ADJ', 'PUNCT', 'NOUN'],
#  'prāṇa': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'balakaḍe': ['INTJ'],
#  'beṃḍekāyi': ['PROPN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'muṃcitavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'muṃduvari': ['PART', 'VERB'],
#  'mugi': ['PART', 'VERB'],
#  'mugisu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'yati': ['VERB', 'ADJ'],
#  'rūḍhi': ['NOUN', 'PUNCT', 'NOUN'],
#  'rūpa': ['NOUN', 'PUNCT', 'NOUN'],
#  'lābha': ['NOUN', 'PUNCT', 'NOUN'],
#  'liṃga': ['PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'sinima': ['NOUN', 'NOUN'],
#  'hāgādare': ['ADP', 'DET', 'NOUN', 'PUNCT', 'SCONJ', 'PRON', 'AUX', 'ADV'],
#  'hāgū': ['CCONJ', 'PUNCT', 'ADV'],
#  'haṇṇugaḷellavu': [],
#  'vidyārthigaḷellaru': [],
#  'elladariṃda': ['ADP', 'PRON'],
#  'elladakke': ['ADP', 'PRON'],
#  'elladara': ['ADP', 'PRON'],
#  'elladaralli': ['ADP', 'PRON'],
#  'baredukoḷḷi': ['INTJ',
#   'VERB',
#   'ADP',
#   'X',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'SCONJ',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'PUNCT'],
#  'baredukoḍi': ['INTJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADP',
#   'PRON',
#   'ADP',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT'],
#  'maretubiḍi!': ['INTJ', 'VERB', 'PRON', 'PUNCT'],
#  'saṃkōcapaḍabēḍa': ['AUX',
#   'PART',
#   'AUX',
#   'ADJ',
#   'X',
#   'PUNCT',
#   'AUX',
#   'PART',
#   'VERB',
#   'PROPN',
#   'PUNCT',
#   'PUNCT'],
#  'oṃdu': ['NUM', 'PUNCT', 'PRON'],
#  'oṃdannu': ['NUM'],
#  'oṃdariṃda': ['ADP', 'NUM'],
#  'oṃdakke': ['ADP', 'NUM'],
#  'oṃdara': ['ADP', 'NUM'],
#  'oṃdaralli': ['ADP', 'NUM'],
#  'eraḍannu': ['NUM'],
#  'mūrakke': ['ADP', 'NUM'],
#  'nālkara': ['ADP', 'NUM'],
#  'aidariṃda': ['ADP', 'NUM'],
#  'āraralli': ['ADP',
#   'NUM',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'sāvira': ['NUM',
#   'SCONJ',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN'],
#  'oṃdaneyadu': ['DET', 'ADJ', 'NUM'],
#  'hattaneyavanu': ['DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'X',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'aidaneyadaralli': ['ADP', 'DET', 'ADJ', 'NUM'],
#  'hattaneyavanige': ['ADP', 'DET', 'ADJ', 'NOUN'],
#  'obbanu': ['NUM', 'X', 'NOUN', 'X', 'NOUN'],
#  'obbaḷu': ['NUM', 'X', 'ADJ', 'PUNCT', 'NOUN'],
#  'obbaru': ['NUM', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'CCONJ', 'ADJ', 'PUNCT'],
#  'ibbaru': ['NUM', 'NOUN'],
#  'mūvaru': ['NUM', 'NOUN'],
#  'nālvaru': ['NUM', 'NOUN'],
#  'aivaru': ['NUM', 'NOUN'],
#  'ari': ['PART', 'VERB'],
#  'aritenu': ['PRON', 'VERB'],
#  'kalitenu': ['PRON', 'VERB'],
#  'mare': ['PART', 'VERB'],
#  'ennu': ['PART', 'VERB'],
#  'eṃdenu': ['PRON', 'VERB'],
#  'tinnu': ['PART', 'VERB'],
#  'tiṃdenu': ['PRON', 'VERB'],
#  'baydenu': ['PRON',
#   'VERB',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'PUNCT',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN'],
#  'kāyu': ['PART', 'VERB', 'SYM', 'VERB', 'ADJ'],
#  'kādenu': ['PRON', 'VERB'],
#  'kuḷiru': ['PART', 'VERB', 'ADP'],
#  'kuḷitenu': ['PRON', 'VERB', 'ADP'],
#  'sōlu': ['PART', 'AUX', 'VERB'],
#  'sīnu': ['PART', 'VERB'],
#  'sītenu': ['PRON',
#   'VERB',
#   'PRON',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADV',
#   'SCONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADV'],
#  'ese': ['PART', 'VERB'],
#  'kuri': ['PART', 'VERB'],
#  'kusi': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB'],
#  'koḷe': ['PART', 'VERB'],
#  'caḷi': ['PART', 'AUX', 'ADJ'],
#  'dore': ['PART', 'AUX', 'VERB'],
#  'bese': ['PART', 'VERB'],
#  'mase': ['AUX', 'VERB'],
#  'moḷe': ['PART', 'VERB'],
#  'husi': ['PART', 'VERB', 'NOUN', 'SYM', 'NOUN'],
#  'āyu': ['PART', 'VERB'],
#  'oyyu': ['PART', 'VERB', 'ADP'],
#  'koyyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'geyyu': ['PART', 'VERB'],
#  'tēyu': ['PART', 'VERB'],
#  'toyyu': ['PART', 'VERB', 'ADJ'],
#  'māyu': ['PART', 'AUX', 'VERB'],
#  'mēyu': ['PART', 'VERB'],
#  'suyyu': ['PART', 'VERB'],
#  'hāyu': ['PART', 'VERB', 'ADP'],
#  'kavalu': ['PART', 'VERB', 'ADJ'],
#  'ciguru': ['PART', 'VERB'],
#  'bevaru': ['PART', 'VERB'],
#  'nāru': ['PART', 'VERB'],
#  'iru': ['PART', 'AUX'],
#  'teru': ['PART', 'VERB'],
#  'bēsaru': ['PART', 'AUX', 'VERB'],
#  'heru': ['PART', 'VERB', 'NOUN'],
#  'horu': ['PART', 'VERB', 'DET', 'NOUN'],
#  'kollu': ['PART', 'VERB'],
#  'gellu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'nillu': ['PART', 'VERB'],
#  'aḷu': ['PART', 'VERB'],
#  'uḷu': ['PART', 'VERB'],
#  'ēḷu': ['PART', 'VERB'],
#  'kaḷu': ['PART', 'VERB'],
#  'kīḷu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'biddu': [],
#  'bēyu': ['AUX', 'VERB'],
#  'mīyu': ['PART', 'VERB'],
#  'aḍu': ['PART', 'VERB'],
#  'uḍu': ['PART', 'VERB'],
#  'keḍu': ['PART', 'AUX', 'VERB'],
#  'toḍu': ['PART', 'VERB'],
#  'neḍu': ['PART', 'VERB'],
#  'biḍu': ['PART', 'VERB'],
#  'suḍu': ['PART', 'VERB'],
#  'uṇṇu': ['PART', 'VERB'],
#  'kāṇu': ['PART', 'VERB'],
#  'hogu': ['PART', 'VERB'],
#  'hokku': ['ADJ', 'VERB', 'NOUN', 'PUNCT'],
#  'ode': ['PART', 'VERB'],
#  'hode': ['PART', 'VERB', 'ADP'],
#  'eḷe': ['PART', 'VERB'],
#  'tege': ['PART', 'VERB'],
#  'mlēccha': ['PROPN', 'PUNCT', 'NOUN'],
#  'adannu': ['PRON'],
#  'oḷḷeyadu': ['ADJ', 'NOUN'],
#  'kalitare': ['SCONJ', 'X', 'NUM', 'PUNCT', 'VERB'],
#  'cennāgide': ['AUX', 'ADJ'],
#  'daya': ['NOUN', 'PUNCT', 'NOUN'],
#  'namage': ['PRON'],
#  'niṃtiddāre': ['PRON', 'VERB'],
#  'baruttāre': ['PRON', 'VERB'],
#  'mara': ['NOUN', 'PUNCT', 'NOUN'],
#  'meccuviri': ['PRON', 'AUX', 'VERB'],
#  'yaśasvi': ['ADJ', 'PUNCT', 'ADJ'],
#  'agnimaṃḍala': ['NOUN', 'ADP', 'NOUN'],
#  'apasmara': [],
#  'uṃṭāgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'uṃṭumāḍu': ['PART', 'VERB'],
#  'kaiyalli': ['PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'ADP'],
#  'korate': ['NOUN', 'PUNCT', 'VERB'],
#  'gaṃgādhara': ['PUNCT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'caṃdraśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'tāṃḍava': [],
#  'nakk-': [],
#  'naṃjuṃḍa': ['PUNCT', 'PRON', 'VERB', 'NOUN', 'PUNCT'],
#  'nāśa': ['NOUN', 'PUNCT', 'PROPN'],
#  'Madhvācārya': [],
#  'mallikārjuna': ['PUNCT', 'ADJ', 'ADP', 'NOUN', 'PUNCT'],
#  'mahatva': ['NOUN', 'PUNCT', 'NOUN'],
#  'rēkhē': ['ADJ', 'PUNCT', 'NOUN'],
#  'vāsasthaḷa': ['NOUN', 'ADP', 'NOUN'],
#  'vibhūti': ['PROPN',
#   'PROPN',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'śivabhakta': ['NOUN', 'ADP', 'NOUN'],
#  'siddhapuruṣa': ['ADV', 'VERB', 'NOUN'],
#  'sōmaśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'svabhāva': ['NOUN', 'PUNCT', 'NOUN'],
#  'haccu': ['PART', 'VERB', 'PUNCT', 'VERB']}

# %%
# POS Tagging for all other sentences
other_sentences_sentences = [item['english'] for item in other_sentences]

other_sentences_transliterations = [item['transliteration'] for item in other_sentences]
other_pos_tags = pos_tagging(other_sentences_sentences)
# Out:
# 100%|██████████| 393/393 [00:01<00:00, 202.42it/s]

# %%
# Display first 10 items from other pos tags
for i, tags in enumerate(other_pos_tags[:10]):
    print(f"{i+1}. Transliteration: {other_sentences_transliterations[i]}")
    for word, pos in tags:
        print(f"   {word}: {pos}")
    
    transliteration = other_sentences_transliterations[i].lower()
    transliteration = transliteration.strip()
    # Remove any trailing punctuation
    transliteration = transliteration.rstrip('.,!?')
    # Print the transliteration

    transliteration = transliteration.split()
    # Check if the transliteration is in the pos_mapping
    for word in transliteration:
        word = word.lower()
        if word in pos_mapping:
            print(f"POS tags for {word}: {pos_mapping[word]}")
        elif word in kannada_pos_mapping:
            print(f"POS tags for {word}: {kannada_pos_mapping[word]}")
        else:
            print(f"No POS tags found for {word}")
    print("=========================================")
# Out:
# 1. Transliteration: Idu pustaka.
#    This: PRON
#    is: AUX
#    a: DET
#    book: NOUN
#    .: PUNCT
# POS tags for idu: ['PRON']
# POS tags for pustaka: ['NOUN']
# =========================================
# 2. Transliteration: Ivu pustakagaḷu.
#    These: PRON
#    are: AUX
#    books: NOUN
#    .: PUNCT
# POS tags for ivu: ['PRON', 'PUNCT', 'PRON']
# No POS tags found for pustakagaḷu
# =========================================
# 3. Transliteration: Adu mara.
#    That: PRON
#    is: AUX
#    a: DET
#    tree: NOUN
#    .: PUNCT
# POS tags for adu: ['PRON']
# POS tags for mara: ['NOUN']
# =========================================
# 4. Transliteration: Avu maragaḷu.
#    Those: PRON
#    are: AUX
#    trees: NOUN
#    .: PUNCT
# POS tags for avu: ['PRON']
# No POS tags found for maragaḷu
# =========================================
# 5. Transliteration: Adu huḍuga.
#    That: PRON
#    is: AUX
#    a: DET
#    boy: NOUN
#    .: PUNCT
# POS tags for adu: ['PRON']
# POS tags for huḍuga: ['PROPN']
# =========================================
# 6. Transliteration: Adu mane.
#    That: PRON
#    is: AUX
#    a: DET
#    house: NOUN
#    .: PUNCT
# POS tags for adu: ['PRON']
# POS tags for mane: ['NOUN']
# =========================================
# 7. Transliteration: Avu manegaḷu.
#    Those: PRON
#    are: AUX
#    houses: NOUN
#    .: PUNCT
# POS tags for avu: ['PRON']
# No POS tags found for manegaḷu
# =========================================
# 8. Transliteration: Adu mahiḷe.
#    That: PRON
#    is: AUX
#    a: DET
#    lady: NOUN
#    .: PUNCT
# POS tags for adu: ['PRON']
# POS tags for mahiḷe: ['PROPN']
# =========================================
# 9. Transliteration: Nānu vidyārthi.
#    I: PRON
#    am: AUX
#    a: DET
#    [: X
#    male: NOUN
#    ]: X
#    student: NOUN
#    .: PUNCT
# POS tags for nānu: ['PRON']
# POS tags for vidyārthi: ['X', 'NOUN', 'X', 'NOUN']
# =========================================
# 10. Transliteration: Nānu vidyārthini.
#    I: PRON
#    am: AUX
#    a: DET
#    [: X
#    female: ADJ
#    ]: PUNCT
#    student: NOUN
#    .: PUNCT
# POS tags for nānu: ['PRON']
# POS tags for vidyārthini: ['X', 'ADJ', 'PUNCT', 'NOUN']
# =========================================

# %%
all_pos_mapping = {}
# Combine all mappings  
all_pos_mapping.update(pos_mapping)
all_pos_mapping.update(kannada_pos_mapping)

all_pos_mapping
# Out:
# {'huḷi': ['ADJ'],
#  'huli': ['NOUN'],
#  'haḷḷi': ['NOUN'],
#  'halli': ['NOUN'],
#  'maṇe': ['PROPN'],
#  'mane': ['NOUN'],
#  'hālu': ['NOUN'],
#  'hallu': ['VERB'],
#  'dēva': ['PROPN'],
#  'devva': ['PROPN'],
#  'nānu': ['PRON'],
#  'nāvu': ['PRON'],
#  'avanu': ['PRON'],
#  'avaḷu': ['PRON'],
#  'ivanu': ['PRON'],
#  'ivaḷu': ['PRON'],
#  'illi': ['ADV'],
#  'alli': ['ADV'],
#  'elli': ['SCONJ', 'PUNCT'],
#  'īga': ['ADV'],
#  'āga': ['ADV', 'PUNCT', 'DET', 'NOUN'],
#  'adu': ['PRON', 'PUNCT', 'PRON'],
#  'almāri': ['NOUN'],
#  'ākāśa': ['NOUN'],
#  'idu': ['PRON', 'PUNCT', 'PRON'],
#  'innoṃdu': ['PRON'],
#  'ivattu': ['NOUN'],
#  'ūṭa': [],
#  'ūru': ['NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN'],
#  'eraḍu': ['NUM'],
#  'aidu': ['NUM'],
#  'oṃdu': ['NUM', 'PUNCT', 'PRON'],
#  'kaṃpyūṭaru': ['NOUN'],
#  'kaṭṭaḍa': ['VERB'],
#  'kāgada': ['NOUN'],
#  'kāḍu': ['NOUN'],
#  'kāru': ['NOUN'],
#  'kiṭaki': ['NOUN'],
#  'kurci': ['NOUN'],
#  'gilāsu': ['NOUN'],
#  'guri': ['NOUN'],
#  'guru': ['NOUN'],
#  'guruvāra': ['PROPN'],
#  'camaca': ['VERB'],
#  'cāku': ['NOUN'],
#  'cāpe': ['NOUN'],
#  'cāvi': ['ADJ'],
#  'citra': ['NOUN'],
#  'ṭyāksi': ['NOUN'],
#  'ṭyūbulaiṭu': ['NOUN'],
#  'taṭṭe': ['NOUN'],
#  'tuṃba': ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'],
#  'dīpa': ['PROPN'],
#  'dēvasthāna': ['PROPN'],
#  'nālku': ['NUM'],
#  'nāḷe': ['NOUN'],
#  'nela': ['NOUN'],
#  'noṇa': ['VERB'],
#  'pustaka': ['NOUN'],
#  'pensilu': ['NOUN'],
#  'phorenar': ['NOUN'],
#  'phōrku': ['NOUN'],
#  'bāgilu': ['NOUN'],
#  'budhavāra': ['PROPN'],
#  'beṃki': ['NOUN'],
#  'bēli': ['NOUN'],
#  'bhāratīya': ['ADJ'],
#  'maṃgaḷavāra': ['PROPN'],
#  'mattu': ['CCONJ'],
#  'manuṣya': ['ADJ', 'PUNCT', 'NOUN'],
#  'mara': ['NOUN', 'PUNCT', 'NOUN'],
#  'mahiḷe': ['PROPN'],
#  'maḷe': ['NOUN'],
#  'māle': ['VERB'],
#  'mūru': ['NUM'],
#  'mēju': ['NOUN'],
#  'mēṇabatti': ['NOUN'],
#  'mōḍa': ['PROPN'],
#  'ravivāra': ['PROPN'],
#  'raste': ['NOUN'],
#  'rikṣā': ['NOUN'],
#  'vimāna': ['NOUN'],
#  'śanivāra': ['PROPN'],
#  'śukravāra': ['NOUN', 'PUNCT', 'NOUN'],
#  'sūṭkēsu': ['NOUN'],
#  'sūrya': ['PROPN'],
#  'sōmavāra': ['PROPN'],
#  'strī': ['NOUN'],
#  'hakki': ['NOUN'],
#  'halavu': ['ADJ'],
#  'hasu': ['NOUN'],
#  'hāḍu': ['NOUN', 'PUNCT', 'PART', 'VERB'],
#  'hippi': ['VERB'],
#  'huḍuga': ['PROPN'],
#  'huḍugi': ['NOUN'],
#  'hū': ['NOUN'],
#  'heṃgasu': ['NOUN'],
#  'hola': ['NOUN'],
#  'haudu': ['INTJ'],
#  'yāvāgalū illa': ['ADV'],
#  'ēnū illa': ['PRON'],
#  'yārū illa': ['PRON'],
#  'ide': ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'],
#  'ēke': ['SCONJ', 'PUNCT'],
#  'ēnu': ['PRON', 'PUNCT'],
#  'kappu': ['ADJ'],
#  'kaṣṭa': ['ADJ'],
#  'toḍaku': ['NOUN'],
#  'nanna': ['PRON'],
#  'namma': ['PRON'],
#  'patra': ['NOUN'],
#  'purōhita': ['NOUN'],
#  'biḷi': ['PROPN'],
#  'maneyavaru': ['NOUN'],
#  'yāru': ['PRON', 'PUNCT'],
#  'yāva': ['PRON', 'PUNCT'],
#  'yāvāga': ['SCONJ', 'PUNCT'],
#  'samācāra': ['NOUN'],
#  'hesaru': ['NOUN'],
#  'hēge': ['ADP', 'PRON', 'NOUN', 'PUNCT'],
#  'appa': ['PROPN'],
#  'amma': ['NOUN'],
#  'kaṇṇu': ['NOUN'],
#  'kivi': ['NOUN'],
#  'kuri': ['PART', 'VERB'],
#  'kūsu': ['NOUN'],
#  'gaṃḍa': ['NOUN'],
#  'gaṃḍasu': ['NOUN'],
#  'nighaṃṭu': ['PROPN'],
#  'nīru': ['NOUN'],
#  'buṭṭi': ['NOUN'],
#  'maga': ['NOUN'],
#  'magaḷu': ['NOUN'],
#  'magu': ['NOUN'],
#  'māva': ['NOUN'],
#  'rāja': ['NOUN'],
#  'raita': ['NOUN'],
#  'vidhave': ['NOUN'],
#  'anubhava': ['VERB'],
#  'āṭike': ['NOUN'],
#  'āyke': ['NOUN'],
#  'keṃpu': ['PROPN'],
#  'koṃbu': ['NOUN'],
#  'koṃbe': ['NOUN'],
#  'cūpu': ['ADJ'],
#  'tudi': ['NOUN'],
#  'parimāṇa': ['NOUN'],
#  'baṭṭe': ['NOUN'],
#  'baṇṇa': ['NOUN'],
#  'bēre': ['ADJ', 'PUNCT', 'PRON', 'ADV'],
#  'saṃkhye': ['NOUN'],
#  'hasiru': ['ADJ'],
#  'haḷadi': ['ADJ'],
#  'heṃḍati': ['NOUN'],
#  'nidde': ['NOUN'],
#  'nāyi': ['NOUN'],
#  'kathe': ['NOUN'],
#  'kelasa': ['NOUN'],
#  'toṃdare': ['NOUN'],
#  'nenne': ['NOUN'],
#  'satya': ['NOUN'],
#  'haṇa': ['NOUN'],
#  'haṇṇu': ['NOUN'],
#  'mēle': ['ADP'],
#  'keḷage': ['ADP'],
#  'oḷage': ['ADP'],
#  'oḷagu': ['ADP'],
#  'hattira': ['ADV', 'PUNCT', 'NOUN'],
#  'bage': ['VERB'],
#  'madhya': ['ADJ'],
#  'muṃde': ['ADP'],
#  'horage': ['ADV'],
#  'aḍige': ['VERB'],
#  'uttara': ['NOUN'],
#  'kāpi': ['NOUN'],
#  'gaḍi': ['NOUN'],
#  'cahā': ['NOUN'],
#  'padārtha': ['NOUN'],
#  'pavāḍa': ['NOUN'],
#  'viśēṣavāda': ['ADJ'],
#  'vaiṣṇava': ['NOUN', 'ADP', 'PROPN', 'PUNCT', 'PROPN'],
#  'samādhi': ['NOUN'],
#  'ele': ['VERB'],
#  'athavā': ['CCONJ'],
#  'abhiprāya': ['NOUN'],
#  'iḍiya': ['ADJ'],
#  'upayukta': ['ADJ'],
#  'keṭṭa': ['ADJ'],
#  'kliṣṭa': ['VERB'],
#  'gaddala': ['NOUN'],
#  'cakravarti': ['NOUN'],
#  'cikka': ['ADJ'],
#  'jagattu': ['NOUN'],
#  'dūra': ['NOUN'],
#  'nīli': ['ADJ'],
#  'praśne': ['NOUN'],
#  'bīdi': ['PROPN'],
#  'bhāra': ['NOUN'],
#  'bhārata': ['PROPN'],
#  'mukhya': ['PRON', 'ADJ'],
#  'yuga': ['NOUN'],
#  'saṃgīta': ['NOUN'],
#  'suṃdara': ['ADJ'],
#  'kelavu': ['PRON'],
#  'kōlu': ['VERB'],
#  'ciṃtaka': ['NOUN'],
#  'tīra': ['PROPN'],
#  'bhakta': ['NOUN', 'PUNCT', 'NOUN'],
#  'maṭha': ['VERB'],
#  'Madhvācārya': [],
#  'śatamāna': ['NOUN'],
#  'saṃpradāya': ['NOUN'],
#  'hadimūraneya': ['NOUN'],
#  'āphisu': ['NOUN'],
#  'oraṭu': ['NOUN'],
#  'krūra': ['ADJ'],
#  'khuśi': ['NOUN'],
#  'tiṃgaḷu': ['NOUN'],
#  'dayaviṭṭu': ['INTJ'],
#  'pāṭha': ['NOUN'],
#  'prayatna': ['NOUN', 'PUNCT', 'VERB', 'PUNCT', 'NOUN'],
#  'muṃdina': ['ADV'],
#  'yōcane': ['VERB'],
#  'vākya': ['VERB'],
#  'śabda': ['NOUN'],
#  'saṃtōṣa': ['NOUN'],
#  'sammēḷana': ['NOUN'],
#  'spaṣṭa': ['ADJ'],
#  'artha': ['VERB'],
#  'ādare': ['CCONJ'],
#  'kṣame': ['NOUN'],
#  'daya': ['NOUN', 'PUNCT', 'NOUN'],
#  'hōṭalu': ['NOUN'],
#  'adhyāpaka': ['NOUN'],
#  'kōpa': ['NOUN'],
#  'graṃthapālaka': ['PROPN'],
#  'graṃthālaya': ['NOUN'],
#  'patrike': ['NOUN'],
#  'sahāya': ['VERB'],
#  'hemme': ['NOUN'],
#  'hōguvike': ['VERB'],
#  'bāḷike': ['VERB'],
#  'ārōgya': ['NOUN'],
#  'gōḍe': ['NOUN'],
#  'gōva': ['PROPN'],
#  'jōru': ['NOUN', 'PUNCT', 'NOUN'],
#  'tinnu': ['PART', 'VERB'],
#  'māṃsa': ['NOUN'],
#  'miliṭari': ['NOUN'],
#  'miliṭari hōṭalu': ['ADJ', 'ADJ', 'NOUN'],
#  'auṣadhi': ['NOUN'],
#  'kaṭṭe': ['VERB'],
#  'giḍa': ['NOUN'],
#  'dēvi': ['NOUN'],
#  'patni': ['NOUN'],
#  'pradakṣiṇe': ['NOUN'],
#  'bhakti': ['NOUN'],
#  'mātra': ['ADV'],
#  'saṃpattu': ['NOUN'],
#  'sādhya': ['ADJ'],
#  'sulabha': ['ADJ'],
#  'saubhāgya': ['ADV', 'PUNCT', 'NOUN'],
#  'atṛpta': ['ADJ'],
#  'atṛpti': ['NOUN'],
#  'anubhāvi': ['ADJ'],
#  'anuyāyi': ['NOUN'],
#  'asamānate': ['NOUN'],
#  'ityādi': ['X', 'X'],
#  'kuṭuṃba': ['NOUN'],
#  'kelavomme': ['ADV'],
#  'guṃpu': ['NOUN'],
#  'jāti': ['NOUN'],
#  'jīvana': ['NOUN'],
#  'tṛpta': ['ADJ'],
#  'tṛpti': ['NOUN'],
#  'dhārmika': ['ADJ'],
#  'naitika': ['ADJ'],
#  'paraṃpare': ['NOUN'],
#  'prapaṃca': ['NOUN'],
#  'prācīna': ['ADJ'],
#  'prīti': ['NOUN'],
#  'Basava': ['PUNCT', 'NOUN', 'PUNCT'],
#  'beḷavaṇige': ['NOUN'],
#  'maṃdi': ['NOUN'],
#  'manassu': ['NOUN'],
#  'samāna': ['ADJ'],
#  'samānate': ['NOUN'],
#  'sāmājika': ['ADJ'],
#  'hiṃde': ['ADV', 'PUNCT', 'ADV'],
#  'hinnele': ['NOUN'],
#  'hosa': ['ADJ'],
#  'anēka': ['ADJ'],
#  'ippataidu': ['NUM', 'PUNCT', 'NUM'],
#  'ēkeṃdare': ['SCONJ'],
#  'omme': ['ADV'],
#  'karāvaḷi': ['PROPN'],
#  'kaḷatmaka': ['ADJ'],
#  'kāphi': ['NOUN'],
#  'kāryakrama': ['NOUN'],
#  'kuḍuma': ['PUNCT', 'NOUN', 'PUNCT'],
#  'kēṃdra': ['NOUN'],
#  'caḷi': ['PART', 'AUX', 'ADJ'],
#  'cikitsālaya': ['NOUN'],
#  'jille': ['NOUN'],
#  'taṃde': ['PROPN'],
#  'takṣaṇa': ['ADV'],
#  'tale': ['NOUN'],
#  'talenōvu': ['PROPN'],
#  'dēvate': ['NOUN'],
#  'Dharmasthaḷa': ['PUNCT', 'NOUN', 'PUNCT'],
#  'nōvu': ['NOUN'],
#  'paṃḍita': ['NOUN'],
#  'pūrvaja': ['NOUN'],
#  'Maṃjunātha': ['PUNCT', 'NOUN', 'PUNCT'],
#  'yātrika': ['NOUN'],
#  'rakṣaṇe': ['NOUN'],
#  'varegū': ['ADP'],
#  'varṣa': ['NOUN'],
#  'Vādirāja': ['PUNCT', 'NOUN', 'PUNCT'],
#  'śikṣaka': ['NOUN'],
#  'saṃgrahālaya': ['NOUN'],
#  'sahiṣṇute': ['NOUN'],
#  'sāṃskṛtika': ['ADJ'],
#  'sāvira': ['NUM',
#   'SCONJ',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN'],
#  'sāvirāru': ['NOUN'],
#  'sumāru': ['ADV'],
#  'hadināraneya': ['ADJ'],
#  'huṣāru': ['NOUN'],
#  'ellarannu / ellarannū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellariṃda / ellariṃdalū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellara': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellaralli / ellarallū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'āru': ['NUM'],
#  'ēḷu': ['PART', 'VERB'],
#  'eṃṭu': ['NUM'],
#  'oṃbattu': ['NUM'],
#  'hannoṃdu': ['NUM'],
#  'hanneraḍu': ['NUM'],
#  'hadimūru': ['NUM'],
#  'hadinālku': ['NUM'],
#  'hadinaidu': ['NUM'],
#  'hadināru': ['NUM'],
#  'hadinēḷu': ['X'],
#  'hadineṃṭu': ['NUM'],
#  'hattoṃbattu': ['NUM'],
#  'ippattu': ['NUM'],
#  'ippattoṃdu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteraḍu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattanālku': ['NUM', 'PUNCT', 'NUM'],
#  'ippattaidu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattāru': ['NUM', 'PUNCT', 'NUM'],
#  'ippattēḷu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteṃṭu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattoṃbattu': ['NUM', 'PUNCT', 'NUM'],
#  'aivattu': ['NUM'],
#  'aravattu': ['NUM'],
#  'eppattu': ['NUM'],
#  'eṃbattu': ['NUM'],
#  'toṃbattu': ['NUM'],
#  'nūru': ['NUM'],
#  'innūru': ['NUM'],
#  'munnūru': ['NUM'],
#  'nānūru': ['NUM'],
#  'ainūru': ['NUM'],
#  'ārunūru': ['NUM'],
#  'ēḷunūru': ['NUM'],
#  'eṃṭunūru': ['NUM'],
#  'oṃbainūru': ['NUM'],
#  'nūra nalvattoṃdu': ['NUM'],
#  'sāvirada oṃbainūra toṃbattaidu': ['NUM'],
#  'āgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'hōgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'utkhanana': ['NOUN'],
#  'hagga': ['NOUN'],
#  'heccu': ['ADV', 'PUNCT', 'DET', 'NOUN', 'PUNCT', 'ADV'],
#  'ajja': ['NOUN'],
#  'jñāna': ['NOUN'],
#  'daḍḍa': ['NOUN'],
#  'kobbu': ['ADJ'],
#  'udbhava': ['NOUN'],
#  'ayya': ['PROPN'],
#  'prabhāva': ['NOUN'],
#  'tatva': ['NOUN'],
#  'utsava': ['NOUN'],
#  'kaḷḷa': ['NOUN'],
#  'aparūpavāgi': ['ADV'],
#  'jana': ['NOUN', 'PUNCT', 'NOUN'],
#  'bahaḷa': ['ADJ', 'PUNCT', 'ADJ', 'PUNCT', 'ADV'],
#  'bhāṣe': ['NOUN'],
#  'yāvāgalū': ['ADV'],
#  'haḷeya': ['ADJ'],
#  'aṃgaḍiyavaru': ['NOUN'],
#  'ajñāna': ['NOUN'],
#  'gottu': ['NOUN', 'PUNCT', 'ADJ', 'NOUN'],
#  'nṛtya': ['VERB'],
#  'paravā': ['VERB'],
#  'parvata': ['NOUN'],
#  'baḷi': ['ADP'],
#  'buddhi': ['NOUN'],
#  'beḷaku': ['ADJ'],
#  'bhasma': ['PROPN'],
#  'majjige': ['NOUN'],
#  'mūgu': ['NOUN'],
#  'modalaneya': ['ADV'],
#  'rākṣasa': ['NOUN'],
#  'rūpa': ['NOUN', 'PUNCT', 'NOUN'],
#  'vimānanildāṇa': ['NOUN'],
#  'vaiṣṇavadharma': ['NOUN'],
#  'saṃkēta': ['NOUN'],
#  'saṃsthe': ['PROPN'],
#  'sāṃkētika': ['ADJ'],
#  'sāmānya': ['ADJ'],
#  'haṇe': ['PROPN'],
#  'ōḍu': ['PART', 'VERB'],
#  'ōdu': ['PART', 'VERB'],
#  'hēḷu': ['PART', 'VERB'],
#  'hēlu': ['PART', 'VERB'],
#  'baḍi': ['PART', 'VERB'],
#  'baḍḍi': ['NOUN'],
#  'maḍi': ['ADV', 'ADJ'],
#  'māḍi': ['INTJ',
#   'VERB',
#   'DET',
#   'NUM',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'ADJ'],
#  'nīnu': ['PRON'],
#  'nīvu': ['PRON'],
#  'avaru': ['PRON'],
#  'avu': ['PRON'],
#  'ivaru': ['PRON', 'SYM', 'PRON'],
#  'ivu': ['PRON', 'PUNCT', 'PRON'],
#  'hīge': ['ADP', 'DET', 'NOUN'],
#  'hāge': ['ADP', 'DET', 'NOUN'],
#  'iṣṭu': ['PRON', 'ADJ'],
#  'aṣṭu': ['ADV', 'ADV'],
#  'eṣṭu': ['SCONJ', 'ADJ', 'PUNCT'],
#  'ili': ['PROPN', 'PUNCT', 'CCONJ'],
#  'kālu': ['PROPN', 'PUNCT', 'NOUN'],
#  'kai': ['NOUN', 'PUNCT', 'VERB'],
#  'graṃtha': ['NOUN', 'PUNCT', 'NOUN'],
#  'doḍḍa': ['ADJ', 'PUNCT', 'ADJ'],
#  'paṃce': [],
#  'pennu': ['PROPN', 'NOUN'],
#  'pyāṃṭu': ['NOUN', 'ADP', 'NOUN'],
#  'beṭṭa': ['PROPN', 'PUNCT', 'NOUN'],
#  'muduki': ['ADJ', 'NOUN'],
#  'maidāna': ['PROPN', 'PUNCT', 'NOUN'],
#  'yuvati': ['ADJ', 'NOUN'],
#  'luṃgi': [],
#  'vidyārthi': ['X', 'NOUN', 'X', 'NOUN'],
#  'vidyārthini': ['X', 'ADJ', 'PUNCT', 'NOUN'],
#  'Viṣṇu': [],
#  'Śiva': [],
#  'sagaṇi': ['NOUN', 'PROPN'],
#  'sāmānugaḷu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sīre': [],
#  'hāḍugāra': ['NOUN'],
#  'hāḍugārti': ['NOUN'],
#  'Namaskāra.': [],
#  'Banni.': ['INTJ', 'PUNCT', 'PRON', 'AUX', 'VERB'],
#  'Hēgiddīri?': ['SCONJ', 'AUX', 'PRON', 'PUNCT', 'NOUN'],
#  'ivara': ['PRON', 'SYM', 'PRON'],
#  'elliṃda': ['ADP', 'SCONJ', 'PUNCT'],
#  'cennāgi': ['ADV', 'PUNCT', 'ADV'],
#  'nimma': ['PRON'],
#  'banni': ['INTJ', 'VERB'],
#  'barali': ['PRON', 'AUX', 'VERB'],
#  'baru': ['PART', 'VERB'],
#  'bassu': ['NOUN'],
#  'bēku': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'],
#  'bēḍa': ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'viśēṣa': ['PRON', 'ADJ'],
#  'sari': ['INTJ', 'PUNCT', 'ADV', 'ADV', 'PUNCT', 'ADJ'],
#  'akka': ['ADJ', 'NOUN'],
#  'aṇṇa': ['ADJ', 'NOUN'],
#  'kere': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'cīla': ['PROPN', 'PUNCT', 'NOUN'],
#  'dēśa': ['NOUN', 'PUNCT', 'NOUN'],
#  'puṭa': ['NOUN'],
#  'snēhita': ['NOUN'],
#  'snēhite': ['NOUN'],
#  'aṃgaḍi': ['PROPN', 'PUNCT', 'NOUN'],
#  'jijñāsu': ['ADJ', 'PART', 'VERB'],
#  'paṃḍite': ['VERB', 'NOUN'],
#  'hōdenu': ['PRON', 'VERB'],
#  'ādenu': ['PRON', 'VERB'],
#  'hōdi': ['PRON', 'VERB'],
#  'ādi': ['PRON', 'VERB'],
#  'hōdanu': ['PRON', 'VERB'],
#  'ādanu': ['PRON', 'VERB'],
#  'hōdaḷu': ['PRON', 'VERB'],
#  'ādaḷu': ['PRON', 'VERB'],
#  'hōdevu': ['PRON', 'VERB'],
#  'ādevu': ['PRON', 'VERB'],
#  'hōdiri': ['PRON', 'VERB'],
#  'ādiri': ['PRON', 'VERB'],
#  'hōdaru': ['PRON', 'VERB'],
#  'ādaru': ['PRON', 'VERB'],
#  'āgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'jigi': ['PART', 'VERB'],
#  'kare': ['PART', 'VERB'],
#  'taru': ['PART', 'VERB'],
#  'tiḷi': ['PART', 'VERB'],
#  'nagu': ['PART', 'VERB'],
#  'bīḷu': ['PART', 'VERB'],
#  'māḍu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hoḍe': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hōgu': ['PART', 'VERB'],
#  'nōḍu': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADP'],
#  'bare': ['PART', 'VERB'],
#  'anna': ['NOUN'],
#  'koḍu': ['PART', 'VERB'],
#  'viṣaya': ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'sāku': ['PRON', 'AUX', 'ADJ'],
#  'sāladu': ['PRON', 'AUX', 'PART', 'ADJ'],
#  'mēlu': ['ADJ', 'NOUN'],
#  'keḷagu': ['ADJ', 'NOUN'],
#  'hiṃdu': ['ADJ', 'NOUN'],
#  'āyitu': ['ADV', 'ADV', 'PUNCT', 'INTJ'],
#  'iḍu': ['ADP', 'NOUN', 'PUNCT', 'VERB'],
#  'īgalū': ['ADV', 'ADV'],
#  'kaḍe': ['NOUN', 'PUNCT', 'NOUN'],
#  'kōṇe': ['NOUN', 'PUNCT', 'PROPN'],
#  'gaḍipradēśa': ['NOUN', 'NOUN'],
#  'tagoḷḷu': ['PART', 'VERB'],
#  'darśana': ['VERB',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN'],
#  'nija': ['ADJ', 'PUNCT', 'ADJ'],
#  'nijavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'pradēśa': ['PROPN', 'PUNCT', 'NOUN'],
#  'bāḷu': ['PART', 'VERB'],
#  'summane': ['ADV', 'ADP', 'PRON', 'PUNCT', 'ADV'],
#  'svalpa': ['DET', 'NOUN', 'PUNCT', 'DET', 'ADJ'],
#  'bāḷe': ['PROPN', 'NOUN'],
#  'rīti': ['NOUN', 'PUNCT', 'ADJ'],
#  'asahya': ['ADJ', 'PUNCT', 'ADJ'],
#  'āḍu': ['PART', 'VERB'],
#  'iṣṭa': ['VERB', 'PUNCT', 'VERB'],
#  'kēḷu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'kṣētra': ['NOUN', 'ADP', 'NOUN'],
#  'jāga': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'taṃgi': ['ADJ', 'NOUN'],
#  'tīrthaṃkara': [],
#  'pūjārha': ['ADJ', 'ADP', 'NOUN'],
#  'prakāra': ['VERB', 'ADP'],
#  'mūrti': ['NOUN', 'PUNCT', 'NOUN'],
#  'modalu': ['ADV', 'PUNCT', 'ADP', 'DET', 'NOUN'],
#  'mōkṣa': [],
#  'saṃsāra': ['PUNCT', 'DET', 'ADJ', 'NOUN', 'ADP'],
#  'hoṃdu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'kelasadavaḷu': ['VERB'],
#  'avatāra': ['NOUN', 'ADP', 'DET', 'NOUN'],
#  'gurutu': ['PROPN', 'PUNCT', 'ADJ'],
#  'jāsti': ['ADV', 'ADJ', 'PUNCT', 'ADV'],
#  'taṃdaru': ['PRON'],
#  'tanna': ['PRON', 'SYM', 'PRON', 'SYM', 'PRON', 'ADJ'],
#  'divasā': ['DET', 'NOUN'],
#  'pūje': ['NOUN', 'ADP', 'NOUN'],
#  'rathabīdi': ['PROPN', 'PROPN'],
#  'vidēśa': ['ADJ', 'NOUN'],
#  'samudra': ['PROPN', 'PUNCT', 'NOUN'],
#  'iḷi': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADV'],
#  'kadi': ['PART', 'VERB'],
#  'kāpāḍu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'koḷḷu': ['PART', 'VERB'],
#  'tīvra': ['ADJ', 'PUNCT', 'ADJ'],
#  'naḍe': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'paḍu': ['PART', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'VERB'],
#  'bayyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'beḷe': ['PART', 'VERB'],
#  'bhāgavahisu': ['PART', 'VERB'],
#  'malagu': ['PART', 'VERB', 'ADV', 'PUNCT', 'VERB'],
#  'mātanāḍu': ['PART', 'VERB'],
#  'lēkhaki': ['NOUN'],
#  'vāpasu': ['ADV', 'PUNCT', 'VERB'],
#  'sustu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sogasu': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'hattu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'hāru': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'horaḍu': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB', 'ADP'],
#  'kareyisu': ['PART', 'VERB', 'PART', 'VERB'],
#  'prakaṭa': ['VERB', 'PUNCT', 'ADJ'],
#  'bēga': ['ADV', 'PUNCT', 'ADV'],
#  'mēṣṭaru': [],
#  'vicitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'araḷu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'tamma': ['ADJ', 'NOUN'],
#  'neraḷu': ['PROPN', 'PUNCT', 'NOUN'],
#  'mātu': ['NOUN', 'PUNCT', 'NOUN'],
#  'vāsa': ['VERB', 'PUNCT', 'VERB'],
#  'sigu': ['PART', 'AUX', 'VERB', 'PUNCT', 'PART', 'AUX', 'VERB'],
#  'suddi': ['NOUN', 'PUNCT', 'NOUN'],
#  'bāradu': ['AUX', 'PART'],
#  'āse': ['NOUN', 'PUNCT', 'VERB'],
#  'heṃḍa': ['ADJ', 'NOUN'],
#  'eṃdare': ['X', 'PUNCT', 'PRON', 'AUX', 'PART', 'VERB'],
#  'oḍati': ['NOUN', 'PUNCT', 'NOUN'],
#  'kāṇisu': ['PART', 'AUX', 'VERB', 'PUNCT', 'VERB'],
#  'kāraṇa': ['NOUN', 'PUNCT', 'NOUN'],
#  'tuḷasi': ['ADJ', 'NOUN'],
#  'pavitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'pūjisu': ['PART', 'VERB'],
#  'baḷasu': ['PART', 'VERB'],
#  'beḷigge': ['ADP', 'DET', 'NOUN'],
#  'śakti': ['NOUN', 'PUNCT', 'NOUN'],
#  'hittalu': ['NOUN', 'NOUN'],
#  'hedaru': ['PART', 'VERB'],
#  'kareyavu': ['ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'VERB',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'AUX',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'PART'],
#  'anubhavisu': ['PART', 'VERB'],
#  'anubhāva': ['ADJ', 'NOUN'],
#  'kelavaru': ['DET', 'NOUN'],
#  'guṃpugārike': ['NOUN', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT'],
#  'naṃbu': ['PART', 'VERB'],
#  'baduku': ['PART', 'VERB'],
#  'Basavaṇṇa': [],
#  'mānava': ['ADJ', 'PUNCT', 'NOUN'],
#  'vacana': [],
#  'vaiyaktika': ['PRON', 'ADJ'],
#  'vyakti': ['NOUN', 'PUNCT', 'ADJ'],
#  'śivamaya': ['VERB', 'ADP', 'PROPN'],
#  'śaiva': ['VERB', 'ADP', 'PROPN'],
#  'saṃbhavisu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'sādhane': ['ADJ', 'NOUN', 'SYM', 'NOUN'],
#  'sāhityakṛti': ['ADJ', 'NOUN'],
#  'halavaru': ['ADJ', 'NOUN'],
#  'ivattina': ['NOUN', 'PART', 'PUNCT', 'ADP', 'NOUN'],
#  'īgina': ['ADP', 'ADV', 'PUNCT', 'ADJ'],
#  'uḷi': ['PART', 'VERB'],
#  'kali': ['PART', 'VERB'],
#  'guḍḍa': ['PROPN', 'PUNCT', 'NOUN'],
#  'jotege': ['ADV', 'ADP'],
#  'dharmādhikāri': [],
#  'neṃṭa': [],
#  'pradhāna': ['ADJ', 'PUNCT', 'NOUN'],
#  'prāṇa': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'balakaḍe': ['INTJ'],
#  'beṃḍekāyi': ['PROPN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'muṃcitavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'muṃduvari': ['PART', 'VERB'],
#  'mugi': ['PART', 'VERB'],
#  'mugisu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'yati': ['VERB', 'ADJ'],
#  'rūḍhi': ['NOUN', 'PUNCT', 'NOUN'],
#  'lābha': ['NOUN', 'PUNCT', 'NOUN'],
#  'liṃga': ['PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'sinima': ['NOUN', 'NOUN'],
#  'hāgādare': ['ADP', 'DET', 'NOUN', 'PUNCT', 'SCONJ', 'PRON', 'AUX', 'ADV'],
#  'hāgū': ['CCONJ', 'PUNCT', 'ADV'],
#  'haṇṇugaḷellavu': [],
#  'vidyārthigaḷellaru': [],
#  'elladariṃda': ['ADP', 'PRON'],
#  'elladakke': ['ADP', 'PRON'],
#  'elladara': ['ADP', 'PRON'],
#  'elladaralli': ['ADP', 'PRON'],
#  'baredukoḷḷi': ['INTJ',
#   'VERB',
#   'ADP',
#   'X',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'SCONJ',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'PUNCT'],
#  'baredukoḍi': ['INTJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADP',
#   'PRON',
#   'ADP',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT'],
#  'maretubiḍi!': ['INTJ', 'VERB', 'PRON', 'PUNCT'],
#  'saṃkōcapaḍabēḍa': ['AUX',
#   'PART',
#   'AUX',
#   'ADJ',
#   'X',
#   'PUNCT',
#   'AUX',
#   'PART',
#   'VERB',
#   'PROPN',
#   'PUNCT',
#   'PUNCT'],
#  'oṃdannu': ['NUM'],
#  'oṃdariṃda': ['ADP', 'NUM'],
#  'oṃdakke': ['ADP', 'NUM'],
#  'oṃdara': ['ADP', 'NUM'],
#  'oṃdaralli': ['ADP', 'NUM'],
#  'eraḍannu': ['NUM'],
#  'mūrakke': ['ADP', 'NUM'],
#  'nālkara': ['ADP', 'NUM'],
#  'aidariṃda': ['ADP', 'NUM'],
#  'āraralli': ['ADP',
#   'NUM',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'oṃdaneyadu': ['DET', 'ADJ', 'NUM'],
#  'hattaneyavanu': ['DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'X',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'aidaneyadaralli': ['ADP', 'DET', 'ADJ', 'NUM'],
#  'hattaneyavanige': ['ADP', 'DET', 'ADJ', 'NOUN'],
#  'obbanu': ['NUM', 'X', 'NOUN', 'X', 'NOUN'],
#  'obbaḷu': ['NUM', 'X', 'ADJ', 'PUNCT', 'NOUN'],
#  'obbaru': ['NUM', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'CCONJ', 'ADJ', 'PUNCT'],
#  'ibbaru': ['NUM', 'NOUN'],
#  'mūvaru': ['NUM', 'NOUN'],
#  'nālvaru': ['NUM', 'NOUN'],
#  'aivaru': ['NUM', 'NOUN'],
#  'ari': ['PART', 'VERB'],
#  'aritenu': ['PRON', 'VERB'],
#  'kalitenu': ['PRON', 'VERB'],
#  'mare': ['PART', 'VERB'],
#  'ennu': ['PART', 'VERB'],
#  'eṃdenu': ['PRON', 'VERB'],
#  'tiṃdenu': ['PRON', 'VERB'],
#  'baydenu': ['PRON',
#   'VERB',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'PUNCT',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN'],
#  'kāyu': ['PART', 'VERB', 'SYM', 'VERB', 'ADJ'],
#  'kādenu': ['PRON', 'VERB'],
#  'kuḷiru': ['PART', 'VERB', 'ADP'],
#  'kuḷitenu': ['PRON', 'VERB', 'ADP'],
#  'sōlu': ['PART', 'AUX', 'VERB'],
#  'sīnu': ['PART', 'VERB'],
#  'sītenu': ['PRON',
#   'VERB',
#   'PRON',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADV',
#   'SCONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADV'],
#  'ese': ['PART', 'VERB'],
#  'kusi': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB'],
#  'koḷe': ['PART', 'VERB'],
#  'dore': ['PART', 'AUX', 'VERB'],
#  'bese': ['PART', 'VERB'],
#  'mase': ['AUX', 'VERB'],
#  'moḷe': ['PART', 'VERB'],
#  'husi': ['PART', 'VERB', 'NOUN', 'SYM', 'NOUN'],
#  'āyu': ['PART', 'VERB'],
#  'oyyu': ['PART', 'VERB', 'ADP'],
#  'koyyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'geyyu': ['PART', 'VERB'],
#  'tēyu': ['PART', 'VERB'],
#  'toyyu': ['PART', 'VERB', 'ADJ'],
#  'māyu': ['PART', 'AUX', 'VERB'],
#  'mēyu': ['PART', 'VERB'],
#  'suyyu': ['PART', 'VERB'],
#  'hāyu': ['PART', 'VERB', 'ADP'],
#  'kavalu': ['PART', 'VERB', 'ADJ'],
#  'ciguru': ['PART', 'VERB'],
#  'bevaru': ['PART', 'VERB'],
#  'nāru': ['PART', 'VERB'],
#  'iru': ['PART', 'AUX'],
#  'teru': ['PART', 'VERB'],
#  'bēsaru': ['PART', 'AUX', 'VERB'],
#  'heru': ['PART', 'VERB', 'NOUN'],
#  'horu': ['PART', 'VERB', 'DET', 'NOUN'],
#  'kollu': ['PART', 'VERB'],
#  'gellu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'nillu': ['PART', 'VERB'],
#  'aḷu': ['PART', 'VERB'],
#  'uḷu': ['PART', 'VERB'],
#  'kaḷu': ['PART', 'VERB'],
#  'kīḷu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'biddu': [],
#  'bēyu': ['AUX', 'VERB'],
#  'mīyu': ['PART', 'VERB'],
#  'aḍu': ['PART', 'VERB'],
#  'uḍu': ['PART', 'VERB'],
#  'keḍu': ['PART', 'AUX', 'VERB'],
#  'toḍu': ['PART', 'VERB'],
#  'neḍu': ['PART', 'VERB'],
#  'biḍu': ['PART', 'VERB'],
#  'suḍu': ['PART', 'VERB'],
#  'uṇṇu': ['PART', 'VERB'],
#  'kāṇu': ['PART', 'VERB'],
#  'hogu': ['PART', 'VERB'],
#  'hokku': ['ADJ', 'VERB', 'NOUN', 'PUNCT'],
#  'ode': ['PART', 'VERB'],
#  'hode': ['PART', 'VERB', 'ADP'],
#  'eḷe': ['PART', 'VERB'],
#  'tege': ['PART', 'VERB'],
#  'mlēccha': ['PROPN', 'PUNCT', 'NOUN'],
#  'adannu': ['PRON'],
#  'oḷḷeyadu': ['ADJ', 'NOUN'],
#  'kalitare': ['SCONJ', 'X', 'NUM', 'PUNCT', 'VERB'],
#  'cennāgide': ['AUX', 'ADJ'],
#  'namage': ['PRON'],
#  'niṃtiddāre': ['PRON', 'VERB'],
#  'baruttāre': ['PRON', 'VERB'],
#  'meccuviri': ['PRON', 'AUX', 'VERB'],
#  'yaśasvi': ['ADJ', 'PUNCT', 'ADJ'],
#  'agnimaṃḍala': ['NOUN', 'ADP', 'NOUN'],
#  'apasmara': [],
#  'uṃṭāgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'uṃṭumāḍu': ['PART', 'VERB'],
#  'kaiyalli': ['PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'ADP'],
#  'korate': ['NOUN', 'PUNCT', 'VERB'],
#  'gaṃgādhara': ['PUNCT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'caṃdraśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'tāṃḍava': [],
#  'nakk-': [],
#  'naṃjuṃḍa': ['PUNCT', 'PRON', 'VERB', 'NOUN', 'PUNCT'],
#  'nāśa': ['NOUN', 'PUNCT', 'PROPN'],
#  'mallikārjuna': ['PUNCT', 'ADJ', 'ADP', 'NOUN', 'PUNCT'],
#  'mahatva': ['NOUN', 'PUNCT', 'NOUN'],
#  'rēkhē': ['ADJ', 'PUNCT', 'NOUN'],
#  'vāsasthaḷa': ['NOUN', 'ADP', 'NOUN'],
#  'vibhūti': ['PROPN',
#   'PROPN',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'śivabhakta': ['NOUN', 'ADP', 'NOUN'],
#  'siddhapuruṣa': ['ADV', 'VERB', 'NOUN'],
#  'sōmaśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'svabhāva': ['NOUN', 'PUNCT', 'NOUN'],
#  'haccu': ['PART', 'VERB', 'PUNCT', 'VERB']}

# %%
# Display the dictionary
kan_to_eng_mapping
# Out:
# {'ōḍu': 'to run',
#  'ōdu': 'to read',
#  'hēḷu': 'to say',
#  'hēlu': 'to shit',
#  'baḍi': 'to beat',
#  'baḍḍi': 'interest (on money)',
#  'maḍi': 'ritually pure',
#  'māḍi': 'please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:',
#  'nīnu': 'you (singular and non-honorific)',
#  'nīvu': 'you (plural / honorific)',
#  'adu': 'it / that',
#  'avaru': 'they (persons)',
#  'avu': 'they (non-persons)',
#  'idu': 'it / this',
#  'ivaru': 'he / she (honorific)',
#  'ivu': 'they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.)',
#  'hīge': 'in this manner',
#  'hāge': 'in that manner',
#  'hēge': 'in which manner?',
#  'iṣṭu': 'this much',
#  'aṣṭu': 'that much',
#  'eṣṭu': 'how much?',
#  'ide': 'it is, it exists',
#  'ili': 'mouse, rat',
#  'kālu': 'leg, foot',
#  'kai': 'hand, arm',
#  'graṃtha': 'book, volume',
#  'doḍḍa': 'big, large',
#  'paṃce': '(traditional men’s dress: ‘dhoti’)',
#  'pennu': 'ballpoint pen',
#  'pyāṃṭu': 'pair of trousers',
#  'beṭṭa': 'hill, mountain',
#  'muduki': 'old woman',
#  'maidāna': 'lawn, field',
#  'yuvati': 'young woman',
#  'luṃgi': '(traditional men’s dress: long loincloth)',
#  'vidyārthi': '[male] student',
#  'vidyārthini': '[female] student',
#  'Viṣṇu': '(name of god)',
#  'Śiva': '(name of god)',
#  'sagaṇi': 'cow dung',
#  'sāmānugaḷu': 'things, belongings',
#  'sīre': '(traditional ladies’ dress: ‘sari’)',
#  'hāḍugāra': 'singer (male)',
#  'hāḍugārti': 'singer (female)',
#  'Namaskāra.': '(the same is said when parting)',
#  'Banni.': 'Yes, you may go (‘Please come’).',
#  'Hēgiddīri?': 'How are you? Gururāja',
#  'ivara': 'his / her (honorific)',
#  'elliṃda': 'from where?',
#  'cennāgi': 'nicely, finely',
#  'nimma': 'your (honorific)',
#  'banni': 'please come',
#  'barali': 'I should come',
#  'baru': 'to come',
#  'bassu': 'bus (vehicle)',
#  'bēku': 'is wanted / required / needed',
#  'bēḍa': 'is not wanted / not required',
#  'viśēṣa': 'something special',
#  'sari': 'okay, all right, correct',
#  'akka': 'elder sister',
#  'aṇṇa': 'elder brother',
#  'kere': 'tank, water reservoir',
#  'cīla': 'bag, purse',
#  'dēśa': 'country, land',
#  'puṭa': 'page (of book etc.)',
#  'snēhita': 'friend (male)',
#  'snēhite': 'friend (female)',
#  'aṃgaḍi': 'store, shop',
#  'jana': 'person, people',
#  'jijñāsu': 'eager to learn',
#  'paṃḍite': 'learned woman',
#  'hōdenu': 'I went',
#  'ādenu': 'I became',
#  'hōdi': 'you went',
#  'ādi': 'you became',
#  'hōdanu': 'he went',
#  'ādanu': 'he became',
#  'hōdaḷu': 'she went',
#  'ādaḷu': 'she became',
#  'hōdevu': 'we went',
#  'ādevu': 'we became',
#  'hōdiri': 'you went',
#  'ādiri': 'you became',
#  'hōdaru': 'they went',
#  'ādaru': 'they became',
#  'āgu': 'to become, occur',
#  'jigi': 'to jump',
#  'kare': 'to call',
#  'taru': 'to bring',
#  'tiḷi': 'to understand',
#  'nagu': 'to laugh',
#  'bīḷu': 'to fall',
#  'māḍu': 'to do, make',
#  'hoḍe': 'to hit, strike',
#  'hōgu': 'to go',
#  'nōḍu': 'to watch, look at',
#  'bare': 'to write',
#  'anna': 'rice (cooked)',
#  'ūṭa': '(cooked) meal',
#  'koḍu': 'to give',
#  'viṣaya': 'matter, thing, topic',
#  'sāku': 'it is enough',
#  'sāladu': 'it is not enough',
#  'mēlu': 'top side',
#  'keḷagu': 'lower side',
#  'hiṃde': 'behind, ago',
#  'hiṃdu': 'rear side',
#  'āyitu': 'all right, okay',
#  'iḍu': 'to place, put',
#  'īgalū': 'also now',
#  'kaḍe': 'side, direction',
#  'kōṇe': 'room, chamber',
#  'gaḍipradēśa': 'border area',
#  'tagoḷḷu': 'to take',
#  'tuṃba': 'very, much, many',
#  'darśana': 'seeing, sight, ritual viewing of an object of reverence',
#  'nija': 'real, true',
#  'nijavāgi': 'really, truly',
#  'pradēśa': 'region, area',
#  'bāḷu': 'to live',
#  'bhakta': 'devotee, follower',
#  'śatamāna': 'century (100 years)',
#  'summane': 'just like that, quietly',
#  'svalpa': 'a bit, a little',
#  'bāḷe': 'banana tree',
#  'bēre': 'other, something else',
#  'rīti': 'style, kind',
#  'asahya': 'intolerable, disgusting',
#  'āḍu': 'to play',
#  'iṣṭa': 'liked, appreciated',
#  'ūru': 'place, village, town, ‘native place’, city',
#  'kēḷu': 'to ask, to hear',
#  'kṣētra': 'place of pilgrimage',
#  'jāga': 'place, space, spot',
#  'taṃgi': 'younger sister',
#  'tīrthaṃkara': '(holiest person in Jainism)',
#  'pūjārha': 'worthy of worship',
#  'prakāra': 'according to',
#  'manuṣya': 'human, person',
#  'mūrti': 'icon, statue',
#  'modalu': 'firstly, in the beginning',
#  'mōkṣa': '(religious) liberation',
#  'saṃsāra': '‘the worldly system of',
#  'hoṃdu': 'to acquire, achieve',
#  'kelasadavaḷu': 'housemaid (‘of-the-work she’)',
#  'maneyavaru': 'spouse (‘of-the-house person’)',
#  'avatāra': 'incarnation of a god',
#  'gurutu': 'mark, characteristic',
#  'jāsti': 'too much, excessively',
#  'taṃdaru': 'he (hon.) brought',
#  'tanna': 'his / her / its own',
#  'divasā': 'every day',
#  'pūje': 'ritual of worship',
#  'mukhya': 'something important',
#  'rathabīdi': 'Temple Street',
#  'vidēśa': 'foreign country',
#  'vaiṣṇava': 'devotee of Viṣṇu, Viṣṇuite',
#  'samudra': 'sea, ocean',
#  'hattira': 'near; nearness',
#  'heccu': 'much, a lot, very',
#  'iḷi': 'to descend, go down',
#  'kadi': 'to steal',
#  'kāpāḍu': 'to protect, guard',
#  'koḷḷu': 'to buy',
#  'jōru': 'force, forcefulness',
#  'tīvra': 'severe, intense',
#  'naḍe': 'to walk, to happen',
#  'paḍu': 'to suffer, experience, undergo',
#  'bayyu': 'to abuse, scold',
#  'beḷe': 'to grow',
#  'bhāgavahisu': 'to participate',
#  'malagu': 'to lie down, sleep',
#  'mātanāḍu': 'to speak',
#  'lēkhaki': 'writer (feminine)',
#  'vāpasu': 'back, returned',
#  'sustu': 'tiredness, fatigue',
#  'sogasu': 'grace, elegance, beauty',
#  'hattu': 'to climb; to begin',
#  'hāḍu': 'song; to sing',
#  'hāru': 'to fly, jump',
#  'horaḍu': 'to set out, leave for',
#  'kareyisu': 'to cause to call',
#  'prakaṭa': 'published, public',
#  'prayatna': 'attempt, try, effort',
#  'bēga': 'fast, soon',
#  'mēṣṭaru': '(school) teacher (‘master’)',
#  'vicitra': 'strange, odd',
#  'araḷu': 'to bloom, blossom',
#  'tamma': 'younger brother',
#  'neraḷu': 'shade, shadow',
#  'mātu': 'word, utterance',
#  'vāsa': 'living, dwelling',
#  'sigu': 'to be obtained, to be met',
#  'suddi': 'news, message',
#  'bāradu': 'may not',
#  'āse': 'desire, wish',
#  'heṃḍa': 'alcoholic beverage',
#  'eṃdare': 'i.e., that is to say',
#  'oḍati': 'mistress, owner',
#  'kāṇisu': 'to be seen, appear',
#  'kāraṇa': 'cause, reason',
#  'gottu': 'knowledge, known thing',
#  'tuḷasi': 'Indian basil',
#  'pavitra': 'pure, holy',
#  'pūjisu': 'to worship',
#  'bahaḷa': 'much, many, very',
#  'baḷasu': 'to use',
#  'beḷigge': 'in the morning',
#  'śakti': 'energy, power',
#  'śukravāra': 'energy, power',
#  'hittalu': 'back yard',
#  'hedaru': 'to fear',
#  'kareyavu': 'In modern usage, these forms are generally considered rather old-fash- ioned and hardly occur. The main reason for this is that they do not',
#  'anubhavisu': 'to experience',
#  'anubhāva': 'religious experience',
#  'kelavaru': 'some persons',
#  'kelavu': 'some (things)',
#  'guṃpugārike': 'group consciousness, ‘groupism’',
#  'naṃbu': 'to believe',
#  'baduku': 'to live',
#  'Basavaṇṇa': '(name, ‘elder brother B.’)',
#  'mānava': 'human, person',
#  'vacana': '(name of a literary form, ‘utterance’)',
#  'vaiyaktika': 'something personal',
#  'vyakti': 'person, individual',
#  'śivamaya': 'made of god',
#  'śaiva': 'pertaining to Śiva',
#  'saṃbhavisu': 'to arise, originate',
#  'sādhane': 'religious discipline / practice',
#  'sāhityakṛti': 'literary work',
#  'halavaru': 'many persons',
#  'āga': 'then, that time',
#  'ivattina': 'today’s, of today',
#  'īgina': 'of now, present',
#  'uḷi': 'to remain',
#  'kali': 'to learn',
#  'guḍḍa': 'hill, hillock',
#  'jotege': 'together with',
#  'dharmādhikāri': '(religious title and function)',
#  'neṃṭa': '(blood-) relative',
#  'pradhāna': 'main, chief',
#  'prāṇa': 'life, life force',
#  'balakaḍe': 'right (side)',
#  'beṃḍekāyi': 'okra, ‘ladies’ fingers’',
#  'muṃcitavāgi': 'beforehand, earlier',
#  'muṃduvari': 'to continue',
#  'mugi': 'to end (intr.)',
#  'mugisu': 'to end, finish (trans.)',
#  'yati': 'wandering ascetic',
#  'rūḍhi': 'custom, usage',
#  'rūpa': 'form, shape',
#  'lābha': 'profit, advantage',
#  'liṃga': '‘sign’, a particular depiction of Śiva',
#  'sinima': 'movie theatre',
#  'hāgādare': 'in that case, if that is so',
#  'hāgū': 'and, also',
#  'haṇṇugaḷellavu': '(the same)',
#  'vidyārthigaḷellaru': '(the same)',
#  'elladariṃda': 'from everything (ablative)',
#  'elladakke': 'to everything (dative)',
#  'elladara': 'of everything (genitive)',
#  'elladaralli': 'in everything (locative)',
#  'baredukoḷḷi': 'please note down [‘having written, please take’, i.e., write this down so that you need not remember]',
#  'baredukoḍi': 'please write it down for me [‘having written, please give’]',
#  'maretubiḍi!': 'please forget it!',
#  'saṃkōcapaḍabēḍa': 'don’t be shy [‘do not suffer shyness’]',
#  'oṃdu': 'one, a',
#  'oṃdannu': 'one (specific accusative)',
#  'oṃdariṃda': 'from one',
#  'oṃdakke': 'to one',
#  'oṃdara': 'of one',
#  'oṃdaralli': 'in one',
#  'eraḍannu': 'two (specific accusative)',
#  'mūrakke': 'to three',
#  'nālkara': 'of four',
#  'aidariṃda': 'from five',
#  'āraralli': 'in six Often, though, these inflected forms of the numerals must be translated in special idiomatic manners:',
#  'sāvira': '1000 When smaller numbers are added to higher units (hundreds, thousands, etc.), the connection between the higher and lower elements in the numeral is indicated by the genitive case:',
#  'oṃdaneyadu': 'the first one',
#  'hattaneyavanu': 'the tenth man These new words can of course be declined, like any pronoun or pro- nomi nalized word:',
#  'aidaneyadaralli': 'in the fifth one',
#  'hattaneyavanige': 'to the tenth man',
#  'obbanu': 'one [male] person',
#  'obbaḷu': 'one [female] person',
#  'obbaru': 'one person [politely, or neutral]',
#  'ibbaru': 'two persons',
#  'mūvaru': 'three persons',
#  'nālvaru': 'four persons',
#  'aivaru': 'five persons',
#  'ari': 'to know',
#  'aritenu': 'I knew',
#  'kalitenu': 'I learnt',
#  'mare': 'to forget',
#  'ennu': 'to say',
#  'eṃdenu': 'I said',
#  'tinnu': 'to eat',
#  'tiṃdenu': 'I ate',
#  'baydenu': 'I abused / reviled These are roots which originally, in Old Kannada, ended in a consonant',
#  'kāyu': 'to wait / grow hot',
#  'kādenu': 'I waited',
#  'kuḷiru': 'to sit down',
#  'kuḷitenu': 'I sat down',
#  'sōlu': 'to be defeated',
#  'sīnu': 'to sneeze',
#  'sītenu': 'I sneezed It should be noticed here that in the case of some of these verbs, more',
#  'ese': 'to throw',
#  'kuri': 'to aim',
#  'kusi': 'to sink down / collapse',
#  'koḷe': 'to rot',
#  'caḷi': 'to be tired',
#  'dore': 'to be obtained',
#  'bese': 'to solder',
#  'mase': 'to whet',
#  'moḷe': 'to sprout',
#  'husi': 'to speak falsehood / lie',
#  'āyu': 'to choose',
#  'oyyu': 'to carry off',
#  'koyyu': 'to reap, pluck',
#  'geyyu': 'to make',
#  'tēyu': 'to grind',
#  'toyyu': 'to become wet',
#  'māyu': 'to be hidden',
#  'mēyu': 'to graze',
#  'suyyu': 'to sigh',
#  'hāyu': 'to cross over',
#  'kavalu': 'to become branched',
#  'ciguru': 'to sprout',
#  'bevaru': 'to perspire',
#  'nāru': 'to stink',
#  'iru': 'to be',
#  'teru': 'to pay',
#  'bēsaru': 'to be bored',
#  'heru': 'to give birth',
#  'horu': 'to bear a burden',
#  'kollu': 'to kill',
#  'gellu': 'to win, overcome',
#  'nillu': 'to stand',
#  'aḷu': 'to weep',
#  'uḷu': 'to plough',
#  'ēḷu': 'to rise',
#  'kaḷu': 'to steal',
#  'kīḷu': 'to pluck, pick',
#  'biddu': '(Note the shortening of the vowel in the case of the two last-mentioned verbs.)',
#  'bēyu': 'be burnt',
#  'mīyu': 'to bathe',
#  'aḍu': 'to cook',
#  'uḍu': 'to dress',
#  'keḍu': 'to be spoilt',
#  'toḍu': 'to dress',
#  'neḍu': 'to plant',
#  'biḍu': 'to leave',
#  'suḍu': 'to burn',
#  'uṇṇu': 'to eat',
#  'kāṇu': 'to see',
#  'hogu': 'to enter',
#  'hokku': 'Alternative abbreviated forms:',
#  'ode': 'to kick',
#  'hode': 'to put on (dress)',
#  'eḷe': 'to pull',
#  'tege': 'to take',
#  'mlēccha': 'barbarian, foreigner',
#  'adannu': 'that (accusative case)',
#  'oḷḷeyadu': 'good thing',
#  'kalitare': 'if [one] learns',
#  'cennāgide': 'is good',
#  'daya': 'grace, mercy',
#  'namage': 'us (dative case)',
#  'niṃtiddāre': 'they stand',
#  'baruttāre': 'they come',
#  'mara': 'tree, wood',
#  'meccuviri': 'you will like',
#  'yaśasvi': 'glorious, successful',
#  'agnimaṃḍala': 'circle of fire',
#  'apasmara': '(name of a demon)',
#  'uṃṭāgu': 'to arise, originate',
#  'uṃṭumāḍu': 'to create',
#  'kaiyalli': '‘in the hand’, with, near',
#  'korate': 'defect, shortcoming',
#  'gaṃgādhara': '‘bearer of the Ganges’, Śiva',
#  'caṃdraśēkhara': '‘who has the moon on his crest’, Śiva',
#  'tāṃḍava': '(name of Śiva’s dance)',
#  'nakk-': '(past stem of nagu)',
#  'naṃjuṃḍa': '‘who drank poison’',
#  'nāśa': 'destruction, ruin',
#  'Madhvācārya': '(name of a philosopher)',
#  'mallikārjuna': '‘white like jasmine’',
#  'mahatva': 'greatness, importance',
#  'rēkhē': 'stripe, line',
#  'vāsasthaḷa': 'place of residence',
#  'vibhūti': 'holy ash as used by the devotees of Śiva',
#  'śivabhakta': 'devotee of Śiva',
#  'siddhapuruṣa': 'religiously liberated person',
#  'sōmaśēkhara': '‘who has the moon on his crest’, Śiva',
#  'svabhāva': 'nature, character',
#  'haccu': 'to smear, apply',
#  'huḷi': 'sour',
#  'huli': 'tiger',
#  'haḷḷi': 'village',
#  'halli': 'lizard',
#  'maṇe': 'stool',
#  'mane': 'house',
#  'hālu': 'milk',
#  'hallu': 'tooth',
#  'dēva': 'god',
#  'devva': 'spirit',
#  'nānu': 'I',
#  'nāvu': 'we',
#  'avanu': 'he',
#  'avaḷu': 'she',
#  'ivanu': 'he',
#  'ivaḷu': 'she',
#  'illi': 'here',
#  'alli': 'there',
#  'elli': 'where?',
#  'īga': 'now',
#  'almāri': 'closet',
#  'ākāśa': 'sky',
#  'innoṃdu': 'another',
#  'ivattu': 'today',
#  'eraḍu': 'two',
#  'aidu': 'five',
#  'kaṃpyūṭaru': 'computer',
#  'kaṭṭaḍa': 'building',
#  'kāgada': 'paper',
#  'kāḍu': 'forest',
#  'kāru': 'car',
#  'kiṭaki': 'window',
#  'kurci': 'chair',
#  'gilāsu': 'glass',
#  'guri': 'goal',
#  'guru': 'teacher',
#  'guruvāra': 'Thursday',
#  'camaca': 'spoon',
#  'cāku': 'knife',
#  'cāpe': 'mat',
#  'cāvi': 'key',
#  'citra': 'picture',
#  'ṭyāksi': 'taxi',
#  'ṭyūbulaiṭu': 'tubelight',
#  'taṭṭe': 'plate',
#  'dīpa': 'lamp',
#  'dēvasthāna': 'temple',
#  'nālku': 'four',
#  'nāḷe': 'tomorrow',
#  'nela': 'floor',
#  'noṇa': 'fly',
#  'pustaka': 'book',
#  'pensilu': 'pencil',
#  'phorenar': 'foreigner',
#  'phōrku': 'fork',
#  'bāgilu': 'door',
#  'budhavāra': 'Wednesday',
#  'beṃki': 'fire',
#  'bēli': 'fence',
#  'bhāratīya': 'Indian',
#  'maṃgaḷavāra': 'Tuesday',
#  'mattu': 'and',
#  'mahiḷe': 'lady',
#  'maḷe': 'rain',
#  'māle': 'garland',
#  'mūru': 'three',
#  'mēju': 'table',
#  'mēṇabatti': 'candle',
#  'mōḍa': 'cloud',
#  'ravivāra': 'Sunday',
#  'raste': 'road',
#  'rikṣā': 'rikshaw',
#  'vimāna': 'airplane',
#  'śanivāra': 'Saturday',
#  'sūṭkēsu': 'suitcase',
#  'sūrya': 'sun',
#  'sōmavāra': 'Monday',
#  'strī': 'woman',
#  'hakki': 'bird',
#  'halavu': 'many',
#  'hasu': 'cow',
#  'hippi': 'hippie',
#  'huḍuga': 'boy',
#  'huḍugi': 'girl',
#  'hū': 'flower',
#  'heṃgasu': 'woman',
#  'hola': 'field',
#  'haudu': 'yes',
#  'yāvāgalū illa': 'never',
#  'ēnū illa': 'nothing',
#  'yārū illa': 'nobody',
#  'ēke': 'why?',
#  'ēnu': 'what?',
#  'kappu': 'black',
#  'kaṣṭa': 'difficult',
#  'toḍaku': 'problem',
#  'nanna': 'my',
#  'namma': 'our',
#  'patra': 'letter',
#  'purōhita': 'priest',
#  'biḷi': 'white',
#  'yāru': 'who?',
#  'yāva': 'which?',
#  'yāvāga': 'when?',
#  'samācāra': 'news',
#  'hesaru': 'name',
#  'appa': 'father',
#  'amma': 'mother',
#  'kaṇṇu': 'eye',
#  'kivi': 'ear',
#  'kūsu': 'baby',
#  'gaṃḍa': 'husband',
#  'gaṃḍasu': 'man',
#  'nighaṃṭu': 'dictionary',
#  'nīru': 'water',
#  'buṭṭi': 'basket',
#  'maga': 'son',
#  'magaḷu': 'daughter',
#  'magu': 'child',
#  'māva': 'uncle',
#  'rāja': 'king',
#  'raita': 'farmer',
#  'vidhave': 'widow',
#  'anubhava': 'experience',
#  'āṭike': 'toy',
#  'āyke': 'choice',
#  'keṃpu': 'red',
#  'koṃbu': 'horn',
#  'koṃbe': 'branch',
#  'cūpu': 'sharp',
#  'tudi': 'tip',
#  'parimāṇa': 'size',
#  'baṭṭe': 'cloth',
#  'baṇṇa': 'colour',
#  'saṃkhye': 'number',
#  'hasiru': 'green',
#  'haḷadi': 'yellow',
#  'heṃḍati': 'wife',
#  'nidde': 'sleep',
#  'nāyi': 'dog',
#  'kathe': 'story',
#  'kelasa': 'work',
#  'toṃdare': 'trouble',
#  'nenne': 'yesterday',
#  'satya': 'truth',
#  'haṇa': 'money',
#  'haṇṇu': 'fruit',
#  'mēle': 'on',
#  'keḷage': 'under',
#  'oḷage': 'within',
#  'oḷagu': 'inside',
#  'bage': 'thought',
#  'madhya': 'middle',
#  'muṃde': 'before',
#  'horage': 'outside',
#  'aḍige': 'cooking',
#  'uttara': 'north',
#  'kāpi': 'coffee',
#  'gaḍi': 'border',
#  'cahā': 'tea',
#  'padārtha': 'thing',
#  'pavāḍa': 'miracle',
#  'viśēṣavāda': 'special',
#  'samādhi': 'tomb',
#  'ele': 'leaf',
#  'athavā': 'or',
#  'abhiprāya': 'opinion',
#  'iḍiya': 'entire',
#  'upayukta': 'useful',
#  'keṭṭa': 'bad',
#  'kliṣṭa': 'complicated',
#  'gaddala': 'noise',
#  'cakravarti': 'emperor',
#  'cikka': 'small',
#  'jagattu': 'world',
#  'dūra': 'distance',
#  'nīli': 'blue',
#  'praśne': 'question',
#  'bīdi': 'street',
#  'bhāra': 'weight',
#  'bhārata': 'India',
#  'yuga': 'era',
#  'saṃgīta': 'music',
#  'suṃdara': 'beautiful',
#  'kōlu': 'stick',
#  'ciṃtaka': 'thinker',
#  'tīra': 'coast',
#  'maṭha': 'monastery',
#  'saṃpradāya': 'tradition',
#  'hadimūraneya': 'thirteenth',
#  'āphisu': 'office',
#  'oraṭu': 'coarseness',
#  'krūra': 'cruel',
#  'khuśi': 'joy',
#  'tiṃgaḷu': 'month',
#  'dayaviṭṭu': 'please',
#  'pāṭha': 'lesson',
#  'muṃdina': 'next',
#  'yōcane': 'thought',
#  'vākya': 'sentence',
#  'śabda': 'word',
#  'saṃtōṣa': 'joy',
#  'sammēḷana': 'conference',
#  'spaṣṭa': 'clear',
#  'artha': 'meaning',
#  'ādare': 'but',
#  'kṣame': 'forgiveness',
#  'hōṭalu': 'restaurant',
#  'adhyāpaka': 'teacher',
#  'kōpa': 'anger',
#  'graṃthapālaka': 'librarian',
#  'graṃthālaya': 'library',
#  'patrike': 'magazine',
#  'sahāya': 'help',
#  'hemme': 'pride',
#  'hōguvike': 'going',
#  'bāḷike': 'living',
#  'ārōgya': 'health',
#  'gōḍe': 'wall',
#  'gōva': 'Goa',
#  'māṃsa': 'meat',
#  'miliṭari': 'military',
#  'miliṭari hōṭalu': 'non-vegetarian',
#  'auṣadhi': 'medicine',
#  'kaṭṭe': 'mount',
#  'giḍa': 'plant',
#  'dēvi': 'goddess',
#  'patni': 'wife',
#  'pradakṣiṇe': 'circumambulation',
#  'bhakti': 'devotion',
#  'mātra': 'only',
#  'saṃpattu': 'wealth',
#  'sādhya': 'possible',
#  'sulabha': 'easy',
#  'saubhāgya': 'well-being',
#  'atṛpta': 'dissatisfied',
#  'atṛpti': 'dissatisfaction',
#  'anubhāvi': 'mystic',
#  'anuyāyi': 'follower',
#  'asamānate': 'inequality',
#  'ityādi': 'etc.',
#  'kuṭuṃba': 'family',
#  'kelavomme': 'sometimes',
#  'guṃpu': 'group',
#  'jāti': 'caste',
#  'jīvana': 'life',
#  'tṛpta': 'satisfied',
#  'tṛpti': 'satisfaction',
#  'dhārmika': 'religious',
#  'naitika': 'moral',
#  'paraṃpare': 'tradition',
#  'prapaṃca': 'world',
#  'prācīna': 'ancient',
#  'prīti': 'love',
#  'Basava': '(name)',
#  'beḷavaṇige': 'development',
#  'maṃdi': 'person',
#  'manassu': 'mind',
#  'samāna': 'equal',
#  'samānate': 'equality',
#  'sāmājika': 'social',
#  'hinnele': 'background',
#  'hosa': 'new',
#  'anēka': 'many',
#  'ippataidu': 'twenty-five',
#  'ēkeṃdare': 'because',
#  'omme': 'once',
#  'karāvaḷi': 'coast',
#  'kaḷatmaka': 'artistic',
#  'kāphi': 'coffee',
#  'kāryakrama': 'program',
#  'kuḍuma': '(placename)',
#  'kēṃdra': 'centre',
#  'cikitsālaya': 'clinic',
#  'jille': 'district',
#  'taṃde': 'father',
#  'takṣaṇa': 'immediately',
#  'tale': 'head',
#  'talenōvu': 'headache',
#  'dēvate': 'divinity',
#  'Dharmasthaḷa': '(placename)',
#  'nōvu': 'pain',
#  'paṃḍita': 'scholar',
#  'pūrvaja': 'ancestor',
#  'Maṃjunātha': '(name)',
#  'yātrika': 'pilgrim',
#  'rakṣaṇe': 'protection',
#  'varegū': 'until',
#  'varṣa': 'year',
#  'Vādirāja': '(name)',
#  'śikṣaka': 'teacher',
#  'saṃgrahālaya': 'museum',
#  'sahiṣṇute': 'tolerance',
#  'sāṃskṛtika': 'cultural',
#  'sāvirāru': 'thousands',
#  'sumāru': 'approximately',
#  'hadināraneya': 'sixteenth',
#  'huṣāru': 'healthiness',
#  'ellarannu / ellarannū': '(accusative)',
#  'ellariṃda / ellariṃdalū': '(ablative)',
#  'ellara': '(genitive)',
#  'ellaralli / ellarallū': '(locative)',
#  'āru': 'six',
#  'eṃṭu': 'eight',
#  'oṃbattu': 'nine',
#  'hannoṃdu': 'eleven',
#  'hanneraḍu': 'twelve',
#  'hadimūru': 'thirteen',
#  'hadinālku': 'fourteen',
#  'hadinaidu': 'fifteen',
#  'hadināru': 'sixteen',
#  'hadinēḷu': 'seventeen',
#  'hadineṃṭu': 'eighteen',
#  'hattoṃbattu': 'nineteen',
#  'ippattu': 'twenty',
#  'ippattoṃdu': 'twenty-one',
#  'ippatteraḍu': 'twenty-two',
#  'ippattanālku': 'twenty-four',
#  'ippattaidu': 'twenty-five',
#  'ippattāru': 'twenty-six',
#  'ippattēḷu': 'twenty-seven',
#  'ippatteṃṭu': 'twenty-eight',
#  'ippattoṃbattu': 'twenty-nine',
#  'aivattu': 'fifty',
#  'aravattu': 'sixty',
#  'eppattu': 'seventy',
#  'eṃbattu': 'eighty',
#  'toṃbattu': 'ninety',
#  'nūru': 'hundred',
#  'innūru': '200',
#  'munnūru': '300',
#  'nānūru': '400',
#  'ainūru': '500',
#  'ārunūru': '600',
#  'ēḷunūru': '700',
#  'eṃṭunūru': '800',
#  'oṃbainūru': '900',
#  'nūra nalvattoṃdu': '141',
#  'sāvirada oṃbainūra toṃbattaidu': '1995',
#  'āgi': '(gerund)',
#  'hōgi': '(gerund)',
#  'utkhanana': 'excavation',
#  'hagga': 'rope',
#  'ajja': 'grandfather',
#  'jñāna': 'knowledge',
#  'daḍḍa': 'dunce',
#  'kobbu': 'fat',
#  'udbhava': 'origin',
#  'ayya': 'lord',
#  'prabhāva': 'influence',
#  'tatva': 'principle',
#  'utsava': 'feast',
#  'kaḷḷa': 'thief',
#  'aparūpavāgi': 'rarely',
#  'bhāṣe': 'language',
#  'yāvāgalū': 'always',
#  'haḷeya': 'old',
#  'aṃgaḍiyavaru': 'shopkeeper',
#  'ajñāna': 'ignorance',
#  'nṛtya': 'dance',
#  'paravā': 'worry',
#  'parvata': 'mountain',
#  'baḷi': 'near',
#  'buddhi': 'intelligence',
#  'beḷaku': 'light',
#  'bhasma': 'ash',
#  'majjige': 'buttermilk',
#  'mūgu': 'nose',
#  'modalaneya': 'first',
#  'rākṣasa': 'demon',
#  'vimānanildāṇa': 'airport',
#  'vaiṣṇavadharma': 'Viṣṇuism',
#  'saṃkēta': 'symbol',
#  'saṃsthe': 'institute',
#  'sāṃkētika': 'symbolic',
#  'sāmānya': 'ordinary',
#  'haṇe': 'forehead'}

# %%
# Create a dict with the values as dict of transation and pos tag
all_pos_mapping_dict = {}
for transliteration, pos_tags in all_pos_mapping.items():
    all_pos_mapping_dict[transliteration] = {
        'translation': kan_to_eng_mapping.get(transliteration, ""),
        "pos_tags": pos_tags
    }

# Save
with open("all_pos_mapping_with_translation.json", "w", encoding="utf-8") as f:
    json.dump(all_pos_mapping_dict, f, ensure_ascii=False, indent=4)

all_pos_mapping_dict
# Out:
# {'huḷi': {'translation': 'sour', 'pos_tags': ['ADJ']},
#  'huli': {'translation': 'tiger', 'pos_tags': ['NOUN']},
#  'haḷḷi': {'translation': 'village', 'pos_tags': ['NOUN']},
#  'halli': {'translation': 'lizard', 'pos_tags': ['NOUN']},
#  'maṇe': {'translation': 'stool', 'pos_tags': ['PROPN']},
#  'mane': {'translation': 'house', 'pos_tags': ['NOUN']},
#  'hālu': {'translation': 'milk', 'pos_tags': ['NOUN']},
#  'hallu': {'translation': 'tooth', 'pos_tags': ['VERB']},
#  'dēva': {'translation': 'god', 'pos_tags': ['PROPN']},
#  'devva': {'translation': 'spirit', 'pos_tags': ['PROPN']},
#  'nānu': {'translation': 'I', 'pos_tags': ['PRON']},
#  'nāvu': {'translation': 'we', 'pos_tags': ['PRON']},
#  'avanu': {'translation': 'he', 'pos_tags': ['PRON']},
#  'avaḷu': {'translation': 'she', 'pos_tags': ['PRON']},
#  'ivanu': {'translation': 'he', 'pos_tags': ['PRON']},
#  'ivaḷu': {'translation': 'she', 'pos_tags': ['PRON']},
#  'illi': {'translation': 'here', 'pos_tags': ['ADV']},
#  'alli': {'translation': 'there', 'pos_tags': ['ADV']},
#  'elli': {'translation': 'where?', 'pos_tags': ['SCONJ', 'PUNCT']},
#  'īga': {'translation': 'now', 'pos_tags': ['ADV']},
#  'āga': {'translation': 'then, that time',
#   'pos_tags': ['ADV', 'PUNCT', 'DET', 'NOUN']},
#  'adu': {'translation': 'it / that', 'pos_tags': ['PRON', 'PUNCT', 'PRON']},
#  'almāri': {'translation': 'closet', 'pos_tags': ['NOUN']},
#  'ākāśa': {'translation': 'sky', 'pos_tags': ['NOUN']},
#  'idu': {'translation': 'it / this', 'pos_tags': ['PRON', 'PUNCT', 'PRON']},
#  'innoṃdu': {'translation': 'another', 'pos_tags': ['PRON']},
#  'ivattu': {'translation': 'today', 'pos_tags': ['NOUN']},
#  'ūṭa': {'translation': '(cooked) meal', 'pos_tags': []},
#  'ūru': {'translation': 'place, village, town, ‘native place’, city',
#   'pos_tags': ['NOUN',
#    'PUNCT',
#    'NOUN',
#    'PUNCT',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'NOUN']},
#  'eraḍu': {'translation': 'two', 'pos_tags': ['NUM']},
#  'aidu': {'translation': 'five', 'pos_tags': ['NUM']},
#  'oṃdu': {'translation': 'one, a', 'pos_tags': ['NUM', 'PUNCT', 'PRON']},
#  'kaṃpyūṭaru': {'translation': 'computer', 'pos_tags': ['NOUN']},
#  'kaṭṭaḍa': {'translation': 'building', 'pos_tags': ['VERB']},
#  'kāgada': {'translation': 'paper', 'pos_tags': ['NOUN']},
#  'kāḍu': {'translation': 'forest', 'pos_tags': ['NOUN']},
#  'kāru': {'translation': 'car', 'pos_tags': ['NOUN']},
#  'kiṭaki': {'translation': 'window', 'pos_tags': ['NOUN']},
#  'kurci': {'translation': 'chair', 'pos_tags': ['NOUN']},
#  'gilāsu': {'translation': 'glass', 'pos_tags': ['NOUN']},
#  'guri': {'translation': 'goal', 'pos_tags': ['NOUN']},
#  'guru': {'translation': 'teacher', 'pos_tags': ['NOUN']},
#  'guruvāra': {'translation': 'Thursday', 'pos_tags': ['PROPN']},
#  'camaca': {'translation': 'spoon', 'pos_tags': ['VERB']},
#  'cāku': {'translation': 'knife', 'pos_tags': ['NOUN']},
#  'cāpe': {'translation': 'mat', 'pos_tags': ['NOUN']},
#  'cāvi': {'translation': 'key', 'pos_tags': ['ADJ']},
#  'citra': {'translation': 'picture', 'pos_tags': ['NOUN']},
#  'ṭyāksi': {'translation': 'taxi', 'pos_tags': ['NOUN']},
#  'ṭyūbulaiṭu': {'translation': 'tubelight', 'pos_tags': ['NOUN']},
#  'taṭṭe': {'translation': 'plate', 'pos_tags': ['NOUN']},
#  'tuṃba': {'translation': 'very, much, many',
#   'pos_tags': ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ']},
#  'dīpa': {'translation': 'lamp', 'pos_tags': ['PROPN']},
#  'dēvasthāna': {'translation': 'temple', 'pos_tags': ['PROPN']},
#  'nālku': {'translation': 'four', 'pos_tags': ['NUM']},
#  'nāḷe': {'translation': 'tomorrow', 'pos_tags': ['NOUN']},
#  'nela': {'translation': 'floor', 'pos_tags': ['NOUN']},
#  'noṇa': {'translation': 'fly', 'pos_tags': ['VERB']},
#  'pustaka': {'translation': 'book', 'pos_tags': ['NOUN']},
#  'pensilu': {'translation': 'pencil', 'pos_tags': ['NOUN']},
#  'phorenar': {'translation': 'foreigner', 'pos_tags': ['NOUN']},
#  'phōrku': {'translation': 'fork', 'pos_tags': ['NOUN']},
#  'bāgilu': {'translation': 'door', 'pos_tags': ['NOUN']},
#  'budhavāra': {'translation': 'Wednesday', 'pos_tags': ['PROPN']},
#  'beṃki': {'translation': 'fire', 'pos_tags': ['NOUN']},
#  'bēli': {'translation': 'fence', 'pos_tags': ['NOUN']},
#  'bhāratīya': {'translation': 'Indian', 'pos_tags': ['ADJ']},
#  'maṃgaḷavāra': {'translation': 'Tuesday', 'pos_tags': ['PROPN']},
#  'mattu': {'translation': 'and', 'pos_tags': ['CCONJ']},
#  'manuṣya': {'translation': 'human, person',
#   'pos_tags': ['ADJ', 'PUNCT', 'NOUN']},
#  'mara': {'translation': 'tree, wood', 'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'mahiḷe': {'translation': 'lady', 'pos_tags': ['PROPN']},
#  'maḷe': {'translation': 'rain', 'pos_tags': ['NOUN']},
#  'māle': {'translation': 'garland', 'pos_tags': ['VERB']},
#  'mūru': {'translation': 'three', 'pos_tags': ['NUM']},
#  'mēju': {'translation': 'table', 'pos_tags': ['NOUN']},
#  'mēṇabatti': {'translation': 'candle', 'pos_tags': ['NOUN']},
#  'mōḍa': {'translation': 'cloud', 'pos_tags': ['PROPN']},
#  'ravivāra': {'translation': 'Sunday', 'pos_tags': ['PROPN']},
#  'raste': {'translation': 'road', 'pos_tags': ['NOUN']},
#  'rikṣā': {'translation': 'rikshaw', 'pos_tags': ['NOUN']},
#  'vimāna': {'translation': 'airplane', 'pos_tags': ['NOUN']},
#  'śanivāra': {'translation': 'Saturday', 'pos_tags': ['PROPN']},
#  'śukravāra': {'translation': 'energy, power',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'sūṭkēsu': {'translation': 'suitcase', 'pos_tags': ['NOUN']},
#  'sūrya': {'translation': 'sun', 'pos_tags': ['PROPN']},
#  'sōmavāra': {'translation': 'Monday', 'pos_tags': ['PROPN']},
#  'strī': {'translation': 'woman', 'pos_tags': ['NOUN']},
#  'hakki': {'translation': 'bird', 'pos_tags': ['NOUN']},
#  'halavu': {'translation': 'many', 'pos_tags': ['ADJ']},
#  'hasu': {'translation': 'cow', 'pos_tags': ['NOUN']},
#  'hāḍu': {'translation': 'song; to sing',
#   'pos_tags': ['NOUN', 'PUNCT', 'PART', 'VERB']},
#  'hippi': {'translation': 'hippie', 'pos_tags': ['VERB']},
#  'huḍuga': {'translation': 'boy', 'pos_tags': ['PROPN']},
#  'huḍugi': {'translation': 'girl', 'pos_tags': ['NOUN']},
#  'hū': {'translation': 'flower', 'pos_tags': ['NOUN']},
#  'heṃgasu': {'translation': 'woman', 'pos_tags': ['NOUN']},
#  'hola': {'translation': 'field', 'pos_tags': ['NOUN']},
#  'haudu': {'translation': 'yes', 'pos_tags': ['INTJ']},
#  'yāvāgalū illa': {'translation': 'never', 'pos_tags': ['ADV']},
#  'ēnū illa': {'translation': 'nothing', 'pos_tags': ['PRON']},
#  'yārū illa': {'translation': 'nobody', 'pos_tags': ['PRON']},
#  'ide': {'translation': 'it is, it exists',
#   'pos_tags': ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB']},
#  'ēke': {'translation': 'why?', 'pos_tags': ['SCONJ', 'PUNCT']},
#  'ēnu': {'translation': 'what?', 'pos_tags': ['PRON', 'PUNCT']},
#  'kappu': {'translation': 'black', 'pos_tags': ['ADJ']},
#  'kaṣṭa': {'translation': 'difficult', 'pos_tags': ['ADJ']},
#  'toḍaku': {'translation': 'problem', 'pos_tags': ['NOUN']},
#  'nanna': {'translation': 'my', 'pos_tags': ['PRON']},
#  'namma': {'translation': 'our', 'pos_tags': ['PRON']},
#  'patra': {'translation': 'letter', 'pos_tags': ['NOUN']},
#  'purōhita': {'translation': 'priest', 'pos_tags': ['NOUN']},
#  'biḷi': {'translation': 'white', 'pos_tags': ['PROPN']},
#  'maneyavaru': {'translation': 'spouse (‘of-the-house person’)',
#   'pos_tags': ['NOUN']},
#  'yāru': {'translation': 'who?', 'pos_tags': ['PRON', 'PUNCT']},
#  'yāva': {'translation': 'which?', 'pos_tags': ['PRON', 'PUNCT']},
#  'yāvāga': {'translation': 'when?', 'pos_tags': ['SCONJ', 'PUNCT']},
#  'samācāra': {'translation': 'news', 'pos_tags': ['NOUN']},
#  'hesaru': {'translation': 'name', 'pos_tags': ['NOUN']},
#  'hēge': {'translation': 'in which manner?',
#   'pos_tags': ['ADP', 'PRON', 'NOUN', 'PUNCT']},
#  'appa': {'translation': 'father', 'pos_tags': ['PROPN']},
#  'amma': {'translation': 'mother', 'pos_tags': ['NOUN']},
#  'kaṇṇu': {'translation': 'eye', 'pos_tags': ['NOUN']},
#  'kivi': {'translation': 'ear', 'pos_tags': ['NOUN']},
#  'kuri': {'translation': 'to aim', 'pos_tags': ['PART', 'VERB']},
#  'kūsu': {'translation': 'baby', 'pos_tags': ['NOUN']},
#  'gaṃḍa': {'translation': 'husband', 'pos_tags': ['NOUN']},
#  'gaṃḍasu': {'translation': 'man', 'pos_tags': ['NOUN']},
#  'nighaṃṭu': {'translation': 'dictionary', 'pos_tags': ['PROPN']},
#  'nīru': {'translation': 'water', 'pos_tags': ['NOUN']},
#  'buṭṭi': {'translation': 'basket', 'pos_tags': ['NOUN']},
#  'maga': {'translation': 'son', 'pos_tags': ['NOUN']},
#  'magaḷu': {'translation': 'daughter', 'pos_tags': ['NOUN']},
#  'magu': {'translation': 'child', 'pos_tags': ['NOUN']},
#  'māva': {'translation': 'uncle', 'pos_tags': ['NOUN']},
#  'rāja': {'translation': 'king', 'pos_tags': ['NOUN']},
#  'raita': {'translation': 'farmer', 'pos_tags': ['NOUN']},
#  'vidhave': {'translation': 'widow', 'pos_tags': ['NOUN']},
#  'anubhava': {'translation': 'experience', 'pos_tags': ['VERB']},
#  'āṭike': {'translation': 'toy', 'pos_tags': ['NOUN']},
#  'āyke': {'translation': 'choice', 'pos_tags': ['NOUN']},
#  'keṃpu': {'translation': 'red', 'pos_tags': ['PROPN']},
#  'koṃbu': {'translation': 'horn', 'pos_tags': ['NOUN']},
#  'koṃbe': {'translation': 'branch', 'pos_tags': ['NOUN']},
#  'cūpu': {'translation': 'sharp', 'pos_tags': ['ADJ']},
#  'tudi': {'translation': 'tip', 'pos_tags': ['NOUN']},
#  'parimāṇa': {'translation': 'size', 'pos_tags': ['NOUN']},
#  'baṭṭe': {'translation': 'cloth', 'pos_tags': ['NOUN']},
#  'baṇṇa': {'translation': 'colour', 'pos_tags': ['NOUN']},
#  'bēre': {'translation': 'other, something else',
#   'pos_tags': ['ADJ', 'PUNCT', 'PRON', 'ADV']},
#  'saṃkhye': {'translation': 'number', 'pos_tags': ['NOUN']},
#  'hasiru': {'translation': 'green', 'pos_tags': ['ADJ']},
#  'haḷadi': {'translation': 'yellow', 'pos_tags': ['ADJ']},
#  'heṃḍati': {'translation': 'wife', 'pos_tags': ['NOUN']},
#  'nidde': {'translation': 'sleep', 'pos_tags': ['NOUN']},
#  'nāyi': {'translation': 'dog', 'pos_tags': ['NOUN']},
#  'kathe': {'translation': 'story', 'pos_tags': ['NOUN']},
#  'kelasa': {'translation': 'work', 'pos_tags': ['NOUN']},
#  'toṃdare': {'translation': 'trouble', 'pos_tags': ['NOUN']},
#  'nenne': {'translation': 'yesterday', 'pos_tags': ['NOUN']},
#  'satya': {'translation': 'truth', 'pos_tags': ['NOUN']},
#  'haṇa': {'translation': 'money', 'pos_tags': ['NOUN']},
#  'haṇṇu': {'translation': 'fruit', 'pos_tags': ['NOUN']},
#  'mēle': {'translation': 'on', 'pos_tags': ['ADP']},
#  'keḷage': {'translation': 'under', 'pos_tags': ['ADP']},
#  'oḷage': {'translation': 'within', 'pos_tags': ['ADP']},
#  'oḷagu': {'translation': 'inside', 'pos_tags': ['ADP']},
#  'hattira': {'translation': 'near; nearness',
#   'pos_tags': ['ADV', 'PUNCT', 'NOUN']},
#  'bage': {'translation': 'thought', 'pos_tags': ['VERB']},
#  'madhya': {'translation': 'middle', 'pos_tags': ['ADJ']},
#  'muṃde': {'translation': 'before', 'pos_tags': ['ADP']},
#  'horage': {'translation': 'outside', 'pos_tags': ['ADV']},
#  'aḍige': {'translation': 'cooking', 'pos_tags': ['VERB']},
#  'uttara': {'translation': 'north', 'pos_tags': ['NOUN']},
#  'kāpi': {'translation': 'coffee', 'pos_tags': ['NOUN']},
#  'gaḍi': {'translation': 'border', 'pos_tags': ['NOUN']},
#  'cahā': {'translation': 'tea', 'pos_tags': ['NOUN']},
#  'padārtha': {'translation': 'thing', 'pos_tags': ['NOUN']},
#  'pavāḍa': {'translation': 'miracle', 'pos_tags': ['NOUN']},
#  'viśēṣavāda': {'translation': 'special', 'pos_tags': ['ADJ']},
#  'vaiṣṇava': {'translation': 'devotee of Viṣṇu, Viṣṇuite',
#   'pos_tags': ['NOUN', 'ADP', 'PROPN', 'PUNCT', 'PROPN']},
#  'samādhi': {'translation': 'tomb', 'pos_tags': ['NOUN']},
#  'ele': {'translation': 'leaf', 'pos_tags': ['VERB']},
#  'athavā': {'translation': 'or', 'pos_tags': ['CCONJ']},
#  'abhiprāya': {'translation': 'opinion', 'pos_tags': ['NOUN']},
#  'iḍiya': {'translation': 'entire', 'pos_tags': ['ADJ']},
#  'upayukta': {'translation': 'useful', 'pos_tags': ['ADJ']},
#  'keṭṭa': {'translation': 'bad', 'pos_tags': ['ADJ']},
#  'kliṣṭa': {'translation': 'complicated', 'pos_tags': ['VERB']},
#  'gaddala': {'translation': 'noise', 'pos_tags': ['NOUN']},
#  'cakravarti': {'translation': 'emperor', 'pos_tags': ['NOUN']},
#  'cikka': {'translation': 'small', 'pos_tags': ['ADJ']},
#  'jagattu': {'translation': 'world', 'pos_tags': ['NOUN']},
#  'dūra': {'translation': 'distance', 'pos_tags': ['NOUN']},
#  'nīli': {'translation': 'blue', 'pos_tags': ['ADJ']},
#  'praśne': {'translation': 'question', 'pos_tags': ['NOUN']},
#  'bīdi': {'translation': 'street', 'pos_tags': ['PROPN']},
#  'bhāra': {'translation': 'weight', 'pos_tags': ['NOUN']},
#  'bhārata': {'translation': 'India', 'pos_tags': ['PROPN']},
#  'mukhya': {'translation': 'something important', 'pos_tags': ['PRON', 'ADJ']},
#  'yuga': {'translation': 'era', 'pos_tags': ['NOUN']},
#  'saṃgīta': {'translation': 'music', 'pos_tags': ['NOUN']},
#  'suṃdara': {'translation': 'beautiful', 'pos_tags': ['ADJ']},
#  'kelavu': {'translation': 'some (things)', 'pos_tags': ['PRON']},
#  'kōlu': {'translation': 'stick', 'pos_tags': ['VERB']},
#  'ciṃtaka': {'translation': 'thinker', 'pos_tags': ['NOUN']},
#  'tīra': {'translation': 'coast', 'pos_tags': ['PROPN']},
#  'bhakta': {'translation': 'devotee, follower',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'maṭha': {'translation': 'monastery', 'pos_tags': ['VERB']},
#  'Madhvācārya': {'translation': '(name of a philosopher)', 'pos_tags': []},
#  'śatamāna': {'translation': 'century (100 years)', 'pos_tags': ['NOUN']},
#  'saṃpradāya': {'translation': 'tradition', 'pos_tags': ['NOUN']},
#  'hadimūraneya': {'translation': 'thirteenth', 'pos_tags': ['NOUN']},
#  'āphisu': {'translation': 'office', 'pos_tags': ['NOUN']},
#  'oraṭu': {'translation': 'coarseness', 'pos_tags': ['NOUN']},
#  'krūra': {'translation': 'cruel', 'pos_tags': ['ADJ']},
#  'khuśi': {'translation': 'joy', 'pos_tags': ['NOUN']},
#  'tiṃgaḷu': {'translation': 'month', 'pos_tags': ['NOUN']},
#  'dayaviṭṭu': {'translation': 'please', 'pos_tags': ['INTJ']},
#  'pāṭha': {'translation': 'lesson', 'pos_tags': ['NOUN']},
#  'prayatna': {'translation': 'attempt, try, effort',
#   'pos_tags': ['NOUN', 'PUNCT', 'VERB', 'PUNCT', 'NOUN']},
#  'muṃdina': {'translation': 'next', 'pos_tags': ['ADV']},
#  'yōcane': {'translation': 'thought', 'pos_tags': ['VERB']},
#  'vākya': {'translation': 'sentence', 'pos_tags': ['VERB']},
#  'śabda': {'translation': 'word', 'pos_tags': ['NOUN']},
#  'saṃtōṣa': {'translation': 'joy', 'pos_tags': ['NOUN']},
#  'sammēḷana': {'translation': 'conference', 'pos_tags': ['NOUN']},
#  'spaṣṭa': {'translation': 'clear', 'pos_tags': ['ADJ']},
#  'artha': {'translation': 'meaning', 'pos_tags': ['VERB']},
#  'ādare': {'translation': 'but', 'pos_tags': ['CCONJ']},
#  'kṣame': {'translation': 'forgiveness', 'pos_tags': ['NOUN']},
#  'daya': {'translation': 'grace, mercy',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'hōṭalu': {'translation': 'restaurant', 'pos_tags': ['NOUN']},
#  'adhyāpaka': {'translation': 'teacher', 'pos_tags': ['NOUN']},
#  'kōpa': {'translation': 'anger', 'pos_tags': ['NOUN']},
#  'graṃthapālaka': {'translation': 'librarian', 'pos_tags': ['PROPN']},
#  'graṃthālaya': {'translation': 'library', 'pos_tags': ['NOUN']},
#  'patrike': {'translation': 'magazine', 'pos_tags': ['NOUN']},
#  'sahāya': {'translation': 'help', 'pos_tags': ['VERB']},
#  'hemme': {'translation': 'pride', 'pos_tags': ['NOUN']},
#  'hōguvike': {'translation': 'going', 'pos_tags': ['VERB']},
#  'bāḷike': {'translation': 'living', 'pos_tags': ['VERB']},
#  'ārōgya': {'translation': 'health', 'pos_tags': ['NOUN']},
#  'gōḍe': {'translation': 'wall', 'pos_tags': ['NOUN']},
#  'gōva': {'translation': 'Goa', 'pos_tags': ['PROPN']},
#  'jōru': {'translation': 'force, forcefulness',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'tinnu': {'translation': 'to eat', 'pos_tags': ['PART', 'VERB']},
#  'māṃsa': {'translation': 'meat', 'pos_tags': ['NOUN']},
#  'miliṭari': {'translation': 'military', 'pos_tags': ['NOUN']},
#  'miliṭari hōṭalu': {'translation': 'non-vegetarian',
#   'pos_tags': ['ADJ', 'ADJ', 'NOUN']},
#  'auṣadhi': {'translation': 'medicine', 'pos_tags': ['NOUN']},
#  'kaṭṭe': {'translation': 'mount', 'pos_tags': ['VERB']},
#  'giḍa': {'translation': 'plant', 'pos_tags': ['NOUN']},
#  'dēvi': {'translation': 'goddess', 'pos_tags': ['NOUN']},
#  'patni': {'translation': 'wife', 'pos_tags': ['NOUN']},
#  'pradakṣiṇe': {'translation': 'circumambulation', 'pos_tags': ['NOUN']},
#  'bhakti': {'translation': 'devotion', 'pos_tags': ['NOUN']},
#  'mātra': {'translation': 'only', 'pos_tags': ['ADV']},
#  'saṃpattu': {'translation': 'wealth', 'pos_tags': ['NOUN']},
#  'sādhya': {'translation': 'possible', 'pos_tags': ['ADJ']},
#  'sulabha': {'translation': 'easy', 'pos_tags': ['ADJ']},
#  'saubhāgya': {'translation': 'well-being',
#   'pos_tags': ['ADV', 'PUNCT', 'NOUN']},
#  'atṛpta': {'translation': 'dissatisfied', 'pos_tags': ['ADJ']},
#  'atṛpti': {'translation': 'dissatisfaction', 'pos_tags': ['NOUN']},
#  'anubhāvi': {'translation': 'mystic', 'pos_tags': ['ADJ']},
#  'anuyāyi': {'translation': 'follower', 'pos_tags': ['NOUN']},
#  'asamānate': {'translation': 'inequality', 'pos_tags': ['NOUN']},
#  'ityādi': {'translation': 'etc.', 'pos_tags': ['X', 'X']},
#  'kuṭuṃba': {'translation': 'family', 'pos_tags': ['NOUN']},
#  'kelavomme': {'translation': 'sometimes', 'pos_tags': ['ADV']},
#  'guṃpu': {'translation': 'group', 'pos_tags': ['NOUN']},
#  'jāti': {'translation': 'caste', 'pos_tags': ['NOUN']},
#  'jīvana': {'translation': 'life', 'pos_tags': ['NOUN']},
#  'tṛpta': {'translation': 'satisfied', 'pos_tags': ['ADJ']},
#  'tṛpti': {'translation': 'satisfaction', 'pos_tags': ['NOUN']},
#  'dhārmika': {'translation': 'religious', 'pos_tags': ['ADJ']},
#  'naitika': {'translation': 'moral', 'pos_tags': ['ADJ']},
#  'paraṃpare': {'translation': 'tradition', 'pos_tags': ['NOUN']},
#  'prapaṃca': {'translation': 'world', 'pos_tags': ['NOUN']},
#  'prācīna': {'translation': 'ancient', 'pos_tags': ['ADJ']},
#  'prīti': {'translation': 'love', 'pos_tags': ['NOUN']},
#  'Basava': {'translation': '(name)', 'pos_tags': ['PUNCT', 'NOUN', 'PUNCT']},
#  'beḷavaṇige': {'translation': 'development', 'pos_tags': ['NOUN']},
#  'maṃdi': {'translation': 'person', 'pos_tags': ['NOUN']},
#  'manassu': {'translation': 'mind', 'pos_tags': ['NOUN']},
#  'samāna': {'translation': 'equal', 'pos_tags': ['ADJ']},
#  'samānate': {'translation': 'equality', 'pos_tags': ['NOUN']},
#  'sāmājika': {'translation': 'social', 'pos_tags': ['ADJ']},
#  'hiṃde': {'translation': 'behind, ago', 'pos_tags': ['ADV', 'PUNCT', 'ADV']},
#  'hinnele': {'translation': 'background', 'pos_tags': ['NOUN']},
#  'hosa': {'translation': 'new', 'pos_tags': ['ADJ']},
#  'anēka': {'translation': 'many', 'pos_tags': ['ADJ']},
#  'ippataidu': {'translation': 'twenty-five',
#   'pos_tags': ['NUM', 'PUNCT', 'NUM']},
#  'ēkeṃdare': {'translation': 'because', 'pos_tags': ['SCONJ']},
#  'omme': {'translation': 'once', 'pos_tags': ['ADV']},
#  'karāvaḷi': {'translation': 'coast', 'pos_tags': ['PROPN']},
#  'kaḷatmaka': {'translation': 'artistic', 'pos_tags': ['ADJ']},
#  'kāphi': {'translation': 'coffee', 'pos_tags': ['NOUN']},
#  'kāryakrama': {'translation': 'program', 'pos_tags': ['NOUN']},
#  'kuḍuma': {'translation': '(placename)',
#   'pos_tags': ['PUNCT', 'NOUN', 'PUNCT']},
#  'kēṃdra': {'translation': 'centre', 'pos_tags': ['NOUN']},
#  'caḷi': {'translation': 'to be tired', 'pos_tags': ['PART', 'AUX', 'ADJ']},
#  'cikitsālaya': {'translation': 'clinic', 'pos_tags': ['NOUN']},
#  'jille': {'translation': 'district', 'pos_tags': ['NOUN']},
#  'taṃde': {'translation': 'father', 'pos_tags': ['PROPN']},
#  'takṣaṇa': {'translation': 'immediately', 'pos_tags': ['ADV']},
#  'tale': {'translation': 'head', 'pos_tags': ['NOUN']},
#  'talenōvu': {'translation': 'headache', 'pos_tags': ['PROPN']},
#  'dēvate': {'translation': 'divinity', 'pos_tags': ['NOUN']},
#  'Dharmasthaḷa': {'translation': '(placename)',
#   'pos_tags': ['PUNCT', 'NOUN', 'PUNCT']},
#  'nōvu': {'translation': 'pain', 'pos_tags': ['NOUN']},
#  'paṃḍita': {'translation': 'scholar', 'pos_tags': ['NOUN']},
#  'pūrvaja': {'translation': 'ancestor', 'pos_tags': ['NOUN']},
#  'Maṃjunātha': {'translation': '(name)',
#   'pos_tags': ['PUNCT', 'NOUN', 'PUNCT']},
#  'yātrika': {'translation': 'pilgrim', 'pos_tags': ['NOUN']},
#  'rakṣaṇe': {'translation': 'protection', 'pos_tags': ['NOUN']},
#  'varegū': {'translation': 'until', 'pos_tags': ['ADP']},
#  'varṣa': {'translation': 'year', 'pos_tags': ['NOUN']},
#  'Vādirāja': {'translation': '(name)', 'pos_tags': ['PUNCT', 'NOUN', 'PUNCT']},
#  'śikṣaka': {'translation': 'teacher', 'pos_tags': ['NOUN']},
#  'saṃgrahālaya': {'translation': 'museum', 'pos_tags': ['NOUN']},
#  'sahiṣṇute': {'translation': 'tolerance', 'pos_tags': ['NOUN']},
#  'sāṃskṛtika': {'translation': 'cultural', 'pos_tags': ['ADJ']},
#  'sāvira': {'translation': '1000 When smaller numbers are added to higher units (hundreds, thousands, etc.), the connection between the higher and lower elements in the numeral is indicated by the genitive case:',
#   'pos_tags': ['NUM',
#    'SCONJ',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'ADP',
#    'ADJ',
#    'NOUN']},
#  'sāvirāru': {'translation': 'thousands', 'pos_tags': ['NOUN']},
#  'sumāru': {'translation': 'approximately', 'pos_tags': ['ADV']},
#  'hadināraneya': {'translation': 'sixteenth', 'pos_tags': ['ADJ']},
#  'huṣāru': {'translation': 'healthiness', 'pos_tags': ['NOUN']},
#  'ellarannu / ellarannū': {'translation': '(accusative)',
#   'pos_tags': ['PUNCT', 'ADJ', 'PUNCT']},
#  'ellariṃda / ellariṃdalū': {'translation': '(ablative)',
#   'pos_tags': ['PUNCT', 'ADJ', 'PUNCT']},
#  'ellara': {'translation': '(genitive)',
#   'pos_tags': ['PUNCT', 'ADJ', 'PUNCT']},
#  'ellaralli / ellarallū': {'translation': '(locative)',
#   'pos_tags': ['PUNCT', 'ADJ', 'PUNCT']},
#  'āru': {'translation': 'six', 'pos_tags': ['NUM']},
#  'ēḷu': {'translation': 'to rise', 'pos_tags': ['PART', 'VERB']},
#  'eṃṭu': {'translation': 'eight', 'pos_tags': ['NUM']},
#  'oṃbattu': {'translation': 'nine', 'pos_tags': ['NUM']},
#  'hannoṃdu': {'translation': 'eleven', 'pos_tags': ['NUM']},
#  'hanneraḍu': {'translation': 'twelve', 'pos_tags': ['NUM']},
#  'hadimūru': {'translation': 'thirteen', 'pos_tags': ['NUM']},
#  'hadinālku': {'translation': 'fourteen', 'pos_tags': ['NUM']},
#  'hadinaidu': {'translation': 'fifteen', 'pos_tags': ['NUM']},
#  'hadināru': {'translation': 'sixteen', 'pos_tags': ['NUM']},
#  'hadinēḷu': {'translation': 'seventeen', 'pos_tags': ['X']},
#  'hadineṃṭu': {'translation': 'eighteen', 'pos_tags': ['NUM']},
#  'hattoṃbattu': {'translation': 'nineteen', 'pos_tags': ['NUM']},
#  'ippattu': {'translation': 'twenty', 'pos_tags': ['NUM']},
#  'ippattoṃdu': {'translation': 'twenty-one',
#   'pos_tags': ['NUM', 'PUNCT', 'NUM']},
#  'ippatteraḍu': {'translation': 'twenty-two',
#   'pos_tags': ['NUM', 'PUNCT', 'NUM']},
#  'ippattanālku': {'translation': 'twenty-four',
#   'pos_tags': ['NUM', 'PUNCT', 'NUM']},
#  'ippattaidu': {'translation': 'twenty-five',
#   'pos_tags': ['NUM', 'PUNCT', 'NUM']},
#  'ippattāru': {'translation': 'twenty-six',
#   'pos_tags': ['NUM', 'PUNCT', 'NUM']},
#  'ippattēḷu': {'translation': 'twenty-seven',
#   'pos_tags': ['NUM', 'PUNCT', 'NUM']},
#  'ippatteṃṭu': {'translation': 'twenty-eight',
#   'pos_tags': ['NUM', 'PUNCT', 'NUM']},
#  'ippattoṃbattu': {'translation': 'twenty-nine',
#   'pos_tags': ['NUM', 'PUNCT', 'NUM']},
#  'aivattu': {'translation': 'fifty', 'pos_tags': ['NUM']},
#  'aravattu': {'translation': 'sixty', 'pos_tags': ['NUM']},
#  'eppattu': {'translation': 'seventy', 'pos_tags': ['NUM']},
#  'eṃbattu': {'translation': 'eighty', 'pos_tags': ['NUM']},
#  'toṃbattu': {'translation': 'ninety', 'pos_tags': ['NUM']},
#  'nūru': {'translation': 'hundred', 'pos_tags': ['NUM']},
#  'innūru': {'translation': '200', 'pos_tags': ['NUM']},
#  'munnūru': {'translation': '300', 'pos_tags': ['NUM']},
#  'nānūru': {'translation': '400', 'pos_tags': ['NUM']},
#  'ainūru': {'translation': '500', 'pos_tags': ['NUM']},
#  'ārunūru': {'translation': '600', 'pos_tags': ['NUM']},
#  'ēḷunūru': {'translation': '700', 'pos_tags': ['NUM']},
#  'eṃṭunūru': {'translation': '800', 'pos_tags': ['NUM']},
#  'oṃbainūru': {'translation': '900', 'pos_tags': ['NUM']},
#  'nūra nalvattoṃdu': {'translation': '141', 'pos_tags': ['NUM']},
#  'sāvirada oṃbainūra toṃbattaidu': {'translation': '1995',
#   'pos_tags': ['NUM']},
#  'āgi': {'translation': '(gerund)', 'pos_tags': ['PUNCT', 'NOUN', 'PUNCT']},
#  'hōgi': {'translation': '(gerund)', 'pos_tags': ['PUNCT', 'NOUN', 'PUNCT']},
#  'utkhanana': {'translation': 'excavation', 'pos_tags': ['NOUN']},
#  'hagga': {'translation': 'rope', 'pos_tags': ['NOUN']},
#  'heccu': {'translation': 'much, a lot, very',
#   'pos_tags': ['ADV', 'PUNCT', 'DET', 'NOUN', 'PUNCT', 'ADV']},
#  'ajja': {'translation': 'grandfather', 'pos_tags': ['NOUN']},
#  'jñāna': {'translation': 'knowledge', 'pos_tags': ['NOUN']},
#  'daḍḍa': {'translation': 'dunce', 'pos_tags': ['NOUN']},
#  'kobbu': {'translation': 'fat', 'pos_tags': ['ADJ']},
#  'udbhava': {'translation': 'origin', 'pos_tags': ['NOUN']},
#  'ayya': {'translation': 'lord', 'pos_tags': ['PROPN']},
#  'prabhāva': {'translation': 'influence', 'pos_tags': ['NOUN']},
#  'tatva': {'translation': 'principle', 'pos_tags': ['NOUN']},
#  'utsava': {'translation': 'feast', 'pos_tags': ['NOUN']},
#  'kaḷḷa': {'translation': 'thief', 'pos_tags': ['NOUN']},
#  'aparūpavāgi': {'translation': 'rarely', 'pos_tags': ['ADV']},
#  'jana': {'translation': 'person, people',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'bahaḷa': {'translation': 'much, many, very',
#   'pos_tags': ['ADJ', 'PUNCT', 'ADJ', 'PUNCT', 'ADV']},
#  'bhāṣe': {'translation': 'language', 'pos_tags': ['NOUN']},
#  'yāvāgalū': {'translation': 'always', 'pos_tags': ['ADV']},
#  'haḷeya': {'translation': 'old', 'pos_tags': ['ADJ']},
#  'aṃgaḍiyavaru': {'translation': 'shopkeeper', 'pos_tags': ['NOUN']},
#  'ajñāna': {'translation': 'ignorance', 'pos_tags': ['NOUN']},
#  'gottu': {'translation': 'knowledge, known thing',
#   'pos_tags': ['NOUN', 'PUNCT', 'ADJ', 'NOUN']},
#  'nṛtya': {'translation': 'dance', 'pos_tags': ['VERB']},
#  'paravā': {'translation': 'worry', 'pos_tags': ['VERB']},
#  'parvata': {'translation': 'mountain', 'pos_tags': ['NOUN']},
#  'baḷi': {'translation': 'near', 'pos_tags': ['ADP']},
#  'buddhi': {'translation': 'intelligence', 'pos_tags': ['NOUN']},
#  'beḷaku': {'translation': 'light', 'pos_tags': ['ADJ']},
#  'bhasma': {'translation': 'ash', 'pos_tags': ['PROPN']},
#  'majjige': {'translation': 'buttermilk', 'pos_tags': ['NOUN']},
#  'mūgu': {'translation': 'nose', 'pos_tags': ['NOUN']},
#  'modalaneya': {'translation': 'first', 'pos_tags': ['ADV']},
#  'rākṣasa': {'translation': 'demon', 'pos_tags': ['NOUN']},
#  'rūpa': {'translation': 'form, shape', 'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'vimānanildāṇa': {'translation': 'airport', 'pos_tags': ['NOUN']},
#  'vaiṣṇavadharma': {'translation': 'Viṣṇuism', 'pos_tags': ['NOUN']},
#  'saṃkēta': {'translation': 'symbol', 'pos_tags': ['NOUN']},
#  'saṃsthe': {'translation': 'institute', 'pos_tags': ['PROPN']},
#  'sāṃkētika': {'translation': 'symbolic', 'pos_tags': ['ADJ']},
#  'sāmānya': {'translation': 'ordinary', 'pos_tags': ['ADJ']},
#  'haṇe': {'translation': 'forehead', 'pos_tags': ['PROPN']},
#  'ōḍu': {'translation': 'to run', 'pos_tags': ['PART', 'VERB']},
#  'ōdu': {'translation': 'to read', 'pos_tags': ['PART', 'VERB']},
#  'hēḷu': {'translation': 'to say', 'pos_tags': ['PART', 'VERB']},
#  'hēlu': {'translation': 'to shit', 'pos_tags': ['PART', 'VERB']},
#  'baḍi': {'translation': 'to beat', 'pos_tags': ['PART', 'VERB']},
#  'baḍḍi': {'translation': 'interest (on money)', 'pos_tags': ['NOUN']},
#  'maḍi': {'translation': 'ritually pure', 'pos_tags': ['ADV', 'ADJ']},
#  'māḍi': {'translation': 'please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:',
#   'pos_tags': ['INTJ',
#    'VERB',
#    'DET',
#    'NUM',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'NOUN',
#    'AUX',
#    'ADV',
#    'ADJ']},
#  'nīnu': {'translation': 'you (singular and non-honorific)',
#   'pos_tags': ['PRON']},
#  'nīvu': {'translation': 'you (plural / honorific)', 'pos_tags': ['PRON']},
#  'avaru': {'translation': 'they (persons)', 'pos_tags': ['PRON']},
#  'avu': {'translation': 'they (non-persons)', 'pos_tags': ['PRON']},
#  'ivaru': {'translation': 'he / she (honorific)',
#   'pos_tags': ['PRON', 'SYM', 'PRON']},
#  'ivu': {'translation': 'they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.)',
#   'pos_tags': ['PRON', 'PUNCT', 'PRON']},
#  'hīge': {'translation': 'in this manner', 'pos_tags': ['ADP', 'DET', 'NOUN']},
#  'hāge': {'translation': 'in that manner', 'pos_tags': ['ADP', 'DET', 'NOUN']},
#  'iṣṭu': {'translation': 'this much', 'pos_tags': ['PRON', 'ADJ']},
#  'aṣṭu': {'translation': 'that much', 'pos_tags': ['ADV', 'ADV']},
#  'eṣṭu': {'translation': 'how much?', 'pos_tags': ['SCONJ', 'ADJ', 'PUNCT']},
#  'ili': {'translation': 'mouse, rat', 'pos_tags': ['PROPN', 'PUNCT', 'CCONJ']},
#  'kālu': {'translation': 'leg, foot', 'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'kai': {'translation': 'hand, arm', 'pos_tags': ['NOUN', 'PUNCT', 'VERB']},
#  'graṃtha': {'translation': 'book, volume',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'doḍḍa': {'translation': 'big, large', 'pos_tags': ['ADJ', 'PUNCT', 'ADJ']},
#  'paṃce': {'translation': '(traditional men’s dress: ‘dhoti’)',
#   'pos_tags': []},
#  'pennu': {'translation': 'ballpoint pen', 'pos_tags': ['PROPN', 'NOUN']},
#  'pyāṃṭu': {'translation': 'pair of trousers',
#   'pos_tags': ['NOUN', 'ADP', 'NOUN']},
#  'beṭṭa': {'translation': 'hill, mountain',
#   'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'muduki': {'translation': 'old woman', 'pos_tags': ['ADJ', 'NOUN']},
#  'maidāna': {'translation': 'lawn, field',
#   'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'yuvati': {'translation': 'young woman', 'pos_tags': ['ADJ', 'NOUN']},
#  'luṃgi': {'translation': '(traditional men’s dress: long loincloth)',
#   'pos_tags': []},
#  'vidyārthi': {'translation': '[male] student',
#   'pos_tags': ['X', 'NOUN', 'X', 'NOUN']},
#  'vidyārthini': {'translation': '[female] student',
#   'pos_tags': ['X', 'ADJ', 'PUNCT', 'NOUN']},
#  'Viṣṇu': {'translation': '(name of god)', 'pos_tags': []},
#  'Śiva': {'translation': '(name of god)', 'pos_tags': []},
#  'sagaṇi': {'translation': 'cow dung', 'pos_tags': ['NOUN', 'PROPN']},
#  'sāmānugaḷu': {'translation': 'things, belongings',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'sīre': {'translation': '(traditional ladies’ dress: ‘sari’)',
#   'pos_tags': []},
#  'hāḍugāra': {'translation': 'singer (male)', 'pos_tags': ['NOUN']},
#  'hāḍugārti': {'translation': 'singer (female)', 'pos_tags': ['NOUN']},
#  'Namaskāra.': {'translation': '(the same is said when parting)',
#   'pos_tags': []},
#  'Banni.': {'translation': 'Yes, you may go (‘Please come’).',
#   'pos_tags': ['INTJ', 'PUNCT', 'PRON', 'AUX', 'VERB']},
#  'Hēgiddīri?': {'translation': 'How are you? Gururāja',
#   'pos_tags': ['SCONJ', 'AUX', 'PRON', 'PUNCT', 'NOUN']},
#  'ivara': {'translation': 'his / her (honorific)',
#   'pos_tags': ['PRON', 'SYM', 'PRON']},
#  'elliṃda': {'translation': 'from where?',
#   'pos_tags': ['ADP', 'SCONJ', 'PUNCT']},
#  'cennāgi': {'translation': 'nicely, finely',
#   'pos_tags': ['ADV', 'PUNCT', 'ADV']},
#  'nimma': {'translation': 'your (honorific)', 'pos_tags': ['PRON']},
#  'banni': {'translation': 'please come', 'pos_tags': ['INTJ', 'VERB']},
#  'barali': {'translation': 'I should come',
#   'pos_tags': ['PRON', 'AUX', 'VERB']},
#  'baru': {'translation': 'to come', 'pos_tags': ['PART', 'VERB']},
#  'bassu': {'translation': 'bus (vehicle)', 'pos_tags': ['NOUN']},
#  'bēku': {'translation': 'is wanted / required / needed',
#   'pos_tags': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB']},
#  'bēḍa': {'translation': 'is not wanted / not required',
#   'pos_tags': ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB']},
#  'viśēṣa': {'translation': 'something special', 'pos_tags': ['PRON', 'ADJ']},
#  'sari': {'translation': 'okay, all right, correct',
#   'pos_tags': ['INTJ', 'PUNCT', 'ADV', 'ADV', 'PUNCT', 'ADJ']},
#  'akka': {'translation': 'elder sister', 'pos_tags': ['ADJ', 'NOUN']},
#  'aṇṇa': {'translation': 'elder brother', 'pos_tags': ['ADJ', 'NOUN']},
#  'kere': {'translation': 'tank, water reservoir',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN', 'NOUN']},
#  'cīla': {'translation': 'bag, purse', 'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'dēśa': {'translation': 'country, land',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'puṭa': {'translation': 'page (of book etc.)', 'pos_tags': ['NOUN']},
#  'snēhita': {'translation': 'friend (male)', 'pos_tags': ['NOUN']},
#  'snēhite': {'translation': 'friend (female)', 'pos_tags': ['NOUN']},
#  'aṃgaḍi': {'translation': 'store, shop',
#   'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'jijñāsu': {'translation': 'eager to learn',
#   'pos_tags': ['ADJ', 'PART', 'VERB']},
#  'paṃḍite': {'translation': 'learned woman', 'pos_tags': ['VERB', 'NOUN']},
#  'hōdenu': {'translation': 'I went', 'pos_tags': ['PRON', 'VERB']},
#  'ādenu': {'translation': 'I became', 'pos_tags': ['PRON', 'VERB']},
#  'hōdi': {'translation': 'you went', 'pos_tags': ['PRON', 'VERB']},
#  'ādi': {'translation': 'you became', 'pos_tags': ['PRON', 'VERB']},
#  'hōdanu': {'translation': 'he went', 'pos_tags': ['PRON', 'VERB']},
#  'ādanu': {'translation': 'he became', 'pos_tags': ['PRON', 'VERB']},
#  'hōdaḷu': {'translation': 'she went', 'pos_tags': ['PRON', 'VERB']},
#  'ādaḷu': {'translation': 'she became', 'pos_tags': ['PRON', 'VERB']},
#  'hōdevu': {'translation': 'we went', 'pos_tags': ['PRON', 'VERB']},
#  'ādevu': {'translation': 'we became', 'pos_tags': ['PRON', 'VERB']},
#  'hōdiri': {'translation': 'you went', 'pos_tags': ['PRON', 'VERB']},
#  'ādiri': {'translation': 'you became', 'pos_tags': ['PRON', 'VERB']},
#  'hōdaru': {'translation': 'they went', 'pos_tags': ['PRON', 'VERB']},
#  'ādaru': {'translation': 'they became', 'pos_tags': ['PRON', 'VERB']},
#  'āgu': {'translation': 'to become, occur',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'jigi': {'translation': 'to jump', 'pos_tags': ['PART', 'VERB']},
#  'kare': {'translation': 'to call', 'pos_tags': ['PART', 'VERB']},
#  'taru': {'translation': 'to bring', 'pos_tags': ['PART', 'VERB']},
#  'tiḷi': {'translation': 'to understand', 'pos_tags': ['PART', 'VERB']},
#  'nagu': {'translation': 'to laugh', 'pos_tags': ['PART', 'VERB']},
#  'bīḷu': {'translation': 'to fall', 'pos_tags': ['PART', 'VERB']},
#  'māḍu': {'translation': 'to do, make',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'hoḍe': {'translation': 'to hit, strike',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'hōgu': {'translation': 'to go', 'pos_tags': ['PART', 'VERB']},
#  'nōḍu': {'translation': 'to watch, look at',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADP']},
#  'bare': {'translation': 'to write', 'pos_tags': ['PART', 'VERB']},
#  'anna': {'translation': 'rice (cooked)', 'pos_tags': ['NOUN']},
#  'koḍu': {'translation': 'to give', 'pos_tags': ['PART', 'VERB']},
#  'viṣaya': {'translation': 'matter, thing, topic',
#   'pos_tags': ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']},
#  'sāku': {'translation': 'it is enough', 'pos_tags': ['PRON', 'AUX', 'ADJ']},
#  'sāladu': {'translation': 'it is not enough',
#   'pos_tags': ['PRON', 'AUX', 'PART', 'ADJ']},
#  'mēlu': {'translation': 'top side', 'pos_tags': ['ADJ', 'NOUN']},
#  'keḷagu': {'translation': 'lower side', 'pos_tags': ['ADJ', 'NOUN']},
#  'hiṃdu': {'translation': 'rear side', 'pos_tags': ['ADJ', 'NOUN']},
#  'āyitu': {'translation': 'all right, okay',
#   'pos_tags': ['ADV', 'ADV', 'PUNCT', 'INTJ']},
#  'iḍu': {'translation': 'to place, put',
#   'pos_tags': ['ADP', 'NOUN', 'PUNCT', 'VERB']},
#  'īgalū': {'translation': 'also now', 'pos_tags': ['ADV', 'ADV']},
#  'kaḍe': {'translation': 'side, direction',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'kōṇe': {'translation': 'room, chamber',
#   'pos_tags': ['NOUN', 'PUNCT', 'PROPN']},
#  'gaḍipradēśa': {'translation': 'border area', 'pos_tags': ['NOUN', 'NOUN']},
#  'tagoḷḷu': {'translation': 'to take', 'pos_tags': ['PART', 'VERB']},
#  'darśana': {'translation': 'seeing, sight, ritual viewing of an object of reverence',
#   'pos_tags': ['VERB',
#    'PUNCT',
#    'NOUN',
#    'PUNCT',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'NOUN']},
#  'nija': {'translation': 'real, true', 'pos_tags': ['ADJ', 'PUNCT', 'ADJ']},
#  'nijavāgi': {'translation': 'really, truly',
#   'pos_tags': ['ADV', 'PUNCT', 'ADV']},
#  'pradēśa': {'translation': 'region, area',
#   'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'bāḷu': {'translation': 'to live', 'pos_tags': ['PART', 'VERB']},
#  'summane': {'translation': 'just like that, quietly',
#   'pos_tags': ['ADV', 'ADP', 'PRON', 'PUNCT', 'ADV']},
#  'svalpa': {'translation': 'a bit, a little',
#   'pos_tags': ['DET', 'NOUN', 'PUNCT', 'DET', 'ADJ']},
#  'bāḷe': {'translation': 'banana tree', 'pos_tags': ['PROPN', 'NOUN']},
#  'rīti': {'translation': 'style, kind', 'pos_tags': ['NOUN', 'PUNCT', 'ADJ']},
#  'asahya': {'translation': 'intolerable, disgusting',
#   'pos_tags': ['ADJ', 'PUNCT', 'ADJ']},
#  'āḍu': {'translation': 'to play', 'pos_tags': ['PART', 'VERB']},
#  'iṣṭa': {'translation': 'liked, appreciated',
#   'pos_tags': ['VERB', 'PUNCT', 'VERB']},
#  'kēḷu': {'translation': 'to ask, to hear',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB']},
#  'kṣētra': {'translation': 'place of pilgrimage',
#   'pos_tags': ['NOUN', 'ADP', 'NOUN']},
#  'jāga': {'translation': 'place, space, spot',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']},
#  'taṃgi': {'translation': 'younger sister', 'pos_tags': ['ADJ', 'NOUN']},
#  'tīrthaṃkara': {'translation': '(holiest person in Jainism)', 'pos_tags': []},
#  'pūjārha': {'translation': 'worthy of worship',
#   'pos_tags': ['ADJ', 'ADP', 'NOUN']},
#  'prakāra': {'translation': 'according to', 'pos_tags': ['VERB', 'ADP']},
#  'mūrti': {'translation': 'icon, statue',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'modalu': {'translation': 'firstly, in the beginning',
#   'pos_tags': ['ADV', 'PUNCT', 'ADP', 'DET', 'NOUN']},
#  'mōkṣa': {'translation': '(religious) liberation', 'pos_tags': []},
#  'saṃsāra': {'translation': '‘the worldly system of',
#   'pos_tags': ['PUNCT', 'DET', 'ADJ', 'NOUN', 'ADP']},
#  'hoṃdu': {'translation': 'to acquire, achieve',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'kelasadavaḷu': {'translation': 'housemaid (‘of-the-work she’)',
#   'pos_tags': ['VERB']},
#  'avatāra': {'translation': 'incarnation of a god',
#   'pos_tags': ['NOUN', 'ADP', 'DET', 'NOUN']},
#  'gurutu': {'translation': 'mark, characteristic',
#   'pos_tags': ['PROPN', 'PUNCT', 'ADJ']},
#  'jāsti': {'translation': 'too much, excessively',
#   'pos_tags': ['ADV', 'ADJ', 'PUNCT', 'ADV']},
#  'taṃdaru': {'translation': 'he (hon.) brought', 'pos_tags': ['PRON']},
#  'tanna': {'translation': 'his / her / its own',
#   'pos_tags': ['PRON', 'SYM', 'PRON', 'SYM', 'PRON', 'ADJ']},
#  'divasā': {'translation': 'every day', 'pos_tags': ['DET', 'NOUN']},
#  'pūje': {'translation': 'ritual of worship',
#   'pos_tags': ['NOUN', 'ADP', 'NOUN']},
#  'rathabīdi': {'translation': 'Temple Street', 'pos_tags': ['PROPN', 'PROPN']},
#  'vidēśa': {'translation': 'foreign country', 'pos_tags': ['ADJ', 'NOUN']},
#  'samudra': {'translation': 'sea, ocean',
#   'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'iḷi': {'translation': 'to descend, go down',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADV']},
#  'kadi': {'translation': 'to steal', 'pos_tags': ['PART', 'VERB']},
#  'kāpāḍu': {'translation': 'to protect, guard',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'NOUN']},
#  'koḷḷu': {'translation': 'to buy', 'pos_tags': ['PART', 'VERB']},
#  'tīvra': {'translation': 'severe, intense',
#   'pos_tags': ['ADJ', 'PUNCT', 'ADJ']},
#  'naḍe': {'translation': 'to walk, to happen',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB']},
#  'paḍu': {'translation': 'to suffer, experience, undergo',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'VERB']},
#  'bayyu': {'translation': 'to abuse, scold',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'beḷe': {'translation': 'to grow', 'pos_tags': ['PART', 'VERB']},
#  'bhāgavahisu': {'translation': 'to participate',
#   'pos_tags': ['PART', 'VERB']},
#  'malagu': {'translation': 'to lie down, sleep',
#   'pos_tags': ['PART', 'VERB', 'ADV', 'PUNCT', 'VERB']},
#  'mātanāḍu': {'translation': 'to speak', 'pos_tags': ['PART', 'VERB']},
#  'lēkhaki': {'translation': 'writer (feminine)', 'pos_tags': ['NOUN']},
#  'vāpasu': {'translation': 'back, returned',
#   'pos_tags': ['ADV', 'PUNCT', 'VERB']},
#  'sustu': {'translation': 'tiredness, fatigue',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'sogasu': {'translation': 'grace, elegance, beauty',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN']},
#  'hattu': {'translation': 'to climb; to begin',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB']},
#  'hāru': {'translation': 'to fly, jump',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'horaḍu': {'translation': 'to set out, leave for',
#   'pos_tags': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB', 'ADP']},
#  'kareyisu': {'translation': 'to cause to call',
#   'pos_tags': ['PART', 'VERB', 'PART', 'VERB']},
#  'prakaṭa': {'translation': 'published, public',
#   'pos_tags': ['VERB', 'PUNCT', 'ADJ']},
#  'bēga': {'translation': 'fast, soon', 'pos_tags': ['ADV', 'PUNCT', 'ADV']},
#  'mēṣṭaru': {'translation': '(school) teacher (‘master’)', 'pos_tags': []},
#  'vicitra': {'translation': 'strange, odd',
#   'pos_tags': ['ADJ', 'PUNCT', 'ADJ']},
#  'araḷu': {'translation': 'to bloom, blossom',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'NOUN']},
#  'tamma': {'translation': 'younger brother', 'pos_tags': ['ADJ', 'NOUN']},
#  'neraḷu': {'translation': 'shade, shadow',
#   'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'mātu': {'translation': 'word, utterance',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'vāsa': {'translation': 'living, dwelling',
#   'pos_tags': ['VERB', 'PUNCT', 'VERB']},
#  'sigu': {'translation': 'to be obtained, to be met',
#   'pos_tags': ['PART', 'AUX', 'VERB', 'PUNCT', 'PART', 'AUX', 'VERB']},
#  'suddi': {'translation': 'news, message',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'bāradu': {'translation': 'may not', 'pos_tags': ['AUX', 'PART']},
#  'āse': {'translation': 'desire, wish', 'pos_tags': ['NOUN', 'PUNCT', 'VERB']},
#  'heṃḍa': {'translation': 'alcoholic beverage', 'pos_tags': ['ADJ', 'NOUN']},
#  'eṃdare': {'translation': 'i.e., that is to say',
#   'pos_tags': ['X', 'PUNCT', 'PRON', 'AUX', 'PART', 'VERB']},
#  'oḍati': {'translation': 'mistress, owner',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'kāṇisu': {'translation': 'to be seen, appear',
#   'pos_tags': ['PART', 'AUX', 'VERB', 'PUNCT', 'VERB']},
#  'kāraṇa': {'translation': 'cause, reason',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'tuḷasi': {'translation': 'Indian basil', 'pos_tags': ['ADJ', 'NOUN']},
#  'pavitra': {'translation': 'pure, holy', 'pos_tags': ['ADJ', 'PUNCT', 'ADJ']},
#  'pūjisu': {'translation': 'to worship', 'pos_tags': ['PART', 'VERB']},
#  'baḷasu': {'translation': 'to use', 'pos_tags': ['PART', 'VERB']},
#  'beḷigge': {'translation': 'in the morning',
#   'pos_tags': ['ADP', 'DET', 'NOUN']},
#  'śakti': {'translation': 'energy, power',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'hittalu': {'translation': 'back yard', 'pos_tags': ['NOUN', 'NOUN']},
#  'hedaru': {'translation': 'to fear', 'pos_tags': ['PART', 'VERB']},
#  'kareyavu': {'translation': 'In modern usage, these forms are generally considered rather old-fash- ioned and hardly occur. The main reason for this is that they do not',
#   'pos_tags': ['ADP',
#    'ADJ',
#    'NOUN',
#    'PUNCT',
#    'DET',
#    'NOUN',
#    'AUX',
#    'ADV',
#    'VERB',
#    'ADV',
#    'ADJ',
#    'PUNCT',
#    'ADJ',
#    'VERB',
#    'CCONJ',
#    'ADV',
#    'VERB',
#    'PUNCT',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'AUX',
#    'SCONJ',
#    'PRON',
#    'VERB',
#    'PART']},
#  'anubhavisu': {'translation': 'to experience', 'pos_tags': ['PART', 'VERB']},
#  'anubhāva': {'translation': 'religious experience',
#   'pos_tags': ['ADJ', 'NOUN']},
#  'kelavaru': {'translation': 'some persons', 'pos_tags': ['DET', 'NOUN']},
#  'guṃpugārike': {'translation': 'group consciousness, ‘groupism’',
#   'pos_tags': ['NOUN', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT']},
#  'naṃbu': {'translation': 'to believe', 'pos_tags': ['PART', 'VERB']},
#  'baduku': {'translation': 'to live', 'pos_tags': ['PART', 'VERB']},
#  'Basavaṇṇa': {'translation': '(name, ‘elder brother B.’)', 'pos_tags': []},
#  'mānava': {'translation': 'human, person',
#   'pos_tags': ['ADJ', 'PUNCT', 'NOUN']},
#  'vacana': {'translation': '(name of a literary form, ‘utterance’)',
#   'pos_tags': []},
#  'vaiyaktika': {'translation': 'something personal',
#   'pos_tags': ['PRON', 'ADJ']},
#  'vyakti': {'translation': 'person, individual',
#   'pos_tags': ['NOUN', 'PUNCT', 'ADJ']},
#  'śivamaya': {'translation': 'made of god',
#   'pos_tags': ['VERB', 'ADP', 'PROPN']},
#  'śaiva': {'translation': 'pertaining to Śiva',
#   'pos_tags': ['VERB', 'ADP', 'PROPN']},
#  'saṃbhavisu': {'translation': 'to arise, originate',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'sādhane': {'translation': 'religious discipline / practice',
#   'pos_tags': ['ADJ', 'NOUN', 'SYM', 'NOUN']},
#  'sāhityakṛti': {'translation': 'literary work', 'pos_tags': ['ADJ', 'NOUN']},
#  'halavaru': {'translation': 'many persons', 'pos_tags': ['ADJ', 'NOUN']},
#  'ivattina': {'translation': 'today’s, of today',
#   'pos_tags': ['NOUN', 'PART', 'PUNCT', 'ADP', 'NOUN']},
#  'īgina': {'translation': 'of now, present',
#   'pos_tags': ['ADP', 'ADV', 'PUNCT', 'ADJ']},
#  'uḷi': {'translation': 'to remain', 'pos_tags': ['PART', 'VERB']},
#  'kali': {'translation': 'to learn', 'pos_tags': ['PART', 'VERB']},
#  'guḍḍa': {'translation': 'hill, hillock',
#   'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'jotege': {'translation': 'together with', 'pos_tags': ['ADV', 'ADP']},
#  'dharmādhikāri': {'translation': '(religious title and function)',
#   'pos_tags': []},
#  'neṃṭa': {'translation': '(blood-) relative', 'pos_tags': []},
#  'pradhāna': {'translation': 'main, chief',
#   'pos_tags': ['ADJ', 'PUNCT', 'NOUN']},
#  'prāṇa': {'translation': 'life, life force',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN', 'NOUN']},
#  'balakaḍe': {'translation': 'right (side)', 'pos_tags': ['INTJ']},
#  'beṃḍekāyi': {'translation': 'okra, ‘ladies’ fingers’',
#   'pos_tags': ['PROPN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT']},
#  'muṃcitavāgi': {'translation': 'beforehand, earlier',
#   'pos_tags': ['ADV', 'PUNCT', 'ADV']},
#  'muṃduvari': {'translation': 'to continue', 'pos_tags': ['PART', 'VERB']},
#  'mugi': {'translation': 'to end (intr.)', 'pos_tags': ['PART', 'VERB']},
#  'mugisu': {'translation': 'to end, finish (trans.)',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'yati': {'translation': 'wandering ascetic', 'pos_tags': ['VERB', 'ADJ']},
#  'rūḍhi': {'translation': 'custom, usage',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'lābha': {'translation': 'profit, advantage',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'liṃga': {'translation': '‘sign’, a particular depiction of Śiva',
#   'pos_tags': ['PUNCT',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'ADP',
#    'PROPN']},
#  'sinima': {'translation': 'movie theatre', 'pos_tags': ['NOUN', 'NOUN']},
#  'hāgādare': {'translation': 'in that case, if that is so',
#   'pos_tags': ['ADP', 'DET', 'NOUN', 'PUNCT', 'SCONJ', 'PRON', 'AUX', 'ADV']},
#  'hāgū': {'translation': 'and, also', 'pos_tags': ['CCONJ', 'PUNCT', 'ADV']},
#  'haṇṇugaḷellavu': {'translation': '(the same)', 'pos_tags': []},
#  'vidyārthigaḷellaru': {'translation': '(the same)', 'pos_tags': []},
#  'elladariṃda': {'translation': 'from everything (ablative)',
#   'pos_tags': ['ADP', 'PRON']},
#  'elladakke': {'translation': 'to everything (dative)',
#   'pos_tags': ['ADP', 'PRON']},
#  'elladara': {'translation': 'of everything (genitive)',
#   'pos_tags': ['ADP', 'PRON']},
#  'elladaralli': {'translation': 'in everything (locative)',
#   'pos_tags': ['ADP', 'PRON']},
#  'baredukoḷḷi': {'translation': 'please note down [‘having written, please take’, i.e., write this down so that you need not remember]',
#   'pos_tags': ['INTJ',
#    'VERB',
#    'ADP',
#    'X',
#    'PUNCT',
#    'AUX',
#    'VERB',
#    'PUNCT',
#    'INTJ',
#    'VERB',
#    'PUNCT',
#    'PUNCT',
#    'X',
#    'PUNCT',
#    'VERB',
#    'PRON',
#    'ADP',
#    'SCONJ',
#    'SCONJ',
#    'PRON',
#    'AUX',
#    'PART',
#    'VERB',
#    'PUNCT']},
#  'baredukoḍi': {'translation': 'please write it down for me [‘having written, please give’]',
#   'pos_tags': ['INTJ',
#    'VERB',
#    'PRON',
#    'ADP',
#    'ADP',
#    'PRON',
#    'ADP',
#    'PUNCT',
#    'AUX',
#    'VERB',
#    'PUNCT',
#    'INTJ',
#    'VERB',
#    'PUNCT',
#    'PUNCT']},
#  'maretubiḍi!': {'translation': 'please forget it!',
#   'pos_tags': ['INTJ', 'VERB', 'PRON', 'PUNCT']},
#  'saṃkōcapaḍabēḍa': {'translation': 'don’t be shy [‘do not suffer shyness’]',
#   'pos_tags': ['AUX',
#    'PART',
#    'AUX',
#    'ADJ',
#    'X',
#    'PUNCT',
#    'AUX',
#    'PART',
#    'VERB',
#    'PROPN',
#    'PUNCT',
#    'PUNCT']},
#  'oṃdannu': {'translation': 'one (specific accusative)', 'pos_tags': ['NUM']},
#  'oṃdariṃda': {'translation': 'from one', 'pos_tags': ['ADP', 'NUM']},
#  'oṃdakke': {'translation': 'to one', 'pos_tags': ['ADP', 'NUM']},
#  'oṃdara': {'translation': 'of one', 'pos_tags': ['ADP', 'NUM']},
#  'oṃdaralli': {'translation': 'in one', 'pos_tags': ['ADP', 'NUM']},
#  'eraḍannu': {'translation': 'two (specific accusative)', 'pos_tags': ['NUM']},
#  'mūrakke': {'translation': 'to three', 'pos_tags': ['ADP', 'NUM']},
#  'nālkara': {'translation': 'of four', 'pos_tags': ['ADP', 'NUM']},
#  'aidariṃda': {'translation': 'from five', 'pos_tags': ['ADP', 'NUM']},
#  'āraralli': {'translation': 'in six Often, though, these inflected forms of the numerals must be translated in special idiomatic manners:',
#   'pos_tags': ['ADP',
#    'NUM',
#    'ADV',
#    'PUNCT',
#    'ADV',
#    'PUNCT',
#    'PRON',
#    'VERB',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'AUX',
#    'AUX',
#    'VERB',
#    'ADP',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT']},
#  'oṃdaneyadu': {'translation': 'the first one',
#   'pos_tags': ['DET', 'ADJ', 'NUM']},
#  'hattaneyavanu': {'translation': 'the tenth man These new words can of course be declined, like any pronoun or pro- nomi nalized word:',
#   'pos_tags': ['DET',
#    'ADJ',
#    'NOUN',
#    'DET',
#    'ADJ',
#    'NOUN',
#    'AUX',
#    'ADP',
#    'NOUN',
#    'AUX',
#    'VERB',
#    'PUNCT',
#    'ADP',
#    'DET',
#    'NOUN',
#    'CCONJ',
#    'X',
#    'ADJ',
#    'ADJ',
#    'NOUN',
#    'PUNCT']},
#  'aidaneyadaralli': {'translation': 'in the fifth one',
#   'pos_tags': ['ADP', 'DET', 'ADJ', 'NUM']},
#  'hattaneyavanige': {'translation': 'to the tenth man',
#   'pos_tags': ['ADP', 'DET', 'ADJ', 'NOUN']},
#  'obbanu': {'translation': 'one [male] person',
#   'pos_tags': ['NUM', 'X', 'NOUN', 'X', 'NOUN']},
#  'obbaḷu': {'translation': 'one [female] person',
#   'pos_tags': ['NUM', 'X', 'ADJ', 'PUNCT', 'NOUN']},
#  'obbaru': {'translation': 'one person [politely, or neutral]',
#   'pos_tags': ['NUM',
#    'NOUN',
#    'PUNCT',
#    'ADV',
#    'PUNCT',
#    'CCONJ',
#    'ADJ',
#    'PUNCT']},
#  'ibbaru': {'translation': 'two persons', 'pos_tags': ['NUM', 'NOUN']},
#  'mūvaru': {'translation': 'three persons', 'pos_tags': ['NUM', 'NOUN']},
#  'nālvaru': {'translation': 'four persons', 'pos_tags': ['NUM', 'NOUN']},
#  'aivaru': {'translation': 'five persons', 'pos_tags': ['NUM', 'NOUN']},
#  'ari': {'translation': 'to know', 'pos_tags': ['PART', 'VERB']},
#  'aritenu': {'translation': 'I knew', 'pos_tags': ['PRON', 'VERB']},
#  'kalitenu': {'translation': 'I learnt', 'pos_tags': ['PRON', 'VERB']},
#  'mare': {'translation': 'to forget', 'pos_tags': ['PART', 'VERB']},
#  'ennu': {'translation': 'to say', 'pos_tags': ['PART', 'VERB']},
#  'eṃdenu': {'translation': 'I said', 'pos_tags': ['PRON', 'VERB']},
#  'tiṃdenu': {'translation': 'I ate', 'pos_tags': ['PRON', 'VERB']},
#  'baydenu': {'translation': 'I abused / reviled These are roots which originally, in Old Kannada, ended in a consonant',
#   'pos_tags': ['PRON',
#    'VERB',
#    'PUNCT',
#    'VERB',
#    'PRON',
#    'AUX',
#    'NOUN',
#    'PRON',
#    'ADV',
#    'PUNCT',
#    'ADP',
#    'PROPN',
#    'PROPN',
#    'PUNCT',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN']},
#  'kāyu': {'translation': 'to wait / grow hot',
#   'pos_tags': ['PART', 'VERB', 'SYM', 'VERB', 'ADJ']},
#  'kādenu': {'translation': 'I waited', 'pos_tags': ['PRON', 'VERB']},
#  'kuḷiru': {'translation': 'to sit down', 'pos_tags': ['PART', 'VERB', 'ADP']},
#  'kuḷitenu': {'translation': 'I sat down',
#   'pos_tags': ['PRON', 'VERB', 'ADP']},
#  'sōlu': {'translation': 'to be defeated',
#   'pos_tags': ['PART', 'AUX', 'VERB']},
#  'sīnu': {'translation': 'to sneeze', 'pos_tags': ['PART', 'VERB']},
#  'sītenu': {'translation': 'I sneezed It should be noticed here that in the case of some of these verbs, more',
#   'pos_tags': ['PRON',
#    'VERB',
#    'PRON',
#    'AUX',
#    'AUX',
#    'VERB',
#    'ADV',
#    'SCONJ',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'ADV']},
#  'ese': {'translation': 'to throw', 'pos_tags': ['PART', 'VERB']},
#  'kusi': {'translation': 'to sink down / collapse',
#   'pos_tags': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB']},
#  'koḷe': {'translation': 'to rot', 'pos_tags': ['PART', 'VERB']},
#  'dore': {'translation': 'to be obtained',
#   'pos_tags': ['PART', 'AUX', 'VERB']},
#  'bese': {'translation': 'to solder', 'pos_tags': ['PART', 'VERB']},
#  'mase': {'translation': 'to whet', 'pos_tags': ['AUX', 'VERB']},
#  'moḷe': {'translation': 'to sprout', 'pos_tags': ['PART', 'VERB']},
#  'husi': {'translation': 'to speak falsehood / lie',
#   'pos_tags': ['PART', 'VERB', 'NOUN', 'SYM', 'NOUN']},
#  'āyu': {'translation': 'to choose', 'pos_tags': ['PART', 'VERB']},
#  'oyyu': {'translation': 'to carry off', 'pos_tags': ['PART', 'VERB', 'ADP']},
#  'koyyu': {'translation': 'to reap, pluck',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'geyyu': {'translation': 'to make', 'pos_tags': ['PART', 'VERB']},
#  'tēyu': {'translation': 'to grind', 'pos_tags': ['PART', 'VERB']},
#  'toyyu': {'translation': 'to become wet',
#   'pos_tags': ['PART', 'VERB', 'ADJ']},
#  'māyu': {'translation': 'to be hidden', 'pos_tags': ['PART', 'AUX', 'VERB']},
#  'mēyu': {'translation': 'to graze', 'pos_tags': ['PART', 'VERB']},
#  'suyyu': {'translation': 'to sigh', 'pos_tags': ['PART', 'VERB']},
#  'hāyu': {'translation': 'to cross over', 'pos_tags': ['PART', 'VERB', 'ADP']},
#  'kavalu': {'translation': 'to become branched',
#   'pos_tags': ['PART', 'VERB', 'ADJ']},
#  'ciguru': {'translation': 'to sprout', 'pos_tags': ['PART', 'VERB']},
#  'bevaru': {'translation': 'to perspire', 'pos_tags': ['PART', 'VERB']},
#  'nāru': {'translation': 'to stink', 'pos_tags': ['PART', 'VERB']},
#  'iru': {'translation': 'to be', 'pos_tags': ['PART', 'AUX']},
#  'teru': {'translation': 'to pay', 'pos_tags': ['PART', 'VERB']},
#  'bēsaru': {'translation': 'to be bored', 'pos_tags': ['PART', 'AUX', 'VERB']},
#  'heru': {'translation': 'to give birth',
#   'pos_tags': ['PART', 'VERB', 'NOUN']},
#  'horu': {'translation': 'to bear a burden',
#   'pos_tags': ['PART', 'VERB', 'DET', 'NOUN']},
#  'kollu': {'translation': 'to kill', 'pos_tags': ['PART', 'VERB']},
#  'gellu': {'translation': 'to win, overcome',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'nillu': {'translation': 'to stand', 'pos_tags': ['PART', 'VERB']},
#  'aḷu': {'translation': 'to weep', 'pos_tags': ['PART', 'VERB']},
#  'uḷu': {'translation': 'to plough', 'pos_tags': ['PART', 'VERB']},
#  'kaḷu': {'translation': 'to steal', 'pos_tags': ['PART', 'VERB']},
#  'kīḷu': {'translation': 'to pluck, pick',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'biddu': {'translation': '(Note the shortening of the vowel in the case of the two last-mentioned verbs.)',
#   'pos_tags': []},
#  'bēyu': {'translation': 'be burnt', 'pos_tags': ['AUX', 'VERB']},
#  'mīyu': {'translation': 'to bathe', 'pos_tags': ['PART', 'VERB']},
#  'aḍu': {'translation': 'to cook', 'pos_tags': ['PART', 'VERB']},
#  'uḍu': {'translation': 'to dress', 'pos_tags': ['PART', 'VERB']},
#  'keḍu': {'translation': 'to be spoilt', 'pos_tags': ['PART', 'AUX', 'VERB']},
#  'toḍu': {'translation': 'to dress', 'pos_tags': ['PART', 'VERB']},
#  'neḍu': {'translation': 'to plant', 'pos_tags': ['PART', 'VERB']},
#  'biḍu': {'translation': 'to leave', 'pos_tags': ['PART', 'VERB']},
#  'suḍu': {'translation': 'to burn', 'pos_tags': ['PART', 'VERB']},
#  'uṇṇu': {'translation': 'to eat', 'pos_tags': ['PART', 'VERB']},
#  'kāṇu': {'translation': 'to see', 'pos_tags': ['PART', 'VERB']},
#  'hogu': {'translation': 'to enter', 'pos_tags': ['PART', 'VERB']},
#  'hokku': {'translation': 'Alternative abbreviated forms:',
#   'pos_tags': ['ADJ', 'VERB', 'NOUN', 'PUNCT']},
#  'ode': {'translation': 'to kick', 'pos_tags': ['PART', 'VERB']},
#  'hode': {'translation': 'to put on (dress)',
#   'pos_tags': ['PART', 'VERB', 'ADP']},
#  'eḷe': {'translation': 'to pull', 'pos_tags': ['PART', 'VERB']},
#  'tege': {'translation': 'to take', 'pos_tags': ['PART', 'VERB']},
#  'mlēccha': {'translation': 'barbarian, foreigner',
#   'pos_tags': ['PROPN', 'PUNCT', 'NOUN']},
#  'adannu': {'translation': 'that (accusative case)', 'pos_tags': ['PRON']},
#  'oḷḷeyadu': {'translation': 'good thing', 'pos_tags': ['ADJ', 'NOUN']},
#  'kalitare': {'translation': 'if [one] learns',
#   'pos_tags': ['SCONJ', 'X', 'NUM', 'PUNCT', 'VERB']},
#  'cennāgide': {'translation': 'is good', 'pos_tags': ['AUX', 'ADJ']},
#  'namage': {'translation': 'us (dative case)', 'pos_tags': ['PRON']},
#  'niṃtiddāre': {'translation': 'they stand', 'pos_tags': ['PRON', 'VERB']},
#  'baruttāre': {'translation': 'they come', 'pos_tags': ['PRON', 'VERB']},
#  'meccuviri': {'translation': 'you will like',
#   'pos_tags': ['PRON', 'AUX', 'VERB']},
#  'yaśasvi': {'translation': 'glorious, successful',
#   'pos_tags': ['ADJ', 'PUNCT', 'ADJ']},
#  'agnimaṃḍala': {'translation': 'circle of fire',
#   'pos_tags': ['NOUN', 'ADP', 'NOUN']},
#  'apasmara': {'translation': '(name of a demon)', 'pos_tags': []},
#  'uṃṭāgu': {'translation': 'to arise, originate',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']},
#  'uṃṭumāḍu': {'translation': 'to create', 'pos_tags': ['PART', 'VERB']},
#  'kaiyalli': {'translation': '‘in the hand’, with, near',
#   'pos_tags': ['PUNCT',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'ADP',
#    'PUNCT',
#    'ADP']},
#  'korate': {'translation': 'defect, shortcoming',
#   'pos_tags': ['NOUN', 'PUNCT', 'VERB']},
#  'gaṃgādhara': {'translation': '‘bearer of the Ganges’, Śiva',
#   'pos_tags': ['PUNCT',
#    'NOUN',
#    'ADP',
#    'DET',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'PROPN']},
#  'caṃdraśēkhara': {'translation': '‘who has the moon on his crest’, Śiva',
#   'pos_tags': ['PUNCT',
#    'PRON',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'PROPN']},
#  'tāṃḍava': {'translation': '(name of Śiva’s dance)', 'pos_tags': []},
#  'nakk-': {'translation': '(past stem of nagu)', 'pos_tags': []},
#  'naṃjuṃḍa': {'translation': '‘who drank poison’',
#   'pos_tags': ['PUNCT', 'PRON', 'VERB', 'NOUN', 'PUNCT']},
#  'nāśa': {'translation': 'destruction, ruin',
#   'pos_tags': ['NOUN', 'PUNCT', 'PROPN']},
#  'mallikārjuna': {'translation': '‘white like jasmine’',
#   'pos_tags': ['PUNCT', 'ADJ', 'ADP', 'NOUN', 'PUNCT']},
#  'mahatva': {'translation': 'greatness, importance',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'rēkhē': {'translation': 'stripe, line',
#   'pos_tags': ['ADJ', 'PUNCT', 'NOUN']},
#  'vāsasthaḷa': {'translation': 'place of residence',
#   'pos_tags': ['NOUN', 'ADP', 'NOUN']},
#  'vibhūti': {'translation': 'holy ash as used by the devotees of Śiva',
#   'pos_tags': ['PROPN',
#    'PROPN',
#    'SCONJ',
#    'VERB',
#    'ADP',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PROPN']},
#  'śivabhakta': {'translation': 'devotee of Śiva',
#   'pos_tags': ['NOUN', 'ADP', 'NOUN']},
#  'siddhapuruṣa': {'translation': 'religiously liberated person',
#   'pos_tags': ['ADV', 'VERB', 'NOUN']},
#  'sōmaśēkhara': {'translation': '‘who has the moon on his crest’, Śiva',
#   'pos_tags': ['PUNCT',
#    'PRON',
#    'VERB',
#    'DET',
#    'NOUN',
#    'ADP',
#    'PRON',
#    'NOUN',
#    'PUNCT',
#    'PUNCT',
#    'PROPN']},
#  'svabhāva': {'translation': 'nature, character',
#   'pos_tags': ['NOUN', 'PUNCT', 'NOUN']},
#  'haccu': {'translation': 'to smear, apply',
#   'pos_tags': ['PART', 'VERB', 'PUNCT', 'VERB']}}

# %%
all_pos_mapping
# Out:
# {'huḷi': ['ADJ'],
#  'huli': ['NOUN'],
#  'haḷḷi': ['NOUN'],
#  'halli': ['NOUN'],
#  'maṇe': ['PROPN'],
#  'mane': ['NOUN'],
#  'hālu': ['NOUN'],
#  'hallu': ['VERB'],
#  'dēva': ['PROPN'],
#  'devva': ['PROPN'],
#  'nānu': ['PRON'],
#  'nāvu': ['PRON'],
#  'avanu': ['PRON'],
#  'avaḷu': ['PRON'],
#  'ivanu': ['PRON'],
#  'ivaḷu': ['PRON'],
#  'illi': ['ADV'],
#  'alli': ['ADV'],
#  'elli': ['SCONJ', 'PUNCT'],
#  'īga': ['ADV'],
#  'āga': ['ADV', 'PUNCT', 'DET', 'NOUN'],
#  'adu': ['PRON', 'PUNCT', 'PRON'],
#  'almāri': ['NOUN'],
#  'ākāśa': ['NOUN'],
#  'idu': ['PRON', 'PUNCT', 'PRON'],
#  'innoṃdu': ['PRON'],
#  'ivattu': ['NOUN'],
#  'ūṭa': [],
#  'ūru': ['NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'NOUN'],
#  'eraḍu': ['NUM'],
#  'aidu': ['NUM'],
#  'oṃdu': ['NUM', 'PUNCT', 'PRON'],
#  'kaṃpyūṭaru': ['NOUN'],
#  'kaṭṭaḍa': ['VERB'],
#  'kāgada': ['NOUN'],
#  'kāḍu': ['NOUN'],
#  'kāru': ['NOUN'],
#  'kiṭaki': ['NOUN'],
#  'kurci': ['NOUN'],
#  'gilāsu': ['NOUN'],
#  'guri': ['NOUN'],
#  'guru': ['NOUN'],
#  'guruvāra': ['PROPN'],
#  'camaca': ['VERB'],
#  'cāku': ['NOUN'],
#  'cāpe': ['NOUN'],
#  'cāvi': ['ADJ'],
#  'citra': ['NOUN'],
#  'ṭyāksi': ['NOUN'],
#  'ṭyūbulaiṭu': ['NOUN'],
#  'taṭṭe': ['NOUN'],
#  'tuṃba': ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'],
#  'dīpa': ['PROPN'],
#  'dēvasthāna': ['PROPN'],
#  'nālku': ['NUM'],
#  'nāḷe': ['NOUN'],
#  'nela': ['NOUN'],
#  'noṇa': ['VERB'],
#  'pustaka': ['NOUN'],
#  'pensilu': ['NOUN'],
#  'phorenar': ['NOUN'],
#  'phōrku': ['NOUN'],
#  'bāgilu': ['NOUN'],
#  'budhavāra': ['PROPN'],
#  'beṃki': ['NOUN'],
#  'bēli': ['NOUN'],
#  'bhāratīya': ['ADJ'],
#  'maṃgaḷavāra': ['PROPN'],
#  'mattu': ['CCONJ'],
#  'manuṣya': ['ADJ', 'PUNCT', 'NOUN'],
#  'mara': ['NOUN', 'PUNCT', 'NOUN'],
#  'mahiḷe': ['PROPN'],
#  'maḷe': ['NOUN'],
#  'māle': ['VERB'],
#  'mūru': ['NUM'],
#  'mēju': ['NOUN'],
#  'mēṇabatti': ['NOUN'],
#  'mōḍa': ['PROPN'],
#  'ravivāra': ['PROPN'],
#  'raste': ['NOUN'],
#  'rikṣā': ['NOUN'],
#  'vimāna': ['NOUN'],
#  'śanivāra': ['PROPN'],
#  'śukravāra': ['NOUN', 'PUNCT', 'NOUN'],
#  'sūṭkēsu': ['NOUN'],
#  'sūrya': ['PROPN'],
#  'sōmavāra': ['PROPN'],
#  'strī': ['NOUN'],
#  'hakki': ['NOUN'],
#  'halavu': ['ADJ'],
#  'hasu': ['NOUN'],
#  'hāḍu': ['NOUN', 'PUNCT', 'PART', 'VERB'],
#  'hippi': ['VERB'],
#  'huḍuga': ['PROPN'],
#  'huḍugi': ['NOUN'],
#  'hū': ['NOUN'],
#  'heṃgasu': ['NOUN'],
#  'hola': ['NOUN'],
#  'haudu': ['INTJ'],
#  'yāvāgalū illa': ['ADV'],
#  'ēnū illa': ['PRON'],
#  'yārū illa': ['PRON'],
#  'ide': ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'],
#  'ēke': ['SCONJ', 'PUNCT'],
#  'ēnu': ['PRON', 'PUNCT'],
#  'kappu': ['ADJ'],
#  'kaṣṭa': ['ADJ'],
#  'toḍaku': ['NOUN'],
#  'nanna': ['PRON'],
#  'namma': ['PRON'],
#  'patra': ['NOUN'],
#  'purōhita': ['NOUN'],
#  'biḷi': ['PROPN'],
#  'maneyavaru': ['NOUN'],
#  'yāru': ['PRON', 'PUNCT'],
#  'yāva': ['PRON', 'PUNCT'],
#  'yāvāga': ['SCONJ', 'PUNCT'],
#  'samācāra': ['NOUN'],
#  'hesaru': ['NOUN'],
#  'hēge': ['ADP', 'PRON', 'NOUN', 'PUNCT'],
#  'appa': ['PROPN'],
#  'amma': ['NOUN'],
#  'kaṇṇu': ['NOUN'],
#  'kivi': ['NOUN'],
#  'kuri': ['PART', 'VERB'],
#  'kūsu': ['NOUN'],
#  'gaṃḍa': ['NOUN'],
#  'gaṃḍasu': ['NOUN'],
#  'nighaṃṭu': ['PROPN'],
#  'nīru': ['NOUN'],
#  'buṭṭi': ['NOUN'],
#  'maga': ['NOUN'],
#  'magaḷu': ['NOUN'],
#  'magu': ['NOUN'],
#  'māva': ['NOUN'],
#  'rāja': ['NOUN'],
#  'raita': ['NOUN'],
#  'vidhave': ['NOUN'],
#  'anubhava': ['VERB'],
#  'āṭike': ['NOUN'],
#  'āyke': ['NOUN'],
#  'keṃpu': ['PROPN'],
#  'koṃbu': ['NOUN'],
#  'koṃbe': ['NOUN'],
#  'cūpu': ['ADJ'],
#  'tudi': ['NOUN'],
#  'parimāṇa': ['NOUN'],
#  'baṭṭe': ['NOUN'],
#  'baṇṇa': ['NOUN'],
#  'bēre': ['ADJ', 'PUNCT', 'PRON', 'ADV'],
#  'saṃkhye': ['NOUN'],
#  'hasiru': ['ADJ'],
#  'haḷadi': ['ADJ'],
#  'heṃḍati': ['NOUN'],
#  'nidde': ['NOUN'],
#  'nāyi': ['NOUN'],
#  'kathe': ['NOUN'],
#  'kelasa': ['NOUN'],
#  'toṃdare': ['NOUN'],
#  'nenne': ['NOUN'],
#  'satya': ['NOUN'],
#  'haṇa': ['NOUN'],
#  'haṇṇu': ['NOUN'],
#  'mēle': ['ADP'],
#  'keḷage': ['ADP'],
#  'oḷage': ['ADP'],
#  'oḷagu': ['ADP'],
#  'hattira': ['ADV', 'PUNCT', 'NOUN'],
#  'bage': ['VERB'],
#  'madhya': ['ADJ'],
#  'muṃde': ['ADP'],
#  'horage': ['ADV'],
#  'aḍige': ['VERB'],
#  'uttara': ['NOUN'],
#  'kāpi': ['NOUN'],
#  'gaḍi': ['NOUN'],
#  'cahā': ['NOUN'],
#  'padārtha': ['NOUN'],
#  'pavāḍa': ['NOUN'],
#  'viśēṣavāda': ['ADJ'],
#  'vaiṣṇava': ['NOUN', 'ADP', 'PROPN', 'PUNCT', 'PROPN'],
#  'samādhi': ['NOUN'],
#  'ele': ['VERB'],
#  'athavā': ['CCONJ'],
#  'abhiprāya': ['NOUN'],
#  'iḍiya': ['ADJ'],
#  'upayukta': ['ADJ'],
#  'keṭṭa': ['ADJ'],
#  'kliṣṭa': ['VERB'],
#  'gaddala': ['NOUN'],
#  'cakravarti': ['NOUN'],
#  'cikka': ['ADJ'],
#  'jagattu': ['NOUN'],
#  'dūra': ['NOUN'],
#  'nīli': ['ADJ'],
#  'praśne': ['NOUN'],
#  'bīdi': ['PROPN'],
#  'bhāra': ['NOUN'],
#  'bhārata': ['PROPN'],
#  'mukhya': ['PRON', 'ADJ'],
#  'yuga': ['NOUN'],
#  'saṃgīta': ['NOUN'],
#  'suṃdara': ['ADJ'],
#  'kelavu': ['PRON'],
#  'kōlu': ['VERB'],
#  'ciṃtaka': ['NOUN'],
#  'tīra': ['PROPN'],
#  'bhakta': ['NOUN', 'PUNCT', 'NOUN'],
#  'maṭha': ['VERB'],
#  'Madhvācārya': [],
#  'śatamāna': ['NOUN'],
#  'saṃpradāya': ['NOUN'],
#  'hadimūraneya': ['NOUN'],
#  'āphisu': ['NOUN'],
#  'oraṭu': ['NOUN'],
#  'krūra': ['ADJ'],
#  'khuśi': ['NOUN'],
#  'tiṃgaḷu': ['NOUN'],
#  'dayaviṭṭu': ['INTJ'],
#  'pāṭha': ['NOUN'],
#  'prayatna': ['NOUN', 'PUNCT', 'VERB', 'PUNCT', 'NOUN'],
#  'muṃdina': ['ADV'],
#  'yōcane': ['VERB'],
#  'vākya': ['VERB'],
#  'śabda': ['NOUN'],
#  'saṃtōṣa': ['NOUN'],
#  'sammēḷana': ['NOUN'],
#  'spaṣṭa': ['ADJ'],
#  'artha': ['VERB'],
#  'ādare': ['CCONJ'],
#  'kṣame': ['NOUN'],
#  'daya': ['NOUN', 'PUNCT', 'NOUN'],
#  'hōṭalu': ['NOUN'],
#  'adhyāpaka': ['NOUN'],
#  'kōpa': ['NOUN'],
#  'graṃthapālaka': ['PROPN'],
#  'graṃthālaya': ['NOUN'],
#  'patrike': ['NOUN'],
#  'sahāya': ['VERB'],
#  'hemme': ['NOUN'],
#  'hōguvike': ['VERB'],
#  'bāḷike': ['VERB'],
#  'ārōgya': ['NOUN'],
#  'gōḍe': ['NOUN'],
#  'gōva': ['PROPN'],
#  'jōru': ['NOUN', 'PUNCT', 'NOUN'],
#  'tinnu': ['PART', 'VERB'],
#  'māṃsa': ['NOUN'],
#  'miliṭari': ['NOUN'],
#  'miliṭari hōṭalu': ['ADJ', 'ADJ', 'NOUN'],
#  'auṣadhi': ['NOUN'],
#  'kaṭṭe': ['VERB'],
#  'giḍa': ['NOUN'],
#  'dēvi': ['NOUN'],
#  'patni': ['NOUN'],
#  'pradakṣiṇe': ['NOUN'],
#  'bhakti': ['NOUN'],
#  'mātra': ['ADV'],
#  'saṃpattu': ['NOUN'],
#  'sādhya': ['ADJ'],
#  'sulabha': ['ADJ'],
#  'saubhāgya': ['ADV', 'PUNCT', 'NOUN'],
#  'atṛpta': ['ADJ'],
#  'atṛpti': ['NOUN'],
#  'anubhāvi': ['ADJ'],
#  'anuyāyi': ['NOUN'],
#  'asamānate': ['NOUN'],
#  'ityādi': ['X', 'X'],
#  'kuṭuṃba': ['NOUN'],
#  'kelavomme': ['ADV'],
#  'guṃpu': ['NOUN'],
#  'jāti': ['NOUN'],
#  'jīvana': ['NOUN'],
#  'tṛpta': ['ADJ'],
#  'tṛpti': ['NOUN'],
#  'dhārmika': ['ADJ'],
#  'naitika': ['ADJ'],
#  'paraṃpare': ['NOUN'],
#  'prapaṃca': ['NOUN'],
#  'prācīna': ['ADJ'],
#  'prīti': ['NOUN'],
#  'Basava': ['PUNCT', 'NOUN', 'PUNCT'],
#  'beḷavaṇige': ['NOUN'],
#  'maṃdi': ['NOUN'],
#  'manassu': ['NOUN'],
#  'samāna': ['ADJ'],
#  'samānate': ['NOUN'],
#  'sāmājika': ['ADJ'],
#  'hiṃde': ['ADV', 'PUNCT', 'ADV'],
#  'hinnele': ['NOUN'],
#  'hosa': ['ADJ'],
#  'anēka': ['ADJ'],
#  'ippataidu': ['NUM', 'PUNCT', 'NUM'],
#  'ēkeṃdare': ['SCONJ'],
#  'omme': ['ADV'],
#  'karāvaḷi': ['PROPN'],
#  'kaḷatmaka': ['ADJ'],
#  'kāphi': ['NOUN'],
#  'kāryakrama': ['NOUN'],
#  'kuḍuma': ['PUNCT', 'NOUN', 'PUNCT'],
#  'kēṃdra': ['NOUN'],
#  'caḷi': ['PART', 'AUX', 'ADJ'],
#  'cikitsālaya': ['NOUN'],
#  'jille': ['NOUN'],
#  'taṃde': ['PROPN'],
#  'takṣaṇa': ['ADV'],
#  'tale': ['NOUN'],
#  'talenōvu': ['PROPN'],
#  'dēvate': ['NOUN'],
#  'Dharmasthaḷa': ['PUNCT', 'NOUN', 'PUNCT'],
#  'nōvu': ['NOUN'],
#  'paṃḍita': ['NOUN'],
#  'pūrvaja': ['NOUN'],
#  'Maṃjunātha': ['PUNCT', 'NOUN', 'PUNCT'],
#  'yātrika': ['NOUN'],
#  'rakṣaṇe': ['NOUN'],
#  'varegū': ['ADP'],
#  'varṣa': ['NOUN'],
#  'Vādirāja': ['PUNCT', 'NOUN', 'PUNCT'],
#  'śikṣaka': ['NOUN'],
#  'saṃgrahālaya': ['NOUN'],
#  'sahiṣṇute': ['NOUN'],
#  'sāṃskṛtika': ['ADJ'],
#  'sāvira': ['NUM',
#   'SCONJ',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'NOUN'],
#  'sāvirāru': ['NOUN'],
#  'sumāru': ['ADV'],
#  'hadināraneya': ['ADJ'],
#  'huṣāru': ['NOUN'],
#  'ellarannu / ellarannū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellariṃda / ellariṃdalū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellara': ['PUNCT', 'ADJ', 'PUNCT'],
#  'ellaralli / ellarallū': ['PUNCT', 'ADJ', 'PUNCT'],
#  'āru': ['NUM'],
#  'ēḷu': ['PART', 'VERB'],
#  'eṃṭu': ['NUM'],
#  'oṃbattu': ['NUM'],
#  'hannoṃdu': ['NUM'],
#  'hanneraḍu': ['NUM'],
#  'hadimūru': ['NUM'],
#  'hadinālku': ['NUM'],
#  'hadinaidu': ['NUM'],
#  'hadināru': ['NUM'],
#  'hadinēḷu': ['X'],
#  'hadineṃṭu': ['NUM'],
#  'hattoṃbattu': ['NUM'],
#  'ippattu': ['NUM'],
#  'ippattoṃdu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteraḍu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattanālku': ['NUM', 'PUNCT', 'NUM'],
#  'ippattaidu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattāru': ['NUM', 'PUNCT', 'NUM'],
#  'ippattēḷu': ['NUM', 'PUNCT', 'NUM'],
#  'ippatteṃṭu': ['NUM', 'PUNCT', 'NUM'],
#  'ippattoṃbattu': ['NUM', 'PUNCT', 'NUM'],
#  'aivattu': ['NUM'],
#  'aravattu': ['NUM'],
#  'eppattu': ['NUM'],
#  'eṃbattu': ['NUM'],
#  'toṃbattu': ['NUM'],
#  'nūru': ['NUM'],
#  'innūru': ['NUM'],
#  'munnūru': ['NUM'],
#  'nānūru': ['NUM'],
#  'ainūru': ['NUM'],
#  'ārunūru': ['NUM'],
#  'ēḷunūru': ['NUM'],
#  'eṃṭunūru': ['NUM'],
#  'oṃbainūru': ['NUM'],
#  'nūra nalvattoṃdu': ['NUM'],
#  'sāvirada oṃbainūra toṃbattaidu': ['NUM'],
#  'āgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'hōgi': ['PUNCT', 'NOUN', 'PUNCT'],
#  'utkhanana': ['NOUN'],
#  'hagga': ['NOUN'],
#  'heccu': ['ADV', 'PUNCT', 'DET', 'NOUN', 'PUNCT', 'ADV'],
#  'ajja': ['NOUN'],
#  'jñāna': ['NOUN'],
#  'daḍḍa': ['NOUN'],
#  'kobbu': ['ADJ'],
#  'udbhava': ['NOUN'],
#  'ayya': ['PROPN'],
#  'prabhāva': ['NOUN'],
#  'tatva': ['NOUN'],
#  'utsava': ['NOUN'],
#  'kaḷḷa': ['NOUN'],
#  'aparūpavāgi': ['ADV'],
#  'jana': ['NOUN', 'PUNCT', 'NOUN'],
#  'bahaḷa': ['ADJ', 'PUNCT', 'ADJ', 'PUNCT', 'ADV'],
#  'bhāṣe': ['NOUN'],
#  'yāvāgalū': ['ADV'],
#  'haḷeya': ['ADJ'],
#  'aṃgaḍiyavaru': ['NOUN'],
#  'ajñāna': ['NOUN'],
#  'gottu': ['NOUN', 'PUNCT', 'ADJ', 'NOUN'],
#  'nṛtya': ['VERB'],
#  'paravā': ['VERB'],
#  'parvata': ['NOUN'],
#  'baḷi': ['ADP'],
#  'buddhi': ['NOUN'],
#  'beḷaku': ['ADJ'],
#  'bhasma': ['PROPN'],
#  'majjige': ['NOUN'],
#  'mūgu': ['NOUN'],
#  'modalaneya': ['ADV'],
#  'rākṣasa': ['NOUN'],
#  'rūpa': ['NOUN', 'PUNCT', 'NOUN'],
#  'vimānanildāṇa': ['NOUN'],
#  'vaiṣṇavadharma': ['NOUN'],
#  'saṃkēta': ['NOUN'],
#  'saṃsthe': ['PROPN'],
#  'sāṃkētika': ['ADJ'],
#  'sāmānya': ['ADJ'],
#  'haṇe': ['PROPN'],
#  'ōḍu': ['PART', 'VERB'],
#  'ōdu': ['PART', 'VERB'],
#  'hēḷu': ['PART', 'VERB'],
#  'hēlu': ['PART', 'VERB'],
#  'baḍi': ['PART', 'VERB'],
#  'baḍḍi': ['NOUN'],
#  'maḍi': ['ADV', 'ADJ'],
#  'māḍi': ['INTJ',
#   'VERB',
#   'DET',
#   'NUM',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'ADJ'],
#  'nīnu': ['PRON'],
#  'nīvu': ['PRON'],
#  'avaru': ['PRON'],
#  'avu': ['PRON'],
#  'ivaru': ['PRON', 'SYM', 'PRON'],
#  'ivu': ['PRON', 'PUNCT', 'PRON'],
#  'hīge': ['ADP', 'DET', 'NOUN'],
#  'hāge': ['ADP', 'DET', 'NOUN'],
#  'iṣṭu': ['PRON', 'ADJ'],
#  'aṣṭu': ['ADV', 'ADV'],
#  'eṣṭu': ['SCONJ', 'ADJ', 'PUNCT'],
#  'ili': ['PROPN', 'PUNCT', 'CCONJ'],
#  'kālu': ['PROPN', 'PUNCT', 'NOUN'],
#  'kai': ['NOUN', 'PUNCT', 'VERB'],
#  'graṃtha': ['NOUN', 'PUNCT', 'NOUN'],
#  'doḍḍa': ['ADJ', 'PUNCT', 'ADJ'],
#  'paṃce': [],
#  'pennu': ['PROPN', 'NOUN'],
#  'pyāṃṭu': ['NOUN', 'ADP', 'NOUN'],
#  'beṭṭa': ['PROPN', 'PUNCT', 'NOUN'],
#  'muduki': ['ADJ', 'NOUN'],
#  'maidāna': ['PROPN', 'PUNCT', 'NOUN'],
#  'yuvati': ['ADJ', 'NOUN'],
#  'luṃgi': [],
#  'vidyārthi': ['X', 'NOUN', 'X', 'NOUN'],
#  'vidyārthini': ['X', 'ADJ', 'PUNCT', 'NOUN'],
#  'Viṣṇu': [],
#  'Śiva': [],
#  'sagaṇi': ['NOUN', 'PROPN'],
#  'sāmānugaḷu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sīre': [],
#  'hāḍugāra': ['NOUN'],
#  'hāḍugārti': ['NOUN'],
#  'Namaskāra.': [],
#  'Banni.': ['INTJ', 'PUNCT', 'PRON', 'AUX', 'VERB'],
#  'Hēgiddīri?': ['SCONJ', 'AUX', 'PRON', 'PUNCT', 'NOUN'],
#  'ivara': ['PRON', 'SYM', 'PRON'],
#  'elliṃda': ['ADP', 'SCONJ', 'PUNCT'],
#  'cennāgi': ['ADV', 'PUNCT', 'ADV'],
#  'nimma': ['PRON'],
#  'banni': ['INTJ', 'VERB'],
#  'barali': ['PRON', 'AUX', 'VERB'],
#  'baru': ['PART', 'VERB'],
#  'bassu': ['NOUN'],
#  'bēku': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'],
#  'bēḍa': ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'viśēṣa': ['PRON', 'ADJ'],
#  'sari': ['INTJ', 'PUNCT', 'ADV', 'ADV', 'PUNCT', 'ADJ'],
#  'akka': ['ADJ', 'NOUN'],
#  'aṇṇa': ['ADJ', 'NOUN'],
#  'kere': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'cīla': ['PROPN', 'PUNCT', 'NOUN'],
#  'dēśa': ['NOUN', 'PUNCT', 'NOUN'],
#  'puṭa': ['NOUN'],
#  'snēhita': ['NOUN'],
#  'snēhite': ['NOUN'],
#  'aṃgaḍi': ['PROPN', 'PUNCT', 'NOUN'],
#  'jijñāsu': ['ADJ', 'PART', 'VERB'],
#  'paṃḍite': ['VERB', 'NOUN'],
#  'hōdenu': ['PRON', 'VERB'],
#  'ādenu': ['PRON', 'VERB'],
#  'hōdi': ['PRON', 'VERB'],
#  'ādi': ['PRON', 'VERB'],
#  'hōdanu': ['PRON', 'VERB'],
#  'ādanu': ['PRON', 'VERB'],
#  'hōdaḷu': ['PRON', 'VERB'],
#  'ādaḷu': ['PRON', 'VERB'],
#  'hōdevu': ['PRON', 'VERB'],
#  'ādevu': ['PRON', 'VERB'],
#  'hōdiri': ['PRON', 'VERB'],
#  'ādiri': ['PRON', 'VERB'],
#  'hōdaru': ['PRON', 'VERB'],
#  'ādaru': ['PRON', 'VERB'],
#  'āgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'jigi': ['PART', 'VERB'],
#  'kare': ['PART', 'VERB'],
#  'taru': ['PART', 'VERB'],
#  'tiḷi': ['PART', 'VERB'],
#  'nagu': ['PART', 'VERB'],
#  'bīḷu': ['PART', 'VERB'],
#  'māḍu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hoḍe': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'hōgu': ['PART', 'VERB'],
#  'nōḍu': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADP'],
#  'bare': ['PART', 'VERB'],
#  'anna': ['NOUN'],
#  'koḍu': ['PART', 'VERB'],
#  'viṣaya': ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'sāku': ['PRON', 'AUX', 'ADJ'],
#  'sāladu': ['PRON', 'AUX', 'PART', 'ADJ'],
#  'mēlu': ['ADJ', 'NOUN'],
#  'keḷagu': ['ADJ', 'NOUN'],
#  'hiṃdu': ['ADJ', 'NOUN'],
#  'āyitu': ['ADV', 'ADV', 'PUNCT', 'INTJ'],
#  'iḍu': ['ADP', 'NOUN', 'PUNCT', 'VERB'],
#  'īgalū': ['ADV', 'ADV'],
#  'kaḍe': ['NOUN', 'PUNCT', 'NOUN'],
#  'kōṇe': ['NOUN', 'PUNCT', 'PROPN'],
#  'gaḍipradēśa': ['NOUN', 'NOUN'],
#  'tagoḷḷu': ['PART', 'VERB'],
#  'darśana': ['VERB',
#   'PUNCT',
#   'NOUN',
#   'PUNCT',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'NOUN'],
#  'nija': ['ADJ', 'PUNCT', 'ADJ'],
#  'nijavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'pradēśa': ['PROPN', 'PUNCT', 'NOUN'],
#  'bāḷu': ['PART', 'VERB'],
#  'summane': ['ADV', 'ADP', 'PRON', 'PUNCT', 'ADV'],
#  'svalpa': ['DET', 'NOUN', 'PUNCT', 'DET', 'ADJ'],
#  'bāḷe': ['PROPN', 'NOUN'],
#  'rīti': ['NOUN', 'PUNCT', 'ADJ'],
#  'asahya': ['ADJ', 'PUNCT', 'ADJ'],
#  'āḍu': ['PART', 'VERB'],
#  'iṣṭa': ['VERB', 'PUNCT', 'VERB'],
#  'kēḷu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'kṣētra': ['NOUN', 'ADP', 'NOUN'],
#  'jāga': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'taṃgi': ['ADJ', 'NOUN'],
#  'tīrthaṃkara': [],
#  'pūjārha': ['ADJ', 'ADP', 'NOUN'],
#  'prakāra': ['VERB', 'ADP'],
#  'mūrti': ['NOUN', 'PUNCT', 'NOUN'],
#  'modalu': ['ADV', 'PUNCT', 'ADP', 'DET', 'NOUN'],
#  'mōkṣa': [],
#  'saṃsāra': ['PUNCT', 'DET', 'ADJ', 'NOUN', 'ADP'],
#  'hoṃdu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'kelasadavaḷu': ['VERB'],
#  'avatāra': ['NOUN', 'ADP', 'DET', 'NOUN'],
#  'gurutu': ['PROPN', 'PUNCT', 'ADJ'],
#  'jāsti': ['ADV', 'ADJ', 'PUNCT', 'ADV'],
#  'taṃdaru': ['PRON'],
#  'tanna': ['PRON', 'SYM', 'PRON', 'SYM', 'PRON', 'ADJ'],
#  'divasā': ['DET', 'NOUN'],
#  'pūje': ['NOUN', 'ADP', 'NOUN'],
#  'rathabīdi': ['PROPN', 'PROPN'],
#  'vidēśa': ['ADJ', 'NOUN'],
#  'samudra': ['PROPN', 'PUNCT', 'NOUN'],
#  'iḷi': ['PART', 'VERB', 'PUNCT', 'VERB', 'ADV'],
#  'kadi': ['PART', 'VERB'],
#  'kāpāḍu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'koḷḷu': ['PART', 'VERB'],
#  'tīvra': ['ADJ', 'PUNCT', 'ADJ'],
#  'naḍe': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'paḍu': ['PART', 'VERB', 'PUNCT', 'NOUN', 'PUNCT', 'VERB'],
#  'bayyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'beḷe': ['PART', 'VERB'],
#  'bhāgavahisu': ['PART', 'VERB'],
#  'malagu': ['PART', 'VERB', 'ADV', 'PUNCT', 'VERB'],
#  'mātanāḍu': ['PART', 'VERB'],
#  'lēkhaki': ['NOUN'],
#  'vāpasu': ['ADV', 'PUNCT', 'VERB'],
#  'sustu': ['NOUN', 'PUNCT', 'NOUN'],
#  'sogasu': ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#  'hattu': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#  'hāru': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'horaḍu': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB', 'ADP'],
#  'kareyisu': ['PART', 'VERB', 'PART', 'VERB'],
#  'prakaṭa': ['VERB', 'PUNCT', 'ADJ'],
#  'bēga': ['ADV', 'PUNCT', 'ADV'],
#  'mēṣṭaru': [],
#  'vicitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'araḷu': ['PART', 'VERB', 'PUNCT', 'NOUN'],
#  'tamma': ['ADJ', 'NOUN'],
#  'neraḷu': ['PROPN', 'PUNCT', 'NOUN'],
#  'mātu': ['NOUN', 'PUNCT', 'NOUN'],
#  'vāsa': ['VERB', 'PUNCT', 'VERB'],
#  'sigu': ['PART', 'AUX', 'VERB', 'PUNCT', 'PART', 'AUX', 'VERB'],
#  'suddi': ['NOUN', 'PUNCT', 'NOUN'],
#  'bāradu': ['AUX', 'PART'],
#  'āse': ['NOUN', 'PUNCT', 'VERB'],
#  'heṃḍa': ['ADJ', 'NOUN'],
#  'eṃdare': ['X', 'PUNCT', 'PRON', 'AUX', 'PART', 'VERB'],
#  'oḍati': ['NOUN', 'PUNCT', 'NOUN'],
#  'kāṇisu': ['PART', 'AUX', 'VERB', 'PUNCT', 'VERB'],
#  'kāraṇa': ['NOUN', 'PUNCT', 'NOUN'],
#  'tuḷasi': ['ADJ', 'NOUN'],
#  'pavitra': ['ADJ', 'PUNCT', 'ADJ'],
#  'pūjisu': ['PART', 'VERB'],
#  'baḷasu': ['PART', 'VERB'],
#  'beḷigge': ['ADP', 'DET', 'NOUN'],
#  'śakti': ['NOUN', 'PUNCT', 'NOUN'],
#  'hittalu': ['NOUN', 'NOUN'],
#  'hedaru': ['PART', 'VERB'],
#  'kareyavu': ['ADP',
#   'ADJ',
#   'NOUN',
#   'PUNCT',
#   'DET',
#   'NOUN',
#   'AUX',
#   'ADV',
#   'VERB',
#   'ADV',
#   'ADJ',
#   'PUNCT',
#   'ADJ',
#   'VERB',
#   'CCONJ',
#   'ADV',
#   'VERB',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'AUX',
#   'SCONJ',
#   'PRON',
#   'VERB',
#   'PART'],
#  'anubhavisu': ['PART', 'VERB'],
#  'anubhāva': ['ADJ', 'NOUN'],
#  'kelavaru': ['DET', 'NOUN'],
#  'guṃpugārike': ['NOUN', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT'],
#  'naṃbu': ['PART', 'VERB'],
#  'baduku': ['PART', 'VERB'],
#  'Basavaṇṇa': [],
#  'mānava': ['ADJ', 'PUNCT', 'NOUN'],
#  'vacana': [],
#  'vaiyaktika': ['PRON', 'ADJ'],
#  'vyakti': ['NOUN', 'PUNCT', 'ADJ'],
#  'śivamaya': ['VERB', 'ADP', 'PROPN'],
#  'śaiva': ['VERB', 'ADP', 'PROPN'],
#  'saṃbhavisu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'sādhane': ['ADJ', 'NOUN', 'SYM', 'NOUN'],
#  'sāhityakṛti': ['ADJ', 'NOUN'],
#  'halavaru': ['ADJ', 'NOUN'],
#  'ivattina': ['NOUN', 'PART', 'PUNCT', 'ADP', 'NOUN'],
#  'īgina': ['ADP', 'ADV', 'PUNCT', 'ADJ'],
#  'uḷi': ['PART', 'VERB'],
#  'kali': ['PART', 'VERB'],
#  'guḍḍa': ['PROPN', 'PUNCT', 'NOUN'],
#  'jotege': ['ADV', 'ADP'],
#  'dharmādhikāri': [],
#  'neṃṭa': [],
#  'pradhāna': ['ADJ', 'PUNCT', 'NOUN'],
#  'prāṇa': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#  'balakaḍe': ['INTJ'],
#  'beṃḍekāyi': ['PROPN', 'PUNCT', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT'],
#  'muṃcitavāgi': ['ADV', 'PUNCT', 'ADV'],
#  'muṃduvari': ['PART', 'VERB'],
#  'mugi': ['PART', 'VERB'],
#  'mugisu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'yati': ['VERB', 'ADJ'],
#  'rūḍhi': ['NOUN', 'PUNCT', 'NOUN'],
#  'lābha': ['NOUN', 'PUNCT', 'NOUN'],
#  'liṃga': ['PUNCT',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'sinima': ['NOUN', 'NOUN'],
#  'hāgādare': ['ADP', 'DET', 'NOUN', 'PUNCT', 'SCONJ', 'PRON', 'AUX', 'ADV'],
#  'hāgū': ['CCONJ', 'PUNCT', 'ADV'],
#  'haṇṇugaḷellavu': [],
#  'vidyārthigaḷellaru': [],
#  'elladariṃda': ['ADP', 'PRON'],
#  'elladakke': ['ADP', 'PRON'],
#  'elladara': ['ADP', 'PRON'],
#  'elladaralli': ['ADP', 'PRON'],
#  'baredukoḷḷi': ['INTJ',
#   'VERB',
#   'ADP',
#   'X',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT',
#   'X',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'ADP',
#   'SCONJ',
#   'SCONJ',
#   'PRON',
#   'AUX',
#   'PART',
#   'VERB',
#   'PUNCT'],
#  'baredukoḍi': ['INTJ',
#   'VERB',
#   'PRON',
#   'ADP',
#   'ADP',
#   'PRON',
#   'ADP',
#   'PUNCT',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'INTJ',
#   'VERB',
#   'PUNCT',
#   'PUNCT'],
#  'maretubiḍi!': ['INTJ', 'VERB', 'PRON', 'PUNCT'],
#  'saṃkōcapaḍabēḍa': ['AUX',
#   'PART',
#   'AUX',
#   'ADJ',
#   'X',
#   'PUNCT',
#   'AUX',
#   'PART',
#   'VERB',
#   'PROPN',
#   'PUNCT',
#   'PUNCT'],
#  'oṃdannu': ['NUM'],
#  'oṃdariṃda': ['ADP', 'NUM'],
#  'oṃdakke': ['ADP', 'NUM'],
#  'oṃdara': ['ADP', 'NUM'],
#  'oṃdaralli': ['ADP', 'NUM'],
#  'eraḍannu': ['NUM'],
#  'mūrakke': ['ADP', 'NUM'],
#  'nālkara': ['ADP', 'NUM'],
#  'aidariṃda': ['ADP', 'NUM'],
#  'āraralli': ['ADP',
#   'NUM',
#   'ADV',
#   'PUNCT',
#   'ADV',
#   'PUNCT',
#   'PRON',
#   'VERB',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADP',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'oṃdaneyadu': ['DET', 'ADJ', 'NUM'],
#  'hattaneyavanu': ['DET',
#   'ADJ',
#   'NOUN',
#   'DET',
#   'ADJ',
#   'NOUN',
#   'AUX',
#   'ADP',
#   'NOUN',
#   'AUX',
#   'VERB',
#   'PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'CCONJ',
#   'X',
#   'ADJ',
#   'ADJ',
#   'NOUN',
#   'PUNCT'],
#  'aidaneyadaralli': ['ADP', 'DET', 'ADJ', 'NUM'],
#  'hattaneyavanige': ['ADP', 'DET', 'ADJ', 'NOUN'],
#  'obbanu': ['NUM', 'X', 'NOUN', 'X', 'NOUN'],
#  'obbaḷu': ['NUM', 'X', 'ADJ', 'PUNCT', 'NOUN'],
#  'obbaru': ['NUM', 'NOUN', 'PUNCT', 'ADV', 'PUNCT', 'CCONJ', 'ADJ', 'PUNCT'],
#  'ibbaru': ['NUM', 'NOUN'],
#  'mūvaru': ['NUM', 'NOUN'],
#  'nālvaru': ['NUM', 'NOUN'],
#  'aivaru': ['NUM', 'NOUN'],
#  'ari': ['PART', 'VERB'],
#  'aritenu': ['PRON', 'VERB'],
#  'kalitenu': ['PRON', 'VERB'],
#  'mare': ['PART', 'VERB'],
#  'ennu': ['PART', 'VERB'],
#  'eṃdenu': ['PRON', 'VERB'],
#  'tiṃdenu': ['PRON', 'VERB'],
#  'baydenu': ['PRON',
#   'VERB',
#   'PUNCT',
#   'VERB',
#   'PRON',
#   'AUX',
#   'NOUN',
#   'PRON',
#   'ADV',
#   'PUNCT',
#   'ADP',
#   'PROPN',
#   'PROPN',
#   'PUNCT',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN'],
#  'kāyu': ['PART', 'VERB', 'SYM', 'VERB', 'ADJ'],
#  'kādenu': ['PRON', 'VERB'],
#  'kuḷiru': ['PART', 'VERB', 'ADP'],
#  'kuḷitenu': ['PRON', 'VERB', 'ADP'],
#  'sōlu': ['PART', 'AUX', 'VERB'],
#  'sīnu': ['PART', 'VERB'],
#  'sītenu': ['PRON',
#   'VERB',
#   'PRON',
#   'AUX',
#   'AUX',
#   'VERB',
#   'ADV',
#   'SCONJ',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'ADV'],
#  'ese': ['PART', 'VERB'],
#  'kusi': ['PART', 'VERB', 'ADP', 'PUNCT', 'VERB'],
#  'koḷe': ['PART', 'VERB'],
#  'dore': ['PART', 'AUX', 'VERB'],
#  'bese': ['PART', 'VERB'],
#  'mase': ['AUX', 'VERB'],
#  'moḷe': ['PART', 'VERB'],
#  'husi': ['PART', 'VERB', 'NOUN', 'SYM', 'NOUN'],
#  'āyu': ['PART', 'VERB'],
#  'oyyu': ['PART', 'VERB', 'ADP'],
#  'koyyu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'geyyu': ['PART', 'VERB'],
#  'tēyu': ['PART', 'VERB'],
#  'toyyu': ['PART', 'VERB', 'ADJ'],
#  'māyu': ['PART', 'AUX', 'VERB'],
#  'mēyu': ['PART', 'VERB'],
#  'suyyu': ['PART', 'VERB'],
#  'hāyu': ['PART', 'VERB', 'ADP'],
#  'kavalu': ['PART', 'VERB', 'ADJ'],
#  'ciguru': ['PART', 'VERB'],
#  'bevaru': ['PART', 'VERB'],
#  'nāru': ['PART', 'VERB'],
#  'iru': ['PART', 'AUX'],
#  'teru': ['PART', 'VERB'],
#  'bēsaru': ['PART', 'AUX', 'VERB'],
#  'heru': ['PART', 'VERB', 'NOUN'],
#  'horu': ['PART', 'VERB', 'DET', 'NOUN'],
#  'kollu': ['PART', 'VERB'],
#  'gellu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'nillu': ['PART', 'VERB'],
#  'aḷu': ['PART', 'VERB'],
#  'uḷu': ['PART', 'VERB'],
#  'kaḷu': ['PART', 'VERB'],
#  'kīḷu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'biddu': [],
#  'bēyu': ['AUX', 'VERB'],
#  'mīyu': ['PART', 'VERB'],
#  'aḍu': ['PART', 'VERB'],
#  'uḍu': ['PART', 'VERB'],
#  'keḍu': ['PART', 'AUX', 'VERB'],
#  'toḍu': ['PART', 'VERB'],
#  'neḍu': ['PART', 'VERB'],
#  'biḍu': ['PART', 'VERB'],
#  'suḍu': ['PART', 'VERB'],
#  'uṇṇu': ['PART', 'VERB'],
#  'kāṇu': ['PART', 'VERB'],
#  'hogu': ['PART', 'VERB'],
#  'hokku': ['ADJ', 'VERB', 'NOUN', 'PUNCT'],
#  'ode': ['PART', 'VERB'],
#  'hode': ['PART', 'VERB', 'ADP'],
#  'eḷe': ['PART', 'VERB'],
#  'tege': ['PART', 'VERB'],
#  'mlēccha': ['PROPN', 'PUNCT', 'NOUN'],
#  'adannu': ['PRON'],
#  'oḷḷeyadu': ['ADJ', 'NOUN'],
#  'kalitare': ['SCONJ', 'X', 'NUM', 'PUNCT', 'VERB'],
#  'cennāgide': ['AUX', 'ADJ'],
#  'namage': ['PRON'],
#  'niṃtiddāre': ['PRON', 'VERB'],
#  'baruttāre': ['PRON', 'VERB'],
#  'meccuviri': ['PRON', 'AUX', 'VERB'],
#  'yaśasvi': ['ADJ', 'PUNCT', 'ADJ'],
#  'agnimaṃḍala': ['NOUN', 'ADP', 'NOUN'],
#  'apasmara': [],
#  'uṃṭāgu': ['PART', 'VERB', 'PUNCT', 'VERB'],
#  'uṃṭumāḍu': ['PART', 'VERB'],
#  'kaiyalli': ['PUNCT',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'ADP',
#   'PUNCT',
#   'ADP'],
#  'korate': ['NOUN', 'PUNCT', 'VERB'],
#  'gaṃgādhara': ['PUNCT',
#   'NOUN',
#   'ADP',
#   'DET',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'caṃdraśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'tāṃḍava': [],
#  'nakk-': [],
#  'naṃjuṃḍa': ['PUNCT', 'PRON', 'VERB', 'NOUN', 'PUNCT'],
#  'nāśa': ['NOUN', 'PUNCT', 'PROPN'],
#  'mallikārjuna': ['PUNCT', 'ADJ', 'ADP', 'NOUN', 'PUNCT'],
#  'mahatva': ['NOUN', 'PUNCT', 'NOUN'],
#  'rēkhē': ['ADJ', 'PUNCT', 'NOUN'],
#  'vāsasthaḷa': ['NOUN', 'ADP', 'NOUN'],
#  'vibhūti': ['PROPN',
#   'PROPN',
#   'SCONJ',
#   'VERB',
#   'ADP',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PROPN'],
#  'śivabhakta': ['NOUN', 'ADP', 'NOUN'],
#  'siddhapuruṣa': ['ADV', 'VERB', 'NOUN'],
#  'sōmaśēkhara': ['PUNCT',
#   'PRON',
#   'VERB',
#   'DET',
#   'NOUN',
#   'ADP',
#   'PRON',
#   'NOUN',
#   'PUNCT',
#   'PUNCT',
#   'PROPN'],
#  'svabhāva': ['NOUN', 'PUNCT', 'NOUN'],
#  'haccu': ['PART', 'VERB', 'PUNCT', 'VERB']}

# %% [markdown]
# # Quick affix separation test

# %%
processed_sentences = []

desc_sorted_all_pos_mapping = dict(sorted(all_pos_mapping.items(), key=lambda item: len(item[0]), reverse=True))
for i, sentence in enumerate(other_sentences_transliterations):

    translated_sentence = other_sentences_sentences[i]
    transliteration = sentence.lower()
    transliteration = transliteration.strip()
    # Remove any trailing punctuation
    
    # Split into words
    transliteration = transliteration.split()
    # Remove trailing punctuation from each word
    transliteration = [word.rstrip('.,!?') for word in transliteration]
    #print(transliteration)
    result_dict = {}
    
    # Check if the transliteration is in the pos_mapping
    for word in transliteration:
        word = word.lower()
        if word in all_pos_mapping:
            # Check if the word is in kan_to_eng_mapping
            if word in kan_to_eng_mapping:
                translation = kan_to_eng_mapping[word]
            else:
                print(f"No translation found for {word}")
                translation = None
            result_dict[word] = {"pos": all_pos_mapping[word], "translation": translation, "affix": None}
        else:
            #print(f"No POS tags found for {word}")
            # Find if the word is affixed form of any word in all_pos_mapping
            found = False
            for key in desc_sorted_all_pos_mapping.keys():
                temp_key = key
                key = key.lower()
                if word.find(key) != -1:
                    found = True
                    #print(f"Found affixed form of {key} in {word}")
                    #print(transliteration)
                    affix = word.replace(key, "______")
                    prefix, suffix = affix.split("______")
                    #print(f"Prefix: {prefix} Suffix: {suffix}")
                    result_dict[word] = {
                        "pos": all_pos_mapping[temp_key],
                        "translation": kan_to_eng_mapping.get(temp_key, None),
                        "affix": {
                            "prefix": prefix,
                            "suffix": suffix
                        }
                    }
                    
                    break
            if not found:
                print(f"No affixed form found for '{word}' do more fuzzy matching (TODO)")
                result_dict[word] = {"pos": None, "translation": None, "affix": None}
    processed_sentences.append((sentence, translated_sentence, result_dict))
    #print("=========================================")
# Out:
# No affixed form found for 'adū' do more fuzzy matching (TODO)
# No affixed form found for 'alla' do more fuzzy matching (TODO)
# No affixed form found for 'toḍak-alla' do more fuzzy matching (TODO)
# No affixed form found for 'toḍak-illa' do more fuzzy matching (TODO)
# No affixed form found for 'adū' do more fuzzy matching (TODO)
# No affixed form found for 'adū' do more fuzzy matching (TODO)
# No affixed form found for 'adū' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'bekku' do more fuzzy matching (TODO)
# No affixed form found for 'dhāravāḍa' do more fuzzy matching (TODO)
# No affixed form found for 'karnāṭakada' do more fuzzy matching (TODO)
# No affixed form found for 'ēnū' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'nīvū' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'baralā' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'nānū' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'baralā' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'kṣamisi' do more fuzzy matching (TODO)
# No affixed form found for '/' do more fuzzy matching (TODO)
# No affixed form found for 'kṣamisiri' do more fuzzy matching (TODO)
# No affixed form found for 'avara' do more fuzzy matching (TODO)
# No affixed form found for 'baṃda' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'maisūrige' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷidanu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭanu' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'sāladā' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'kaṭṭidaru' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'nanagōskara' do more fuzzy matching (TODO)
# No affixed form found for 'nimagōskara' do more fuzzy matching (TODO)
# No affixed form found for 'baṃda' do more fuzzy matching (TODO)
# No affixed form found for 'ō' do more fuzzy matching (TODO)
# No affixed form found for 'gaṇēśarē' do more fuzzy matching (TODO)
# No affixed form found for 'hēgiddīri' do more fuzzy matching (TODO)
# No affixed form found for 'namaskāra' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'alla' do more fuzzy matching (TODO)
# No affixed form found for 'tagoḷḷi' do more fuzzy matching (TODO)
# No affixed form found for 'exercise' do more fuzzy matching (TODO)
# No affixed form found for '2' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'exercise' do more fuzzy matching (TODO)
# No affixed form found for '2' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'avaradakke' do more fuzzy matching (TODO)
# No affixed form found for 'rāmanigiṃta' do more fuzzy matching (TODO)
# No affixed form found for 'gaṇēśa' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'dhāravāḍa' do more fuzzy matching (TODO)
# No affixed form found for 'adakkiṃta' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'elladakkiṃta' do more fuzzy matching (TODO)
# No affixed form found for 'rāma' do more fuzzy matching (TODO)
# No affixed form found for 'surēśarē' do more fuzzy matching (TODO)
# No affixed form found for 'gaṇēśā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'kēḷi' do more fuzzy matching (TODO)
# No affixed form found for 'paṭṭaru' do more fuzzy matching (TODO)
# No affixed form found for 'ōdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'ōdiddenu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'mātanāḍidanu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdaru' do more fuzzy matching (TODO)
# No affixed form found for '/' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'tappu' do more fuzzy matching (TODO)
# No affixed form found for 'tōruttade' do more fuzzy matching (TODO)
# No affixed form found for 'tōrisuttēne' do more fuzzy matching (TODO)
# No affixed form found for '/' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍida' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍida' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍidaru' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍida' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'tōrisida' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷida' do more fuzzy matching (TODO)
# No affixed form found for 'baṃda' do more fuzzy matching (TODO)
# No affixed form found for 'nagara' do more fuzzy matching (TODO)
# No affixed form found for 'nagara' do more fuzzy matching (TODO)
# No affixed form found for 'avaḷige' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'nagara' do more fuzzy matching (TODO)
# No affixed form found for 'avaḷige' do more fuzzy matching (TODO)
# No affixed form found for 'ōdida' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'araḷida' do more fuzzy matching (TODO)
# No affixed form found for 'araḷida' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍidanu' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍidanō' do more fuzzy matching (TODO)
# No affixed form found for 'avanige' do more fuzzy matching (TODO)
# No affixed form found for 'koṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'bhēṭi' do more fuzzy matching (TODO)
# No affixed form found for 'ādevō' do more fuzzy matching (TODO)
# No affixed form found for 'avaḷannu' do more fuzzy matching (TODO)
# No affixed form found for 'gottilla' do more fuzzy matching (TODO)
# No affixed form found for 'nagabēkō' do more fuzzy matching (TODO)
# No affixed form found for 'aḷabēkō' do more fuzzy matching (TODO)
# No affixed form found for 'gottilla' do more fuzzy matching (TODO)
# No affixed form found for 'ēḷige' do more fuzzy matching (TODO)
# No affixed form found for 'ēḷge' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'gottilla' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'taṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'koḷḷalu' do more fuzzy matching (TODO)
# No affixed form found for 'taṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'māḍalikke' do more fuzzy matching (TODO)
# No affixed form found for 'samaya' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'bēkā' do more fuzzy matching (TODO)
# No affixed form found for 'avarannu' do more fuzzy matching (TODO)
# No affixed form found for 'māḍabēḍi' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nānū' do more fuzzy matching (TODO)
# No affixed form found for 'barabahudā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'gottilla' do more fuzzy matching (TODO)
# No affixed form found for 'avarū' do more fuzzy matching (TODO)
# No affixed form found for 'barabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'yuvudilla' do more fuzzy matching (TODO)
# No affixed form found for 'ba-' do more fuzzy matching (TODO)
# No affixed form found for 'reyuvudilla' do more fuzzy matching (TODO)
# No affixed form found for 'ba-' do more fuzzy matching (TODO)
# No affixed form found for 'reyuvudilla' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'vudilla' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷidanu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷidaru' do more fuzzy matching (TODO)
# No affixed form found for 'laṃḍan' do more fuzzy matching (TODO)
# No affixed form found for 'eṃba' do more fuzzy matching (TODO)
# No affixed form found for 'ūrige' do more fuzzy matching (TODO)
# No affixed form found for 'eṃbudu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'māḍalilla' do more fuzzy matching (TODO)
# No affixed form found for 'aṃte' do more fuzzy matching (TODO)
# No affixed form found for 'ūraṃte' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'iddāre' do more fuzzy matching (TODO)
# No affixed form found for 'ive' do more fuzzy matching (TODO)
# No affixed form found for 'avana' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'avaniṃda' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'nānū' do more fuzzy matching (TODO)
# No affixed form found for 'na' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'huṣāriralilla' do more fuzzy matching (TODO)
# No affixed form found for 'sīte' do more fuzzy matching (TODO)
# No affixed form found for 'avara' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdare' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdarū' do more fuzzy matching (TODO)
# No affixed form found for 'nānū' do more fuzzy matching (TODO)
# No affixed form found for 'yārō' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdaru' do more fuzzy matching (TODO)
# No affixed form found for 'yārannō' do more fuzzy matching (TODO)
# No affixed form found for 'yārādarū' do more fuzzy matching (TODO)
# No affixed form found for 'barabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'kūtukoḷḷi' do more fuzzy matching (TODO)
# No affixed form found for 'ēnādarū' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷi' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'iddāre' do more fuzzy matching (TODO)
# No affixed form found for 'hōda' do more fuzzy matching (TODO)
# No affixed form found for 'ēnū' do more fuzzy matching (TODO)
# No affixed form found for 'illa' do more fuzzy matching (TODO)
# No affixed form found for 'ella' do more fuzzy matching (TODO)
# No affixed form found for 'ella' do more fuzzy matching (TODO)
# No affixed form found for 'vidhy-' do more fuzzy matching (TODO)
# No affixed form found for 'tiṃda' do more fuzzy matching (TODO)
# No affixed form found for 'ella' do more fuzzy matching (TODO)
# No affixed form found for 'tiṃda' do more fuzzy matching (TODO)
# No affixed form found for 'tānu' do more fuzzy matching (TODO)
# No affixed form found for 'śrēṣṭhaneṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'tānē' do more fuzzy matching (TODO)
# No affixed form found for 'ī' do more fuzzy matching (TODO)
# No affixed form found for 'tānē' do more fuzzy matching (TODO)
# No affixed form found for 'baṃda' do more fuzzy matching (TODO)
# No affixed form found for 'tamage' do more fuzzy matching (TODO)
# No affixed form found for 'svāmi' do more fuzzy matching (TODO)
# No affixed form found for 'tāvu' do more fuzzy matching (TODO)
# No affixed form found for 'hēḷidare' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'avarannu' do more fuzzy matching (TODO)
# No affixed form found for 'tagoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'bā' do more fuzzy matching (TODO)
# No affixed form found for 'karakoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'baṃdiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'idannu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'ōdibiṭṭenu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'biṭṭubiḍi' do more fuzzy matching (TODO)
# No affixed form found for 'ōdalu' do more fuzzy matching (TODO)
# No affixed form found for 'māḍabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'biḍabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'kaḷedu' do more fuzzy matching (TODO)
# No affixed form found for 'hōyitu' do more fuzzy matching (TODO)
# No affixed form found for 'ōḍi' do more fuzzy matching (TODO)
# No affixed form found for 'hōda' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'oḍedu' do more fuzzy matching (TODO)
# No affixed form found for 'vikāsagoḷḷuttade' do more fuzzy matching (TODO)
# No affixed form found for 'saṃkōcapaḍisuttāne' do more fuzzy matching (TODO)
# No affixed form found for 'māḍaballe' do more fuzzy matching (TODO)
# No affixed form found for 'māḍaballa' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'taralā' do more fuzzy matching (TODO)
# No affixed form found for 'tanni' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'sikkitu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'sikka' do more fuzzy matching (TODO)
# No affixed form found for 'nimage' do more fuzzy matching (TODO)
# No affixed form found for 'iṃgliṣu' do more fuzzy matching (TODO)
# No affixed form found for 'nanage' do more fuzzy matching (TODO)
# No affixed form found for 'koḷalu' do more fuzzy matching (TODO)
# No affixed form found for 'ive' do more fuzzy matching (TODO)
# No affixed form found for 'biddive' do more fuzzy matching (TODO)
# No affixed form found for 'ārakke' do more fuzzy matching (TODO)
# No affixed form found for 'kūḍisu' do more fuzzy matching (TODO)
# No affixed form found for 'mūrannu' do more fuzzy matching (TODO)
# No affixed form found for 'guṇisu' do more fuzzy matching (TODO)
# No affixed form found for 'nūrannu' do more fuzzy matching (TODO)
# No affixed form found for 'ive' do more fuzzy matching (TODO)
# No affixed form found for 'ive' do more fuzzy matching (TODO)
# No affixed form found for 'eṃdu' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍiri' do more fuzzy matching (TODO)
# No affixed form found for 'meravaṇige' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'girākigaḷige' do more fuzzy matching (TODO)
# No affixed form found for 'māriddāne' do more fuzzy matching (TODO)
# No affixed form found for 'ibbarū' do more fuzzy matching (TODO)
# No affixed form found for 'barabahudu' do more fuzzy matching (TODO)
# No affixed form found for 'nōḍiddēne' do more fuzzy matching (TODO)
# No affixed form found for 'mūrū' do more fuzzy matching (TODO)
# No affixed form found for 'mējina' do more fuzzy matching (TODO)
# No affixed form found for 'iddaru' do more fuzzy matching (TODO)
# No affixed form found for 'rūpāyi' do more fuzzy matching (TODO)
# No affixed form found for 'kharcu' do more fuzzy matching (TODO)
# No affixed form found for 'hoddu' do more fuzzy matching (TODO)
# No affixed form found for 'avarannu' do more fuzzy matching (TODO)
# No affixed form found for 'karakoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'tagoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'avarannu' do more fuzzy matching (TODO)
# No affixed form found for 'karakoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'tagoṃḍu' do more fuzzy matching (TODO)
# No affixed form found for 'ā' do more fuzzy matching (TODO)
# No affixed form found for 'lesson' do more fuzzy matching (TODO)
# No affixed form found for '4' do more fuzzy matching (TODO)
# No affixed form found for 'lesson' do more fuzzy matching (TODO)
# No affixed form found for '12' do more fuzzy matching (TODO)

# %%
for result in processed_sentences:
    sentence, translated_sentence,pos_info = result
    print(f"Sentence: {sentence}")
    print(f"Translated Sentence: {translated_sentence}")
    for word, info in pos_info.items():
        print(f"  Word: {word}, POS: {info['pos']}, Translation: {info['translation']}, Affix: {info['affix']}")
    print("=========================================")
# Out:
# Sentence: Idu pustaka.
# Translated Sentence: This is a book.
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
# =========================================
# Sentence: Ivu pustakagaḷu.
# Translated Sentence: These are books.
#   Word: ivu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.), Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: Adu mara.
# Translated Sentence: That is a tree.
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: mara, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: None
# =========================================
# Sentence: Avu maragaḷu.
# Translated Sentence: Those are trees.
#   Word: avu, POS: ['PRON'], Translation: they (non-persons), Affix: None
#   Word: maragaḷu, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: Adu huḍuga.
# Translated Sentence: That is a boy.
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: huḍuga, POS: ['PROPN'], Translation: boy, Affix: None
# =========================================
# Sentence: Adu mane.
# Translated Sentence: That is a house.
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: mane, POS: ['NOUN'], Translation: house, Affix: None
# =========================================
# Sentence: Avu manegaḷu.
# Translated Sentence: Those are houses.
#   Word: avu, POS: ['PRON'], Translation: they (non-persons), Affix: None
#   Word: manegaḷu, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: Adu mahiḷe.
# Translated Sentence: That is a lady.
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: mahiḷe, POS: ['PROPN'], Translation: lady, Affix: None
# =========================================
# Sentence: Nānu vidyārthi.
# Translated Sentence: I am a [male] student.
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: vidyārthi, POS: ['X', 'NOUN', 'X', 'NOUN'], Translation: [male] student, Affix: None
# =========================================
# Sentence: Nānu vidyārthini.
# Translated Sentence: I am a [female] student.
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: vidyārthini, POS: ['X', 'ADJ', 'PUNCT', 'NOUN'], Translation: [female] student, Affix: None
# =========================================
# Sentence: idu mane
# Translated Sentence: this [is a] house [‘this thing – house’]
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: mane, POS: ['NOUN'], Translation: house, Affix: None
# =========================================
# Sentence: adu kaṭṭaḍa
# Translated Sentence: that [is a] building [‘that thing – building’]
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: kaṭṭaḍa, POS: ['VERB'], Translation: building, Affix: None
# =========================================
# Sentence: adu huḍugi
# Translated Sentence: that [is a] girl
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: avaḷu huḍugi
# Translated Sentence: she [is a] girl When sentences of the above type are pronounced, there is a slight
#   Word: avaḷu, POS: ['PRON'], Translation: she, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: avanu nanna maga
# Translated Sentence: he is my son
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nanna, POS: ['PRON'], Translation: my, Affix: None
#   Word: maga, POS: ['NOUN'], Translation: son, Affix: None
# =========================================
# Sentence: avaru nanna gurugaḷu
# Translated Sentence: he is my teacher
#   Word: avaru, POS: ['PRON'], Translation: they (persons), Affix: None
#   Word: nanna, POS: ['PRON'], Translation: my, Affix: None
#   Word: gurugaḷu, POS: ['NOUN'], Translation: teacher, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: avaru namma purōhitaru
# Translated Sentence: he is our priest
#   Word: avaru, POS: ['PRON'], Translation: they (persons), Affix: None
#   Word: namma, POS: ['PRON'], Translation: our, Affix: None
#   Word: purōhitaru, POS: ['NOUN'], Translation: priest, Affix: {'prefix': '', 'suffix': 'ru'}
# =========================================
# Sentence: Nīvu vidyārthiyā?
# Translated Sentence: Are you a [male] student?
#   Word: nīvu, POS: ['PRON'], Translation: you (plural / honorific), Affix: None
#   Word: vidyārthiyā, POS: ['X', 'NOUN', 'X', 'NOUN'], Translation: [male] student, Affix: {'prefix': '', 'suffix': 'yā'}
# =========================================
# Sentence: Nīvu vidyārthiniyā?
# Translated Sentence: Are you a [female] student?
#   Word: nīvu, POS: ['PRON'], Translation: you (plural / honorific), Affix: None
#   Word: vidyārthiniyā, POS: ['X', 'ADJ', 'PUNCT', 'NOUN'], Translation: [female] student, Affix: {'prefix': '', 'suffix': 'yā'}
# =========================================
# Sentence: Haudu, nānu vidyārthini.
# Translated Sentence: Yes, I am a [female] student.
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: vidyārthini, POS: ['X', 'ADJ', 'PUNCT', 'NOUN'], Translation: [female] student, Affix: None
# =========================================
# Sentence: Idu maravā?
# Translated Sentence: Is this a tree?
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: maravā, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: Haudu, idu mara.
# Translated Sentence: Yes, this is a tree.
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: mara, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: None
# =========================================
# Sentence: Adu pustakavā?
# Translated Sentence: Is that a book?
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: pustakavā, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: Haudu, pustaka.
# Translated Sentence: Yes, a book.
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
# =========================================
# Sentence: Adū pustakavā?
# Translated Sentence: Is that a book too?
#   Word: adū, POS: None, Translation: None, Affix: None
#   Word: pustakavā, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: Alla, adu pustakavalla.
# Translated Sentence: No, that is not a book.
#   Word: alla, POS: None, Translation: None, Affix: None
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: pustakavalla, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'valla'}
# =========================================
# Sentence: idu mara-v-alla
# Translated Sentence: this is not a tree
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: mara-v-alla, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': '-v-alla'}
# =========================================
# Sentence: adu toḍak-alla
# Translated Sentence: that is not a problem
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: toḍak-alla, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: adu huḍugi-y-alla
# Translated Sentence: that is not a girl
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: huḍugi-y-alla, POS: ['NOUN'], Translation: girl, Affix: {'prefix': '', 'suffix': '-y-alla'}
# =========================================
# Sentence: alli mara-v-illa
# Translated Sentence: there is no tree there
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: mara-v-illa, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': '-v-illa'}
# =========================================
# Sentence: alli toḍak-illa
# Translated Sentence: there is no problem there
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: toḍak-illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: alli huḍugi-y-illa
# Translated Sentence: there is no girl there Another possible word for expressing a different meaning of the English ‘no’ is the ‘no’ that expresses the denial of being wanted or being neces-
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: huḍugi-y-illa, POS: ['NOUN'], Translation: girl, Affix: {'prefix': '', 'suffix': '-y-illa'}
# =========================================
# Sentence: adū pustakavā?
# Translated Sentence: is that also a book?
#   Word: adū, POS: None, Translation: None, Affix: None
#   Word: pustakavā, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: haudu, adū pustaka
# Translated Sentence: yes, that too is a book
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: adū, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
# =========================================
# Sentence: haudu, adū ide
# Translated Sentence: yes, that too is there
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: adū, POS: None, Translation: None, Affix: None
#   Word: ide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: None
# =========================================
# Sentence: illa, adu illa
# Translated Sentence: no, that is not there
#   Word: illa, POS: None, Translation: None, Affix: None
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
# =========================================
# Sentence: ākāśa mattu bekku
# Translated Sentence: The Sky and the
#   Word: ākāśa, POS: ['NOUN'], Translation: sky, Affix: None
#   Word: mattu, POS: ['CCONJ'], Translation: and, Affix: None
#   Word: bekku, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: maisūru maṃgaḷūru beṃgaḷūru śivamogga dhāravāḍa ivu karnāṭakada nagaragaḷu
# Translated Sentence: Mysore, Mangalore, Bangalore, Shimoga, and Dharwad are cities in (‘of’) Karnataka
#   Word: maisūru, POS: ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN'], Translation: place, village, town, ‘native place’, city, Affix: {'prefix': 'mais', 'suffix': ''}
#   Word: maṃgaḷūru, POS: ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN'], Translation: place, village, town, ‘native place’, city, Affix: {'prefix': 'maṃgaḷ', 'suffix': ''}
#   Word: beṃgaḷūru, POS: ['NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN', 'PUNCT', 'PUNCT', 'ADJ', 'NOUN', 'PUNCT', 'PUNCT', 'NOUN'], Translation: place, village, town, ‘native place’, city, Affix: {'prefix': 'beṃgaḷ', 'suffix': ''}
#   Word: śivamogga, POS: [], Translation: (name of god), Affix: {'prefix': '', 'suffix': 'mogga'}
#   Word: dhāravāḍa, POS: None, Translation: None, Affix: None
#   Word: ivu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.), Affix: None
#   Word: karnāṭakada, POS: None, Translation: None, Affix: None
#   Word: nagaragaḷu, POS: ['PART', 'VERB'], Translation: to weep, Affix: {'prefix': 'nagarag', 'suffix': ''}
# =========================================
# Sentence: Ēnu samācāra?
# Translated Sentence: What is the news?
#   Word: ēnu, POS: ['PRON', 'PUNCT'], Translation: what?, Affix: None
#   Word: samācāra, POS: ['NOUN'], Translation: news, Affix: None
# =========================================
# Sentence: Ēnū illa.
# Translated Sentence: Nothing (‘what-also is not’).
#   Word: ēnū, POS: None, Translation: None, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Nīvū cennāgiddīrā?
# Translated Sentence: Are you fine too?
#   Word: nīvū, POS: None, Translation: None, Affix: None
#   Word: cennāgiddīrā, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddīrā'}
# =========================================
# Sentence: Paravā illa.
# Translated Sentence: All right (‘there is no worry’).
#   Word: paravā, POS: ['VERB'], Translation: worry, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: (Nānu) baralā?
# Translated Sentence: May I leave? (‘Shall I come?’)
#   Word: (nānu), POS: ['PRON'], Translation: I, Affix: {'prefix': '(', 'suffix': ')'}
#   Word: baralā, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Namaskāra, Gururājarē.
# Translated Sentence: Greetings, Mr Gururaja. Gururāja
#   Word: namaskāra, POS: None, Translation: None, Affix: None
#   Word: gururājarē, POS: ['NOUN'], Translation: teacher, Affix: {'prefix': '', 'suffix': 'rājarē'}
# =========================================
# Sentence: Namaskāra, Rāmappanavarē.
# Translated Sentence: Greetings, Mr Rāmappa. Rāmappa
#   Word: namaskāra, POS: None, Translation: None, Affix: None
#   Word: rāmappanavarē, POS: ['PROPN'], Translation: father, Affix: {'prefix': 'rām', 'suffix': 'navarē'}
# =========================================
# Sentence: Nānu cennāgiddēne. Nīvu?
# Translated Sentence: I’m fine. And you? Rāmappa
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: cennāgiddēne, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddēne'}
#   Word: nīvu, POS: ['PRON'], Translation: you (plural / honorific), Affix: None
# =========================================
# Sentence: Nānū cennāgiddēne. Ivaru nimma maneyavarā?
# Translated Sentence: I’m fine too. Is this your wife?
#   Word: nānū, POS: None, Translation: None, Affix: None
#   Word: cennāgiddēne, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddēne'}
#   Word: ivaru, POS: ['PRON', 'SYM', 'PRON'], Translation: he / she (honorific), Affix: None
#   Word: nimma, POS: ['PRON'], Translation: your (honorific), Affix: None
#   Word: maneyavarā, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'yavarā'}
# =========================================
# Sentence: Haudu, ivara hesaru Sītamma.
# Translated Sentence: Yes, her name is Sītamma. Rāmappa
#   Word: haudu, POS: ['INTJ'], Translation: yes, Affix: None
#   Word: ivara, POS: ['PRON', 'SYM', 'PRON'], Translation: his / her (honorific), Affix: None
#   Word: hesaru, POS: ['NOUN'], Translation: name, Affix: None
#   Word: sītamma, POS: ['ADJ', 'NOUN'], Translation: younger brother, Affix: {'prefix': 'sī', 'suffix': ''}
# =========================================
# Sentence: Namaskāra, Sītammanavarē.
# Translated Sentence: Greetings, Mrs Sītamma.
#   Word: namaskāra, POS: None, Translation: None, Affix: None
#   Word: sītammanavarē, POS: ['ADJ', 'NOUN'], Translation: younger brother, Affix: {'prefix': 'sī', 'suffix': 'navarē'}
# =========================================
# Sentence: Nānu baralā?
# Translated Sentence: May I take leave? Gururāja
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: baralā, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Sari, banni.
# Translated Sentence: All right, good bye. Rāmappa
#   Word: sari, POS: ['INTJ', 'PUNCT', 'ADV', 'ADV', 'PUNCT', 'ADJ'], Translation: okay, all right, correct, Affix: None
#   Word: banni, POS: ['INTJ', 'VERB'], Translation: please come, Affix: None
# =========================================
# Sentence: Baruttēne, Sītammanavarē. Namaskāra.
# Translated Sentence: Till next time, Mrs Sītamma. Good bye.
#   Word: baruttēne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttēne'}
#   Word: sītammanavarē, POS: ['ADJ', 'NOUN'], Translation: younger brother, Affix: {'prefix': 'sī', 'suffix': 'navarē'}
#   Word: namaskāra, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: kṣamisi / kṣamisiri
# Translated Sentence: excuse me, sorry (honorific)
#   Word: kṣamisi, POS: None, Translation: None, Affix: None
#   Word: /, POS: None, Translation: None, Affix: None
#   Word: kṣamisiri, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: idu hasu
# Translated Sentence: this is a cow
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: hasu, POS: ['NOUN'], Translation: cow, Affix: None
# =========================================
# Sentence: ivu hasuvina koṃbugaḷu
# Translated Sentence: these are a cow’s horns
#   Word: ivu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: they / these (neuter) The proximate pronouns are used when the objects to which they refer are near to the speaker. (Whenever the distantness or proximity of the object is unclear, irrelevant or unimportant, the distant pronouns are generally used.), Affix: None
#   Word: hasuvina, POS: ['NOUN'], Translation: cow, Affix: {'prefix': '', 'suffix': 'vina'}
#   Word: koṃbugaḷu, POS: ['NOUN'], Translation: horn, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: idu baṇṇa
# Translated Sentence: this is a colour
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: baṇṇa, POS: ['NOUN'], Translation: colour, Affix: None
# =========================================
# Sentence: idu hesaru
# Translated Sentence: this is a name
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: hesaru, POS: ['NOUN'], Translation: name, Affix: None
# =========================================
# Sentence: idu avara hesaru
# Translated Sentence: this is their name
#   Word: idu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / this, Affix: None
#   Word: avara, POS: None, Translation: None, Affix: None
#   Word: hesaru, POS: ['NOUN'], Translation: name, Affix: None
# =========================================
# Sentence: pustaka cennāgide
# Translated Sentence: the book is nice
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: cennāgide, POS: ['AUX', 'ADJ'], Translation: is good, Affix: None
# =========================================
# Sentence: huḍugi baṃdaḷu
# Translated Sentence: the girl came
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
#   Word: baṃdaḷu, POS: ['PART', 'VERB'], Translation: to weep, Affix: {'prefix': 'baṃd', 'suffix': ''}
# =========================================
# Sentence: huḍuga baṃda
# Translated Sentence: the boy came
#   Word: huḍuga, POS: ['PROPN'], Translation: boy, Affix: None
#   Word: baṃda, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avanu yāvāgalū ōduttāne
# Translated Sentence: he always reads
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: yāvāgalū, POS: ['ADV'], Translation: always, Affix: None
#   Word: ōduttāne, POS: ['PART', 'VERB'], Translation: to read, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu nāḷe baruttāne
# Translated Sentence: he will come
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nāḷe, POS: ['NOUN'], Translation: tomorrow, Affix: None
#   Word: baruttāne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu yāvāgalū ōduttāne
# Translated Sentence: he always reads
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: yāvāgalū, POS: ['ADV'], Translation: always, Affix: None
#   Word: ōduttāne, POS: ['PART', 'VERB'], Translation: to read, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu yāvāgalū ōduvanu
# Translated Sentence: he will always read mean practically the same, and it is largely a matter of stylistic prefer- ence whether one uses the one or the other. In coastal Karnataka there is a stronger tendency to differentiate between the use of the present
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: yāvāgalū, POS: ['ADV'], Translation: always, Affix: None
#   Word: ōduvanu, POS: ['PART', 'VERB'], Translation: to read, Affix: {'prefix': '', 'suffix': 'vanu'}
# =========================================
# Sentence: adu baruvudilla
# Translated Sentence: it will not come
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: baruvudilla, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'vudilla'}
# =========================================
# Sentence: nānu nidde māḍuvudilla
# Translated Sentence: I will not sleep
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: nidde, POS: ['NOUN'], Translation: sleep, Affix: None
#   Word: māḍuvudilla, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: {'prefix': '', 'suffix': 'vudilla'}
# =========================================
# Sentence: avanu nidde māḍuvudilla
# Translated Sentence: he will not sleep
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nidde, POS: ['NOUN'], Translation: sleep, Affix: None
#   Word: māḍuvudilla, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: {'prefix': '', 'suffix': 'vudilla'}
# =========================================
# Sentence: nīvu nidde māḍuvudilla
# Translated Sentence: you will not sleep It is important to note that there is no distinction in the written lan-
#   Word: nīvu, POS: ['PRON'], Translation: you (plural / honorific), Affix: None
#   Word: nidde, POS: ['NOUN'], Translation: sleep, Affix: None
#   Word: māḍuvudilla, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: {'prefix': '', 'suffix': 'vudilla'}
# =========================================
# Sentence: nidde māḍu
# Translated Sentence: to sleep
#   Word: nidde, POS: ['NOUN'], Translation: sleep, Affix: None
#   Word: māḍu, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: None
# =========================================
# Sentence: ā mara
# Translated Sentence: that tree
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: mara, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: None
# =========================================
# Sentence: ā maragaḷu
# Translated Sentence: those trees
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: maragaḷu, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: ā huḍugi
# Translated Sentence: that girl
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: ā huḍugiyaru
# Translated Sentence: those girls
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: huḍugiyaru, POS: ['NOUN'], Translation: girl, Affix: {'prefix': '', 'suffix': 'yaru'}
# =========================================
# Sentence: ī huḍugi
# Translated Sentence: this girl
#   Word: ī, POS: None, Translation: None, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: ī huḍugiyaru
# Translated Sentence: these girls
#   Word: ī, POS: None, Translation: None, Affix: None
#   Word: huḍugiyaru, POS: ['NOUN'], Translation: girl, Affix: {'prefix': '', 'suffix': 'yaru'}
# =========================================
# Sentence: avanu ā huḍuganannu hoḍeyuttāne
# Translated Sentence: he hits that boy The learner should note here the order of the parts of a transitive sen-
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: huḍuganannu, POS: ['PROPN'], Translation: boy, Affix: {'prefix': '', 'suffix': 'nannu'}
#   Word: hoḍeyuttāne, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to hit, strike, Affix: {'prefix': '', 'suffix': 'yuttāne'}
# =========================================
# Sentence: nenne avanu Maisūrige hōdanu
# Translated Sentence: yesterday he went to Mysore Here the city Maisūru (‘Mysore’ in Anglified spelling; nowadays offi- cially spelt ‘Mysuru’) is the destination of the subject’s travel, therefore
#   Word: nenne, POS: ['NOUN'], Translation: yesterday, Affix: None
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: maisūrige, POS: None, Translation: None, Affix: None
#   Word: hōdanu, POS: ['PRON', 'VERB'], Translation: he went, Affix: None
# =========================================
# Sentence: avanu ā huḍuganige ī viṣayavannu hēḷidanu
# Translated Sentence: he told this matter to that boy Usually, the indirect object (in the dative) is placed before the direct object (in the accusative) in the sentence; but because these parts of the sentence are clearly indicated by the case endings, there is some degree of freedom in the order of these parts, if the speaker / writer wishes to emphasize a part of the sentence by a less usual word order. Therefore a Kannada speaker will not say ‘he told this matter to that boy’ but ‘he to that boy this matter told’, etc. One could also say ‘to that boy he this matter told’ to emphasize the receiver of the message; or ‘he this matter to that boy told’ to emphasize the object, or ‘this matter he to that boy told’ to emphasize the object still more. But the
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: huḍuganige, POS: ['PROPN'], Translation: boy, Affix: {'prefix': '', 'suffix': 'nige'}
#   Word: ī, POS: None, Translation: None, Affix: None
#   Word: viṣayavannu, POS: ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'], Translation: matter, thing, topic, Affix: {'prefix': '', 'suffix': 'vannu'}
#   Word: hēḷidanu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avanu ūṭakke manege hōdanu
# Translated Sentence: he went home for lunch / dinner
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: ūṭakke, POS: [], Translation: (cooked) meal, Affix: {'prefix': '', 'suffix': 'kke'}
#   Word: manege, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'ge'}
#   Word: hōdanu, POS: ['PRON', 'VERB'], Translation: he went, Affix: None
# =========================================
# Sentence: avanu nanage pustaka koṭṭanu
# Translated Sentence: he gave me a book
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nanage, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: koṭṭanu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nānu nimage pustaka koṭṭenu
# Translated Sentence: I gave you a book
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: nimage, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: koṭṭenu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nānu avarige pustaka koṭṭenu
# Translated Sentence: I gave them a book
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: avarige, POS: ['PART', 'VERB'], Translation: to know, Affix: {'prefix': 'av', 'suffix': 'ge'}
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: koṭṭenu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nanage ā pustaka bēku
# Translated Sentence: I want / need that book
#   Word: nanage, POS: None, Translation: None, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: nimage ā pustakagaḷu bēku
# Translated Sentence: you want / need those books The above sentences mean, more literally translated: ‘to me that book is a desired thing’, and ‘to you those books are a desired thing’. The grammatical subject can be anything (singular, plural, neuter, femi-
#   Word: nimage, POS: None, Translation: None, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: nīvu namage bēku
# Translated Sentence: we want / need you
#   Word: nīvu, POS: ['PRON'], Translation: you (plural / honorific), Affix: None
#   Word: namage, POS: ['PRON'], Translation: us (dative case), Affix: None
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: nanage ā pustaka bēḍa
# Translated Sentence: I do not want / need that book
#   Word: nanage, POS: None, Translation: None, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēḍa, POS: ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: is not wanted / not required, Affix: None
# =========================================
# Sentence: nimage ā pustakagaḷu bēḍa
# Translated Sentence: you do not want / need those books
#   Word: nimage, POS: None, Translation: None, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: bēḍa, POS: ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: is not wanted / not required, Affix: None
# =========================================
# Sentence: nanage iṣṭu anna sāku
# Translated Sentence: this much rice is enough for me
#   Word: nanage, POS: None, Translation: None, Affix: None
#   Word: iṣṭu, POS: ['PRON', 'ADJ'], Translation: this much, Affix: None
#   Word: anna, POS: ['NOUN'], Translation: rice (cooked), Affix: None
#   Word: sāku, POS: ['PRON', 'AUX', 'ADJ'], Translation: it is enough, Affix: None
# =========================================
# Sentence: aṣṭu haṇa nimage sāladā?
# Translated Sentence: is that much money not enough for you?
#   Word: aṣṭu, POS: ['ADV', 'ADV'], Translation: that much, Affix: None
#   Word: haṇa, POS: ['NOUN'], Translation: money, Affix: None
#   Word: nimage, POS: None, Translation: None, Affix: None
#   Word: sāladā, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avaru idannu kaiyiṃda baredaru
# Translated Sentence: they wrote this by hand
#   Word: avaru, POS: ['PRON'], Translation: they (persons), Affix: None
#   Word: idannu, POS: None, Translation: None, Affix: None
#   Word: kaiyiṃda, POS: ['NOUN', 'PUNCT', 'VERB'], Translation: hand, arm, Affix: {'prefix': '', 'suffix': 'yiṃda'}
#   Word: baredaru, POS: ['PART', 'VERB'], Translation: to write, Affix: {'prefix': '', 'suffix': 'daru'}
# =========================================
# Sentence: avaru kiviyiṃda kēḷuvaru
# Translated Sentence: they will listen with their ear[s]
#   Word: avaru, POS: ['PRON'], Translation: they (persons), Affix: None
#   Word: kiviyiṃda, POS: ['NOUN'], Translation: ear, Affix: {'prefix': '', 'suffix': 'yiṃda'}
#   Word: kēḷuvaru, POS: ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: to ask, to hear, Affix: {'prefix': '', 'suffix': 'varu'}
# =========================================
# Sentence: avaru idannu kalliniṃda kaṭṭidaru
# Translated Sentence: they built this from stone
#   Word: avaru, POS: ['PRON'], Translation: they (persons), Affix: None
#   Word: idannu, POS: None, Translation: None, Affix: None
#   Word: kalliniṃda, POS: ['ADV'], Translation: there, Affix: {'prefix': 'k', 'suffix': 'niṃda'}
#   Word: kaṭṭidaru, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avaru idannu kaiyalli baredaru
# Translated Sentence: they wrote this by hand
#   Word: avaru, POS: ['PRON'], Translation: they (persons), Affix: None
#   Word: idannu, POS: None, Translation: None, Affix: None
#   Word: kaiyalli, POS: ['PUNCT', 'ADP', 'DET', 'NOUN', 'PUNCT', 'PUNCT', 'ADP', 'PUNCT', 'ADP'], Translation: ‘in the hand’, with, near, Affix: None
#   Word: baredaru, POS: ['PART', 'VERB'], Translation: to write, Affix: {'prefix': '', 'suffix': 'daru'}
# =========================================
# Sentence: avanu maneyoḷaginiṃda baruttāne
# Translated Sentence: he comes from within the house literally means ‘he house-[of]-inside-[from] comes’. Also the dative and especially genitive forms of postpositions are used often:
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: maneyoḷaginiṃda, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'yoḷaginiṃda'}
#   Word: baruttāne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu maneyoḷakke hōguttāne
# Translated Sentence: he enters the house
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: maneyoḷakke, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'yoḷakke'}
#   Word: hōguttāne, POS: ['PART', 'VERB'], Translation: to go, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: avanu ūṭakkōskara baruttāne
# Translated Sentence: he comes for the meal
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: ūṭakkōskara, POS: [], Translation: (cooked) meal, Affix: {'prefix': '', 'suffix': 'kkōskara'}
#   Word: baruttāne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttāne'}
# =========================================
# Sentence: pustaka nanagōskara ide
# Translated Sentence: the book is for me
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: nanagōskara, POS: None, Translation: None, Affix: None
#   Word: ide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: None
# =========================================
# Sentence: avanu nimagōskara baṃda
# Translated Sentence: he came for you
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: nimagōskara, POS: None, Translation: None, Affix: None
#   Word: baṃda, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Ō banni, oḷage banni, Gaṇēśarē.
# Translated Sentence: Oh, come in, com in, Mr Ganesha.
#   Word: ō, POS: None, Translation: None, Affix: None
#   Word: banni, POS: ['INTJ', 'VERB'], Translation: please come, Affix: None
#   Word: oḷage, POS: ['ADP'], Translation: within, Affix: None
#   Word: gaṇēśarē, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Hēgiddīri? Ēnu samācāra?
# Translated Sentence: How are you? What is new? Gaṇēśa
#   Word: hēgiddīri, POS: None, Translation: None, Affix: None
#   Word: ēnu, POS: ['PRON', 'PUNCT'], Translation: what?, Affix: None
#   Word: samācāra, POS: ['NOUN'], Translation: news, Affix: None
# =========================================
# Sentence: Namaskāra, Rāmayyanavarē. Nānu cennāgiddēne. Toṃdare illa. Viśēṣavāda samācāravilla.
# Translated Sentence: Greetings, Mr Rāmayya. I’m fine. No problems. There’s no special news.
#   Word: namaskāra, POS: None, Translation: None, Affix: None
#   Word: rāmayyanavarē, POS: ['PROPN'], Translation: lord, Affix: {'prefix': 'rām', 'suffix': 'navarē'}
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: cennāgiddēne, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddēne'}
#   Word: toṃdare, POS: ['NOUN'], Translation: trouble, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
#   Word: viśēṣavāda, POS: ['ADJ'], Translation: special, Affix: None
#   Word: samācāravilla, POS: ['NOUN'], Translation: news, Affix: {'prefix': '', 'suffix': 'villa'}
# =========================================
# Sentence: Cennāgiddēne, amma.
# Translated Sentence: I’m fine, madam. Sītamma
#   Word: cennāgiddēne, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 'ddēne'}
#   Word: amma, POS: ['NOUN'], Translation: mother, Affix: None
# =========================================
# Sentence: Nīvu ēnu tagoḷḷuttīri? Nānu cahā māḍuttēne.
# Translated Sentence: What will you have? I’ll make some tea.
#   Word: nīvu, POS: ['PRON'], Translation: you (plural / honorific), Affix: None
#   Word: ēnu, POS: ['PRON', 'PUNCT'], Translation: what?, Affix: None
#   Word: tagoḷḷuttīri, POS: ['PART', 'VERB'], Translation: to take, Affix: {'prefix': '', 'suffix': 'ttīri'}
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: cahā, POS: ['NOUN'], Translation: tea, Affix: None
#   Word: māḍuttēne, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to do, make, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: Alla, svalpa tagoḷḷi.
# Translated Sentence: No, have a little bit. Gaṇēśa
#   Word: alla, POS: None, Translation: None, Affix: None
#   Word: svalpa, POS: ['DET', 'NOUN', 'PUNCT', 'DET', 'ADJ'], Translation: a bit, a little, Affix: None
#   Word: tagoḷḷi, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Nijavāgi bēḍamma.
# Translated Sentence: Really, no, madam. Sītamma
#   Word: nijavāgi, POS: ['ADV', 'PUNCT', 'ADV'], Translation: really, truly, Affix: None
#   Word: bēḍamma, POS: ['NOUN'], Translation: mother, Affix: {'prefix': 'bēḍ', 'suffix': ''}
# =========================================
# Sentence: Exercise 2
# Translated Sentence: Ask a fellow learner about the location of various objects and persons in the room, and let him answer.
#   Word: exercise, POS: None, Translation: None, Affix: None
#   Word: 2, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: adu mara
# Translated Sentence: that is a tree
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: mara, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: None
# =========================================
# Sentence: avu maragaḷu
# Translated Sentence: those are trees
#   Word: avu, POS: ['PRON'], Translation: they (non-persons), Affix: None
#   Word: maragaḷu, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: nāvu raitaru
# Translated Sentence: we are farmers
#   Word: nāvu, POS: ['PRON'], Translation: we, Affix: None
#   Word: raitaru, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'ru'}
# =========================================
# Sentence: nīvu raitaru
# Translated Sentence: you are farmers
#   Word: nīvu, POS: ['PRON'], Translation: you (plural / honorific), Affix: None
#   Word: raitaru, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'ru'}
# =========================================
# Sentence: adu maravalla
# Translated Sentence: that is not a tree
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: maravalla, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'valla'}
# =========================================
# Sentence: avu maragaḷalla
# Translated Sentence: those are not trees
#   Word: avu, POS: ['PRON'], Translation: they (non-persons), Affix: None
#   Word: maragaḷalla, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷalla'}
# =========================================
# Sentence: nānu raitanalla
# Translated Sentence: I am not a farmer
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: raitanalla, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'nalla'}
# =========================================
# Sentence: nāvu raitaralla
# Translated Sentence: we are not farmers
#   Word: nāvu, POS: ['PRON'], Translation: we, Affix: None
#   Word: raitaralla, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'ralla'}
# =========================================
# Sentence: nīvu raitaralla
# Translated Sentence: you are not farmers
#   Word: nīvu, POS: ['PRON'], Translation: you (plural / honorific), Affix: None
#   Word: raitaralla, POS: ['NOUN'], Translation: farmer, Affix: {'prefix': '', 'suffix': 'ralla'}
# =========================================
# Sentence: maragaḷu alli illa
# Translated Sentence: trees are not there
#   Word: maragaḷu, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nānu alli illa
# Translated Sentence: I am not there
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: illa, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: namage pustaka bēku
# Translated Sentence: we need a book
#   Word: namage, POS: ['PRON'], Translation: us (dative case), Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: namage pustakagaḷu bēku
# Translated Sentence: we need books
#   Word: namage, POS: ['PRON'], Translation: us (dative case), Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: namage pustaka bēḍa
# Translated Sentence: we do not need a book
#   Word: namage, POS: ['PRON'], Translation: us (dative case), Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēḍa, POS: ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: is not wanted / not required, Affix: None
# =========================================
# Sentence: namage pustakagaḷu bēḍa
# Translated Sentence: we do not need books
#   Word: namage, POS: ['PRON'], Translation: us (dative case), Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: bēḍa, POS: ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: is not wanted / not required, Affix: None
# =========================================
# Sentence: adu maravā?
# Translated Sentence: Is that a tree?
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: maravā, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'vā'}
# =========================================
# Sentence: adu maravē?
# Translated Sentence: That surely is a tree, isn’t it?
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: maravē, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'vē'}
# =========================================
# Sentence: adu maravō?
# Translated Sentence: That is not a tree, is it?
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: maravō, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'vō'}
# =========================================
# Sentence: ā bassu keṃpu
# Translated Sentence: that bus is red
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: bassu, POS: ['NOUN'], Translation: bus (vehicle), Affix: None
#   Word: keṃpu, POS: ['PROPN'], Translation: red, Affix: None
# =========================================
# Sentence: avanu cikka huḍuga
# Translated Sentence: he is a small boy
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: cikka, POS: ['ADJ'], Translation: small, Affix: None
#   Word: huḍuga, POS: ['PROPN'], Translation: boy, Affix: None
# =========================================
# Sentence: avaḷu cikka huḍugi
# Translated Sentence: she is a small girl
#   Word: avaḷu, POS: ['PRON'], Translation: she, Affix: None
#   Word: cikka, POS: ['ADJ'], Translation: small, Affix: None
#   Word: huḍugi, POS: ['NOUN'], Translation: girl, Affix: None
# =========================================
# Sentence: adu cikka mane
# Translated Sentence: that is a small house
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: cikka, POS: ['ADJ'], Translation: small, Affix: None
#   Word: mane, POS: ['NOUN'], Translation: house, Affix: None
# =========================================
# Sentence: avaru cikka huḍugaru
# Translated Sentence: they are small boys
#   Word: avaru, POS: ['PRON'], Translation: they (persons), Affix: None
#   Word: cikka, POS: ['ADJ'], Translation: small, Affix: None
#   Word: huḍugaru, POS: ['PROPN'], Translation: boy, Affix: {'prefix': '', 'suffix': 'ru'}
# =========================================
# Sentence: avaḷu ā cikka huḍugarannu nōḍidaḷu
# Translated Sentence: she looked at those small boys
#   Word: avaḷu, POS: ['PRON'], Translation: she, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: cikka, POS: ['ADJ'], Translation: small, Affix: None
#   Word: huḍugarannu, POS: ['PROPN'], Translation: boy, Affix: {'prefix': '', 'suffix': 'rannu'}
#   Word: nōḍidaḷu, POS: ['PART', 'VERB'], Translation: to weep, Affix: {'prefix': 'nōḍid', 'suffix': ''}
# =========================================
# Sentence: adu keṭṭa pustaka
# Translated Sentence: that is a bad book then one is actually saying (from an etymological and grammatical
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: keṭṭa, POS: ['ADJ'], Translation: bad, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
# =========================================
# Sentence: adu suṃdaravāda saṃgīta
# Translated Sentence: that is beautiful music
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: suṃdaravāda, POS: ['ADJ'], Translation: beautiful, Affix: {'prefix': '', 'suffix': 'vāda'}
#   Word: saṃgīta, POS: ['NOUN'], Translation: music, Affix: None
# =========================================
# Sentence: adu kliṣṭa-v-āda viṣaya
# Translated Sentence: that is a complicated matter
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
#   Word: kliṣṭa-v-āda, POS: ['VERB'], Translation: complicated, Affix: {'prefix': '', 'suffix': '-v-āda'}
#   Word: viṣaya, POS: ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'], Translation: matter, thing, topic, Affix: None
# =========================================
# Sentence: ā praśne kaṣṭa
# Translated Sentence: that question is difficult
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: praśne, POS: ['NOUN'], Translation: question, Affix: None
#   Word: kaṣṭa, POS: ['ADJ'], Translation: difficult, Affix: None
# =========================================
# Sentence: adu bēre pustaka
# Translated Sentence: that is a different book
#   Word: adu, POS: ['PRON', 'PUNCT', 'PRON'], Translation: it / that, Affix: None
# ...
# Translated Sentence: There are seven bags over there. The fourth one contains apples [lit.: in the fourth one there are apples].
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: ēḷu, POS: ['PART', 'VERB'], Translation: to rise, Affix: None
#   Word: cīlagaḷu, POS: ['PROPN', 'PUNCT', 'NOUN'], Translation: bag, purse, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: ive, POS: None, Translation: None, Affix: None
#   Word: nālkaneyadaralli, POS: ['ADV'], Translation: there, Affix: {'prefix': 'nālkaneyadar', 'suffix': ''}
#   Word: sēbugaḷu, POS: ['PART', 'VERB'], Translation: to weep, Affix: {'prefix': 'sēbug', 'suffix': ''}
# =========================================
# Sentence: eṣṭu maṃdi oḷage baruttāre eṃdu nōḍiri. nūraneyavaru baṃdāga uḷidavarannu bēre kaḍege kaḷuhisiri.
# Translated Sentence: See how many people come in. When the one-hundredth person has come, send the remaining persons somewhere else.
#   Word: eṣṭu, POS: ['SCONJ', 'ADJ', 'PUNCT'], Translation: how much?, Affix: None
#   Word: maṃdi, POS: ['NOUN'], Translation: person, Affix: None
#   Word: oḷage, POS: ['ADP'], Translation: within, Affix: None
#   Word: baruttāre, POS: ['PRON', 'VERB'], Translation: they come, Affix: None
#   Word: eṃdu, POS: None, Translation: None, Affix: None
#   Word: nōḍiri, POS: None, Translation: None, Affix: None
#   Word: nūraneyavaru, POS: ['PRON'], Translation: they (persons), Affix: {'prefix': 'nūraney', 'suffix': ''}
#   Word: baṃdāga, POS: ['ADV', 'PUNCT', 'DET', 'NOUN'], Translation: then, that time, Affix: {'prefix': 'baṃd', 'suffix': ''}
#   Word: uḷidavarannu, POS: ['PART', 'VERB'], Translation: to remain, Affix: {'prefix': '', 'suffix': 'davarannu'}
#   Word: bēre, POS: ['ADJ', 'PUNCT', 'PRON', 'ADV'], Translation: other, something else, Affix: None
#   Word: kaḍege, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: side, direction, Affix: {'prefix': '', 'suffix': 'ge'}
#   Word: kaḷuhisiri, POS: ['PART', 'VERB'], Translation: to steal, Affix: {'prefix': '', 'suffix': 'hisiri'}
# =========================================
# Sentence: nālku pustakagaḷu
# Translated Sentence: four books
#   Word: nālku, POS: ['NUM'], Translation: four, Affix: None
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
# =========================================
# Sentence: meravaṇige mūru bīdigaḷalli sāgitu.
# Translated Sentence: The procession went through three streets.
#   Word: meravaṇige, POS: None, Translation: None, Affix: None
#   Word: mūru, POS: ['NUM'], Translation: three, Affix: None
#   Word: bīdigaḷalli, POS: ['ADV'], Translation: there, Affix: {'prefix': 'bīdigaḷ', 'suffix': ''}
#   Word: sāgitu, POS: ['PUNCT', 'NOUN', 'PUNCT'], Translation: (gerund), Affix: {'prefix': 's', 'suffix': 'tu'}
# =========================================
# Sentence: ā nālku pustaka bēku.
# Translated Sentence: [I] need those four books. In most cases, however, the plain numerals are not used with nouns
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: nālku, POS: ['NUM'], Translation: four, Affix: None
#   Word: pustaka, POS: ['NOUN'], Translation: book, Affix: None
#   Word: bēku, POS: ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'], Translation: is wanted / required / needed, Affix: None
# =========================================
# Sentence: alli aidu maṃdi vidyārthigaḷu niṃtiddāre.
# Translated Sentence: Four students are standing there.
#   Word: alli, POS: ['ADV'], Translation: there, Affix: None
#   Word: aidu, POS: ['NUM'], Translation: five, Affix: None
#   Word: maṃdi, POS: ['NOUN'], Translation: person, Affix: None
#   Word: vidyārthigaḷu, POS: ['X', 'NOUN', 'X', 'NOUN'], Translation: [male] student, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: niṃtiddāre, POS: ['PRON', 'VERB'], Translation: they stand, Affix: None
# =========================================
# Sentence: hattu jana girākigaḷige haṇṇu māriddāne.
# Translated Sentence: He has sold fruits to ten customers. Alternatively, up to the count of five, one can use pronominalized short forms of numerals.
#   Word: hattu, POS: ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'], Translation: to climb; to begin, Affix: None
#   Word: jana, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: person, people, Affix: None
#   Word: girākigaḷige, POS: None, Translation: None, Affix: None
#   Word: haṇṇu, POS: ['NOUN'], Translation: fruit, Affix: None
#   Word: māriddāne, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: ibbarū barabahudu.
# Translated Sentence: Both of them may come.
#   Word: ibbarū, POS: None, Translation: None, Affix: None
#   Word: barabahudu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: ibbarigū hēḷidenu
# Translated Sentence: I told both of them.
#   Word: ibbarigū, POS: ['PART', 'VERB'], Translation: to know, Affix: {'prefix': 'ibb', 'suffix': 'gū'}
#   Word: hēḷidenu, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: {'prefix': 'hēḷ', 'suffix': 'nu'}
# =========================================
# Sentence: saṃgrahālayadalli mūru citragaḷannu nōḍiddēne. mūrū cennāgive.
# Translated Sentence: I have seen three pictures in the museum. All three of them are nice.
#   Word: saṃgrahālayadalli, POS: ['NOUN'], Translation: museum, Affix: {'prefix': '', 'suffix': 'dalli'}
#   Word: mūru, POS: ['NUM'], Translation: three, Affix: None
#   Word: citragaḷannu, POS: ['NOUN'], Translation: picture, Affix: {'prefix': '', 'suffix': 'gaḷannu'}
#   Word: nōḍiddēne, POS: None, Translation: None, Affix: None
#   Word: mūrū, POS: None, Translation: None, Affix: None
#   Word: cennāgive, POS: ['ADV', 'PUNCT', 'ADV'], Translation: nicely, finely, Affix: {'prefix': '', 'suffix': 've'}
# =========================================
# Sentence: mējina mēle hattāru pustakagaḷu iddavu
# Translated Sentence: there were dozens of books on the table
#   Word: mējina, POS: None, Translation: None, Affix: None
#   Word: mēle, POS: ['ADP'], Translation: on, Affix: None
#   Word: hattāru, POS: ['NUM'], Translation: six, Affix: {'prefix': 'hatt', 'suffix': ''}
#   Word: pustakagaḷu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷu'}
#   Word: iddavu, POS: ['PRON'], Translation: they (non-persons), Affix: {'prefix': 'idd', 'suffix': ''}
# =========================================
# Sentence: bīdiyalli nūrāru jana iddaru
# Translated Sentence: there were hundreds of people in the street
#   Word: bīdiyalli, POS: ['ADV'], Translation: there, Affix: {'prefix': 'bīdiy', 'suffix': ''}
#   Word: nūrāru, POS: ['NUM'], Translation: six, Affix: {'prefix': 'nūr', 'suffix': ''}
#   Word: jana, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: person, people, Affix: None
#   Word: iddaru, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: avanu sāvirāru rūpāyi kharcu māḍida
# Translated Sentence: he spent thousands of rupees
#   Word: avanu, POS: ['PRON'], Translation: he, Affix: None
#   Word: sāvirāru, POS: ['NOUN'], Translation: thousands, Affix: None
#   Word: rūpāyi, POS: None, Translation: None, Affix: None
#   Word: kharcu, POS: None, Translation: None, Affix: None
#   Word: māḍida, POS: ['INTJ', 'VERB', 'DET', 'NUM', 'VERB', 'NOUN', 'ADP', 'NOUN', 'AUX', 'ADV', 'ADJ'], Translation: please do The two following pairs of words are prosodically similar (a long sylla- ble followed by a short one), but whereas in the first word of both pairs the long syllable is long because the vowel is long, in the second word it is because of the doubled consonant, and this difference is heard in pronunciation:, Affix: {'prefix': '', 'suffix': 'da'}
# =========================================
# Sentence: hodedu, hoddu
# Translated Sentence: A few common verbs have special alternative abbreviated forms of the
#   Word: hodedu, POS: ['PART', 'VERB', 'ADP'], Translation: to put on (dress), Affix: {'prefix': '', 'suffix': 'du'}
#   Word: hoddu, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: nānu avarannu karakoṃḍu baruttēne
# Translated Sentence: I’ll bring them (along with me)
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: avarannu, POS: None, Translation: None, Affix: None
#   Word: karakoṃḍu, POS: None, Translation: None, Affix: None
#   Word: baruttēne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: nānu ā pustakagaḷannu tagoṃḍu baruttēne
# Translated Sentence: I’ll bring those books
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustakagaḷannu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷannu'}
#   Word: tagoṃḍu, POS: None, Translation: None, Affix: None
#   Word: baruttēne, POS: ['PART', 'VERB'], Translation: to come, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: nānu avarannu karakoṃḍu manege hōguttēne
# Translated Sentence: I’ll take them (persons) to my home
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: avarannu, POS: None, Translation: None, Affix: None
#   Word: karakoṃḍu, POS: None, Translation: None, Affix: None
#   Word: manege, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'ge'}
#   Word: hōguttēne, POS: ['PART', 'VERB'], Translation: to go, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: nānu ā pustakagaḷannu tagoṃḍu manege hōguttēne
# Translated Sentence: I’ll take those books home
#   Word: nānu, POS: ['PRON'], Translation: I, Affix: None
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: pustakagaḷannu, POS: ['NOUN'], Translation: book, Affix: {'prefix': '', 'suffix': 'gaḷannu'}
#   Word: tagoṃḍu, POS: None, Translation: None, Affix: None
#   Word: manege, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'ge'}
#   Word: hōguttēne, POS: ['PART', 'VERB'], Translation: to go, Affix: {'prefix': '', 'suffix': 'ttēne'}
# =========================================
# Sentence: Marada keḷage ēnide?
# Translated Sentence: What lies under the tree?
#   Word: marada, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: tree, wood, Affix: {'prefix': '', 'suffix': 'da'}
#   Word: keḷage, POS: ['ADP'], Translation: under, Affix: None
#   Word: ēnide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: {'prefix': 'ēn', 'suffix': ''}
# =========================================
# Sentence: ūṭa cennāgide.
# Translated Sentence: The meal tasted good.
#   Word: ūṭa, POS: [], Translation: (cooked) meal, Affix: None
#   Word: cennāgide, POS: ['AUX', 'ADJ'], Translation: is good, Affix: None
# =========================================
# Sentence: Maneya hattira kere ide.
# Translated Sentence: There is a water tank near the house.
#   Word: maneya, POS: ['NOUN'], Translation: house, Affix: {'prefix': '', 'suffix': 'ya'}
#   Word: hattira, POS: ['ADV', 'PUNCT', 'NOUN'], Translation: near; nearness, Affix: None
#   Word: kere, POS: ['NOUN', 'PUNCT', 'NOUN', 'NOUN'], Translation: tank, water reservoir, Affix: None
#   Word: ide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: None
# =========================================
# Sentence: Dēvara dayadiṃda namage oḷḷeyadu āguttade.
# Translated Sentence: By God’s grace good things happen to us.
#   Word: dēvara, POS: ['PROPN'], Translation: god, Affix: {'prefix': '', 'suffix': 'ra'}
#   Word: dayadiṃda, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: grace, mercy, Affix: {'prefix': '', 'suffix': 'diṃda'}
#   Word: namage, POS: ['PRON'], Translation: us (dative case), Affix: None
#   Word: oḷḷeyadu, POS: ['ADJ', 'NOUN'], Translation: good thing, Affix: None
#   Word: āguttade, POS: ['PART', 'VERB', 'PUNCT', 'VERB'], Translation: to become, occur, Affix: {'prefix': '', 'suffix': 'ttade'}
# =========================================
# Sentence: Tuṃba jana illi niṃtiddāre.
# Translated Sentence: Many people are standing here.
#   Word: tuṃba, POS: ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'], Translation: very, much, many, Affix: None
#   Word: jana, POS: ['NOUN', 'PUNCT', 'NOUN'], Translation: person, people, Affix: None
#   Word: illi, POS: ['ADV'], Translation: here, Affix: None
#   Word: niṃtiddāre, POS: ['PRON', 'VERB'], Translation: they stand, Affix: None
# =========================================
# Sentence: Nanna kelasa hēgide?
# Translated Sentence: How is my work?
#   Word: nanna, POS: ['PRON'], Translation: my, Affix: None
#   Word: kelasa, POS: ['NOUN'], Translation: work, Affix: None
#   Word: hēgide, POS: ['PRON', 'AUX', 'PUNCT', 'PRON', 'VERB'], Translation: it is, it exists, Affix: {'prefix': 'hēg', 'suffix': ''}
# =========================================
# Sentence: Bahaḷa aparūpavāgi baruttāre.
# Translated Sentence: They come here rarely.
#   Word: bahaḷa, POS: ['ADJ', 'PUNCT', 'ADJ', 'PUNCT', 'ADV'], Translation: much, many, very, Affix: None
#   Word: aparūpavāgi, POS: ['ADV'], Translation: rarely, Affix: None
#   Word: baruttāre, POS: ['PRON', 'VERB'], Translation: they come, Affix: None
# =========================================
# Sentence: ā kelasa māḍuvavaru yāvāgalū yaśasviyāguttāre.
# Translated Sentence: Those who do this work always become successful.
#   Word: ā, POS: None, Translation: None, Affix: None
#   Word: kelasa, POS: ['NOUN'], Translation: work, Affix: None
#   Word: māḍuvavaru, POS: ['PRON'], Translation: they (persons), Affix: {'prefix': 'māḍuv', 'suffix': ''}
#   Word: yāvāgalū, POS: ['ADV'], Translation: always, Affix: None
#   Word: yaśasviyāguttāre, POS: ['ADJ', 'PUNCT', 'ADJ'], Translation: glorious, successful, Affix: {'prefix': '', 'suffix': 'yāguttāre'}
# =========================================
# Sentence: Kannaḍa oṃdu haḷeya, suṃdaravāda bhāṣe; nīvu kalitare adannu tuṃba meccuviri.
# Translated Sentence: Kannada is an old, beautiful language; if you learn it, you will like it a lot.
#   Word: kannaḍa, POS: ['NOUN'], Translation: rice (cooked), Affix: {'prefix': 'k', 'suffix': 'ḍa'}
#   Word: oṃdu, POS: ['NUM', 'PUNCT', 'PRON'], Translation: one, a, Affix: None
#   Word: haḷeya, POS: ['ADJ'], Translation: old, Affix: None
#   Word: suṃdaravāda, POS: ['ADJ'], Translation: beautiful, Affix: {'prefix': '', 'suffix': 'vāda'}
#   Word: bhāṣe;, POS: ['NOUN'], Translation: language, Affix: {'prefix': '', 'suffix': ';'}
#   Word: nīvu, POS: ['PRON'], Translation: you (plural / honorific), Affix: None
#   Word: kalitare, POS: ['SCONJ', 'X', 'NUM', 'PUNCT', 'VERB'], Translation: if [one] learns, Affix: None
#   Word: adannu, POS: ['PRON'], Translation: that (accusative case), Affix: None
#   Word: tuṃba, POS: ['ADV', 'PUNCT', 'ADJ', 'PUNCT', 'ADJ'], Translation: very, much, many, Affix: None
#   Word: meccuviri, POS: ['PRON', 'AUX', 'VERB'], Translation: you will like, Affix: None
# =========================================
# Sentence: Lesson 4
# Translated Sentence: 1. This is the door of my house. 2. That is the horn of a cow. 3. The tip of the horn is not sharp. 4. My book is there. 5. The colour of the book is red. 6. The colour of your books is yellow. 7. Their colour is
#   Word: lesson, POS: None, Translation: None, Affix: None
#   Word: 4, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: Lesson 12
# Translated Sentence: 1. Gaṇēśa! Have you gone home? 2. He was tired and went to sleep. 3. That girl sang elegantly. 4. That boy spoke coarsely. 5. He scolded me badly and went away. 6. She saw that and laughed happily. 7. Read this lesson and ask questions. 8. The neighbours went on travel yesterday and will return next month. 9. Did he really say so? 10. Try hard and read these sentences. 11. Please speak a bit quickly. 12. He
#   Word: lesson, POS: None, Translation: None, Affix: None
#   Word: 12, POS: None, Translation: None, Affix: None
# =========================================
# Sentence: miliṭari hōṭalu
# Translated Sentence: non-vegetarian restaurant
#   Word: miliṭari, POS: ['NOUN'], Translation: military, Affix: None
#   Word: hōṭalu, POS: ['NOUN'], Translation: restaurant, Affix: None
# =========================================

# %%
# Further splitting of prefix and suffix TODO:
for result in results:
    sentence, translated_sentence, pos_info = result
    for word, info in pos_info.items():
        if info['affix'] is not None:
            prefix = info['affix']['prefix']
            suffix = info['affix']['suffix']
            
            # Find suffxies
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Further splitting of prefix and suffix TODO:
# ----> 2 for result in results:
#       3     sentence, translated_sentence, pos_info = result
#       4     for word, info in pos_info.items():
#
# NameError: name 'results' is not defined

# %% [markdown]
# # Get list of common affixes and their frequencies, along with the different words that contain them

# %%
from collections import defaultdict

# Words and suffixes detected
words_with_suffixes = defaultdict(list)
words_with_prefixes = defaultdict(list)
for result in results:
    sentence, translated_sentence, pos_info = result
    for word, info in pos_info.items():
        if info['affix'] is not None:
            prefix = info['affix']['prefix']
            suffix = info['affix']['suffix']
            
            # Find prefixes
            if prefix:
                words_with_prefixes[prefix].append(word)
            
            # Find suffixes
            if suffix:
                words_with_suffixes[suffix].append(word)


words_with_suffixes = dict(words_with_suffixes)

#words_with_prefixes = dict(words_with_prefixes)

words_with_suffixes

# TODO: I KNOW KANNADA HAS SUFFIXES, BUT HOW DO YOU DETECT THAT IN THE LANGUAGE?
# Out:
# {'gaḷu': ['pustakagaḷu',
#   'maragaḷu',
#   'manegaḷu',
#   'gurugaḷu',
#   'koṃbugaḷu',
#   'maragaḷu',
#   'pustakagaḷu',
#   'pustakagaḷu',
#   'maragaḷu',
#   'maragaḷu',
#   'pustakagaḷu',
#   'pustakagaḷu',
#   'pustakagaḷu',
#   'haṇṇugaḷu',
#   'maragaḷu',
#   'haṇṇugaḷu',
#   'cīlagaḷu',
#   'pustakagaḷu',
#   'vidyārthigaḷu',
#   'pustakagaḷu'],
#  'ru': ['purōhitaru',
#   'raitaru',
#   'raitaru',
#   'huḍugaru',
#   'huḍugaru',
#   'tammaṃdiru',
#   'janaru',
#   'janaru'],
#  'yā': ['vidyārthiyā', 'vidyārthiniyā'],
#  'vā': ['maravā', 'pustakavā', 'pustakavā', 'pustakavā', 'maravā'],
#  'valla': ['pustakavalla', 'maravalla', 'iṣṭavalla'],
#  '-v-alla': ['mara-v-alla'],
#  '-y-alla': ['huḍugi-y-alla'],
#  '-v-illa': ['mara-v-illa'],
#  '-y-illa': ['huḍugi-y-illa'],
#  'mogga': ['śivamogga'],
#  'ddīrā': ['cennāgiddīrā'],
#  ')': ['(nānu)', '(aṣṭu)', '(aṣṭu)'],
#  'rājarē': ['gururājarē'],
#  'navarē': ['rāmappanavarē',
#   'sītammanavarē',
#   'sītammanavarē',
#   'rāmayyanavarē'],
#  'ddēne': ['cennāgiddēne',
#   'cennāgiddēne',
#   'cennāgiddēne',
#   'cennāgiddēne',
#   'māḍiddēne',
#   'hōgiddēne'],
#  'yavarā': ['maneyavarā'],
#  'ttēne': ['baruttēne',
#   'māḍuttēne',
#   'mugisuttēne',
#   'baruttēne',
#   'baredukoḷḷuttēne',
#   'baruttēne',
#   'baruttēne',
#   'hōguttēne',
#   'hōguttēne'],
#  'vina': ['hasuvina'],
#  'ttāne': ['ōduttāne',
#   'baruttāne',
#   'ōduttāne',
#   'baruttāne',
#   'hōguttāne',
#   'baruttāne',
#   'hōguttāne',
#   'hōguttāne'],
#  'vanu': ['ōduvanu'],
#  'vudilla': ['baruvudilla',
#   'māḍuvudilla',
#   'māḍuvudilla',
#   'māḍuvudilla',
#   'māḍuvudilla',
#   'māḍuvudilla',
#   'māḍuvudilla',
#   'baruvudilla',
#   'baruvudilla',
#   'māḍuvudilla',
#   'māḍuvudilla',
#   'māḍuvudilla',
#   'baruvudilla'],
#  'yaru': ['huḍugiyaru', 'huḍugiyaru', 'huḍugiyaru'],
#  'nannu': ['huḍuganannu',
#   'manuṣyanannu',
#   'huḍuganannu',
#   'manuṣyanannu',
#   'maganannu'],
#  'yuttāne': ['hoḍeyuttāne'],
#  'nige': ['huḍuganige', 'manuṣyanige'],
#  'vannu': ['viṣayavannu',
#   'saṃgītavannu',
#   'pustakavannu',
#   'pustakavannu',
#   'pustakavannu',
#   'kelasavannu',
#   'pustakavannu',
#   'pustakavannu',
#   'pustakavannu',
#   'hūvannu',
#   'pustakavannu',
#   'pustakavannu',
#   'kelasavannu',
#   'patravannu',
#   'pustakavannu',
#   'patravannu',
#   'patravannu',
#   'pustakavannu',
#   'patravannu',
#   'pustakavannu',
#   'patravannu',
#   'pustakavannu',
#   'pustakavannu'],
#  'kke': ['ūṭakke'],
#  'ge': ['manege',
#   'avarige',
#   'manege',
#   'manege',
#   'manege',
#   'manege',
#   'manege',
#   'manege',
#   'avarige',
#   'bagege',
#   'kaḍege',
#   'manege',
#   'manege'],
#  'yiṃda': ['kaiyiṃda', 'kiviyiṃda'],
#  'daru': ['baredaru', 'baredaru', 'baredaru', 'baredaru', 'māḍidaru'],
#  'varu': ['kēḷuvaru', 'cikkavaru'],
#  'niṃda': ['kalliniṃda'],
#  'yoḷaginiṃda': ['maneyoḷaginiṃda'],
#  'yoḷakke': ['maneyoḷakke'],
#  'kkōskara': ['ūṭakkōskara'],
#  'villa': ['samācāravilla', 'sādhyavilla', 'sādhyavilla'],
#  'ttīri': ['tagoḷḷuttīri', 'hōguttīri'],
#  'gaḷalla': ['maragaḷalla'],
#  'nalla': ['raitanalla'],
#  'ralla': ['raitaralla', 'raitaralla'],
#  'vē': ['maravē'],
#  'vō': ['maravō'],
#  'rannu': ['huḍugarannu'],
#  'vāda': ['suṃdaravāda', 'suṃdaravāda', 'suṃdaravāda'],
#  '-v-āda': ['kliṣṭa-v-āda'],
#  'ya': ['maneya', 'bhāṣeya', 'maneya'],
#  'vu': ['nōḍidevu'],
#  'du': ['nannadu', 'doḍḍadu', 'takkadu', 'hodedu'],
#  'da': ['pakkada',
#   'māḍida',
#   'māḍida',
#   'bareda',
#   'bareda',
#   'māḍida',
#   'māḍida',
#   'marada'],
#  'giṃta': ['kurcigiṃta', 'ellarigiṃta'],
#  'de': ['ellide', 'hōgide'],
#  'ddāḷō': ['māḍiddāḷō', 'māḍiddāḷō'],
#  'ttī': ['māḍuttī'],
#  'nu': ['malagidenu',
#   'nōḍidenu',
#   'nōḍidenu',
#   'yōcisidenu',
#   'yōcisidenu',
#   'nōḍidenu',
#   'nōḍidenu',
#   'hēḷidenu'],
#  'denu': ['māḍidenu', 'māḍidenu'],
#  'venu': ['ōdiruvenu', 'hāḍuvenu', 'nōḍuvenu', 'māḍuvenu', 'biḍuvenu'],
#  'dāgi': ['doḍḍadāgi', 'keṭṭadāgi'],
#  'dide': ['beḷedide'],
#  'ddāne': ['māḍiddāne'],
#  'vāgi': ['krūravāgi', 'suṃdaravāgi'],
#  'ddāḷe': ['māḍiddāḷe'],
#  'yāgi': ['lēkhakiyāgi'],
#  'dalli': ['sammēḷanadalli', 'dēvasthānadalli', 'saṃgrahālayadalli'],
#  'vahisidaḷu': ['bhāgavahisidaḷu'],
#  'nāgi': ['purōhitanāgi'],
#  'danu': ['māḍidanu'],
#  'ne': ['bēgane'],
#  'tta': ['māḍutta'],
#  'ttiddēne': ['ōduttiddēne'],
#  'ttiddenu': ['ōduttiddenu', 'baruttiddenu'],
#  'ttiruvenu': ['ōduttiruvenu'],
#  'sidenu': ['māḍisidenu'],
#  'nnu': ['tappannu',
#   'nannannu',
#   'nannannu',
#   'nannannu',
#   'ivarannu',
#   'ellarannu'],
#  'isu': ['arthaisu'],
#  'visu': ['arthavisu'],
#  'va': ['hēḷuva', 'hēḷuva', 'māḍuva', 'iruva'],
#  'yuva': ['bareyuva', 'bareyuva', 'naḍeyuva', 'naḍeyuva'],
#  'yuttēne': ['kareyuttēne', 'kareyuttēne'],
#  'yuvavanannu': ['naḍeyuvavanannu'],
#  'dannu': ['araḷidudannu', 'araḷidudannu'],
#  'nō': ['nōḍidenō'],
#  'ttānō': ['baruttānō'],
#  'vudu': ['māḍuvudu', 'māḍuvudu', 'māḍuvudu', 'māḍuvudu', 'māḍuvudu'],
#  'lla': ['cennāgilla', 'māḍilla', 'baralilla'],
#  'yuvudu': ['bareyuvudu',
#   'bareyuvudu',
#   'bareyuvudu',
#   'bareyuvudu',
#   'bareyuvudu'],
#  'kate': ['saṇṇakate'],
#  'vudakke': ['koḷḷuvudakke'],
#  'ḍa': ['kannaḍa', 'kannaḍa'],
#  'yalu': ['kaliyalu', 'bareyalu', 'bareyalu', 'bareyalu'],
#  'yuvudilla': ['bareyuvudilla', 'bareyuvudilla', 'bareyuvudilla'],
#  '-': ['bare-', 'māva-'],
#  'yuttalilla': ['bareyuttalilla'],
#  'yalilla': ['bareyalilla',
#   'bareyalilla',
#   'bareyalilla',
#   'bareyalilla',
#   'bareyalilla',
#   'bareyalilla'],
#  'dilla': ['baredilla', 'baredilla'],
#  'yāgiral-': ['vidyārthiyāgiral-'],
#  'yāgiru-': ['vidyārthiyāgiru-'],
#  'yāgiruvenu': ['vidyārthiyāgiruvenu'],
#  'vāgide': ['kaṣṭavāgide'],
#  'ttu': ['bēkāgittu'],
#  'ruvudu': ['bēkāgiruvudu'],
#  'ttade': ['bēkāguttade',
#   'māḍalpaḍuttade',
#   'māḍalpaḍuttade',
#   'māḍalāguttade',
#   'baruttade',
#   'āguttade'],
#  'ttēne”': ['baruttēne”'],
#  '”': ['cennāgide”'],
#  'daḷu': ['hedaridaḷu', 'hedaridaḷu', 'hedaridaḷu'],
#  'vudillaveṃdu': ['baruvudillaveṃdu'],
#  'veṃdu': ['kaṣṭaveṃdu'],
#  'ṃdu': ['hōgabēkeṃdu'],
#  'lli': ['nimmalli'],
#  'vuḷḷa': ['haṇavuḷḷa'],
#  'yuḷḷa': ['buddhiyuḷḷa'],
#  'villada': ['haṇavillada'],
#  'gaḷannu': ['pustakagaḷannu',
#   'haṇṇugaḷannu',
#   'patrikegaḷannu',
#   'citragaḷannu',
#   'pustakagaḷannu',
#   'pustakagaḷannu'],
#  'ddare': ['māḍiddare'],
#  'yāguttade': ['caḷiyāguttade'],
#  'yitu': ['mugiyitu'],
#  'yō': ['elliyō'],
#  'yādarū': ['elliyādarū'],
#  'daṃte': ['māḍidaṃte'],
#  'dahāge': ['māḍidahāge'],
#  'vaṃte': ['hēḷuvaṃte'],
#  ']': ['[maṃdi]'],
#  'gaḷellarannū': ['vidyārthigaḷellarannū'],
#  'gaḷannella': ['haṇṇugaḷannella'],
#  'dukoṃḍiddāne': ['tiḷidukoṃḍiddāne'],
#  'tiddāḷe': ['maretiddāḷe'],
#  'dukoṃḍiddīyā': ['tiḷidukoṃḍiddīyā'],
#  'dukoṃḍiddēne': ['tegedukoṃḍiddēne'],
#  'dukoṃḍu': ['tegedukoṃḍu', 'tegedukoṃḍu'],
#  'dukoṃḍiddīrā': ['karedukoṃḍiddīrā'],
#  'dukoḍuttēne': ['baredukoḍuttēne'],
#  'biḍu': ['māḍibiḍu'],
#  'dubiḍuttāre': ['baredubiḍuttāre'],
#  'ttāre': ['biḍuttāre'],
#  'ri': ['balliri'],
#  'nū': ['snēhitanū'],
#  'li': ['āgali'],
#  'vāgali': ['guruvāravāgali', 'śukravāravāgali'],
#  'ttadeyā': ['baruttadeyā'],
#  'vide': ['sādhyavide'],
#  'ttave': ['kāṇisuttave'],
#  'ṃda': ['nālkariṃda', 'nālkariṃda', 'ippattariṃda'],
#  'su': ['bhāgisu'],
#  'davarannu': ['uḷidavarannu'],
#  'hisiri': ['kaḷuhisiri'],
#  'tu': ['sāgitu'],
#  'gū': ['ibbarigū'],
#  've': ['cennāgive'],
#  'ra': ['dēvara'],
#  'diṃda': ['dayadiṃda'],
#  'yāguttāre': ['yaśasviyāguttāre'],
#  ';': ['bhāṣe;']}

# %%
suffix_counts = defaultdict(lambda: defaultdict(int))   # suffix → {stem: freq}
# For each suffix, the dictionary will contain a dict counting stems that use it
for suffix, words in words_with_suffixes.items():
    for word in words:
        # Extract the stem by removing the suffix
        stem = word[:-len(suffix)] if len(suffix) > 0 else word
        suffix_counts[suffix][stem] += 1

# %%
suffix_counts = dict(suffix_counts)
# Display the suffix counts
for suffix, stems in suffix_counts.items():
    print(f"Suffix: {suffix}")
    for stem, freq in stems.items():
        print(f"  Stem: {stem}, Frequency: {freq}")
    print("=========================================")
# Out:
# Suffix: gaḷu
#   Stem: pustaka, Frequency: 8
#   Stem: mara, Frequency: 5
#   Stem: mane, Frequency: 1
#   Stem: guru, Frequency: 1
#   Stem: koṃbu, Frequency: 1
#   Stem: haṇṇu, Frequency: 2
#   Stem: cīla, Frequency: 1
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: ru
#   Stem: purōhita, Frequency: 1
#   Stem: raita, Frequency: 2
#   Stem: huḍuga, Frequency: 2
#   Stem: tammaṃdi, Frequency: 1
#   Stem: jana, Frequency: 2
# =========================================
# Suffix: yā
#   Stem: vidyārthi, Frequency: 1
#   Stem: vidyārthini, Frequency: 1
# =========================================
# Suffix: vā
#   Stem: mara, Frequency: 2
#   Stem: pustaka, Frequency: 3
# =========================================
# Suffix: valla
#   Stem: pustaka, Frequency: 1
#   Stem: mara, Frequency: 1
#   Stem: iṣṭa, Frequency: 1
# =========================================
# Suffix: -v-alla
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: -y-alla
#   Stem: huḍugi, Frequency: 1
# =========================================
# Suffix: -v-illa
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: -y-illa
#   Stem: huḍugi, Frequency: 1
# =========================================
# Suffix: mogga
#   Stem: śiva, Frequency: 1
# =========================================
# Suffix: ddīrā
#   Stem: cennāgi, Frequency: 1
# =========================================
# Suffix: )
#   Stem: (nānu, Frequency: 1
#   Stem: (aṣṭu, Frequency: 2
# =========================================
# Suffix: rājarē
#   Stem: guru, Frequency: 1
# =========================================
# Suffix: navarē
#   Stem: rāmappa, Frequency: 1
#   Stem: sītamma, Frequency: 2
#   Stem: rāmayya, Frequency: 1
# =========================================
# Suffix: ddēne
#   Stem: cennāgi, Frequency: 4
#   Stem: māḍi, Frequency: 1
#   Stem: hōgi, Frequency: 1
# =========================================
# Suffix: yavarā
#   Stem: mane, Frequency: 1
# =========================================
# Suffix: ttēne
#   Stem: baru, Frequency: 4
#   Stem: māḍu, Frequency: 1
#   Stem: mugisu, Frequency: 1
#   Stem: baredukoḷḷu, Frequency: 1
#   Stem: hōgu, Frequency: 2
# =========================================
# Suffix: vina
#   Stem: hasu, Frequency: 1
# =========================================
# Suffix: ttāne
#   Stem: ōdu, Frequency: 2
#   Stem: baru, Frequency: 3
#   Stem: hōgu, Frequency: 3
# =========================================
# Suffix: vanu
#   Stem: ōdu, Frequency: 1
# =========================================
# Suffix: vudilla
#   Stem: baru, Frequency: 4
#   Stem: māḍu, Frequency: 9
# =========================================
# Suffix: yaru
#   Stem: huḍugi, Frequency: 3
# =========================================
# Suffix: nannu
#   Stem: huḍuga, Frequency: 2
#   Stem: manuṣya, Frequency: 2
#   Stem: maga, Frequency: 1
# =========================================
# Suffix: yuttāne
#   Stem: hoḍe, Frequency: 1
# =========================================
# Suffix: nige
#   Stem: huḍuga, Frequency: 1
#   Stem: manuṣya, Frequency: 1
# =========================================
# Suffix: vannu
#   Stem: viṣaya, Frequency: 1
#   Stem: saṃgīta, Frequency: 1
#   Stem: pustaka, Frequency: 13
#   Stem: kelasa, Frequency: 2
#   Stem: hū, Frequency: 1
#   Stem: patra, Frequency: 5
# =========================================
# Suffix: kke
#   Stem: ūṭa, Frequency: 1
# =========================================
# Suffix: ge
#   Stem: mane, Frequency: 9
#   Stem: avari, Frequency: 2
#   Stem: bage, Frequency: 1
#   Stem: kaḍe, Frequency: 1
# =========================================
# Suffix: yiṃda
#   Stem: kai, Frequency: 1
#   Stem: kivi, Frequency: 1
# =========================================
# Suffix: daru
#   Stem: bare, Frequency: 4
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: varu
#   Stem: kēḷu, Frequency: 1
#   Stem: cikka, Frequency: 1
# =========================================
# Suffix: niṃda
#   Stem: kalli, Frequency: 1
# =========================================
# Suffix: yoḷaginiṃda
#   Stem: mane, Frequency: 1
# =========================================
# Suffix: yoḷakke
#   Stem: mane, Frequency: 1
# =========================================
# Suffix: kkōskara
#   Stem: ūṭa, Frequency: 1
# =========================================
# Suffix: villa
#   Stem: samācāra, Frequency: 1
#   Stem: sādhya, Frequency: 2
# =========================================
# Suffix: ttīri
#   Stem: tagoḷḷu, Frequency: 1
#   Stem: hōgu, Frequency: 1
# =========================================
# Suffix: gaḷalla
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: nalla
#   Stem: raita, Frequency: 1
# =========================================
# Suffix: ralla
#   Stem: raita, Frequency: 2
# =========================================
# Suffix: vē
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: vō
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: rannu
#   Stem: huḍuga, Frequency: 1
# =========================================
# Suffix: vāda
#   Stem: suṃdara, Frequency: 3
# =========================================
# Suffix: -v-āda
#   Stem: kliṣṭa, Frequency: 1
# =========================================
# Suffix: ya
#   Stem: mane, Frequency: 2
#   Stem: bhāṣe, Frequency: 1
# =========================================
# Suffix: vu
#   Stem: nōḍide, Frequency: 1
# =========================================
# Suffix: du
#   Stem: nanna, Frequency: 1
#   Stem: doḍḍa, Frequency: 1
#   Stem: takka, Frequency: 1
#   Stem: hode, Frequency: 1
# =========================================
# Suffix: da
#   Stem: pakka, Frequency: 1
#   Stem: māḍi, Frequency: 4
#   Stem: bare, Frequency: 2
#   Stem: mara, Frequency: 1
# =========================================
# Suffix: giṃta
#   Stem: kurci, Frequency: 1
#   Stem: ellari, Frequency: 1
# =========================================
# Suffix: de
#   Stem: elli, Frequency: 1
#   Stem: hōgi, Frequency: 1
# =========================================
# Suffix: ddāḷō
#   Stem: māḍi, Frequency: 2
# =========================================
# Suffix: ttī
#   Stem: māḍu, Frequency: 1
# =========================================
# Suffix: nu
#   Stem: malagide, Frequency: 1
#   Stem: nōḍide, Frequency: 4
#   Stem: yōciside, Frequency: 2
#   Stem: hēḷide, Frequency: 1
# =========================================
# Suffix: denu
#   Stem: māḍi, Frequency: 2
# =========================================
# Suffix: venu
#   Stem: ōdiru, Frequency: 1
#   Stem: hāḍu, Frequency: 1
#   Stem: nōḍu, Frequency: 1
#   Stem: māḍu, Frequency: 1
#   Stem: biḍu, Frequency: 1
# =========================================
# Suffix: dāgi
#   Stem: doḍḍa, Frequency: 1
#   Stem: keṭṭa, Frequency: 1
# =========================================
# Suffix: dide
#   Stem: beḷe, Frequency: 1
# =========================================
# Suffix: ddāne
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: vāgi
#   Stem: krūra, Frequency: 1
#   Stem: suṃdara, Frequency: 1
# =========================================
# Suffix: ddāḷe
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: yāgi
#   Stem: lēkhaki, Frequency: 1
# =========================================
# Suffix: dalli
#   Stem: sammēḷana, Frequency: 1
#   Stem: dēvasthāna, Frequency: 1
#   Stem: saṃgrahālaya, Frequency: 1
# =========================================
# Suffix: vahisidaḷu
#   Stem: bhāga, Frequency: 1
# =========================================
# Suffix: nāgi
#   Stem: purōhita, Frequency: 1
# =========================================
# Suffix: danu
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: ne
#   Stem: bēga, Frequency: 1
# =========================================
# Suffix: tta
#   Stem: māḍu, Frequency: 1
# =========================================
# Suffix: ttiddēne
#   Stem: ōdu, Frequency: 1
# =========================================
# Suffix: ttiddenu
#   Stem: ōdu, Frequency: 1
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: ttiruvenu
#   Stem: ōdu, Frequency: 1
# =========================================
# Suffix: sidenu
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: nnu
#   Stem: tappa, Frequency: 1
#   Stem: nanna, Frequency: 3
#   Stem: ivara, Frequency: 1
#   Stem: ellara, Frequency: 1
# =========================================
# Suffix: isu
#   Stem: artha, Frequency: 1
# =========================================
# Suffix: visu
#   Stem: artha, Frequency: 1
# =========================================
# Suffix: va
#   Stem: hēḷu, Frequency: 2
#   Stem: māḍu, Frequency: 1
#   Stem: iru, Frequency: 1
# =========================================
# Suffix: yuva
#   Stem: bare, Frequency: 2
#   Stem: naḍe, Frequency: 2
# =========================================
# Suffix: yuttēne
#   Stem: kare, Frequency: 2
# =========================================
# Suffix: yuvavanannu
#   Stem: naḍe, Frequency: 1
# =========================================
# Suffix: dannu
#   Stem: araḷidu, Frequency: 2
# =========================================
# Suffix: nō
#   Stem: nōḍide, Frequency: 1
# =========================================
# Suffix: ttānō
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: vudu
#   Stem: māḍu, Frequency: 5
# =========================================
# Suffix: lla
#   Stem: cennāgi, Frequency: 1
#   Stem: māḍi, Frequency: 1
#   Stem: barali, Frequency: 1
# =========================================
# Suffix: yuvudu
#   Stem: bare, Frequency: 5
# =========================================
# Suffix: kate
#   Stem: saṇṇa, Frequency: 1
# =========================================
# Suffix: vudakke
#   Stem: koḷḷu, Frequency: 1
# =========================================
# Suffix: ḍa
#   Stem: kanna, Frequency: 2
# =========================================
# Suffix: yalu
#   Stem: kali, Frequency: 1
#   Stem: bare, Frequency: 3
# =========================================
# Suffix: yuvudilla
#   Stem: bare, Frequency: 3
# =========================================
# Suffix: -
#   Stem: bare, Frequency: 1
#   Stem: māva, Frequency: 1
# =========================================
# Suffix: yuttalilla
#   Stem: bare, Frequency: 1
# =========================================
# Suffix: yalilla
#   Stem: bare, Frequency: 6
# =========================================
# Suffix: dilla
#   Stem: bare, Frequency: 2
# =========================================
# Suffix: yāgiral-
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: yāgiru-
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: yāgiruvenu
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: vāgide
#   Stem: kaṣṭa, Frequency: 1
# =========================================
# Suffix: ttu
#   Stem: bēkāgi, Frequency: 1
# =========================================
# Suffix: ruvudu
#   Stem: bēkāgi, Frequency: 1
# =========================================
# Suffix: ttade
#   Stem: bēkāgu, Frequency: 1
#   Stem: māḍalpaḍu, Frequency: 2
#   Stem: māḍalāgu, Frequency: 1
#   Stem: baru, Frequency: 1
#   Stem: āgu, Frequency: 1
# =========================================
# Suffix: ttēne”
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: ”
#   Stem: cennāgide, Frequency: 1
# =========================================
# Suffix: daḷu
#   Stem: hedari, Frequency: 3
# =========================================
# Suffix: vudillaveṃdu
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: veṃdu
#   Stem: kaṣṭa, Frequency: 1
# =========================================
# Suffix: ṃdu
#   Stem: hōgabēke, Frequency: 1
# =========================================
# Suffix: lli
#   Stem: nimma, Frequency: 1
# =========================================
# Suffix: vuḷḷa
#   Stem: haṇa, Frequency: 1
# =========================================
# Suffix: yuḷḷa
#   Stem: buddhi, Frequency: 1
# =========================================
# Suffix: villada
#   Stem: haṇa, Frequency: 1
# =========================================
# Suffix: gaḷannu
#   Stem: pustaka, Frequency: 3
#   Stem: haṇṇu, Frequency: 1
#   Stem: patrike, Frequency: 1
#   Stem: citra, Frequency: 1
# =========================================
# Suffix: ddare
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: yāguttade
#   Stem: caḷi, Frequency: 1
# =========================================
# Suffix: yitu
#   Stem: mugi, Frequency: 1
# =========================================
# Suffix: yō
#   Stem: elli, Frequency: 1
# =========================================
# Suffix: yādarū
#   Stem: elli, Frequency: 1
# =========================================
# Suffix: daṃte
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: dahāge
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: vaṃte
#   Stem: hēḷu, Frequency: 1
# =========================================
# Suffix: ]
#   Stem: [maṃdi, Frequency: 1
# =========================================
# Suffix: gaḷellarannū
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Suffix: gaḷannella
#   Stem: haṇṇu, Frequency: 1
# =========================================
# Suffix: dukoṃḍiddāne
#   Stem: tiḷi, Frequency: 1
# =========================================
# Suffix: tiddāḷe
#   Stem: mare, Frequency: 1
# =========================================
# Suffix: dukoṃḍiddīyā
#   Stem: tiḷi, Frequency: 1
# =========================================
# Suffix: dukoṃḍiddēne
#   Stem: tege, Frequency: 1
# =========================================
# Suffix: dukoṃḍu
#   Stem: tege, Frequency: 2
# =========================================
# Suffix: dukoṃḍiddīrā
#   Stem: kare, Frequency: 1
# =========================================
# Suffix: dukoḍuttēne
#   Stem: bare, Frequency: 1
# =========================================
# Suffix: biḍu
#   Stem: māḍi, Frequency: 1
# =========================================
# Suffix: dubiḍuttāre
#   Stem: bare, Frequency: 1
# =========================================
# Suffix: ttāre
#   Stem: biḍu, Frequency: 1
# =========================================
# Suffix: ri
#   Stem: balli, Frequency: 1
# =========================================
# Suffix: nū
#   Stem: snēhita, Frequency: 1
# =========================================
# Suffix: li
#   Stem: āga, Frequency: 1
# =========================================
# Suffix: vāgali
#   Stem: guruvāra, Frequency: 1
#   Stem: śukravāra, Frequency: 1
# =========================================
# Suffix: ttadeyā
#   Stem: baru, Frequency: 1
# =========================================
# Suffix: vide
#   Stem: sādhya, Frequency: 1
# =========================================
# Suffix: ttave
#   Stem: kāṇisu, Frequency: 1
# =========================================
# Suffix: ṃda
#   Stem: nālkari, Frequency: 2
#   Stem: ippattari, Frequency: 1
# =========================================
# Suffix: su
#   Stem: bhāgi, Frequency: 1
# =========================================
# Suffix: davarannu
#   Stem: uḷi, Frequency: 1
# =========================================
# Suffix: hisiri
#   Stem: kaḷu, Frequency: 1
# =========================================
# Suffix: tu
#   Stem: sāgi, Frequency: 1
# =========================================
# Suffix: gū
#   Stem: ibbari, Frequency: 1
# =========================================
# Suffix: ve
#   Stem: cennāgi, Frequency: 1
# =========================================
# Suffix: ra
#   Stem: dēva, Frequency: 1
# =========================================
# Suffix: diṃda
#   Stem: daya, Frequency: 1
# =========================================
# Suffix: yāguttāre
#   Stem: yaśasvi, Frequency: 1
# =========================================
# Suffix: ;
#   Stem: bhāṣe, Frequency: 1
# =========================================

# %%
# Retain productive suffixes
productive_suffixes = {suffix: stems for suffix, stems in suffix_counts.items() if len(stems) > 1}

# Display productive suffixes
for suffix, stems in productive_suffixes.items():
    print(f"Productive Suffix: {suffix}")
    for stem, freq in stems.items():
        print(f"  Stem: {stem}, Frequency: {freq}")
    print("=========================================")
# Out:
# Productive Suffix: gaḷu
#   Stem: pustaka, Frequency: 8
#   Stem: mara, Frequency: 5
#   Stem: mane, Frequency: 1
#   Stem: guru, Frequency: 1
#   Stem: koṃbu, Frequency: 1
#   Stem: haṇṇu, Frequency: 2
#   Stem: cīla, Frequency: 1
#   Stem: vidyārthi, Frequency: 1
# =========================================
# Productive Suffix: ru
#   Stem: purōhita, Frequency: 1
#   Stem: raita, Frequency: 2
#   Stem: huḍuga, Frequency: 2
#   Stem: tammaṃdi, Frequency: 1
#   Stem: jana, Frequency: 2
# =========================================
# Productive Suffix: yā
#   Stem: vidyārthi, Frequency: 1
#   Stem: vidyārthini, Frequency: 1
# =========================================
# Productive Suffix: vā
#   Stem: mara, Frequency: 2
#   Stem: pustaka, Frequency: 3
# =========================================
# Productive Suffix: valla
#   Stem: pustaka, Frequency: 1
#   Stem: mara, Frequency: 1
#   Stem: iṣṭa, Frequency: 1
# =========================================
# Productive Suffix: )
#   Stem: (nānu, Frequency: 1
#   Stem: (aṣṭu, Frequency: 2
# =========================================
# Productive Suffix: navarē
#   Stem: rāmappa, Frequency: 1
#   Stem: sītamma, Frequency: 2
#   Stem: rāmayya, Frequency: 1
# =========================================
# Productive Suffix: ddēne
#   Stem: cennāgi, Frequency: 4
#   Stem: māḍi, Frequency: 1
#   Stem: hōgi, Frequency: 1
# =========================================
# Productive Suffix: ttēne
#   Stem: baru, Frequency: 4
#   Stem: māḍu, Frequency: 1
#   Stem: mugisu, Frequency: 1
#   Stem: baredukoḷḷu, Frequency: 1
#   Stem: hōgu, Frequency: 2
# =========================================
# Productive Suffix: ttāne
#   Stem: ōdu, Frequency: 2
#   Stem: baru, Frequency: 3
#   Stem: hōgu, Frequency: 3
# =========================================
# Productive Suffix: vudilla
#   Stem: baru, Frequency: 4
#   Stem: māḍu, Frequency: 9
# =========================================
# Productive Suffix: nannu
#   Stem: huḍuga, Frequency: 2
#   Stem: manuṣya, Frequency: 2
#   Stem: maga, Frequency: 1
# =========================================
# Productive Suffix: nige
#   Stem: huḍuga, Frequency: 1
#   Stem: manuṣya, Frequency: 1
# =========================================
# Productive Suffix: vannu
#   Stem: viṣaya, Frequency: 1
#   Stem: saṃgīta, Frequency: 1
#   Stem: pustaka, Frequency: 13
#   Stem: kelasa, Frequency: 2
#   Stem: hū, Frequency: 1
#   Stem: patra, Frequency: 5
# =========================================
# Productive Suffix: ge
#   Stem: mane, Frequency: 9
#   Stem: avari, Frequency: 2
#   Stem: bage, Frequency: 1
#   Stem: kaḍe, Frequency: 1
# =========================================
# Productive Suffix: yiṃda
#   Stem: kai, Frequency: 1
#   Stem: kivi, Frequency: 1
# =========================================
# Productive Suffix: daru
#   Stem: bare, Frequency: 4
#   Stem: māḍi, Frequency: 1
# =========================================
# Productive Suffix: varu
#   Stem: kēḷu, Frequency: 1
#   Stem: cikka, Frequency: 1
# =========================================
# Productive Suffix: villa
#   Stem: samācāra, Frequency: 1
#   Stem: sādhya, Frequency: 2
# =========================================
# Productive Suffix: ttīri
#   Stem: tagoḷḷu, Frequency: 1
#   Stem: hōgu, Frequency: 1
# =========================================
# Productive Suffix: ya
#   Stem: mane, Frequency: 2
#   Stem: bhāṣe, Frequency: 1
# =========================================
# Productive Suffix: du
#   Stem: nanna, Frequency: 1
#   Stem: doḍḍa, Frequency: 1
#   Stem: takka, Frequency: 1
#   Stem: hode, Frequency: 1
# =========================================
# Productive Suffix: da
#   Stem: pakka, Frequency: 1
#   Stem: māḍi, Frequency: 4
#   Stem: bare, Frequency: 2
#   Stem: mara, Frequency: 1
# =========================================
# Productive Suffix: giṃta
#   Stem: kurci, Frequency: 1
#   Stem: ellari, Frequency: 1
# =========================================
# Productive Suffix: de
#   Stem: elli, Frequency: 1
#   Stem: hōgi, Frequency: 1
# =========================================
# Productive Suffix: nu
#   Stem: malagide, Frequency: 1
#   Stem: nōḍide, Frequency: 4
#   Stem: yōciside, Frequency: 2
#   Stem: hēḷide, Frequency: 1
# =========================================
# Productive Suffix: venu
#   Stem: ōdiru, Frequency: 1
#   Stem: hāḍu, Frequency: 1
#   Stem: nōḍu, Frequency: 1
#   Stem: māḍu, Frequency: 1
#   Stem: biḍu, Frequency: 1
# =========================================
# Productive Suffix: dāgi
#   Stem: doḍḍa, Frequency: 1
#   Stem: keṭṭa, Frequency: 1
# =========================================
# Productive Suffix: vāgi
#   Stem: krūra, Frequency: 1
#   Stem: suṃdara, Frequency: 1
# =========================================
# Productive Suffix: dalli
#   Stem: sammēḷana, Frequency: 1
#   Stem: dēvasthāna, Frequency: 1
#   Stem: saṃgrahālaya, Frequency: 1
# =========================================
# Productive Suffix: ttiddenu
#   Stem: ōdu, Frequency: 1
#   Stem: baru, Frequency: 1
# =========================================
# Productive Suffix: nnu
#   Stem: tappa, Frequency: 1
#   Stem: nanna, Frequency: 3
#   Stem: ivara, Frequency: 1
#   Stem: ellara, Frequency: 1
# =========================================
# Productive Suffix: va
#   Stem: hēḷu, Frequency: 2
#   Stem: māḍu, Frequency: 1
#   Stem: iru, Frequency: 1
# =========================================
# Productive Suffix: yuva
#   Stem: bare, Frequency: 2
#   Stem: naḍe, Frequency: 2
# =========================================
# Productive Suffix: lla
#   Stem: cennāgi, Frequency: 1
#   Stem: māḍi, Frequency: 1
#   Stem: barali, Frequency: 1
# =========================================
# Productive Suffix: yalu
#   Stem: kali, Frequency: 1
#   Stem: bare, Frequency: 3
# =========================================
# Productive Suffix: -
#   Stem: bare, Frequency: 1
#   Stem: māva, Frequency: 1
# =========================================
# Productive Suffix: ttade
#   Stem: bēkāgu, Frequency: 1
#   Stem: māḍalpaḍu, Frequency: 2
#   Stem: māḍalāgu, Frequency: 1
#   Stem: baru, Frequency: 1
#   Stem: āgu, Frequency: 1
# =========================================
# Productive Suffix: gaḷannu
#   Stem: pustaka, Frequency: 3
#   Stem: haṇṇu, Frequency: 1
#   Stem: patrike, Frequency: 1
#   Stem: citra, Frequency: 1
# =========================================
# Productive Suffix: vāgali
#   Stem: guruvāra, Frequency: 1
#   Stem: śukravāra, Frequency: 1
# =========================================
# Productive Suffix: ṃda
#   Stem: nālkari, Frequency: 2
#   Stem: ippattari, Frequency: 1
# =========================================

# %%
# Take all words in the sentences and get stems with suffixes
all_words = set()
for result in results:
    sentence, translated_sentence, pos_info = result
    for word in pos_info.keys():
        all_words.add(word) 
# Display all words
print(f"Total unique words in sentences: {len(all_words)}")
# Out:
# Total unique words in sentences: 593

# %%
#all_words
# Remove all punctutation from the words
all_words = [word.strip('.,!?()[]/"!') for word in all_words]

all_words = set(all_words)  # Convert to set to remove duplicates

# Display all words
print(f"Total unique words in sentences after removing punctuation: {len(all_words)}")
# Out:
# Total unique words in sentences after removing punctuation: 590

# %%
all_words
# Out:
# {'',
#  '12',
#  '2',
#  '4',
#  'adakkiṃta',
#  'adannu',
#  'adu',
#  'adū',
#  'aidaralli',
#  'aidu',
#  'alla',
#  'alli',
#  'amma',
#  'anna',
#  'aparūpavāgi',
#  'araḷida',
#  'araḷidudannu',
#  'arthaisu',
#  'arthavisu',
#  'asādhya',
#  'athavā',
#  'avana',
#  'avanige',
#  'avaniṃda',
#  'avanu',
#  'avara',
#  'avaradakke',
#  'avarannu',
#  'avarige',
#  'avaru',
#  'avarū',
#  'avaḷannu',
#  'avaḷige',
#  'avaḷu',
#  'avu',
#  'aḷabēkō',
#  'aṃte',
#  'aṣṭu',
#  'ba-',
#  'bagege',
#  'bahaḷa',
#  'balliri',
#  'banni',
#  'barabahudu',
#  'barabahudā',
#  'baralilla',
#  'baralā',
#  'bare-',
#  'bareda',
#  'baredaru',
#  'baredilla',
#  'baredubiḍuttāre',
#  'baredukoḍuttēne',
#  'baredukoḷḷuttēne',
#  'bareyalilla',
#  'bareyalu',
#  'bareyuttalilla',
#  'bareyuva',
#  'bareyuvudilla',
#  'bareyuvudu',
#  'baruttade',
#  'baruttadeyā',
#  'baruttiddenu',
#  'baruttāne',
#  'baruttānō',
#  'baruttāre',
#  'baruttēne',
#  'baruttēne”',
#  'baruvahāge',
#  'baruvudilla',
#  'baruvudillaveṃdu',
#  'bassu',
#  'baṃda',
#  'baṃdare',
#  'baṃdaru',
#  'baṃdarū',
#  'baṃdavanu',
#  'baṃdaḷu',
#  'baṃdiddēne',
#  'baṃdāga',
#  'baṇṇa',
#  'bekku',
#  'beḷedide',
#  'beṃgaḷūru',
#  'bhāgavahisidaḷu',
#  'bhāgisu',
#  'bhāra',
#  'bhāṣe;',
#  'bhāṣeya',
#  'bhēṭi',
#  'biddive',
#  'biḍabahudu',
#  'biḍuttāre',
#  'biḍuvenu',
#  'biṭṭubiḍi',
#  'buddhi',
#  'buddhiyuḷḷa',
#  'bā',
#  'bēga',
#  'bēgane',
#  'bēku',
#  'bēkā',
#  'bēkāgide',
#  'bēkāgiruvudu',
#  'bēkāgittu',
#  'bēkāguttade',
#  'bēre',
#  'bēḍa',
#  'bēḍamma',
#  'bīdigaḷalli',
#  'bīdiyalli',
#  'cahā',
#  'caḷiyāguttade',
#  'cennāgi',
#  'cennāgiddēne',
#  'cennāgiddīrā',
#  'cennāgide',
#  'cennāgide”',
#  'cennāgilla',
#  'cennāgive',
#  'cikka',
#  'cikkavaru',
#  'citragaḷannu',
#  'cīlagaḷu',
#  'dayadiṃda',
#  'dayaviṭṭu',
#  'dhāravāḍa',
#  'doḍḍa',
#  'doḍḍadu',
#  'doḍḍadāgi',
#  'doḍḍavanu',
#  'doḍḍavaḷu',
#  'dēvara',
#  'dēvasthānadalli',
#  'ella',
#  'elladakkiṃta',
#  'ellarannu',
#  'ellarigiṃta',
#  'elli',
#  'ellide',
#  'elliyādarū',
#  'elliyō',
#  'eraḍannu',
#  'exercise',
#  'eṃba',
#  'eṃbudu',
#  'eṃdare',
#  'eṃdu',
#  'eṣṭu',
#  'gaḷu',
#  'gaṇēśa',
#  'gaṇēśarē',
#  'gaṇēśā',
#  'girākigaḷige',
#  'gottilla',
#  'gurugaḷu',
#  'gururājarē',
#  'guruvāravāgali',
#  'guṇisu',
#  'hasu',
#  'hasuvina',
#  'hattira',
#  'hattu',
#  'hattāru',
#  'haudu',
#  'haḷeya',
#  'haṇa',
#  'haṇavillada',
#  'haṇavuḷḷa',
#  'haṇṇu',
#  'haṇṇugaḷannella',
#  'haṇṇugaḷannu',
#  'haṇṇugaḷu',
#  'heccu',
#  'hedaridaḷu',
#  'hesaru',
#  'hiṃde',
#  'hoddu',
#  'hodedu',
#  'hoḍeyuttāne',
#  'huḍuga',
#  'huḍuganannu',
#  'huḍuganige',
#  'huḍugarannu',
#  'huḍugaru',
#  'huḍugi',
#  'huḍugi-y-alla',
#  'huḍugi-y-illa',
#  'huḍugiyaru',
#  'huṣāriralilla',
#  'hāge',
#  'hāḍidaṣṭu',
#  'hāḍuvenu',
#  'hēgiddīri',
#  'hēgide',
#  'hēḷi',
#  'hēḷida',
#  'hēḷidanu',
#  'hēḷidare',
#  'hēḷidaru',
#  'hēḷiddēne',
#  'hēḷidenu',
#  'hēḷuva',
#  'hēḷuvaṃte',
#  'hīge',
#  'hōda',
#  'hōdanu',
#  'hōdaru',
#  'hōdenu',
#  'hōdevu',
#  'hōgabēkeṃdu',
#  'hōgabēku',
#  'hōgi',
#  'hōgiddēne',
#  'hōgide',
#  'hōguttāne',
#  'hōguttēne',
#  'hōguttīri',
#  'hōguvalli',
#  'hōyitu',
#  'hōṭalu',
#  'hū',
#  'hūvannu',
#  'ibbarigū',
#  'ibbarū',
#  'idannu',
#  'iddaru',
#  'iddavu',
#  'iddāre',
#  'ide',
#  'idu',
#  'illa',
#  'illi',
#  'ippattariṃda',
#  'iruva',
#  'ivara',
#  'ivarannu',
#  'ivaru',
#  'ive',
#  'ivu',
#  'iṃgliṣu',
#  'iṣṭavalla',
#  'iṣṭu',
#  'jana',
#  'janaru',
#  'jāga',
#  'kaiyalli',
#  'kaiyiṃda',
#  'kalitare',
#  'kaliyalu',
#  'kalliniṃda',
#  'kannaḍa',
#  'karakoṃḍu',
#  'karedukoṃḍiddīrā',
#  'kareyuttēne',
#  'karnāṭakada',
#  'kaḍege',
#  'kaḷedu',
#  'kaḷuhisiri',
#  'kaṣṭa',
#  'kaṣṭaveṃdu',
#  'kaṣṭavāgide',
#  'kaṭṭaḍa',
#  'kaṭṭidaru',
#  'kelasa',
#  'kelasavannu',
#  'kelavu',
#  'kere',
#  'keḷage',
#  'keṃpu',
#  'keṭṭa',
#  'keṭṭadāgi',
#  'kharcu',
#  'kiviyiṃda',
#  'kiṭaki',
#  'kliṣṭa-v-āda',
#  'koḷalu',
#  'koḷḷalu',
#  'koḷḷuvudakke',
#  'koṃbugaḷu',
#  'koṭṭanu',
#  'koṭṭenu',
#  'krūravāgi',
#  'kurci',
#  'kurcigiṃta',
#  'kāru',
#  'kāṇisuttave',
#  'kēḷi',
#  'kēḷuvaru',
#  'kūtukoḷḷi',
#  'kūḍisu',
#  'kṣamisi',
#  'kṣamisiri',
#  'laṃḍan',
#  'lesson',
#  'lēkhakiyāgi',
#  'maga',
#  'maganannu',
#  'mahiḷe',
#  'maisūrige',
#  'maisūru',
#  'malagabēku',
#  'malagidenu',
#  'mane',
#  'manegaḷu',
#  'manege',
#  'maneya',
#  'maneyavaru',
#  'maneyavarā',
#  'maneyoḷaginiṃda',
#  'maneyoḷakke',
#  'manuṣya',
#  'manuṣyanannu',
#  'manuṣyanige',
#  'mara',
#  'mara-v-alla',
#  'mara-v-illa',
#  'marada',
#  'maragaḷalla',
#  'maragaḷu',
#  'maravalla',
#  'maravā',
#  'maravē',
#  'maravō',
#  'maretiddāḷe',
#  'mattu',
#  'maṃdi',
#  'maṃgaḷūru',
#  'meccuviri',
#  'meravaṇige',
#  'miliṭari',
#  'mugisuttēne',
#  'mugiyitu',
#  'muṃde',
#  'māriddāne',
#  'mātanāḍidanu',
#  'māva-',
#  'māḍabahudu',
#  'māḍaballa',
#  'māḍaballe',
#  'māḍabāradu',
#  'māḍabēḍa',
#  'māḍabēḍi',
#  'māḍalikke',
#  'māḍalilla',
#  'māḍalpaḍuttade',
#  'māḍalāguttade',
#  'māḍalāyitu',
#  'māḍibiḍu',
#  'māḍida',
#  'māḍidahāge',
#  'māḍidalli',
#  'māḍidanu',
#  'māḍidaru',
#  'māḍidavanu',
#  'māḍidaṃte',
#  'māḍiddare',
#  'māḍiddāne',
#  'māḍiddāḷe',
#  'māḍiddāḷō',
#  'māḍiddēne',
#  'māḍidenu',
#  'māḍilla',
#  'māḍisidenu',
#  'māḍu',
#  'māḍutta',
#  'māḍuttēne',
#  'māḍuttī',
#  'māḍuva',
#  'māḍuvavaru',
#  'māḍuvenu',
#  'māḍuvudilla',
#  'māḍuvudu',
#  'mējina',
#  'mēle',
#  'mūgu',
#  'mūrannu',
#  'mūru',
#  'mūrū',
#  'na',
#  'nagabēkō',
#  'nagara',
#  'nagaragaḷu',
#  'namage',
#  'namaskāra',
#  'namma',
#  'nammavaradannu',
#  'nanage',
#  'nanagōskara',
#  'nanna',
#  'nannadu',
#  'nannannu',
#  'naḍeyuva',
#  'naḍeyuvavanannu',
#  'nenne',
#  'neṃṭa',
#  'nidde',
#  'nijavāgi',
#  'nimage',
#  'nimagōskara',
#  'nimma',
#  'nimmalli',
#  'niṃtiddāre',
#  'nālkaneyadaralli',
#  'nālkariṃda',
#  'nālku',
#  'nānu',
#  'nānū',
#  'nāvu',
#  'nāḷe',
#  'nīru',
#  'nīvu',
#  'nīvēnu',
#  'nīvū',
#  'nōḍabēku',
#  'nōḍida',
#  'nōḍidanu',
#  'nōḍidanō',
#  'nōḍidaru',
#  'nōḍidaḷu',
#  'nōḍiddēne',
#  'nōḍidenu',
#  'nōḍidenō',
#  'nōḍidevu',
#  'nōḍiri',
#  'nōḍuvenu',
#  'nūraneyavaru',
#  'nūrannu',
#  'nūrāru',
#  'oḍedu',
#  'oḷage',
#  'oḷḷeyadu',
#  'oṃdu',
#  'pakkada',
#  'paravā',
#  'patni',
#  'patra',
#  'patravannu',
#  'patrikegaḷannu',
#  'paṭṭaru',
#  'praśne',
#  'purōhitanāgi',
#  'purōhitaru',
#  'pustaka',
#  'pustakagaḷannu',
#  'pustakagaḷu',
#  'pustakavalla',
#  'pustakavannu',
#  'pustakavā',
#  'raitanalla',
#  'raitaralla',
#  'raitaru',
#  'reyuvudilla',
#  'rāma',
#  'rāmanigiṃta',
#  'rāmappanavarē',
#  'rāmayyanavarē',
#  'rūpāyi',
#  'samaya',
#  'sammēḷanadalli',
#  'samācāra',
#  'samācāravilla',
#  'sari',
#  'saṃgrahālayadalli',
#  'saṃgīta',
#  'saṃgītavannu',
#  'saṃkōcapaḍisuttāne',
#  'saṃsthe',
#  'saṃtōṣa',
#  'saṇṇakate',
#  'sikka',
#  'sikkide',
#  'sikkitu',
#  'snēhitanū',
#  'surēśarē',
#  'sustāgi',
#  'suṃdaravāda',
#  'suṃdaravāgi',
#  'svalpa',
#  'svāmi',
#  'sādhya',
#  'sādhyavide',
#  'sādhyavilla',
#  'sāgitu',
#  'sāku',
#  'sāladā',
#  'sāvirāru',
#  'sēbugaḷu',
#  'sītamma',
#  'sītammanavarē',
#  'sīte',
#  'tagoḷḷi',
#  'tagoḷḷuttīri',
#  'tagoṃḍu',
#  'takkadu',
#  'tamage',
#  'tammaṃdiru',
#  'tanna',
#  'tanni',
#  'tappannu',
#  'tappu',
#  'taralā',
#  'taṃde',
#  'taṃdiddēne',
#  'tegedukoṃḍiddēne',
#  'tegedukoṃḍu',
#  'tiḷidukoṃḍiddāne',
#  'tiḷidukoṃḍiddīyā',
#  'tiṃda',
#  'toḍak-alla',
#  'toḍak-illa',
#  'toṃdare',
#  'tuṃba',
#  'tānu',
#  'tānē',
#  'tāvu',
#  'tōrisida',
#  'tōrisuttēne',
#  'tōruttade',
#  'uḷidavarannu',
#  'varṣa',
#  'vidhy-',
#  'vidyārthi',
#  'vidyārthigaḷellarannū',
#  'vidyārthigaḷu',
#  'vidyārthini',
#  'vidyārthiniyā',
#  'vidyārthiyā',
#  'vidyārthiyāgiral-',
#  'vidyārthiyāgiru-',
#  'vidyārthiyāgiruvenu',
#  'vikāsagoḷḷuttade',
#  'viśēṣavāda',
#  'viṣaya',
#  'viṣayavannu',
#  'vudilla',
#  'vāsa',
#  'yaśasviyāguttāre',
#  'yuvudilla',
#  'yārannō',
#  'yārādarū',
#  'yārō',
#  'yāva',
#  'yāvāga',
#  'yāvāgalū',
#  'yōcane',
#  'yōcisidenu',
#  'ā',
#  'ādare',
#  'ādevō',
#  'āgali',
#  'āguttade',
#  'ākāśa',
#  'ārakke',
#  'ārthigaḷu',
#  'ēke',
#  'ēnide',
#  'ēnu',
#  'ēnādarū',
#  'ēnū',
#  'ēḷge',
#  'ēḷige',
#  'ēḷu',
#  'ī',
#  'īga',
#  'ō',
#  'ōdabāradu',
#  'ōdalu',
#  'ōdalāgide',
#  'ōdibiṭṭenu',
#  'ōdida',
#  'ōdiddenu',
#  'ōdiddēne',
#  'ōdiruvenu',
#  'ōduttiddenu',
#  'ōduttiddēne',
#  'ōduttiruvenu',
#  'ōduttāne',
#  'ōduvanu',
#  'ōḍi',
#  'śivamogga',
#  'śrēṣṭhaneṃdu',
#  'śukravāravāgali',
#  'ūraṃte',
#  'ūrige',
#  'ūṭa',
#  'ūṭakke',
#  'ūṭakkōskara',
#  '“idu',
#  '“nāḷe'}

# %%
# Find stems in all_words that have suffixes we found in productive_suffixes
stems_with_suffixes = defaultdict(list)  # stem → [suffix1, suffix2, ...]
for word in all_words:
    for suffix in productive_suffixes.keys():
        if word.endswith(suffix):
            stem = word[:-len(suffix)] if len(suffix) > 0 else word
            stems_with_suffixes[stem].append(suffix)
# Convert to a regular dictionary
stems_with_suffixes = dict(stems_with_suffixes)
# Display stems with their suffixes
for stem, suffixes in stems_with_suffixes.items():
    print(f"Stem: {stem}, Suffixes: {suffixes}")
# Out:
# Stem: para, Suffixes: ['vā']
# Stem: baruvahā, Suffixes: ['ge']
# Stem: idan, Suffixes: ['nu']
# Stem: ida, Suffixes: ['nnu']
# Stem: vidyārthi, Suffixes: ['gaḷu', 'yā']
# Stem: i, Suffixes: ['du', 'lla', 'de', 'varu']
# Stem: saṃkōcapaḍisu, Suffixes: ['ttāne']
# Stem: samācāra, Suffixes: ['villa']
# Stem: samācāravi, Suffixes: ['lla']
# Stem: hēḷida, Suffixes: ['ru', 'nu']
# Stem: hēḷi, Suffixes: ['daru', 'da', 'ddēne']
# Stem: viṣaya, Suffixes: ['vannu']
# Stem: viṣayavan, Suffixes: ['nu']
# Stem: viṣayava, Suffixes: ['nnu']
# Stem: māḍu, Suffixes: ['va', 'vudilla', 'ttēne', 'venu']
# Stem: āgutta, Suffixes: ['de']
# Stem: āgu, Suffixes: ['ttade']
# Stem: maga, Suffixes: ['nannu']
# Stem: maganan, Suffixes: ['nu']
# Stem: magana, Suffixes: ['nnu']
# Stem: oḍe, Suffixes: ['du']
# Stem: saṃgīta, Suffixes: ['vannu']
# Stem: saṃgītavan, Suffixes: ['nu']
# Stem: saṃgītava, Suffixes: ['nnu']
# Stem: kliṣṭa-v-ā, Suffixes: ['da']
# Stem: ellari, Suffixes: ['giṃta']
# Stem: kali, Suffixes: ['yalu']
# Stem: hiṃ, Suffixes: ['de']
# Stem: taṃ, Suffixes: ['de']
# Stem: purōhita, Suffixes: ['ru']
# Stem: nana, Suffixes: ['ge']
# Stem: ellaran, Suffixes: ['nu']
# Stem: ellara, Suffixes: ['nnu']
# Stem: patra, Suffixes: ['vannu']
# Stem: patravan, Suffixes: ['nu']
# Stem: patrava, Suffixes: ['nnu']
# Stem: raitara, Suffixes: ['lla']
# Stem: cennāgi, Suffixes: ['lla', 'de', 'ddēne']
# Stem: muṃ, Suffixes: ['de']
# Stem: ōduttiruve, Suffixes: ['nu']
# Stem: ōduttiru, Suffixes: ['venu']
# Stem: eṃ, Suffixes: ['du']
# Stem: huḍugiya, Suffixes: ['ru']
# Stem: pustaka, Suffixes: ['valla', 'gaḷannu', 'vannu', 'gaḷu', 'vā']
# Stem: pustakava, Suffixes: ['lla', 'nnu']
# Stem: doḍḍa, Suffixes: ['du', 'dāgi']
# Stem: suṃdaravā, Suffixes: ['da']
# Stem: ārthi, Suffixes: ['gaḷu']
# Stem: koṃbu, Suffixes: ['gaḷu']
# Stem: nūran, Suffixes: ['nu']
# Stem: nūra, Suffixes: ['nnu']
# Stem: bēkāgiruvu, Suffixes: ['du']
# Stem: tappan, Suffixes: ['nu']
# Stem: tappa, Suffixes: ['nnu']
# Stem: biḍuve, Suffixes: ['nu']
# Stem: biḍu, Suffixes: ['venu']
# Stem: vidhy, Suffixes: ['-']
# Stem: nagara, Suffixes: ['gaḷu']
# Stem: baruttidde, Suffixes: ['nu']
# Stem: baru, Suffixes: ['ttiddenu', 'ttade', 'vudilla', 'ttēne', 'ttāne']
# Stem: nōḍuve, Suffixes: ['nu']
# Stem: nōḍu, Suffixes: ['venu']
# Stem: sādhyavi, Suffixes: ['de', 'lla']
# Stem: idda, Suffixes: ['ru']
# Stem: id, Suffixes: ['daru']
# Stem: maisū, Suffixes: ['ru']
# Stem: saṃgrahālaya, Suffixes: ['dalli']
# Stem: mugisu, Suffixes: ['ttēne']
# Stem: nōḍi, Suffixes: ['da', 'ddēne', 'daru']
# Stem: maṃgaḷū, Suffixes: ['ru']
# Stem: huḍugi-y-a, Suffixes: ['lla']
# Stem: guruvāra, Suffixes: ['vāgali']
# Stem: māḍaba, Suffixes: ['lla']
# Stem: barutta, Suffixes: ['de']
# Stem: manuṣya, Suffixes: ['nannu', 'nige']
# Stem: manuṣyanan, Suffixes: ['nu']
# Stem: manuṣyana, Suffixes: ['nnu']
# Stem: ōdalāgi, Suffixes: ['de']
# Stem: aparūpa, Suffixes: ['vāgi']
# Stem: doḍḍava, Suffixes: ['nu']
# Stem: raita, Suffixes: ['ru']
# Stem: tiṃ, Suffixes: ['da']
# Stem: ti, Suffixes: ['ṃda']
# Stem: kurci, Suffixes: ['giṃta']
# Stem: nan, Suffixes: ['nannu']
# Stem: nannan, Suffixes: ['nu']
# Stem: nanna, Suffixes: ['nnu', 'du']
# Stem: kā, Suffixes: ['ru']
# Stem: ūri, Suffixes: ['ge']
# Stem: malagide, Suffixes: ['nu']
# Stem: māḍabahu, Suffixes: ['du']
# Stem: bēkāgutta, Suffixes: ['de']
# Stem: bēkāgu, Suffixes: ['ttade']
# Stem: bareyu, Suffixes: ['va', 'vudilla']
# Stem: bare, Suffixes: ['yuva', 'da', '-', 'yalu', 'daru']
# Stem: māḍi, Suffixes: ['lla', 'dalli', 'daru', 'ddēne', 'da']
# Stem: śukravāra, Suffixes: ['vāgali']
# Stem: haṇṇugaḷan, Suffixes: ['nu']
# Stem: haṇṇugaḷa, Suffixes: ['nnu']
# Stem: haṇṇu, Suffixes: ['gaḷannu', 'gaḷu']
# Stem: kaṭṭida, Suffixes: ['ru']
# Stem: kaṭṭi, Suffixes: ['daru']
# Stem: ōdabāra, Suffixes: ['du']
# Stem: rāmappa, Suffixes: ['navarē']
# Stem: pustakagaḷan, Suffixes: ['nu']
# Stem: pustakagaḷa, Suffixes: ['nnu']
# Stem: keḷa, Suffixes: ['ge']
# Stem: māḍuvudi, Suffixes: ['lla']
# Stem: koṭṭa, Suffixes: ['nu']
# Stem: mara, Suffixes: ['vā', 'da', 'valla', 'gaḷu']
# Stem: mane, Suffixes: ['gaḷu', 'ge', 'ya']
# Stem: barabahu, Suffixes: ['du']
# Stem: nūraneyava, Suffixes: ['ru']
# Stem: nūraneya, Suffixes: ['varu']
# Stem: tegedukoṃḍi, Suffixes: ['ddēne']
# Stem: manuṣ, Suffixes: ['ya']
# Stem: nid, Suffixes: ['de']
# Stem: hau, Suffixes: ['du']
# Stem: yā, Suffixes: ['va']
# Stem: mū, Suffixes: ['ru']
# Stem: avaḷi, Suffixes: ['ge']
# Stem: hōgu, Suffixes: ['ttīri', 'ttēne', 'ttāne']
# Stem: hod, Suffixes: ['du']
# Stem: hī, Suffixes: ['ge']
# Stem: toḍak-i, Suffixes: ['lla']
# Stem: oḷḷeya, Suffixes: ['du']
# Stem: beṃgaḷū, Suffixes: ['ru']
# Stem: hoḍeyu, Suffixes: ['ttāne']
# Stem: karnāṭaka, Suffixes: ['da']
# Stem: viṣa, Suffixes: ['ya']
# Stem: bēkāgi, Suffixes: ['de']
# Stem: mūran, Suffixes: ['nu']
# Stem: mūra, Suffixes: ['nnu']
# Stem: guru, Suffixes: ['gaḷu']
# Stem: ai, Suffixes: ['du']
# Stem: eraḍan, Suffixes: ['nu']
# Stem: eraḍa, Suffixes: ['nnu']
# Stem: , Suffixes: ['vudilla', 'gaḷu']
# Stem: vudi, Suffixes: ['lla']
# Stem: hū, Suffixes: ['vannu']
# Stem: hūvan, Suffixes: ['nu']
# Stem: hūva, Suffixes: ['nnu']
# Stem: cikkava, Suffixes: ['ru']
# Stem: cikka, Suffixes: ['varu']
# Stem: tā, Suffixes: ['nu']
# Stem: baredukoḍu, Suffixes: ['ttēne']
# Stem: huḍuga, Suffixes: ['nige', 'nannu', 'ru']
# Stem: huḍugani, Suffixes: ['ge']
# Stem: pustakavan, Suffixes: ['nu']
# Stem: hōde, Suffixes: ['nu']
# Stem: nūrā, Suffixes: ['ru']
# Stem: viśēṣavā, Suffixes: ['da']
# Stem: hōda, Suffixes: ['nu', 'ru']
# Stem: vidyārthini, Suffixes: ['yā']
# Stem: nima, Suffixes: ['ge']
# Stem: a, Suffixes: ['lla', 'du', 'varu']
# Stem: huḍuganan, Suffixes: ['nu']
# Stem: huḍugana, Suffixes: ['nnu']
# Stem: avari, Suffixes: ['ge']
# Stem: sama, Suffixes: ['ya']
# Stem: citragaḷan, Suffixes: ['nu']
# Stem: citragaḷa, Suffixes: ['nnu']
# Stem: citra, Suffixes: ['gaḷannu']
# Stem: jana, Suffixes: ['ru']
# Stem: nīvē, Suffixes: ['nu']
# Stem: tiḷidukoṃḍiddī, Suffixes: ['yā']
# Stem: kai, Suffixes: ['yiṃda']
# Stem: kaiyiṃ, Suffixes: ['da']
# Stem: kaiyi, Suffixes: ['ṃda']
# Stem: reyu, Suffixes: ['vudilla']
# Stem: reyuvudi, Suffixes: ['lla']
# Stem: taṃdi, Suffixes: ['ddēne']
# Stem: araḷi, Suffixes: ['da']
# Stem: huṣārirali, Suffixes: ['lla']
# Stem: asādh, Suffixes: ['ya']
# Stem: kelasa, Suffixes: ['vannu']
# Stem: kelasavan, Suffixes: ['nu']
# Stem: kelasava, Suffixes: ['nnu']
# Stem: bhāṣe, Suffixes: ['ya']
# Stem: paṭṭa, Suffixes: ['ru']
# Stem: ōduttidde, Suffixes: ['nu']
# Stem: ōdu, Suffixes: ['ttiddenu', 'ttāne']
# Stem: vikāsagoḷḷutta, Suffixes: ['de']
# Stem: vikāsagoḷḷu, Suffixes: ['ttade']
# Stem: vidyārthiyāgiruve, Suffixes: ['nu']
# Stem: vidyārthiyāgiru, Suffixes: ['venu', '-']
# Stem: kareyu, Suffixes: ['ttēne']
# Stem: pakka, Suffixes: ['da']
# Stem: beḷedi, Suffixes: ['de']
# Stem: māḍide, Suffixes: ['nu']
# Stem: avaniṃ, Suffixes: ['da']
# Stem: avani, Suffixes: ['ṃda', 'ge']
# Stem: māḍida, Suffixes: ['ru', 'nu']
# Stem: sikki, Suffixes: ['de']
# Stem: mara-v-a, Suffixes: ['lla']
# Stem: nōḍida, Suffixes: ['nu', 'ru']
# Stem: tōrisu, Suffixes: ['ttēne']
# Stem: nija, Suffixes: ['vāgi']
# Stem: māḍabāra, Suffixes: ['du']
# Stem: sītamma, Suffixes: ['navarē']
# Stem: suṃdara, Suffixes: ['vāgi']
# Stem: adan, Suffixes: ['nu']
# Stem: ada, Suffixes: ['nnu']
# Stem: ōdibiṭṭe, Suffixes: ['nu']
# Stem: baredukoḷḷu, Suffixes: ['ttēne']
# Stem: kēḷuva, Suffixes: ['ru']
# Stem: kēḷu, Suffixes: ['varu']
# Stem: araḷidudan, Suffixes: ['nu']
# Stem: araḷiduda, Suffixes: ['nnu']
# Stem: ōdi, Suffixes: ['ddēne', 'da']
# Stem: kaṣṭaveṃ, Suffixes: ['du']
# Stem: tagoḷḷu, Suffixes: ['ttīri']
# Stem: māḍiside, Suffixes: ['nu']
# Stem: ava, Suffixes: ['nu', 'ru', 'nige']
# Stem: dēvasthāna, Suffixes: ['dalli']
# Stem: hōgi, Suffixes: ['ddēne', 'de']
# Stem: hā, Suffixes: ['ge']
# Stem: hō, Suffixes: ['da', 'daru']
# Stem: atha, Suffixes: ['vā']
# Stem: śrēṣṭhaneṃ, Suffixes: ['du']
# Stem: huḍugaran, Suffixes: ['nu']
# Stem: huḍugara, Suffixes: ['nnu']
# Stem: “i, Suffixes: ['du']
# Stem: māḍidava, Suffixes: ['nu']
# Stem: iṣṭa, Suffixes: ['valla']
# Stem: iṣṭava, Suffixes: ['lla']
# Stem: māḍali, Suffixes: ['lla']
# Stem: girākigaḷi, Suffixes: ['ge']
# Stem: māḍuvu, Suffixes: ['du']
# Stem: ēḷi, Suffixes: ['ge']
# Stem: ōdiruve, Suffixes: ['nu']
# Stem: ōdiru, Suffixes: ['venu']
# Stem: biḍabahu, Suffixes: ['du']
# Stem: ba, Suffixes: ['-', 'ṃda']
# Stem: sēbu, Suffixes: ['gaḷu']
# Stem: yōciside, Suffixes: ['nu']
# Stem: tammaṃdi, Suffixes: ['ru']
# Stem: bareyali, Suffixes: ['lla']
# Stem: māḍalāgutta, Suffixes: ['de']
# Stem: māḍalāgu, Suffixes: ['ttade']
# Stem: baruttade, Suffixes: ['yā']
# Stem: cīla, Suffixes: ['gaḷu']
# Stem: hode, Suffixes: ['du']
# Stem: maneyoḷaginiṃ, Suffixes: ['da']
# Stem: maneyoḷagini, Suffixes: ['ṃda']
# Stem: barali, Suffixes: ['lla']
# Stem: marava, Suffixes: ['lla']
# Stem: bareyuvu, Suffixes: ['du']
# Stem: sammēḷana, Suffixes: ['dalli']
# Stem: huḍugi-y-i, Suffixes: ['lla']
# Stem: naḍeyuvava, Suffixes: ['nannu']
# Stem: naḍeyuvavanan, Suffixes: ['nu']
# Stem: naḍeyuvavana, Suffixes: ['nnu']
# Stem: toḍak-a, Suffixes: ['lla']
# Stem: oṃ, Suffixes: ['du']
# Stem: nālkariṃ, Suffixes: ['da']
# Stem: nālkari, Suffixes: ['ṃda']
# Stem: vidyārthiyāgiral, Suffixes: ['-']
# Stem: baṃdava, Suffixes: ['nu']
# Stem: meravaṇi, Suffixes: ['ge']
# Stem: hattā, Suffixes: ['ru']
# Stem: hēḷu, Suffixes: ['va']
# Stem: tōrisi, Suffixes: ['da']
# Stem: nammavaradan, Suffixes: ['nu']
# Stem: nammavarada, Suffixes: ['nnu']
# Stem: haṇṇugaḷanne, Suffixes: ['lla']
# Stem: baruvudi, Suffixes: ['lla']
# Stem: kaḍe, Suffixes: ['ge']
# Stem: raitana, Suffixes: ['lla']
# Stem: sādhya, Suffixes: ['villa']
# Stem: koṭṭe, Suffixes: ['nu']
# Stem: manuṣyani, Suffixes: ['ge']
# Stem: kalliniṃ, Suffixes: ['da']
# Stem: kallini, Suffixes: ['ṃda']
# Stem: tama, Suffixes: ['ge']
# Stem: iva, Suffixes: ['ru']
# Stem: nā, Suffixes: ['nu']
# Stem: caḷiyāgutta, Suffixes: ['de']
# Stem: caḷiyāgu, Suffixes: ['ttade']
# Stem: avaran, Suffixes: ['nu']
# Stem: avara, Suffixes: ['nnu']
# Stem: elli, Suffixes: ['de']
# Stem: māḍalpaḍutta, Suffixes: ['de']
# Stem: māḍalpaḍu, Suffixes: ['ttade']
# Stem: keṭṭa, Suffixes: ['dāgi']
# Stem: ōduva, Suffixes: ['nu']
# Stem: haṇavilla, Suffixes: ['da']
# Stem: nī, Suffixes: ['ru']
# Stem: iru, Suffixes: ['va']
# Stem: ōdidde, Suffixes: ['nu']
# Stem: bareyuvudi, Suffixes: ['lla']
# Stem: uḷidavaran, Suffixes: ['nu']
# Stem: uḷidavara, Suffixes: ['nnu']
# Stem: tōrutta, Suffixes: ['de']
# Stem: tōru, Suffixes: ['ttade']
# Stem: ōdutti, Suffixes: ['ddēne']
# Stem: eṃbu, Suffixes: ['du']
# Stem: baṃdi, Suffixes: ['ddēne']
# Stem: maneyava, Suffixes: ['ru']
# Stem: maneya, Suffixes: ['varu']
# Stem: baruvudillaveṃ, Suffixes: ['du']
# Stem: patrikegaḷan, Suffixes: ['nu']
# Stem: patrikegaḷa, Suffixes: ['nnu']
# Stem: patrike, Suffixes: ['gaḷannu']
# Stem: hāḍuve, Suffixes: ['nu']
# Stem: hāḍu, Suffixes: ['venu']
# Stem: kaḷe, Suffixes: ['du']
# Stem: nama, Suffixes: ['ge']
# Stem: sādh, Suffixes: ['ya']
# Stem: dayadiṃ, Suffixes: ['da']
# Stem: dayadi, Suffixes: ['ṃda']
# Stem: bage, Suffixes: ['ge']
# Stem: ēni, Suffixes: ['de']
# Stem: ippattariṃ, Suffixes: ['da']
# Stem: ippattari, Suffixes: ['ṃda']
# Stem: maisūri, Suffixes: ['ge']
# Stem: baṃda, Suffixes: ['ru']
# Stem: baṃ, Suffixes: ['daru', 'da']
# Stem: oḷa, Suffixes: ['ge']
# Stem: haḷe, Suffixes: ['ya']
# Stem: mātanāḍida, Suffixes: ['nu']
# Stem: bareda, Suffixes: ['ru']
# Stem: baredi, Suffixes: ['lla']
# Stem: ēḷ, Suffixes: ['ge']
# Stem: krūra, Suffixes: ['vāgi']
# Stem: kaṣṭavāgi, Suffixes: ['de']
# Stem: kivi, Suffixes: ['yiṃda']
# Stem: kiviyiṃ, Suffixes: ['da']
# Stem: kiviyi, Suffixes: ['ṃda']
# Stem: hēgi, Suffixes: ['de']
# Stem: takka, Suffixes: ['du']
# Stem: māva, Suffixes: ['-']
# Stem: sāvirā, Suffixes: ['ru']
# Stem: avaḷan, Suffixes: ['nu']
# Stem: avaḷa, Suffixes: ['nnu']
# Stem: hēḷide, Suffixes: ['nu']
# Stem: bareyuttali, Suffixes: ['lla']
# Stem: nōḍide, Suffixes: ['nu']
# Stem: māḍuve, Suffixes: ['nu']
# Stem: maragaḷa, Suffixes: ['lla']
# Stem: gotti, Suffixes: ['lla']
# Stem: ē, Suffixes: ['nu']
# Stem: yu, Suffixes: ['vudilla']
# Stem: yuvudi, Suffixes: ['lla']
# Stem: hōgabēkeṃ, Suffixes: ['du']
# Stem: naḍeyu, Suffixes: ['va']
# Stem: naḍe, Suffixes: ['yuva']
# Stem: hesa, Suffixes: ['ru']
# Stem: rāmayya, Suffixes: ['navarē']
# Stem: mara-v-i, Suffixes: ['lla']
# Stem: māḍuvava, Suffixes: ['ru']
# Stem: māḍuva, Suffixes: ['varu']
# Stem: e, Suffixes: ['lla']
# Stem: māḍidahā, Suffixes: ['ge']
# Stem: rāmani, Suffixes: ['giṃta']
# Stem: ivaran, Suffixes: ['nu']
# Stem: ivara, Suffixes: ['nnu']

# %%
suffix_info = {}

suffix_to_stems = defaultdict(list)  # suffix → [stems]
for stem, suffixes in stems_with_suffixes.items():
    for suffix in suffixes:
        suffix_to_stems[suffix].append(stem)

for suffix, stems in suffix_to_stems.items():
    # Create dict for this suffix
    suffix_info[suffix] = {
        "count": {},  # Will store stem:count pairs
    }
    
    # Count occurrences of each stem
    for stem in stems:
        if stem in suffix_info[suffix]["count"]:
            suffix_info[suffix]["count"][stem] += 1
        else:
            suffix_info[suffix]["count"][stem] = 1

# Display summary
print("Created info dictionary for", len(suffix_info), "suffixes")
suffix_info
# Out:
# Created info dictionary for 40 suffixes
# {'vā': {'count': {'para': 1, 'pustaka': 1, 'mara': 1, 'atha': 1}},
#  'ge': {'count': {'baruvahā': 1,
#    'nana': 1,
#    'ūri': 1,
#    'keḷa': 1,
#    'mane': 1,
#    'avaḷi': 1,
#    'hī': 1,
#    'huḍugani': 1,
#    'nima': 1,
#    'avari': 1,
#    'avani': 1,
#    'hā': 1,
#    'girākigaḷi': 1,
#    'ēḷi': 1,
#    'meravaṇi': 1,
#    'kaḍe': 1,
#    'manuṣyani': 1,
#    'tama': 1,
#    'nama': 1,
#    'bage': 1,
#    'maisūri': 1,
#    'oḷa': 1,
#    'ēḷ': 1,
#    'māḍidahā': 1}},
#  'nu': {'count': {'idan': 1,
#    'hēḷida': 1,
#    'viṣayavan': 1,
#    'maganan': 1,
#    'saṃgītavan': 1,
#    'ellaran': 1,
#    'patravan': 1,
#    'ōduttiruve': 1,
#    'nūran': 1,
#    'tappan': 1,
#    'biḍuve': 1,
#    'baruttidde': 1,
#    'nōḍuve': 1,
#    'manuṣyanan': 1,
#    'doḍḍava': 1,
#    'nannan': 1,
#    'malagide': 1,
#    'haṇṇugaḷan': 1,
#    'pustakagaḷan': 1,
#    'koṭṭa': 1,
#    'mūran': 1,
#    'eraḍan': 1,
#    'hūvan': 1,
#    'tā': 1,
#    'pustakavan': 1,
#    'hōde': 1,
#    'hōda': 1,
#    'huḍuganan': 1,
#    'citragaḷan': 1,
#    'nīvē': 1,
#    'kelasavan': 1,
#    'ōduttidde': 1,
#    'vidyārthiyāgiruve': 1,
#    'māḍide': 1,
#    'māḍida': 1,
#    'nōḍida': 1,
#    'adan': 1,
#    'ōdibiṭṭe': 1,
#    'araḷidudan': 1,
#    'māḍiside': 1,
#    'ava': 1,
#    'huḍugaran': 1,
#    'māḍidava': 1,
#    'ōdiruve': 1,
#    'yōciside': 1,
#    'naḍeyuvavanan': 1,
#    'baṃdava': 1,
#    'nammavaradan': 1,
#    'koṭṭe': 1,
#    'nā': 1,
#    'avaran': 1,
#    'ōduva': 1,
#    'ōdidde': 1,
#    'uḷidavaran': 1,
#    'patrikegaḷan': 1,
#    'hāḍuve': 1,
#    'mātanāḍida': 1,
#    'avaḷan': 1,
#    'hēḷide': 1,
#    'nōḍide': 1,
#    'māḍuve': 1,
#    'ē': 1,
#    'ivaran': 1}},
#  'nnu': {'count': {'ida': 1,
#    'viṣayava': 1,
#    'magana': 1,
#    'saṃgītava': 1,
#    'ellara': 1,
#    'patrava': 1,
#    'pustakava': 1,
#    'nūra': 1,
#    'tappa': 1,
#    'manuṣyana': 1,
#    'nanna': 1,
#    'haṇṇugaḷa': 1,
#    'pustakagaḷa': 1,
#    'mūra': 1,
#    'eraḍa': 1,
#    'hūva': 1,
#    'huḍugana': 1,
#    'citragaḷa': 1,
#    'kelasava': 1,
#    'ada': 1,
#    'araḷiduda': 1,
#    'huḍugara': 1,
#    'naḍeyuvavana': 1,
#    'nammavarada': 1,
#    'avara': 1,
#    'uḷidavara': 1,
#    'patrikegaḷa': 1,
#    'avaḷa': 1,
#    'ivara': 1}},
#  'gaḷu': {'count': {'vidyārthi': 1,
#    'pustaka': 1,
#    'ārthi': 1,
#    'koṃbu': 1,
#    'nagara': 1,
#    'haṇṇu': 1,
#    'mara': 1,
#    'mane': 1,
#    'guru': 1,
#    '': 1,
#    'sēbu': 1,
#    'cīla': 1}},
#  'yā': {'count': {'vidyārthi': 1,
#    'vidyārthini': 1,
#    'tiḷidukoṃḍiddī': 1,
#    'baruttade': 1}},
#  'du': {'count': {'i': 1,
#    'oḍe': 1,
#    'eṃ': 1,
#    'doḍḍa': 1,
#    'bēkāgiruvu': 1,
#    'nanna': 1,
#    'māḍabahu': 1,
#    'ōdabāra': 1,
#    'barabahu': 1,
#    'hau': 1,
#    'hod': 1,
#    'oḷḷeya': 1,
#    'ai': 1,
#    'a': 1,
#    'māḍabāra': 1,
#    'kaṣṭaveṃ': 1,
#    'śrēṣṭhaneṃ': 1,
#    '“i': 1,
#    'māḍuvu': 1,
#    'biḍabahu': 1,
#    'hode': 1,
#    'bareyuvu': 1,
#    'oṃ': 1,
#    'eṃbu': 1,
#    'baruvudillaveṃ': 1,
#    'kaḷe': 1,
#    'takka': 1,
#    'hōgabēkeṃ': 1}},
#  'lla': {'count': {'i': 1,
#    'samācāravi': 1,
#    'raitara': 1,
#    'cennāgi': 1,
#    'pustakava': 1,
#    'sādhyavi': 1,
#    'huḍugi-y-a': 1,
#    'māḍaba': 1,
#    'māḍi': 1,
#    'māḍuvudi': 1,
#    'toḍak-i': 1,
#    'vudi': 1,
#    'a': 1,
#    'reyuvudi': 1,
#    'huṣārirali': 1,
#    'mara-v-a': 1,
#    'iṣṭava': 1,
#    'māḍali': 1,
#    'bareyali': 1,
#    'barali': 1,
#    'marava': 1,
#    'huḍugi-y-i': 1,
#    'toḍak-a': 1,
#    'haṇṇugaḷanne': 1,
#    'baruvudi': 1,
#    'raitana': 1,
#    'bareyuvudi': 1,
#    'baredi': 1,
#    'bareyuttali': 1,
#    'maragaḷa': 1,
#    'gotti': 1,
#    'yuvudi': 1,
#    'mara-v-i': 1,
#    'e': 1}},
#  'de': {'count': {'i': 1,
#    'āgutta': 1,
#    'hiṃ': 1,
#    'taṃ': 1,
#    'cennāgi': 1,
#    'muṃ': 1,
#    'sādhyavi': 1,
#    'barutta': 1,
#    'ōdalāgi': 1,
#    'bēkāgutta': 1,
#    'nid': 1,
#    'bēkāgi': 1,
#    'vikāsagoḷḷutta': 1,
#    'beḷedi': 1,
#    'sikki': 1,
#    'hōgi': 1,
#    'māḍalāgutta': 1,
#    'caḷiyāgutta': 1,
#    'elli': 1,
#    'māḍalpaḍutta': 1,
#    'tōrutta': 1,
#    'ēni': 1,
#    'kaṣṭavāgi': 1,
#    'hēgi': 1}},
#  'varu': {'count': {'i': 1,
#    'nūraneya': 1,
#    'cikka': 1,
#    'a': 1,
#    'kēḷu': 1,
#    'maneya': 1,
#    'māḍuva': 1}},
#  'ttāne': {'count': {'saṃkōcapaḍisu': 1,
#    'baru': 1,
#    'hōgu': 1,
#    'hoḍeyu': 1,
#    'ōdu': 1}},
#  'villa': {'count': {'samācāra': 1, 'sādhya': 1}},
#  'ru': {'count': {'hēḷida': 1,
#    'purōhita': 1,
#    'huḍugiya': 1,
#    'idda': 1,
#    'maisū': 1,
#    'maṃgaḷū': 1,
#    'raita': 1,
#    'kā': 1,
#    'kaṭṭida': 1,
#    'nūraneyava': 1,
#    'mū': 1,
#    'beṃgaḷū': 1,
#    'cikkava': 1,
#    'huḍuga': 1,
#    'nūrā': 1,
#    'hōda': 1,
#    'jana': 1,
#    'paṭṭa': 1,
#    'māḍida': 1,
#    'nōḍida': 1,
#    'kēḷuva': 1,
#    'ava': 1,
#    'tammaṃdi': 1,
#    'hattā': 1,
#    'iva': 1,
#    'nī': 1,
#    'maneyava': 1,
#    'baṃda': 1,
#    'bareda': 1,
#    'sāvirā': 1,
#    'hesa': 1,
#    'māḍuvava': 1}},
#  'daru': {'count': {'hēḷi': 1,
#    'id': 1,
#    'nōḍi': 1,
#    'bare': 1,
#    'māḍi': 1,
#    'kaṭṭi': 1,
#    'hō': 1,
#    'baṃ': 1}},
#  'da': {'count': {'hēḷi': 1,
#    'kliṣṭa-v-ā': 1,
#    'suṃdaravā': 1,
#    'nōḍi': 1,
#    'tiṃ': 1,
#    'bare': 1,
#    'māḍi': 1,
#    'mara': 1,
#    'karnāṭaka': 1,
#    'viśēṣavā': 1,
#    'kaiyiṃ': 1,
#    'araḷi': 1,
#    'pakka': 1,
#    'avaniṃ': 1,
#    'ōdi': 1,
#    'hō': 1,
#    'maneyoḷaginiṃ': 1,
#    'nālkariṃ': 1,
#    'tōrisi': 1,
#    'kalliniṃ': 1,
#    'haṇavilla': 1,
#    'dayadiṃ': 1,
#    'ippattariṃ': 1,
#    'baṃ': 1,
#    'kiviyiṃ': 1}},
#  'ddēne': {'count': {'hēḷi': 1,
#    'cennāgi': 1,
#    'nōḍi': 1,
#    'māḍi': 1,
#    'tegedukoṃḍi': 1,
#    'taṃdi': 1,
#    'ōdi': 1,
#    'hōgi': 1,
#    'ōdutti': 1,
#    'baṃdi': 1}},
#  'vannu': {'count': {'viṣaya': 1,
#    'saṃgīta': 1,
#    'patra': 1,
#    'pustaka': 1,
#    'hū': 1,
#    'kelasa': 1}},
#  'va': {'count': {'māḍu': 1,
#    'bareyu': 1,
#    'yā': 1,
#    'hēḷu': 1,
#    'iru': 1,
#    'naḍeyu': 1}},
#  'vudilla': {'count': {'māḍu': 1,
#    'baru': 1,
#    'bareyu': 1,
#    '': 1,
#    'reyu': 1,
#    'yu': 1}},
#  'ttēne': {'count': {'māḍu': 1,
#    'baru': 1,
#    'mugisu': 1,
#    'hōgu': 1,
#    'baredukoḍu': 1,
#    'kareyu': 1,
#    'tōrisu': 1,
#    'baredukoḷḷu': 1}},
#  'venu': {'count': {'māḍu': 1,
#    'ōduttiru': 1,
#    'biḍu': 1,
#    'nōḍu': 1,
#    'vidyārthiyāgiru': 1,
#    'ōdiru': 1,
#    'hāḍu': 1}},
#  'ttade': {'count': {'āgu': 1,
#    'baru': 1,
#    'bēkāgu': 1,
#    'vikāsagoḷḷu': 1,
#    'māḍalāgu': 1,
#    'caḷiyāgu': 1,
#    'māḍalpaḍu': 1,
#    'tōru': 1}},
#  'nannu': {'count': {'maga': 1,
#    'manuṣya': 1,
#    'nan': 1,
#    'huḍuga': 1,
#    'naḍeyuvava': 1}},
#  'giṃta': {'count': {'ellari': 1, 'kurci': 1, 'rāmani': 1}},
#  'yalu': {'count': {'kali': 1, 'bare': 1}},
#  'valla': {'count': {'pustaka': 1, 'mara': 1, 'iṣṭa': 1}},
#  'gaḷannu': {'count': {'pustaka': 1, 'haṇṇu': 1, 'citra': 1, 'patrike': 1}},
#  'dāgi': {'count': {'doḍḍa': 1, 'keṭṭa': 1}},
#  '-': {'count': {'vidhy': 1,
#    'bare': 1,
#    'vidyārthiyāgiru': 1,
#    'ba': 1,
#    'vidyārthiyāgiral': 1,
#    'māva': 1}},
#  'ttiddenu': {'count': {'baru': 1, 'ōdu': 1}},
#  'dalli': {'count': {'saṃgrahālaya': 1,
#    'māḍi': 1,
#    'dēvasthāna': 1,
#    'sammēḷana': 1}},
#  'vāgali': {'count': {'guruvāra': 1, 'śukravāra': 1}},
#  'nige': {'count': {'manuṣya': 1, 'huḍuga': 1, 'ava': 1}},
#  'vāgi': {'count': {'aparūpa': 1, 'nija': 1, 'suṃdara': 1, 'krūra': 1}},
#  'ṃda': {'count': {'ti': 1,
#    'kaiyi': 1,
#    'avani': 1,
#    'ba': 1,
#    'maneyoḷagini': 1,
#    'nālkari': 1,
#    'kallini': 1,
#    'dayadi': 1,
#    'ippattari': 1,
#    'kiviyi': 1}},
#  'yuva': {'count': {'bare': 1, 'naḍe': 1}},
#  'navarē': {'count': {'rāmappa': 1, 'sītamma': 1, 'rāmayya': 1}},
#  'ya': {'count': {'mane': 1,
#    'manuṣ': 1,
#    'viṣa': 1,
#    'sama': 1,
#    'asādh': 1,
#    'bhāṣe': 1,
#    'sādh': 1,
#    'haḷe': 1}},
#  'ttīri': {'count': {'hōgu': 1, 'tagoḷḷu': 1}},
#  'yiṃda': {'count': {'kai': 1, 'kivi': 1}}}

# %%
from collections import Counter

# Go through the results again, word by word, and check if the word has a stem with a suffix

for result in results:
    sentence, translated_sentence, pos_info = result
    transliterations = sentence.split()
    
    # Convert pos_info.items() to a list to support indexing
    pos_items = list(pos_info.items())
    
    for i,(word, info) in enumerate(pos_items):
        if info['affix'] is not None:
            prefix = info['affix']['prefix']
            suffix = info['affix']['suffix']
            
            # Check if the suffix is in the productive suffixes
            if suffix in productive_suffixes:
                # Add POS tag for the stem, POS tag for the previous word and POS tag for the next word into suffix_info[suffix]
                stem = word[:-len(suffix)] if len(suffix) > 0 else word
                
                # Get POS tags
                stem_pos = info.get('pos', [])
                prev_pos = pos_items[i-1][1].get('pos', []) if i > 0 else ['<BOS>']  # Beginning of sentence
                next_pos = pos_items[i+1][1].get('pos', []) if i < len(pos_items)-1 else ['<EOS>']  # End of sentence
                
                # Get translation tokens if available
                trans_tokens = []
                if translated_sentence:
                    trans_tokens = translated_sentence.lower().split()
                
                # Initialize or update the add_info stats for this suffix
                if suffix not in suffix_info:
                    suffix_info[suffix] = {
                        'count': defaultdict(int),
                        'stats': {
                            'stem_pos': Counter(),  # POS tags of stems
                            'pos_before': Counter(),  # POS tags of words before
                            'pos_after': Counter(),  # POS tags of words after
                            'trans_tokens': Counter(),  # Translation tokens
                            'lemma_set': set()  # Set of unique translations
                        }
                    }
                
                # Update statistics
                suffix_info[suffix]['count'][stem] += 1
                
                # Update POS tag counts
                if 'stats' not in suffix_info[suffix]:
                    suffix_info[suffix]['stats'] = {
                        'stem_pos': Counter(),
                        'pos_before': Counter(),
                        'pos_after': Counter(), 
                    }
                if stem_pos:
                    suffix_info[suffix]['stats']['stem_pos'].update(stem_pos)
                for pos in prev_pos:
                    suffix_info[suffix]['stats']['pos_before'][pos] += 1
                for pos in next_pos:
                    suffix_info[suffix]['stats']['pos_after'][pos] += 1

                # Update translation tokens
                if translated_sentence:  # Only add translation tokens if we have a translated sentence
                    if 'trans_tokens' not in suffix_info[suffix]['stats']:
                        suffix_info[suffix]['trans_tokens'] = []
                    try:
                        suffix_info[suffix]['stats']['trans_tokens'].update(trans_tokens)
                    except KeyError:
                        print(suffix_info[suffix]['stats'])
                # Add translation to lemma set if available
                if info.get('translation'):
                    suffix_info[suffix]['stats']['lemma_set'].add(info['translation'])
# Out:
# {'stem_pos': Counter({'NOUN': 2}), 'pos_before': Counter({'PRON': 4, 'PUNCT': 2}), 'pos_after': Counter({'<EOS>': 2})}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 72
#      70 # Add translation to lemma set if available
#      71 if info.get('translation'):
# ---> 72     suffix_info[suffix]['stats']['lemma_set'].add(info['translation'])
#
# KeyError: 'lemma_set'

# %%
# PRINT
for suffix, info in suffix_info.items():
    print(f"Suffix: {suffix}")
    print(f"  Count: {len(info['count'])} stems")
    #for stem, count in info['count'].items():
    #
    #     print(f"  Stem: {stem}, Count: {count}")
    if "add_info" in info:
        add_info = info["add_info"]
        print(f"  Stem: {add_info['stem']}, POS: {add_info['pos']}, Previous POS: {add_info['prev_pos']}, Next POS: {add_info['next_pos']}")
    print("=========================================")
# Out:
# Suffix: vā
#   Count: 4 stems
# =========================================
# Suffix: ge
#   Count: 24 stems
# =========================================
# Suffix: nu
#   Count: 63 stems
# =========================================
# Suffix: nnu
#   Count: 29 stems
# =========================================
# Suffix: gaḷu
#   Count: 12 stems
# =========================================
# Suffix: yā
#   Count: 4 stems
# =========================================
# Suffix: du
#   Count: 28 stems
# =========================================
# Suffix: lla
#   Count: 34 stems
# =========================================
# Suffix: de
#   Count: 24 stems
# =========================================
# Suffix: varu
#   Count: 7 stems
# =========================================
# Suffix: ttāne
#   Count: 5 stems
# =========================================
# Suffix: villa
#   Count: 2 stems
# =========================================
# Suffix: ru
#   Count: 32 stems
# =========================================
# Suffix: daru
#   Count: 8 stems
# =========================================
# Suffix: da
#   Count: 25 stems
# =========================================
# Suffix: ddēne
#   Count: 10 stems
# =========================================
# Suffix: vannu
#   Count: 6 stems
# =========================================
# Suffix: va
#   Count: 6 stems
# =========================================
# Suffix: vudilla
#   Count: 6 stems
# =========================================
# Suffix: ttēne
#   Count: 8 stems
# =========================================
# Suffix: venu
#   Count: 7 stems
# =========================================
# Suffix: ttade
#   Count: 8 stems
# =========================================
# Suffix: nannu
#   Count: 5 stems
# =========================================
# Suffix: giṃta
#   Count: 3 stems
# =========================================
# Suffix: yalu
#   Count: 2 stems
# =========================================
# Suffix: valla
#   Count: 3 stems
# =========================================
# Suffix: gaḷannu
#   Count: 4 stems
# =========================================
# Suffix: dāgi
#   Count: 2 stems
# =========================================
# Suffix: -
#   Count: 6 stems
# =========================================
# Suffix: ttiddenu
#   Count: 2 stems
# =========================================
# Suffix: dalli
#   Count: 4 stems
# =========================================
# Suffix: vāgali
#   Count: 2 stems
# =========================================
# Suffix: nige
#   Count: 3 stems
# =========================================
# Suffix: vāgi
#   Count: 4 stems
# =========================================
# Suffix: ṃda
#   Count: 10 stems
# =========================================
# Suffix: yuva
#   Count: 2 stems
# =========================================
# Suffix: navarē
#   Count: 3 stems
# =========================================
# Suffix: ya
#   Count: 8 stems
# =========================================
# Suffix: ttīri
#   Count: 2 stems
# =========================================
# Suffix: yiṃda
#   Count: 2 stems
# =========================================

# %% [markdown]
# # Unimorph morphology mapping

# %%
import pandas as pd

df = pd.read_csv("data/unimorph_eng.txt",sep="\t",header=None)

df
# Out:
#                       0                1             2
# 0             microtome       microtomes          N;PL
# 1             microtome       microtomes    V;PRS;3;SG
# 2             microtome      microtoming  V;V.PTCP;PRS
# 3             microtome       microtomed         V;PST
# 4             microtome       microtomed  V;V.PTCP;PST
# ...                 ...              ...           ...
# 652472       myriadaire       myriadaire          N;SG
# 652473     dibridgehead     dibridgehead          N;SG
# 652474       Chicagoese       Chicagoese          N;SG
# 652475           Druzer           Druzer          N;SG
# 652476  electrosensible  electrosensible          N;SG
#
# [652477 rows x 3 columns]

# %%
# For each row in the dictionary of kan to eng, check the mapping for the eng
import re
from tqdm import tqdm
count = 0

no_unimorph = []
unimorph_mapping = {}

for row in tqdm(kan_to_eng_mapping.items()):
    kan_word = row[0]
    eng_word = row[1]

    # clean the eng word
    
    # Remove content in brackets (Unless the entire content is in brackets)
    if eng_word.startswith('(') and eng_word.endswith(')'):
        eng_word_clean = eng_word.strip('()').strip()
    else:
        eng_word_clean = re.sub(r'\(.*?\)', '', eng_word).strip()
    # If there is a comma, split by it and take the first part TODO: Check if both words give same unimorph
    if ',' in eng_word_clean:
        eng_word_clean = eng_word_clean.split(',')[0].strip()

    # If there is a / in the eng_word, split by it and take the first part
    if '/' in eng_word_clean:
        eng_word_clean = eng_word_clean.split('/')[0].strip()

    if ';' in eng_word_clean:
        eng_word_clean = eng_word_clean.split(';')[0].strip()

    if eng_word_clean == "":
        print(eng_word)

    # Check if the eng_word is in the df
    if eng_word_clean in df[1].values:
        

        
        # Get the row index
        row_index = df[df[1] == eng_word_clean].index[0]
        
        # Get the unimorph value
        unimorph_value = df.iloc[row_index]
        unimorph_value_str = "|".join(unimorph_value)
        #print(f"{kan_word} -> {eng_word_clean}, Unimorph: {str(unimorph_value)}")
        unimorph_mapping[kan_word] = {
            "eng_word": eng_word_clean,
            "eng_word_full": eng_word,
            "unimorph": unimorph_value[2],
            "stem": unimorph_value[0],
        }
        count+=1
    else:
        #print(f"{kan_word} -> {eng_word}, Unimorph: Not found")
        if eng_word_clean.startswith("to"):

            # Just get the verb form and add infinitive form
            eng_word_verb = eng_word_clean.replace("to", "").strip()
            if eng_word_verb in df[1].values:
                row_index = df[df[1] == eng_word_verb].index[0]
                unimorph_value = df.iloc[row_index]
                unimorph_value_str = "|".join(unimorph_value)
                #print(f"{kan_word} -> {eng_word_clean}, Unimorph: {str(unimorph_value)}")
                unimorph_mapping[kan_word] = {
                    "eng_word": eng_word_clean,
                    "eng_word_full": eng_word,
                    "unimorph": "V;NFIN",
                    "unimorph_value_str": unimorph_value_str,
                    "stem": unimorph_value[0],
                }
                count+=1
            else:

                no_unimorph.append((eng_word_clean,eng_word))

print(f"Total number of words with unimorph mapping: {count} / {len(kan_to_eng_mapping)}")
# Out:
# 100%|██████████| 773/773 [00:21<00:00, 35.24it/s]
# Total number of words with unimorph mapping: 534 / 773

# %%
no_unimorph
# Out:
# [('top side', 'top side'),
#  ('to lie down', 'to lie down, sleep'),
#  ('to set out', 'to set out, leave for'),
#  ('to cause to call', 'to cause to call'),
#  ('to be obtained', 'to be obtained, to be met'),
#  ('to be seen', 'to be seen, appear'),
#  ('today’s', 'today’s, of today'),
#  ('together with', 'together with'),
#  ('to everything', 'to everything (dative)'),
#  ('to the tenth man', 'to the tenth man'),
#  ('to sit down', 'to sit down'),
#  ('to be defeated', 'to be defeated'),
#  ('to sink down', 'to sink down / collapse'),
#  ('to be tired', 'to be tired'),
#  ('to be obtained', 'to be obtained'),
#  ('to speak falsehood', 'to speak falsehood / lie'),
#  ('to carry off', 'to carry off'),
#  ('to become wet', 'to become wet'),
#  ('to be hidden', 'to be hidden'),
#  ('to become branched', 'to become branched'),
#  ('to be', 'to be'),
#  ('to be bored', 'to be bored'),
#  ('to give birth', 'to give birth'),
#  ('to bear a burden', 'to bear a burden'),
#  ('to be spoilt', 'to be spoilt'),
#  ('to put on', 'to put on (dress)')]

# %%
eng_word = "interest (neuter)"
eng_word = re.sub(r'\(.*?\)', '', eng_word).strip()
eng_word
# Out:
# 'interest'

# %%
unimorph_mapping
# Out:
# {'ōḍu': {'eng_word': 'to run',
#   'eng_word_full': 'to run',
#   'unimorph': 'V;V.PTCP;PST;NFIN',
#   'unimorph_value_str': 'rin|run|V;V.PTCP;PST',
#   'stem': 'rin'},
#  'ōdu': {'eng_word': 'to read',
#   'eng_word_full': 'to read',
#   'unimorph': 'V;PST;NFIN',
#   'unimorph_value_str': 'read|read|V;PST',
#   'stem': 'read'},
#  'hēḷu': {'eng_word': 'to say',
#   'eng_word_full': 'to say',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'say|say|V;NFIN;IMP+SBJV',
#   'stem': 'say'},
#  'hēlu': {'eng_word': 'to shit',
#   'eng_word_full': 'to shit',
#   'unimorph': 'V;PST;NFIN',
#   'unimorph_value_str': 'shit|shit|V;PST',
#   'stem': 'shit'},
#  'baḍi': {'eng_word': 'to beat',
#   'eng_word_full': 'to beat',
#   'unimorph': 'V;PST;NFIN',
#   'unimorph_value_str': 'beat|beat|V;PST',
#   'stem': 'beat'},
#  'baḍḍi': {'eng_word': 'interest',
#   'eng_word_full': 'interest (on money)',
#   'unimorph': 'N;SG',
#   'stem': 'interest'},
#  'nīnu': {'eng_word': 'you',
#   'eng_word_full': 'you (singular and non-honorific)',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'you'},
#  'nīvu': {'eng_word': 'you',
#   'eng_word_full': 'you (plural / honorific)',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'you'},
#  'adu': {'eng_word': 'it',
#   'eng_word_full': 'it / that',
#   'unimorph': 'V;PST',
#   'stem': 'it'},
#  'idu': {'eng_word': 'it',
#   'eng_word_full': 'it / this',
#   'unimorph': 'V;PST',
#   'stem': 'it'},
#  'ivaru': {'eng_word': 'he',
#   'eng_word_full': 'he / she (honorific)',
#   'unimorph': 'N;SG',
#   'stem': 'he'},
#  'ili': {'eng_word': 'mouse',
#   'eng_word_full': 'mouse, rat',
#   'unimorph': 'N;SG',
#   'stem': 'mouse'},
#  'kālu': {'eng_word': 'leg',
#   'eng_word_full': 'leg, foot',
#   'unimorph': 'N;SG',
#   'stem': 'leg'},
#  'kai': {'eng_word': 'hand',
#   'eng_word_full': 'hand, arm',
#   'unimorph': 'N;SG',
#   'stem': 'hand'},
#  'graṃtha': {'eng_word': 'book',
#   'eng_word_full': 'book, volume',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'book'},
#  'doḍḍa': {'eng_word': 'big',
#   'eng_word_full': 'big, large',
#   'unimorph': 'N;SG',
#   'stem': 'big'},
#  'beṭṭa': {'eng_word': 'hill',
#   'eng_word_full': 'hill, mountain',
#   'unimorph': 'N;SG',
#   'stem': 'hill'},
#  'maidāna': {'eng_word': 'lawn',
#   'eng_word_full': 'lawn, field',
#   'unimorph': 'N;SG',
#   'stem': 'lawn'},
#  'sāmānugaḷu': {'eng_word': 'things',
#   'eng_word_full': 'things, belongings',
#   'unimorph': 'N;PL',
#   'stem': 'thing'},
#  'hāḍugāra': {'eng_word': 'singer',
#   'eng_word_full': 'singer (male)',
#   'unimorph': 'N;SG',
#   'stem': 'singer'},
#  'hāḍugārti': {'eng_word': 'singer',
#   'eng_word_full': 'singer (female)',
#   'unimorph': 'N;SG',
#   'stem': 'singer'},
#  'ivara': {'eng_word': 'his',
#   'eng_word_full': 'his / her (honorific)',
#   'unimorph': 'N;PL',
#   'stem': 'hi'},
#  'baru': {'eng_word': 'to come',
#   'eng_word_full': 'to come',
#   'unimorph': 'ADJ',
#   'stem': 'to come'},
#  'bassu': {'eng_word': 'bus',
#   'eng_word_full': 'bus (vehicle)',
#   'unimorph': 'N;SG',
#   'stem': 'bus'},
#  'sari': {'eng_word': 'okay',
#   'eng_word_full': 'okay, all right, correct',
#   'unimorph': 'N;SG',
#   'stem': 'okay'},
#  'kere': {'eng_word': 'tank',
#   'eng_word_full': 'tank, water reservoir',
#   'unimorph': 'N;SG',
#   'stem': 'tank'},
#  'cīla': {'eng_word': 'bag',
#   'eng_word_full': 'bag, purse',
#   'unimorph': 'N;SG',
#   'stem': 'bag'},
#  'dēśa': {'eng_word': 'country',
#   'eng_word_full': 'country, land',
#   'unimorph': 'N;SG',
#   'stem': 'country'},
#  'puṭa': {'eng_word': 'page',
#   'eng_word_full': 'page (of book etc.)',
#   'unimorph': 'N;SG',
#   'stem': 'page'},
#  'snēhita': {'eng_word': 'friend',
#   'eng_word_full': 'friend (male)',
#   'unimorph': 'N;SG',
#   'stem': 'friend'},
#  'snēhite': {'eng_word': 'friend',
#   'eng_word_full': 'friend (female)',
#   'unimorph': 'N;SG',
#   'stem': 'friend'},
#  'aṃgaḍi': {'eng_word': 'store',
#   'eng_word_full': 'store, shop',
#   'unimorph': 'N;SG',
#   'stem': 'store'},
#  'jana': {'eng_word': 'person',
#   'eng_word_full': 'person, people',
#   'unimorph': 'N;SG',
#   'stem': 'person'},
#  'āgu': {'eng_word': 'to become',
#   'eng_word_full': 'to become, occur',
#   'unimorph': 'V;V.PTCP;PST;NFIN',
#   'unimorph_value_str': 'become|become|V;V.PTCP;PST',
#   'stem': 'become'},
#  'jigi': {'eng_word': 'to jump',
#   'eng_word_full': 'to jump',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'jump|jump|V;NFIN;IMP+SBJV',
#   'stem': 'jump'},
#  'kare': {'eng_word': 'to call',
#   'eng_word_full': 'to call',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'call|call|N;SG',
#   'stem': 'call'},
#  'taru': {'eng_word': 'to bring',
#   'eng_word_full': 'to bring',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'bring|bring|V;NFIN;IMP+SBJV',
#   'stem': 'bring'},
#  'tiḷi': {'eng_word': 'to understand',
#   'eng_word_full': 'to understand',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'understand|understand|V;NFIN;IMP+SBJV',
#   'stem': 'understand'},
#  'nagu': {'eng_word': 'to laugh',
#   'eng_word_full': 'to laugh',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'laugh|laugh|N;SG',
#   'stem': 'laugh'},
#  'bīḷu': {'eng_word': 'to fall',
#   'eng_word_full': 'to fall',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'fall|fall|N;SG',
#   'stem': 'fall'},
#  'māḍu': {'eng_word': 'to do',
#   'eng_word_full': 'to do, make',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'do|do|V;NFIN;IMP+SBJV',
#   'stem': 'do'},
#  'hoḍe': {'eng_word': 'to hit',
#   'eng_word_full': 'to hit, strike',
#   'unimorph': 'V;PST;NFIN',
#   'unimorph_value_str': 'hit|hit|V;PST',
#   'stem': 'hit'},
#  'hōgu': {'eng_word': 'to go',
#   'eng_word_full': 'to go',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'go|go|V;NFIN;IMP+SBJV',
#   'stem': 'go'},
#  'nōḍu': {'eng_word': 'to watch',
#   'eng_word_full': 'to watch, look at',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'watch|watch|N;SG',
#   'stem': 'watch'},
#  'bare': {'eng_word': 'to write',
#   'eng_word_full': 'to write',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'write|write|V;NFIN;IMP+SBJV',
#   'stem': 'write'},
#  'anna': {'eng_word': 'rice',
#   'eng_word_full': 'rice (cooked)',
#   'unimorph': 'N;SG',
#   'stem': 'rice'},
#  'ūṭa': {'eng_word': 'meal',
#   'eng_word_full': '(cooked) meal',
#   'unimorph': 'N;SG',
#   'stem': 'meal'},
#  'koḍu': {'eng_word': 'to give',
#   'eng_word_full': 'to give',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'give|give|V;NFIN;IMP+SBJV',
#   'stem': 'give'},
#  'viṣaya': {'eng_word': 'matter',
#   'eng_word_full': 'matter, thing, topic',
#   'unimorph': 'N;SG',
#   'stem': 'matter'},
#  'hiṃde': {'eng_word': 'behind',
#   'eng_word_full': 'behind, ago',
#   'unimorph': 'N;SG',
#   'stem': 'behind'},
#  'āyitu': {'eng_word': 'all right',
#   'eng_word_full': 'all right, okay',
#   'unimorph': 'ADJ',
#   'stem': 'all right'},
#  'iḍu': {'eng_word': 'to place',
#   'eng_word_full': 'to place, put',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'place|place|N;SG',
#   'stem': 'place'},
#  'kaḍe': {'eng_word': 'side',
#   'eng_word_full': 'side, direction',
#   'unimorph': 'N;SG',
#   'stem': 'side'},
#  'kōṇe': {'eng_word': 'room',
#   'eng_word_full': 'room, chamber',
#   'unimorph': 'ADJ',
#   'stem': 'room'},
#  'tagoḷḷu': {'eng_word': 'to take',
#   'eng_word_full': 'to take',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'take|take|V;NFIN;IMP+SBJV',
#   'stem': 'take'},
#  'tuṃba': {'eng_word': 'very',
#   'eng_word_full': 'very, much, many',
#   'unimorph': 'ADJ',
#   'stem': 'very'},
#  'darśana': {'eng_word': 'seeing',
#   'eng_word_full': 'seeing, sight, ritual viewing of an object of reverence',
#   'unimorph': 'V;V.PTCP;PRS',
#   'stem': 'see'},
#  'nija': {'eng_word': 'real',
#   'eng_word_full': 'real, true',
#   'unimorph': 'N;SG',
#   'stem': 'real'},
#  'nijavāgi': {'eng_word': 'really',
#   'eng_word_full': 'really, truly',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'really'},
#  'pradēśa': {'eng_word': 'region',
#   'eng_word_full': 'region, area',
#   'unimorph': 'N;SG',
#   'stem': 'region'},
#  'bāḷu': {'eng_word': 'to live',
#   'eng_word_full': 'to live',
#   'unimorph': 'N;PL;NFIN',
#   'unimorph_value_str': 'livetrap|live|N;PL',
#   'stem': 'livetrap'},
#  'bhakta': {'eng_word': 'devotee',
#   'eng_word_full': 'devotee, follower',
#   'unimorph': 'N;SG',
#   'stem': 'devotee'},
#  'śatamāna': {'eng_word': 'century',
#   'eng_word_full': 'century (100 years)',
#   'unimorph': 'N;SG',
#   'stem': 'century'},
#  'bēre': {'eng_word': 'other',
#   'eng_word_full': 'other, something else',
#   'unimorph': 'N;SG',
#   'stem': 'other'},
#  'rīti': {'eng_word': 'style',
#   'eng_word_full': 'style, kind',
#   'unimorph': 'N;SG',
#   'stem': 'style'},
#  'asahya': {'eng_word': 'intolerable',
#   'eng_word_full': 'intolerable, disgusting',
#   'unimorph': 'ADJ',
#   'stem': 'intolerable'},
#  'āḍu': {'eng_word': 'to play',
#   'eng_word_full': 'to play',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'play|play|V;NFIN;IMP+SBJV',
#   'stem': 'play'},
#  'iṣṭa': {'eng_word': 'liked',
#   'eng_word_full': 'liked, appreciated',
#   'unimorph': 'V;PST',
#   'stem': 'like'},
#  'ūru': {'eng_word': 'place',
#   'eng_word_full': 'place, village, town, ‘native place’, city',
#   'unimorph': 'N;SG',
#   'stem': 'place'},
#  'kēḷu': {'eng_word': 'to ask',
#   'eng_word_full': 'to ask, to hear',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'ask|ask|V;NFIN;IMP+SBJV',
#   'stem': 'ask'},
#  'jāga': {'eng_word': 'place',
#   'eng_word_full': 'place, space, spot',
#   'unimorph': 'N;SG',
#   'stem': 'place'},
#  'manuṣya': {'eng_word': 'human',
#   'eng_word_full': 'human, person',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'human'},
#  'mūrti': {'eng_word': 'icon',
#   'eng_word_full': 'icon, statue',
#   'unimorph': 'N;SG',
#   'stem': 'icon'},
#  'mōkṣa': {'eng_word': 'liberation',
#   'eng_word_full': '(religious) liberation',
#   'unimorph': 'N;SG',
#   'stem': 'liberation'},
#  'hoṃdu': {'eng_word': 'to acquire',
#   'eng_word_full': 'to acquire, achieve',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'acquire|acquire|V;NFIN;IMP+SBJV',
#   'stem': 'acquire'},
#  'kelasadavaḷu': {'eng_word': 'housemaid',
#   'eng_word_full': 'housemaid (‘of-the-work she’)',
#   'unimorph': 'N;SG',
#   'stem': 'housemaid'},
#  'maneyavaru': {'eng_word': 'spouse',
#   'eng_word_full': 'spouse (‘of-the-house person’)',
#   'unimorph': 'N;SG',
#   'stem': 'spouse'},
#  'gurutu': {'eng_word': 'mark',
#   'eng_word_full': 'mark, characteristic',
#   'unimorph': 'N;SG',
#   'stem': 'mark'},
#  'jāsti': {'eng_word': 'too much',
#   'eng_word_full': 'too much, excessively',
#   'unimorph': 'ADJ',
#   'stem': 'too much'},
#  'tanna': {'eng_word': 'his',
#   'eng_word_full': 'his / her / its own',
#   'unimorph': 'N;PL',
#   'stem': 'hi'},
#  'samudra': {'eng_word': 'sea',
#   'eng_word_full': 'sea, ocean',
#   'unimorph': 'N;SG',
#   'stem': 'sea'},
#  'hattira': {'eng_word': 'near',
#   'eng_word_full': 'near; nearness',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'near'},
#  'heccu': {'eng_word': 'much',
#   'eng_word_full': 'much, a lot, very',
#   'unimorph': 'ADJ',
#   'stem': 'much'},
#  'iḷi': {'eng_word': 'to descend',
#   'eng_word_full': 'to descend, go down',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'descend|descend|V;NFIN;IMP+SBJV',
#   'stem': 'descend'},
#  'kadi': {'eng_word': 'to steal',
#   'eng_word_full': 'to steal',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'steal|steal|V;NFIN;IMP+SBJV',
#   'stem': 'steal'},
#  'kāpāḍu': {'eng_word': 'to protect',
#   'eng_word_full': 'to protect, guard',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'protect|protect|V;NFIN;IMP+SBJV',
#   'stem': 'protect'},
#  'koḷḷu': {'eng_word': 'to buy',
#   'eng_word_full': 'to buy',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'buy|buy|V;NFIN;IMP+SBJV',
#   'stem': 'buy'},
#  'jōru': {'eng_word': 'force',
#   'eng_word_full': 'force, forcefulness',
#   'unimorph': 'N;SG',
#   'stem': 'force'},
#  'tīvra': {'eng_word': 'severe',
#   'eng_word_full': 'severe, intense',
#   'unimorph': 'ADJ',
#   'stem': 'severe'},
#  'naḍe': {'eng_word': 'to walk',
#   'eng_word_full': 'to walk, to happen',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'walk|walk|V;NFIN;IMP+SBJV',
#   'stem': 'walk'},
#  'paḍu': {'eng_word': 'to suffer',
#   'eng_word_full': 'to suffer, experience, undergo',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'suffer|suffer|V;NFIN;IMP+SBJV',
#   'stem': 'suffer'},
#  'bayyu': {'eng_word': 'to abuse',
#   'eng_word_full': 'to abuse, scold',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'abuse|abuse|N;SG',
#   'stem': 'abuse'},
#  'beḷe': {'eng_word': 'to grow',
#   'eng_word_full': 'to grow',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'grow|grow|V;NFIN;IMP+SBJV',
#   'stem': 'grow'},
#  'bhāgavahisu': {'eng_word': 'to participate',
#   'eng_word_full': 'to participate',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'participate|participate|V;NFIN;IMP+SBJV',
#   'stem': 'participate'},
#  'mātanāḍu': {'eng_word': 'to speak',
#   'eng_word_full': 'to speak',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'speak|speak|V;NFIN;IMP+SBJV',
#   'stem': 'speak'},
#  'lēkhaki': {'eng_word': 'writer',
#   'eng_word_full': 'writer (feminine)',
#   'unimorph': 'N;SG',
#   'stem': 'writer'},
#  'vāpasu': {'eng_word': 'back',
#   'eng_word_full': 'back, returned',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'back'},
#  'sustu': {'eng_word': 'tiredness',
#   'eng_word_full': 'tiredness, fatigue',
#   'unimorph': 'N;SG',
#   'stem': 'tiredness'},
#  'sogasu': {'eng_word': 'grace',
#   'eng_word_full': 'grace, elegance, beauty',
#   'unimorph': 'N;SG',
#   'stem': 'grace'},
#  'hattu': {'eng_word': 'to climb',
#   'eng_word_full': 'to climb; to begin',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'climb|climb|V;NFIN;IMP+SBJV',
#   'stem': 'climb'},
#  'hāḍu': {'eng_word': 'song',
#   'eng_word_full': 'song; to sing',
#   'unimorph': 'N;SG',
#   'stem': 'song'},
#  'hāru': {'eng_word': 'to fly',
#   'eng_word_full': 'to fly, jump',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'fly|fly|V;NFIN;IMP+SBJV',
#   'stem': 'fly'},
#  'prakaṭa': {'eng_word': 'published',
#   'eng_word_full': 'published, public',
#   'unimorph': 'V;PST',
#   'stem': 'publish'},
#  'prayatna': {'eng_word': 'attempt',
#   'eng_word_full': 'attempt, try, effort',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'attempt'},
#  'bēga': {'eng_word': 'fast',
#   'eng_word_full': 'fast, soon',
#   'unimorph': 'N;SG',
#   'stem': 'fast'},
#  'vicitra': {'eng_word': 'strange',
#   'eng_word_full': 'strange, odd',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'strange'},
#  'araḷu': {'eng_word': 'to bloom',
#   'eng_word_full': 'to bloom, blossom',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'bloom|bloom|N;SG',
#   'stem': 'bloom'},
#  'neraḷu': {'eng_word': 'shade',
#   'eng_word_full': 'shade, shadow',
#   'unimorph': 'N;SG',
#   'stem': 'shade'},
#  'mātu': {'eng_word': 'word',
#   'eng_word_full': 'word, utterance',
#   'unimorph': 'N;SG',
#   'stem': 'word'},
#  'vāsa': {'eng_word': 'living',
#   'eng_word_full': 'living, dwelling',
#   'unimorph': 'V;V.PTCP;PRS',
#   'stem': 'live'},
#  'suddi': {'eng_word': 'news',
#   'eng_word_full': 'news, message',
#   'unimorph': 'N;SG',
#   'stem': 'news'},
#  'āse': {'eng_word': 'desire',
#   'eng_word_full': 'desire, wish',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'desire'},
#  'oḍati': {'eng_word': 'mistress',
#   'eng_word_full': 'mistress, owner',
#   'unimorph': 'N;SG',
#   'stem': 'mistress'},
#  'kāraṇa': {'eng_word': 'cause',
#   'eng_word_full': 'cause, reason',
#   'unimorph': 'N;SG',
#   'stem': 'cause'},
#  'gottu': {'eng_word': 'knowledge',
#   'eng_word_full': 'knowledge, known thing',
#   'unimorph': 'N;SG',
#   'stem': 'knowledge'},
#  'pavitra': {'eng_word': 'pure',
#   'eng_word_full': 'pure, holy',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'pure'},
#  'pūjisu': {'eng_word': 'to worship',
#   'eng_word_full': 'to worship',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'worship|worship|N;SG',
#   'stem': 'worship'},
#  'bahaḷa': {'eng_word': 'much',
#   'eng_word_full': 'much, many, very',
#   'unimorph': 'ADJ',
#   'stem': 'much'},
#  'baḷasu': {'eng_word': 'to use',
#   'eng_word_full': 'to use',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'use|use|N;SG',
#   'stem': 'use'},
#  'śakti': {'eng_word': 'energy',
#   'eng_word_full': 'energy, power',
#   'unimorph': 'N;SG',
#   'stem': 'energy'},
#  'śukravāra': {'eng_word': 'energy',
#   'eng_word_full': 'energy, power',
#   'unimorph': 'N;SG',
#   'stem': 'energy'},
#  'hedaru': {'eng_word': 'to fear',
#   'eng_word_full': 'to fear',
#   'unimorph': 'ADJ;NFIN',
#   'unimorph_value_str': 'fear|fear|ADJ',
#   'stem': 'fear'},
#  'anubhavisu': {'eng_word': 'to experience',
#   'eng_word_full': 'to experience',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'experience|experience|N;SG',
#   'stem': 'experience'},
#  'naṃbu': {'eng_word': 'to believe',
#   'eng_word_full': 'to believe',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'believe|believe|V;NFIN;IMP+SBJV',
#   'stem': 'believe'},
#  'baduku': {'eng_word': 'to live',
#   'eng_word_full': 'to live',
#   'unimorph': 'N;PL;NFIN',
#   'unimorph_value_str': 'livetrap|live|N;PL',
#   'stem': 'livetrap'},
#  'Basavaṇṇa': {'eng_word': 'name',
#   'eng_word_full': '(name, ‘elder brother B.’)',
#   'unimorph': 'N;SG',
#   'stem': 'name'},
#  'mānava': {'eng_word': 'human',
#   'eng_word_full': 'human, person',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'human'},
#  'vyakti': {'eng_word': 'person',
#   'eng_word_full': 'person, individual',
#   'unimorph': 'N;SG',
#   'stem': 'person'},
#  'saṃbhavisu': {'eng_word': 'to arise',
#   'eng_word_full': 'to arise, originate',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'arise|arise|V;NFIN;IMP+SBJV',
#   'stem': 'arise'},
#  'āga': {'eng_word': 'then',
#   'eng_word_full': 'then, that time',
#   'unimorph': 'ADJ',
#   'stem': 'then'},
#  'uḷi': {'eng_word': 'to remain',
#   'eng_word_full': 'to remain',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'remain|remain|N;SG',
#   'stem': 'remain'},
#  'kali': {'eng_word': 'to learn',
#   'eng_word_full': 'to learn',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'learn|learn|V;NFIN;IMP+SBJV',
#   'stem': 'learn'},
#  'guḍḍa': {'eng_word': 'hill',
#   'eng_word_full': 'hill, hillock',
#   'unimorph': 'N;SG',
#   'stem': 'hill'},
#  'neṃṭa': {'eng_word': 'relative',
#   'eng_word_full': '(blood-) relative',
#   'unimorph': 'N;SG',
#   'stem': 'relative'},
#  'pradhāna': {'eng_word': 'main',
#   'eng_word_full': 'main, chief',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'main'},
#  'prāṇa': {'eng_word': 'life',
#   'eng_word_full': 'life, life force',
#   'unimorph': 'N;SG',
#   'stem': 'life'},
#  'balakaḍe': {'eng_word': 'right',
#   'eng_word_full': 'right (side)',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'right'},
#  'beṃḍekāyi': {'eng_word': 'okra',
#   'eng_word_full': 'okra, ‘ladies’ fingers’',
#   'unimorph': 'N;SG',
#   'stem': 'okra'},
#  'muṃcitavāgi': {'eng_word': 'beforehand',
#   'eng_word_full': 'beforehand, earlier',
#   'unimorph': 'ADJ',
#   'stem': 'beforehand'},
#  'muṃduvari': {'eng_word': 'to continue',
#   'eng_word_full': 'to continue',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'continue|continue|V;NFIN;IMP+SBJV',
#   'stem': 'continue'},
#  'mugi': {'eng_word': 'to end',
#   'eng_word_full': 'to end (intr.)',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'end|end|N;SG',
#   'stem': 'end'},
#  'mugisu': {'eng_word': 'to end',
#   'eng_word_full': 'to end, finish (trans.)',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'end|end|N;SG',
#   'stem': 'end'},
#  'rūḍhi': {'eng_word': 'custom',
#   'eng_word_full': 'custom, usage',
#   'unimorph': 'ADJ',
#   'stem': 'custom'},
#  'rūpa': {'eng_word': 'form',
#   'eng_word_full': 'form, shape',
#   'unimorph': 'N;SG',
#   'stem': 'form'},
#  'lābha': {'eng_word': 'profit',
#   'eng_word_full': 'profit, advantage',
#   'unimorph': 'N;SG',
#   'stem': 'profit'},
#  'hāgū': {'eng_word': 'and',
#   'eng_word_full': 'and, also',
#   'unimorph': 'ADJ;CMPR',
#   'stem': 'null and void'},
#  'oṃdu': {'eng_word': 'one',
#   'eng_word_full': 'one, a',
#   'unimorph': 'N;SG',
#   'stem': 'one'},
#  'oṃdannu': {'eng_word': 'one',
#   'eng_word_full': 'one (specific accusative)',
#   'unimorph': 'N;SG',
#   'stem': 'one'},
#  'oṃdakke': {'eng_word': 'to one',
#   'eng_word_full': 'to one',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'one|one|N;SG',
#   'stem': 'one'},
#  'eraḍannu': {'eng_word': 'two',
#   'eng_word_full': 'two (specific accusative)',
#   'unimorph': 'N;SG',
#   'stem': 'two'},
#  'mūrakke': {'eng_word': 'to three',
#   'eng_word_full': 'to three',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'three|three|N;SG',
#   'stem': 'three'},
#  'ari': {'eng_word': 'to know',
#   'eng_word_full': 'to know',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'know|know|V;NFIN;IMP+SBJV',
#   'stem': 'know'},
#  'mare': {'eng_word': 'to forget',
#   'eng_word_full': 'to forget',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'forget|forget|V;NFIN;IMP+SBJV',
#   'stem': 'forget'},
#  'ennu': {'eng_word': 'to say',
#   'eng_word_full': 'to say',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'say|say|V;NFIN;IMP+SBJV',
#   'stem': 'say'},
#  'tinnu': {'eng_word': 'to eat',
#   'eng_word_full': 'to eat',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'eat|eat|V;NFIN;IMP+SBJV',
#   'stem': 'eat'},
#  'kāyu': {'eng_word': 'to wait',
#   'eng_word_full': 'to wait / grow hot',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'wait|wait|V;NFIN;IMP+SBJV',
#   'stem': 'wait'},
#  'sīnu': {'eng_word': 'to sneeze',
#   'eng_word_full': 'to sneeze',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'sneeze|sneeze|V;NFIN;IMP+SBJV',
#   'stem': 'sneeze'},
#  'ese': {'eng_word': 'to throw',
#   'eng_word_full': 'to throw',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'throw|throw|V;NFIN;IMP+SBJV',
#   'stem': 'throw'},
#  'kuri': {'eng_word': 'to aim',
#   'eng_word_full': 'to aim',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'aim|aim|N;SG',
#   'stem': 'aim'},
#  'koḷe': {'eng_word': 'to rot',
#   'eng_word_full': 'to rot',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'rot|rot|V;NFIN;IMP+SBJV',
#   'stem': 'rot'},
#  'bese': {'eng_word': 'to solder',
#   'eng_word_full': 'to solder',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'solder|solder|N;SG',
#   'stem': 'solder'},
#  'mase': {'eng_word': 'to whet',
#   'eng_word_full': 'to whet',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'whet|whet|V;NFIN;IMP+SBJV',
#   'stem': 'whet'},
#  'moḷe': {'eng_word': 'to sprout',
#   'eng_word_full': 'to sprout',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'sprout|sprout|N;SG',
#   'stem': 'sprout'},
#  'āyu': {'eng_word': 'to choose',
#   'eng_word_full': 'to choose',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'choose|choose|V;NFIN;IMP+SBJV',
#   'stem': 'choose'},
#  'koyyu': {'eng_word': 'to reap',
#   'eng_word_full': 'to reap, pluck',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'reap|reap|V;NFIN;IMP+SBJV',
#   'stem': 'reap'},
#  'geyyu': {'eng_word': 'to make',
#   'eng_word_full': 'to make',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'make|make|V;NFIN;IMP+SBJV',
#   'stem': 'make'},
#  'tēyu': {'eng_word': 'to grind',
#   'eng_word_full': 'to grind',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'grind|grind|N;SG',
#   'stem': 'grind'},
#  'mēyu': {'eng_word': 'to graze',
#   'eng_word_full': 'to graze',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'graze|graze|N;SG',
#   'stem': 'graze'},
#  'suyyu': {'eng_word': 'to sigh',
#   'eng_word_full': 'to sigh',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'sigh|sigh|V;NFIN;IMP+SBJV',
#   'stem': 'sigh'},
#  'hāyu': {'eng_word': 'to cross over',
#   'eng_word_full': 'to cross over',
#   'unimorph': 'ADJ;NFIN',
#   'unimorph_value_str': 'cross over|cross over|ADJ',
#   'stem': 'cross over'},
#  'ciguru': {'eng_word': 'to sprout',
#   'eng_word_full': 'to sprout',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'sprout|sprout|N;SG',
#   'stem': 'sprout'},
#  'bevaru': {'eng_word': 'to perspire',
#   'eng_word_full': 'to perspire',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'perspire|perspire|V;NFIN;IMP+SBJV',
#   'stem': 'perspire'},
#  'nāru': {'eng_word': 'to stink',
#   'eng_word_full': 'to stink',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'stink|stink|V;NFIN;IMP+SBJV',
#   'stem': 'stink'},
#  'teru': {'eng_word': 'to pay',
#   'eng_word_full': 'to pay',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'pay|pay|V;NFIN;IMP+SBJV',
#   'stem': 'pay'},
#  'kollu': {'eng_word': 'to kill',
#   'eng_word_full': 'to kill',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'kill|kill|V;NFIN;IMP+SBJV',
#   'stem': 'kill'},
#  'gellu': {'eng_word': 'to win',
#   'eng_word_full': 'to win, overcome',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'win|win|V;NFIN;IMP+SBJV',
#   'stem': 'win'},
#  'nillu': {'eng_word': 'to stand',
#   'eng_word_full': 'to stand',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'stand|stand|V;NFIN;IMP+SBJV',
#   'stem': 'stand'},
#  'aḷu': {'eng_word': 'to weep',
#   'eng_word_full': 'to weep',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'weep|weep|V;NFIN;IMP+SBJV',
#   'stem': 'weep'},
#  'uḷu': {'eng_word': 'to plough',
#   'eng_word_full': 'to plough',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'plough|plough|N;SG',
#   'stem': 'plough'},
#  'ēḷu': {'eng_word': 'to rise',
#   'eng_word_full': 'to rise',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'rise|rise|V;NFIN;IMP+SBJV',
#   'stem': 'rise'},
#  'kaḷu': {'eng_word': 'to steal',
#   'eng_word_full': 'to steal',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'steal|steal|V;NFIN;IMP+SBJV',
#   'stem': 'steal'},
#  'kīḷu': {'eng_word': 'to pluck',
#   'eng_word_full': 'to pluck, pick',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'pluck|pluck|V;NFIN;IMP+SBJV',
#   'stem': 'pluck'},
#  'mīyu': {'eng_word': 'to bathe',
#   'eng_word_full': 'to bathe',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'bathe|bathe|V;NFIN;IMP+SBJV',
#   'stem': 'bathe'},
#  'aḍu': {'eng_word': 'to cook',
#   'eng_word_full': 'to cook',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'cook|cook|V;NFIN;IMP+SBJV',
#   'stem': 'cook'},
#  'uḍu': {'eng_word': 'to dress',
#   'eng_word_full': 'to dress',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'dress|dress|V;NFIN;IMP+SBJV',
#   'stem': 'dress'},
#  'toḍu': {'eng_word': 'to dress',
#   'eng_word_full': 'to dress',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'dress|dress|V;NFIN;IMP+SBJV',
#   'stem': 'dress'},
#  'neḍu': {'eng_word': 'to plant',
#   'eng_word_full': 'to plant',
#   'unimorph': 'N;SG;NFIN',
#   'unimorph_value_str': 'plant|plant|N;SG',
#   'stem': 'plant'},
#  'biḍu': {'eng_word': 'to leave',
#   'eng_word_full': 'to leave',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'leave|leave|V;NFIN;IMP+SBJV',
#   'stem': 'leave'},
#  'suḍu': {'eng_word': 'to burn',
#   'eng_word_full': 'to burn',
#   'unimorph': 'ADJ',
#   'stem': 'to burn'},
#  'uṇṇu': {'eng_word': 'to eat',
#   'eng_word_full': 'to eat',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'eat|eat|V;NFIN;IMP+SBJV',
#   'stem': 'eat'},
#  'kāṇu': {'eng_word': 'to see',
#   'eng_word_full': 'to see',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'see|see|V;NFIN;IMP+SBJV',
#   'stem': 'see'},
#  'hogu': {'eng_word': 'to enter',
#   'eng_word_full': 'to enter',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'enter|enter|V;NFIN;IMP+SBJV',
#   'stem': 'enter'},
#  'ode': {'eng_word': 'to kick',
#   'eng_word_full': 'to kick',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'kick|kick|V;NFIN;IMP+SBJV',
#   'stem': 'kick'},
#  'eḷe': {'eng_word': 'to pull',
#   'eng_word_full': 'to pull',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'pull|pull|V;NFIN;IMP+SBJV',
#   'stem': 'pull'},
#  'tege': {'eng_word': 'to take',
#   'eng_word_full': 'to take',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'take|take|V;NFIN;IMP+SBJV',
#   'stem': 'take'},
#  'mlēccha': {'eng_word': 'barbarian',
#   'eng_word_full': 'barbarian, foreigner',
#   'unimorph': 'N;SG',
#   'stem': 'barbarian'},
#  'adannu': {'eng_word': 'that',
#   'eng_word_full': 'that (accusative case)',
#   'unimorph': 'N;SG',
#   'stem': 'that'},
#  'daya': {'eng_word': 'grace',
#   'eng_word_full': 'grace, mercy',
#   'unimorph': 'N;SG',
#   'stem': 'grace'},
#  'mara': {'eng_word': 'tree',
#   'eng_word_full': 'tree, wood',
#   'unimorph': 'N;SG',
#   'stem': 'tree'},
#  'yaśasvi': {'eng_word': 'glorious',
#   'eng_word_full': 'glorious, successful',
#   'unimorph': 'ADJ',
#   'stem': 'glorious'},
#  'uṃṭāgu': {'eng_word': 'to arise',
#   'eng_word_full': 'to arise, originate',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'arise|arise|V;NFIN;IMP+SBJV',
#   'stem': 'arise'},
#  'uṃṭumāḍu': {'eng_word': 'to create',
#   'eng_word_full': 'to create',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'create|create|V;NFIN;IMP+SBJV',
#   'stem': 'create'},
#  'korate': {'eng_word': 'defect',
#   'eng_word_full': 'defect, shortcoming',
#   'unimorph': 'N;SG',
#   'stem': 'defect'},
#  'nāśa': {'eng_word': 'destruction',
#   'eng_word_full': 'destruction, ruin',
#   'unimorph': 'N;SG',
#   'stem': 'destruction'},
#  'mahatva': {'eng_word': 'greatness',
#   'eng_word_full': 'greatness, importance',
#   'unimorph': 'N;SG',
#   'stem': 'greatness'},
#  'rēkhē': {'eng_word': 'stripe',
#   'eng_word_full': 'stripe, line',
#   'unimorph': 'N;SG',
#   'stem': 'stripe'},
#  'svabhāva': {'eng_word': 'nature',
#   'eng_word_full': 'nature, character',
#   'unimorph': 'N;SG',
#   'stem': 'nature'},
#  'haccu': {'eng_word': 'to smear',
#   'eng_word_full': 'to smear, apply',
#   'unimorph': 'V;NFIN;IMP+SBJV;NFIN',
#   'unimorph_value_str': 'smear|smear|V;NFIN;IMP+SBJV',
#   'stem': 'smear'},
#  'huḷi': {'eng_word': 'sour',
#   'eng_word_full': 'sour',
#   'unimorph': 'N;SG',
#   'stem': 'sour'},
#  'huli': {'eng_word': 'tiger',
#   'eng_word_full': 'tiger',
#   'unimorph': 'N;SG',
#   'stem': 'tiger'},
#  'haḷḷi': {'eng_word': 'village',
#   'eng_word_full': 'village',
#   'unimorph': 'N;SG',
#   'stem': 'village'},
#  'halli': {'eng_word': 'lizard',
#   'eng_word_full': 'lizard',
#   'unimorph': 'N;SG',
#   'stem': 'lizard'},
#  'maṇe': {'eng_word': 'stool',
#   'eng_word_full': 'stool',
#   'unimorph': 'N;SG',
#   'stem': 'stool'},
#  'mane': {'eng_word': 'house',
#   'eng_word_full': 'house',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'house'},
#  'hālu': {'eng_word': 'milk',
#   'eng_word_full': 'milk',
#   'unimorph': 'N;SG',
#   'stem': 'milk'},
#  'hallu': {'eng_word': 'tooth',
#   'eng_word_full': 'tooth',
#   'unimorph': 'N;SG',
#   'stem': 'tooth'},
#  'dēva': {'eng_word': 'god',
#   'eng_word_full': 'god',
#   'unimorph': 'N;SG',
#   'stem': 'god'},
#  'devva': {'eng_word': 'spirit',
#   'eng_word_full': 'spirit',
#   'unimorph': 'N;SG',
#   'stem': 'spirit'},
#  'avanu': {'eng_word': 'he',
#   'eng_word_full': 'he',
#   'unimorph': 'N;SG',
#   'stem': 'he'},
#  'avaḷu': {'eng_word': 'she',
#   'eng_word_full': 'she',
#   'unimorph': 'N;SG',
#   'stem': 'she'},
#  'ivanu': {'eng_word': 'he',
#   'eng_word_full': 'he',
#   'unimorph': 'N;SG',
#   'stem': 'he'},
#  'ivaḷu': {'eng_word': 'she',
#   'eng_word_full': 'she',
#   'unimorph': 'N;SG',
#   'stem': 'she'},
#  'illi': {'eng_word': 'here',
#   'eng_word_full': 'here',
#   'unimorph': 'ADJ',
#   'stem': 'here'},
#  'alli': {'eng_word': 'there',
#   'eng_word_full': 'there',
#   'unimorph': 'N;SG',
#   'stem': 'there'},
#  'īga': {'eng_word': 'now',
#   'eng_word_full': 'now',
#   'unimorph': 'ADJ',
#   'stem': 'now'},
#  'almāri': {'eng_word': 'closet',
#   'eng_word_full': 'closet',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'closet'},
#  'ākāśa': {'eng_word': 'sky',
#   'eng_word_full': 'sky',
#   'unimorph': 'N;SG',
#   'stem': 'sky'},
#  'ivattu': {'eng_word': 'today',
#   'eng_word_full': 'today',
#   'unimorph': 'N;SG',
#   'stem': 'today'},
#  'eraḍu': {'eng_word': 'two',
#   'eng_word_full': 'two',
#   'unimorph': 'N;SG',
#   'stem': 'two'},
#  'aidu': {'eng_word': 'five',
#   'eng_word_full': 'five',
#   'unimorph': 'N;SG',
#   'stem': 'five'},
#  'kaṃpyūṭaru': {'eng_word': 'computer',
#   'eng_word_full': 'computer',
#   'unimorph': 'N;SG',
#   'stem': 'computer'},
#  'kaṭṭaḍa': {'eng_word': 'building',
#   'eng_word_full': 'building',
#   'unimorph': 'V;V.PTCP;PRS',
#   'stem': 'build'},
#  'kāgada': {'eng_word': 'paper',
#   'eng_word_full': 'paper',
#   'unimorph': 'ADJ',
#   'stem': 'paper'},
#  'kāḍu': {'eng_word': 'forest',
#   'eng_word_full': 'forest',
#   'unimorph': 'N;SG',
#   'stem': 'forest'},
#  'kāru': {'eng_word': 'car',
#   'eng_word_full': 'car',
#   'unimorph': 'N;SG',
#   'stem': 'car'},
#  'kiṭaki': {'eng_word': 'window',
#   'eng_word_full': 'window',
#   'unimorph': 'N;SG',
#   'stem': 'window'},
#  'kurci': {'eng_word': 'chair',
#   'eng_word_full': 'chair',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'chair'},
#  'gilāsu': {'eng_word': 'glass',
#   'eng_word_full': 'glass',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'glass'},
#  'guri': {'eng_word': 'goal',
#   'eng_word_full': 'goal',
#   'unimorph': 'N;SG',
#   'stem': 'goal'},
#  'guru': {'eng_word': 'teacher',
#   'eng_word_full': 'teacher',
#   'unimorph': 'N;SG',
#   'stem': 'teacher'},
#  'guruvāra': {'eng_word': 'Thursday',
#   'eng_word_full': 'Thursday',
#   'unimorph': 'N;SG',
#   'stem': 'Thursday'},
#  'camaca': {'eng_word': 'spoon',
#   'eng_word_full': 'spoon',
#   'unimorph': 'N;SG',
#   'stem': 'spoon'},
#  'cāku': {'eng_word': 'knife',
#   'eng_word_full': 'knife',
#   'unimorph': 'N;SG',
#   'stem': 'knife'},
#  'cāpe': {'eng_word': 'mat',
#   'eng_word_full': 'mat',
#   'unimorph': 'N;SG',
#   'stem': 'mat'},
#  'cāvi': {'eng_word': 'key',
#   'eng_word_full': 'key',
#   'unimorph': 'N;SG',
#   'stem': 'key'},
#  'citra': {'eng_word': 'picture',
#   'eng_word_full': 'picture',
#   'unimorph': 'N;SG',
#   'stem': 'picture'},
#  'ṭyāksi': {'eng_word': 'taxi',
#   'eng_word_full': 'taxi',
#   'unimorph': 'N;SG',
#   'stem': 'taxi'},
#  'ṭyūbulaiṭu': {'eng_word': 'tubelight',
#   'eng_word_full': 'tubelight',
#   'unimorph': 'N;SG',
#   'stem': 'tubelight'},
#  'taṭṭe': {'eng_word': 'plate',
#   'eng_word_full': 'plate',
#   'unimorph': 'N;SG',
#   'stem': 'plate'},
#  'dīpa': {'eng_word': 'lamp',
#   'eng_word_full': 'lamp',
#   'unimorph': 'N;SG',
#   'stem': 'lamp'},
#  'dēvasthāna': {'eng_word': 'temple',
#   'eng_word_full': 'temple',
#   'unimorph': 'N;SG',
#   'stem': 'temple'},
#  'nālku': {'eng_word': 'four',
#   'eng_word_full': 'four',
#   'unimorph': 'N;SG',
#   'stem': 'four'},
#  'nāḷe': {'eng_word': 'tomorrow',
#   'eng_word_full': 'tomorrow',
#   'unimorph': 'N;SG',
#   'stem': 'tomorrow'},
#  'nela': {'eng_word': 'floor',
#   'eng_word_full': 'floor',
#   'unimorph': 'N;SG',
#   'stem': 'floor'},
#  'noṇa': {'eng_word': 'fly',
#   'eng_word_full': 'fly',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'fly'},
#  'pustaka': {'eng_word': 'book',
#   'eng_word_full': 'book',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'book'},
#  'pensilu': {'eng_word': 'pencil',
#   'eng_word_full': 'pencil',
#   'unimorph': 'N;SG',
#   'stem': 'pencil'},
#  'phorenar': {'eng_word': 'foreigner',
#   'eng_word_full': 'foreigner',
#   'unimorph': 'N;SG',
#   'stem': 'foreigner'},
#  'phōrku': {'eng_word': 'fork',
#   'eng_word_full': 'fork',
#   'unimorph': 'N;SG',
#   'stem': 'fork'},
#  'bāgilu': {'eng_word': 'door',
#   'eng_word_full': 'door',
#   'unimorph': 'N;SG',
#   'stem': 'door'},
#  'budhavāra': {'eng_word': 'Wednesday',
#   'eng_word_full': 'Wednesday',
#   'unimorph': 'N;SG',
#   'stem': 'Wednesday'},
#  'beṃki': {'eng_word': 'fire',
#   'eng_word_full': 'fire',
#   'unimorph': 'N;SG',
#   'stem': 'fire'},
#  'bēli': {'eng_word': 'fence',
#   'eng_word_full': 'fence',
#   'unimorph': 'N;SG',
#   'stem': 'fence'},
#  'bhāratīya': {'eng_word': 'Indian',
#   'eng_word_full': 'Indian',
#   'unimorph': 'ADJ',
#   'stem': 'Indian'},
#  'maṃgaḷavāra': {'eng_word': 'Tuesday',
#   'eng_word_full': 'Tuesday',
#   'unimorph': 'N;SG',
#   'stem': 'Tuesday'},
#  'mattu': {'eng_word': 'and',
#   'eng_word_full': 'and',
#   'unimorph': 'ADJ;CMPR',
#   'stem': 'null and void'},
#  'mahiḷe': {'eng_word': 'lady',
#   'eng_word_full': 'lady',
#   'unimorph': 'N;SG',
#   'stem': 'lady'},
#  'maḷe': {'eng_word': 'rain',
#   'eng_word_full': 'rain',
#   'unimorph': 'N;SG',
#   'stem': 'rain'},
#  'māle': {'eng_word': 'garland',
#   'eng_word_full': 'garland',
#   'unimorph': 'N;SG',
#   'stem': 'garland'},
#  'mūru': {'eng_word': 'three',
#   'eng_word_full': 'three',
#   'unimorph': 'N;SG',
#   'stem': 'three'},
#  'mēju': {'eng_word': 'table',
#   'eng_word_full': 'table',
#   'unimorph': 'N;SG',
#   'stem': 'table'},
#  'mēṇabatti': {'eng_word': 'candle',
#   'eng_word_full': 'candle',
#   'unimorph': 'N;SG',
#   'stem': 'candle'},
#  'mōḍa': {'eng_word': 'cloud',
#   'eng_word_full': 'cloud',
#   'unimorph': 'N;SG',
#   'stem': 'cloud'},
#  'ravivāra': {'eng_word': 'Sunday',
#   'eng_word_full': 'Sunday',
#   'unimorph': 'N;SG',
#   'stem': 'Sunday'},
#  'raste': {'eng_word': 'road',
#   'eng_word_full': 'road',
#   'unimorph': 'N;SG',
#   'stem': 'road'},
#  'rikṣā': {'eng_word': 'rikshaw',
#   'eng_word_full': 'rikshaw',
#   'unimorph': 'N;SG',
#   'stem': 'rikshaw'},
#  'vimāna': {'eng_word': 'airplane',
#   'eng_word_full': 'airplane',
#   'unimorph': 'N;SG',
#   'stem': 'airplane'},
#  'śanivāra': {'eng_word': 'Saturday',
#   'eng_word_full': 'Saturday',
#   'unimorph': 'N;SG',
#   'stem': 'Saturday'},
#  'sūṭkēsu': {'eng_word': 'suitcase',
#   'eng_word_full': 'suitcase',
#   'unimorph': 'N;SG',
#   'stem': 'suitcase'},
#  'sūrya': {'eng_word': 'sun',
#   'eng_word_full': 'sun',
#   'unimorph': 'N;SG',
#   'stem': 'sun'},
#  'sōmavāra': {'eng_word': 'Monday',
#   'eng_word_full': 'Monday',
#   'unimorph': 'N;SG',
#   'stem': 'Monday'},
#  'strī': {'eng_word': 'woman',
#   'eng_word_full': 'woman',
#   'unimorph': 'N;SG',
#   'stem': 'woman'},
#  'hakki': {'eng_word': 'bird',
#   'eng_word_full': 'bird',
#   'unimorph': 'N;SG',
#   'stem': 'bird'},
#  'halavu': {'eng_word': 'many',
#   'eng_word_full': 'many',
#   'unimorph': 'ADJ',
#   'stem': 'many'},
#  'hasu': {'eng_word': 'cow',
#   'eng_word_full': 'cow',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'cow'},
#  'hippi': {'eng_word': 'hippie',
#   'eng_word_full': 'hippie',
#   'unimorph': 'N;SG',
#   'stem': 'hippie'},
#  'huḍuga': {'eng_word': 'boy',
#   'eng_word_full': 'boy',
#   'unimorph': 'N;SG',
#   'stem': 'boy'},
#  'huḍugi': {'eng_word': 'girl',
#   'eng_word_full': 'girl',
#   'unimorph': 'N;SG',
#   'stem': 'girl'},
#  'hū': {'eng_word': 'flower',
#   'eng_word_full': 'flower',
#   'unimorph': 'N;SG',
#   'stem': 'flower'},
#  'heṃgasu': {'eng_word': 'woman',
#   'eng_word_full': 'woman',
#   'unimorph': 'N;SG',
#   'stem': 'woman'},
#  'hola': {'eng_word': 'field',
#   'eng_word_full': 'field',
#   'unimorph': 'N;SG',
#   'stem': 'field'},
#  'haudu': {'eng_word': 'yes',
#   'eng_word_full': 'yes',
#   'unimorph': 'N;SG',
#   'stem': 'yes'},
#  'ēnū illa': {'eng_word': 'nothing',
#   'eng_word_full': 'nothing',
#   'unimorph': 'N;SG',
#   'stem': 'nothing'},
#  'yārū illa': {'eng_word': 'nobody',
#   'eng_word_full': 'nobody',
#   'unimorph': 'N;SG',
#   'stem': 'nobody'},
#  'kappu': {'eng_word': 'black',
#   'eng_word_full': 'black',
#   'unimorph': 'ADJ',
#   'stem': 'black'},
#  'kaṣṭa': {'eng_word': 'difficult',
#   'eng_word_full': 'difficult',
#   'unimorph': 'ADJ',
#   'stem': 'difficult'},
#  'toḍaku': {'eng_word': 'problem',
#   'eng_word_full': 'problem',
#   'unimorph': 'N;SG',
#   'stem': 'problem'},
#  'namma': {'eng_word': 'our',
#   'eng_word_full': 'our',
#   'unimorph': 'N;SG',
#   'stem': 'our'},
#  'patra': {'eng_word': 'letter',
#   'eng_word_full': 'letter',
#   'unimorph': 'N;SG',
#   'stem': 'letter'},
#  'purōhita': {'eng_word': 'priest',
#   'eng_word_full': 'priest',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'priest'},
#  'biḷi': {'eng_word': 'white',
#   'eng_word_full': 'white',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'white'},
#  'samācāra': {'eng_word': 'news',
#   'eng_word_full': 'news',
#   'unimorph': 'N;SG',
#   'stem': 'news'},
#  'hesaru': {'eng_word': 'name',
#   'eng_word_full': 'name',
#   'unimorph': 'N;SG',
#   'stem': 'name'},
#  'appa': {'eng_word': 'father',
#   'eng_word_full': 'father',
#   'unimorph': 'N;SG',
#   'stem': 'father'},
#  'amma': {'eng_word': 'mother',
#   'eng_word_full': 'mother',
#   'unimorph': 'N;SG',
#   'stem': 'mother'},
#  'kaṇṇu': {'eng_word': 'eye',
#   'eng_word_full': 'eye',
#   'unimorph': 'N;SG',
#   'stem': 'eye'},
#  'kivi': {'eng_word': 'ear',
#   'eng_word_full': 'ear',
#   'unimorph': 'N;SG',
#   'stem': 'ear'},
#  'kūsu': {'eng_word': 'baby',
#   'eng_word_full': 'baby',
#   'unimorph': 'N;SG',
#   'stem': 'baby'},
#  'gaṃḍa': {'eng_word': 'husband',
#   'eng_word_full': 'husband',
#   'unimorph': 'N;SG',
#   'stem': 'husband'},
#  'gaṃḍasu': {'eng_word': 'man',
#   'eng_word_full': 'man',
#   'unimorph': 'ADJ;CMPR',
#   'stem': 'every man for himself'},
#  'nighaṃṭu': {'eng_word': 'dictionary',
#   'eng_word_full': 'dictionary',
#   'unimorph': 'N;SG',
#   'stem': 'dictionary'},
#  'nīru': {'eng_word': 'water',
#   'eng_word_full': 'water',
#   'unimorph': 'N;SG',
#   'stem': 'water'},
#  'buṭṭi': {'eng_word': 'basket',
#   'eng_word_full': 'basket',
#   'unimorph': 'N;SG',
#   'stem': 'basket'},
#  'maga': {'eng_word': 'son',
#   'eng_word_full': 'son',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'son'},
#  'magaḷu': {'eng_word': 'daughter',
#   'eng_word_full': 'daughter',
#   'unimorph': 'N;SG',
#   'stem': 'daughter'},
#  'magu': {'eng_word': 'child',
#   'eng_word_full': 'child',
#   'unimorph': 'N;SG',
#   'stem': 'child'},
#  'māva': {'eng_word': 'uncle',
#   'eng_word_full': 'uncle',
#   'unimorph': 'N;SG',
#   'stem': 'uncle'},
#  'rāja': {'eng_word': 'king',
#   'eng_word_full': 'king',
#   'unimorph': 'N;SG',
#   'stem': 'king'},
#  'raita': {'eng_word': 'farmer',
#   'eng_word_full': 'farmer',
#   'unimorph': 'N;SG',
#   'stem': 'farmer'},
#  'vidhave': {'eng_word': 'widow',
#   'eng_word_full': 'widow',
#   'unimorph': 'N;SG',
#   'stem': 'widow'},
#  'anubhava': {'eng_word': 'experience',
#   'eng_word_full': 'experience',
#   'unimorph': 'N;SG',
#   'stem': 'experience'},
#  'āṭike': {'eng_word': 'toy',
#   'eng_word_full': 'toy',
#   'unimorph': 'N;SG',
#   'stem': 'toy'},
#  'āyke': {'eng_word': 'choice',
#   'eng_word_full': 'choice',
#   'unimorph': 'ADJ',
#   'stem': 'choice'},
#  'keṃpu': {'eng_word': 'red',
#   'eng_word_full': 'red',
#   'unimorph': 'V;PST',
#   'stem': 'rede'},
#  'koṃbu': {'eng_word': 'horn',
#   'eng_word_full': 'horn',
#   'unimorph': 'N;SG',
#   'stem': 'horn'},
#  'koṃbe': {'eng_word': 'branch',
#   'eng_word_full': 'branch',
#   'unimorph': 'N;SG',
#   'stem': 'branch'},
#  'cūpu': {'eng_word': 'sharp',
#   'eng_word_full': 'sharp',
#   'unimorph': 'N;SG',
#   'stem': 'sharp'},
#  'tudi': {'eng_word': 'tip',
#   'eng_word_full': 'tip',
#   'unimorph': 'N;SG',
#   'stem': 'tip'},
#  'parimāṇa': {'eng_word': 'size',
#   'eng_word_full': 'size',
#   'unimorph': 'N;SG',
#   'stem': 'size'},
#  'baṭṭe': {'eng_word': 'cloth',
#   'eng_word_full': 'cloth',
#   'unimorph': 'N;SG',
#   'stem': 'cloth'},
#  'baṇṇa': {'eng_word': 'colour',
#   'eng_word_full': 'colour',
#   'unimorph': 'ADJ',
#   'stem': 'colour'},
#  'saṃkhye': {'eng_word': 'number',
#   'eng_word_full': 'number',
#   'unimorph': 'ADJ;CMPR',
#   'stem': 'numb'},
#  'hasiru': {'eng_word': 'green',
#   'eng_word_full': 'green',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'green'},
#  'haḷadi': {'eng_word': 'yellow',
#   'eng_word_full': 'yellow',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'yellow'},
#  'heṃḍati': {'eng_word': 'wife',
#   'eng_word_full': 'wife',
#   'unimorph': 'N;SG',
#   'stem': 'wife'},
#  'nidde': {'eng_word': 'sleep',
#   'eng_word_full': 'sleep',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'sleep'},
#  'nāyi': {'eng_word': 'dog',
#   'eng_word_full': 'dog',
#   'unimorph': 'N;SG',
#   'stem': 'dog'},
#  'kathe': {'eng_word': 'story',
#   'eng_word_full': 'story',
#   'unimorph': 'N;SG',
#   'stem': 'story'},
#  'kelasa': {'eng_word': 'work',
#   'eng_word_full': 'work',
#   'unimorph': 'N;SG',
#   'stem': 'work'},
#  'toṃdare': {'eng_word': 'trouble',
#   'eng_word_full': 'trouble',
#   'unimorph': 'N;SG',
#   'stem': 'trouble'},
#  'nenne': {'eng_word': 'yesterday',
#   'eng_word_full': 'yesterday',
#   'unimorph': 'N;SG',
#   'stem': 'yesterday'},
#  'satya': {'eng_word': 'truth',
#   'eng_word_full': 'truth',
#   'unimorph': 'N;SG',
#   'stem': 'truth'},
#  'haṇṇu': {'eng_word': 'fruit',
#   'eng_word_full': 'fruit',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'fruit'},
#  'mēle': {'eng_word': 'on',
#   'eng_word_full': 'on',
#   'unimorph': 'ADJ',
#   'stem': 'on'},
#  'keḷage': {'eng_word': 'under',
#   'eng_word_full': 'under',
#   'unimorph': 'ADJ',
#   'stem': 'under'},
#  'oḷage': {'eng_word': 'within',
#   'eng_word_full': 'within',
#   'unimorph': 'ADJ',
#   'stem': 'within'},
#  'oḷagu': {'eng_word': 'inside',
#   'eng_word_full': 'inside',
#   'unimorph': 'N;SG',
#   'stem': 'inside'},
#  'bage': {'eng_word': 'thought',
#   'eng_word_full': 'thought',
#   'unimorph': 'V;PST',
#   'stem': 'thinke'},
#  'madhya': {'eng_word': 'middle',
#   'eng_word_full': 'middle',
#   'unimorph': 'N;SG',
#   'stem': 'middle'},
#  'horage': {'eng_word': 'outside',
#   'eng_word_full': 'outside',
#   'unimorph': 'N;SG',
#   'stem': 'outside'},
#  'aḍige': {'eng_word': 'cooking',
#   'eng_word_full': 'cooking',
#   'unimorph': 'V;V.PTCP;PRS',
#   'stem': 'cook'},
#  'uttara': {'eng_word': 'north',
#   'eng_word_full': 'north',
#   'unimorph': 'ADJ',
#   'stem': 'north'},
#  'kāpi': {'eng_word': 'coffee',
#   'eng_word_full': 'coffee',
#   'unimorph': 'N;SG',
#   'stem': 'coffee'},
#  'gaḍi': {'eng_word': 'border',
#   'eng_word_full': 'border',
#   'unimorph': 'N;SG',
#   'stem': 'border'},
#  'cahā': {'eng_word': 'tea',
#   'eng_word_full': 'tea',
#   'unimorph': 'N;SG',
#   'stem': 'tea'},
#  'padārtha': {'eng_word': 'thing',
#   'eng_word_full': 'thing',
#   'unimorph': 'N;SG',
#   'stem': 'thing'},
#  'pavāḍa': {'eng_word': 'miracle',
#   'eng_word_full': 'miracle',
#   'unimorph': 'N;SG',
#   'stem': 'miracle'},
#  'viśēṣavāda': {'eng_word': 'special',
#   'eng_word_full': 'special',
#   'unimorph': 'N;SG',
#   'stem': 'special'},
#  'samādhi': {'eng_word': 'tomb',
#   'eng_word_full': 'tomb',
#   'unimorph': 'N;SG',
#   'stem': 'tomb'},
#  'ele': {'eng_word': 'leaf',
#   'eng_word_full': 'leaf',
#   'unimorph': 'N;SG',
#   'stem': 'leaf'},
#  'athavā': {'eng_word': 'or',
#   'eng_word_full': 'or',
#   'unimorph': 'ADJ',
#   'stem': 'or'},
#  'abhiprāya': {'eng_word': 'opinion',
#   'eng_word_full': 'opinion',
#   'unimorph': 'N;SG',
#   'stem': 'opinion'},
#  'iḍiya': {'eng_word': 'entire',
#   'eng_word_full': 'entire',
#   'unimorph': 'ADJ',
#   'stem': 'entire'},
#  'upayukta': {'eng_word': 'useful',
#   'eng_word_full': 'useful',
#   'unimorph': 'ADJ',
#   'stem': 'useful'},
#  'keṭṭa': {'eng_word': 'bad',
#   'eng_word_full': 'bad',
#   'unimorph': 'N;SG',
#   'stem': 'bad'},
#  'kliṣṭa': {'eng_word': 'complicated',
#   'eng_word_full': 'complicated',
#   'unimorph': 'V;PST',
#   'stem': 'complicate'},
#  'gaddala': {'eng_word': 'noise',
#   'eng_word_full': 'noise',
#   'unimorph': 'N;SG',
#   'stem': 'noise'},
#  'cakravarti': {'eng_word': 'emperor',
#   'eng_word_full': 'emperor',
#   'unimorph': 'N;SG',
#   'stem': 'emperor'},
#  'cikka': {'eng_word': 'small',
#   'eng_word_full': 'small',
#   'unimorph': 'N;SG',
#   'stem': 'small'},
#  'jagattu': {'eng_word': 'world',
#   'eng_word_full': 'world',
#   'unimorph': 'N;SG',
#   'stem': 'world'},
#  'dūra': {'eng_word': 'distance',
#   'eng_word_full': 'distance',
#   'unimorph': 'N;SG',
#   'stem': 'distance'},
#  'nīli': {'eng_word': 'blue',
#   'eng_word_full': 'blue',
#   'unimorph': 'N;SG',
#   'stem': 'blue'},
#  'praśne': {'eng_word': 'question',
#   'eng_word_full': 'question',
#   'unimorph': 'N;SG',
#   'stem': 'question'},
#  'bīdi': {'eng_word': 'street',
#   'eng_word_full': 'street',
#   'unimorph': 'N;SG',
#   'stem': 'street'},
#  'bhāra': {'eng_word': 'weight',
#   'eng_word_full': 'weight',
#   'unimorph': 'N;SG',
#   'stem': 'weight'},
#  'yuga': {'eng_word': 'era',
#   'eng_word_full': 'era',
#   'unimorph': 'N;SG',
#   'stem': 'era'},
#  'saṃgīta': {'eng_word': 'music',
#   'eng_word_full': 'music',
#   'unimorph': 'N;SG',
#   'stem': 'music'},
#  'suṃdara': {'eng_word': 'beautiful',
#   'eng_word_full': 'beautiful',
#   'unimorph': 'N;SG',
#   'stem': 'beautiful'},
#  'kōlu': {'eng_word': 'stick',
#   'eng_word_full': 'stick',
#   'unimorph': 'N;SG',
#   'stem': 'stick'},
#  'ciṃtaka': {'eng_word': 'thinker',
#   'eng_word_full': 'thinker',
#   'unimorph': 'N;SG',
#   'stem': 'thinker'},
#  'tīra': {'eng_word': 'coast',
#   'eng_word_full': 'coast',
#   'unimorph': 'N;SG',
#   'stem': 'coast'},
#  'maṭha': {'eng_word': 'monastery',
#   'eng_word_full': 'monastery',
#   'unimorph': 'N;SG',
#   'stem': 'monastery'},
#  'saṃpradāya': {'eng_word': 'tradition',
#   'eng_word_full': 'tradition',
#   'unimorph': 'N;SG',
#   'stem': 'tradition'},
#  'hadimūraneya': {'eng_word': 'thirteenth',
# ...
#  'dayaviṭṭu': {'eng_word': 'please',
#   'eng_word_full': 'please',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'please'},
#  'pāṭha': {'eng_word': 'lesson',
#   'eng_word_full': 'lesson',
#   'unimorph': 'N;SG',
#   'stem': 'lesson'},
#  'muṃdina': {'eng_word': 'next',
#   'eng_word_full': 'next',
#   'unimorph': 'ADJ',
#   'stem': 'next'},
#  'yōcane': {'eng_word': 'thought',
#   'eng_word_full': 'thought',
#   'unimorph': 'V;PST',
#   'stem': 'thinke'},
#  'vākya': {'eng_word': 'sentence',
#   'eng_word_full': 'sentence',
#   'unimorph': 'N;SG',
#   'stem': 'sentence'},
#  'śabda': {'eng_word': 'word',
#   'eng_word_full': 'word',
#   'unimorph': 'N;SG',
#   'stem': 'word'},
#  'saṃtōṣa': {'eng_word': 'joy',
#   'eng_word_full': 'joy',
#   'unimorph': 'N;SG',
#   'stem': 'joy'},
#  'sammēḷana': {'eng_word': 'conference',
#   'eng_word_full': 'conference',
#   'unimorph': 'N;SG',
#   'stem': 'conference'},
#  'spaṣṭa': {'eng_word': 'clear',
#   'eng_word_full': 'clear',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'clear'},
#  'artha': {'eng_word': 'meaning',
#   'eng_word_full': 'meaning',
#   'unimorph': 'V;V.PTCP;PRS',
#   'stem': 'mean'},
#  'ādare': {'eng_word': 'but',
#   'eng_word_full': 'but',
#   'unimorph': 'N;SG',
#   'stem': 'but'},
#  'kṣame': {'eng_word': 'forgiveness',
#   'eng_word_full': 'forgiveness',
#   'unimorph': 'N;SG',
#   'stem': 'forgiveness'},
#  'hōṭalu': {'eng_word': 'restaurant',
#   'eng_word_full': 'restaurant',
#   'unimorph': 'N;SG',
#   'stem': 'restaurant'},
#  'adhyāpaka': {'eng_word': 'teacher',
#   'eng_word_full': 'teacher',
#   'unimorph': 'N;SG',
#   'stem': 'teacher'},
#  'kōpa': {'eng_word': 'anger',
#   'eng_word_full': 'anger',
#   'unimorph': 'N;SG',
#   'stem': 'anger'},
#  'graṃthapālaka': {'eng_word': 'librarian',
#   'eng_word_full': 'librarian',
#   'unimorph': 'N;SG',
#   'stem': 'librarian'},
#  'graṃthālaya': {'eng_word': 'library',
#   'eng_word_full': 'library',
#   'unimorph': 'N;SG',
#   'stem': 'library'},
#  'patrike': {'eng_word': 'magazine',
#   'eng_word_full': 'magazine',
#   'unimorph': 'N;SG',
#   'stem': 'magazine'},
#  'sahāya': {'eng_word': 'help',
#   'eng_word_full': 'help',
#   'unimorph': 'N;SG',
#   'stem': 'help'},
#  'hemme': {'eng_word': 'pride',
#   'eng_word_full': 'pride',
#   'unimorph': 'N;SG',
#   'stem': 'pride'},
#  'hōguvike': {'eng_word': 'going',
#   'eng_word_full': 'going',
#   'unimorph': 'V;V.PTCP;PRS',
#   'stem': 'go'},
#  'bāḷike': {'eng_word': 'living',
#   'eng_word_full': 'living',
#   'unimorph': 'V;V.PTCP;PRS',
#   'stem': 'live'},
#  'ārōgya': {'eng_word': 'health',
#   'eng_word_full': 'health',
#   'unimorph': 'N;SG',
#   'stem': 'health'},
#  'gōḍe': {'eng_word': 'wall',
#   'eng_word_full': 'wall',
#   'unimorph': 'N;SG',
#   'stem': 'wall'},
#  'māṃsa': {'eng_word': 'meat',
#   'eng_word_full': 'meat',
#   'unimorph': 'N;SG',
#   'stem': 'meat'},
#  'miliṭari': {'eng_word': 'military',
#   'eng_word_full': 'military',
#   'unimorph': 'ADJ',
#   'stem': 'military'},
#  'auṣadhi': {'eng_word': 'medicine',
#   'eng_word_full': 'medicine',
#   'unimorph': 'N;SG',
#   'stem': 'medicine'},
#  'kaṭṭe': {'eng_word': 'mount',
#   'eng_word_full': 'mount',
#   'unimorph': 'N;SG',
#   'stem': 'mount'},
#  'giḍa': {'eng_word': 'plant',
#   'eng_word_full': 'plant',
#   'unimorph': 'N;SG',
#   'stem': 'plant'},
#  'dēvi': {'eng_word': 'goddess',
#   'eng_word_full': 'goddess',
#   'unimorph': 'N;SG',
#   'stem': 'goddess'},
#  'patni': {'eng_word': 'wife',
#   'eng_word_full': 'wife',
#   'unimorph': 'N;SG',
#   'stem': 'wife'},
#  'pradakṣiṇe': {'eng_word': 'circumambulation',
#   'eng_word_full': 'circumambulation',
#   'unimorph': 'N;SG',
#   'stem': 'circumambulation'},
#  'bhakti': {'eng_word': 'devotion',
#   'eng_word_full': 'devotion',
#   'unimorph': 'N;SG',
#   'stem': 'devotion'},
#  'mātra': {'eng_word': 'only',
#   'eng_word_full': 'only',
#   'unimorph': 'ADJ',
#   'stem': 'only'},
#  'saṃpattu': {'eng_word': 'wealth',
#   'eng_word_full': 'wealth',
#   'unimorph': 'N;SG',
#   'stem': 'wealth'},
#  'sādhya': {'eng_word': 'possible',
#   'eng_word_full': 'possible',
#   'unimorph': 'N;SG',
#   'stem': 'possible'},
#  'sulabha': {'eng_word': 'easy',
#   'eng_word_full': 'easy',
#   'unimorph': 'N;SG',
#   'stem': 'easy'},
#  'saubhāgya': {'eng_word': 'well-being',
#   'eng_word_full': 'well-being',
#   'unimorph': 'N;SG',
#   'stem': 'well-being'},
#  'atṛpta': {'eng_word': 'dissatisfied',
#   'eng_word_full': 'dissatisfied',
#   'unimorph': 'V;PST',
#   'stem': 'dissatisfy'},
#  'atṛpti': {'eng_word': 'dissatisfaction',
#   'eng_word_full': 'dissatisfaction',
#   'unimorph': 'N;SG',
#   'stem': 'dissatisfaction'},
#  'anubhāvi': {'eng_word': 'mystic',
#   'eng_word_full': 'mystic',
#   'unimorph': 'N;SG',
#   'stem': 'mystic'},
#  'anuyāyi': {'eng_word': 'follower',
#   'eng_word_full': 'follower',
#   'unimorph': 'N;SG',
#   'stem': 'follower'},
#  'asamānate': {'eng_word': 'inequality',
#   'eng_word_full': 'inequality',
#   'unimorph': 'N;SG',
#   'stem': 'inequality'},
#  'kuṭuṃba': {'eng_word': 'family',
#   'eng_word_full': 'family',
#   'unimorph': 'ADJ',
#   'stem': 'family'},
#  'kelavomme': {'eng_word': 'sometimes',
#   'eng_word_full': 'sometimes',
#   'unimorph': 'ADJ',
#   'stem': 'sometimes'},
#  'guṃpu': {'eng_word': 'group',
#   'eng_word_full': 'group',
#   'unimorph': 'N;SG',
#   'stem': 'group'},
#  'jāti': {'eng_word': 'caste',
#   'eng_word_full': 'caste',
#   'unimorph': 'N;SG',
#   'stem': 'caste'},
#  'jīvana': {'eng_word': 'life',
#   'eng_word_full': 'life',
#   'unimorph': 'N;SG',
#   'stem': 'life'},
#  'tṛpta': {'eng_word': 'satisfied',
#   'eng_word_full': 'satisfied',
#   'unimorph': 'V;PST',
#   'stem': 'satisfy'},
#  'tṛpti': {'eng_word': 'satisfaction',
#   'eng_word_full': 'satisfaction',
#   'unimorph': 'N;SG',
#   'stem': 'satisfaction'},
#  'dhārmika': {'eng_word': 'religious',
#   'eng_word_full': 'religious',
#   'unimorph': 'ADJ',
#   'stem': 'religious'},
#  'naitika': {'eng_word': 'moral',
#   'eng_word_full': 'moral',
#   'unimorph': 'N;SG',
#   'stem': 'moral'},
#  'paraṃpare': {'eng_word': 'tradition',
#   'eng_word_full': 'tradition',
#   'unimorph': 'N;SG',
#   'stem': 'tradition'},
#  'prapaṃca': {'eng_word': 'world',
#   'eng_word_full': 'world',
#   'unimorph': 'N;SG',
#   'stem': 'world'},
#  'prācīna': {'eng_word': 'ancient',
#   'eng_word_full': 'ancient',
#   'unimorph': 'N;SG',
#   'stem': 'ancient'},
#  'prīti': {'eng_word': 'love',
#   'eng_word_full': 'love',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'love'},
#  'Basava': {'eng_word': 'name',
#   'eng_word_full': '(name)',
#   'unimorph': 'N;SG',
#   'stem': 'name'},
#  'beḷavaṇige': {'eng_word': 'development',
#   'eng_word_full': 'development',
#   'unimorph': 'N;SG',
#   'stem': 'development'},
#  'maṃdi': {'eng_word': 'person',
#   'eng_word_full': 'person',
#   'unimorph': 'N;SG',
#   'stem': 'person'},
#  'manassu': {'eng_word': 'mind',
#   'eng_word_full': 'mind',
#   'unimorph': 'N;SG',
#   'stem': 'mind'},
#  'samāna': {'eng_word': 'equal',
#   'eng_word_full': 'equal',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'equal'},
#  'samānate': {'eng_word': 'equality',
#   'eng_word_full': 'equality',
#   'unimorph': 'N;SG',
#   'stem': 'equality'},
#  'sāmājika': {'eng_word': 'social',
#   'eng_word_full': 'social',
#   'unimorph': 'ADJ',
#   'stem': 'social'},
#  'hinnele': {'eng_word': 'background',
#   'eng_word_full': 'background',
#   'unimorph': 'ADJ',
#   'stem': 'background'},
#  'hosa': {'eng_word': 'new',
#   'eng_word_full': 'new',
#   'unimorph': 'N;SG',
#   'stem': 'new'},
#  'anēka': {'eng_word': 'many',
#   'eng_word_full': 'many',
#   'unimorph': 'ADJ',
#   'stem': 'many'},
#  'ippataidu': {'eng_word': 'twenty-five',
#   'eng_word_full': 'twenty-five',
#   'unimorph': 'N;SG',
#   'stem': 'twenty-five'},
#  'karāvaḷi': {'eng_word': 'coast',
#   'eng_word_full': 'coast',
#   'unimorph': 'N;SG',
#   'stem': 'coast'},
#  'kaḷatmaka': {'eng_word': 'artistic',
#   'eng_word_full': 'artistic',
#   'unimorph': 'ADJ',
#   'stem': 'artistic'},
#  'kāphi': {'eng_word': 'coffee',
#   'eng_word_full': 'coffee',
#   'unimorph': 'N;SG',
#   'stem': 'coffee'},
#  'kāryakrama': {'eng_word': 'program',
#   'eng_word_full': 'program',
#   'unimorph': 'N;SG',
#   'stem': 'program'},
#  'kuḍuma': {'eng_word': 'placename',
#   'eng_word_full': '(placename)',
#   'unimorph': 'N;SG',
#   'stem': 'placename'},
#  'kēṃdra': {'eng_word': 'centre',
#   'eng_word_full': 'centre',
#   'unimorph': 'N;SG',
#   'stem': 'centre'},
#  'cikitsālaya': {'eng_word': 'clinic',
#   'eng_word_full': 'clinic',
#   'unimorph': 'N;SG',
#   'stem': 'clinic'},
#  'jille': {'eng_word': 'district',
#   'eng_word_full': 'district',
#   'unimorph': 'N;SG',
#   'stem': 'district'},
#  'taṃde': {'eng_word': 'father',
#   'eng_word_full': 'father',
#   'unimorph': 'N;SG',
#   'stem': 'father'},
#  'tale': {'eng_word': 'head',
#   'eng_word_full': 'head',
#   'unimorph': 'ADJ',
#   'stem': 'head'},
#  'talenōvu': {'eng_word': 'headache',
#   'eng_word_full': 'headache',
#   'unimorph': 'N;SG',
#   'stem': 'headache'},
#  'dēvate': {'eng_word': 'divinity',
#   'eng_word_full': 'divinity',
#   'unimorph': 'N;SG',
#   'stem': 'divinity'},
#  'Dharmasthaḷa': {'eng_word': 'placename',
#   'eng_word_full': '(placename)',
#   'unimorph': 'N;SG',
#   'stem': 'placename'},
#  'nōvu': {'eng_word': 'pain',
#   'eng_word_full': 'pain',
#   'unimorph': 'N;SG',
#   'stem': 'pain'},
#  'paṃḍita': {'eng_word': 'scholar',
#   'eng_word_full': 'scholar',
#   'unimorph': 'N;SG',
#   'stem': 'scholar'},
#  'pūrvaja': {'eng_word': 'ancestor',
#   'eng_word_full': 'ancestor',
#   'unimorph': 'N;SG',
#   'stem': 'ancestor'},
#  'Maṃjunātha': {'eng_word': 'name',
#   'eng_word_full': '(name)',
#   'unimorph': 'N;SG',
#   'stem': 'name'},
#  'yātrika': {'eng_word': 'pilgrim',
#   'eng_word_full': 'pilgrim',
#   'unimorph': 'N;SG',
#   'stem': 'pilgrim'},
#  'rakṣaṇe': {'eng_word': 'protection',
#   'eng_word_full': 'protection',
#   'unimorph': 'N;SG',
#   'stem': 'protection'},
#  'varṣa': {'eng_word': 'year',
#   'eng_word_full': 'year',
#   'unimorph': 'N;SG',
#   'stem': 'year'},
#  'Vādirāja': {'eng_word': 'name',
#   'eng_word_full': '(name)',
#   'unimorph': 'N;SG',
#   'stem': 'name'},
#  'śikṣaka': {'eng_word': 'teacher',
#   'eng_word_full': 'teacher',
#   'unimorph': 'N;SG',
#   'stem': 'teacher'},
#  'saṃgrahālaya': {'eng_word': 'museum',
#   'eng_word_full': 'museum',
#   'unimorph': 'N;SG',
#   'stem': 'museum'},
#  'sahiṣṇute': {'eng_word': 'tolerance',
#   'eng_word_full': 'tolerance',
#   'unimorph': 'N;SG',
#   'stem': 'tolerance'},
#  'sāṃskṛtika': {'eng_word': 'cultural',
#   'eng_word_full': 'cultural',
#   'unimorph': 'ADJ',
#   'stem': 'cultural'},
#  'hadināraneya': {'eng_word': 'sixteenth',
#   'eng_word_full': 'sixteenth',
#   'unimorph': 'N;SG',
#   'stem': 'sixteenth'},
#  'huṣāru': {'eng_word': 'healthiness',
#   'eng_word_full': 'healthiness',
#   'unimorph': 'N;SG',
#   'stem': 'healthiness'},
#  'ellarannu / ellarannū': {'eng_word': 'accusative',
#   'eng_word_full': '(accusative)',
#   'unimorph': 'N;SG',
#   'stem': 'accusative'},
#  'ellariṃda / ellariṃdalū': {'eng_word': 'ablative',
#   'eng_word_full': '(ablative)',
#   'unimorph': 'N;SG',
#   'stem': 'ablative'},
#  'ellara': {'eng_word': 'genitive',
#   'eng_word_full': '(genitive)',
#   'unimorph': 'ADJ',
#   'stem': 'genitive'},
#  'ellaralli / ellarallū': {'eng_word': 'locative',
#   'eng_word_full': '(locative)',
#   'unimorph': 'N;SG',
#   'stem': 'locative'},
#  'āru': {'eng_word': 'six',
#   'eng_word_full': 'six',
#   'unimorph': 'N;SG',
#   'stem': 'six'},
#  'eṃṭu': {'eng_word': 'eight',
#   'eng_word_full': 'eight',
#   'unimorph': 'N;SG',
#   'stem': 'eight'},
#  'oṃbattu': {'eng_word': 'nine',
#   'eng_word_full': 'nine',
#   'unimorph': 'N;SG',
#   'stem': 'nine'},
#  'hannoṃdu': {'eng_word': 'eleven',
#   'eng_word_full': 'eleven',
#   'unimorph': 'N;SG',
#   'stem': 'eleven'},
#  'hanneraḍu': {'eng_word': 'twelve',
#   'eng_word_full': 'twelve',
#   'unimorph': 'N;SG',
#   'stem': 'twelve'},
#  'ippattu': {'eng_word': 'twenty',
#   'eng_word_full': 'twenty',
#   'unimorph': 'N;SG',
#   'stem': 'twenty'},
#  'ippattoṃdu': {'eng_word': 'twenty-one',
#   'eng_word_full': 'twenty-one',
#   'unimorph': 'N;SG',
#   'stem': 'twenty-one'},
#  'ippatteraḍu': {'eng_word': 'twenty-two',
#   'eng_word_full': 'twenty-two',
#   'unimorph': 'N;SG',
#   'stem': 'twenty-two'},
#  'ippattaidu': {'eng_word': 'twenty-five',
#   'eng_word_full': 'twenty-five',
#   'unimorph': 'N;SG',
#   'stem': 'twenty-five'},
#  'aivattu': {'eng_word': 'fifty',
#   'eng_word_full': 'fifty',
#   'unimorph': 'N;SG',
#   'stem': 'fifty'},
#  'nūru': {'eng_word': 'hundred',
#   'eng_word_full': 'hundred',
#   'unimorph': 'N;SG',
#   'stem': 'hundred'},
#  'oṃbainūru': {'eng_word': '900',
#   'eng_word_full': '900',
#   'unimorph': 'N;SG',
#   'stem': '900'},
#  'āgi': {'eng_word': 'gerund',
#   'eng_word_full': '(gerund)',
#   'unimorph': 'N;SG',
#   'stem': 'gerund'},
#  'hōgi': {'eng_word': 'gerund',
#   'eng_word_full': '(gerund)',
#   'unimorph': 'N;SG',
#   'stem': 'gerund'},
#  'utkhanana': {'eng_word': 'excavation',
#   'eng_word_full': 'excavation',
#   'unimorph': 'N;SG',
#   'stem': 'excavation'},
#  'hagga': {'eng_word': 'rope',
#   'eng_word_full': 'rope',
#   'unimorph': 'N;SG',
#   'stem': 'rope'},
#  'ajja': {'eng_word': 'grandfather',
#   'eng_word_full': 'grandfather',
#   'unimorph': 'N;SG',
#   'stem': 'grandfather'},
#  'jñāna': {'eng_word': 'knowledge',
#   'eng_word_full': 'knowledge',
#   'unimorph': 'N;SG',
#   'stem': 'knowledge'},
#  'daḍḍa': {'eng_word': 'dunce',
#   'eng_word_full': 'dunce',
#   'unimorph': 'N;SG',
#   'stem': 'dunce'},
#  'kobbu': {'eng_word': 'fat',
#   'eng_word_full': 'fat',
#   'unimorph': 'N;SG',
#   'stem': 'fat'},
#  'udbhava': {'eng_word': 'origin',
#   'eng_word_full': 'origin',
#   'unimorph': 'N;SG',
#   'stem': 'origin'},
#  'ayya': {'eng_word': 'lord',
#   'eng_word_full': 'lord',
#   'unimorph': 'N;SG',
#   'stem': 'lord'},
#  'prabhāva': {'eng_word': 'influence',
#   'eng_word_full': 'influence',
#   'unimorph': 'N;SG',
#   'stem': 'influence'},
#  'tatva': {'eng_word': 'principle',
#   'eng_word_full': 'principle',
#   'unimorph': 'N;SG',
#   'stem': 'principle'},
#  'utsava': {'eng_word': 'feast',
#   'eng_word_full': 'feast',
#   'unimorph': 'N;SG',
#   'stem': 'feast'},
#  'kaḷḷa': {'eng_word': 'thief',
#   'eng_word_full': 'thief',
#   'unimorph': 'N;SG',
#   'stem': 'thief'},
#  'bhāṣe': {'eng_word': 'language',
#   'eng_word_full': 'language',
#   'unimorph': 'N;SG',
#   'stem': 'language'},
#  'haḷeya': {'eng_word': 'old',
#   'eng_word_full': 'old',
#   'unimorph': 'N;SG',
#   'stem': 'old'},
#  'aṃgaḍiyavaru': {'eng_word': 'shopkeeper',
#   'eng_word_full': 'shopkeeper',
#   'unimorph': 'N;SG',
#   'stem': 'shopkeeper'},
#  'ajñāna': {'eng_word': 'ignorance',
#   'eng_word_full': 'ignorance',
#   'unimorph': 'N;SG',
#   'stem': 'ignorance'},
#  'nṛtya': {'eng_word': 'dance',
#   'eng_word_full': 'dance',
#   'unimorph': 'N;SG',
#   'stem': 'dance'},
#  'paravā': {'eng_word': 'worry',
#   'eng_word_full': 'worry',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'worry'},
#  'parvata': {'eng_word': 'mountain',
#   'eng_word_full': 'mountain',
#   'unimorph': 'N;SG',
#   'stem': 'mountain'},
#  'baḷi': {'eng_word': 'near',
#   'eng_word_full': 'near',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'near'},
#  'buddhi': {'eng_word': 'intelligence',
#   'eng_word_full': 'intelligence',
#   'unimorph': 'N;SG',
#   'stem': 'intelligence'},
#  'beḷaku': {'eng_word': 'light',
#   'eng_word_full': 'light',
#   'unimorph': 'N;PL',
#   'stem': 'lightbulb'},
#  'bhasma': {'eng_word': 'ash',
#   'eng_word_full': 'ash',
#   'unimorph': 'N;SG',
#   'stem': 'ash'},
#  'majjige': {'eng_word': 'buttermilk',
#   'eng_word_full': 'buttermilk',
#   'unimorph': 'N;SG',
#   'stem': 'buttermilk'},
#  'mūgu': {'eng_word': 'nose',
#   'eng_word_full': 'nose',
#   'unimorph': 'N;SG',
#   'stem': 'nose'},
#  'modalaneya': {'eng_word': 'first',
#   'eng_word_full': 'first',
#   'unimorph': 'N;SG',
#   'stem': 'first'},
#  'rākṣasa': {'eng_word': 'demon',
#   'eng_word_full': 'demon',
#   'unimorph': 'N;SG',
#   'stem': 'demon'},
#  'vimānanildāṇa': {'eng_word': 'airport',
#   'eng_word_full': 'airport',
#   'unimorph': 'N;SG',
#   'stem': 'airport'},
#  'saṃkēta': {'eng_word': 'symbol',
#   'eng_word_full': 'symbol',
#   'unimorph': 'N;SG',
#   'stem': 'symbol'},
#  'saṃsthe': {'eng_word': 'institute',
#   'eng_word_full': 'institute',
#   'unimorph': 'V;NFIN;IMP+SBJV',
#   'stem': 'institute'},
#  'sāṃkētika': {'eng_word': 'symbolic',
#   'eng_word_full': 'symbolic',
#   'unimorph': 'ADJ',
#   'stem': 'symbolic'},
#  'sāmānya': {'eng_word': 'ordinary',
#   'eng_word_full': 'ordinary',
#   'unimorph': 'N;SG',
#   'stem': 'ordinary'},
#  'haṇe': {'eng_word': 'forehead',
#   'eng_word_full': 'forehead',
#   'unimorph': 'N;SG',
#   'stem': 'forehead'}}

# %%
# Save unimorph mapping to a json file
with open("unimorph_mapping.json", "w", encoding="utf-8") as f:
    json.dump(unimorph_mapping, f, ensure_ascii=False, indent=4)

# %%
# Go through the parallel sentences and create a data with the POS tag of each word and unimorph mapping of each word
parallel_sentences_with_pos_and_unimorph = []
for result in processed_sentences:
    sentence, translated_sentence, pos_info = result
    pos_unimorph_info = {}
    
    for word in sentence.split():
        word = word.lower()
        word = word.strip('.,!?()[]/"!')  # Remove punctuation from the word
        word = word.strip()  # Remove leading and trailing whitespace

        if word in pos_mapping:
            pos_unimorph_info[word] = {
                "pos": pos_mapping[word],
                "affix": None,  # No affix for this case
                "unimorph": unimorph_mapping.get(word, None)
            }
        elif word in kannada_pos_mapping:
            pos_unimorph_info[word] = {
                "pos": kannada_pos_mapping[word],
                "affix": None,  # No affix for this case
                "unimorph": unimorph_mapping.get(word, None)
            }
        else:
            # If the word is not found in any mapping, check the stemming dictionary
            found = False
            for affix, info in suffix_info.items():
                #if word.startswith("pustaka"):
                    #print(word,affix,word.endswith(affix),word.replace(affix,""))

                if word.endswith(affix):
                    word_stem = word.replace(affix,"") if len(affix) > 0 else word
                    if word_stem in pos_mapping:
                        pos_unimorph_info[word] = {
                            "pos": pos_mapping[word_stem],
                            "affix": affix,
                            "unimorph": unimorph_mapping.get(word_stem, None)
                        }
                        found = True
                        break
                    elif word_stem in kannada_pos_mapping:
                        pos_unimorph_info[word] = {
                            "pos": kannada_pos_mapping[word_stem],
                            "affix": affix,
                            "unimorph": unimorph_mapping.get(word_stem, None)
                        }
                        found = True
                        break
                    else:
                        # If the stem is not found, check if the affix is in the suffix_info
                        if affix in suffix_info:
                            pos_unimorph_info[word] = {
                                "pos": None,
                                "affix": affix,
                                "unimorph": None  # No unimorph mapping for this case
                            }
                

            # If still not found, add a placeholder


            if not found:
                pos_unimorph_info[word] = {
                    "pos": None,
                    "affix": None,  # No affix for this case
                    "unimorph": None
                }
        
    # Append the sentence with its translation and POS/unimorph info
    #print(f"Sentence: {sentence}")
    #print(f"Translated Sentence: {translated_sentence}")
    #print(f"POS/Unimorph Info: {pos_unimorph_info}")
    parallel_sentences_with_pos_and_unimorph.append({
        "sentence": sentence,
        "translated_sentence": translated_sentence,
        "pos_unimorph_info": pos_unimorph_info
    })

# Save the parallel sentences with POS and unimorph mapping to a json file


parallel_sentences_with_pos_and_unimorph
# Out:
# [{'sentence': 'Idu pustaka.',
#   'translated_sentence': 'This is a book.',
#   'pos_unimorph_info': {'idu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / this',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}}}},
#  {'sentence': 'Ivu pustakagaḷu.',
#   'translated_sentence': 'These are books.',
#   'pos_unimorph_info': {'ivu': {'pos': ['PRON', 'PUNCT', 'PRON'],
#     'affix': None,
#     'unimorph': None},
#    'pustakagaḷu': {'pos': ['NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}}}},
#  {'sentence': 'Adu mara.',
#   'translated_sentence': 'That is a tree.',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'mara': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'tree',
#      'eng_word_full': 'tree, wood',
#      'unimorph': 'N;SG',
#      'stem': 'tree'}}}},
#  {'sentence': 'Avu maragaḷu.',
#   'translated_sentence': 'Those are trees.',
#   'pos_unimorph_info': {'avu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'maragaḷu': {'pos': ['NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': {'eng_word': 'tree',
#      'eng_word_full': 'tree, wood',
#      'unimorph': 'N;SG',
#      'stem': 'tree'}}}},
#  {'sentence': 'Adu huḍuga.',
#   'translated_sentence': 'That is a boy.',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'huḍuga': {'pos': ['PROPN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'boy',
#      'eng_word_full': 'boy',
#      'unimorph': 'N;SG',
#      'stem': 'boy'}}}},
#  {'sentence': 'Adu mane.',
#   'translated_sentence': 'That is a house.',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'mane': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'house',
#      'eng_word_full': 'house',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'house'}}}},
#  {'sentence': 'Avu manegaḷu.',
#   'translated_sentence': 'Those are houses.',
#   'pos_unimorph_info': {'avu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'manegaḷu': {'pos': ['NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': {'eng_word': 'house',
#      'eng_word_full': 'house',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'house'}}}},
#  {'sentence': 'Adu mahiḷe.',
#   'translated_sentence': 'That is a lady.',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'mahiḷe': {'pos': ['PROPN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'lady',
#      'eng_word_full': 'lady',
#      'unimorph': 'N;SG',
#      'stem': 'lady'}}}},
#  {'sentence': 'Nānu vidyārthi.',
#   'translated_sentence': 'I am a [male] student.',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'vidyārthi': {'pos': ['X', 'NOUN', 'X', 'NOUN'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'Nānu vidyārthini.',
#   'translated_sentence': 'I am a [female] student.',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'vidyārthini': {'pos': ['X', 'ADJ', 'PUNCT', 'NOUN'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'idu mane',
#   'translated_sentence': 'this [is a] house [‘this thing – house’]',
#   'pos_unimorph_info': {'idu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / this',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'mane': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'house',
#      'eng_word_full': 'house',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'house'}}}},
#  {'sentence': 'adu kaṭṭaḍa',
#   'translated_sentence': 'that [is a] building [‘that thing – building’]',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'kaṭṭaḍa': {'pos': ['VERB'],
#     'affix': None,
#     'unimorph': {'eng_word': 'building',
#      'eng_word_full': 'building',
#      'unimorph': 'V;V.PTCP;PRS',
#      'stem': 'build'}}}},
#  {'sentence': 'adu huḍugi',
#   'translated_sentence': 'that [is a] girl',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'huḍugi': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'girl',
#      'eng_word_full': 'girl',
#      'unimorph': 'N;SG',
#      'stem': 'girl'}}}},
#  {'sentence': 'avaḷu huḍugi',
#   'translated_sentence': 'she [is a] girl When sentences of the above type are pronounced, there is a slight',
#   'pos_unimorph_info': {'avaḷu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'she',
#      'eng_word_full': 'she',
#      'unimorph': 'N;SG',
#      'stem': 'she'}},
#    'huḍugi': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'girl',
#      'eng_word_full': 'girl',
#      'unimorph': 'N;SG',
#      'stem': 'girl'}}}},
#  {'sentence': 'avanu nanna maga',
#   'translated_sentence': 'he is my son',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'nanna': {'pos': ['PRON'], 'affix': None, 'unimorph': None},
#    'maga': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'son',
#      'eng_word_full': 'son',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'son'}}}},
#  {'sentence': 'avaru nanna gurugaḷu',
#   'translated_sentence': 'he is my teacher',
#   'pos_unimorph_info': {'avaru': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'nanna': {'pos': ['PRON'], 'affix': None, 'unimorph': None},
#    'gurugaḷu': {'pos': ['NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': {'eng_word': 'teacher',
#      'eng_word_full': 'teacher',
#      'unimorph': 'N;SG',
#      'stem': 'teacher'}}}},
#  {'sentence': 'avaru namma purōhitaru',
#   'translated_sentence': 'he is our priest',
#   'pos_unimorph_info': {'avaru': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'namma': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'our',
#      'eng_word_full': 'our',
#      'unimorph': 'N;SG',
#      'stem': 'our'}},
#    'purōhitaru': {'pos': ['NOUN'],
#     'affix': 'ru',
#     'unimorph': {'eng_word': 'priest',
#      'eng_word_full': 'priest',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'priest'}}}},
#  {'sentence': 'Nīvu vidyārthiyā?',
#   'translated_sentence': 'Are you a [male] student?',
#   'pos_unimorph_info': {'nīvu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'you',
#      'eng_word_full': 'you (plural / honorific)',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'you'}},
#    'vidyārthiyā': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Nīvu vidyārthiniyā?',
#   'translated_sentence': 'Are you a [female] student?',
#   'pos_unimorph_info': {'nīvu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'you',
#      'eng_word_full': 'you (plural / honorific)',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'you'}},
#    'vidyārthiniyā': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Haudu, nānu vidyārthini.',
#   'translated_sentence': 'Yes, I am a [female] student.',
#   'pos_unimorph_info': {'haudu': {'pos': ['INTJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'yes',
#      'eng_word_full': 'yes',
#      'unimorph': 'N;SG',
#      'stem': 'yes'}},
#    'nānu': {'pos': ['PRON'], 'affix': None, 'unimorph': None},
#    'vidyārthini': {'pos': ['X', 'ADJ', 'PUNCT', 'NOUN'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'Idu maravā?',
#   'translated_sentence': 'Is this a tree?',
#   'pos_unimorph_info': {'idu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / this',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'maravā': {'pos': ['NOUN'],
#     'affix': 'vā',
#     'unimorph': {'eng_word': 'tree',
#      'eng_word_full': 'tree, wood',
#      'unimorph': 'N;SG',
#      'stem': 'tree'}}}},
#  {'sentence': 'Haudu, idu mara.',
#   'translated_sentence': 'Yes, this is a tree.',
#   'pos_unimorph_info': {'haudu': {'pos': ['INTJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'yes',
#      'eng_word_full': 'yes',
#      'unimorph': 'N;SG',
#      'stem': 'yes'}},
#    'idu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / this',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'mara': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'tree',
#      'eng_word_full': 'tree, wood',
#      'unimorph': 'N;SG',
#      'stem': 'tree'}}}},
#  {'sentence': 'Adu pustakavā?',
#   'translated_sentence': 'Is that a book?',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'pustakavā': {'pos': ['NOUN'],
#     'affix': 'vā',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}}}},
#  {'sentence': 'Haudu, pustaka.',
#   'translated_sentence': 'Yes, a book.',
#   'pos_unimorph_info': {'haudu': {'pos': ['INTJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'yes',
#      'eng_word_full': 'yes',
#      'unimorph': 'N;SG',
#      'stem': 'yes'}},
#    'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}}}},
#  {'sentence': 'Adū pustakavā?',
#   'translated_sentence': 'Is that a book too?',
#   'pos_unimorph_info': {'adū': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustakavā': {'pos': ['NOUN'],
#     'affix': 'vā',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}}}},
#  {'sentence': 'Alla, adu pustakavalla.',
#   'translated_sentence': 'No, that is not a book.',
#   'pos_unimorph_info': {'alla': {'pos': None, 'affix': None, 'unimorph': None},
#    'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'pustakavalla': {'pos': ['NOUN'],
#     'affix': 'valla',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}}}},
#  {'sentence': 'idu mara-v-alla',
#   'translated_sentence': 'this is not a tree',
#   'pos_unimorph_info': {'idu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / this',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'mara-v-alla': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'adu toḍak-alla',
#   'translated_sentence': 'that is not a problem',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'toḍak-alla': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'adu huḍugi-y-alla',
#   'translated_sentence': 'that is not a girl',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'huḍugi-y-alla': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'alli mara-v-illa',
#   'translated_sentence': 'there is no tree there',
#   'pos_unimorph_info': {'alli': {'pos': ['ADV'],
#     'affix': None,
#     'unimorph': {'eng_word': 'there',
#      'eng_word_full': 'there',
#      'unimorph': 'N;SG',
#      'stem': 'there'}},
#    'mara-v-illa': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'alli toḍak-illa',
#   'translated_sentence': 'there is no problem there',
#   'pos_unimorph_info': {'alli': {'pos': ['ADV'],
#     'affix': None,
#     'unimorph': {'eng_word': 'there',
#      'eng_word_full': 'there',
#      'unimorph': 'N;SG',
#      'stem': 'there'}},
#    'toḍak-illa': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'alli huḍugi-y-illa',
#   'translated_sentence': 'there is no girl there Another possible word for expressing a different meaning of the English ‘no’ is the ‘no’ that expresses the denial of being wanted or being neces-',
#   'pos_unimorph_info': {'alli': {'pos': ['ADV'],
#     'affix': None,
#     'unimorph': {'eng_word': 'there',
#      'eng_word_full': 'there',
#      'unimorph': 'N;SG',
#      'stem': 'there'}},
#    'huḍugi-y-illa': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'adū pustakavā?',
#   'translated_sentence': 'is that also a book?',
#   'pos_unimorph_info': {'adū': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustakavā': {'pos': ['NOUN'],
#     'affix': 'vā',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}}}},
#  {'sentence': 'haudu, adū pustaka',
#   'translated_sentence': 'yes, that too is a book',
#   'pos_unimorph_info': {'haudu': {'pos': ['INTJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'yes',
#      'eng_word_full': 'yes',
#      'unimorph': 'N;SG',
#      'stem': 'yes'}},
#    'adū': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}}}},
#  {'sentence': 'haudu, adū ide',
#   'translated_sentence': 'yes, that too is there',
#   'pos_unimorph_info': {'haudu': {'pos': ['INTJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'yes',
#      'eng_word_full': 'yes',
#      'unimorph': 'N;SG',
#      'stem': 'yes'}},
#    'adū': {'pos': None, 'affix': None, 'unimorph': None},
#    'ide': {'pos': ['AUX'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'illa, adu illa',
#   'translated_sentence': 'no, that is not there',
#   'pos_unimorph_info': {'illa': {'pos': None, 'affix': None, 'unimorph': None},
#    'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}}}},
#  {'sentence': 'ākāśa mattu bekku',
#   'translated_sentence': 'The Sky and the',
#   'pos_unimorph_info': {'ākāśa': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'sky',
#      'eng_word_full': 'sky',
#      'unimorph': 'N;SG',
#      'stem': 'sky'}},
#    'mattu': {'pos': ['CCONJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'and',
#      'eng_word_full': 'and',
#      'unimorph': 'ADJ;CMPR',
#      'stem': 'null and void'}},
#    'bekku': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'maisūru maṃgaḷūru beṃgaḷūru śivamogga dhāravāḍa ivu karnāṭakada nagaragaḷu',
#   'translated_sentence': 'Mysore, Mangalore, Bangalore, Shimoga, and Dharwad are cities in (‘of’) Karnataka',
#   'pos_unimorph_info': {'maisūru': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'maṃgaḷūru': {'pos': None, 'affix': None, 'unimorph': None},
#    'beṃgaḷūru': {'pos': None, 'affix': None, 'unimorph': None},
#    'śivamogga': {'pos': None, 'affix': None, 'unimorph': None},
#    'dhāravāḍa': {'pos': None, 'affix': None, 'unimorph': None},
#    'ivu': {'pos': ['PRON', 'PUNCT', 'PRON'], 'affix': None, 'unimorph': None},
#    'karnāṭakada': {'pos': None, 'affix': None, 'unimorph': None},
#    'nagaragaḷu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Ēnu samācāra?',
#   'translated_sentence': 'What is the news?',
#   'pos_unimorph_info': {'ēnu': {'pos': ['PRON', 'PUNCT'],
#     'affix': None,
#     'unimorph': None},
#    'samācāra': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'news',
#      'eng_word_full': 'news',
#      'unimorph': 'N;SG',
#      'stem': 'news'}}}},
#  {'sentence': 'Ēnū illa.',
#   'translated_sentence': 'Nothing (‘what-also is not’).',
#   'pos_unimorph_info': {'ēnū': {'pos': None, 'affix': None, 'unimorph': None},
#    'illa': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Nīvū cennāgiddīrā?',
#   'translated_sentence': 'Are you fine too?',
#   'pos_unimorph_info': {'nīvū': {'pos': None, 'affix': None, 'unimorph': None},
#    'cennāgiddīrā': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Paravā illa.',
#   'translated_sentence': 'All right (‘there is no worry’).',
#   'pos_unimorph_info': {'paravā': {'pos': ['VERB'],
#     'affix': None,
#     'unimorph': {'eng_word': 'worry',
#      'eng_word_full': 'worry',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'worry'}},
#    'illa': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': '(Nānu) baralā?',
#   'translated_sentence': 'May I leave? (‘Shall I come?’)',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'baralā': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Namaskāra, Gururājarē.',
#   'translated_sentence': 'Greetings, Mr Gururaja. Gururāja',
#   'pos_unimorph_info': {'namaskāra': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'gururājarē': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Namaskāra, Rāmappanavarē.',
#   'translated_sentence': 'Greetings, Mr Rāmappa. Rāmappa',
#   'pos_unimorph_info': {'namaskāra': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'rāmappanavarē': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Nānu cennāgiddēne. Nīvu?',
#   'translated_sentence': 'I’m fine. And you? Rāmappa',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'cennāgiddēne': {'pos': ['ADV', 'PUNCT', 'ADV'],
#     'affix': 'ddēne',
#     'unimorph': None},
#    'nīvu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'you',
#      'eng_word_full': 'you (plural / honorific)',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'you'}}}},
#  {'sentence': 'Nānū cennāgiddēne. Ivaru nimma maneyavarā?',
#   'translated_sentence': 'I’m fine too. Is this your wife?',
#   'pos_unimorph_info': {'nānū': {'pos': None, 'affix': None, 'unimorph': None},
#    'cennāgiddēne': {'pos': ['ADV', 'PUNCT', 'ADV'],
#     'affix': 'ddēne',
#     'unimorph': None},
#    'ivaru': {'pos': ['PRON', 'SYM', 'PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he / she (honorific)',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'nimma': {'pos': ['PRON'], 'affix': None, 'unimorph': None},
#    'maneyavarā': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Haudu, ivara hesaru Sītamma.',
#   'translated_sentence': 'Yes, her name is Sītamma. Rāmappa',
#   'pos_unimorph_info': {'haudu': {'pos': ['INTJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'yes',
#      'eng_word_full': 'yes',
#      'unimorph': 'N;SG',
#      'stem': 'yes'}},
#    'ivara': {'pos': ['PRON', 'SYM', 'PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'his',
#      'eng_word_full': 'his / her (honorific)',
#      'unimorph': 'N;PL',
#      'stem': 'hi'}},
#    'hesaru': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'name',
#      'eng_word_full': 'name',
#      'unimorph': 'N;SG',
#      'stem': 'name'}},
#    'sītamma': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Namaskāra, Sītammanavarē.',
#   'translated_sentence': 'Greetings, Mrs Sītamma.',
#   'pos_unimorph_info': {'namaskāra': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'sītammanavarē': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Nānu baralā?',
#   'translated_sentence': 'May I take leave? Gururāja',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'baralā': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Sari, banni.',
#   'translated_sentence': 'All right, good bye. Rāmappa',
#   'pos_unimorph_info': {'sari': {'pos': ['INTJ',
#      'PUNCT',
#      'ADV',
#      'ADV',
#      'PUNCT',
#      'ADJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'okay',
#      'eng_word_full': 'okay, all right, correct',
#      'unimorph': 'N;SG',
#      'stem': 'okay'}},
#    'banni': {'pos': ['INTJ', 'VERB'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Baruttēne, Sītammanavarē. Namaskāra.',
#   'translated_sentence': 'Till next time, Mrs Sītamma. Good bye.',
#   'pos_unimorph_info': {'baruttēne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttēne',
#     'unimorph': {'eng_word': 'to come',
#      'eng_word_full': 'to come',
#      'unimorph': 'ADJ',
#      'stem': 'to come'}},
#    'sītammanavarē': {'pos': None, 'affix': None, 'unimorph': None},
#    'namaskāra': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'kṣamisi / kṣamisiri',
#   'translated_sentence': 'excuse me, sorry (honorific)',
#   'pos_unimorph_info': {'kṣamisi': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    '': {'pos': None, 'affix': None, 'unimorph': None},
#    'kṣamisiri': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'idu hasu',
#   'translated_sentence': 'this is a cow',
#   'pos_unimorph_info': {'idu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / this',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'hasu': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'cow',
#      'eng_word_full': 'cow',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'cow'}}}},
#  {'sentence': 'ivu hasuvina koṃbugaḷu',
#   'translated_sentence': 'these are a cow’s horns',
#   'pos_unimorph_info': {'ivu': {'pos': ['PRON', 'PUNCT', 'PRON'],
#     'affix': None,
#     'unimorph': None},
#    'hasuvina': {'pos': None, 'affix': None, 'unimorph': None},
#    'koṃbugaḷu': {'pos': ['NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': {'eng_word': 'horn',
#      'eng_word_full': 'horn',
#      'unimorph': 'N;SG',
#      'stem': 'horn'}}}},
#  {'sentence': 'idu baṇṇa',
#   'translated_sentence': 'this is a colour',
#   'pos_unimorph_info': {'idu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / this',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'baṇṇa': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'colour',
#      'eng_word_full': 'colour',
#      'unimorph': 'ADJ',
#      'stem': 'colour'}}}},
#  {'sentence': 'idu hesaru',
#   'translated_sentence': 'this is a name',
#   'pos_unimorph_info': {'idu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / this',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'hesaru': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'name',
#      'eng_word_full': 'name',
#      'unimorph': 'N;SG',
#      'stem': 'name'}}}},
#  {'sentence': 'idu avara hesaru',
#   'translated_sentence': 'this is their name',
#   'pos_unimorph_info': {'idu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / this',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'avara': {'pos': None, 'affix': None, 'unimorph': None},
#    'hesaru': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'name',
#      'eng_word_full': 'name',
#      'unimorph': 'N;SG',
#      'stem': 'name'}}}},
#  {'sentence': 'pustaka cennāgide',
#   'translated_sentence': 'the book is nice',
#   'pos_unimorph_info': {'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'cennāgide': {'pos': ['AUX', 'ADJ'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'huḍugi baṃdaḷu',
#   'translated_sentence': 'the girl came',
#   'pos_unimorph_info': {'huḍugi': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'girl',
#      'eng_word_full': 'girl',
#      'unimorph': 'N;SG',
#      'stem': 'girl'}},
#    'baṃdaḷu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'huḍuga baṃda',
#   'translated_sentence': 'the boy came',
#   'pos_unimorph_info': {'huḍuga': {'pos': ['PROPN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'boy',
#      'eng_word_full': 'boy',
#      'unimorph': 'N;SG',
#      'stem': 'boy'}},
#    'baṃda': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'avanu yāvāgalū ōduttāne',
#   'translated_sentence': 'he always reads',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'yāvāgalū': {'pos': ['ADV'], 'affix': None, 'unimorph': None},
#    'ōduttāne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttāne',
#     'unimorph': {'eng_word': 'to read',
#      'eng_word_full': 'to read',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'read|read|V;PST',
#      'stem': 'read'}}}},
#  {'sentence': 'avanu nāḷe baruttāne',
#   'translated_sentence': 'he will come',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'nāḷe': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'tomorrow',
#      'eng_word_full': 'tomorrow',
#      'unimorph': 'N;SG',
#      'stem': 'tomorrow'}},
#    'baruttāne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttāne',
#     'unimorph': {'eng_word': 'to come',
#      'eng_word_full': 'to come',
#      'unimorph': 'ADJ',
#      'stem': 'to come'}}}},
#  {'sentence': 'avanu yāvāgalū ōduttāne',
#   'translated_sentence': 'he always reads',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'yāvāgalū': {'pos': ['ADV'], 'affix': None, 'unimorph': None},
#    'ōduttāne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttāne',
#     'unimorph': {'eng_word': 'to read',
#      'eng_word_full': 'to read',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'read|read|V;PST',
#      'stem': 'read'}}}},
#  {'sentence': 'avanu yāvāgalū ōduvanu',
#   'translated_sentence': 'he will always read mean practically the same, and it is largely a matter of stylistic prefer- ence whether one uses the one or the other. In coastal Karnataka there is a stronger tendency to differentiate between the use of the present',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'yāvāgalū': {'pos': ['ADV'], 'affix': None, 'unimorph': None},
#    'ōduvanu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'adu baruvudilla',
#   'translated_sentence': 'it will not come',
#   'pos_unimorph_info': {'adu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'it',
#      'eng_word_full': 'it / that',
#      'unimorph': 'V;PST',
#      'stem': 'it'}},
#    'baruvudilla': {'pos': ['PART', 'VERB'],
#     'affix': 'vudilla',
#     'unimorph': {'eng_word': 'to come',
#      'eng_word_full': 'to come',
#      'unimorph': 'ADJ',
#      'stem': 'to come'}}}},
#  {'sentence': 'nānu nidde māḍuvudilla',
#   'translated_sentence': 'I will not sleep',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'nidde': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'sleep',
#      'eng_word_full': 'sleep',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'sleep'}},
#    'māḍuvudilla': {'pos': ['PART', 'VERB', 'PUNCT', 'VERB'],
#     'affix': 'vudilla',
#     'unimorph': {'eng_word': 'to do',
#      'eng_word_full': 'to do, make',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'do|do|V;NFIN;IMP+SBJV',
#      'stem': 'do'}}}},
#  {'sentence': 'avanu nidde māḍuvudilla',
#   'translated_sentence': 'he will not sleep',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'nidde': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'sleep',
#      'eng_word_full': 'sleep',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'sleep'}},
#    'māḍuvudilla': {'pos': ['PART', 'VERB', 'PUNCT', 'VERB'],
#     'affix': 'vudilla',
#     'unimorph': {'eng_word': 'to do',
#      'eng_word_full': 'to do, make',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'do|do|V;NFIN;IMP+SBJV',
#      'stem': 'do'}}}},
#  {'sentence': 'nīvu nidde māḍuvudilla',
#   'translated_sentence': 'you will not sleep It is important to note that there is no distinction in the written lan-',
#   'pos_unimorph_info': {'nīvu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'you',
#      'eng_word_full': 'you (plural / honorific)',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'you'}},
#    'nidde': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'sleep',
#      'eng_word_full': 'sleep',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'sleep'}},
#    'māḍuvudilla': {'pos': ['PART', 'VERB', 'PUNCT', 'VERB'],
#     'affix': 'vudilla',
#     'unimorph': {'eng_word': 'to do',
#      'eng_word_full': 'to do, make',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'do|do|V;NFIN;IMP+SBJV',
#      'stem': 'do'}}}},
#  {'sentence': 'nidde māḍu',
#   'translated_sentence': 'to sleep',
#   'pos_unimorph_info': {'nidde': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'sleep',
#      'eng_word_full': 'sleep',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'sleep'}},
#    'māḍu': {'pos': ['PART', 'VERB', 'PUNCT', 'VERB'],
#     'affix': None,
#     'unimorph': {'eng_word': 'to do',
#      'eng_word_full': 'to do, make',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'do|do|V;NFIN;IMP+SBJV',
#      'stem': 'do'}}}},
#  {'sentence': 'ā mara',
#   'translated_sentence': 'that tree',
#   'pos_unimorph_info': {'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'mara': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'tree',
#      'eng_word_full': 'tree, wood',
#      'unimorph': 'N;SG',
#      'stem': 'tree'}}}},
#  {'sentence': 'ā maragaḷu',
#   'translated_sentence': 'those trees',
#   'pos_unimorph_info': {'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'maragaḷu': {'pos': ['NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': {'eng_word': 'tree',
#      'eng_word_full': 'tree, wood',
#      'unimorph': 'N;SG',
#      'stem': 'tree'}}}},
#  {'sentence': 'ā huḍugi',
#   'translated_sentence': 'that girl',
#   'pos_unimorph_info': {'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'huḍugi': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'girl',
#      'eng_word_full': 'girl',
#      'unimorph': 'N;SG',
#      'stem': 'girl'}}}},
#  {'sentence': 'ā huḍugiyaru',
#   'translated_sentence': 'those girls',
#   'pos_unimorph_info': {'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'huḍugiyaru': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'ī huḍugi',
#   'translated_sentence': 'this girl',
#   'pos_unimorph_info': {'ī': {'pos': None, 'affix': None, 'unimorph': None},
#    'huḍugi': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'girl',
#      'eng_word_full': 'girl',
#      'unimorph': 'N;SG',
#      'stem': 'girl'}}}},
#  {'sentence': 'ī huḍugiyaru',
#   'translated_sentence': 'these girls',
#   'pos_unimorph_info': {'ī': {'pos': None, 'affix': None, 'unimorph': None},
#    'huḍugiyaru': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'avanu ā huḍuganannu hoḍeyuttāne',
#   'translated_sentence': 'he hits that boy The learner should note here the order of the parts of a transitive sen-',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'huḍuganannu': {'pos': ['PROPN'],
#     'affix': 'nannu',
#     'unimorph': {'eng_word': 'boy',
#      'eng_word_full': 'boy',
#      'unimorph': 'N;SG',
#      'stem': 'boy'}},
#    'hoḍeyuttāne': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'nenne avanu Maisūrige hōdanu',
#   'translated_sentence': 'yesterday he went to Mysore Here the city Maisūru (‘Mysore’ in Anglified spelling; nowadays offi- cially spelt ‘Mysuru’) is the destination of the subject’s travel, therefore',
#   'pos_unimorph_info': {'nenne': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'yesterday',
#      'eng_word_full': 'yesterday',
#      'unimorph': 'N;SG',
#      'stem': 'yesterday'}},
#    'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'maisūrige': {'pos': None, 'affix': None, 'unimorph': None},
#    'hōdanu': {'pos': ['PRON', 'VERB'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'avanu ā huḍuganige ī viṣayavannu hēḷidanu',
#   'translated_sentence': 'he told this matter to that boy Usually, the indirect object (in the dative) is placed before the direct object (in the accusative) in the sentence; but because these parts of the sentence are clearly indicated by the case endings, there is some degree of freedom in the order of these parts, if the speaker / writer wishes to emphasize a part of the sentence by a less usual word order. Therefore a Kannada speaker will not say ‘he told this matter to that boy’ but ‘he to that boy this matter told’, etc. One could also say ‘to that boy he this matter told’ to emphasize the receiver of the message; or ‘he this matter to that boy told’ to emphasize the object, or ‘this matter he to that boy told’ to emphasize the object still more. But the',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'huḍuganige': {'pos': ['PROPN'],
#     'affix': 'nige',
#     'unimorph': {'eng_word': 'boy',
#      'eng_word_full': 'boy',
#      'unimorph': 'N;SG',
#      'stem': 'boy'}},
#    'ī': {'pos': None, 'affix': None, 'unimorph': None},
#    'viṣayavannu': {'pos': ['ADV', 'PUNCT', 'NOUN', 'PUNCT', 'NOUN'],
#     'affix': 'vannu',
#     'unimorph': {'eng_word': 'matter',
#      'eng_word_full': 'matter, thing, topic',
#      'unimorph': 'N;SG',
#      'stem': 'matter'}},
#    'hēḷidanu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'avanu ūṭakke manege hōdanu',
#   'translated_sentence': 'he went home for lunch / dinner',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'ūṭakke': {'pos': None, 'affix': None, 'unimorph': None},
#    'manege': {'pos': ['NOUN'],
#     'affix': 'ge',
#     'unimorph': {'eng_word': 'house',
#      'eng_word_full': 'house',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'house'}},
#    'hōdanu': {'pos': ['PRON', 'VERB'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'avanu nanage pustaka koṭṭanu',
#   'translated_sentence': 'he gave me a book',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'nanage': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'koṭṭanu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'nānu nimage pustaka koṭṭenu',
#   'translated_sentence': 'I gave you a book',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'nimage': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'koṭṭenu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'nānu avarige pustaka koṭṭenu',
#   'translated_sentence': 'I gave them a book',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'avarige': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'koṭṭenu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'nanage ā pustaka bēku',
#   'translated_sentence': 'I want / need that book',
#   'pos_unimorph_info': {'nanage': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'bēku': {'pos': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'nimage ā pustakagaḷu bēku',
#   'translated_sentence': 'you want / need those books The above sentences mean, more literally translated: ‘to me that book is a desired thing’, and ‘to you those books are a desired thing’. The grammatical subject can be anything (singular, plural, neuter, femi-',
#   'pos_unimorph_info': {'nimage': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustakagaḷu': {'pos': ['NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'bēku': {'pos': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'nīvu namage bēku',
#   'translated_sentence': 'we want / need you',
#   'pos_unimorph_info': {'nīvu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'you',
#      'eng_word_full': 'you (plural / honorific)',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'you'}},
#    'namage': {'pos': ['PRON'], 'affix': None, 'unimorph': None},
#    'bēku': {'pos': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'nanage ā pustaka bēḍa',
#   'translated_sentence': 'I do not want / need that book',
#   'pos_unimorph_info': {'nanage': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'bēḍa': {'pos': ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'nimage ā pustakagaḷu bēḍa',
#   'translated_sentence': 'you do not want / need those books',
#   'pos_unimorph_info': {'nimage': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustakagaḷu': {'pos': ['NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'bēḍa': {'pos': ['AUX', 'PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'nanage iṣṭu anna sāku',
#   'translated_sentence': 'this much rice is enough for me',
#   'pos_unimorph_info': {'nanage': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'iṣṭu': {'pos': ['PRON', 'ADJ'], 'affix': None, 'unimorph': None},
#    'anna': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'rice',
#      'eng_word_full': 'rice (cooked)',
#      'unimorph': 'N;SG',
#      'stem': 'rice'}},
#    'sāku': {'pos': ['PRON', 'AUX', 'ADJ'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'aṣṭu haṇa nimage sāladā?',
#   'translated_sentence': 'is that much money not enough for you?',
#   'pos_unimorph_info': {'aṣṭu': {'pos': ['ADV', 'ADV'],
#     'affix': None,
#     'unimorph': None},
#    'haṇa': {'pos': ['NOUN'], 'affix': None, 'unimorph': None},
#    'nimage': {'pos': None, 'affix': None, 'unimorph': None},
#    'sāladā': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'avaru idannu kaiyiṃda baredaru',
#   'translated_sentence': 'they wrote this by hand',
#   'pos_unimorph_info': {'avaru': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'idannu': {'pos': None, 'affix': None, 'unimorph': None},
#    'kaiyiṃda': {'pos': ['NOUN', 'PUNCT', 'VERB'],
#     'affix': 'yiṃda',
#     'unimorph': {'eng_word': 'hand',
#      'eng_word_full': 'hand, arm',
#      'unimorph': 'N;SG',
#      'stem': 'hand'}},
#    'baredaru': {'pos': ['PART', 'VERB'],
#     'affix': 'daru',
#     'unimorph': {'eng_word': 'to write',
#      'eng_word_full': 'to write',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'write|write|V;NFIN;IMP+SBJV',
#      'stem': 'write'}}}},
#  {'sentence': 'avaru kiviyiṃda kēḷuvaru',
#   'translated_sentence': 'they will listen with their ear[s]',
#   'pos_unimorph_info': {'avaru': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'kiviyiṃda': {'pos': ['NOUN'],
#     'affix': 'yiṃda',
#     'unimorph': {'eng_word': 'ear',
#      'eng_word_full': 'ear',
#      'unimorph': 'N;SG',
#      'stem': 'ear'}},
#    'kēḷuvaru': {'pos': ['PART', 'VERB', 'PUNCT', 'PART', 'VERB'],
#     'affix': 'varu',
#     'unimorph': {'eng_word': 'to ask',
#      'eng_word_full': 'to ask, to hear',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'ask|ask|V;NFIN;IMP+SBJV',
#      'stem': 'ask'}}}},
#  {'sentence': 'avaru idannu kalliniṃda kaṭṭidaru',
#   'translated_sentence': 'they built this from stone',
#   'pos_unimorph_info': {'avaru': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'idannu': {'pos': None, 'affix': None, 'unimorph': None},
#    'kalliniṃda': {'pos': None, 'affix': None, 'unimorph': None},
#    'kaṭṭidaru': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'avaru idannu kaiyalli baredaru',
#   'translated_sentence': 'they wrote this by hand',
#   'pos_unimorph_info': {'avaru': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'idannu': {'pos': None, 'affix': None, 'unimorph': None},
#    'kaiyalli': {'pos': ['PUNCT',
#      'ADP',
#      'DET',
#      'NOUN',
#      'PUNCT',
#      'PUNCT',
#      'ADP',
#      'PUNCT',
#      'ADP'],
#     'affix': None,
#     'unimorph': None},
#    'baredaru': {'pos': ['PART', 'VERB'],
#     'affix': 'daru',
#     'unimorph': {'eng_word': 'to write',
#      'eng_word_full': 'to write',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'write|write|V;NFIN;IMP+SBJV',
#      'stem': 'write'}}}},
#  {'sentence': 'avanu maneyoḷaginiṃda baruttāne',
#   'translated_sentence': 'he comes from within the house literally means ‘he house-[of]-inside-[from] comes’. Also the dative and especially genitive forms of postpositions are used often:',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'maneyoḷaginiṃda': {'pos': None, 'affix': None, 'unimorph': None},
#    'baruttāne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttāne',
#     'unimorph': {'eng_word': 'to come',
#      'eng_word_full': 'to come',
#      'unimorph': 'ADJ',
#      'stem': 'to come'}}}},
#  {'sentence': 'avanu maneyoḷakke hōguttāne',
#   'translated_sentence': 'he enters the house',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'maneyoḷakke': {'pos': None, 'affix': None, 'unimorph': None},
#    'hōguttāne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttāne',
#     'unimorph': {'eng_word': 'to go',
#      'eng_word_full': 'to go',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'go|go|V;NFIN;IMP+SBJV',
#      'stem': 'go'}}}},
#  {'sentence': 'avanu ūṭakkōskara baruttāne',
#   'translated_sentence': 'he comes for the meal',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'ūṭakkōskara': {'pos': None, 'affix': None, 'unimorph': None},
#    'baruttāne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttāne',
#     'unimorph': {'eng_word': 'to come',
#      'eng_word_full': 'to come',
#      'unimorph': 'ADJ',
#      'stem': 'to come'}}}},
#  {'sentence': 'pustaka nanagōskara ide',
#   'translated_sentence': 'the book is for me',
#   'pos_unimorph_info': {'pustaka': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'nanagōskara': {'pos': None, 'affix': None, 'unimorph': None},
#    'ide': {'pos': ['AUX'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'avanu nimagōskara baṃda',
#   'translated_sentence': 'he came for you',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'nimagōskara': {'pos': None, 'affix': None, 'unimorph': None},
#    'baṃda': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Ō banni, oḷage banni, Gaṇēśarē.',
#   'translated_sentence': 'Oh, come in, com in, Mr Ganesha.',
#   'pos_unimorph_info': {'ō': {'pos': None, 'affix': None, 'unimorph': None},
#    'banni': {'pos': ['INTJ', 'VERB'], 'affix': None, 'unimorph': None},
#    'oḷage': {'pos': ['ADP'],
#     'affix': None,
#     'unimorph': {'eng_word': 'within',
#      'eng_word_full': 'within',
#      'unimorph': 'ADJ',
#      'stem': 'within'}},
#    'gaṇēśarē': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Hēgiddīri? Ēnu samācāra?',
#   'translated_sentence': 'How are you? What is new? Gaṇēśa',
#   'pos_unimorph_info': {'hēgiddīri': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'ēnu': {'pos': ['PRON', 'PUNCT'], 'affix': None, 'unimorph': None},
#    'samācāra': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'news',
#      'eng_word_full': 'news',
#      'unimorph': 'N;SG',
#      'stem': 'news'}}}},
#  {'sentence': 'Namaskāra, Rāmayyanavarē. Nānu cennāgiddēne. Toṃdare illa. Viśēṣavāda samācāravilla.',
#   'translated_sentence': 'Greetings, Mr Rāmayya. I’m fine. No problems. There’s no special news.',
#   'pos_unimorph_info': {'namaskāra': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'rāmayyanavarē': {'pos': None, 'affix': None, 'unimorph': None},
#    'nānu': {'pos': ['PRON'], 'affix': None, 'unimorph': None},
#    'cennāgiddēne': {'pos': ['ADV', 'PUNCT', 'ADV'],
#     'affix': 'ddēne',
#     'unimorph': None},
#    'toṃdare': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'trouble',
#      'eng_word_full': 'trouble',
#      'unimorph': 'N;SG',
#      'stem': 'trouble'}},
#    'illa': {'pos': None, 'affix': None, 'unimorph': None},
#    'viśēṣavāda': {'pos': ['ADJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'special',
#      'eng_word_full': 'special',
#      'unimorph': 'N;SG',
#      'stem': 'special'}},
#    'samācāravilla': {'pos': ['NOUN'],
#     'affix': 'villa',
#     'unimorph': {'eng_word': 'news',
#      'eng_word_full': 'news',
#      'unimorph': 'N;SG',
#      'stem': 'news'}}}},
#  {'sentence': 'Cennāgiddēne, amma.',
#   'translated_sentence': 'I’m fine, madam. Sītamma',
#   'pos_unimorph_info': {'cennāgiddēne': {'pos': ['ADV', 'PUNCT', 'ADV'],
#     'affix': 'ddēne',
#     'unimorph': None},
#    'amma': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'mother',
#      'eng_word_full': 'mother',
# ...
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'bēku': {'pos': ['AUX', 'VERB', 'SYM', 'VERB', 'SYM', 'VERB'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'alli aidu maṃdi vidyārthigaḷu niṃtiddāre.',
#   'translated_sentence': 'Four students are standing there.',
#   'pos_unimorph_info': {'alli': {'pos': ['ADV'],
#     'affix': None,
#     'unimorph': {'eng_word': 'there',
#      'eng_word_full': 'there',
#      'unimorph': 'N;SG',
#      'stem': 'there'}},
#    'aidu': {'pos': ['NUM'],
#     'affix': None,
#     'unimorph': {'eng_word': 'five',
#      'eng_word_full': 'five',
#      'unimorph': 'N;SG',
#      'stem': 'five'}},
#    'maṃdi': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'person',
#      'eng_word_full': 'person',
#      'unimorph': 'N;SG',
#      'stem': 'person'}},
#    'vidyārthigaḷu': {'pos': ['X', 'NOUN', 'X', 'NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': None},
#    'niṃtiddāre': {'pos': ['PRON', 'VERB'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'hattu jana girākigaḷige haṇṇu māriddāne.',
#   'translated_sentence': 'He has sold fruits to ten customers. Alternatively, up to the count of five, one can use pronominalized short forms of numerals.',
#   'pos_unimorph_info': {'hattu': {'pos': ['PART',
#      'VERB',
#      'PUNCT',
#      'PART',
#      'VERB'],
#     'affix': None,
#     'unimorph': {'eng_word': 'to climb',
#      'eng_word_full': 'to climb; to begin',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'climb|climb|V;NFIN;IMP+SBJV',
#      'stem': 'climb'}},
#    'jana': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'person',
#      'eng_word_full': 'person, people',
#      'unimorph': 'N;SG',
#      'stem': 'person'}},
#    'girākigaḷige': {'pos': None, 'affix': None, 'unimorph': None},
#    'haṇṇu': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'fruit',
#      'eng_word_full': 'fruit',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'fruit'}},
#    'māriddāne': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'ibbarū barabahudu.',
#   'translated_sentence': 'Both of them may come.',
#   'pos_unimorph_info': {'ibbarū': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'barabahudu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'ibbarigū hēḷidenu',
#   'translated_sentence': 'I told both of them.',
#   'pos_unimorph_info': {'ibbarigū': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'hēḷidenu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'saṃgrahālayadalli mūru citragaḷannu nōḍiddēne. mūrū cennāgive.',
#   'translated_sentence': 'I have seen three pictures in the museum. All three of them are nice.',
#   'pos_unimorph_info': {'saṃgrahālayadalli': {'pos': ['NOUN'],
#     'affix': 'dalli',
#     'unimorph': {'eng_word': 'museum',
#      'eng_word_full': 'museum',
#      'unimorph': 'N;SG',
#      'stem': 'museum'}},
#    'mūru': {'pos': ['NUM'],
#     'affix': None,
#     'unimorph': {'eng_word': 'three',
#      'eng_word_full': 'three',
#      'unimorph': 'N;SG',
#      'stem': 'three'}},
#    'citragaḷannu': {'pos': ['NOUN'],
#     'affix': 'gaḷannu',
#     'unimorph': {'eng_word': 'picture',
#      'eng_word_full': 'picture',
#      'unimorph': 'N;SG',
#      'stem': 'picture'}},
#    'nōḍiddēne': {'pos': None, 'affix': None, 'unimorph': None},
#    'mūrū': {'pos': None, 'affix': None, 'unimorph': None},
#    'cennāgive': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'mējina mēle hattāru pustakagaḷu iddavu',
#   'translated_sentence': 'there were dozens of books on the table',
#   'pos_unimorph_info': {'mējina': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'mēle': {'pos': ['ADP'],
#     'affix': None,
#     'unimorph': {'eng_word': 'on',
#      'eng_word_full': 'on',
#      'unimorph': 'ADJ',
#      'stem': 'on'}},
#    'hattāru': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustakagaḷu': {'pos': ['NOUN'],
#     'affix': 'gaḷu',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'iddavu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'bīdiyalli nūrāru jana iddaru',
#   'translated_sentence': 'there were hundreds of people in the street',
#   'pos_unimorph_info': {'bīdiyalli': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'nūrāru': {'pos': None, 'affix': None, 'unimorph': None},
#    'jana': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'person',
#      'eng_word_full': 'person, people',
#      'unimorph': 'N;SG',
#      'stem': 'person'}},
#    'iddaru': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'avanu sāvirāru rūpāyi kharcu māḍida',
#   'translated_sentence': 'he spent thousands of rupees',
#   'pos_unimorph_info': {'avanu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'he',
#      'eng_word_full': 'he',
#      'unimorph': 'N;SG',
#      'stem': 'he'}},
#    'sāvirāru': {'pos': ['NOUN'], 'affix': None, 'unimorph': None},
#    'rūpāyi': {'pos': None, 'affix': None, 'unimorph': None},
#    'kharcu': {'pos': None, 'affix': None, 'unimorph': None},
#    'māḍida': {'pos': ['INTJ',
#      'VERB',
#      'DET',
#      'NUM',
#      'VERB',
#      'NOUN',
#      'ADP',
#      'NOUN',
#      'AUX',
#      'ADV',
#      'ADJ'],
#     'affix': 'da',
#     'unimorph': None}}},
#  {'sentence': 'hodedu, hoddu',
#   'translated_sentence': 'A few common verbs have special alternative abbreviated forms of the',
#   'pos_unimorph_info': {'hodedu': {'pos': ['PART', 'VERB', 'ADP'],
#     'affix': 'du',
#     'unimorph': None},
#    'hoddu': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'nānu avarannu karakoṃḍu baruttēne',
#   'translated_sentence': 'I’ll bring them (along with me)',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'avarannu': {'pos': None, 'affix': None, 'unimorph': None},
#    'karakoṃḍu': {'pos': None, 'affix': None, 'unimorph': None},
#    'baruttēne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttēne',
#     'unimorph': {'eng_word': 'to come',
#      'eng_word_full': 'to come',
#      'unimorph': 'ADJ',
#      'stem': 'to come'}}}},
#  {'sentence': 'nānu ā pustakagaḷannu tagoṃḍu baruttēne',
#   'translated_sentence': 'I’ll bring those books',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustakagaḷannu': {'pos': ['NOUN'],
#     'affix': 'gaḷannu',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'tagoṃḍu': {'pos': None, 'affix': None, 'unimorph': None},
#    'baruttēne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttēne',
#     'unimorph': {'eng_word': 'to come',
#      'eng_word_full': 'to come',
#      'unimorph': 'ADJ',
#      'stem': 'to come'}}}},
#  {'sentence': 'nānu avarannu karakoṃḍu manege hōguttēne',
#   'translated_sentence': 'I’ll take them (persons) to my home',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'avarannu': {'pos': None, 'affix': None, 'unimorph': None},
#    'karakoṃḍu': {'pos': None, 'affix': None, 'unimorph': None},
#    'manege': {'pos': ['NOUN'],
#     'affix': 'ge',
#     'unimorph': {'eng_word': 'house',
#      'eng_word_full': 'house',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'house'}},
#    'hōguttēne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttēne',
#     'unimorph': {'eng_word': 'to go',
#      'eng_word_full': 'to go',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'go|go|V;NFIN;IMP+SBJV',
#      'stem': 'go'}}}},
#  {'sentence': 'nānu ā pustakagaḷannu tagoṃḍu manege hōguttēne',
#   'translated_sentence': 'I’ll take those books home',
#   'pos_unimorph_info': {'nānu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'pustakagaḷannu': {'pos': ['NOUN'],
#     'affix': 'gaḷannu',
#     'unimorph': {'eng_word': 'book',
#      'eng_word_full': 'book',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'book'}},
#    'tagoṃḍu': {'pos': None, 'affix': None, 'unimorph': None},
#    'manege': {'pos': ['NOUN'],
#     'affix': 'ge',
#     'unimorph': {'eng_word': 'house',
#      'eng_word_full': 'house',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'house'}},
#    'hōguttēne': {'pos': ['PART', 'VERB'],
#     'affix': 'ttēne',
#     'unimorph': {'eng_word': 'to go',
#      'eng_word_full': 'to go',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'go|go|V;NFIN;IMP+SBJV',
#      'stem': 'go'}}}},
#  {'sentence': 'Marada keḷage ēnide?',
#   'translated_sentence': 'What lies under the tree?',
#   'pos_unimorph_info': {'marada': {'pos': ['NOUN'],
#     'affix': 'da',
#     'unimorph': {'eng_word': 'tree',
#      'eng_word_full': 'tree, wood',
#      'unimorph': 'N;SG',
#      'stem': 'tree'}},
#    'keḷage': {'pos': ['ADP'],
#     'affix': None,
#     'unimorph': {'eng_word': 'under',
#      'eng_word_full': 'under',
#      'unimorph': 'ADJ',
#      'stem': 'under'}},
#    'ēnide': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'ūṭa cennāgide.',
#   'translated_sentence': 'The meal tasted good.',
#   'pos_unimorph_info': {'ūṭa': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'meal',
#      'eng_word_full': '(cooked) meal',
#      'unimorph': 'N;SG',
#      'stem': 'meal'}},
#    'cennāgide': {'pos': ['AUX', 'ADJ'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Maneya hattira kere ide.',
#   'translated_sentence': 'There is a water tank near the house.',
#   'pos_unimorph_info': {'maneya': {'pos': ['NOUN'],
#     'affix': 'ya',
#     'unimorph': {'eng_word': 'house',
#      'eng_word_full': 'house',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'house'}},
#    'hattira': {'pos': ['ADP'],
#     'affix': None,
#     'unimorph': {'eng_word': 'near',
#      'eng_word_full': 'near; nearness',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'near'}},
#    'kere': {'pos': ['NOUN', 'PUNCT', 'NOUN', 'NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'tank',
#      'eng_word_full': 'tank, water reservoir',
#      'unimorph': 'N;SG',
#      'stem': 'tank'}},
#    'ide': {'pos': ['AUX'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Dēvara dayadiṃda namage oḷḷeyadu āguttade.',
#   'translated_sentence': 'By God’s grace good things happen to us.',
#   'pos_unimorph_info': {'dēvara': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'dayadiṃda': {'pos': None, 'affix': None, 'unimorph': None},
#    'namage': {'pos': ['PRON'], 'affix': None, 'unimorph': None},
#    'oḷḷeyadu': {'pos': ['ADJ', 'NOUN'], 'affix': None, 'unimorph': None},
#    'āguttade': {'pos': ['PART', 'VERB', 'PUNCT', 'VERB'],
#     'affix': 'ttade',
#     'unimorph': {'eng_word': 'to become',
#      'eng_word_full': 'to become, occur',
#      'unimorph': 'V;NFIN',
#      'unimorph_value_str': 'become|become|V;V.PTCP;PST',
#      'stem': 'become'}}}},
#  {'sentence': 'Tuṃba jana illi niṃtiddāre.',
#   'translated_sentence': 'Many people are standing here.',
#   'pos_unimorph_info': {'tuṃba': {'pos': ['ADJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'very',
#      'eng_word_full': 'very, much, many',
#      'unimorph': 'ADJ',
#      'stem': 'very'}},
#    'jana': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'person',
#      'eng_word_full': 'person, people',
#      'unimorph': 'N;SG',
#      'stem': 'person'}},
#    'illi': {'pos': ['ADV'],
#     'affix': None,
#     'unimorph': {'eng_word': 'here',
#      'eng_word_full': 'here',
#      'unimorph': 'ADJ',
#      'stem': 'here'}},
#    'niṃtiddāre': {'pos': ['PRON', 'VERB'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Nanna kelasa hēgide?',
#   'translated_sentence': 'How is my work?',
#   'pos_unimorph_info': {'nanna': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': None},
#    'kelasa': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'work',
#      'eng_word_full': 'work',
#      'unimorph': 'N;SG',
#      'stem': 'work'}},
#    'hēgide': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Bahaḷa aparūpavāgi baruttāre.',
#   'translated_sentence': 'They come here rarely.',
#   'pos_unimorph_info': {'bahaḷa': {'pos': ['ADJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'much',
#      'eng_word_full': 'much, many, very',
#      'unimorph': 'ADJ',
#      'stem': 'much'}},
#    'aparūpavāgi': {'pos': ['ADV'], 'affix': None, 'unimorph': None},
#    'baruttāre': {'pos': ['PRON', 'VERB'], 'affix': None, 'unimorph': None}}},
#  {'sentence': 'ā kelasa māḍuvavaru yāvāgalū yaśasviyāguttāre.',
#   'translated_sentence': 'Those who do this work always become successful.',
#   'pos_unimorph_info': {'ā': {'pos': None, 'affix': None, 'unimorph': None},
#    'kelasa': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'work',
#      'eng_word_full': 'work',
#      'unimorph': 'N;SG',
#      'stem': 'work'}},
#    'māḍuvavaru': {'pos': None, 'affix': None, 'unimorph': None},
#    'yāvāgalū': {'pos': ['ADV'], 'affix': None, 'unimorph': None},
#    'yaśasviyāguttāre': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Kannaḍa oṃdu haḷeya, suṃdaravāda bhāṣe; nīvu kalitare adannu tuṃba meccuviri.',
#   'translated_sentence': 'Kannada is an old, beautiful language; if you learn it, you will like it a lot.',
#   'pos_unimorph_info': {'kannaḍa': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    'oṃdu': {'pos': ['NUM'],
#     'affix': None,
#     'unimorph': {'eng_word': 'one',
#      'eng_word_full': 'one, a',
#      'unimorph': 'N;SG',
#      'stem': 'one'}},
#    'haḷeya': {'pos': ['ADJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'old',
#      'eng_word_full': 'old',
#      'unimorph': 'N;SG',
#      'stem': 'old'}},
#    'suṃdaravāda': {'pos': None, 'affix': None, 'unimorph': None},
#    'bhāṣe;': {'pos': None, 'affix': None, 'unimorph': None},
#    'nīvu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'you',
#      'eng_word_full': 'you (plural / honorific)',
#      'unimorph': 'V;NFIN;IMP+SBJV',
#      'stem': 'you'}},
#    'kalitare': {'pos': ['SCONJ', 'X', 'NUM', 'PUNCT', 'VERB'],
#     'affix': None,
#     'unimorph': None},
#    'adannu': {'pos': ['PRON'],
#     'affix': None,
#     'unimorph': {'eng_word': 'that',
#      'eng_word_full': 'that (accusative case)',
#      'unimorph': 'N;SG',
#      'stem': 'that'}},
#    'tuṃba': {'pos': ['ADJ'],
#     'affix': None,
#     'unimorph': {'eng_word': 'very',
#      'eng_word_full': 'very, much, many',
#      'unimorph': 'ADJ',
#      'stem': 'very'}},
#    'meccuviri': {'pos': ['PRON', 'AUX', 'VERB'],
#     'affix': None,
#     'unimorph': None}}},
#  {'sentence': 'Lesson 4',
#   'translated_sentence': '1. This is the door of my house. 2. That is the horn of a cow. 3. The tip of the horn is not sharp. 4. My book is there. 5. The colour of the book is red. 6. The colour of your books is yellow. 7. Their colour is',
#   'pos_unimorph_info': {'lesson': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    '4': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'Lesson 12',
#   'translated_sentence': '1. Gaṇēśa! Have you gone home? 2. He was tired and went to sleep. 3. That girl sang elegantly. 4. That boy spoke coarsely. 5. He scolded me badly and went away. 6. She saw that and laughed happily. 7. Read this lesson and ask questions. 8. The neighbours went on travel yesterday and will return next month. 9. Did he really say so? 10. Try hard and read these sentences. 11. Please speak a bit quickly. 12. He',
#   'pos_unimorph_info': {'lesson': {'pos': None,
#     'affix': None,
#     'unimorph': None},
#    '12': {'pos': None, 'affix': None, 'unimorph': None}}},
#  {'sentence': 'miliṭari hōṭalu',
#   'translated_sentence': 'non-vegetarian restaurant',
#   'pos_unimorph_info': {'miliṭari': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'military',
#      'eng_word_full': 'military',
#      'unimorph': 'ADJ',
#      'stem': 'military'}},
#    'hōṭalu': {'pos': ['NOUN'],
#     'affix': None,
#     'unimorph': {'eng_word': 'restaurant',
#      'eng_word_full': 'restaurant',
#      'unimorph': 'N;SG',
#      'stem': 'restaurant'}}}}]

# %%
# Save the parallel sentences with POS and unimorph mapping to a json file
with open("parallel_sentences_with_pos_and_unimorph.json", "w", encoding="utf-8") as f:
    json.dump(parallel_sentences_with_pos_and_unimorph, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # Lemmatization and POS tagging

# %%
import spacy
import unimorph

nlp = spacy.load("en_core_web_sm")

sent = "I ate a cat"
doc  = nlp(sent)

for tok in doc:
    print(f"{tok.i:2}  {tok.text:<4}  "
          f"lemma={tok.lemma_:<5}  "
          f"upos={tok.pos_:<4}  "
          f"tag={tok.tag_:<4}  "
          f"morph={tok.morph}")
# Out:
#  0  I     lemma=I      upos=PRON  tag=PRP   morph=Case=Nom|Number=Sing|Person=1|PronType=Prs
#  1  ate   lemma=eat    upos=VERB  tag=VBD   morph=Tense=Past|VerbForm=Fin
#  2  a     lemma=a      upos=DET   tag=DT    morph=Definite=Ind|PronType=Art
#  3  cat   lemma=cat    upos=NOUN  tag=NN    morph=Number=Sing

# %%
import json

with open("parallel_sentences_with_pos_and_unimorph.json","r", encoding="utf-8") as f:
    parallel_sentences_with_pos_and_unimorph = json.load(f)

# %%
len(parallel_sentences_with_pos_and_unimorph)

# Display the first 10 sentences with their POS and unimorph info
for i, sentence_data in enumerate(parallel_sentences_with_pos_and_unimorph[:10]):
    sentence = sentence_data['sentence']
    translated_sentence = sentence_data['translated_sentence']
    pos_unimorph_info = sentence_data['pos_unimorph_info']
    
    print(f"{i+1}. Sentence: {sentence}")
    print(f"   Translated Sentence: {translated_sentence}")
# Out:
# 1. Sentence: Idu pustaka.
#    Translated Sentence: This is a book.
# 2. Sentence: Ivu pustakagaḷu.
#    Translated Sentence: These are books.
# 3. Sentence: Adu mara.
#    Translated Sentence: That is a tree.
# 4. Sentence: Avu maragaḷu.
#    Translated Sentence: Those are trees.
# 5. Sentence: Adu huḍuga.
#    Translated Sentence: That is a boy.
# 6. Sentence: Adu mane.
#    Translated Sentence: That is a house.
# 7. Sentence: Avu manegaḷu.
#    Translated Sentence: Those are houses.
# 8. Sentence: Adu mahiḷe.
#    Translated Sentence: That is a lady.
# 9. Sentence: Nānu vidyārthi.
#    Translated Sentence: I am a [male] student.
# 10. Sentence: Nānu vidyārthini.
#    Translated Sentence: I am a [female] student.

# %%
for sentence in parallel_sentences_with_pos_and_unimorph:
    translated_sentence = sentence["translated_sentence"]
    doc = nlp(translated_sentence)
    res = []
    tense = None
    genders = []
    number = None
    plural_details = None  # To store details if plural is detected
    genders_details = []
    for tok in doc:
        morph = tok.morph.to_dict()
        res.append({
            "word": tok.text,
            "lemma": tok.lemma_,
            "upos": tok.pos_,
            "tag": tok.tag_,
            "morph": morph,
        })

        if not number and morph.get("Number", None):
            number = morph.get("Number", None)
        elif morph.get("Number", None) == "Plur":
            number = "Plur"
            plural_details = {
                "word": tok.text, 
                "morph": morph
            }

        if not tense and morph.get("Tense", None):
            tense = morph.get("Tense", None)

        if morph.get("Gender", None):
            genders.append(morph.get("Gender", None))
            genders_details.append({
                "word": tok.text, 
                "morph": morph})

        
        
        #if morph.get("")


        
    #print(f"Sentence: {translated_sentence} \n Tense: {tense}, Number: {number}, Genders: {genders}")
    print(f"Sentence: {translated_sentence} \n Plural_details: {plural_details}, gender_details: {genders_details}")
    

        
    sentence["spacy_info"] = {"res": res, "tense": tense, "number": number, "plural_details": plural_details, "genders": genders,"genders_details":genders_details}

with open("parallel_sentences_with_additional_info.json", "w", encoding="utf-8") as f:
    json.dump(parallel_sentences_with_pos_and_unimorph, f, ensure_ascii=False, indent=4)

#parallel_sentences_with_pos_and_unimorph
# Out:
# Sentence: This is a book.
#  Plural_details: None, gender_details: []
# Sentence: These are books.
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: That is a tree.
#  Plural_details: None, gender_details: []
# Sentence: Those are trees.
#  Plural_details: {'word': 'trees', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: That is a boy.
#  Plural_details: None, gender_details: []
# Sentence: That is a house.
#  Plural_details: None, gender_details: []
# Sentence: Those are houses.
#  Plural_details: {'word': 'houses', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: That is a lady.
#  Plural_details: None, gender_details: []
# Sentence: I am a [male] student.
#  Plural_details: None, gender_details: []
# Sentence: I am a [female] student.
#  Plural_details: None, gender_details: []
# Sentence: this [is a] house [‘this thing – house’]
#  Plural_details: None, gender_details: []
# Sentence: that [is a] building [‘that thing – building’]
#  Plural_details: None, gender_details: []
# Sentence: that [is a] girl
#  Plural_details: None, gender_details: []
# Sentence: she [is a] girl When sentences of the above type are pronounced, there is a slight
#  Plural_details: {'word': 'sentences', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he is my son
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he is my teacher
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he is our priest
#  Plural_details: {'word': 'our', 'morph': {'Number': 'Plur', 'Person': '1', 'Poss': 'Yes', 'PronType': 'Prs'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: Are you a [male] student?
#  Plural_details: None, gender_details: []
# Sentence: Are you a [female] student?
#  Plural_details: None, gender_details: []
# Sentence: Yes, I am a [female] student.
#  Plural_details: None, gender_details: []
# Sentence: Is this a tree?
#  Plural_details: None, gender_details: []
# Sentence: Yes, this is a tree.
#  Plural_details: None, gender_details: []
# Sentence: Is that a book?
#  Plural_details: None, gender_details: []
# Sentence: Yes, a book.
#  Plural_details: None, gender_details: []
# Sentence: Is that a book too?
#  Plural_details: None, gender_details: []
# Sentence: No, that is not a book.
#  Plural_details: None, gender_details: []
# Sentence: this is not a tree
#  Plural_details: None, gender_details: []
# Sentence: that is not a problem
#  Plural_details: None, gender_details: []
# Sentence: that is not a girl
#  Plural_details: None, gender_details: []
# Sentence: there is no tree there
#  Plural_details: None, gender_details: []
# Sentence: there is no problem there
#  Plural_details: None, gender_details: []
# Sentence: there is no girl there Another possible word for expressing a different meaning of the English ‘no’ is the ‘no’ that expresses the denial of being wanted or being neces-
#  Plural_details: None, gender_details: []
# Sentence: is that also a book?
#  Plural_details: None, gender_details: []
# Sentence: yes, that too is a book
#  Plural_details: None, gender_details: []
# Sentence: yes, that too is there
#  Plural_details: None, gender_details: []
# Sentence: no, that is not there
#  Plural_details: None, gender_details: []
# Sentence: The Sky and the
#  Plural_details: None, gender_details: []
# Sentence: Mysore, Mangalore, Bangalore, Shimoga, and Dharwad are cities in (‘of’) Karnataka
#  Plural_details: {'word': 'cities', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: What is the news?
#  Plural_details: None, gender_details: []
# Sentence: Nothing (‘what-also is not’).
#  Plural_details: None, gender_details: []
# Sentence: Are you fine too?
#  Plural_details: None, gender_details: []
# Sentence: All right (‘there is no worry’).
#  Plural_details: None, gender_details: []
# Sentence: May I leave? (‘Shall I come?’)
#  Plural_details: None, gender_details: []
# Sentence: Greetings, Mr Gururaja. Gururāja
#  Plural_details: None, gender_details: []
# Sentence: Greetings, Mr Rāmappa. Rāmappa
#  Plural_details: None, gender_details: []
# Sentence: I’m fine. And you? Rāmappa
#  Plural_details: None, gender_details: []
# Sentence: I’m fine too. Is this your wife?
#  Plural_details: None, gender_details: []
# Sentence: Yes, her name is Sītamma. Rāmappa
#  Plural_details: None, gender_details: [{'word': 'her', 'morph': {'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}]
# Sentence: Greetings, Mrs Sītamma.
#  Plural_details: None, gender_details: []
# Sentence: May I take leave? Gururāja
#  Plural_details: None, gender_details: []
# Sentence: All right, good bye. Rāmappa
#  Plural_details: None, gender_details: []
# Sentence: Till next time, Mrs Sītamma. Good bye.
#  Plural_details: None, gender_details: []
# Sentence: excuse me, sorry (honorific)
#  Plural_details: None, gender_details: []
# Sentence: this is a cow
#  Plural_details: None, gender_details: []
# Sentence: these are a cow’s horns
#  Plural_details: {'word': 'horns', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: this is a colour
#  Plural_details: None, gender_details: []
# Sentence: this is a name
#  Plural_details: None, gender_details: []
# Sentence: this is their name
#  Plural_details: {'word': 'their', 'morph': {'Number': 'Plur', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}, gender_details: []
# Sentence: the book is nice
#  Plural_details: None, gender_details: []
# Sentence: the girl came
#  Plural_details: None, gender_details: []
# Sentence: the boy came
#  Plural_details: None, gender_details: []
# Sentence: he always reads
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he will come
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he always reads
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he will always read mean practically the same, and it is largely a matter of stylistic prefer- ence whether one uses the one or the other. In coastal Karnataka there is a stronger tendency to differentiate between the use of the present
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: it will not come
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I will not sleep
#  Plural_details: None, gender_details: []
# Sentence: he will not sleep
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: you will not sleep It is important to note that there is no distinction in the written lan-
#  Plural_details: None, gender_details: [{'word': 'It', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: to sleep
#  Plural_details: None, gender_details: []
# Sentence: that tree
#  Plural_details: None, gender_details: []
# Sentence: those trees
#  Plural_details: {'word': 'trees', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: that girl
#  Plural_details: None, gender_details: []
# Sentence: those girls
#  Plural_details: {'word': 'girls', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: this girl
#  Plural_details: None, gender_details: []
# Sentence: these girls
#  Plural_details: {'word': 'girls', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: he hits that boy The learner should note here the order of the parts of a transitive sen-
#  Plural_details: {'word': 'parts', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: yesterday he went to Mysore Here the city Maisūru (‘Mysore’ in Anglified spelling; nowadays offi- cially spelt ‘Mysuru’) is the destination of the subject’s travel, therefore
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he told this matter to that boy Usually, the indirect object (in the dative) is placed before the direct object (in the accusative) in the sentence; but because these parts of the sentence are clearly indicated by the case endings, there is some degree of freedom in the order of these parts, if the speaker / writer wishes to emphasize a part of the sentence by a less usual word order. Therefore a Kannada speaker will not say ‘he told this matter to that boy’ but ‘he to that boy this matter told’, etc. One could also say ‘to that boy he this matter told’ to emphasize the receiver of the message; or ‘he this matter to that boy told’ to emphasize the object, or ‘this matter he to that boy told’ to emphasize the object still more. But the
#  Plural_details: {'word': 'parts', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he went home for lunch / dinner
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he gave me a book
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I gave you a book
#  Plural_details: None, gender_details: []
# Sentence: I gave them a book
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: []
# Sentence: I want / need that book
#  Plural_details: None, gender_details: []
# Sentence: you want / need those books The above sentences mean, more literally translated: ‘to me that book is a desired thing’, and ‘to you those books are a desired thing’. The grammatical subject can be anything (singular, plural, neuter, femi-
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: we want / need you
#  Plural_details: None, gender_details: []
# Sentence: I do not want / need that book
#  Plural_details: None, gender_details: []
# Sentence: you do not want / need those books
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: this much rice is enough for me
#  Plural_details: None, gender_details: []
# Sentence: is that much money not enough for you?
#  Plural_details: None, gender_details: []
# Sentence: they wrote this by hand
#  Plural_details: None, gender_details: []
# Sentence: they will listen with their ear[s]
#  Plural_details: {'word': 'their', 'morph': {'Number': 'Plur', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}, gender_details: []
# Sentence: they built this from stone
#  Plural_details: None, gender_details: []
# Sentence: they wrote this by hand
#  Plural_details: None, gender_details: []
# Sentence: he comes from within the house literally means ‘he house-[of]-inside-[from] comes’. Also the dative and especially genitive forms of postpositions are used often:
#  Plural_details: {'word': 'postpositions', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he enters the house
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he comes for the meal
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the book is for me
#  Plural_details: None, gender_details: []
# Sentence: he came for you
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: Oh, come in, com in, Mr Ganesha.
#  Plural_details: None, gender_details: []
# Sentence: How are you? What is new? Gaṇēśa
#  Plural_details: None, gender_details: []
# Sentence: Greetings, Mr Rāmayya. I’m fine. No problems. There’s no special news.
#  Plural_details: {'word': 'problems', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I’m fine, madam. Sītamma
#  Plural_details: None, gender_details: []
# Sentence: What will you have? I’ll make some tea.
#  Plural_details: None, gender_details: []
# Sentence: No, have a little bit. Gaṇēśa
#  Plural_details: None, gender_details: []
# Sentence: Really, no, madam. Sītamma
#  Plural_details: None, gender_details: []
# Sentence: Ask a fellow learner about the location of various objects and persons in the room, and let him answer.
#  Plural_details: {'word': 'persons', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'him', 'morph': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: that is a tree
#  Plural_details: None, gender_details: []
# Sentence: those are trees
#  Plural_details: {'word': 'trees', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: we are farmers
#  Plural_details: {'word': 'farmers', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: you are farmers
#  Plural_details: None, gender_details: []
# Sentence: that is not a tree
#  Plural_details: None, gender_details: []
# Sentence: those are not trees
#  Plural_details: {'word': 'trees', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I am not a farmer
#  Plural_details: None, gender_details: []
# Sentence: we are not farmers
#  Plural_details: {'word': 'farmers', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: you are not farmers
#  Plural_details: None, gender_details: []
# Sentence: trees are not there
#  Plural_details: None, gender_details: []
# Sentence: I am not there
#  Plural_details: None, gender_details: []
# Sentence: we need a book
#  Plural_details: None, gender_details: []
# Sentence: we need books
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: we do not need a book
#  Plural_details: None, gender_details: []
# Sentence: we do not need books
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: Is that a tree?
#  Plural_details: None, gender_details: []
# Sentence: That surely is a tree, isn’t it?
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: That is not a tree, is it?
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: that bus is red
#  Plural_details: None, gender_details: []
# Sentence: he is a small boy
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: she is a small girl
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: that is a small house
#  Plural_details: None, gender_details: []
# Sentence: they are small boys
#  Plural_details: {'word': 'boys', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: she looked at those small boys
#  Plural_details: {'word': 'boys', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: that is a bad book then one is actually saying (from an etymological and grammatical
#  Plural_details: None, gender_details: []
# Sentence: that is beautiful music
#  Plural_details: None, gender_details: []
# Sentence: that is a complicated matter
#  Plural_details: None, gender_details: []
# Sentence: that question is difficult
#  Plural_details: None, gender_details: []
# Sentence: that is a different book
#  Plural_details: None, gender_details: []
# Sentence: that book is a different one
#  Plural_details: None, gender_details: []
# Sentence: different kinds of people come there
#  Plural_details: {'word': 'people', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: in front of the house there is a very big car
#  Plural_details: None, gender_details: []
# Sentence: Translate into Kannada: 1. That person is disgusting. 2. His beautiful house is over there. 3. There are no yellow flowers here. 4. He brought heavy tables.
#  Plural_details: {'word': 'tables', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'His', 'morph': {'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}, {'word': 'He', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: Those boys are small
#  Plural_details: {'word': 'boys', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: That girl is big Pronominalization is a very productive grammatical device: it is used by every Kannada speaker and writer very many times every day. There- fore the learner must learn to recognize and understand it well. Once the powerful mechanism of pronominalization is understood, the learner will also be able to appreciate other, more complex appli- cations of the mechanism. It is possible (although in practice this does not occur often) to stack pronomi nalization suffixes to build longer words.
#  Plural_details: {'word': 'words', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'it', 'morph': {'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'It', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: we saw the thing that belongs to our friends
#  Plural_details: {'word': 'friends', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: we went to his (his thing, his house, etc.) In the following sentence, we see two pronominalized words:
#  Plural_details: {'word': 'words', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'his', 'morph': {'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}, {'word': 'his', 'morph': {'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}, {'word': 'his', 'morph': {'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}]
# Sentence: mine is good ( = ‘my thing is a good thing’)
#  Plural_details: None, gender_details: []
# Sentence: neighbour (‘person of the house of the side’) In these examples, we see attributive words, namely, the genitives of
#  Plural_details: {'word': 'genitives', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: Ganēśa is taller than Rāma (‘compared to Rāma, Gaṇēśa is a big male person’)
#  Plural_details: None, gender_details: []
# Sentence: that chair is heavier than this one (‘in comparison with this chair, that [one] is weight’)
#  Plural_details: None, gender_details: []
# Sentence: Where is Dharwad? Bangalore is closer than that (‘in comparison with that, Bangalore is nearness’) There is a bit of flexibility in the word order here: one can also say
#  Plural_details: None, gender_details: []
# Sentence: this chair is the biggest
#  Plural_details: None, gender_details: []
# Sentence: Rāma is the biggest / tallest Literally, these sentences mean ‘this chair, is comparison with all [other chairs], is a big one’, and ‘Rāma, compared to all, is a big fellow’. To express that a certain quality is present to a high degree (‘very’),
#  Plural_details: {'word': 'chairs', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: this is very difficult
#  Plural_details: None, gender_details: []
# Sentence: (the same)
#  Plural_details: None, gender_details: []
# Sentence: I will not do as much work as she has done
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: Surēśa! Where are you going?
#  Plural_details: None, gender_details: []
# Sentence: Gaṇēśa! What are you doing?
#  Plural_details: None, gender_details: []
# Sentence: I went home and went to sleep (or: after going home, I went to sleep) (literally: I house-to having-gone lay down)
#  Plural_details: None, gender_details: []
# Sentence: they heard the music and were happy (or: after hearing that music, they were happy) (literally: they that music having-heard joy underwent) It is important that the learner understands the use of the gerund. Not a single bit of adult conversation is spoken, nor is a single column of newspaper text printed, without the use of gerunds. The learner may now understand what the ordinary Kannada sen- tence structure would be if one wishes to translate a complex English sentence like the one given above. “I left the house, walked to the bus, got on the bus, went downtown, got off, and walked to the office” be-
#  Plural_details: {'word': 'gerunds', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'It', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I did that
#  Plural_details: None, gender_details: []
# Sentence: I have done that (lit.: I that having-done am)
#  Plural_details: None, gender_details: []
# Sentence: I went
#  Plural_details: None, gender_details: []
# Sentence: I have gone (lit.: I having-gone am) Like the English perfect, this construction signifies that an action or
#  Plural_details: None, gender_details: []
# Sentence: I have read the book
#  Plural_details: None, gender_details: []
# Sentence: I had read the book
#  Plural_details: None, gender_details: []
# Sentence: I will have read the book
#  Plural_details: None, gender_details: []
# Sentence: that tree has grown tall After what has been said about gerunds in this lesson, one can now
#  Plural_details: {'word': 'gerunds', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: he has done this work badly Literally: “he this work, a bad thing having become, has made.” Obvi- ously, the ‘he’ has not become a bad thing; it is the work that he was doing, that has become bad; in other words, he did the work badly.
#  Plural_details: {'word': 'words', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he spoke very cruelly
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: she has done that very beautifully
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: she participated in that conference as a writer
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he worked in a temple as a priest Literally, the two above sentences mean “she, writer having become, in that con ference participated” and “he, priest having become, in temple work did”. When used with nouns that denote conditions, the meaning is that that condition has come about:
#  Plural_details: {'word': 'conditions', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: they came tired
#  Plural_details: None, gender_details: []
# Sentence: soon, fast, quickly
#  Plural_details: None, gender_details: []
# Sentence: he went home immersed in thought (lit.: he thought making home-to went) This participial use of the present participle does not occur as often as
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I am reading the book
#  Plural_details: None, gender_details: []
# Sentence: I was reading the book
#  Plural_details: None, gender_details: []
# Sentence: I will be reading the book However, there are a few alternatives: for ‘I am reading’ one can find
#  Plural_details: {'word': 'alternatives', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I did the work
#  Plural_details: None, gender_details: []
# Sentence: I had the work done (by someone else)
#  Plural_details: None, gender_details: []
# Sentence: I’ll finish that
#  Plural_details: None, gender_details: []
# Sentence: a mistake is visible here
#  Plural_details: None, gender_details: []
# Sentence: I’ll show your mistake
#  Plural_details: None, gender_details: []
# Sentence: to explain
#  Plural_details: None, gender_details: []
# Sentence: Word by word, the Kannada sentence runs “I seen man there goes”. What has happened here? The most remarkable part of this sen-
#  Plural_details: None, gender_details: []
# Sentence: Here again, the ‘me’ must be the object of the ‘seeing’, therefore the ‘man’ must be the agent; but ‘man’ here is also in the accusative case.
#  Plural_details: None, gender_details: []
# Sentence: (Me seen man-to book gave-I.)
#  Plural_details: None, gender_details: []
# Sentence: means: “The fruit that was shown to me is tasty (good).” Here it is
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the work that was done there (‘there done work’)
#  Plural_details: None, gender_details: []
# Sentence: the place about which I was told (‘me-to said place’)
#  Plural_details: None, gender_details: []
# Sentence: the city to which he came
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the city where he lived
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the letter which she wrote
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the letter that I had written to her
#  Plural_details: None, gender_details: [{'word': 'her', 'morph': {'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}]
# Sentence: the place about which he speaks
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the place about which I am being told
#  Plural_details: None, gender_details: []
# Sentence: the city where he lives
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the letter which she writes
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the letter that is being written to her
#  Plural_details: None, gender_details: [{'word': 'her', 'morph': {'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}]
# Sentence: the letter which I read
#  Plural_details: None, gender_details: []
# Sentence: he who did this work Such pronominalizations of relative participles are very common, and it is important that the learner understands the mechanism behind them.
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: a boy who is walking / a walking boy
#  Plural_details: None, gender_details: []
# Sentence: a blossomed flower / a flower that has bloomed When in lesson 1 the pronouns were discussed, it was shown that the pronouns for the third person are actually pronominalization endings that are preceded by demonstrative prefixes for ‘distance’ or ‘proximi- ty’ as possible attributes of the person that are expressed in the ending
#  Plural_details: {'word': 'attributes', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'it', 'morph': {'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I call the boy who is walking
#  Plural_details: None, gender_details: []
# Sentence: I call the one who is walking (walking-[male]-person I call)
#  Plural_details: None, gender_details: []
# Sentence: I saw the flower that blossomed
#  Plural_details: None, gender_details: []
# Sentence: I saw the one that blossomed (blossomed-thing I saw) We can also use these pronominalized relative participles to say some- thing about (for instance) a boy who came home and saw the flower that blossomed (‘the one who came home saw the one that had blos- somed’ becomes ‘home-to come-male-person [nominative] blossomed- thing [accusative] saw [3rd person singular masculine]’):
#  Plural_details: {'word': 'participles', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: A sentence such as this last one could be literally translated as ‘the man who came home saw the thing that had blossomed’, or, depending on the context of the sentence, ‘when he came home he saw what had blos- somed’. (We will see a more usual method of indicating time in lesson
#  Plural_details: {'word': 'We', 'morph': {'Case': 'Nom', 'Number': 'Plur', 'Person': '1', 'PronType': 'Prs'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I will sing as much as he sang (‘he sang-that- much I will sing’)
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the man whom I saw yesterday goes there
#  Plural_details: None, gender_details: []
# Sentence: I gave a book to the man who saw me yesterday Literally, what is said in these two sentences is “which man did I see yesterday? He goes there”, and “which man saw me yesterday? I gave him a book”.
#  Plural_details: {'word': 'sentences', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'He', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'him', 'morph': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I will see her where we met before Or more literally: “where did we meet before? I will see her there”. Such quasi-questions can also be used in equative sentences:
#  Plural_details: {'word': 'sentences', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'her', 'morph': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'her', 'morph': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I will not do so much work as she has done (‘how much work has she done? I will not do so much’) Curiously enough, although this construction is considered clumsy and arti fi cial and is rarely used, whether in conversation or in writing, a shortened form is often used collo quially to express doubt about some- thing:
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: [I] don’t know
#  Plural_details: None, gender_details: []
# Sentence: I don’t know whether I should laugh or cry More literally: “When will he come? It is not known”, and “Should one laugh? Should one cry? It is not known”.
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'It', 'morph': {'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'It', 'morph': {'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: rising It is largely a matter of convention which suffix is used for the for- mation of which noun: therefore the learner must learn these nouns separately. These verbal nouns are inflected just as any other neuter
#  Plural_details: {'word': 'nouns', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'It', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: what he does is not nice
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: doing is good
#  Plural_details: None, gender_details: []
# Sentence: What she is writing is a short story. In the third model sentence, we have what corresponds to a verbal noun in most European languages (which, however, is a conceptional
#  Plural_details: {'word': 'languages', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I’ll do that work. Or I
#  Plural_details: None, gender_details: []
# Sentence: Doing [the work] is good [i.e., is preferable]. There are two important reasons for preferring verbal nouns of this
#  Plural_details: {'word': 'nouns', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: Literally, these sentences say “I Kannada learning-for having-come am- I” and “that book buying-for money having-brought am-I”. This use of the dative of a verbal noun for indicating purpose is so extremely common that one hears various contracted forms in the spoken lan-
#  Plural_details: {'word': 'forms', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I have come to learn Kannada
#  Plural_details: None, gender_details: []
# Sentence: I have brought money to buy that book One could also perfectly well say:
#  Plural_details: None, gender_details: []
# Sentence: I need / want water [lit.: ‘to-me water is-needed’
#  Plural_details: None, gender_details: []
# Sentence: [one] needs time to do that work [lit.: that work doing-for time is-needed’]
#  Plural_details: None, gender_details: []
# Sentence: Do you want some
#  Plural_details: None, gender_details: []
# Sentence: I want to / must go home [I home-to to go is-needed]
#  Plural_details: None, gender_details: []
# Sentence: I want to / must see them [I them to-see is-needed]
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: []
# Sentence: [I] must go home and go to bed soon [lit.: home-to having-gone quickly to-lie-down is-needed]
#  Plural_details: None, gender_details: []
# Sentence: do not do that! [lit.: thus to-do is-not-desired]
#  Plural_details: None, gender_details: []
# Sentence: please do not do that [lit.: pity having-placed thus to-do is-not-desired]
#  Plural_details: None, gender_details: []
# Sentence: I do not want to do that work [lit.: I that work doing is-not-desired]
#  Plural_details: None, gender_details: []
# Sentence: May I come too? [lit.: I-also to-come is-permitted- (question)?]
#  Plural_details: None, gender_details: []
# Sentence: I don’t know, but they too may come
#  Plural_details: {'word': 'they', 'morph': {'Case': 'Nom', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: []
# Sentence: I am not allowed to do that
#  Plural_details: None, gender_details: []
# Sentence: they do not do / will not do
#  Plural_details: None, gender_details: []
# Sentence: I do not write / will not write
#  Plural_details: None, gender_details: []
# Sentence: we do not write / will not write
#  Plural_details: None, gender_details: []
# Sentence: they do not write / will not write An object, or other parts of the sentence, are generally placed between the subject and the verbal noun.
#  Plural_details: {'word': 'parts', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I will not write the letter
#  Plural_details: None, gender_details: []
# Sentence: they will not write the book
#  Plural_details: None, gender_details: []
# Sentence: we will not write the letter tomorrow There is a separate negative form for the present continuous mood,
#  Plural_details: None, gender_details: []
# Sentence: The first possibility is by far the most common; the second and third are used when a speaker wishes to emphasize the momentary actuality, and the fourth possibility is found mainly in the northern part of the Kannada linguistic area. Also here, the verbal forms say nothing about the agent and are invariable:
#  Plural_details: {'word': 'forms', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I did not write
#  Plural_details: None, gender_details: []
# Sentence: you did not write
#  Plural_details: None, gender_details: []
# Sentence: they did not write
#  Plural_details: None, gender_details: []
# Sentence: I did not write the letter
#  Plural_details: None, gender_details: []
# Sentence: they did not write the book
#  Plural_details: None, gender_details: []
# Sentence: we did not write the letter yesterday
#  Plural_details: None, gender_details: []
# Sentence: I have not done the work
#  Plural_details: None, gender_details: []
# Sentence: they have not written the book
#  Plural_details: None, gender_details: []
# Sentence: we have not written the letter yesterday
#  Plural_details: None, gender_details: []
# Sentence: I was not a student (‘I had not become a student’)
#  Plural_details: None, gender_details: []
# Sentence: I will not be a student (‘I will not have become a student’)
#  Plural_details: None, gender_details: []
# Sentence: I will be a student More literally, these three sentences could be translated as ‘I had be- come a student’ / ‘I was as a student’, ‘I have become a student’ / ‘I am as a student’, and ‘I will have become a student’ / ‘I will be as a student’. Yet this is the way in which the English sentences ‘I was a student’ etc. are translated into Kannada while retaining the three different tenses.
#  Plural_details: {'word': 'tenses', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: are both correct and both can be translated as ‘this is difficult’. (The only difference is that because there is no indication of tense in the first sentence, that sentence suggests that ‘this’ is difficult not only now, but in general and always.)
#  Plural_details: None, gender_details: []
# Sentence: I need that book
#  Plural_details: None, gender_details: []
# Sentence: I needed that book
#  Plural_details: None, gender_details: []
# Sentence: I will need that book
#  Plural_details: None, gender_details: []
# Sentence: I will need that book It is useful to think of such a sentence as meaning ‘that book becomes a required thing for me’.
#  Plural_details: None, gender_details: [{'word': 'It', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: “I’ll come tomorrow,” he said
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: “this is nice,” I thought
#  Plural_details: None, gender_details: []
# Sentence: she feared that he would not come For the sake of clarity, the reported speech has been placed between quotation marks in two of the above examples. Syntactically there is no difference in Kannada between the equivalents of “‘I’ll come tomor- row,’ he said” and “he said that he’ll come tomorrow”. Kannada has only this one construction: first the reported speech, then a form of
#  Plural_details: {'word': 'equivalents', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: she feared that he would not come
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I thought this is nice
#  Plural_details: None, gender_details: []
# Sentence: he wrote that this is very difficult
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: she feared that he would not come
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he wrote that this is very difficult
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he said that [we / he / somebody] have / has to go
#  Plural_details: {'word': 'we', 'morph': {'Case': 'Nom', 'Number': 'Plur', 'Person': '1', 'PronType': 'Prs'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: they went to a place named ‘London’
#  Plural_details: None, gender_details: []
# Sentence: I do not like the idea that girls should not read much
#  Plural_details: {'word': 'girls', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: they say he didn’t do it
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: Mysore is reported to be a beautiful town The reader must be careful not to mistake this word for the homonym
#  Plural_details: None, gender_details: []
# Sentence: I have a nose
#  Plural_details: None, gender_details: []
# Sentence: you have intelligence [ = you are intelligent]
#  Plural_details: None, gender_details: []
# Sentence: I have three younger brothers (2) Possession of material goods other than body parts is not considered
#  Plural_details: {'word': 'parts', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I have a house [lit. ‘my house is’] One also may find a variation of this construction, using a pronominal- ized genitive:
#  Plural_details: None, gender_details: []
# Sentence: you have many books [lit. ‘where you are, many books are’]
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: he has money [lit. ‘near to him money is’]
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'him', 'morph': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: an institution that has money
#  Plural_details: None, gender_details: []
# Sentence: a student with intelligence
#  Plural_details: None, gender_details: []
# Sentence: an institution without money
#  Plural_details: None, gender_details: []
# Sentence: that work is being done This type of construction, although commonly understood, is consid-
#  Plural_details: None, gender_details: []
# Sentence: this is being done by him (In practice, this is rarely done, because the main reason for using a passive con struction is to focus on the logical object.) A more common construction to achieve the same result (namely, to indicate that a transitive action takes place, without indicating the
#  Plural_details: None, gender_details: [{'word': 'him', 'morph': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: that work is being done
#  Plural_details: None, gender_details: []
# Sentence: that work was done
#  Plural_details: None, gender_details: []
# Sentence: those books have been read Also this construction is not often used, although clearly more fre-
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: if he had done this, I too would have come
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he is my relative, that is to say, my cousin [uncle’s son]
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: that work is very difficult, in other words: I will not do it
# ...
# Sentence: all the fruits
#  Plural_details: None, gender_details: []
# Sentence: all the students
#  Plural_details: None, gender_details: []
# Sentence: I saw all the students
#  Plural_details: {'word': 'students', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: he ate all the fruits
#  Plural_details: {'word': 'fruits', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he ate all the fruits
#  Plural_details: {'word': 'fruits', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he thinks that he [himself] is the best
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'himself', 'morph': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs', 'Reflex': 'Yes'}}]
# Sentence: she has forgotten her [own] book
#  Plural_details: None, gender_details: [{'word': 'she', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'her', 'morph': {'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}]
# Sentence: he did this work himself
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'himself', 'morph': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs', 'Reflex': 'Yes'}}]
# Sentence: he came just now
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: what does your eminence wish, lord?
#  Plural_details: None, gender_details: []
# Sentence: it is enough if your highness says so
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I write this [for my own use, lit. ‘having written, I take’]
#  Plural_details: None, gender_details: []
# Sentence: did you understand this? [‘having understood this, did you take?’]
#  Plural_details: None, gender_details: []
# Sentence: I have taken that
#  Plural_details: None, gender_details: []
# Sentence: I have brought that
#  Plural_details: None, gender_details: []
# Sentence: he took it away
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: did you invite them? [‘having called them, did you take?’]
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: []
# Sentence: bring (it)
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I have brought them along
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: []
# Sentence: I write this [for somebody else’s use, lit. ‘having written, I give’]
#  Plural_details: None, gender_details: []
# Sentence: I finished reading that book
#  Plural_details: None, gender_details: []
# Sentence: get that work done!
#  Plural_details: None, gender_details: []
# Sentence: they will finish writing that
#  Plural_details: None, gender_details: []
# Sentence: please get rid of that!
#  Plural_details: None, gender_details: []
# Sentence: the father allows his son to read
#  Plural_details: None, gender_details: [{'word': 'his', 'morph': {'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}]
# Sentence: one can do that, or not One can think of such expressions as ‘you can do that, or leave it’.
#  Plural_details: {'word': 'expressions', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: that was lost
#  Plural_details: None, gender_details: []
# Sentence: he ran away (i.e., he ran in such a manner that he disappeared)
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: that window is thoroughly broken Two examples from linguistic literature in Kannada:
#  Plural_details: {'word': 'examples', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: this develops nicely [‘this nicely takes development’]
#  Plural_details: None, gender_details: []
# Sentence: he embarrasses everybody [‘causes all to suffer shyness’]
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: what do you know
#  Plural_details: None, gender_details: []
# Sentence: I can do that
#  Plural_details: None, gender_details: []
# Sentence: people who know how to do it will not come here
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: he is also my friend
#  Plural_details: None, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: shall I bring those magazines tomorrow? okay, please bring them It is often used in the meaning ‘or’, when the speaker is indifferent to whether one situation or another arises:
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: [{'word': 'It', 'morph': {'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: please come on Thursday or Friday Such utterances should be understood as ‘let it be Thursday, let it be Friday (it does not matter which one of these days it is), please come’.
#  Plural_details: {'word': 'days', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I got it
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I have got it
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: I met him
#  Plural_details: None, gender_details: [{'word': 'him', 'morph': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: it is proper to do that [‘so-doing is a proper thing’] Very often, however, one finds the combination of a verb in the short
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: the people who will be there mean exactly the same. The difference is merely a stylistic one, the
#  Plural_details: None, gender_details: []
# Sentence: do you know English? [‘does English come to you?’]
#  Plural_details: None, gender_details: []
# Sentence: I know how to play the flute [‘the flute comes to me’]
#  Plural_details: None, gender_details: []
# Sentence: it is possible to write that
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: it is possible to write that
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: it is possible to write that
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: it is not possible to write that
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: it is not possible to write that
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: it is not possible to write that
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: it is not possible to write that
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Nom', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: There are a few trees over there. Fruits can be seen in five of them.
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: []
# Sentence: Fruits have fallen from four of them. Expressions such as the above are rather rare in modern practice. These
#  Plural_details: {'word': 'These', 'morph': {'Number': 'Plur', 'PronType': 'Dem'}}, gender_details: []
# Sentence: add two to six
#  Plural_details: None, gender_details: []
# Sentence: multiply three by four
#  Plural_details: None, gender_details: []
# Sentence: divide one hundred by twenty The numerals eleven to nineteen demand some attention. Note that
#  Plural_details: None, gender_details: []
# Sentence: There are seven bags over there. The fourth one contains apples [lit.: in the fourth one there are apples].
#  Plural_details: {'word': 'apples', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: See how many people come in. When the one-hundredth person has come, send the remaining persons somewhere else.
#  Plural_details: {'word': 'persons', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: four books
#  Plural_details: None, gender_details: []
# Sentence: The procession went through three streets.
#  Plural_details: {'word': 'streets', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: [I] need those four books. In most cases, however, the plain numerals are not used with nouns
#  Plural_details: {'word': 'nouns', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: Four students are standing there.
#  Plural_details: None, gender_details: []
# Sentence: He has sold fruits to ten customers. Alternatively, up to the count of five, one can use pronominalized short forms of numerals.
#  Plural_details: {'word': 'numerals', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'He', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: Both of them may come.
#  Plural_details: None, gender_details: []
# Sentence: I told both of them.
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: []
# Sentence: I have seen three pictures in the museum. All three of them are nice.
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: []
# Sentence: there were dozens of books on the table
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: there were hundreds of people in the street
#  Plural_details: {'word': 'people', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: he spent thousands of rupees
#  Plural_details: {'word': 'rupees', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: A few common verbs have special alternative abbreviated forms of the
#  Plural_details: {'word': 'forms', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I’ll bring them (along with me)
#  Plural_details: {'word': 'them', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '3', 'PronType': 'Prs'}}, gender_details: []
# Sentence: I’ll bring those books
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I’ll take them (persons) to my home
#  Plural_details: {'word': 'persons', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: I’ll take those books home
#  Plural_details: {'word': 'books', 'morph': {'Number': 'Plur'}}, gender_details: []
# Sentence: What lies under the tree?
#  Plural_details: None, gender_details: []
# Sentence: The meal tasted good.
#  Plural_details: None, gender_details: []
# Sentence: There is a water tank near the house.
#  Plural_details: None, gender_details: []
# Sentence: By God’s grace good things happen to us.
#  Plural_details: {'word': 'us', 'morph': {'Case': 'Acc', 'Number': 'Plur', 'Person': '1', 'PronType': 'Prs'}}, gender_details: []
# Sentence: Many people are standing here.
#  Plural_details: None, gender_details: []
# Sentence: How is my work?
#  Plural_details: None, gender_details: []
# Sentence: They come here rarely.
#  Plural_details: None, gender_details: []
# Sentence: Those who do this work always become successful.
#  Plural_details: None, gender_details: []
# Sentence: Kannada is an old, beautiful language; if you learn it, you will like it a lot.
#  Plural_details: None, gender_details: [{'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'it', 'morph': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: 1. This is the door of my house. 2. That is the horn of a cow. 3. The tip of the horn is not sharp. 4. My book is there. 5. The colour of the book is red. 6. The colour of your books is yellow. 7. Their colour is
#  Plural_details: {'word': 'Their', 'morph': {'Number': 'Plur', 'Person': '3', 'Poss': 'Yes', 'PronType': 'Prs'}}, gender_details: []
# Sentence: 1. Gaṇēśa! Have you gone home? 2. He was tired and went to sleep. 3. That girl sang elegantly. 4. That boy spoke coarsely. 5. He scolded me badly and went away. 6. She saw that and laughed happily. 7. Read this lesson and ask questions. 8. The neighbours went on travel yesterday and will return next month. 9. Did he really say so? 10. Try hard and read these sentences. 11. Please speak a bit quickly. 12. He
#  Plural_details: {'word': 'sentences', 'morph': {'Number': 'Plur'}}, gender_details: [{'word': 'He', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'He', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'She', 'morph': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'he', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}, {'word': 'He', 'morph': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing', 'Person': '3', 'PronType': 'Prs'}}]
# Sentence: non-vegetarian restaurant
#  Plural_details: None, gender_details: []

# %%
parallel_sentences_with_pos_and_unimorph[0]["spacy_info"]
# Out:
# {'res': [{'word': 'This',
#    'lemma': 'this',
#    'upos': 'PRON',
#    'tag': 'DT',
#    'morph': {'Number': 'Sing', 'PronType': 'Dem'}},
#   {'word': 'is',
#    'lemma': 'be',
#    'upos': 'AUX',
#    'tag': 'VBZ',
#    'morph': {'Mood': 'Ind',
#     'Number': 'Sing',
#     'Person': '3',
#     'Tense': 'Pres',
#     'VerbForm': 'Fin'}},
#   {'word': 'a',
#    'lemma': 'a',
#    'upos': 'DET',
#    'tag': 'DT',
#    'morph': {'Definite': 'Ind', 'PronType': 'Art'}},
#   {'word': 'book',
#    'lemma': 'book',
#    'upos': 'NOUN',
#    'tag': 'NN',
#    'morph': {'Number': 'Sing'}},
#   {'word': '.',
#    'lemma': '.',
#    'upos': 'PUNCT',
#    'tag': '.',
#    'morph': {'PunctType': 'Peri'}}],
#  'tense': 'Pres',
#  'number': 'Sing',
#  'plural_details': None,
#  'genders': [],
#  'genders_details': []}

# %% [markdown]
# # Unimorph analysis and inflection

# %%
result = unimorph.analyze_word("testing", lang="eng")

print(result)
# Out:
# test	testing	V;V.PTCP;PRS
# testing	testing	ADJ
# testing	testing	N;SG

# %%
result = unimorph.inflect_word("test",lang="eng")

print(result)
# Out:
# test	tests	N;PL
# test	tests	V;PRS;3;SG
# test	testing	V;V.PTCP;PRS
# test	tested	V;PST
# test	tested	V;V.PTCP;PST
# test	test	N;SG
# test	test	V;NFIN;IMP+SBJV

# %%
for sentence
